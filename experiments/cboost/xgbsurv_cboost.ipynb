# %% [markdown]
# ## XGBSurv Breslow Benchmark

# %%
from xgbsurv.datasets import (load_metabric, load_flchain, load_rgbsg, load_support, load_tcga)
from xgbsurv import XGBSurv
from xgbsurv.evaluation import cindex_censored, ibs
from xgbsurv.models.utils import sort_X_y
import os
import numpy as np
import pandas as pd
from scipy.stats import uniform as scuniform
from scipy.stats import randint as scrandint
from scipy.stats import loguniform as scloguniform 
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, LabelBinarizer, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.decomposition import PCA
# import models
from xgbsurv.models.breslow_final import breslow_likelihood,get_cumulative_hazard_function_breslow
from xgbsurv.models.efron_final import efron_likelihood
from xgbsurv.models.cind_final import cind_loss
from xgbsurv.models.deephit_pycox_final import deephit_loss1_pycox
from xgbsurv.models.eh_aft_final import aft_likelihood
from xgbsurv.models.eh_ah_final import ah_likelihood
from pycox.evaluation import EvalSurv
from sklearn.utils.fixes import loguniform
from xgbsurv.models.utils import sort_X_y_pandas, transform_back, transform
from xgbsurv.preprocessing.dataset_preprocessing import discretizer_df
import os
import sys
current_path = os.getcwd() 
one_level_up = os.path.abspath(os.path.join(current_path,  ".."))
two_levels_up = os.path.abspath(os.path.join(current_path,  "..",".."))
sys.path.append(one_level_up+'/gbdt_pipeline')
from gbdt_pipeline import get_gbdt_pipeline, train_gbdt, train_gbdt_complete
# Out:
# current path /Users/JUSC/Documents/xgbsurv/experiments/cboost

# %% [markdown]
# ## Set Parameters

# %%
# set parameters
n_outer_splits = 5
n_inner_splits = 5
rand_state = 42
n_iter = 10
early_stopping_rounds=10
base_score = 0.0
validation_size = 0.2


# set seed for scipy
np.random.seed(rand_state)

# %% [markdown]
# ## Custom Splitting

# %%
class CustomSplit(StratifiedKFold):
    def __init__(self, n_splits=5, shuffle=True, random_state=None):
        super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)

    def split(self, X, y, groups=None):
        try:
            if y.shape[1]>1:
                y = y[:,0]
        except:
            pass
        bins = np.sign(y)
        return super().split(X, bins, groups=groups)

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

outer_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)

# %% [markdown]
# ## Training

# %%
data_set_fns = [load_metabric,  load_flchain, load_rgbsg, load_support] 
metrics_list = []

for idx, dataset in enumerate(data_set_fns):
    model = 'cind'
    # get name of current dataset
    data = dataset(path=two_levels_up+"/xgbsurv/datasets/data/", as_frame=True)
    filename = data.filename
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()

    print(filename)

    X, y = sort_X_y_pandas(X, y)
    dataset_name = filename.split('_')[0]
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        print(i)
        metric = train_gbdt_complete(dataset_name, X, y, i,  train_index, test_index, model, n_iter)
        print(metric)
        metrics_list.append(metric)
# Out:
# METABRIC_adapted.csv
# 0
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.513847420403411
# Concordance Index Test 0.49220269036942976
# {'model': 'cind', 'dataset': 'METABRIC', 'cindex_train': [0.513847420403411], 'cindex_test': [0.49220269036942976], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 1
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.5036058970998875
# Concordance Index Test 0.5009538044012665
# {'model': 'cind', 'dataset': 'METABRIC', 'cindex_train': [0.5036058970998875], 'cindex_test': [0.5009538044012665], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 2
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.6696579872132606
# Concordance Index Test 0.49849334892849356
# {'model': 'cind', 'dataset': 'METABRIC', 'cindex_train': [0.6696579872132606], 'cindex_test': [0.49849334892849356], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 3
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.6035801607570628
# Concordance Index Test 0.4982784570026596
# {'model': 'cind', 'dataset': 'METABRIC', 'cindex_train': [0.6035801607570628], 'cindex_test': [0.4982784570026596], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 4
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.6569758024322169
# Concordance Index Test 0.5065730235908518
# {'model': 'cind', 'dataset': 'METABRIC', 'cindex_train': [0.6569758024322169], 'cindex_test': [0.5065730235908518], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# FLCHAIN_adapted.csv
# 0
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.581040848386884
# Concordance Index Test 0.5450781865226685
# {'model': 'cind', 'dataset': 'FLCHAIN', 'cindex_train': [0.581040848386884], 'cindex_test': [0.5450781865226685], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 1
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.5780139908938136
# Concordance Index Test 0.5732140702024751
# {'model': 'cind', 'dataset': 'FLCHAIN', 'cindex_train': [0.5780139908938136], 'cindex_test': [0.5732140702024751], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 2
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.48452868143317845
# Concordance Index Test 0.48568482910535277
# {'model': 'cind', 'dataset': 'FLCHAIN', 'cindex_train': [0.48452868143317845], 'cindex_test': [0.48568482910535277], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 3
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.5801829868949749
# Concordance Index Test 0.5723886610710076
# {'model': 'cind', 'dataset': 'FLCHAIN', 'cindex_train': [0.5801829868949749], 'cindex_test': [0.5723886610710076], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 4
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.584620462777587
# Concordance Index Test 0.6094601621271805
# {'model': 'cind', 'dataset': 'FLCHAIN', 'cindex_train': [0.584620462777587], 'cindex_test': [0.6094601621271805], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# RGBSG_adapted.csv
# 0
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.6123777550478968
# Concordance Index Test 0.5507149602050452
# {'model': 'cind', 'dataset': 'RGBSG', 'cindex_train': [0.6123777550478968], 'cindex_test': [0.5507149602050452], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 1
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.6057562287487409
# Concordance Index Test 0.5604334998936848
# {'model': 'cind', 'dataset': 'RGBSG', 'cindex_train': [0.6057562287487409], 'cindex_test': [0.5604334998936848], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 2
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.6063007934549378
# Concordance Index Test 0.6158355030375859
# {'model': 'cind', 'dataset': 'RGBSG', 'cindex_train': [0.6063007934549378], 'cindex_test': [0.6158355030375859], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 3
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.5603443598264678
# Concordance Index Test 0.5148523513418934
# {'model': 'cind', 'dataset': 'RGBSG', 'cindex_train': [0.5603443598264678], 'cindex_test': [0.5148523513418934], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 4
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.6128304481597293
# Concordance Index Test 0.5496434961412129
# {'model': 'cind', 'dataset': 'RGBSG', 'cindex_train': [0.6128304481597293], 'cindex_test': [0.5496434961412129], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# SUPPORT_adapted.csv
# 0
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.5103794918587414
# Concordance Index Test 0.5121786088851624
# {'model': 'cind', 'dataset': 'SUPPORT', 'cindex_train': [0.5103794918587414], 'cindex_test': [0.5121786088851624], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 1
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# Concordance Index 0.5213125909493073
# Concordance Index Test 0.5170689186543019
# {'model': 'cind', 'dataset': 'SUPPORT', 'cindex_train': [0.5213125909493073], 'cindex_test': [0.5170689186543019], 'ibs_train': [nan], 'ibs_score_test': [nan]}
# 2
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# split type <class 'pandas.core.series.Series'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 19
#      17 for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
#      18     print(i)
# ---> 19     metric = train_gbdt_complete(dataset_name, X, y, i,  train_index, test_index, model, n_iter)
#      20     print(metric)
#      21     metrics_list.append(metric)
#
# File ~/Documents/xgbsurv/experiments/gbdt_pipeline/gbdt_pipeline.py:182, in train_gbdt_complete(dataset_name, X, y, i, train_index, test_index, model, n_iter, tcga, rand_state, early_stopping_rounds, base_score, validation_size, verbose, one_hot, n_inner_splits)
#     179 np.savetxt(current_path+'/splits/'+model+'_test_index_'+str(i)+'_'+dataset_name+'.csv', test_index, delimiter=',')
#     181 #pipeline = get_gbdt_pipeline(tcga=tcga,n_iter=n_iter, model=model)
# --> 182 rs.fit(X_train, y_train, estimator__eval_test_size=validation_size, estimator__verbose=0)
#     183 best_preds_train = rs.best_estimator_.predict(X_train)
#     184 best_preds_test = rs.best_estimator_.predict(X_test)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1768, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1766 def _run_search(self, evaluate_candidates):
#    1767     """Search n_iter candidates from param_distributions"""
# -> 1768     evaluate_candidates(
#    1769         ParameterSampler(
#    1770             self.param_distributions, self.n_iter, random_state=self.random_state
#    1771         )
#    1772     )
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
df0 = pd.DataFrame(metrics_list)
df = df0.applymap(lambda x: x[0] if isinstance(x, list) else x)
df.to_csv(current_path+'/metrics/cind_results.csv',index=False)

# %%
df
# Out:
#       model   dataset  cindex_train  cindex_test  ibs_train  ibs_score_test
# 0   breslow  METABRIC      0.745341     0.612912   0.145024        0.174759
# 1   breslow  METABRIC      0.695357     0.606226   0.155386        0.175399
# 2   breslow  METABRIC      0.689499     0.645441   0.158052        0.175104
# 3   breslow  METABRIC      0.632672     0.630312   0.171385        0.162603
# 4   breslow  METABRIC      0.765917     0.650259   0.132623        0.171128
# 5   breslow   FLCHAIN      0.827295     0.796764   0.090990        0.098480
# 6   breslow   FLCHAIN      0.797720     0.798505   0.095773        0.097963
# 7   breslow   FLCHAIN      0.623857     0.592276   0.109427        0.112703
# 8   breslow   FLCHAIN      0.590481     0.557403   0.110090        0.112125
# 9   breslow   FLCHAIN      0.792733     0.795983   0.100312        0.096178
# 10  breslow     RGBSG      0.671694     0.646216   0.181939        0.185710
# 11  breslow     RGBSG      0.681619     0.676257   0.177937        0.183693
# 12  breslow     RGBSG      0.734856     0.682168   0.167949        0.179800
# 13  breslow     RGBSG      0.695391     0.648685   0.180342        0.186016
# 14  breslow     RGBSG      0.661911     0.631973   0.186330        0.189891
# 15  breslow   SUPPORT      0.620166     0.604494   0.195052        0.200570
# 16  breslow   SUPPORT      0.626395     0.600511   0.197861        0.201651
# 17  breslow   SUPPORT      0.622089     0.616577   0.197634        0.198038
# 18  breslow   SUPPORT      0.612455     0.591984   0.200490        0.201162
# 19  breslow   SUPPORT      0.619721     0.609770   0.196789        0.198096

# %% [markdown]
# ## TCGA Train, Test, Evaluation

# %%
cancer_types = [
    'BLCA',
    'BRCA',
    'HNSC',
    'KIRC',
    'LGG',
    'LIHC',
    'LUAD',
    'LUSC',
    'OV',
    'STAD'
    ]

metrics_list = []

for i, cancer_type in enumerate(cancer_types):
    model = 'cind'
    # get name of current dataset
    data = load_tcga(path=two_levels_up+"/xgbsurv/datasets/data/",cancer_type=cancer_type, as_frame=True)
    filename = data.filename
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()

    print(filename)

    X, y = sort_X_y_pandas(X, y)
    dataset_name = filename.split('_')[0]
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        print(i)
        metric = train_gbdt_complete(dataset_name, X, y, i,  train_index, test_index, model, n_iter, tcga=True)
        print(metric)
        metrics_list.append(metric)
# Out:
# BLCA_adapted.csv
# 0
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Concordance Index 0.5795580110497237
# Integrated Brier Score: 0.22069817668662348
# {'model': 'breslow', 'dataset': 'BLCA', 'cindex_train': [0.8630849220103987], 'cindex_test': [0.5795580110497237], 'ibs_train': [0.1442221028427697], 'ibs_score_test': [0.22069817668662348]}
# 1
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Concordance Index 0.6040415073730202
# Integrated Brier Score: 0.22763328758709253
# {'model': 'breslow', 'dataset': 'BLCA', 'cindex_train': [0.9161194583565201], 'cindex_test': [0.6040415073730202], 'ibs_train': [0.11619468174451228], 'ibs_score_test': [0.22763328758709253]}
# 2
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Concordance Index 0.6027479091995221
# Integrated Brier Score: 0.24098837996808853
# {'model': 'breslow', 'dataset': 'BLCA', 'cindex_train': [0.762380538662033], 'cindex_test': [0.6027479091995221], 'ibs_train': [0.18671799337309586], 'ibs_score_test': [0.24098837996808853]}
# 3
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Concordance Index 0.4329896907216495
# Integrated Brier Score: 0.2164749159451163
# {'model': 'breslow', 'dataset': 'BLCA', 'cindex_train': [0.6596686295307413], 'cindex_test': [0.4329896907216495], 'ibs_train': [0.20675651971989306], 'ibs_score_test': [0.2164749159451163]}
# 4
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Concordance Index 0.4906270200387847
# Integrated Brier Score: 0.2147262464217755
# {'model': 'breslow', 'dataset': 'BLCA', 'cindex_train': [0.5311068836750511], 'cindex_test': [0.4906270200387847], 'ibs_train': [0.21965107998422154], 'ibs_score_test': [0.2147262464217755]}
# BRCA_adapted.csv
# 0
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Concordance Index 0.4244791666666667
# Integrated Brier Score: 0.2155038695136837
# {'model': 'breslow', 'dataset': 'BRCA', 'cindex_train': [0.6242858822146468], 'cindex_test': [0.4244791666666667], 'ibs_train': [0.1750033157654117], 'ibs_score_test': [0.2155038695136837]}
# 1
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Concordance Index 0.6799836934366082
# Integrated Brier Score: 0.18992745269152675
# {'model': 'breslow', 'dataset': 'BRCA', 'cindex_train': [0.9284884134626787], 'cindex_test': [0.6799836934366082], 'ibs_train': [0.10600125202716161], 'ibs_score_test': [0.18992745269152675]}
# 2
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
df0 = pd.DataFrame(metrics_list)
df = df0.applymap(lambda x: x[0] if isinstance(x, list) else x)
df.to_csv(current_path+'/metrics/cind_tcga_results.csv',index=False)

# %%
# Out:
#   dataset  ibs_train_mean  ibs_train_std  ibs_test_mean  ibs_test_std
# 0    BLCA          0.2142         0.0043         0.2228        0.0060
# 0    BRCA          0.1905         0.0046         0.1964        0.0092
# 0    HNSC          0.1833         0.0055         0.2038        0.0074
