# %% [markdown]
# ## XGBSurv Breslow Benchmark

# %%
from xgbsurv.datasets import (load_metabric, load_flchain, load_rgbsg, load_support, load_tcga)
from xgbsurv import XGBSurv
from xgbsurv.evaluation import cindex_censored, ibs
from xgbsurv.models.utils import sort_X_y
import os
import numpy as np
import pandas as pd
from scipy.stats import uniform as scuniform
from scipy.stats import randint as scrandint
from scipy.stats import loguniform as scloguniform 
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, LabelBinarizer, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.decomposition import PCA
# import models
from xgbsurv.models.breslow_final import breslow_likelihood,get_cumulative_hazard_function_breslow
from xgbsurv.models.efron_final import efron_likelihood
from xgbsurv.models.cind_final import cind_loss
from xgbsurv.models.deephit_pycox_final import deephit_loss1_pycox
from xgbsurv.models.eh_aft_final import aft_likelihood
from xgbsurv.models.eh_ah_final import ah_likelihood
from pycox.evaluation import EvalSurv
from xgbsurv.models.utils import sort_X_y_pandas, transform_back, transform
from xgbsurv.preprocessing.dataset_preprocessing import discretizer_df

# %% [markdown]
# ## Set Parameters

# %%
# set parameters
n_outer_splits = 5
n_inner_splits = 5
rand_state = 42
n_iter = 5 #0
early_stopping_rounds=10
base_score = 0.0
validation_size = 0.2

# Define parameter grid for random forest classifier
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
}

# %% [markdown]
# ## Custom Splitting

# %%
class CustomSplit(StratifiedKFold):
    def __init__(self, n_splits=5, shuffle=True, random_state=None):
        super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)

    def split(self, X, y, groups=None):
        try:
            if y.shape[1]>1:
                y = y[:,0]
        except:
            pass
        bins = np.sign(y)
        return super().split(X, bins, groups=groups)

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

outer_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)
inner_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)

# %% [markdown]
# ## Scoring Function

# %%
scoring_function = make_scorer(breslow_likelihood, greater_is_better=False)

# %% [markdown]
# ## Set Model & Train Test Evaluate

# %%
data_set_fns = [load_metabric,  load_flchain, load_rgbsg, load_support] #, load_flchain, load_rgbsg, load_support, load_tcga]
data_set_fns_str = ['load_metabric', 'load_flchain', 'load_rgbsg', 'load_support'] 
one_hot_dict = {'load_flchain': ['mgus'], 'load_support':['cancer'], 'load_rgbsg':['grade']}
agg_metrics_cindex = []
agg_metrics_ibs = []

for idx, dataset in enumerate(data_set_fns):
    model = 'xgbsurv_breslow_'
    # get name of current dataset
    data = dataset(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=True)
    filename = data.filename
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()

    print(data_set_fns_str[idx])
    #if data_set_fns_str[idx] in one_hot_dict.keys():
    #    X = pd.get_dummies(X, columns=one_hot_dict[data_set_fns_str[idx]])
    #print(X)
    X, y = sort_X_y_pandas(X, y)
    #print(X.dtypes)
    dataset_name = filename.split('_')[0]
    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            (StandardScaler(), make_column_selector(dtype_include=['float32'])),
            (OneHotEncoder(sparse_output=False), make_column_selector(dtype_include=['category', 'object']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='breslow_objective',
        eval_metric='breslow_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score,
                        )
    pipe = Pipeline([('scaler',ct),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=n_iter, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        #print(X_train.shape, type(X_train))
        #print(y_train.shape, type(y_train))
        #print(y_test.shape, type(y_test))
        #print(X_test.shape, type(X_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        #np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        #np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        #np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        #np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=validation_size)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        np.savetxt('predictions/'+model+'best_preds_train_'+str(i)+'_'+filename, best_preds_train, delimiter=',')
        np.savetxt('predictions/'+model+'best_preds_test_'+str(i)+'_'+filename, best_preds_test, delimiter=',')


        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_breslow(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_breslow(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
    # cindex
    df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                            'cindex_train_mean':df_outer_scores['cindex_train_'+dataset_name].mean(),
                                            'cindex_train_std':df_outer_scores['cindex_train_'+dataset_name].std(),
                                            'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                            'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })
    # IBS
    df_agg_metrics_ibs = pd.DataFrame({'dataset':[dataset_name],
                                            'ibs_train_mean':df_outer_scores['ibs_train_'+dataset_name].mean(),
                                            'ibs_train_std':df_outer_scores['ibs_train_'+dataset_name].std(),
                                            'ibs_test_mean':df_outer_scores['ibs_test_'+dataset_name].mean(),
                                            'ibs_test_std':df_outer_scores['ibs_test_'+dataset_name].std() })
    agg_metrics_cindex.append(df_agg_metrics_cindex)
    agg_metrics_ibs.append(df_agg_metrics_ibs)

df_final_breslow_1_cindex = pd.concat([df for df in agg_metrics_cindex]).round(4)
df_final_breslow_1_cindex.to_csv('metrics/final_gbdt_breslow_1_cindex.csv', index=False)
df_final_breslow_1_cindex.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_breslow_1_cindex.csv', index=False)  #


df_final_breslow_1_ibs = pd.concat([df for df in agg_metrics_ibs]).round(4)
df_final_breslow_1_ibs.to_csv('metrics/final_gbdt_breslow_1_ibs.csv', index=False)
df_final_breslow_1_ibs.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_breslow_1_ibs.csv', index=False)
# Out:
# load_metabric
# [0]	validation_0-breslow_likelihood:5.88265	validation_1-breslow_likelihood:4.47556
# [1]	validation_0-breslow_likelihood:5.86663	validation_1-breslow_likelihood:4.47000
# [2]	validation_0-breslow_likelihood:5.84375	validation_1-breslow_likelihood:4.46834
# [3]	validation_0-breslow_likelihood:5.84196	validation_1-breslow_likelihood:4.46796
# [4]	validation_0-breslow_likelihood:5.65117	validation_1-breslow_likelihood:4.52191
# [5]	validation_0-breslow_likelihood:5.63111	validation_1-breslow_likelihood:4.52218
# [6]	validation_0-breslow_likelihood:5.62815	validation_1-breslow_likelihood:4.52088
# [7]	validation_0-breslow_likelihood:5.62547	validation_1-breslow_likelihood:4.52070
# [8]	validation_0-breslow_likelihood:5.60957	validation_1-breslow_likelihood:4.52517
# [9]	validation_0-breslow_likelihood:5.51911	validation_1-breslow_likelihood:4.54061
# [10]	validation_0-breslow_likelihood:5.47811	validation_1-breslow_likelihood:4.56583
# [11]	validation_0-breslow_likelihood:5.47726	validation_1-breslow_likelihood:4.56950
# [12]	validation_0-breslow_likelihood:5.41966	validation_1-breslow_likelihood:4.59085
# [0]	validation_0-breslow_likelihood:5.88640	validation_1-breslow_likelihood:4.47747
# [1]	validation_0-breslow_likelihood:5.87168	validation_1-breslow_likelihood:4.47523
# [2]	validation_0-breslow_likelihood:5.84891	validation_1-breslow_likelihood:4.46997
# [3]	validation_0-breslow_likelihood:5.84848	validation_1-breslow_likelihood:4.46854
# [4]	validation_0-breslow_likelihood:5.77366	validation_1-breslow_likelihood:4.47720
# [5]	validation_0-breslow_likelihood:5.76192	validation_1-breslow_likelihood:4.47738
# [6]	validation_0-breslow_likelihood:5.74871	validation_1-breslow_likelihood:4.49417
# [7]	validation_0-breslow_likelihood:5.72889	validation_1-breslow_likelihood:4.48984
# [8]	validation_0-breslow_likelihood:5.72485	validation_1-breslow_likelihood:4.49032
# [9]	validation_0-breslow_likelihood:5.72484	validation_1-breslow_likelihood:4.49032
# [10]	validation_0-breslow_likelihood:5.70434	validation_1-breslow_likelihood:4.48822
# [11]	validation_0-breslow_likelihood:5.70432	validation_1-breslow_likelihood:4.48822
# [0]	validation_0-breslow_likelihood:5.89391	validation_1-breslow_likelihood:4.47807
# [1]	validation_0-breslow_likelihood:5.89231	validation_1-breslow_likelihood:4.47828
# [12]	validation_0-breslow_likelihood:5.69170	validation_1-breslow_likelihood:4.48824
# [2]	validation_0-breslow_likelihood:5.89079	validation_1-breslow_likelihood:4.47761
# [3]	validation_0-breslow_likelihood:5.88565	validation_1-breslow_likelihood:4.47642
# [4]	validation_0-breslow_likelihood:5.88407	validation_1-breslow_likelihood:4.47526
# [5]	validation_0-breslow_likelihood:5.87949	validation_1-breslow_likelihood:4.47403
# [6]	validation_0-breslow_likelihood:5.87592	validation_1-breslow_likelihood:4.47249
# [7]	validation_0-breslow_likelihood:5.87270	validation_1-breslow_likelihood:4.47128
# [8]	validation_0-breslow_likelihood:5.87075	validation_1-breslow_likelihood:4.47131
# [9]	validation_0-breslow_likelihood:5.87059	validation_1-breslow_likelihood:4.47139
# [10]	validation_0-breslow_likelihood:5.86606	validation_1-breslow_likelihood:4.46871
# [11]	validation_0-breslow_likelihood:5.86096	validation_1-breslow_likelihood:4.46710
# [12]	validation_0-breslow_likelihood:5.85899	validation_1-breslow_likelihood:4.46552
# [0]	validation_0-breslow_likelihood:5.89388	validation_1-breslow_likelihood:4.47746
# [0]	validation_0-breslow_likelihood:5.88607	validation_1-breslow_likelihood:4.47573
# [1]	validation_0-breslow_likelihood:5.89183	validation_1-breslow_likelihood:4.47640
# [13]	validation_0-breslow_likelihood:5.85610	validation_1-breslow_likelihood:4.46502
# [2]	validation_0-breslow_likelihood:5.88734	validation_1-breslow_likelihood:4.47757
# [3]	validation_0-breslow_likelihood:5.88605	validation_1-breslow_likelihood:4.47689
# [1]	validation_0-breslow_likelihood:5.87667	validation_1-breslow_likelihood:4.47215
# [4]	validation_0-breslow_likelihood:5.88582	validation_1-breslow_likelihood:4.47696
# [14]	validation_0-breslow_likelihood:5.85499	validation_1-breslow_likelihood:4.46415
# [0]	validation_0-breslow_likelihood:5.89361	validation_1-breslow_likelihood:4.47835
# [5]	validation_0-breslow_likelihood:5.88135	validation_1-breslow_likelihood:4.47627
# [1]	validation_0-breslow_likelihood:5.89193	validation_1-breslow_likelihood:4.47794
# [2]	validation_0-breslow_likelihood:5.88991	validation_1-breslow_likelihood:4.47762
# [6]	validation_0-breslow_likelihood:5.88086	validation_1-breslow_likelihood:4.47612
# [2]	validation_0-breslow_likelihood:5.86481	validation_1-breslow_likelihood:4.47634
# [7]	validation_0-breslow_likelihood:5.88041	validation_1-breslow_likelihood:4.47542
# [15]	validation_0-breslow_likelihood:5.85091	validation_1-breslow_likelihood:4.46167
# [8]	validation_0-breslow_likelihood:5.87499	validation_1-breslow_likelihood:4.47332
# [3]	validation_0-breslow_likelihood:5.86312	validation_1-breslow_likelihood:4.47516
# [3]	validation_0-breslow_likelihood:5.88614	validation_1-breslow_likelihood:4.47723
# [9]	validation_0-breslow_likelihood:5.87487	validation_1-breslow_likelihood:4.47311
# [16]	validation_0-breslow_likelihood:5.85091	validation_1-breslow_likelihood:4.46166
# [4]	validation_0-breslow_likelihood:5.81288	validation_1-breslow_likelihood:4.48149
# [5]	validation_0-breslow_likelihood:5.79046	validation_1-breslow_likelihood:4.50157
# [17]	validation_0-breslow_likelihood:5.84932	validation_1-breslow_likelihood:4.46141
# [6]	validation_0-breslow_likelihood:5.77682	validation_1-breslow_likelihood:4.49497
# [10]	validation_0-breslow_likelihood:5.87342	validation_1-breslow_likelihood:4.47185
# [18]	validation_0-breslow_likelihood:5.84607	validation_1-breslow_likelihood:4.45928[4]	validation_0-breslow_likelihood:5.88465	validation_1-breslow_likelihood:4.47765
#
# [7]	validation_0-breslow_likelihood:5.74868	validation_1-breslow_likelihood:4.54050
# [19]	validation_0-breslow_likelihood:5.84337	validation_1-breslow_likelihood:4.45899
# [8]	validation_0-breslow_likelihood:5.74392	validation_1-breslow_likelihood:4.53935
# [11]	validation_0-breslow_likelihood:5.87283	validation_1-breslow_likelihood:4.47185
# [5]	validation_0-breslow_likelihood:5.88019	validation_1-breslow_likelihood:4.47662
# [6]	validation_0-breslow_likelihood:5.87269	validation_1-breslow_likelihood:4.47551
# [12]	validation_0-breslow_likelihood:5.87256	validation_1-breslow_likelihood:4.47161
# [9]	validation_0-breslow_likelihood:5.74001	validation_1-breslow_likelihood:4.53595
# [13]	validation_0-breslow_likelihood:5.87205	validation_1-breslow_likelihood:4.47121
# [14]	validation_0-breslow_likelihood:5.86247	validation_1-breslow_likelihood:4.46858
# [7]	validation_0-breslow_likelihood:5.86850	validation_1-breslow_likelihood:4.47568
# [15]	validation_0-breslow_likelihood:5.85762	validation_1-breslow_likelihood:4.46670
# [16]	validation_0-breslow_likelihood:5.85223	validation_1-breslow_likelihood:4.46452
# [10]	validation_0-breslow_likelihood:5.72962	validation_1-breslow_likelihood:4.53154
# [8]	validation_0-breslow_likelihood:5.86641	validation_1-breslow_likelihood:4.47572
# [17]	validation_0-breslow_likelihood:5.85081	validation_1-breslow_likelihood:4.46385
# [18]	validation_0-breslow_likelihood:5.84612	validation_1-breslow_likelihood:4.46232
# [9]	validation_0-breslow_likelihood:5.86629	validation_1-breslow_likelihood:4.47595
# [19]	validation_0-breslow_likelihood:5.83937	validation_1-breslow_likelihood:4.46317
# [0]	validation_0-breslow_likelihood:5.89325	validation_1-breslow_likelihood:4.47749
# [10]	validation_0-breslow_likelihood:5.86031	validation_1-breslow_likelihood:4.47280
# [1]	validation_0-breslow_likelihood:5.89114	validation_1-breslow_likelihood:4.47673
# [11]	validation_0-breslow_likelihood:5.85279	validation_1-breslow_likelihood:4.47276
# [2]	validation_0-breslow_likelihood:5.88998	validation_1-breslow_likelihood:4.47698
# [3]	validation_0-breslow_likelihood:5.88694	validation_1-breslow_likelihood:4.47642
# [12]	validation_0-breslow_likelihood:5.84912	validation_1-breslow_likelihood:4.47111
# [4]	validation_0-breslow_likelihood:5.88617	validation_1-breslow_likelihood:4.47585
# [5]	validation_0-breslow_likelihood:5.88098	validation_1-breslow_likelihood:4.47600
# [6]	validation_0-breslow_likelihood:5.87528	validation_1-breslow_likelihood:4.47487
# [13]	validation_0-breslow_likelihood:5.84607	validation_1-breslow_likelihood:4.47126
# [7]	validation_0-breslow_likelihood:5.86995	validation_1-breslow_likelihood:4.47375
# [8]	validation_0-breslow_likelihood:5.86771	validation_1-breslow_likelihood:4.47433
# [9]	validation_0-breslow_likelihood:5.86763	validation_1-breslow_likelihood:4.47450
# [14]	validation_0-breslow_likelihood:5.84450	validation_1-breslow_likelihood:4.47058
# [10]	validation_0-breslow_likelihood:5.86226	validation_1-breslow_likelihood:4.47332
# [0]	validation_0-breslow_likelihood:5.88527	validation_1-breslow_likelihood:4.47591
# [11]	validation_0-breslow_likelihood:5.85495	validation_1-breslow_likelihood:4.47106
# [12]	validation_0-breslow_likelihood:5.85210	validation_1-breslow_likelihood:4.46996
# [15]	validation_0-breslow_likelihood:5.83900	validation_1-breslow_likelihood:4.46941
# [16]	validation_0-breslow_likelihood:5.83900	validation_1-breslow_likelihood:4.46941
# [17]	validation_0-breslow_likelihood:5.83744	validation_1-breslow_likelihood:4.46951
# [1]	validation_0-breslow_likelihood:5.86505	validation_1-breslow_likelihood:4.47647
# [18]	validation_0-breslow_likelihood:5.83315	validation_1-breslow_likelihood:4.46890
# [2]	validation_0-breslow_likelihood:5.83870	validation_1-breslow_likelihood:4.48107
# [13]	validation_0-breslow_likelihood:5.84895	validation_1-breslow_likelihood:4.46968
# [19]	validation_0-breslow_likelihood:5.83126	validation_1-breslow_likelihood:4.46957
# [0]	validation_0-breslow_likelihood:5.88780	validation_1-breslow_likelihood:4.47649
# [1]	validation_0-breslow_likelihood:5.87701	validation_1-breslow_likelihood:4.47566
# [3]	validation_0-breslow_likelihood:5.83594	validation_1-breslow_likelihood:4.48243
# [14]	validation_0-breslow_likelihood:5.84702	validation_1-breslow_likelihood:4.46945
# [2]	validation_0-breslow_likelihood:5.86420	validation_1-breslow_likelihood:4.47997
# [3]	validation_0-breslow_likelihood:5.86232	validation_1-breslow_likelihood:4.47853
# [0]	validation_0-breslow_likelihood:5.89551	validation_1-breslow_likelihood:4.47811
# [4]	validation_0-breslow_likelihood:5.79370	validation_1-breslow_likelihood:4.47805
# [1]	validation_0-breslow_likelihood:5.89518	validation_1-breslow_likelihood:4.47780
# [0]	validation_0-breslow_likelihood:5.89529	validation_1-breslow_likelihood:4.47815
# [2]	validation_0-breslow_likelihood:5.89518	validation_1-breslow_likelihood:4.47780
# [5]	validation_0-breslow_likelihood:5.77937	validation_1-breslow_likelihood:4.45940
# [15]	validation_0-breslow_likelihood:5.84251	validation_1-breslow_likelihood:4.46914
# [1]	validation_0-breslow_likelihood:5.89375	validation_1-breslow_likelihood:4.47720
# [3]	validation_0-breslow_likelihood:5.89517	validation_1-breslow_likelihood:4.47771
# [6]	validation_0-breslow_likelihood:5.76383	validation_1-breslow_likelihood:4.46211
# [4]	validation_0-breslow_likelihood:5.89437	validation_1-breslow_likelihood:4.47703
# [4]	validation_0-breslow_likelihood:5.64380	validation_1-breslow_likelihood:4.52142
# [7]	validation_0-breslow_likelihood:5.72360	validation_1-breslow_likelihood:4.45855
# [5]	validation_0-breslow_likelihood:5.89372	validation_1-breslow_likelihood:4.47624
# [8]	validation_0-breslow_likelihood:5.72079	validation_1-breslow_likelihood:4.45947
# [16]	validation_0-breslow_likelihood:5.84239	validation_1-breslow_likelihood:4.46920
# [6]	validation_0-breslow_likelihood:5.89337	validation_1-breslow_likelihood:4.47616
# [2]	validation_0-breslow_likelihood:5.89346	validation_1-breslow_likelihood:4.47720
# [9]	validation_0-breslow_likelihood:5.71454	validation_1-breslow_likelihood:4.45831
# [7]	validation_0-breslow_likelihood:5.89339	validation_1-breslow_likelihood:4.47618
# [5]	validation_0-breslow_likelihood:5.61741	validation_1-breslow_likelihood:4.52547
# [10]	validation_0-breslow_likelihood:5.69461	validation_1-breslow_likelihood:4.46895
# [8]	validation_0-breslow_likelihood:5.89282	validation_1-breslow_likelihood:4.47565
# [11]	validation_0-breslow_likelihood:5.69435	validation_1-breslow_likelihood:4.47025[17]	validation_0-breslow_likelihood:5.84059	validation_1-breslow_likelihood:4.46858
# [9]	validation_0-breslow_likelihood:5.89281	validation_1-breslow_likelihood:4.47565
#
# [6]	validation_0-breslow_likelihood:5.61504	validation_1-breslow_likelihood:4.52653
# [10]	validation_0-breslow_likelihood:5.89218	validation_1-breslow_likelihood:4.47497
# [7]	validation_0-breslow_likelihood:5.61397	validation_1-breslow_likelihood:4.52587
# [11]	validation_0-breslow_likelihood:5.88978	validation_1-breslow_likelihood:4.47332
# [3]	validation_0-breslow_likelihood:5.89328	validation_1-breslow_likelihood:4.47718
# [8]	validation_0-breslow_likelihood:5.58826	validation_1-breslow_likelihood:4.51913
# [12]	validation_0-breslow_likelihood:5.88982	validation_1-breslow_likelihood:4.47341[18]	validation_0-breslow_likelihood:5.83583	validation_1-breslow_likelihood:4.46765
#
# [12]	validation_0-breslow_likelihood:5.67308	validation_1-breslow_likelihood:4.47796
# [13]	validation_0-breslow_likelihood:5.88928	validation_1-breslow_likelihood:4.47293
# [4]	validation_0-breslow_likelihood:5.89085	validation_1-breslow_likelihood:4.47626
# [19]	validation_0-breslow_likelihood:5.83352	validation_1-breslow_likelihood:4.46894
# [13]	validation_0-breslow_likelihood:5.66693	validation_1-breslow_likelihood:4.47455
# [14]	validation_0-breslow_likelihood:5.88924	validation_1-breslow_likelihood:4.47303
# [9]	validation_0-breslow_likelihood:5.51456	validation_1-breslow_likelihood:4.54687
# [5]	validation_0-breslow_likelihood:5.89056	validation_1-breslow_likelihood:4.47594
# [15]	validation_0-breslow_likelihood:5.88891	validation_1-breslow_likelihood:4.47274
# [6]	validation_0-breslow_likelihood:5.89041	validation_1-breslow_likelihood:4.47575
# [16]	validation_0-breslow_likelihood:5.88891	validation_1-breslow_likelihood:4.47274
# [7]	validation_0-breslow_likelihood:5.89028	validation_1-breslow_likelihood:4.47576
# [14]	validation_0-breslow_likelihood:5.66618	validation_1-breslow_likelihood:4.47476
# [17]	validation_0-breslow_likelihood:5.88873	validation_1-breslow_likelihood:4.47266
# [8]	validation_0-breslow_likelihood:5.88936	validation_1-breslow_likelihood:4.47494
# [18]	validation_0-breslow_likelihood:5.88797	validation_1-breslow_likelihood:4.47186
# [9]	validation_0-breslow_likelihood:5.88744	validation_1-breslow_likelihood:4.47381
# [19]	validation_0-breslow_likelihood:5.88707	validation_1-breslow_likelihood:4.47142
# [10]	validation_0-breslow_likelihood:5.88670	validation_1-breslow_likelihood:4.47302
# [20]	validation_0-breslow_likelihood:5.88668	validation_1-breslow_likelihood:4.47106
# [15]	validation_0-breslow_likelihood:5.58544	validation_1-breslow_likelihood:4.52420
# [21]	validation_0-breslow_likelihood:5.88658	validation_1-breslow_likelihood:4.47110
# [22]	validation_0-breslow_likelihood:5.88639	validation_1-breslow_likelihood:4.47069
# [16]	validation_0-breslow_likelihood:5.56591	validation_1-breslow_likelihood:4.52721
# [17]	validation_0-breslow_likelihood:5.56115	validation_1-breslow_likelihood:4.53904
# [18]	validation_0-breslow_likelihood:5.52664	validation_1-breslow_likelihood:4.55322
# [11]	validation_0-breslow_likelihood:5.88655	validation_1-breslow_likelihood:4.47275
# [12]	validation_0-breslow_likelihood:5.88657	validation_1-breslow_likelihood:4.47285
# [13]	validation_0-breslow_likelihood:5.88649	validation_1-breslow_likelihood:4.47305
# [14]	validation_0-breslow_likelihood:5.88632	validation_1-breslow_likelihood:4.47320
# [15]	validation_0-breslow_likelihood:5.88616	validation_1-breslow_likelihood:4.47337
# [16]	validation_0-breslow_likelihood:5.88375	validation_1-breslow_likelihood:4.47286
# [17]	validation_0-breslow_likelihood:5.88405	validation_1-breslow_likelihood:4.47299
# [0]	validation_0-breslow_likelihood:5.89480	validation_1-breslow_likelihood:4.47764
# [18]	validation_0-breslow_likelihood:5.88381	validation_1-breslow_likelihood:4.47247
# [19]	validation_0-breslow_likelihood:5.88365	validation_1-breslow_likelihood:4.47265
# [20]	validation_0-breslow_likelihood:5.88363	validation_1-breslow_likelihood:4.47261
# [1]	validation_0-breslow_likelihood:5.89404	validation_1-breslow_likelihood:4.47729
# [21]	validation_0-breslow_likelihood:5.88329	validation_1-breslow_likelihood:4.47279
# [2]	validation_0-breslow_likelihood:5.89376	validation_1-breslow_likelihood:4.47706
# [22]	validation_0-breslow_likelihood:5.88195	validation_1-breslow_likelihood:4.47201
# [0]	validation_0-breslow_likelihood:5.89529	validation_1-breslow_likelihood:4.47834
# [3]	validation_0-breslow_likelihood:5.89376	validation_1-breslow_likelihood:4.47706
# [4]	validation_0-breslow_likelihood:5.89257	validation_1-breslow_likelihood:4.47660
# [5]	validation_0-breslow_likelihood:5.89252	validation_1-breslow_likelihood:4.47606
# [1]	validation_0-breslow_likelihood:5.89487	validation_1-breslow_likelihood:4.47927
# [6]	validation_0-breslow_likelihood:5.89239	validation_1-breslow_likelihood:4.47635
# [7]	validation_0-breslow_likelihood:5.89238	validation_1-breslow_likelihood:4.47649
# [2]	validation_0-breslow_likelihood:5.89487	validation_1-breslow_likelihood:4.47927
# [8]	validation_0-breslow_likelihood:5.89167	validation_1-breslow_likelihood:4.47649
# [3]	validation_0-breslow_likelihood:5.89430	validation_1-breslow_likelihood:4.47871
# [9]	validation_0-breslow_likelihood:5.88951	validation_1-breslow_likelihood:4.47532
# [4]	validation_0-breslow_likelihood:5.89317	validation_1-breslow_likelihood:4.47840[10]	validation_0-breslow_likelihood:5.88937	validation_1-breslow_likelihood:4.47487
#
# [11]	validation_0-breslow_likelihood:5.88927	validation_1-breslow_likelihood:4.47406
# [5]	validation_0-breslow_likelihood:5.89217	validation_1-breslow_likelihood:4.47761
# [12]	validation_0-breslow_likelihood:5.88920	validation_1-breslow_likelihood:4.47358
# [6]	validation_0-breslow_likelihood:5.89207	validation_1-breslow_likelihood:4.47780
# [13]	validation_0-breslow_likelihood:5.88905	validation_1-breslow_likelihood:4.47359
# [7]	validation_0-breslow_likelihood:5.89182	validation_1-breslow_likelihood:4.47800
# [14]	validation_0-breslow_likelihood:5.88944	validation_1-breslow_likelihood:4.47412
# [8]	validation_0-breslow_likelihood:5.89182	validation_1-breslow_likelihood:4.47800
# [15]	validation_0-breslow_likelihood:5.88944	validation_1-breslow_likelihood:4.47412
# [9]	validation_0-breslow_likelihood:5.89181	validation_1-breslow_likelihood:4.47800
# [16]	validation_0-breslow_likelihood:5.88746	validation_1-breslow_likelihood:4.47335
# [10]	validation_0-breslow_likelihood:5.89117	validation_1-breslow_likelihood:4.47722
# [17]	validation_0-breslow_likelihood:5.88758	validation_1-breslow_likelihood:4.47340
# [11]	validation_0-breslow_likelihood:5.89005	validation_1-breslow_likelihood:4.47638
# [18]	validation_0-breslow_likelihood:5.88750	validation_1-breslow_likelihood:4.47358
# [12]	validation_0-breslow_likelihood:5.89004	validation_1-breslow_likelihood:4.47638
# [19]	validation_0-breslow_likelihood:5.88728	validation_1-breslow_likelihood:4.47335
# [13]	validation_0-breslow_likelihood:5.88921	validation_1-breslow_likelihood:4.47576
# [20]	validation_0-breslow_likelihood:5.88720	validation_1-breslow_likelihood:4.47326
# [14]	validation_0-breslow_likelihood:5.88860	validation_1-breslow_likelihood:4.47553
# [21]	validation_0-breslow_likelihood:5.88683	validation_1-breslow_likelihood:4.47315
# [15]	validation_0-breslow_likelihood:5.88819	validation_1-breslow_likelihood:4.47536
# [16]	validation_0-breslow_likelihood:5.88792	validation_1-breslow_likelihood:4.47541
# [22]	validation_0-breslow_likelihood:5.88617	validation_1-breslow_likelihood:4.47282
# [17]	validation_0-breslow_likelihood:5.88747	validation_1-breslow_likelihood:4.47493
# [18]	validation_0-breslow_likelihood:5.88621	validation_1-breslow_likelihood:4.47482
# [19]	validation_0-breslow_likelihood:5.88602	validation_1-breslow_likelihood:4.47498
# [20]	validation_0-breslow_likelihood:5.88602	validation_1-breslow_likelihood:4.47498
# [21]	validation_0-breslow_likelihood:5.88603	validation_1-breslow_likelihood:4.47498
# [22]	validation_0-breslow_likelihood:5.88504	validation_1-breslow_likelihood:4.47415
# [0]	validation_0-breslow_likelihood:5.89504	validation_1-breslow_likelihood:4.47831
# [1]	validation_0-breslow_likelihood:5.89466	validation_1-breslow_likelihood:4.47777
# [0]	validation_0-breslow_likelihood:5.89386	validation_1-breslow_likelihood:4.47797
# [2]	validation_0-breslow_likelihood:5.89466	validation_1-breslow_likelihood:4.47777
# [3]	validation_0-breslow_likelihood:5.89459	validation_1-breslow_likelihood:4.47813
# [1]	validation_0-breslow_likelihood:5.89095	validation_1-breslow_likelihood:4.47629
# [2]	validation_0-breslow_likelihood:5.88693	validation_1-breslow_likelihood:4.47566
# [4]	validation_0-breslow_likelihood:5.89345	validation_1-breslow_likelihood:4.47773
# [3]	validation_0-breslow_likelihood:5.88618	validation_1-breslow_likelihood:4.47457
# [4]	validation_0-breslow_likelihood:5.88598	validation_1-breslow_likelihood:4.47481
# [5]	validation_0-breslow_likelihood:5.88142	validation_1-breslow_likelihood:4.47418
# [5]	validation_0-breslow_likelihood:5.89328	validation_1-breslow_likelihood:4.47781
# [6]	validation_0-breslow_likelihood:5.88035	validation_1-breslow_likelihood:4.47363
# [7]	validation_0-breslow_likelihood:5.87931	validation_1-breslow_likelihood:4.47309
# [8]	validation_0-breslow_likelihood:5.87311	validation_1-breslow_likelihood:4.47225
# [6]	validation_0-breslow_likelihood:5.89239	validation_1-breslow_likelihood:4.47738
# [9]	validation_0-breslow_likelihood:5.87290	validation_1-breslow_likelihood:4.47225
# [10]	validation_0-breslow_likelihood:5.87054	validation_1-breslow_likelihood:4.47172
# [11]	validation_0-breslow_likelihood:5.87013	validation_1-breslow_likelihood:4.47172
# [12]	validation_0-breslow_likelihood:5.86983	validation_1-breslow_likelihood:4.47163
# [7]	validation_0-breslow_likelihood:5.89248	validation_1-breslow_likelihood:4.47742
# [13]	validation_0-breslow_likelihood:5.86913	validation_1-breslow_likelihood:4.47137
# [14]	validation_0-breslow_likelihood:5.85954	validation_1-breslow_likelihood:4.47065
# [8]	validation_0-breslow_likelihood:5.89248	validation_1-breslow_likelihood:4.47742
# [15]	validation_0-breslow_likelihood:5.85345	validation_1-breslow_likelihood:4.47002
# [16]	validation_0-breslow_likelihood:5.84684	validation_1-breslow_likelihood:4.47053
# [17]	validation_0-breslow_likelihood:5.84474	validation_1-breslow_likelihood:4.47051
# [9]	validation_0-breslow_likelihood:5.89236	validation_1-breslow_likelihood:4.47758
# [18]	validation_0-breslow_likelihood:5.83927	validation_1-breslow_likelihood:4.47037
# [10]	validation_0-breslow_likelihood:5.89200	validation_1-breslow_likelihood:4.47692
# [19]	validation_0-breslow_likelihood:5.83563	validation_1-breslow_likelihood:4.46863
# [11]	validation_0-breslow_likelihood:5.89163	validation_1-breslow_likelihood:4.47733
# [12]	validation_0-breslow_likelihood:5.89082	validation_1-breslow_likelihood:4.47670
# [0]	validation_0-breslow_likelihood:5.89607	validation_1-breslow_likelihood:4.47826
# [13]	validation_0-breslow_likelihood:5.89023	validation_1-breslow_likelihood:4.47652
# [1]	validation_0-breslow_likelihood:5.89326	validation_1-breslow_likelihood:4.47667
# [14]	validation_0-breslow_likelihood:5.88983	validation_1-breslow_likelihood:4.47590
# [2]	validation_0-breslow_likelihood:5.88675	validation_1-breslow_likelihood:4.47902
# [15]	validation_0-breslow_likelihood:5.88950	validation_1-breslow_likelihood:4.47595
# [3]	validation_0-breslow_likelihood:5.88558	validation_1-breslow_likelihood:4.47842
# [16]	validation_0-breslow_likelihood:5.88950	validation_1-breslow_likelihood:4.47595
# [4]	validation_0-breslow_likelihood:5.86989	validation_1-breslow_likelihood:4.47877
# [17]	validation_0-breslow_likelihood:5.88929	validation_1-breslow_likelihood:4.47584
# [18]	validation_0-breslow_likelihood:5.88851	validation_1-breslow_likelihood:4.47506
# [5]	validation_0-breslow_likelihood:5.85459	validation_1-breslow_likelihood:4.48058
# [6]	validation_0-breslow_likelihood:5.85426	validation_1-breslow_likelihood:4.47972
# [19]	validation_0-breslow_likelihood:5.88803	validation_1-breslow_likelihood:4.47467
# [20]	validation_0-breslow_likelihood:5.88804	validation_1-breslow_likelihood:4.47467
# [7]	validation_0-breslow_likelihood:5.85057	validation_1-breslow_likelihood:4.47953
# [21]	validation_0-breslow_likelihood:5.88804	validation_1-breslow_likelihood:4.47467
# [22]	validation_0-breslow_likelihood:5.88590	validation_1-breslow_likelihood:4.47423
# [0]	validation_0-breslow_likelihood:5.89579	validation_1-breslow_likelihood:4.47875
# [1]	validation_0-breslow_likelihood:5.89354	validation_1-breslow_likelihood:4.47593
# [2]	validation_0-breslow_likelihood:5.88760	validation_1-breslow_likelihood:4.47401
# [3]	validation_0-breslow_likelihood:5.88596	validation_1-breslow_likelihood:4.47424
# [4]	validation_0-breslow_likelihood:5.85893	validation_1-breslow_likelihood:4.46620
# [5]	validation_0-breslow_likelihood:5.84415	validation_1-breslow_likelihood:4.46070
# [6]	validation_0-breslow_likelihood:5.84383	validation_1-breslow_likelihood:4.45986
# [7]	validation_0-breslow_likelihood:5.84143	validation_1-breslow_likelihood:4.45929
# [0]	validation_0-breslow_likelihood:5.89593	validation_1-breslow_likelihood:4.47837
# [0]	validation_0-breslow_likelihood:5.89592	validation_1-breslow_likelihood:4.47869
# [1]	validation_0-breslow_likelihood:5.89363	validation_1-breslow_likelihood:4.47767
# [1]	validation_0-breslow_likelihood:5.89505	validation_1-breslow_likelihood:4.47907
# [2]	validation_0-breslow_likelihood:5.88715	validation_1-breslow_likelihood:4.48070
# [2]	validation_0-breslow_likelihood:5.88520	validation_1-breslow_likelihood:4.47760
# [3]	validation_0-breslow_likelihood:5.87485	validation_1-breslow_likelihood:4.47861
# [3]	validation_0-breslow_likelihood:5.87185	validation_1-breslow_likelihood:4.47567
# [4]	validation_0-breslow_likelihood:5.87393	validation_1-breslow_likelihood:4.47761
# [4]	validation_0-breslow_likelihood:5.87136	validation_1-breslow_likelihood:4.47518
# [5]	validation_0-breslow_likelihood:5.87089	validation_1-breslow_likelihood:4.47646
# [5]	validation_0-breslow_likelihood:5.86896	validation_1-breslow_likelihood:4.47329
# [6]	validation_0-breslow_likelihood:5.85630	validation_1-breslow_likelihood:4.47143
# [6]	validation_0-breslow_likelihood:5.84969	validation_1-breslow_likelihood:4.46787
# [7]	validation_0-breslow_likelihood:5.82890	validation_1-breslow_likelihood:4.47069
# [7]	validation_0-breslow_likelihood:5.84263	validation_1-breslow_likelihood:4.46311
# [0]	validation_0-breslow_likelihood:5.89556	validation_1-breslow_likelihood:4.47884
# [1]	validation_0-breslow_likelihood:5.89268	validation_1-breslow_likelihood:4.47746
# [2]	validation_0-breslow_likelihood:5.88402	validation_1-breslow_likelihood:4.47869
# [0]	validation_0-breslow_likelihood:5.89601	validation_1-breslow_likelihood:4.47815
# [1]	validation_0-breslow_likelihood:5.89608	validation_1-breslow_likelihood:4.47831
# [3]	validation_0-breslow_likelihood:5.87075	validation_1-breslow_likelihood:4.48031
# [2]	validation_0-breslow_likelihood:5.89538	validation_1-breslow_likelihood:4.47810
# [3]	validation_0-breslow_likelihood:5.89508	validation_1-breslow_likelihood:4.47739
# [4]	validation_0-breslow_likelihood:5.87010	validation_1-breslow_likelihood:4.47985
# [4]	validation_0-breslow_likelihood:5.89497	validation_1-breslow_likelihood:4.47722
# [5]	validation_0-breslow_likelihood:5.86749	validation_1-breslow_likelihood:4.47998
# [0]	validation_0-breslow_likelihood:5.89617	validation_1-breslow_likelihood:4.47875
# [1]	validation_0-breslow_likelihood:5.89597	validation_1-breslow_likelihood:4.47836
# [5]	validation_0-breslow_likelihood:5.89491	validation_1-breslow_likelihood:4.47736
# [2]	validation_0-breslow_likelihood:5.89556	validation_1-breslow_likelihood:4.47821
# [6]	validation_0-breslow_likelihood:5.89225	validation_1-breslow_likelihood:4.47644
# [6]	validation_0-breslow_likelihood:5.85043	validation_1-breslow_likelihood:4.47387
# [3]	validation_0-breslow_likelihood:5.89546	validation_1-breslow_likelihood:4.47801
# [4]	validation_0-breslow_likelihood:5.89523	validation_1-breslow_likelihood:4.47798
# [7]	validation_0-breslow_likelihood:5.83890	validation_1-breslow_likelihood:4.47695
# [5]	validation_0-breslow_likelihood:5.89524	validation_1-breslow_likelihood:4.47820
# [6]	validation_0-breslow_likelihood:5.89207	validation_1-breslow_likelihood:4.47719
# [7]	validation_0-breslow_likelihood:5.89224	validation_1-breslow_likelihood:4.47644
# [0]	validation_0-breslow_likelihood:5.89608	validation_1-breslow_likelihood:4.47826
# [8]	validation_0-breslow_likelihood:5.89010	validation_1-breslow_likelihood:4.47556
# [7]	validation_0-breslow_likelihood:5.89175	validation_1-breslow_likelihood:4.47716
# [1]	validation_0-breslow_likelihood:5.89562	validation_1-breslow_likelihood:4.47783
# [8]	validation_0-breslow_likelihood:5.88980	validation_1-breslow_likelihood:4.47618
# [9]	validation_0-breslow_likelihood:5.88765	validation_1-breslow_likelihood:4.47495
# [2]	validation_0-breslow_likelihood:5.89544	validation_1-breslow_likelihood:4.47794
# [3]	validation_0-breslow_likelihood:5.89526	validation_1-breslow_likelihood:4.47778
# [9]	validation_0-breslow_likelihood:5.88794	validation_1-breslow_likelihood:4.47571
# [10]	validation_0-breslow_likelihood:5.88712	validation_1-breslow_likelihood:4.47418
# [4]	validation_0-breslow_likelihood:5.89485	validation_1-breslow_likelihood:4.47739
# [11]	validation_0-breslow_likelihood:5.88613	validation_1-breslow_likelihood:4.47409
# [5]	validation_0-breslow_likelihood:5.89458	validation_1-breslow_likelihood:4.47714
# [10]	validation_0-breslow_likelihood:5.88636	validation_1-breslow_likelihood:4.47527
# [12]	validation_0-breslow_likelihood:5.88613	validation_1-breslow_likelihood:4.47409
# [0]	validation_0-breslow_likelihood:5.89587	validation_1-breslow_likelihood:4.47878
# [6]	validation_0-breslow_likelihood:5.89421	validation_1-breslow_likelihood:4.47697
# [11]	validation_0-breslow_likelihood:5.88577	validation_1-breslow_likelihood:4.47484
# [13]	validation_0-breslow_likelihood:5.88597	validation_1-breslow_likelihood:4.47413
# [1]	validation_0-breslow_likelihood:5.89588	validation_1-breslow_likelihood:4.47878
# [7]	validation_0-breslow_likelihood:5.89369	validation_1-breslow_likelihood:4.47674
# [12]	validation_0-breslow_likelihood:5.88577	validation_1-breslow_likelihood:4.47484
# [2]	validation_0-breslow_likelihood:5.89474	validation_1-breslow_likelihood:4.47800
# [14]	validation_0-breslow_likelihood:5.88576	validation_1-breslow_likelihood:4.47365
# [8]	validation_0-breslow_likelihood:5.89333	validation_1-breslow_likelihood:4.47641
# [3]	validation_0-breslow_likelihood:5.89454	validation_1-breslow_likelihood:4.47748
# [15]	validation_0-breslow_likelihood:5.88554	validation_1-breslow_likelihood:4.47372
# [13]	validation_0-breslow_likelihood:5.88569	validation_1-breslow_likelihood:4.47493
# [9]	validation_0-breslow_likelihood:5.89295	validation_1-breslow_likelihood:4.47637
# [4]	validation_0-breslow_likelihood:5.89449	validation_1-breslow_likelihood:4.47735
# [16]	validation_0-breslow_likelihood:5.88342	validation_1-breslow_likelihood:4.47308
# [14]	validation_0-breslow_likelihood:5.88491	validation_1-breslow_likelihood:4.47473
# [10]	validation_0-breslow_likelihood:5.89255	validation_1-breslow_likelihood:4.47600
# [5]	validation_0-breslow_likelihood:5.89442	validation_1-breslow_likelihood:4.47715
# [17]	validation_0-breslow_likelihood:5.88257	validation_1-breslow_likelihood:4.47295
# [15]	validation_0-breslow_likelihood:5.88474	validation_1-breslow_likelihood:4.47495
# [11]	validation_0-breslow_likelihood:5.89221	validation_1-breslow_likelihood:4.47525
# [6]	validation_0-breslow_likelihood:5.89397	validation_1-breslow_likelihood:4.47727
# [18]	validation_0-breslow_likelihood:5.88260	validation_1-breslow_likelihood:4.47312
# [16]	validation_0-breslow_likelihood:5.88192	validation_1-breslow_likelihood:4.47397
# [12]	validation_0-breslow_likelihood:5.89217	validation_1-breslow_likelihood:4.47506
# [7]	validation_0-breslow_likelihood:5.89374	validation_1-breslow_likelihood:4.47758
# [19]	validation_0-breslow_likelihood:5.88250	validation_1-breslow_likelihood:4.47295
# [17]	validation_0-breslow_likelihood:5.88157	validation_1-breslow_likelihood:4.47369
# [8]	validation_0-breslow_likelihood:5.89374	validation_1-breslow_likelihood:4.47758
# [13]	validation_0-breslow_likelihood:5.89082	validation_1-breslow_likelihood:4.47418
# [20]	validation_0-breslow_likelihood:5.88246	validation_1-breslow_likelihood:4.47269
# [18]	validation_0-breslow_likelihood:5.88098	validation_1-breslow_likelihood:4.47349
# [9]	validation_0-breslow_likelihood:5.89290	validation_1-breslow_likelihood:4.47690
# [14]	validation_0-breslow_likelihood:5.89055	validation_1-breslow_likelihood:4.47419
# [21]	validation_0-breslow_likelihood:5.88207	validation_1-breslow_likelihood:4.47289
# [0]	validation_0-breslow_likelihood:5.89591	validation_1-breslow_likelihood:4.47817
# [19]	validation_0-breslow_likelihood:5.88098	validation_1-breslow_likelihood:4.47349
# [10]	validation_0-breslow_likelihood:5.89299	validation_1-breslow_likelihood:4.47714
# [15]	validation_0-breslow_likelihood:5.89025	validation_1-breslow_likelihood:4.47384
# [22]	validation_0-breslow_likelihood:5.88197	validation_1-breslow_likelihood:4.47263
# [1]	validation_0-breslow_likelihood:5.89566	validation_1-breslow_likelihood:4.47795
# [20]	validation_0-breslow_likelihood:5.88042	validation_1-breslow_likelihood:4.47263
# [11]	validation_0-breslow_likelihood:5.89268	validation_1-breslow_likelihood:4.47734
# [16]	validation_0-breslow_likelihood:5.88905	validation_1-breslow_likelihood:4.47267
# [23]	validation_0-breslow_likelihood:5.88198	validation_1-breslow_likelihood:4.47263
# [2]	validation_0-breslow_likelihood:5.89543	validation_1-breslow_likelihood:4.47804
# [12]	validation_0-breslow_likelihood:5.89260	validation_1-breslow_likelihood:4.47735
# [17]	validation_0-breslow_likelihood:5.88864	validation_1-breslow_likelihood:4.47230
# [21]	validation_0-breslow_likelihood:5.88007	validation_1-breslow_likelihood:4.47238
# [24]	validation_0-breslow_likelihood:5.88180	validation_1-breslow_likelihood:4.47224
# [3]	validation_0-breslow_likelihood:5.89544	validation_1-breslow_likelihood:4.47804
# [13]	validation_0-breslow_likelihood:5.89029	validation_1-breslow_likelihood:4.47636
# [18]	validation_0-breslow_likelihood:5.88864	validation_1-breslow_likelihood:4.47230
# [25]	validation_0-breslow_likelihood:5.88171	validation_1-breslow_likelihood:4.47207
# [22]	validation_0-breslow_likelihood:5.88007	validation_1-breslow_likelihood:4.47238
# [4]	validation_0-breslow_likelihood:5.89544	validation_1-breslow_likelihood:4.47804
# [14]	validation_0-breslow_likelihood:5.89002	validation_1-breslow_likelihood:4.47621
# [19]	validation_0-breslow_likelihood:5.88809	validation_1-breslow_likelihood:4.47214
# [26]	validation_0-breslow_likelihood:5.88137	validation_1-breslow_likelihood:4.47225
# [23]	validation_0-breslow_likelihood:5.87996	validation_1-breslow_likelihood:4.47241
# [5]	validation_0-breslow_likelihood:5.89529	validation_1-breslow_likelihood:4.47791
# [15]	validation_0-breslow_likelihood:5.88950	validation_1-breslow_likelihood:4.47702
# [20]	validation_0-breslow_likelihood:5.88815	validation_1-breslow_likelihood:4.47213
# [27]	validation_0-breslow_likelihood:5.87873	validation_1-breslow_likelihood:4.47145
# [24]	validation_0-breslow_likelihood:5.87955	validation_1-breslow_likelihood:4.47239
# [6]	validation_0-breslow_likelihood:5.89488	validation_1-breslow_likelihood:4.47792
# [16]	validation_0-breslow_likelihood:5.88752	validation_1-breslow_likelihood:4.47626
# [21]	validation_0-breslow_likelihood:5.88787	validation_1-breslow_likelihood:4.47187
# [28]	validation_0-breslow_likelihood:5.87873	validation_1-breslow_likelihood:4.47145
# [25]	validation_0-breslow_likelihood:5.87965	validation_1-breslow_likelihood:4.47238
# [17]	validation_0-breslow_likelihood:5.88752	validation_1-breslow_likelihood:4.47626
# [7]	validation_0-breslow_likelihood:5.89503	validation_1-breslow_likelihood:4.47775
# [22]	validation_0-breslow_likelihood:5.88782	validation_1-breslow_likelihood:4.47193
# [26]	validation_0-breslow_likelihood:5.87932	validation_1-breslow_likelihood:4.47211
# [18]	validation_0-breslow_likelihood:5.88746	validation_1-breslow_likelihood:4.47625
# [8]	validation_0-breslow_likelihood:5.89490	validation_1-breslow_likelihood:4.47764
# [23]	validation_0-breslow_likelihood:5.88774	validation_1-breslow_likelihood:4.47194
# [27]	validation_0-breslow_likelihood:5.87669	validation_1-breslow_likelihood:4.47145
# [19]	validation_0-breslow_likelihood:5.88717	validation_1-breslow_likelihood:4.47697
# [9]	validation_0-breslow_likelihood:5.89438	validation_1-breslow_likelihood:4.47755
# [24]	validation_0-breslow_likelihood:5.88773	validation_1-breslow_likelihood:4.47194
# [28]	validation_0-breslow_likelihood:5.87663	validation_1-breslow_likelihood:4.47148
# [20]	validation_0-breslow_likelihood:5.88706	validation_1-breslow_likelihood:4.47693
# [10]	validation_0-breslow_likelihood:5.89414	validation_1-breslow_likelihood:4.47735
# [25]	validation_0-breslow_likelihood:5.88766	validation_1-breslow_likelihood:4.47224
# [21]	validation_0-breslow_likelihood:5.88701	validation_1-breslow_likelihood:4.47676
# [11]	validation_0-breslow_likelihood:5.89368	validation_1-breslow_likelihood:4.47764
# [26]	validation_0-breslow_likelihood:5.88767	validation_1-breslow_likelihood:4.47224
# [22]	validation_0-breslow_likelihood:5.88714	validation_1-breslow_likelihood:4.47670
# [12]	validation_0-breslow_likelihood:5.89356	validation_1-breslow_likelihood:4.47750
# [23]	validation_0-breslow_likelihood:5.88714	validation_1-breslow_likelihood:4.47670
# [13]	validation_0-breslow_likelihood:5.89030	validation_1-breslow_likelihood:4.47598
# [27]	validation_0-breslow_likelihood:5.88722	validation_1-breslow_likelihood:4.47242
# [14]	validation_0-breslow_likelihood:5.89013	validation_1-breslow_likelihood:4.47590
# [28]	validation_0-breslow_likelihood:5.88682	validation_1-breslow_likelihood:4.47223
# [15]	validation_0-breslow_likelihood:5.88964	validation_1-breslow_likelihood:4.47565
# [16]	validation_0-breslow_likelihood:5.88643	validation_1-breslow_likelihood:4.47409
# [17]	validation_0-breslow_likelihood:5.88623	validation_1-breslow_likelihood:4.47393
# [18]	validation_0-breslow_likelihood:5.88616	validation_1-breslow_likelihood:4.47402
# [19]	validation_0-breslow_likelihood:5.88565	validation_1-breslow_likelihood:4.47400
# [20]	validation_0-breslow_likelihood:5.88565	validation_1-breslow_likelihood:4.47400
# [21]	validation_0-breslow_likelihood:5.88531	validation_1-breslow_likelihood:4.47374
# [22]	validation_0-breslow_likelihood:5.88553	validation_1-breslow_likelihood:4.47381
# [23]	validation_0-breslow_likelihood:5.88553	validation_1-breslow_likelihood:4.47381
# [24]	validation_0-breslow_likelihood:5.88547	validation_1-breslow_likelihood:4.47393
# [25]	validation_0-breslow_likelihood:5.88513	validation_1-breslow_likelihood:4.47389
# [26]	validation_0-breslow_likelihood:5.88500	validation_1-breslow_likelihood:4.47372
# [27]	validation_0-breslow_likelihood:5.88474	validation_1-breslow_likelihood:4.47386
# [28]	validation_0-breslow_likelihood:5.88446	validation_1-breslow_likelihood:4.47381
# [0]	validation_0-breslow_likelihood:6.08464	validation_1-breslow_likelihood:4.77867
# [1]	validation_0-breslow_likelihood:6.03078	validation_1-breslow_likelihood:4.78062
# [2]	validation_0-breslow_likelihood:6.02184	validation_1-breslow_likelihood:4.83949
# [3]	validation_0-breslow_likelihood:6.01254	validation_1-breslow_likelihood:4.84367
# [4]	validation_0-breslow_likelihood:5.95897	validation_1-breslow_likelihood:4.87733
# [5]	validation_0-breslow_likelihood:5.94488	validation_1-breslow_likelihood:4.87405
# [6]	validation_0-breslow_likelihood:5.92326	validation_1-breslow_likelihood:4.88129
# [7]	validation_0-breslow_likelihood:5.91459	validation_1-breslow_likelihood:4.87992
# [8]	validation_0-breslow_likelihood:5.91080	validation_1-breslow_likelihood:4.87879
# [9]	validation_0-breslow_likelihood:5.90946	validation_1-breslow_likelihood:4.87897
# Concordance Index 0.362668868695298
# Integrated Brier Score: 0.17334023491519138
# durations 0.76666665 337.03333
# Concordance Index 0.351037657235824
# Integrated Brier Score: 0.18793146558065563
# [0]	validation_0-breslow_likelihood:5.89185	validation_1-breslow_likelihood:4.47746
# [1]	validation_0-breslow_likelihood:5.89160	validation_1-breslow_likelihood:4.47831
# [2]	validation_0-breslow_likelihood:5.89250	validation_1-breslow_likelihood:4.47848
# [3]	validation_0-breslow_likelihood:5.89064	validation_1-breslow_likelihood:4.47863
# [4]	validation_0-breslow_likelihood:5.88646	validation_1-breslow_likelihood:4.47784
# [5]	validation_0-breslow_likelihood:5.88095	validation_1-breslow_likelihood:4.48103
# [6]	validation_0-breslow_likelihood:5.87806	validation_1-breslow_likelihood:4.48076
# [7]	validation_0-breslow_likelihood:5.87692	validation_1-breslow_likelihood:4.48097
# [8]	validation_0-breslow_likelihood:5.87343	validation_1-breslow_likelihood:4.47745
# [9]	validation_0-breslow_likelihood:5.86295	validation_1-breslow_likelihood:4.46955
# [10]	validation_0-breslow_likelihood:5.86093	validation_1-breslow_likelihood:4.46173
# [11]	validation_0-breslow_likelihood:5.86108	validation_1-breslow_likelihood:4.46259
# [12]	validation_0-breslow_likelihood:5.85819	validation_1-breslow_likelihood:4.45885
# [13]	validation_0-breslow_likelihood:5.85948	validation_1-breslow_likelihood:4.46159
# [14]	validation_0-breslow_likelihood:5.85283	validation_1-breslow_likelihood:4.45898
# [15]	validation_0-breslow_likelihood:5.85285	validation_1-breslow_likelihood:4.45898
# [16]	validation_0-breslow_likelihood:5.84666	validation_1-breslow_likelihood:4.46223
# [17]	validation_0-breslow_likelihood:5.84272	validation_1-breslow_likelihood:4.46074
# [0]	validation_0-breslow_likelihood:5.89536	validation_1-breslow_likelihood:4.47850
# [18]	validation_0-breslow_likelihood:5.83876	validation_1-breslow_likelihood:4.46177
# [1]	validation_0-breslow_likelihood:5.89560	validation_1-breslow_likelihood:4.47617
# [19]	validation_0-breslow_likelihood:5.83131	validation_1-breslow_likelihood:4.45945
# [2]	validation_0-breslow_likelihood:5.89425	validation_1-breslow_likelihood:4.47778
# [20]	validation_0-breslow_likelihood:5.83133	validation_1-breslow_likelihood:4.45945
# [3]	validation_0-breslow_likelihood:5.89103	validation_1-breslow_likelihood:4.47153
# [0]	validation_0-breslow_likelihood:5.89443	validation_1-breslow_likelihood:4.47781
# [21]	validation_0-breslow_likelihood:5.82944	validation_1-breslow_likelihood:4.46049
# [4]	validation_0-breslow_likelihood:5.88420	validation_1-breslow_likelihood:4.47144
# [1]	validation_0-breslow_likelihood:5.88767	validation_1-breslow_likelihood:4.47913
# [5]	validation_0-breslow_likelihood:5.87681	validation_1-breslow_likelihood:4.46645
# [2]	validation_0-breslow_likelihood:5.88541	validation_1-breslow_likelihood:4.47358
# [6]	validation_0-breslow_likelihood:5.87347	validation_1-breslow_likelihood:4.46305
# [3]	validation_0-breslow_likelihood:5.88282	validation_1-breslow_likelihood:4.46942
# [4]	validation_0-breslow_likelihood:5.87587	validation_1-breslow_likelihood:4.46343
# [7]	validation_0-breslow_likelihood:5.86990	validation_1-breslow_likelihood:4.45957
# [5]	validation_0-breslow_likelihood:5.87441	validation_1-breslow_likelihood:4.46226
# [0]	validation_0-breslow_likelihood:5.89532	validation_1-breslow_likelihood:4.47932
# [8]	validation_0-breslow_likelihood:5.87142	validation_1-breslow_likelihood:4.45859
# [1]	validation_0-breslow_likelihood:5.89142	validation_1-breslow_likelihood:4.48135
# [6]	validation_0-breslow_likelihood:5.86428	validation_1-breslow_likelihood:4.46418
# [9]	validation_0-breslow_likelihood:5.86839	validation_1-breslow_likelihood:4.46133
# [7]	validation_0-breslow_likelihood:5.85874	validation_1-breslow_likelihood:4.46522
# [2]	validation_0-breslow_likelihood:5.89240	validation_1-breslow_likelihood:4.48321
# [10]	validation_0-breslow_likelihood:5.86641	validation_1-breslow_likelihood:4.45977
# [3]	validation_0-breslow_likelihood:5.88858	validation_1-breslow_likelihood:4.48134
# [8]	validation_0-breslow_likelihood:5.85551	validation_1-breslow_likelihood:4.46935
# [11]	validation_0-breslow_likelihood:5.86527	validation_1-breslow_likelihood:4.46042
# [4]	validation_0-breslow_likelihood:5.88444	validation_1-breslow_likelihood:4.47765
# [9]	validation_0-breslow_likelihood:5.85319	validation_1-breslow_likelihood:4.47142
# [12]	validation_0-breslow_likelihood:5.86186	validation_1-breslow_likelihood:4.46062
# [5]	validation_0-breslow_likelihood:5.88263	validation_1-breslow_likelihood:4.47771
# [10]	validation_0-breslow_likelihood:5.84943	validation_1-breslow_likelihood:4.46722
# [0]	validation_0-breslow_likelihood:5.89459	validation_1-breslow_likelihood:4.47724
# [13]	validation_0-breslow_likelihood:5.85797	validation_1-breslow_likelihood:4.46204
# [11]	validation_0-breslow_likelihood:5.84093	validation_1-breslow_likelihood:4.46170
# [6]	validation_0-breslow_likelihood:5.87390	validation_1-breslow_likelihood:4.47255
# [1]	validation_0-breslow_likelihood:5.88981	validation_1-breslow_likelihood:4.47088
# [14]	validation_0-breslow_likelihood:5.85400	validation_1-breslow_likelihood:4.46081
# [12]	validation_0-breslow_likelihood:5.83760	validation_1-breslow_likelihood:4.46071
# [7]	validation_0-breslow_likelihood:5.87204	validation_1-breslow_likelihood:4.47107
# [15]	validation_0-breslow_likelihood:5.85402	validation_1-breslow_likelihood:4.46081
# [2]	validation_0-breslow_likelihood:5.88798	validation_1-breslow_likelihood:4.47233
# [13]	validation_0-breslow_likelihood:5.83759	validation_1-breslow_likelihood:4.46071
# [8]	validation_0-breslow_likelihood:5.87105	validation_1-breslow_likelihood:4.47480
# [3]	validation_0-breslow_likelihood:5.88574	validation_1-breslow_likelihood:4.47108
# [16]	validation_0-breslow_likelihood:5.85381	validation_1-breslow_likelihood:4.46038
# [0]	validation_0-breslow_likelihood:5.89587	validation_1-breslow_likelihood:4.47813
# [9]	validation_0-breslow_likelihood:5.87004	validation_1-breslow_likelihood:4.47334
# [4]	validation_0-breslow_likelihood:5.87454	validation_1-breslow_likelihood:4.46347
# [14]	validation_0-breslow_likelihood:5.83231	validation_1-breslow_likelihood:4.46025
# [17]	validation_0-breslow_likelihood:5.85384	validation_1-breslow_likelihood:4.46462
# [1]	validation_0-breslow_likelihood:5.89579	validation_1-breslow_likelihood:4.47812
# [5]	validation_0-breslow_likelihood:5.87445	validation_1-breslow_likelihood:4.46345
# [10]	validation_0-breslow_likelihood:5.86838	validation_1-breslow_likelihood:4.47401
# [15]	validation_0-breslow_likelihood:5.82613	validation_1-breslow_likelihood:4.46269
# [0]	validation_0-breslow_likelihood:5.89594	validation_1-breslow_likelihood:4.47829[2]	validation_0-breslow_likelihood:5.89562	validation_1-breslow_likelihood:4.47810
#
# [11]	validation_0-breslow_likelihood:5.85962	validation_1-breslow_likelihood:4.47827
# [6]	validation_0-breslow_likelihood:5.86581	validation_1-breslow_likelihood:4.45242
# [16]	validation_0-breslow_likelihood:5.82184	validation_1-breslow_likelihood:4.45282
# [1]	validation_0-breslow_likelihood:5.89585	validation_1-breslow_likelihood:4.47826
# [3]	validation_0-breslow_likelihood:5.89517	validation_1-breslow_likelihood:4.47797
# [7]	validation_0-breslow_likelihood:5.86486	validation_1-breslow_likelihood:4.45324
# [12]	validation_0-breslow_likelihood:5.85642	validation_1-breslow_likelihood:4.47840
# [17]	validation_0-breslow_likelihood:5.81748	validation_1-breslow_likelihood:4.45133
# [2]	validation_0-breslow_likelihood:5.89565	validation_1-breslow_likelihood:4.47823
# [13]	validation_0-breslow_likelihood:5.85641	validation_1-breslow_likelihood:4.47840
# [8]	validation_0-breslow_likelihood:5.86422	validation_1-breslow_likelihood:4.45755
# [4]	validation_0-breslow_likelihood:5.89442	validation_1-breslow_likelihood:4.47793
# [18]	validation_0-breslow_likelihood:5.81750	validation_1-breslow_likelihood:4.45234
# [3]	validation_0-breslow_likelihood:5.89483	validation_1-breslow_likelihood:4.47822
# [9]	validation_0-breslow_likelihood:5.86440	validation_1-breslow_likelihood:4.46360
# [14]	validation_0-breslow_likelihood:5.85217	validation_1-breslow_likelihood:4.47430
# [19]	validation_0-breslow_likelihood:5.81617	validation_1-breslow_likelihood:4.44723
# ...
# [82]	validation_0-breslow_likelihood:7.37774	validation_1-breslow_likelihood:6.01603
# [65]	validation_0-breslow_likelihood:7.42352	validation_1-breslow_likelihood:6.03335
# [82]	validation_0-breslow_likelihood:7.37722	validation_1-breslow_likelihood:6.02504
# [40]	validation_0-breslow_likelihood:7.42637	validation_1-breslow_likelihood:6.03355
# [61]	validation_0-breslow_likelihood:7.42438	validation_1-breslow_likelihood:6.03318
# [48]	validation_0-breslow_likelihood:7.42622	validation_1-breslow_likelihood:6.03398
# [70]	validation_0-breslow_likelihood:7.42265	validation_1-breslow_likelihood:6.03256
# [83]	validation_0-breslow_likelihood:7.37675	validation_1-breslow_likelihood:6.01545
# [5]	validation_0-breslow_likelihood:8.88158	validation_1-breslow_likelihood:8.87125
# [49]	validation_0-breslow_likelihood:7.42608	validation_1-breslow_likelihood:6.03394
# [41]	validation_0-breslow_likelihood:7.42623	validation_1-breslow_likelihood:6.03351
# [62]	validation_0-breslow_likelihood:7.42426	validation_1-breslow_likelihood:6.03311
# [66]	validation_0-breslow_likelihood:7.42338	validation_1-breslow_likelihood:6.03332
# [9]	validation_0-breslow_likelihood:8.45319	validation_1-breslow_likelihood:10.02249
# [50]	validation_0-breslow_likelihood:7.42591	validation_1-breslow_likelihood:6.03392
# [63]	validation_0-breslow_likelihood:7.42410	validation_1-breslow_likelihood:6.03304
# [84]	validation_0-breslow_likelihood:7.37627	validation_1-breslow_likelihood:6.01504
# [71]	validation_0-breslow_likelihood:7.42247	validation_1-breslow_likelihood:6.03248
# [64]	validation_0-breslow_likelihood:7.42395	validation_1-breslow_likelihood:6.03301
# [65]	validation_0-breslow_likelihood:7.42377	validation_1-breslow_likelihood:6.03293
# [10]	validation_0-breslow_likelihood:8.56605	validation_1-breslow_likelihood:10.22172
# [42]	validation_0-breslow_likelihood:7.42603	validation_1-breslow_likelihood:6.03347
# [66]	validation_0-breslow_likelihood:7.42358	validation_1-breslow_likelihood:6.03284
# [67]	validation_0-breslow_likelihood:7.42321	validation_1-breslow_likelihood:6.03326
# [72]	validation_0-breslow_likelihood:7.42216	validation_1-breslow_likelihood:6.03233
# [85]	validation_0-breslow_likelihood:7.37541	validation_1-breslow_likelihood:6.01511
# [67]	validation_0-breslow_likelihood:7.42340	validation_1-breslow_likelihood:6.03275
# [68]	validation_0-breslow_likelihood:7.42314	validation_1-breslow_likelihood:6.03322
# [43]	validation_0-breslow_likelihood:7.42583	validation_1-breslow_likelihood:6.03338
# [73]	validation_0-breslow_likelihood:7.42206	validation_1-breslow_likelihood:6.03234
# [86]	validation_0-breslow_likelihood:7.37507	validation_1-breslow_likelihood:6.01487
# [69]	validation_0-breslow_likelihood:7.42296	validation_1-breslow_likelihood:6.03314
# [51]	validation_0-breslow_likelihood:7.42574	validation_1-breslow_likelihood:6.03391
# [74]	validation_0-breslow_likelihood:7.42185	validation_1-breslow_likelihood:6.03227
# [68]	validation_0-breslow_likelihood:7.42333	validation_1-breslow_likelihood:6.03270
# [87]	validation_0-breslow_likelihood:7.37445	validation_1-breslow_likelihood:6.01458
# [6]	validation_0-breslow_likelihood:8.44700	validation_1-breslow_likelihood:9.53423
# [44]	validation_0-breslow_likelihood:7.42571	validation_1-breslow_likelihood:6.03331
# [52]	validation_0-breslow_likelihood:7.42561	validation_1-breslow_likelihood:6.03388
# [88]	validation_0-breslow_likelihood:7.37398	validation_1-breslow_likelihood:6.01413
# [70]	validation_0-breslow_likelihood:7.42277	validation_1-breslow_likelihood:6.03310
# [7]	validation_0-breslow_likelihood:8.72349	validation_1-breslow_likelihood:10.12454
# [53]	validation_0-breslow_likelihood:7.42546	validation_1-breslow_likelihood:6.03383
# [75]	validation_0-breslow_likelihood:7.42167	validation_1-breslow_likelihood:6.03219
# [45]	validation_0-breslow_likelihood:7.42557	validation_1-breslow_likelihood:6.03325
# [89]	validation_0-breslow_likelihood:7.37331	validation_1-breslow_likelihood:6.01345
# [71]	validation_0-breslow_likelihood:7.42264	validation_1-breslow_likelihood:6.03306
# [54]	validation_0-breslow_likelihood:7.42530	validation_1-breslow_likelihood:6.03381
# [69]	validation_0-breslow_likelihood:7.42321	validation_1-breslow_likelihood:6.03263
# [46]	validation_0-breslow_likelihood:7.42539	validation_1-breslow_likelihood:6.03321
# [8]	validation_0-breslow_likelihood:8.89877	validation_1-breslow_likelihood:10.13054
# [90]	validation_0-breslow_likelihood:7.37285	validation_1-breslow_likelihood:6.01351
# [55]	validation_0-breslow_likelihood:7.42508	validation_1-breslow_likelihood:6.03374
# [47]	validation_0-breslow_likelihood:7.42521	validation_1-breslow_likelihood:6.03314
# [91]	validation_0-breslow_likelihood:7.37245	validation_1-breslow_likelihood:6.01331
# [56]	validation_0-breslow_likelihood:7.42498	validation_1-breslow_likelihood:6.03370
# [9]	validation_0-breslow_likelihood:8.87645	validation_1-breslow_likelihood:10.49099
# [72]	validation_0-breslow_likelihood:7.42240	validation_1-breslow_likelihood:6.03294
# [70]	validation_0-breslow_likelihood:7.42303	validation_1-breslow_likelihood:6.03256
# [48]	validation_0-breslow_likelihood:7.42504	validation_1-breslow_likelihood:6.03308
# [57]	validation_0-breslow_likelihood:7.42475	validation_1-breslow_likelihood:6.03363
# [73]	validation_0-breslow_likelihood:7.42230	validation_1-breslow_likelihood:6.03291
# [49]	validation_0-breslow_likelihood:7.42492	validation_1-breslow_likelihood:6.03307
# [58]	validation_0-breslow_likelihood:7.42461	validation_1-breslow_likelihood:6.03357
# [50]	validation_0-breslow_likelihood:7.42470	validation_1-breslow_likelihood:6.03299
# [71]	validation_0-breslow_likelihood:7.42288	validation_1-breslow_likelihood:6.03250
# [59]	validation_0-breslow_likelihood:7.42455	validation_1-breslow_likelihood:6.03357
# [51]	validation_0-breslow_likelihood:7.42456	validation_1-breslow_likelihood:6.03294
# [74]	validation_0-breslow_likelihood:7.42209	validation_1-breslow_likelihood:6.03285
# [60]	validation_0-breslow_likelihood:7.42436	validation_1-breslow_likelihood:6.03350
# [52]	validation_0-breslow_likelihood:7.42435	validation_1-breslow_likelihood:6.03287
# [75]	validation_0-breslow_likelihood:7.42199	validation_1-breslow_likelihood:6.03279
# [72]	validation_0-breslow_likelihood:7.42264	validation_1-breslow_likelihood:6.03247
# [61]	validation_0-breslow_likelihood:7.42415	validation_1-breslow_likelihood:6.03345
# [73]	validation_0-breslow_likelihood:7.42246	validation_1-breslow_likelihood:6.03241
# [62]	validation_0-breslow_likelihood:7.42405	validation_1-breslow_likelihood:6.03340
# [53]	validation_0-breslow_likelihood:7.42418	validation_1-breslow_likelihood:6.03278
# [63]	validation_0-breslow_likelihood:7.42389	validation_1-breslow_likelihood:6.03336
# [74]	validation_0-breslow_likelihood:7.42230	validation_1-breslow_likelihood:6.03233
# [64]	validation_0-breslow_likelihood:7.42377	validation_1-breslow_likelihood:6.03333
# [75]	validation_0-breslow_likelihood:7.42217	validation_1-breslow_likelihood:6.03229
# [65]	validation_0-breslow_likelihood:7.42363	validation_1-breslow_likelihood:6.03326
# [54]	validation_0-breslow_likelihood:7.42407	validation_1-breslow_likelihood:6.03273
# [66]	validation_0-breslow_likelihood:7.42352	validation_1-breslow_likelihood:6.03322
# [67]	validation_0-breslow_likelihood:7.42337	validation_1-breslow_likelihood:6.03317
# [55]	validation_0-breslow_likelihood:7.42391	validation_1-breslow_likelihood:6.03269
# [68]	validation_0-breslow_likelihood:7.42330	validation_1-breslow_likelihood:6.03312
# [56]	validation_0-breslow_likelihood:7.42372	validation_1-breslow_likelihood:6.03261
# [69]	validation_0-breslow_likelihood:7.42313	validation_1-breslow_likelihood:6.03307
# [57]	validation_0-breslow_likelihood:7.42355	validation_1-breslow_likelihood:6.03250
# [70]	validation_0-breslow_likelihood:7.42297	validation_1-breslow_likelihood:6.03303
# [58]	validation_0-breslow_likelihood:7.42339	validation_1-breslow_likelihood:6.03247
# [71]	validation_0-breslow_likelihood:7.42281	validation_1-breslow_likelihood:6.03298
# [59]	validation_0-breslow_likelihood:7.42320	validation_1-breslow_likelihood:6.03241
# [72]	validation_0-breslow_likelihood:7.42256	validation_1-breslow_likelihood:6.03291
# [60]	validation_0-breslow_likelihood:7.42313	validation_1-breslow_likelihood:6.03240
# [73]	validation_0-breslow_likelihood:7.42245	validation_1-breslow_likelihood:6.03288
# [61]	validation_0-breslow_likelihood:7.42296	validation_1-breslow_likelihood:6.03234
# [74]	validation_0-breslow_likelihood:7.42229	validation_1-breslow_likelihood:6.03282
# [62]	validation_0-breslow_likelihood:7.42285	validation_1-breslow_likelihood:6.03229
# [75]	validation_0-breslow_likelihood:7.42214	validation_1-breslow_likelihood:6.03277
# [63]	validation_0-breslow_likelihood:7.42270	validation_1-breslow_likelihood:6.03226
# [64]	validation_0-breslow_likelihood:7.42255	validation_1-breslow_likelihood:6.03220
# [65]	validation_0-breslow_likelihood:7.42238	validation_1-breslow_likelihood:6.03214
# [66]	validation_0-breslow_likelihood:7.42214	validation_1-breslow_likelihood:6.03201
# [67]	validation_0-breslow_likelihood:7.42199	validation_1-breslow_likelihood:6.03197
# [68]	validation_0-breslow_likelihood:7.42182	validation_1-breslow_likelihood:6.03192
# [69]	validation_0-breslow_likelihood:7.42169	validation_1-breslow_likelihood:6.03192
# [70]	validation_0-breslow_likelihood:7.42140	validation_1-breslow_likelihood:6.03184
# [71]	validation_0-breslow_likelihood:7.42126	validation_1-breslow_likelihood:6.03177
# [72]	validation_0-breslow_likelihood:7.42112	validation_1-breslow_likelihood:6.03176
# [73]	validation_0-breslow_likelihood:7.42098	validation_1-breslow_likelihood:6.03168
# [74]	validation_0-breslow_likelihood:7.42089	validation_1-breslow_likelihood:6.03165
# [75]	validation_0-breslow_likelihood:7.42073	validation_1-breslow_likelihood:6.03160
# [0]	validation_0-breslow_likelihood:7.63945	validation_1-breslow_likelihood:6.26127
# [1]	validation_0-breslow_likelihood:7.63843	validation_1-breslow_likelihood:6.26070
# [2]	validation_0-breslow_likelihood:7.63652	validation_1-breslow_likelihood:6.25980
# [3]	validation_0-breslow_likelihood:7.63129	validation_1-breslow_likelihood:6.25843
# [4]	validation_0-breslow_likelihood:7.62788	validation_1-breslow_likelihood:6.25865
# [5]	validation_0-breslow_likelihood:7.62598	validation_1-breslow_likelihood:6.25795
# [6]	validation_0-breslow_likelihood:7.62228	validation_1-breslow_likelihood:6.25709
# [7]	validation_0-breslow_likelihood:7.61762	validation_1-breslow_likelihood:6.25649
# [8]	validation_0-breslow_likelihood:7.61554	validation_1-breslow_likelihood:6.25560
# [9]	validation_0-breslow_likelihood:7.61343	validation_1-breslow_likelihood:6.25494
# [10]	validation_0-breslow_likelihood:7.60964	validation_1-breslow_likelihood:6.25458
# [11]	validation_0-breslow_likelihood:7.60640	validation_1-breslow_likelihood:6.25396
# [12]	validation_0-breslow_likelihood:7.60361	validation_1-breslow_likelihood:6.25326
# [13]	validation_0-breslow_likelihood:7.59981	validation_1-breslow_likelihood:6.25261
# [14]	validation_0-breslow_likelihood:7.59555	validation_1-breslow_likelihood:6.25191
# [15]	validation_0-breslow_likelihood:7.59340	validation_1-breslow_likelihood:6.25134
# [16]	validation_0-breslow_likelihood:7.58932	validation_1-breslow_likelihood:6.25047
# [17]	validation_0-breslow_likelihood:7.58609	validation_1-breslow_likelihood:6.24979
# [18]	validation_0-breslow_likelihood:7.58242	validation_1-breslow_likelihood:6.24982
# [19]	validation_0-breslow_likelihood:7.57992	validation_1-breslow_likelihood:6.24910
# [20]	validation_0-breslow_likelihood:7.57726	validation_1-breslow_likelihood:6.24849
# [21]	validation_0-breslow_likelihood:7.57629	validation_1-breslow_likelihood:6.24832
# [22]	validation_0-breslow_likelihood:7.57460	validation_1-breslow_likelihood:6.24784
# [23]	validation_0-breslow_likelihood:7.56938	validation_1-breslow_likelihood:6.24708
# [24]	validation_0-breslow_likelihood:7.56711	validation_1-breslow_likelihood:6.24667
# [25]	validation_0-breslow_likelihood:7.56499	validation_1-breslow_likelihood:6.24636
# [26]	validation_0-breslow_likelihood:7.56120	validation_1-breslow_likelihood:6.24552
# [27]	validation_0-breslow_likelihood:7.56022	validation_1-breslow_likelihood:6.24544
# [28]	validation_0-breslow_likelihood:7.55806	validation_1-breslow_likelihood:6.24517
# [29]	validation_0-breslow_likelihood:7.55500	validation_1-breslow_likelihood:6.24464
# [30]	validation_0-breslow_likelihood:7.55293	validation_1-breslow_likelihood:6.24389
# [31]	validation_0-breslow_likelihood:7.55063	validation_1-breslow_likelihood:6.24360
# [32]	validation_0-breslow_likelihood:7.54754	validation_1-breslow_likelihood:6.24304
# [33]	validation_0-breslow_likelihood:7.54580	validation_1-breslow_likelihood:6.24277
# [34]	validation_0-breslow_likelihood:7.54462	validation_1-breslow_likelihood:6.24294
# [35]	validation_0-breslow_likelihood:7.54095	validation_1-breslow_likelihood:6.24263
# [36]	validation_0-breslow_likelihood:7.53933	validation_1-breslow_likelihood:6.24251
# [37]	validation_0-breslow_likelihood:7.53574	validation_1-breslow_likelihood:6.24215
# [38]	validation_0-breslow_likelihood:7.53535	validation_1-breslow_likelihood:6.24191
# [39]	validation_0-breslow_likelihood:7.53240	validation_1-breslow_likelihood:6.24203
# [40]	validation_0-breslow_likelihood:7.53187	validation_1-breslow_likelihood:6.24192
# [41]	validation_0-breslow_likelihood:7.52919	validation_1-breslow_likelihood:6.24165
# [42]	validation_0-breslow_likelihood:7.52901	validation_1-breslow_likelihood:6.24159
# [43]	validation_0-breslow_likelihood:7.52573	validation_1-breslow_likelihood:6.24183
# [44]	validation_0-breslow_likelihood:7.52453	validation_1-breslow_likelihood:6.24164
# [45]	validation_0-breslow_likelihood:7.52334	validation_1-breslow_likelihood:6.24140
# [46]	validation_0-breslow_likelihood:7.51985	validation_1-breslow_likelihood:6.24152
# [47]	validation_0-breslow_likelihood:7.51732	validation_1-breslow_likelihood:6.24149
# [48]	validation_0-breslow_likelihood:7.51383	validation_1-breslow_likelihood:6.24181
# [49]	validation_0-breslow_likelihood:7.51122	validation_1-breslow_likelihood:6.24160
# [50]	validation_0-breslow_likelihood:7.50854	validation_1-breslow_likelihood:6.24124
# [51]	validation_0-breslow_likelihood:7.50424	validation_1-breslow_likelihood:6.24067
# [52]	validation_0-breslow_likelihood:7.50172	validation_1-breslow_likelihood:6.24044
# [53]	validation_0-breslow_likelihood:7.50003	validation_1-breslow_likelihood:6.23988
# [54]	validation_0-breslow_likelihood:7.49912	validation_1-breslow_likelihood:6.23964
# [55]	validation_0-breslow_likelihood:7.49537	validation_1-breslow_likelihood:6.23916
# [56]	validation_0-breslow_likelihood:7.49399	validation_1-breslow_likelihood:6.23933
# [57]	validation_0-breslow_likelihood:7.49287	validation_1-breslow_likelihood:6.23940
# [58]	validation_0-breslow_likelihood:7.49000	validation_1-breslow_likelihood:6.23925
# [59]	validation_0-breslow_likelihood:7.48620	validation_1-breslow_likelihood:6.23896
# [60]	validation_0-breslow_likelihood:7.48584	validation_1-breslow_likelihood:6.23882
# [61]	validation_0-breslow_likelihood:7.48526	validation_1-breslow_likelihood:6.23887
# [62]	validation_0-breslow_likelihood:7.48381	validation_1-breslow_likelihood:6.23866
# [63]	validation_0-breslow_likelihood:7.48035	validation_1-breslow_likelihood:6.23867
# [64]	validation_0-breslow_likelihood:7.47883	validation_1-breslow_likelihood:6.23877
# [65]	validation_0-breslow_likelihood:7.47577	validation_1-breslow_likelihood:6.23930
# [66]	validation_0-breslow_likelihood:7.47146	validation_1-breslow_likelihood:6.23933
# [67]	validation_0-breslow_likelihood:7.46823	validation_1-breslow_likelihood:6.23918
# [68]	validation_0-breslow_likelihood:7.46578	validation_1-breslow_likelihood:6.23936
# [69]	validation_0-breslow_likelihood:7.46335	validation_1-breslow_likelihood:6.23928
# [70]	validation_0-breslow_likelihood:7.45905	validation_1-breslow_likelihood:6.23981
# [71]	validation_0-breslow_likelihood:7.45584	validation_1-breslow_likelihood:6.23975
# Concordance Index 0.651092062818272
# Integrated Brier Score: 0.1908561761919677
# durations 3.0 2029.0
# Concordance Index 0.6003872377970014
# Integrated Brier Score: 0.19876008393289815

# %% [markdown]
# ## TCGA Train, Test, Evaluation

# %%
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
'pca__n_components': [8, 16, 32, 64]
}

# %%
n_iter = 2

# %%
cancer_types = ['BLCA',
    'BRCA',
    'HNSC',
    'KIRC',
    'LGG',
    'LIHC',
    'LUAD',
    'LUSC',
    'OV',
    'STAD']
agg_metrics_cindex = []
agg_metrics_ibs = []


for idx, cancer_type in enumerate(cancer_types):
    model = 'xgbsurv_breslow_'
    # get name of current dataset
    data = load_tcga(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", cancer_type=cancer_type, as_frame=True)
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()
    filename = data.filename
    dataset_name = filename.split('_')[0]
    X, y = sort_X_y_pandas(X, y)

    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='breslow_objective',
        eval_metric='breslow_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    
    pipe = Pipeline([('scaler',ct),
                    ('pca', PCA()),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=2, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        #print(y_train.shape, type(y_train))
        #print(X_train.shape, type(X_train))
        #print(X_test.shape, type(X_test))
        #print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_breslow(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_breslow(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
            # cindex
    df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                            'cindex_train_mean':df_outer_scores['cindex_train_'+dataset_name].mean(),
                                            'cindex_train_std':df_outer_scores['cindex_train_'+dataset_name].std(),
                                            'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                            'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })
    # IBS
    df_agg_metrics_ibs = pd.DataFrame({'dataset':[dataset_name],
                                            'ibs_train_mean':df_outer_scores['ibs_train_'+dataset_name].mean(),
                                            'ibs_train_std':df_outer_scores['ibs_train_'+dataset_name].std(),
                                            'ibs_test_mean':df_outer_scores['ibs_test_'+dataset_name].mean(),
                                            'ibs_test_std':df_outer_scores['ibs_test_'+dataset_name].std() })

df_agg_metrics_cindex, df_agg_metrics_ibs, best_model,params, outer_scores, best_preds_train, best_preds_test = train_eval(X, y, net, n_iter, data.filename)
agg_metrics_cindex.append(df_agg_metrics_cindex)
agg_metrics_ibs.append(df_agg_metrics_ibs)
# Out:
# (324, 20531) <class 'pandas.core.frame.DataFrame'>
# (324,) <class 'pandas.core.series.Series'>
# (82, 20531) <class 'pandas.core.frame.DataFrame'>
# (82,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:4.19063	validation_1-breslow_likelihood:3.14319
# [1]	validation_0-breslow_likelihood:4.19000	validation_1-breslow_likelihood:3.14292
# [2]	validation_0-breslow_likelihood:4.18900	validation_1-breslow_likelihood:3.14306
# [3]	validation_0-breslow_likelihood:4.18808	validation_1-breslow_likelihood:3.14333
# [4]	validation_0-breslow_likelihood:4.18704	validation_1-breslow_likelihood:3.14423
# [5]	validation_0-breslow_likelihood:4.18650	validation_1-breslow_likelihood:3.14460
# [6]	validation_0-breslow_likelihood:4.18536	validation_1-breslow_likelihood:3.14499
# [7]	validation_0-breslow_likelihood:4.18476	validation_1-breslow_likelihood:3.14466
# [8]	validation_0-breslow_likelihood:4.18395	validation_1-breslow_likelihood:3.14522
# [9]	validation_0-breslow_likelihood:4.18286	validation_1-breslow_likelihood:3.14527
# [10]	validation_0-breslow_likelihood:4.18241	validation_1-breslow_likelihood:3.14510
# [11]	validation_0-breslow_likelihood:4.18211	validation_1-breslow_likelihood:3.14525
# [0]	validation_0-breslow_likelihood:4.20076	validation_1-breslow_likelihood:3.13246
# [1]	validation_0-breslow_likelihood:4.20024	validation_1-breslow_likelihood:3.13209
# [2]	validation_0-breslow_likelihood:4.19973	validation_1-breslow_likelihood:3.13148
# [3]	validation_0-breslow_likelihood:4.19893	validation_1-breslow_likelihood:3.13193
# [4]	validation_0-breslow_likelihood:4.19792	validation_1-breslow_likelihood:3.13188
# [5]	validation_0-breslow_likelihood:4.19698	validation_1-breslow_likelihood:3.13191
# [6]	validation_0-breslow_likelihood:4.19642	validation_1-breslow_likelihood:3.13176
# [7]	validation_0-breslow_likelihood:4.19611	validation_1-breslow_likelihood:3.13157
# [8]	validation_0-breslow_likelihood:4.19544	validation_1-breslow_likelihood:3.13186
# [0]	validation_0-breslow_likelihood:4.19068	validation_1-breslow_likelihood:3.14249
# [9]	validation_0-breslow_likelihood:4.19485	validation_1-breslow_likelihood:3.13154
# [1]	validation_0-breslow_likelihood:4.19034	validation_1-breslow_likelihood:3.14233
# [10]	validation_0-breslow_likelihood:4.19411	validation_1-breslow_likelihood:3.13191
# [2]	validation_0-breslow_likelihood:4.18942	validation_1-breslow_likelihood:3.14226
# [11]	validation_0-breslow_likelihood:4.19367	validation_1-breslow_likelihood:3.13104
# [3]	validation_0-breslow_likelihood:4.18865	validation_1-breslow_likelihood:3.14202
# [12]	validation_0-breslow_likelihood:4.19327	validation_1-breslow_likelihood:3.13055
# [13]	validation_0-breslow_likelihood:4.19281	validation_1-breslow_likelihood:3.13057
# [4]	validation_0-breslow_likelihood:4.18790	validation_1-breslow_likelihood:3.14177
# [14]	validation_0-breslow_likelihood:4.19248	validation_1-breslow_likelihood:3.13035
# [5]	validation_0-breslow_likelihood:4.18709	validation_1-breslow_likelihood:3.14077
# [15]	validation_0-breslow_likelihood:4.19182	validation_1-breslow_likelihood:3.12967
# [6]	validation_0-breslow_likelihood:4.18675	validation_1-breslow_likelihood:3.14121
# [16]	validation_0-breslow_likelihood:4.19114	validation_1-breslow_likelihood:3.13055
# [7]	validation_0-breslow_likelihood:4.18633	validation_1-breslow_likelihood:3.14129
# [17]	validation_0-breslow_likelihood:4.19017	validation_1-breslow_likelihood:3.12980
# [8]	validation_0-breslow_likelihood:4.18558	validation_1-breslow_likelihood:3.14113
# [18]	validation_0-breslow_likelihood:4.18963	validation_1-breslow_likelihood:3.12992
# [9]	validation_0-breslow_likelihood:4.18491	validation_1-breslow_likelihood:3.14066
# [19]	validation_0-breslow_likelihood:4.18930	validation_1-breslow_likelihood:3.12945
# [10]	validation_0-breslow_likelihood:4.18409	validation_1-breslow_likelihood:3.14050
# [20]	validation_0-breslow_likelihood:4.18905	validation_1-breslow_likelihood:3.12931
# [11]	validation_0-breslow_likelihood:4.18342	validation_1-breslow_likelihood:3.14047
# [21]	validation_0-breslow_likelihood:4.18837	validation_1-breslow_likelihood:3.12913
# [12]	validation_0-breslow_likelihood:4.18317	validation_1-breslow_likelihood:3.14068
# [22]	validation_0-breslow_likelihood:4.18775	validation_1-breslow_likelihood:3.12895
# [13]	validation_0-breslow_likelihood:4.18275	validation_1-breslow_likelihood:3.14077
# [23]	validation_0-breslow_likelihood:4.18740	validation_1-breslow_likelihood:3.12930
# [14]	validation_0-breslow_likelihood:4.18250	validation_1-breslow_likelihood:3.14112
# [24]	validation_0-breslow_likelihood:4.18710	validation_1-breslow_likelihood:3.12865
# [15]	validation_0-breslow_likelihood:4.18206	validation_1-breslow_likelihood:3.14078
# [25]	validation_0-breslow_likelihood:4.18656	validation_1-breslow_likelihood:3.12857
# [16]	validation_0-breslow_likelihood:4.18139	validation_1-breslow_likelihood:3.14081
# [26]	validation_0-breslow_likelihood:4.18558	validation_1-breslow_likelihood:3.12955
# [17]	validation_0-breslow_likelihood:4.18107	validation_1-breslow_likelihood:3.14103
# [18]	validation_0-breslow_likelihood:4.18056	validation_1-breslow_likelihood:3.14149
# [27]	validation_0-breslow_likelihood:4.18487	validation_1-breslow_likelihood:3.12982
# [19]	validation_0-breslow_likelihood:4.17976	validation_1-breslow_likelihood:3.14106
# [28]	validation_0-breslow_likelihood:4.18429	validation_1-breslow_likelihood:3.12917
# [20]	validation_0-breslow_likelihood:4.17954	validation_1-breslow_likelihood:3.14084
# [29]	validation_0-breslow_likelihood:4.18347	validation_1-breslow_likelihood:3.12874
# [21]	validation_0-breslow_likelihood:4.17895	validation_1-breslow_likelihood:3.14103
# [30]	validation_0-breslow_likelihood:4.18305	validation_1-breslow_likelihood:3.12910
# [31]	validation_0-breslow_likelihood:4.18259	validation_1-breslow_likelihood:3.12907
# [32]	validation_0-breslow_likelihood:4.18213	validation_1-breslow_likelihood:3.12874
# [33]	validation_0-breslow_likelihood:4.18148	validation_1-breslow_likelihood:3.12911
# [34]	validation_0-breslow_likelihood:4.18078	validation_1-breslow_likelihood:3.12928
# [35]	validation_0-breslow_likelihood:4.18043	validation_1-breslow_likelihood:3.12893
# [0]	validation_0-breslow_likelihood:4.18862	validation_1-breslow_likelihood:3.13234
# [1]	validation_0-breslow_likelihood:4.17586	validation_1-breslow_likelihood:3.13120
# [2]	validation_0-breslow_likelihood:4.16390	validation_1-breslow_likelihood:3.12792
# [3]	validation_0-breslow_likelihood:4.15219	validation_1-breslow_likelihood:3.12918
# [4]	validation_0-breslow_likelihood:4.14170	validation_1-breslow_likelihood:3.12744
# [5]	validation_0-breslow_likelihood:4.13165	validation_1-breslow_likelihood:3.12945
# [6]	validation_0-breslow_likelihood:4.12179	validation_1-breslow_likelihood:3.13048
# [7]	validation_0-breslow_likelihood:4.11112	validation_1-breslow_likelihood:3.13176
# [8]	validation_0-breslow_likelihood:4.10142	validation_1-breslow_likelihood:3.13028
# [9]	validation_0-breslow_likelihood:4.09115	validation_1-breslow_likelihood:3.12942
# [10]	validation_0-breslow_likelihood:4.07994	validation_1-breslow_likelihood:3.12877
# [11]	validation_0-breslow_likelihood:4.06969	validation_1-breslow_likelihood:3.12894
# [12]	validation_0-breslow_likelihood:4.06072	validation_1-breslow_likelihood:3.12858
# [13]	validation_0-breslow_likelihood:4.05026	validation_1-breslow_likelihood:3.13129
# [14]	validation_0-breslow_likelihood:4.04124	validation_1-breslow_likelihood:3.12964
# [0]	validation_0-breslow_likelihood:4.17868	validation_1-breslow_likelihood:3.14824
# [1]	validation_0-breslow_likelihood:4.16654	validation_1-breslow_likelihood:3.15103
# [2]	validation_0-breslow_likelihood:4.15524	validation_1-breslow_likelihood:3.15114
# [3]	validation_0-breslow_likelihood:4.14428	validation_1-breslow_likelihood:3.15367
# [4]	validation_0-breslow_likelihood:4.13390	validation_1-breslow_likelihood:3.15499
# [5]	validation_0-breslow_likelihood:4.12346	validation_1-breslow_likelihood:3.15624
# [6]	validation_0-breslow_likelihood:4.11245	validation_1-breslow_likelihood:3.15958
# [7]	validation_0-breslow_likelihood:4.10119	validation_1-breslow_likelihood:3.16132
# [8]	validation_0-breslow_likelihood:4.09105	validation_1-breslow_likelihood:3.16449
# [9]	validation_0-breslow_likelihood:4.07927	validation_1-breslow_likelihood:3.16575
# [10]	validation_0-breslow_likelihood:4.06906	validation_1-breslow_likelihood:3.16965
# [0]	validation_0-breslow_likelihood:4.20136	validation_1-breslow_likelihood:3.13964
# [1]	validation_0-breslow_likelihood:4.19033	validation_1-breslow_likelihood:3.13926
# [2]	validation_0-breslow_likelihood:4.17990	validation_1-breslow_likelihood:3.13603
# [3]	validation_0-breslow_likelihood:4.16974	validation_1-breslow_likelihood:3.13665
# [4]	validation_0-breslow_likelihood:4.15784	validation_1-breslow_likelihood:3.14099
# [5]	validation_0-breslow_likelihood:4.14651	validation_1-breslow_likelihood:3.14497
# [6]	validation_0-breslow_likelihood:4.13583	validation_1-breslow_likelihood:3.14501
# [7]	validation_0-breslow_likelihood:4.12517	validation_1-breslow_likelihood:3.14432
# [8]	validation_0-breslow_likelihood:4.11390	validation_1-breslow_likelihood:3.14384
# [9]	validation_0-breslow_likelihood:4.10372	validation_1-breslow_likelihood:3.14157
# [10]	validation_0-breslow_likelihood:4.09415	validation_1-breslow_likelihood:3.14331
# [11]	validation_0-breslow_likelihood:4.08145	validation_1-breslow_likelihood:3.14266
# [12]	validation_0-breslow_likelihood:4.07167	validation_1-breslow_likelihood:3.14085
# [0]	validation_0-breslow_likelihood:4.20136	validation_1-breslow_likelihood:3.14122
# [0]	validation_0-breslow_likelihood:4.18045	validation_1-breslow_likelihood:3.14220
# [1]	validation_0-breslow_likelihood:4.20063	validation_1-breslow_likelihood:3.14161
# [1]	validation_0-breslow_likelihood:4.16930	validation_1-breslow_likelihood:3.14123
# [2]	validation_0-breslow_likelihood:4.20013	validation_1-breslow_likelihood:3.14113
# [3]	validation_0-breslow_likelihood:4.19946	validation_1-breslow_likelihood:3.14089
# [2]	validation_0-breslow_likelihood:4.15843	validation_1-breslow_likelihood:3.14358
# [4]	validation_0-breslow_likelihood:4.19847	validation_1-breslow_likelihood:3.14129
# [5]	validation_0-breslow_likelihood:4.19808	validation_1-breslow_likelihood:3.14157
# [3]	validation_0-breslow_likelihood:4.14736	validation_1-breslow_likelihood:3.14289
# [6]	validation_0-breslow_likelihood:4.19733	validation_1-breslow_likelihood:3.14152
# [7]	validation_0-breslow_likelihood:4.19705	validation_1-breslow_likelihood:3.14120
# [4]	validation_0-breslow_likelihood:4.13683	validation_1-breslow_likelihood:3.14411
# [8]	validation_0-breslow_likelihood:4.19647	validation_1-breslow_likelihood:3.14078
# [9]	validation_0-breslow_likelihood:4.19583	validation_1-breslow_likelihood:3.14080
# [5]	validation_0-breslow_likelihood:4.12663	validation_1-breslow_likelihood:3.14441
# [10]	validation_0-breslow_likelihood:4.19495	validation_1-breslow_likelihood:3.14046
# [11]	validation_0-breslow_likelihood:4.19446	validation_1-breslow_likelihood:3.14031
# [6]	validation_0-breslow_likelihood:4.11641	validation_1-breslow_likelihood:3.14311
# [12]	validation_0-breslow_likelihood:4.19384	validation_1-breslow_likelihood:3.14055
# [13]	validation_0-breslow_likelihood:4.19334	validation_1-breslow_likelihood:3.14050
# [7]	validation_0-breslow_likelihood:4.10543	validation_1-breslow_likelihood:3.14309
# [14]	validation_0-breslow_likelihood:4.19276	validation_1-breslow_likelihood:3.14057
# [15]	validation_0-breslow_likelihood:4.19225	validation_1-breslow_likelihood:3.14129
# [16]	validation_0-breslow_likelihood:4.19170	validation_1-breslow_likelihood:3.14134
# [8]	validation_0-breslow_likelihood:4.09552	validation_1-breslow_likelihood:3.14336
# [17]	validation_0-breslow_likelihood:4.19122	validation_1-breslow_likelihood:3.14150
# [9]	validation_0-breslow_likelihood:4.08382	validation_1-breslow_likelihood:3.14662
# [18]	validation_0-breslow_likelihood:4.19061	validation_1-breslow_likelihood:3.14126
# [19]	validation_0-breslow_likelihood:4.19005	validation_1-breslow_likelihood:3.14099
# [10]	validation_0-breslow_likelihood:4.07229	validation_1-breslow_likelihood:3.14615
# [20]	validation_0-breslow_likelihood:4.18968	validation_1-breslow_likelihood:3.14080
# [21]	validation_0-breslow_likelihood:4.18915	validation_1-breslow_likelihood:3.14113
# [11]	validation_0-breslow_likelihood:4.06209	validation_1-breslow_likelihood:3.14691
# [0]	validation_0-breslow_likelihood:4.21119	validation_1-breslow_likelihood:3.14138
# [1]	validation_0-breslow_likelihood:4.21051	validation_1-breslow_likelihood:3.14141
# [2]	validation_0-breslow_likelihood:4.20982	validation_1-breslow_likelihood:3.14153
# [3]	validation_0-breslow_likelihood:4.20911	validation_1-breslow_likelihood:3.14070
# [4]	validation_0-breslow_likelihood:4.20826	validation_1-breslow_likelihood:3.14073
# [5]	validation_0-breslow_likelihood:4.20753	validation_1-breslow_likelihood:3.13983
# [6]	validation_0-breslow_likelihood:4.20670	validation_1-breslow_likelihood:3.14018
# [7]	validation_0-breslow_likelihood:4.20633	validation_1-breslow_likelihood:3.13941
# [8]	validation_0-breslow_likelihood:4.20597	validation_1-breslow_likelihood:3.13941
# [9]	validation_0-breslow_likelihood:4.20518	validation_1-breslow_likelihood:3.13906
# [10]	validation_0-breslow_likelihood:4.20456	validation_1-breslow_likelihood:3.13898
# [11]	validation_0-breslow_likelihood:4.20381	validation_1-breslow_likelihood:3.13973
# [12]	validation_0-breslow_likelihood:4.20306	validation_1-breslow_likelihood:3.14012
# [13]	validation_0-breslow_likelihood:4.20277	validation_1-breslow_likelihood:3.13957
# [14]	validation_0-breslow_likelihood:4.20211	validation_1-breslow_likelihood:3.13961
# [15]	validation_0-breslow_likelihood:4.20168	validation_1-breslow_likelihood:3.13909
# [16]	validation_0-breslow_likelihood:4.20123	validation_1-breslow_likelihood:3.13892
# [17]	validation_0-breslow_likelihood:4.20079	validation_1-breslow_likelihood:3.13858
# [18]	validation_0-breslow_likelihood:4.19991	validation_1-breslow_likelihood:3.13840
# [19]	validation_0-breslow_likelihood:4.19918	validation_1-breslow_likelihood:3.13775
# [20]	validation_0-breslow_likelihood:4.19850	validation_1-breslow_likelihood:3.13738
# [21]	validation_0-breslow_likelihood:4.19770	validation_1-breslow_likelihood:3.13732
# [22]	validation_0-breslow_likelihood:4.19700	validation_1-breslow_likelihood:3.13732
# [23]	validation_0-breslow_likelihood:4.19593	validation_1-breslow_likelihood:3.13831
# [24]	validation_0-breslow_likelihood:4.19493	validation_1-breslow_likelihood:3.13778
# [25]	validation_0-breslow_likelihood:4.19421	validation_1-breslow_likelihood:3.13741
# [26]	validation_0-breslow_likelihood:4.19361	validation_1-breslow_likelihood:3.13760
# [27]	validation_0-breslow_likelihood:4.19277	validation_1-breslow_likelihood:3.13796
# [28]	validation_0-breslow_likelihood:4.19208	validation_1-breslow_likelihood:3.13883
# [29]	validation_0-breslow_likelihood:4.19136	validation_1-breslow_likelihood:3.13861
# [30]	validation_0-breslow_likelihood:4.19078	validation_1-breslow_likelihood:3.13835
# [31]	validation_0-breslow_likelihood:4.18994	validation_1-breslow_likelihood:3.13851
# [32]	validation_0-breslow_likelihood:4.18935	validation_1-breslow_likelihood:3.13838
# [0]	validation_0-breslow_likelihood:4.19095	validation_1-breslow_likelihood:3.13835
# [1]	validation_0-breslow_likelihood:4.17998	validation_1-breslow_likelihood:3.13348
# [2]	validation_0-breslow_likelihood:4.16946	validation_1-breslow_likelihood:3.13314
# [3]	validation_0-breslow_likelihood:4.15734	validation_1-breslow_likelihood:3.13381
# [4]	validation_0-breslow_likelihood:4.14681	validation_1-breslow_likelihood:3.13192
# [5]	validation_0-breslow_likelihood:4.13664	validation_1-breslow_likelihood:3.13141
# [6]	validation_0-breslow_likelihood:4.12675	validation_1-breslow_likelihood:3.13385
# [7]	validation_0-breslow_likelihood:4.11723	validation_1-breslow_likelihood:3.13270
# [8]	validation_0-breslow_likelihood:4.10651	validation_1-breslow_likelihood:3.13226
# [9]	validation_0-breslow_likelihood:4.09548	validation_1-breslow_likelihood:3.13149
# [10]	validation_0-breslow_likelihood:4.08272	validation_1-breslow_likelihood:3.13209
# [11]	validation_0-breslow_likelihood:4.07203	validation_1-breslow_likelihood:3.12957
# [12]	validation_0-breslow_likelihood:4.06245	validation_1-breslow_likelihood:3.12911
# [13]	validation_0-breslow_likelihood:4.05306	validation_1-breslow_likelihood:3.12944
# [14]	validation_0-breslow_likelihood:4.04211	validation_1-breslow_likelihood:3.12717
# [15]	validation_0-breslow_likelihood:4.03145	validation_1-breslow_likelihood:3.12942
# [16]	validation_0-breslow_likelihood:4.02067	validation_1-breslow_likelihood:3.12899
# [17]	validation_0-breslow_likelihood:4.01237	validation_1-breslow_likelihood:3.12751
# [18]	validation_0-breslow_likelihood:4.00263	validation_1-breslow_likelihood:3.12864
# [19]	validation_0-breslow_likelihood:3.99264	validation_1-breslow_likelihood:3.13063
# [20]	validation_0-breslow_likelihood:3.98326	validation_1-breslow_likelihood:3.13037
# [21]	validation_0-breslow_likelihood:3.97495	validation_1-breslow_likelihood:3.12529
# [22]	validation_0-breslow_likelihood:3.96573	validation_1-breslow_likelihood:3.12469
# [23]	validation_0-breslow_likelihood:3.95646	validation_1-breslow_likelihood:3.12679
# [24]	validation_0-breslow_likelihood:3.94658	validation_1-breslow_likelihood:3.12937
# [25]	validation_0-breslow_likelihood:3.93852	validation_1-breslow_likelihood:3.12798
# [26]	validation_0-breslow_likelihood:3.93055	validation_1-breslow_likelihood:3.12848
# [27]	validation_0-breslow_likelihood:3.92273	validation_1-breslow_likelihood:3.12732
# [28]	validation_0-breslow_likelihood:3.91368	validation_1-breslow_likelihood:3.12681
# [29]	validation_0-breslow_likelihood:3.90617	validation_1-breslow_likelihood:3.12644
# [30]	validation_0-breslow_likelihood:3.89786	validation_1-breslow_likelihood:3.12443
# [31]	validation_0-breslow_likelihood:3.88920	validation_1-breslow_likelihood:3.12232
# [32]	validation_0-breslow_likelihood:3.88094	validation_1-breslow_likelihood:3.12202
# [0]	validation_0-breslow_likelihood:4.54032	validation_1-breslow_likelihood:3.38027
# [1]	validation_0-breslow_likelihood:4.52710	validation_1-breslow_likelihood:3.38058
# [2]	validation_0-breslow_likelihood:4.51440	validation_1-breslow_likelihood:3.37897
# [3]	validation_0-breslow_likelihood:4.50259	validation_1-breslow_likelihood:3.38517
# [4]	validation_0-breslow_likelihood:4.49065	validation_1-breslow_likelihood:3.38477
# [5]	validation_0-breslow_likelihood:4.47882	validation_1-breslow_likelihood:3.38808
# [6]	validation_0-breslow_likelihood:4.46771	validation_1-breslow_likelihood:3.38880
# [7]	validation_0-breslow_likelihood:4.45480	validation_1-breslow_likelihood:3.39253
# [8]	validation_0-breslow_likelihood:4.44312	validation_1-breslow_likelihood:3.39571
# [9]	validation_0-breslow_likelihood:4.43209	validation_1-breslow_likelihood:3.39613
# [10]	validation_0-breslow_likelihood:4.42105	validation_1-breslow_likelihood:3.39320
# [11]	validation_0-breslow_likelihood:4.41037	validation_1-breslow_likelihood:3.39269
# [12]	validation_0-breslow_likelihood:4.39967	validation_1-breslow_likelihood:3.39531
# Concordance Index 0.7273129540174785
# Integrated Brier Score: 0.20848843218732357
# durations 17.0 4343.0
# Concordance Index 0.5486187845303867
# Integrated Brier Score: 0.2257184477814743
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:4.21137	validation_1-breslow_likelihood:3.13263
# [1]	validation_0-breslow_likelihood:4.21116	validation_1-breslow_likelihood:3.13259
# [2]	validation_0-breslow_likelihood:4.21098	validation_1-breslow_likelihood:3.13252
# [3]	validation_0-breslow_likelihood:4.21095	validation_1-breslow_likelihood:3.13244
# [4]	validation_0-breslow_likelihood:4.21077	validation_1-breslow_likelihood:3.13242
# [5]	validation_0-breslow_likelihood:4.21059	validation_1-breslow_likelihood:3.13227
# [6]	validation_0-breslow_likelihood:4.21044	validation_1-breslow_likelihood:3.13215
# [7]	validation_0-breslow_likelihood:4.21028	validation_1-breslow_likelihood:3.13211
# [8]	validation_0-breslow_likelihood:4.21010	validation_1-breslow_likelihood:3.13193
# [9]	validation_0-breslow_likelihood:4.20999	validation_1-breslow_likelihood:3.13201
# [10]	validation_0-breslow_likelihood:4.20980	validation_1-breslow_likelihood:3.13180
# [11]	validation_0-breslow_likelihood:4.20945	validation_1-breslow_likelihood:3.13152
# [12]	validation_0-breslow_likelihood:4.20925	validation_1-breslow_likelihood:3.13141
# [13]	validation_0-breslow_likelihood:4.20918	validation_1-breslow_likelihood:3.13140
# [14]	validation_0-breslow_likelihood:4.20909	validation_1-breslow_likelihood:3.13141
# [15]	validation_0-breslow_likelihood:4.20904	validation_1-breslow_likelihood:3.13135
# [16]	validation_0-breslow_likelihood:4.20885	validation_1-breslow_likelihood:3.13128
# [17]	validation_0-breslow_likelihood:4.20866	validation_1-breslow_likelihood:3.13127
# [18]	validation_0-breslow_likelihood:4.20851	validation_1-breslow_likelihood:3.13125
# [19]	validation_0-breslow_likelihood:4.20833	validation_1-breslow_likelihood:3.13118
# [20]	validation_0-breslow_likelihood:4.20811	validation_1-breslow_likelihood:3.13109
# [21]	validation_0-breslow_likelihood:4.20800	validation_1-breslow_likelihood:3.13098
# [22]	validation_0-breslow_likelihood:4.20776	validation_1-breslow_likelihood:3.13088
# [23]	validation_0-breslow_likelihood:4.20768	validation_1-breslow_likelihood:3.13084
# [24]	validation_0-breslow_likelihood:4.20742	validation_1-breslow_likelihood:3.13056
# [25]	validation_0-breslow_likelihood:4.20721	validation_1-breslow_likelihood:3.13048
# [26]	validation_0-breslow_likelihood:4.20709	validation_1-breslow_likelihood:3.13050
# [27]	validation_0-breslow_likelihood:4.20687	validation_1-breslow_likelihood:3.13043
# [28]	validation_0-breslow_likelihood:4.20669	validation_1-breslow_likelihood:3.13031
# [29]	validation_0-breslow_likelihood:4.20647	validation_1-breslow_likelihood:3.13023
# [30]	validation_0-breslow_likelihood:4.20626	validation_1-breslow_likelihood:3.13019
# [31]	validation_0-breslow_likelihood:4.20615	validation_1-breslow_likelihood:3.13020
# [32]	validation_0-breslow_likelihood:4.20587	validation_1-breslow_likelihood:3.12989
# [33]	validation_0-breslow_likelihood:4.20566	validation_1-breslow_likelihood:3.12987
# [34]	validation_0-breslow_likelihood:4.20561	validation_1-breslow_likelihood:3.12981
# [35]	validation_0-breslow_likelihood:4.20545	validation_1-breslow_likelihood:3.12968
# [36]	validation_0-breslow_likelihood:4.20522	validation_1-breslow_likelihood:3.12960
# [37]	validation_0-breslow_likelihood:4.20507	validation_1-breslow_likelihood:3.12938
# [0]	validation_0-breslow_likelihood:4.21301	validation_1-breslow_likelihood:3.14348
# [1]	validation_0-breslow_likelihood:4.21277	validation_1-breslow_likelihood:3.14338
# [2]	validation_0-breslow_likelihood:4.21267	validation_1-breslow_likelihood:3.14333
# [3]	validation_0-breslow_likelihood:4.21246	validation_1-breslow_likelihood:3.14319
# [4]	validation_0-breslow_likelihood:4.21230	validation_1-breslow_likelihood:3.14315
# [5]	validation_0-breslow_likelihood:4.21219	validation_1-breslow_likelihood:3.14301
# [6]	validation_0-breslow_likelihood:4.21203	validation_1-breslow_likelihood:3.14294
# [7]	validation_0-breslow_likelihood:4.21184	validation_1-breslow_likelihood:3.14278
# [8]	validation_0-breslow_likelihood:4.21165	validation_1-breslow_likelihood:3.14271
# [9]	validation_0-breslow_likelihood:4.21150	validation_1-breslow_likelihood:3.14269
# [10]	validation_0-breslow_likelihood:4.21133	validation_1-breslow_likelihood:3.14259
# [11]	validation_0-breslow_likelihood:4.21113	validation_1-breslow_likelihood:3.14241
# [12]	validation_0-breslow_likelihood:4.21100	validation_1-breslow_likelihood:3.14234
# [13]	validation_0-breslow_likelihood:4.21085	validation_1-breslow_likelihood:3.14230
# [14]	validation_0-breslow_likelihood:4.21064	validation_1-breslow_likelihood:3.14204
# [15]	validation_0-breslow_likelihood:4.21051	validation_1-breslow_likelihood:3.14194
# [16]	validation_0-breslow_likelihood:4.21039	validation_1-breslow_likelihood:3.14185
# [17]	validation_0-breslow_likelihood:4.21019	validation_1-breslow_likelihood:3.14183
# [18]	validation_0-breslow_likelihood:4.21002	validation_1-breslow_likelihood:3.14167
# [19]	validation_0-breslow_likelihood:4.20982	validation_1-breslow_likelihood:3.14151
# [20]	validation_0-breslow_likelihood:4.20963	validation_1-breslow_likelihood:3.14134
# [21]	validation_0-breslow_likelihood:4.20941	validation_1-breslow_likelihood:3.14116
# [22]	validation_0-breslow_likelihood:4.20926	validation_1-breslow_likelihood:3.14117
# [23]	validation_0-breslow_likelihood:4.20908	validation_1-breslow_likelihood:3.14097
# [24]	validation_0-breslow_likelihood:4.20896	validation_1-breslow_likelihood:3.14093
# [25]	validation_0-breslow_likelihood:4.20881	validation_1-breslow_likelihood:3.14077
# [26]	validation_0-breslow_likelihood:4.20876	validation_1-breslow_likelihood:3.14079
# [0]	validation_0-breslow_likelihood:4.21178	validation_1-breslow_likelihood:3.14100
# [27]	validation_0-breslow_likelihood:4.20859	validation_1-breslow_likelihood:3.14071
# [1]	validation_0-breslow_likelihood:4.21153	validation_1-breslow_likelihood:3.14099
# [28]	validation_0-breslow_likelihood:4.20843	validation_1-breslow_likelihood:3.14061
# [2]	validation_0-breslow_likelihood:4.21133	validation_1-breslow_likelihood:3.14089
# [29]	validation_0-breslow_likelihood:4.20823	validation_1-breslow_likelihood:3.14057
# [30]	validation_0-breslow_likelihood:4.20804	validation_1-breslow_likelihood:3.14046
# [3]	validation_0-breslow_likelihood:4.21112	validation_1-breslow_likelihood:3.14088
# [31]	validation_0-breslow_likelihood:4.20791	validation_1-breslow_likelihood:3.14044
# [4]	validation_0-breslow_likelihood:4.21094	validation_1-breslow_likelihood:3.14057
# [32]	validation_0-breslow_likelihood:4.20781	validation_1-breslow_likelihood:3.14045
# [5]	validation_0-breslow_likelihood:4.21067	validation_1-breslow_likelihood:3.14064
# [33]	validation_0-breslow_likelihood:4.20766	validation_1-breslow_likelihood:3.14042[6]	validation_0-breslow_likelihood:4.21048	validation_1-breslow_likelihood:3.14043
#
# [7]	validation_0-breslow_likelihood:4.21025	validation_1-breslow_likelihood:3.14038
# [8]	validation_0-breslow_likelihood:4.20998	validation_1-breslow_likelihood:3.14025
# [34]	validation_0-breslow_likelihood:4.20739	validation_1-breslow_likelihood:3.14024
# [9]	validation_0-breslow_likelihood:4.20981	validation_1-breslow_likelihood:3.14044
# [10]	validation_0-breslow_likelihood:4.20963	validation_1-breslow_likelihood:3.14034
# [35]	validation_0-breslow_likelihood:4.20728	validation_1-breslow_likelihood:3.14018
# [11]	validation_0-breslow_likelihood:4.20942	validation_1-breslow_likelihood:3.14004
# [12]	validation_0-breslow_likelihood:4.20921	validation_1-breslow_likelihood:3.13993
# [36]	validation_0-breslow_likelihood:4.20713	validation_1-breslow_likelihood:3.14012
# [13]	validation_0-breslow_likelihood:4.20914	validation_1-breslow_likelihood:3.13984
# [37]	validation_0-breslow_likelihood:4.20697	validation_1-breslow_likelihood:3.14003
# [14]	validation_0-breslow_likelihood:4.20902	validation_1-breslow_likelihood:3.13967
# [15]	validation_0-breslow_likelihood:4.20885	validation_1-breslow_likelihood:3.13942
# [16]	validation_0-breslow_likelihood:4.20871	validation_1-breslow_likelihood:3.13941
# [17]	validation_0-breslow_likelihood:4.20858	validation_1-breslow_likelihood:3.13920
# [18]	validation_0-breslow_likelihood:4.20842	validation_1-breslow_likelihood:3.13897
# [19]	validation_0-breslow_likelihood:4.20822	validation_1-breslow_likelihood:3.13895
# [20]	validation_0-breslow_likelihood:4.20801	validation_1-breslow_likelihood:3.13886
# [21]	validation_0-breslow_likelihood:4.20785	validation_1-breslow_likelihood:3.13881
# [22]	validation_0-breslow_likelihood:4.20756	validation_1-breslow_likelihood:3.13889
# [23]	validation_0-breslow_likelihood:4.20749	validation_1-breslow_likelihood:3.13881
# [24]	validation_0-breslow_likelihood:4.20729	validation_1-breslow_likelihood:3.13857
# [25]	validation_0-breslow_likelihood:4.20705	validation_1-breslow_likelihood:3.13853
# [26]	validation_0-breslow_likelihood:4.20691	validation_1-breslow_likelihood:3.13843
# [27]	validation_0-breslow_likelihood:4.20673	validation_1-breslow_likelihood:3.13855
# [28]	validation_0-breslow_likelihood:4.20658	validation_1-breslow_likelihood:3.13848
# [29]	validation_0-breslow_likelihood:4.20643	validation_1-breslow_likelihood:3.13831
# [30]	validation_0-breslow_likelihood:4.20617	validation_1-breslow_likelihood:3.13833
# [31]	validation_0-breslow_likelihood:4.20601	validation_1-breslow_likelihood:3.13811
# [32]	validation_0-breslow_likelihood:4.20577	validation_1-breslow_likelihood:3.13774
# [33]	validation_0-breslow_likelihood:4.20561	validation_1-breslow_likelihood:3.13745
# [34]	validation_0-breslow_likelihood:4.20551	validation_1-breslow_likelihood:3.13730
# [35]	validation_0-breslow_likelihood:4.20536	validation_1-breslow_likelihood:3.13714
# [36]	validation_0-breslow_likelihood:4.20521	validation_1-breslow_likelihood:3.13725
# [37]	validation_0-breslow_likelihood:4.20508	validation_1-breslow_likelihood:3.13719
# [0]	validation_0-breslow_likelihood:4.21174	validation_1-breslow_likelihood:3.14090
# [1]	validation_0-breslow_likelihood:4.21164	validation_1-breslow_likelihood:3.14090
# [2]	validation_0-breslow_likelihood:4.21156	validation_1-breslow_likelihood:3.14091
# [3]	validation_0-breslow_likelihood:4.21144	validation_1-breslow_likelihood:3.14092
# [4]	validation_0-breslow_likelihood:4.21129	validation_1-breslow_likelihood:3.14094
# [5]	validation_0-breslow_likelihood:4.21117	validation_1-breslow_likelihood:3.14091
# [6]	validation_0-breslow_likelihood:4.21103	validation_1-breslow_likelihood:3.14088
# [7]	validation_0-breslow_likelihood:4.21096	validation_1-breslow_likelihood:3.14091
# [8]	validation_0-breslow_likelihood:4.21081	validation_1-breslow_likelihood:3.14086
# [9]	validation_0-breslow_likelihood:4.21062	validation_1-breslow_likelihood:3.14089
# [10]	validation_0-breslow_likelihood:4.21053	validation_1-breslow_likelihood:3.14086
# [11]	validation_0-breslow_likelihood:4.21042	validation_1-breslow_likelihood:3.14084
# [12]	validation_0-breslow_likelihood:4.21028	validation_1-breslow_likelihood:3.14082
# [13]	validation_0-breslow_likelihood:4.21013	validation_1-breslow_likelihood:3.14087
# [14]	validation_0-breslow_likelihood:4.20994	validation_1-breslow_likelihood:3.14089
# [15]	validation_0-breslow_likelihood:4.20983	validation_1-breslow_likelihood:3.14081
# [16]	validation_0-breslow_likelihood:4.20976	validation_1-breslow_likelihood:3.14078
# [17]	validation_0-breslow_likelihood:4.20959	validation_1-breslow_likelihood:3.14070
# [18]	validation_0-breslow_likelihood:4.20944	validation_1-breslow_likelihood:3.14068
# [19]	validation_0-breslow_likelihood:4.20936	validation_1-breslow_likelihood:3.14066
# [20]	validation_0-breslow_likelihood:4.20923	validation_1-breslow_likelihood:3.14061
# [21]	validation_0-breslow_likelihood:4.20917	validation_1-breslow_likelihood:3.14064
# [22]	validation_0-breslow_likelihood:4.20903	validation_1-breslow_likelihood:3.14062
# [23]	validation_0-breslow_likelihood:4.20885	validation_1-breslow_likelihood:3.14061
# [24]	validation_0-breslow_likelihood:4.20880	validation_1-breslow_likelihood:3.14051
# [25]	validation_0-breslow_likelihood:4.20866	validation_1-breslow_likelihood:3.14056
# [26]	validation_0-breslow_likelihood:4.20852	validation_1-breslow_likelihood:3.14056
# [27]	validation_0-breslow_likelihood:4.20840	validation_1-breslow_likelihood:3.14064
# [28]	validation_0-breslow_likelihood:4.20822	validation_1-breslow_likelihood:3.14063
# [29]	validation_0-breslow_likelihood:4.20807	validation_1-breslow_likelihood:3.14061
# [30]	validation_0-breslow_likelihood:4.20800	validation_1-breslow_likelihood:3.14067
# [31]	validation_0-breslow_likelihood:4.20789	validation_1-breslow_likelihood:3.14056
# [32]	validation_0-breslow_likelihood:4.20779	validation_1-breslow_likelihood:3.14055
# [33]	validation_0-breslow_likelihood:4.20772	validation_1-breslow_likelihood:3.14054
# [34]	validation_0-breslow_likelihood:4.20757	validation_1-breslow_likelihood:3.14046
# [35]	validation_0-breslow_likelihood:4.20747	validation_1-breslow_likelihood:3.14043
# [36]	validation_0-breslow_likelihood:4.20728	validation_1-breslow_likelihood:3.14040
# [37]	validation_0-breslow_likelihood:4.20720	validation_1-breslow_likelihood:3.14045
# [0]	validation_0-breslow_likelihood:4.20194	validation_1-breslow_likelihood:3.12412
# [0]	validation_0-breslow_likelihood:4.19486	validation_1-breslow_likelihood:3.13357
# [1]	validation_0-breslow_likelihood:4.18328	validation_1-breslow_likelihood:3.10718
# [1]	validation_0-breslow_likelihood:4.18196	validation_1-breslow_likelihood:3.13456
# [2]	validation_0-breslow_likelihood:4.16631	validation_1-breslow_likelihood:3.09680
# [2]	validation_0-breslow_likelihood:4.16470	validation_1-breslow_likelihood:3.13647
# [3]	validation_0-breslow_likelihood:4.15551	validation_1-breslow_likelihood:3.09033
# [3]	validation_0-breslow_likelihood:4.14886	validation_1-breslow_likelihood:3.13841
# [4]	validation_0-breslow_likelihood:4.13949	validation_1-breslow_likelihood:3.08052
# [4]	validation_0-breslow_likelihood:4.13843	validation_1-breslow_likelihood:3.14440
# [5]	validation_0-breslow_likelihood:4.12795	validation_1-breslow_likelihood:3.07205
# [5]	validation_0-breslow_likelihood:4.12502	validation_1-breslow_likelihood:3.14553
# [6]	validation_0-breslow_likelihood:4.11082	validation_1-breslow_likelihood:3.06086
# [6]	validation_0-breslow_likelihood:4.11164	validation_1-breslow_likelihood:3.15002
# [7]	validation_0-breslow_likelihood:4.09414	validation_1-breslow_likelihood:3.06137
# [8]	validation_0-breslow_likelihood:4.08125	validation_1-breslow_likelihood:3.05305
# [7]	validation_0-breslow_likelihood:4.09249	validation_1-breslow_likelihood:3.15651
# [9]	validation_0-breslow_likelihood:4.07044	validation_1-breslow_likelihood:3.04518
# [8]	validation_0-breslow_likelihood:4.07745	validation_1-breslow_likelihood:3.16119
# [10]	validation_0-breslow_likelihood:4.05547	validation_1-breslow_likelihood:3.04074
# [11]	validation_0-breslow_likelihood:4.04585	validation_1-breslow_likelihood:3.03640
# [9]	validation_0-breslow_likelihood:4.06474	validation_1-breslow_likelihood:3.16965
# [12]	validation_0-breslow_likelihood:4.03277	validation_1-breslow_likelihood:3.03452
# [10]	validation_0-breslow_likelihood:4.05372	validation_1-breslow_likelihood:3.17272
# [13]	validation_0-breslow_likelihood:4.02093	validation_1-breslow_likelihood:3.03917
# [14]	validation_0-breslow_likelihood:4.01058	validation_1-breslow_likelihood:3.04263
# [15]	validation_0-breslow_likelihood:4.00029	validation_1-breslow_likelihood:3.03176
# [16]	validation_0-breslow_likelihood:3.98696	validation_1-breslow_likelihood:3.03351
# [17]	validation_0-breslow_likelihood:3.97884	validation_1-breslow_likelihood:3.02133
# [18]	validation_0-breslow_likelihood:3.97106	validation_1-breslow_likelihood:3.02112
# [19]	validation_0-breslow_likelihood:3.96282	validation_1-breslow_likelihood:3.02401
# [20]	validation_0-breslow_likelihood:3.95479	validation_1-breslow_likelihood:3.02475
# [21]	validation_0-breslow_likelihood:3.94766	validation_1-breslow_likelihood:3.02192
# [22]	validation_0-breslow_likelihood:3.93749	validation_1-breslow_likelihood:3.02063
# [23]	validation_0-breslow_likelihood:3.92860	validation_1-breslow_likelihood:3.01406
# [24]	validation_0-breslow_likelihood:3.91919	validation_1-breslow_likelihood:3.01374
# [25]	validation_0-breslow_likelihood:3.90436	validation_1-breslow_likelihood:3.01277
# [26]	validation_0-breslow_likelihood:3.89366	validation_1-breslow_likelihood:3.01997
# [27]	validation_0-breslow_likelihood:3.88400	validation_1-breslow_likelihood:3.02001
# [28]	validation_0-breslow_likelihood:3.87500	validation_1-breslow_likelihood:3.02621
# [29]	validation_0-breslow_likelihood:3.86735	validation_1-breslow_likelihood:3.02442
# [30]	validation_0-breslow_likelihood:3.85977	validation_1-breslow_likelihood:3.02589
# [31]	validation_0-breslow_likelihood:3.85229	validation_1-breslow_likelihood:3.03565
# [32]	validation_0-breslow_likelihood:3.84685	validation_1-breslow_likelihood:3.04392
# [33]	validation_0-breslow_likelihood:3.83913	validation_1-breslow_likelihood:3.04492
# [34]	validation_0-breslow_likelihood:3.83067	validation_1-breslow_likelihood:3.04621
# [0]	validation_0-breslow_likelihood:4.19314	validation_1-breslow_likelihood:3.14250
# [1]	validation_0-breslow_likelihood:4.17107	validation_1-breslow_likelihood:3.12514
# [2]	validation_0-breslow_likelihood:4.15567	validation_1-breslow_likelihood:3.12636
# [3]	validation_0-breslow_likelihood:4.13652	validation_1-breslow_likelihood:3.13593
# [4]	validation_0-breslow_likelihood:4.12482	validation_1-breslow_likelihood:3.13303
# [5]	validation_0-breslow_likelihood:4.10675	validation_1-breslow_likelihood:3.12994
# [6]	validation_0-breslow_likelihood:4.09220	validation_1-breslow_likelihood:3.13791
# [7]	validation_0-breslow_likelihood:4.07596	validation_1-breslow_likelihood:3.13143
# [8]	validation_0-breslow_likelihood:4.06278	validation_1-breslow_likelihood:3.12858
# [9]	validation_0-breslow_likelihood:4.05196	validation_1-breslow_likelihood:3.14328
# [10]	validation_0-breslow_likelihood:4.04032	validation_1-breslow_likelihood:3.15705
# [11]	validation_0-breslow_likelihood:4.02802	validation_1-breslow_likelihood:3.15959
# [0]	validation_0-breslow_likelihood:4.19946	validation_1-breslow_likelihood:3.13558
# [1]	validation_0-breslow_likelihood:4.17650	validation_1-breslow_likelihood:3.13588
# [2]	validation_0-breslow_likelihood:4.15800	validation_1-breslow_likelihood:3.13098
# [3]	validation_0-breslow_likelihood:4.14606	validation_1-breslow_likelihood:3.12515
# [4]	validation_0-breslow_likelihood:4.13077	validation_1-breslow_likelihood:3.13263
# [5]	validation_0-breslow_likelihood:4.11249	validation_1-breslow_likelihood:3.13758
# [6]	validation_0-breslow_likelihood:4.09553	validation_1-breslow_likelihood:3.13509
# [7]	validation_0-breslow_likelihood:4.08279	validation_1-breslow_likelihood:3.14177
# [8]	validation_0-breslow_likelihood:4.07195	validation_1-breslow_likelihood:3.14839
# [9]	validation_0-breslow_likelihood:4.05517	validation_1-breslow_likelihood:3.14869
# [10]	validation_0-breslow_likelihood:4.04197	validation_1-breslow_likelihood:3.12911
# [11]	validation_0-breslow_likelihood:4.02956	validation_1-breslow_likelihood:3.13674
# [12]	validation_0-breslow_likelihood:4.01836	validation_1-breslow_likelihood:3.13643
# [13]	validation_0-breslow_likelihood:4.00750	validation_1-breslow_likelihood:3.13816
# [0]	validation_0-breslow_likelihood:4.21299	validation_1-breslow_likelihood:3.14341
# [1]	validation_0-breslow_likelihood:4.21284	validation_1-breslow_likelihood:3.14336
# [2]	validation_0-breslow_likelihood:4.21264	validation_1-breslow_likelihood:3.14315
# [3]	validation_0-breslow_likelihood:4.21235	validation_1-breslow_likelihood:3.14318
# [4]	validation_0-breslow_likelihood:4.21216	validation_1-breslow_likelihood:3.14305
# [5]	validation_0-breslow_likelihood:4.21195	validation_1-breslow_likelihood:3.14296
# [6]	validation_0-breslow_likelihood:4.21188	validation_1-breslow_likelihood:3.14299
# [7]	validation_0-breslow_likelihood:4.21162	validation_1-breslow_likelihood:3.14310
# [8]	validation_0-breslow_likelihood:4.21128	validation_1-breslow_likelihood:3.14331
# [9]	validation_0-breslow_likelihood:4.21120	validation_1-breslow_likelihood:3.14330
# [10]	validation_0-breslow_likelihood:4.21108	validation_1-breslow_likelihood:3.14315
# [11]	validation_0-breslow_likelihood:4.21075	validation_1-breslow_likelihood:3.14322
# [12]	validation_0-breslow_likelihood:4.21049	validation_1-breslow_likelihood:3.14326
# [13]	validation_0-breslow_likelihood:4.21041	validation_1-breslow_likelihood:3.14328
# [0]	validation_0-breslow_likelihood:4.20028	validation_1-breslow_likelihood:3.14244
# [14]	validation_0-breslow_likelihood:4.21019	validation_1-breslow_likelihood:3.14342
# [15]	validation_0-breslow_likelihood:4.20983	validation_1-breslow_likelihood:3.14356
# [1]	validation_0-breslow_likelihood:4.18997	validation_1-breslow_likelihood:3.14761
# [2]	validation_0-breslow_likelihood:4.17687	validation_1-breslow_likelihood:3.15190
# [3]	validation_0-breslow_likelihood:4.16730	validation_1-breslow_likelihood:3.15197
# [4]	validation_0-breslow_likelihood:4.15483	validation_1-breslow_likelihood:3.14803
# [5]	validation_0-breslow_likelihood:4.13741	validation_1-breslow_likelihood:3.15945
# [6]	validation_0-breslow_likelihood:4.12165	validation_1-breslow_likelihood:3.15983
# [7]	validation_0-breslow_likelihood:4.11031	validation_1-breslow_likelihood:3.16186
# [8]	validation_0-breslow_likelihood:4.09922	validation_1-breslow_likelihood:3.16507
# [9]	validation_0-breslow_likelihood:4.08673	validation_1-breslow_likelihood:3.15926
# [10]	validation_0-breslow_likelihood:4.07686	validation_1-breslow_likelihood:3.15898
# [0]	validation_0-breslow_likelihood:4.54147	validation_1-breslow_likelihood:3.41226
# [1]	validation_0-breslow_likelihood:4.54124	validation_1-breslow_likelihood:3.41221
# [2]	validation_0-breslow_likelihood:4.54109	validation_1-breslow_likelihood:3.41212
# [3]	validation_0-breslow_likelihood:4.54079	validation_1-breslow_likelihood:3.41207
# [4]	validation_0-breslow_likelihood:4.54060	validation_1-breslow_likelihood:3.41203
# [5]	validation_0-breslow_likelihood:4.54040	validation_1-breslow_likelihood:3.41189
# [6]	validation_0-breslow_likelihood:4.54013	validation_1-breslow_likelihood:3.41189
# [7]	validation_0-breslow_likelihood:4.53987	validation_1-breslow_likelihood:3.41174
# [8]	validation_0-breslow_likelihood:4.53968	validation_1-breslow_likelihood:3.41166
# [9]	validation_0-breslow_likelihood:4.53954	validation_1-breslow_likelihood:3.41165
# [10]	validation_0-breslow_likelihood:4.53942	validation_1-breslow_likelihood:3.41146
# [11]	validation_0-breslow_likelihood:4.53934	validation_1-breslow_likelihood:3.41148
# [12]	validation_0-breslow_likelihood:4.53908	validation_1-breslow_likelihood:3.41128
# [13]	validation_0-breslow_likelihood:4.53884	validation_1-breslow_likelihood:3.41118
# [14]	validation_0-breslow_likelihood:4.53862	validation_1-breslow_likelihood:3.41101
# [15]	validation_0-breslow_likelihood:4.53841	validation_1-breslow_likelihood:3.41091
# [16]	validation_0-breslow_likelihood:4.53815	validation_1-breslow_likelihood:3.41071
# [17]	validation_0-breslow_likelihood:4.53790	validation_1-breslow_likelihood:3.41061
# [18]	validation_0-breslow_likelihood:4.53773	validation_1-breslow_likelihood:3.41055
# [19]	validation_0-breslow_likelihood:4.53746	validation_1-breslow_likelihood:3.41035
# [20]	validation_0-breslow_likelihood:4.53727	validation_1-breslow_likelihood:3.41019
# [21]	validation_0-breslow_likelihood:4.53700	validation_1-breslow_likelihood:3.41014
# [22]	validation_0-breslow_likelihood:4.53683	validation_1-breslow_likelihood:3.40996
# [23]	validation_0-breslow_likelihood:4.53659	validation_1-breslow_likelihood:3.40986
# [24]	validation_0-breslow_likelihood:4.53641	validation_1-breslow_likelihood:3.40979
# [25]	validation_0-breslow_likelihood:4.53619	validation_1-breslow_likelihood:3.40970
# [26]	validation_0-breslow_likelihood:4.53608	validation_1-breslow_likelihood:3.40964
# [27]	validation_0-breslow_likelihood:4.53577	validation_1-breslow_likelihood:3.40952
# [28]	validation_0-breslow_likelihood:4.53564	validation_1-breslow_likelihood:3.40950
# [29]	validation_0-breslow_likelihood:4.53542	validation_1-breslow_likelihood:3.40930
# [30]	validation_0-breslow_likelihood:4.53522	validation_1-breslow_likelihood:3.40929
# [31]	validation_0-breslow_likelihood:4.53498	validation_1-breslow_likelihood:3.40925
# [32]	validation_0-breslow_likelihood:4.53464	validation_1-breslow_likelihood:3.40923
# [33]	validation_0-breslow_likelihood:4.53446	validation_1-breslow_likelihood:3.40915
# [34]	validation_0-breslow_likelihood:4.53422	validation_1-breslow_likelihood:3.40909
# [35]	validation_0-breslow_likelihood:4.53414	validation_1-breslow_likelihood:3.40907
# [36]	validation_0-breslow_likelihood:4.53403	validation_1-breslow_likelihood:3.40911
# [37]	validation_0-breslow_likelihood:4.53382	validation_1-breslow_likelihood:3.40895
# Concordance Index 0.6671118530884808
# Integrated Brier Score: 0.21043970171653686
# durations 15.0 3817.0
# Concordance Index 0.582195521572911
# Integrated Brier Score: 0.22498524447503845
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:4.58269	validation_1-breslow_likelihood:3.29964
# [1]	validation_0-breslow_likelihood:4.99496	validation_1-breslow_likelihood:4.25462
# [2]	validation_0-breslow_likelihood:6.17632	validation_1-breslow_likelihood:6.47196
# [3]	validation_0-breslow_likelihood:5.45811	validation_1-breslow_likelihood:6.16659
# [4]	validation_0-breslow_likelihood:5.39418	validation_1-breslow_likelihood:6.29704
# [5]	validation_0-breslow_likelihood:7.47513	validation_1-breslow_likelihood:6.83250
# [6]	validation_0-breslow_likelihood:6.82798	validation_1-breslow_likelihood:8.29019
# [7]	validation_0-breslow_likelihood:6.57325	validation_1-breslow_likelihood:8.58531
# [8]	validation_0-breslow_likelihood:9.22968	validation_1-breslow_likelihood:8.79945
# [9]	validation_0-breslow_likelihood:9.41753	validation_1-breslow_likelihood:10.22831
# [10]	validation_0-breslow_likelihood:11.59942	validation_1-breslow_likelihood:11.50985
# [0]	validation_0-breslow_likelihood:4.25493	validation_1-breslow_likelihood:3.13987
# [1]	validation_0-breslow_likelihood:4.20171	validation_1-breslow_likelihood:3.21814
# [2]	validation_0-breslow_likelihood:4.19513	validation_1-breslow_likelihood:3.33723
# [3]	validation_0-breslow_likelihood:4.20829	validation_1-breslow_likelihood:3.32153
# [4]	validation_0-breslow_likelihood:4.16053	validation_1-breslow_likelihood:3.37022
# [5]	validation_0-breslow_likelihood:4.18784	validation_1-breslow_likelihood:3.40621
# [6]	validation_0-breslow_likelihood:4.21556	validation_1-breslow_likelihood:3.50353
# [7]	validation_0-breslow_likelihood:4.17963	validation_1-breslow_likelihood:3.56680
# [8]	validation_0-breslow_likelihood:4.24129	validation_1-breslow_likelihood:3.56468
# [9]	validation_0-breslow_likelihood:4.26637	validation_1-breslow_likelihood:3.56293
# [10]	validation_0-breslow_likelihood:4.21498	validation_1-breslow_likelihood:3.61531
# [0]	validation_0-breslow_likelihood:4.53104	validation_1-breslow_likelihood:3.52605
# [1]	validation_0-breslow_likelihood:4.58258	validation_1-breslow_likelihood:3.95986
# [2]	validation_0-breslow_likelihood:4.45551	validation_1-breslow_likelihood:4.19489
# [3]	validation_0-breslow_likelihood:4.63567	validation_1-breslow_likelihood:4.00596
# [4]	validation_0-breslow_likelihood:4.54690	validation_1-breslow_likelihood:4.22156
# [5]	validation_0-breslow_likelihood:4.91435	validation_1-breslow_likelihood:4.37051
# [6]	validation_0-breslow_likelihood:4.93327	validation_1-breslow_likelihood:4.74821
# [7]	validation_0-breslow_likelihood:4.57745	validation_1-breslow_likelihood:4.34358
# [8]	validation_0-breslow_likelihood:6.06882	validation_1-breslow_likelihood:5.01752
# [9]	validation_0-breslow_likelihood:7.04027	validation_1-breslow_likelihood:6.86186
# [10]	validation_0-breslow_likelihood:6.66836	validation_1-breslow_likelihood:6.97388
# [0]	validation_0-breslow_likelihood:4.25235	validation_1-breslow_likelihood:3.62783
# [1]	validation_0-breslow_likelihood:4.81514	validation_1-breslow_likelihood:3.77234
# [2]	validation_0-breslow_likelihood:4.77955	validation_1-breslow_likelihood:3.62494
# [3]	validation_0-breslow_likelihood:4.82283	validation_1-breslow_likelihood:3.57229
# [4]	validation_0-breslow_likelihood:4.75575	validation_1-breslow_likelihood:3.55254
# [5]	validation_0-breslow_likelihood:5.21972	validation_1-breslow_likelihood:4.55150
# [0]	validation_0-breslow_likelihood:4.79091	validation_1-breslow_likelihood:4.65370
# [6]	validation_0-breslow_likelihood:6.03919	validation_1-breslow_likelihood:7.68569
# [1]	validation_0-breslow_likelihood:4.91522	validation_1-breslow_likelihood:4.96064
# [7]	validation_0-breslow_likelihood:5.19142	validation_1-breslow_likelihood:4.92957
# [2]	validation_0-breslow_likelihood:5.02496	validation_1-breslow_likelihood:5.24238
# [8]	validation_0-breslow_likelihood:5.20637	validation_1-breslow_likelihood:4.67083
# ...
# [4]	validation_0-breslow_likelihood:5.00233	validation_1-breslow_likelihood:3.79050
# [5]	validation_0-breslow_likelihood:4.92119	validation_1-breslow_likelihood:3.79556
# [6]	validation_0-breslow_likelihood:4.85663	validation_1-breslow_likelihood:3.78580
# [7]	validation_0-breslow_likelihood:4.78439	validation_1-breslow_likelihood:3.78129
# [8]	validation_0-breslow_likelihood:4.71722	validation_1-breslow_likelihood:3.82344
# [9]	validation_0-breslow_likelihood:4.65731	validation_1-breslow_likelihood:3.80124
# [10]	validation_0-breslow_likelihood:4.59127	validation_1-breslow_likelihood:3.81607
# [11]	validation_0-breslow_likelihood:4.54406	validation_1-breslow_likelihood:3.82394
# [12]	validation_0-breslow_likelihood:4.47192	validation_1-breslow_likelihood:3.79718
# [13]	validation_0-breslow_likelihood:4.40376	validation_1-breslow_likelihood:3.79814
# [0]	validation_0-breslow_likelihood:5.30499	validation_1-breslow_likelihood:3.76511
# [1]	validation_0-breslow_likelihood:5.22469	validation_1-breslow_likelihood:3.73825
# [2]	validation_0-breslow_likelihood:5.16970	validation_1-breslow_likelihood:3.71705
# [3]	validation_0-breslow_likelihood:5.09172	validation_1-breslow_likelihood:3.71338
# [4]	validation_0-breslow_likelihood:5.04615	validation_1-breslow_likelihood:3.72156
# [5]	validation_0-breslow_likelihood:4.99361	validation_1-breslow_likelihood:3.69211
# [6]	validation_0-breslow_likelihood:4.93872	validation_1-breslow_likelihood:3.69229
# [7]	validation_0-breslow_likelihood:4.87748	validation_1-breslow_likelihood:3.70027
# [8]	validation_0-breslow_likelihood:4.81357	validation_1-breslow_likelihood:3.70519
# [9]	validation_0-breslow_likelihood:4.76375	validation_1-breslow_likelihood:3.72178
# [10]	validation_0-breslow_likelihood:4.71957	validation_1-breslow_likelihood:3.69983
# [11]	validation_0-breslow_likelihood:4.67775	validation_1-breslow_likelihood:3.72634
# [12]	validation_0-breslow_likelihood:4.62233	validation_1-breslow_likelihood:3.70822
# [13]	validation_0-breslow_likelihood:4.57905	validation_1-breslow_likelihood:3.71345
# [14]	validation_0-breslow_likelihood:4.52766	validation_1-breslow_likelihood:3.71040
# [15]	validation_0-breslow_likelihood:4.47528	validation_1-breslow_likelihood:3.67525
# [16]	validation_0-breslow_likelihood:4.42307	validation_1-breslow_likelihood:3.69149
# [17]	validation_0-breslow_likelihood:4.35980	validation_1-breslow_likelihood:3.71235
# [18]	validation_0-breslow_likelihood:4.32580	validation_1-breslow_likelihood:3.70982
# [19]	validation_0-breslow_likelihood:4.29163	validation_1-breslow_likelihood:3.70811
# [0]	validation_0-breslow_likelihood:5.26206	validation_1-breslow_likelihood:3.78026
# [20]	validation_0-breslow_likelihood:4.24670	validation_1-breslow_likelihood:3.70633
# [1]	validation_0-breslow_likelihood:5.18846	validation_1-breslow_likelihood:3.77178
# [0]	validation_0-breslow_likelihood:5.26963	validation_1-breslow_likelihood:3.76647
# [2]	validation_0-breslow_likelihood:5.10981	validation_1-breslow_likelihood:3.78329
# [1]	validation_0-breslow_likelihood:5.19917	validation_1-breslow_likelihood:3.78187
# [21]	validation_0-breslow_likelihood:4.19802	validation_1-breslow_likelihood:3.69472[2]	validation_0-breslow_likelihood:5.11621	validation_1-breslow_likelihood:3.79369
#
# [3]	validation_0-breslow_likelihood:5.02359	validation_1-breslow_likelihood:3.79425
# [3]	validation_0-breslow_likelihood:5.06657	validation_1-breslow_likelihood:3.78906
# [4]	validation_0-breslow_likelihood:4.95061	validation_1-breslow_likelihood:3.77978
# [4]	validation_0-breslow_likelihood:4.98475	validation_1-breslow_likelihood:3.81219
# [5]	validation_0-breslow_likelihood:4.87737	validation_1-breslow_likelihood:3.76660
# [5]	validation_0-breslow_likelihood:4.91949	validation_1-breslow_likelihood:3.79997
# [6]	validation_0-breslow_likelihood:4.87428	validation_1-breslow_likelihood:3.77840
# [6]	validation_0-breslow_likelihood:4.80779	validation_1-breslow_likelihood:3.76616
# [7]	validation_0-breslow_likelihood:4.80852	validation_1-breslow_likelihood:3.75673
# [7]	validation_0-breslow_likelihood:4.75139	validation_1-breslow_likelihood:3.76255
# [8]	validation_0-breslow_likelihood:4.74087	validation_1-breslow_likelihood:3.72407
# [8]	validation_0-breslow_likelihood:4.71680	validation_1-breslow_likelihood:3.74671
# [22]	validation_0-breslow_likelihood:4.17086	validation_1-breslow_likelihood:3.68509
# [9]	validation_0-breslow_likelihood:4.68079	validation_1-breslow_likelihood:3.73707
# [9]	validation_0-breslow_likelihood:4.65447	validation_1-breslow_likelihood:3.77765
# [23]	validation_0-breslow_likelihood:4.12992	validation_1-breslow_likelihood:3.69234
# [10]	validation_0-breslow_likelihood:4.62810	validation_1-breslow_likelihood:3.73311
# [10]	validation_0-breslow_likelihood:4.59650	validation_1-breslow_likelihood:3.76939
# [24]	validation_0-breslow_likelihood:4.08895	validation_1-breslow_likelihood:3.66854
# [11]	validation_0-breslow_likelihood:4.56635	validation_1-breslow_likelihood:3.73647
# [11]	validation_0-breslow_likelihood:4.53507	validation_1-breslow_likelihood:3.76448
# [12]	validation_0-breslow_likelihood:4.51862	validation_1-breslow_likelihood:3.74239
# [25]	validation_0-breslow_likelihood:4.04169	validation_1-breslow_likelihood:3.65092
# [12]	validation_0-breslow_likelihood:4.48541	validation_1-breslow_likelihood:3.75875
# [13]	validation_0-breslow_likelihood:4.46202	validation_1-breslow_likelihood:3.74488
# [26]	validation_0-breslow_likelihood:4.00429	validation_1-breslow_likelihood:3.65745[13]	validation_0-breslow_likelihood:4.42567	validation_1-breslow_likelihood:3.75546
#
# [14]	validation_0-breslow_likelihood:4.39837	validation_1-breslow_likelihood:3.77768
# [14]	validation_0-breslow_likelihood:4.36721	validation_1-breslow_likelihood:3.74358
# [27]	validation_0-breslow_likelihood:3.97416	validation_1-breslow_likelihood:3.64277
# [15]	validation_0-breslow_likelihood:4.35740	validation_1-breslow_likelihood:3.77658
# [15]	validation_0-breslow_likelihood:4.33891	validation_1-breslow_likelihood:3.74410
# [28]	validation_0-breslow_likelihood:3.94302	validation_1-breslow_likelihood:3.67631
# [16]	validation_0-breslow_likelihood:4.30377	validation_1-breslow_likelihood:3.79576
# [16]	validation_0-breslow_likelihood:4.30184	validation_1-breslow_likelihood:3.74189
# [29]	validation_0-breslow_likelihood:3.91979	validation_1-breslow_likelihood:3.67067
# [17]	validation_0-breslow_likelihood:4.27686	validation_1-breslow_likelihood:3.77946
# [17]	validation_0-breslow_likelihood:4.26262	validation_1-breslow_likelihood:3.72775
# [30]	validation_0-breslow_likelihood:3.88199	validation_1-breslow_likelihood:3.68395
# [18]	validation_0-breslow_likelihood:4.23854	validation_1-breslow_likelihood:3.75003
# [31]	validation_0-breslow_likelihood:3.83908	validation_1-breslow_likelihood:3.70961
# [19]	validation_0-breslow_likelihood:4.19471	validation_1-breslow_likelihood:3.74392
# [32]	validation_0-breslow_likelihood:3.80746	validation_1-breslow_likelihood:3.71855
# [20]	validation_0-breslow_likelihood:4.15481	validation_1-breslow_likelihood:3.75056
# [33]	validation_0-breslow_likelihood:3.76759	validation_1-breslow_likelihood:3.72825
# [21]	validation_0-breslow_likelihood:4.12135	validation_1-breslow_likelihood:3.74491
# [34]	validation_0-breslow_likelihood:3.72809	validation_1-breslow_likelihood:3.72558
# [22]	validation_0-breslow_likelihood:4.08161	validation_1-breslow_likelihood:3.76589
# [35]	validation_0-breslow_likelihood:3.70509	validation_1-breslow_likelihood:3.74547
# [23]	validation_0-breslow_likelihood:4.04887	validation_1-breslow_likelihood:3.78377
# [36]	validation_0-breslow_likelihood:3.67160	validation_1-breslow_likelihood:3.76241
# [24]	validation_0-breslow_likelihood:4.01216	validation_1-breslow_likelihood:3.80597
# [25]	validation_0-breslow_likelihood:3.99983	validation_1-breslow_likelihood:3.81519
# [26]	validation_0-breslow_likelihood:3.96812	validation_1-breslow_likelihood:3.81909
# [0]	validation_0-breslow_likelihood:5.25157	validation_1-breslow_likelihood:3.78726
# [1]	validation_0-breslow_likelihood:5.17079	validation_1-breslow_likelihood:3.80750
# [2]	validation_0-breslow_likelihood:5.08355	validation_1-breslow_likelihood:3.84229
# [3]	validation_0-breslow_likelihood:5.01870	validation_1-breslow_likelihood:3.83597
# [4]	validation_0-breslow_likelihood:4.95825	validation_1-breslow_likelihood:3.81882
# [5]	validation_0-breslow_likelihood:4.89684	validation_1-breslow_likelihood:3.79873
# [6]	validation_0-breslow_likelihood:4.84817	validation_1-breslow_likelihood:3.80549
# [7]	validation_0-breslow_likelihood:4.77898	validation_1-breslow_likelihood:3.78750
# [8]	validation_0-breslow_likelihood:4.74587	validation_1-breslow_likelihood:3.78000
# [9]	validation_0-breslow_likelihood:4.70348	validation_1-breslow_likelihood:3.77196
# [10]	validation_0-breslow_likelihood:4.66066	validation_1-breslow_likelihood:3.73543
# [11]	validation_0-breslow_likelihood:4.62830	validation_1-breslow_likelihood:3.71362
# [12]	validation_0-breslow_likelihood:4.57593	validation_1-breslow_likelihood:3.71567
# [13]	validation_0-breslow_likelihood:4.51761	validation_1-breslow_likelihood:3.70751
# [14]	validation_0-breslow_likelihood:4.47333	validation_1-breslow_likelihood:3.70975
# [15]	validation_0-breslow_likelihood:4.43172	validation_1-breslow_likelihood:3.70250
# [16]	validation_0-breslow_likelihood:4.38271	validation_1-breslow_likelihood:3.70872
# [17]	validation_0-breslow_likelihood:4.35307	validation_1-breslow_likelihood:3.74159
# [18]	validation_0-breslow_likelihood:4.33124	validation_1-breslow_likelihood:3.75143
# [19]	validation_0-breslow_likelihood:4.29417	validation_1-breslow_likelihood:3.75932
# [20]	validation_0-breslow_likelihood:4.26936	validation_1-breslow_likelihood:3.75389
# [21]	validation_0-breslow_likelihood:4.22872	validation_1-breslow_likelihood:3.76741
# [22]	validation_0-breslow_likelihood:4.21357	validation_1-breslow_likelihood:3.76886
# [23]	validation_0-breslow_likelihood:4.15888	validation_1-breslow_likelihood:3.77036
# [24]	validation_0-breslow_likelihood:4.12763	validation_1-breslow_likelihood:3.76425
# [25]	validation_0-breslow_likelihood:4.10320	validation_1-breslow_likelihood:3.75871
# [0]	validation_0-breslow_likelihood:5.64323	validation_1-breslow_likelihood:4.30523
# [1]	validation_0-breslow_likelihood:5.71271	validation_1-breslow_likelihood:5.18611
# [2]	validation_0-breslow_likelihood:5.73176	validation_1-breslow_likelihood:5.37544
# [3]	validation_0-breslow_likelihood:5.79876	validation_1-breslow_likelihood:6.58788
# [4]	validation_0-breslow_likelihood:6.15746	validation_1-breslow_likelihood:6.73311
# [5]	validation_0-breslow_likelihood:6.25046	validation_1-breslow_likelihood:6.87343
# [6]	validation_0-breslow_likelihood:6.09699	validation_1-breslow_likelihood:7.05411
# [0]	validation_0-breslow_likelihood:5.33837	validation_1-breslow_likelihood:3.88537
# [7]	validation_0-breslow_likelihood:5.93364	validation_1-breslow_likelihood:7.96284
# [1]	validation_0-breslow_likelihood:5.46657	validation_1-breslow_likelihood:3.95878
# [8]	validation_0-breslow_likelihood:6.14987	validation_1-breslow_likelihood:8.76411
# [2]	validation_0-breslow_likelihood:5.61733	validation_1-breslow_likelihood:4.24920
# [9]	validation_0-breslow_likelihood:7.08522	validation_1-breslow_likelihood:11.36295
# [3]	validation_0-breslow_likelihood:5.66759	validation_1-breslow_likelihood:4.37886
# [4]	validation_0-breslow_likelihood:6.22537	validation_1-breslow_likelihood:5.61667
# [5]	validation_0-breslow_likelihood:6.59318	validation_1-breslow_likelihood:5.40359
# [6]	validation_0-breslow_likelihood:6.63893	validation_1-breslow_likelihood:5.74418
# [7]	validation_0-breslow_likelihood:6.16004	validation_1-breslow_likelihood:6.77095
# [8]	validation_0-breslow_likelihood:6.47799	validation_1-breslow_likelihood:8.19760
# [9]	validation_0-breslow_likelihood:7.04113	validation_1-breslow_likelihood:7.78519
# [0]	validation_0-breslow_likelihood:5.58394	validation_1-breslow_likelihood:4.79551
# [1]	validation_0-breslow_likelihood:5.71315	validation_1-breslow_likelihood:4.72744
# [2]	validation_0-breslow_likelihood:6.00052	validation_1-breslow_likelihood:4.83263
# [3]	validation_0-breslow_likelihood:5.98611	validation_1-breslow_likelihood:4.83198
# [4]	validation_0-breslow_likelihood:6.05431	validation_1-breslow_likelihood:5.24809
# [5]	validation_0-breslow_likelihood:5.89279	validation_1-breslow_likelihood:5.19942
# [6]	validation_0-breslow_likelihood:6.41789	validation_1-breslow_likelihood:5.77356
# [7]	validation_0-breslow_likelihood:5.99662	validation_1-breslow_likelihood:5.34572
# [8]	validation_0-breslow_likelihood:6.28799	validation_1-breslow_likelihood:5.64686
# [9]	validation_0-breslow_likelihood:7.33549	validation_1-breslow_likelihood:6.80718
# [10]	validation_0-breslow_likelihood:6.73038	validation_1-breslow_likelihood:6.99263
# [11]	validation_0-breslow_likelihood:6.81272	validation_1-breslow_likelihood:7.03203
# [0]	validation_0-breslow_likelihood:5.44508	validation_1-breslow_likelihood:3.72728
# [1]	validation_0-breslow_likelihood:5.43815	validation_1-breslow_likelihood:3.73125
# [2]	validation_0-breslow_likelihood:5.35721	validation_1-breslow_likelihood:3.67405
# [3]	validation_0-breslow_likelihood:5.48488	validation_1-breslow_likelihood:3.91623
# [4]	validation_0-breslow_likelihood:5.47208	validation_1-breslow_likelihood:4.32356
# [5]	validation_0-breslow_likelihood:5.63027	validation_1-breslow_likelihood:4.65319
# [6]	validation_0-breslow_likelihood:6.12180	validation_1-breslow_likelihood:6.48033
# [7]	validation_0-breslow_likelihood:5.78688	validation_1-breslow_likelihood:7.23034
# [8]	validation_0-breslow_likelihood:5.80337	validation_1-breslow_likelihood:7.55587
# [9]	validation_0-breslow_likelihood:5.87881	validation_1-breslow_likelihood:8.84730
# [10]	validation_0-breslow_likelihood:6.45397	validation_1-breslow_likelihood:9.06762
# [11]	validation_0-breslow_likelihood:6.44627	validation_1-breslow_likelihood:9.45758
# [0]	validation_0-breslow_likelihood:5.30114	validation_1-breslow_likelihood:3.83614
# [1]	validation_0-breslow_likelihood:5.26169	validation_1-breslow_likelihood:4.03060
# [2]	validation_0-breslow_likelihood:5.30846	validation_1-breslow_likelihood:4.15826
# [3]	validation_0-breslow_likelihood:5.57460	validation_1-breslow_likelihood:5.08230
# [4]	validation_0-breslow_likelihood:5.40417	validation_1-breslow_likelihood:4.98663
# [5]	validation_0-breslow_likelihood:5.54228	validation_1-breslow_likelihood:5.14169
# [6]	validation_0-breslow_likelihood:6.13494	validation_1-breslow_likelihood:6.41263
# [7]	validation_0-breslow_likelihood:6.07779	validation_1-breslow_likelihood:6.12953
# [8]	validation_0-breslow_likelihood:6.73261	validation_1-breslow_likelihood:7.08931
# [9]	validation_0-breslow_likelihood:7.50527	validation_1-breslow_likelihood:5.95210
# [10]	validation_0-breslow_likelihood:6.92862	validation_1-breslow_likelihood:6.41854
# [0]	validation_0-breslow_likelihood:5.49502	validation_1-breslow_likelihood:4.25434
# [1]	validation_0-breslow_likelihood:5.43720	validation_1-breslow_likelihood:4.26028
# [2]	validation_0-breslow_likelihood:5.39078	validation_1-breslow_likelihood:4.25142
# [3]	validation_0-breslow_likelihood:5.33637	validation_1-breslow_likelihood:4.26297
# [4]	validation_0-breslow_likelihood:5.25983	validation_1-breslow_likelihood:4.27321
# [5]	validation_0-breslow_likelihood:5.17231	validation_1-breslow_likelihood:4.29537
# [6]	validation_0-breslow_likelihood:5.09851	validation_1-breslow_likelihood:4.32377
# [7]	validation_0-breslow_likelihood:5.03411	validation_1-breslow_likelihood:4.34205
# [8]	validation_0-breslow_likelihood:4.98148	validation_1-breslow_likelihood:4.35350
# [9]	validation_0-breslow_likelihood:4.92199	validation_1-breslow_likelihood:4.34180
# [10]	validation_0-breslow_likelihood:4.87850	validation_1-breslow_likelihood:4.35372
# [11]	validation_0-breslow_likelihood:4.82602	validation_1-breslow_likelihood:4.35606
# Concordance Index 0.6882567297519689
# Integrated Brier Score: 0.1873903801518616
# durations 5.0 8605.0
# Concordance Index 0.4496527777777778
# Integrated Brier Score: 0.20856637653320173
# (865, 20531) <class 'pandas.core.frame.DataFrame'>
# (865,) <class 'pandas.core.series.Series'>
# (216, 20531) <class 'pandas.core.frame.DataFrame'>
# (216,) <class 'pandas.core.series.Series'>

# %%
df_final_breslow_1_cindex = pd.concat([df for df in agg_metrics_cindex]).round(4)
df_final_breslow_1_cindex.to_csv('metrics/final_gbdt_tcga_breslow_1_cindex.csv', index=False)
df_final_breslow_1_cindex.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_tcga_breslow_1_cindex.csv', index=False)  #
df_final_breslow_1_cindex
# Out:
# Accuracy: 95.6140350877193%
# /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")

# %%
df_final_breslow_1_ibs = pd.concat([df for df in agg_metrics_ibs]).round(4)
df_final_breslow_1_ibs.to_csv('metrics/final_gbdt_tcga_breslow_1_ibs.csv', index=False)
df_final_breslow_1_ibs.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_tcga_breslow_1_ibs.csv', index=False) 
df_final_breslow_1_ibs
