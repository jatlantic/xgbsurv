# %%
## XGBSurv Breslow Benchmark

# %%
from xgbsurv.datasets import (load_metabric, load_flchain, load_rgbsg, load_support, load_tcga)
from xgbsurv import XGBSurv
from xgbsurv.evaluation import cindex_censored, ibs
from xgbsurv.models.utils import sort_X_y
import os
import numpy as np
import pandas as pd
from scipy.stats import uniform as scuniform
from scipy.stats import randint as scrandint
from scipy.stats import loguniform as scloguniform 
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, LabelBinarizer, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.decomposition import PCA
# import models
from xgbsurv.models.breslow_final import breslow_likelihood,get_cumulative_hazard_function_breslow
from xgbsurv.models.efron_final import efron_likelihood
from xgbsurv.models.cind_final import cind_loss
from xgbsurv.models.deephit_pycox_final import deephit_loss1_pycox
from xgbsurv.models.eh_aft_final import aft_likelihood
from xgbsurv.models.eh_ah_final import ah_likelihood
from pycox.evaluation import EvalSurv
from xgbsurv.models.utils import sort_X_y_pandas, transform_back, transform
from xgbsurv.preprocessing.dataset_preprocessing import discretizer_df

# %% [markdown]
# ## Set Parameters

# %%
# set parameters
n_outer_splits = 5
n_inner_splits = 5
rand_state = 42
n_iter = 100
n_iter_cind = 200
early_stopping_rounds=10
base_score = 0.0

# Define parameter grid for random forest classifier
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
}

# %% [markdown]
# ## Custom Splitting

# %%
class CustomSplit(StratifiedKFold):
    def __init__(self, n_splits=5, shuffle=True, random_state=None):
        super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)

    def split(self, X, y, groups=None):
        try:
            if y.shape[1]>1:
                y = y[:,0]
        except:
            pass
        bins = np.sign(y)
        return super().split(X, bins, groups=groups)

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

outer_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)
inner_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)

# %%
## Scoring Function

# %%
scoring_function = make_scorer(breslow_likelihood, greater_is_better=False)

# %%
## Set Model & Train Test Evaluate

# %%
data_set_fns = [load_metabric,  load_flchain, load_rgbsg, load_support] #, load_flchain, load_rgbsg, load_support, load_tcga]
data_set_fns_str = ['load_metabric', 'load_flchain', 'load_rgbsg', 'load_support'] 
one_hot_dict = {'load_flchain': ['mgus'], 'load_support':['cancer'], 'load_rgbsg':['grade']}

for idx, dataset in enumerate(data_set_fns):
    model = 'xgbsurv_breslow_'
    # get name of current dataset
    data = dataset(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=True)
    filename = data.filename
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()

    print(data_set_fns_str[idx])
    if data_set_fns_str[idx] in one_hot_dict.keys():
        X = pd.get_dummies(X, columns=one_hot_dict[data_set_fns_str[idx]])
    X, y = sort_X_y_pandas(X, y)
    #print(X.dtypes)
    dataset_name = filename.split('_')[0]
    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            #(OneHotEncoder(sparse_output=False), make_column_selector(dtype_include=['category', 'object']))
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='breslow_objective',
        eval_metric='breslow_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    pipe = Pipeline([('scaler',ct),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=2, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        print(X_train.shape, type(X_train))
        print(y_train.shape, type(y_train))
        print(X_test.shape, type(X_test))
        print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_breslow(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_breslow(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# Out:
# load_metabric
# (1522, 9) <class 'pandas.core.frame.DataFrame'>
# (1522,) <class 'pandas.core.series.Series'>
# (381, 9) <class 'pandas.core.frame.DataFrame'>
# (381,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:5.85728	validation_1-breslow_likelihood:4.56179
# [1]	validation_0-breslow_likelihood:5.85718	validation_1-breslow_likelihood:4.56138
# [2]	validation_0-breslow_likelihood:5.85596	validation_1-breslow_likelihood:4.56193
# [3]	validation_0-breslow_likelihood:5.85532	validation_1-breslow_likelihood:4.56223
# [4]	validation_0-breslow_likelihood:5.85522	validation_1-breslow_likelihood:4.56217
# [5]	validation_0-breslow_likelihood:5.85443	validation_1-breslow_likelihood:4.56195
# [6]	validation_0-breslow_likelihood:5.85403	validation_1-breslow_likelihood:4.56182
# [7]	validation_0-breslow_likelihood:5.85351	validation_1-breslow_likelihood:4.56198
# [8]	validation_0-breslow_likelihood:5.85351	validation_1-breslow_likelihood:4.56199
# [9]	validation_0-breslow_likelihood:5.85351	validation_1-breslow_likelihood:4.56199
# [10]	validation_0-breslow_likelihood:5.85040	validation_1-breslow_likelihood:4.55896
# [11]	validation_0-breslow_likelihood:5.84804	validation_1-breslow_likelihood:4.55752
# [12]	validation_0-breslow_likelihood:5.84799	validation_1-breslow_likelihood:4.55764
# [13]	validation_0-breslow_likelihood:5.84781	validation_1-breslow_likelihood:4.55729
# [14]	validation_0-breslow_likelihood:5.84693	validation_1-breslow_likelihood:4.55774
# [15]	validation_0-breslow_likelihood:5.84609	validation_1-breslow_likelihood:4.55771
# [16]	validation_0-breslow_likelihood:5.84520	validation_1-breslow_likelihood:4.55757
# [17]	validation_0-breslow_likelihood:5.84469	validation_1-breslow_likelihood:4.55793
# [18]	validation_0-breslow_likelihood:5.84110	validation_1-breslow_likelihood:4.55438
# [19]	validation_0-breslow_likelihood:5.84106	validation_1-breslow_likelihood:4.55432
# [20]	validation_0-breslow_likelihood:5.84067	validation_1-breslow_likelihood:4.55477
# [21]	validation_0-breslow_likelihood:5.84049	validation_1-breslow_likelihood:4.55482
# [22]	validation_0-breslow_likelihood:5.83941	validation_1-breslow_likelihood:4.55433
# [0]	validation_0-breslow_likelihood:5.88861	validation_1-breslow_likelihood:4.50581
# [1]	validation_0-breslow_likelihood:5.88817	validation_1-breslow_likelihood:4.50539
# [2]	validation_0-breslow_likelihood:5.88748	validation_1-breslow_likelihood:4.50486
# [3]	validation_0-breslow_likelihood:5.88567	validation_1-breslow_likelihood:4.50340
# [4]	validation_0-breslow_likelihood:5.88518	validation_1-breslow_likelihood:4.50289
# [0]	validation_0-breslow_likelihood:5.88843	validation_1-breslow_likelihood:4.50564
# [5]	validation_0-breslow_likelihood:5.88396	validation_1-breslow_likelihood:4.50242
# [1]	validation_0-breslow_likelihood:5.88751	validation_1-breslow_likelihood:4.50478
# [6]	validation_0-breslow_likelihood:5.88324	validation_1-breslow_likelihood:4.50180
# [2]	validation_0-breslow_likelihood:5.88677	validation_1-breslow_likelihood:4.50455
# [7]	validation_0-breslow_likelihood:5.88174	validation_1-breslow_likelihood:4.49965
# [3]	validation_0-breslow_likelihood:5.88445	validation_1-breslow_likelihood:4.50413
# [8]	validation_0-breslow_likelihood:5.88153	validation_1-breslow_likelihood:4.49941
# [9]	validation_0-breslow_likelihood:5.88132	validation_1-breslow_likelihood:4.49927
# [4]	validation_0-breslow_likelihood:5.88285	validation_1-breslow_likelihood:4.50303
# [10]	validation_0-breslow_likelihood:5.87803	validation_1-breslow_likelihood:4.49550
# [5]	validation_0-breslow_likelihood:5.88092	validation_1-breslow_likelihood:4.50261
# [11]	validation_0-breslow_likelihood:5.87545	validation_1-breslow_likelihood:4.49329
# [6]	validation_0-breslow_likelihood:5.87972	validation_1-breslow_likelihood:4.50185
# [12]	validation_0-breslow_likelihood:5.87501	validation_1-breslow_likelihood:4.49295
# [7]	validation_0-breslow_likelihood:5.87861	validation_1-breslow_likelihood:4.50115
# [13]	validation_0-breslow_likelihood:5.87469	validation_1-breslow_likelihood:4.49300
# [14]	validation_0-breslow_likelihood:5.87317	validation_1-breslow_likelihood:4.49132
# [8]	validation_0-breslow_likelihood:5.87338	validation_1-breslow_likelihood:4.49936
# [15]	validation_0-breslow_likelihood:5.87176	validation_1-breslow_likelihood:4.49068
# [9]	validation_0-breslow_likelihood:5.87266	validation_1-breslow_likelihood:4.49904
# [16]	validation_0-breslow_likelihood:5.87073	validation_1-breslow_likelihood:4.49026
# [10]	validation_0-breslow_likelihood:5.87221	validation_1-breslow_likelihood:4.49885
# [17]	validation_0-breslow_likelihood:5.86993	validation_1-breslow_likelihood:4.48961
# [11]	validation_0-breslow_likelihood:5.87043	validation_1-breslow_likelihood:4.49764
# [18]	validation_0-breslow_likelihood:5.86784	validation_1-breslow_likelihood:4.48805
# [19]	validation_0-breslow_likelihood:5.86770	validation_1-breslow_likelihood:4.48838
# [20]	validation_0-breslow_likelihood:5.86730	validation_1-breslow_likelihood:4.48846
# [12]	validation_0-breslow_likelihood:5.87016	validation_1-breslow_likelihood:4.49739
# [21]	validation_0-breslow_likelihood:5.86730	validation_1-breslow_likelihood:4.48847
# [13]	validation_0-breslow_likelihood:5.86702	validation_1-breslow_likelihood:4.49583
# [22]	validation_0-breslow_likelihood:5.86681	validation_1-breslow_likelihood:4.48770
# [14]	validation_0-breslow_likelihood:5.86455	validation_1-breslow_likelihood:4.49671
# [15]	validation_0-breslow_likelihood:5.86316	validation_1-breslow_likelihood:4.49629
# [16]	validation_0-breslow_likelihood:5.86160	validation_1-breslow_likelihood:4.49562
# [17]	validation_0-breslow_likelihood:5.86079	validation_1-breslow_likelihood:4.49495
# [18]	validation_0-breslow_likelihood:5.86044	validation_1-breslow_likelihood:4.49485
# [19]	validation_0-breslow_likelihood:5.85669	validation_1-breslow_likelihood:4.49423
# [20]	validation_0-breslow_likelihood:5.85320	validation_1-breslow_likelihood:4.49360
# [21]	validation_0-breslow_likelihood:5.85314	validation_1-breslow_likelihood:4.49354
# [0]	validation_0-breslow_likelihood:5.88280	validation_1-breslow_likelihood:4.43782
# [22]	validation_0-breslow_likelihood:5.84589	validation_1-breslow_likelihood:4.49139
# [23]	validation_0-breslow_likelihood:5.84410	validation_1-breslow_likelihood:4.49081
# [0]	validation_0-breslow_likelihood:5.86931	validation_1-breslow_likelihood:4.47356
# [1]	validation_0-breslow_likelihood:5.86781	validation_1-breslow_likelihood:4.47374
# [24]	validation_0-breslow_likelihood:5.84403	validation_1-breslow_likelihood:4.49092
# [2]	validation_0-breslow_likelihood:5.86672	validation_1-breslow_likelihood:4.47394
# [25]	validation_0-breslow_likelihood:5.84093	validation_1-breslow_likelihood:4.48935
# [3]	validation_0-breslow_likelihood:5.86644	validation_1-breslow_likelihood:4.47350
# [4]	validation_0-breslow_likelihood:5.86552	validation_1-breslow_likelihood:4.47412
# [26]	validation_0-breslow_likelihood:5.84058	validation_1-breslow_likelihood:4.48932
# [5]	validation_0-breslow_likelihood:5.86508	validation_1-breslow_likelihood:4.47358
# [1]	validation_0-breslow_likelihood:5.88218	validation_1-breslow_likelihood:4.43727
# [6]	validation_0-breslow_likelihood:5.86478	validation_1-breslow_likelihood:4.47335
# [27]	validation_0-breslow_likelihood:5.83886	validation_1-breslow_likelihood:4.48904
# [7]	validation_0-breslow_likelihood:5.86405	validation_1-breslow_likelihood:4.47256
# [8]	validation_0-breslow_likelihood:5.86146	validation_1-breslow_likelihood:4.46943
# [28]	validation_0-breslow_likelihood:5.83843	validation_1-breslow_likelihood:4.48857
# [2]	validation_0-breslow_likelihood:5.88150	validation_1-breslow_likelihood:4.43723
# [9]	validation_0-breslow_likelihood:5.86049	validation_1-breslow_likelihood:4.46878
# [29]	validation_0-breslow_likelihood:5.83773	validation_1-breslow_likelihood:4.48813
# [10]	validation_0-breslow_likelihood:5.85996	validation_1-breslow_likelihood:4.46882
# [30]	validation_0-breslow_likelihood:5.83766	validation_1-breslow_likelihood:4.48825
# [11]	validation_0-breslow_likelihood:5.85894	validation_1-breslow_likelihood:4.46866
# [31]	validation_0-breslow_likelihood:5.83722	validation_1-breslow_likelihood:4.48827
# [12]	validation_0-breslow_likelihood:5.85638	validation_1-breslow_likelihood:4.46615
# [3]	validation_0-breslow_likelihood:5.87981	validation_1-breslow_likelihood:4.43616
# [32]	validation_0-breslow_likelihood:5.83395	validation_1-breslow_likelihood:4.48814
# [13]	validation_0-breslow_likelihood:5.85549	validation_1-breslow_likelihood:4.46613
# [14]	validation_0-breslow_likelihood:5.85462	validation_1-breslow_likelihood:4.46628
# [33]	validation_0-breslow_likelihood:5.83194	validation_1-breslow_likelihood:4.48806
# [15]	validation_0-breslow_likelihood:5.85446	validation_1-breslow_likelihood:4.46601
# [34]	validation_0-breslow_likelihood:5.83173	validation_1-breslow_likelihood:4.48777
# [4]	validation_0-breslow_likelihood:5.87852	validation_1-breslow_likelihood:4.43527
# [16]	validation_0-breslow_likelihood:5.85189	validation_1-breslow_likelihood:4.46280
# [35]	validation_0-breslow_likelihood:5.82757	validation_1-breslow_likelihood:4.48727
# [17]	validation_0-breslow_likelihood:5.85119	validation_1-breslow_likelihood:4.46265
# [5]	validation_0-breslow_likelihood:5.87721	validation_1-breslow_likelihood:4.43370
# [18]	validation_0-breslow_likelihood:5.85033	validation_1-breslow_likelihood:4.46330
# [36]	validation_0-breslow_likelihood:5.82284	validation_1-breslow_likelihood:4.48657
# [19]	validation_0-breslow_likelihood:5.84964	validation_1-breslow_likelihood:4.46340
# [37]	validation_0-breslow_likelihood:5.82275	validation_1-breslow_likelihood:4.48652
# [20]	validation_0-breslow_likelihood:5.84697	validation_1-breslow_likelihood:4.46074
# [38]	validation_0-breslow_likelihood:5.82009	validation_1-breslow_likelihood:4.48588
# [21]	validation_0-breslow_likelihood:5.84657	validation_1-breslow_likelihood:4.46077
# [6]	validation_0-breslow_likelihood:5.87706	validation_1-breslow_likelihood:4.43375
# [39]	validation_0-breslow_likelihood:5.81931	validation_1-breslow_likelihood:4.48537
# [22]	validation_0-breslow_likelihood:5.84457	validation_1-breslow_likelihood:4.45857
# [7]	validation_0-breslow_likelihood:5.87609	validation_1-breslow_likelihood:4.43304
# [40]	validation_0-breslow_likelihood:5.81435	validation_1-breslow_likelihood:4.48276
# [8]	validation_0-breslow_likelihood:5.87542	validation_1-breslow_likelihood:4.43236
# [41]	validation_0-breslow_likelihood:5.81408	validation_1-breslow_likelihood:4.48260
# [9]	validation_0-breslow_likelihood:5.87535	validation_1-breslow_likelihood:4.43219
# [10]	validation_0-breslow_likelihood:5.87287	validation_1-breslow_likelihood:4.43137
# [11]	validation_0-breslow_likelihood:5.87053	validation_1-breslow_likelihood:4.42989
# [12]	validation_0-breslow_likelihood:5.86967	validation_1-breslow_likelihood:4.42919
# [13]	validation_0-breslow_likelihood:5.86913	validation_1-breslow_likelihood:4.42842
# [42]	validation_0-breslow_likelihood:5.81217	validation_1-breslow_likelihood:4.48275
# [14]	validation_0-breslow_likelihood:5.86821	validation_1-breslow_likelihood:4.42806
# [15]	validation_0-breslow_likelihood:5.86709	validation_1-breslow_likelihood:4.42758
# [16]	validation_0-breslow_likelihood:5.86651	validation_1-breslow_likelihood:4.42683
# [17]	validation_0-breslow_likelihood:5.86601	validation_1-breslow_likelihood:4.42666
# [18]	validation_0-breslow_likelihood:5.86358	validation_1-breslow_likelihood:4.42507
# [19]	validation_0-breslow_likelihood:5.86323	validation_1-breslow_likelihood:4.42524
# [43]	validation_0-breslow_likelihood:5.81157	validation_1-breslow_likelihood:4.48259
# [20]	validation_0-breslow_likelihood:5.86240	validation_1-breslow_likelihood:4.42482
# [21]	validation_0-breslow_likelihood:5.86189	validation_1-breslow_likelihood:4.42455
# [22]	validation_0-breslow_likelihood:5.86072	validation_1-breslow_likelihood:4.42410
# [44]	validation_0-breslow_likelihood:5.81029	validation_1-breslow_likelihood:4.48245
# [0]	validation_0-breslow_likelihood:5.84251	validation_1-breslow_likelihood:4.45839
# [1]	validation_0-breslow_likelihood:5.84013	validation_1-breslow_likelihood:4.45716
# [2]	validation_0-breslow_likelihood:5.83796	validation_1-breslow_likelihood:4.45701
# [45]	validation_0-breslow_likelihood:5.80433	validation_1-breslow_likelihood:4.48235
# [0]	validation_0-breslow_likelihood:5.85726	validation_1-breslow_likelihood:4.56171
# [3]	validation_0-breslow_likelihood:5.83550	validation_1-breslow_likelihood:4.45682
# [1]	validation_0-breslow_likelihood:5.85672	validation_1-breslow_likelihood:4.56154
# [4]	validation_0-breslow_likelihood:5.83240	validation_1-breslow_likelihood:4.45598
# [2]	validation_0-breslow_likelihood:5.85621	validation_1-breslow_likelihood:4.56096
# [46]	validation_0-breslow_likelihood:5.80208	validation_1-breslow_likelihood:4.48195
# [3]	validation_0-breslow_likelihood:5.85514	validation_1-breslow_likelihood:4.56171
# [47]	validation_0-breslow_likelihood:5.79695	validation_1-breslow_likelihood:4.47895
# [5]	validation_0-breslow_likelihood:5.82538	validation_1-breslow_likelihood:4.45378
# [4]	validation_0-breslow_likelihood:5.85388	validation_1-breslow_likelihood:4.56173
# [48]	validation_0-breslow_likelihood:5.79381	validation_1-breslow_likelihood:4.47668
# [5]	validation_0-breslow_likelihood:5.85104	validation_1-breslow_likelihood:4.56192
# [49]	validation_0-breslow_likelihood:5.78862	validation_1-breslow_likelihood:4.47555
# [6]	validation_0-breslow_likelihood:5.82182	validation_1-breslow_likelihood:4.45296
# [50]	validation_0-breslow_likelihood:5.78849	validation_1-breslow_likelihood:4.47544
# [0]	validation_0-breslow_likelihood:5.88270	validation_1-breslow_likelihood:4.43759
# [6]	validation_0-breslow_likelihood:5.85034	validation_1-breslow_likelihood:4.56189
# [51]	validation_0-breslow_likelihood:5.78590	validation_1-breslow_likelihood:4.47403
# [1]	validation_0-breslow_likelihood:5.88137	validation_1-breslow_likelihood:4.43728
# [52]	validation_0-breslow_likelihood:5.78551	validation_1-breslow_likelihood:4.47409
# [7]	validation_0-breslow_likelihood:5.84994	validation_1-breslow_likelihood:4.56174
# [7]	validation_0-breslow_likelihood:5.81847	validation_1-breslow_likelihood:4.45265
# [2]	validation_0-breslow_likelihood:5.88068	validation_1-breslow_likelihood:4.43762
# [53]	validation_0-breslow_likelihood:5.78259	validation_1-breslow_likelihood:4.47355
# [8]	validation_0-breslow_likelihood:5.84647	validation_1-breslow_likelihood:4.56142
# [8]	validation_0-breslow_likelihood:5.81652	validation_1-breslow_likelihood:4.45155
# [3]	validation_0-breslow_likelihood:5.87793	validation_1-breslow_likelihood:4.43696
# [54]	validation_0-breslow_likelihood:5.78256	validation_1-breslow_likelihood:4.47361
# [9]	validation_0-breslow_likelihood:5.84575	validation_1-breslow_likelihood:4.56142
# [4]	validation_0-breslow_likelihood:5.87595	validation_1-breslow_likelihood:4.43625
# [9]	validation_0-breslow_likelihood:5.80986	validation_1-breslow_likelihood:4.44936
# [55]	validation_0-breslow_likelihood:5.78139	validation_1-breslow_likelihood:4.47267
# [10]	validation_0-breslow_likelihood:5.84551	validation_1-breslow_likelihood:4.56110
# [10]	validation_0-breslow_likelihood:5.80799	validation_1-breslow_likelihood:4.44771
# [56]	validation_0-breslow_likelihood:5.77994	validation_1-breslow_likelihood:4.47207
# [11]	validation_0-breslow_likelihood:5.84392	validation_1-breslow_likelihood:4.56124
# [11]	validation_0-breslow_likelihood:5.80746	validation_1-breslow_likelihood:4.44794
# [5]	validation_0-breslow_likelihood:5.87383	validation_1-breslow_likelihood:4.43545
# [57]	validation_0-breslow_likelihood:5.77853	validation_1-breslow_likelihood:4.47157
# [12]	validation_0-breslow_likelihood:5.80739	validation_1-breslow_likelihood:4.44797
# [6]	validation_0-breslow_likelihood:5.87274	validation_1-breslow_likelihood:4.43514
# [58]	validation_0-breslow_likelihood:5.77733	validation_1-breslow_likelihood:4.47108
# [13]	validation_0-breslow_likelihood:5.80727	validation_1-breslow_likelihood:4.44798
# [7]	validation_0-breslow_likelihood:5.87175	validation_1-breslow_likelihood:4.43503
# [12]	validation_0-breslow_likelihood:5.84380	validation_1-breslow_likelihood:4.56128
# [59]	validation_0-breslow_likelihood:5.77536	validation_1-breslow_likelihood:4.46890
# [14]	validation_0-breslow_likelihood:5.80095	validation_1-breslow_likelihood:4.44785
# [60]	validation_0-breslow_likelihood:5.77532	validation_1-breslow_likelihood:4.46889
# [15]	validation_0-breslow_likelihood:5.80075	validation_1-breslow_likelihood:4.44769
# [61]	validation_0-breslow_likelihood:5.77453	validation_1-breslow_likelihood:4.46855
# [16]	validation_0-breslow_likelihood:5.79808	validation_1-breslow_likelihood:4.44598
# [8]	validation_0-breslow_likelihood:5.86756	validation_1-breslow_likelihood:4.43305
# [17]	validation_0-breslow_likelihood:5.79577	validation_1-breslow_likelihood:4.44582
# [9]	validation_0-breslow_likelihood:5.86632	validation_1-breslow_likelihood:4.43258
# [10]	validation_0-breslow_likelihood:5.86564	validation_1-breslow_likelihood:4.43234
# [18]	validation_0-breslow_likelihood:5.78908	validation_1-breslow_likelihood:4.44212
# [19]	validation_0-breslow_likelihood:5.78913	validation_1-breslow_likelihood:4.44208
# [62]	validation_0-breslow_likelihood:5.77054	validation_1-breslow_likelihood:4.46696
# [20]	validation_0-breslow_likelihood:5.78465	validation_1-breslow_likelihood:4.44369
# [11]	validation_0-breslow_likelihood:5.86315	validation_1-breslow_likelihood:4.43182
# [12]	validation_0-breslow_likelihood:5.86272	validation_1-breslow_likelihood:4.43143
# [13]	validation_0-breslow_likelihood:5.85981	validation_1-breslow_likelihood:4.43015
# [63]	validation_0-breslow_likelihood:5.76952	validation_1-breslow_likelihood:4.46656
# [21]	validation_0-breslow_likelihood:5.78208	validation_1-breslow_likelihood:4.44229
# [64]	validation_0-breslow_likelihood:5.76882	validation_1-breslow_likelihood:4.46640
# [65]	validation_0-breslow_likelihood:5.76747	validation_1-breslow_likelihood:4.46548
# [22]	validation_0-breslow_likelihood:5.78104	validation_1-breslow_likelihood:4.44254
# [23]	validation_0-breslow_likelihood:5.77836	validation_1-breslow_likelihood:4.44219
# [66]	validation_0-breslow_likelihood:5.76733	validation_1-breslow_likelihood:4.46538
# [14]	validation_0-breslow_likelihood:5.85588	validation_1-breslow_likelihood:4.42829
# [67]	validation_0-breslow_likelihood:5.76701	validation_1-breslow_likelihood:4.46505
# [24]	validation_0-breslow_likelihood:5.77190	validation_1-breslow_likelihood:4.44134
# [15]	validation_0-breslow_likelihood:5.85301	validation_1-breslow_likelihood:4.42795
# [25]	validation_0-breslow_likelihood:5.77190	validation_1-breslow_likelihood:4.44134
# [68]	validation_0-breslow_likelihood:5.76274	validation_1-breslow_likelihood:4.46514
# [16]	validation_0-breslow_likelihood:5.85095	validation_1-breslow_likelihood:4.42604
# [17]	validation_0-breslow_likelihood:5.84985	validation_1-breslow_likelihood:4.42605
# [69]	validation_0-breslow_likelihood:5.76261	validation_1-breslow_likelihood:4.46501
# [26]	validation_0-breslow_likelihood:5.77132	validation_1-breslow_likelihood:4.44163
# [27]	validation_0-breslow_likelihood:5.76864	validation_1-breslow_likelihood:4.44084
# [18]	validation_0-breslow_likelihood:5.84955	validation_1-breslow_likelihood:4.42602
# [28]	validation_0-breslow_likelihood:5.76727	validation_1-breslow_likelihood:4.44162
# [70]	validation_0-breslow_likelihood:5.75943	validation_1-breslow_likelihood:4.46362
# [29]	validation_0-breslow_likelihood:5.76724	validation_1-breslow_likelihood:4.44165
# [71]	validation_0-breslow_likelihood:5.75651	validation_1-breslow_likelihood:4.46216
# [19]	validation_0-breslow_likelihood:5.84758	validation_1-breslow_likelihood:4.42607
# [30]	validation_0-breslow_likelihood:5.76554	validation_1-breslow_likelihood:4.44094
# [20]	validation_0-breslow_likelihood:5.84419	validation_1-breslow_likelihood:4.42609
# [21]	validation_0-breslow_likelihood:5.84407	validation_1-breslow_likelihood:4.42597
# [22]	validation_0-breslow_likelihood:5.83776	validation_1-breslow_likelihood:4.42460
# [72]	validation_0-breslow_likelihood:5.75495	validation_1-breslow_likelihood:4.46107
# [31]	validation_0-breslow_likelihood:5.76221	validation_1-breslow_likelihood:4.44017
# [23]	validation_0-breslow_likelihood:5.83609	validation_1-breslow_likelihood:4.42368
# [24]	validation_0-breslow_likelihood:5.83604	validation_1-breslow_likelihood:4.42369
# [0]	validation_0-breslow_likelihood:5.86934	validation_1-breslow_likelihood:4.47355
# [25]	validation_0-breslow_likelihood:5.83301	validation_1-breslow_likelihood:4.42211
# [26]	validation_0-breslow_likelihood:5.83257	validation_1-breslow_likelihood:4.42160
# [32]	validation_0-breslow_likelihood:5.76006	validation_1-breslow_likelihood:4.44110[73]	validation_0-breslow_likelihood:5.74955	validation_1-breslow_likelihood:4.46049
#
# [27]	validation_0-breslow_likelihood:5.83080	validation_1-breslow_likelihood:4.42107
# [28]	validation_0-breslow_likelihood:5.83063	validation_1-breslow_likelihood:4.42087
# [29]	validation_0-breslow_likelihood:5.82988	validation_1-breslow_likelihood:4.42049
# [1]	validation_0-breslow_likelihood:5.86737	validation_1-breslow_likelihood:4.47355
# [30]	validation_0-breslow_likelihood:5.82978	validation_1-breslow_likelihood:4.42050
# [74]	validation_0-breslow_likelihood:5.74949	validation_1-breslow_likelihood:4.46049
# [33]	validation_0-breslow_likelihood:5.75611	validation_1-breslow_likelihood:4.44060
# [31]	validation_0-breslow_likelihood:5.82933	validation_1-breslow_likelihood:4.42060
# [2]	validation_0-breslow_likelihood:5.86465	validation_1-breslow_likelihood:4.47268
# [32]	validation_0-breslow_likelihood:5.82609	validation_1-breslow_likelihood:4.42137
# [34]	validation_0-breslow_likelihood:5.75019	validation_1-breslow_likelihood:4.44000
# [33]	validation_0-breslow_likelihood:5.82396	validation_1-breslow_likelihood:4.41991
# [3]	validation_0-breslow_likelihood:5.86216	validation_1-breslow_likelihood:4.47176
# [75]	validation_0-breslow_likelihood:5.74852	validation_1-breslow_likelihood:4.46050
# [34]	validation_0-breslow_likelihood:5.82378	validation_1-breslow_likelihood:4.41975
# [35]	validation_0-breslow_likelihood:5.74740	validation_1-breslow_likelihood:4.44017
# [76]	validation_0-breslow_likelihood:5.74729	validation_1-breslow_likelihood:4.46026
# [4]	validation_0-breslow_likelihood:5.85779	validation_1-breslow_likelihood:4.46999
# [35]	validation_0-breslow_likelihood:5.81990	validation_1-breslow_likelihood:4.41891
# [77]	validation_0-breslow_likelihood:5.74726	validation_1-breslow_likelihood:4.46025
# [36]	validation_0-breslow_likelihood:5.74670	validation_1-breslow_likelihood:4.43998
# [36]	validation_0-breslow_likelihood:5.81483	validation_1-breslow_likelihood:4.41878
# [5]	validation_0-breslow_likelihood:5.85276	validation_1-breslow_likelihood:4.46827
# [78]	validation_0-breslow_likelihood:5.74680	validation_1-breslow_likelihood:4.46024
# [37]	validation_0-breslow_likelihood:5.81481	validation_1-breslow_likelihood:4.41871
# [0]	validation_0-breslow_likelihood:5.84248	validation_1-breslow_likelihood:4.45832
# [37]	validation_0-breslow_likelihood:5.74341	validation_1-breslow_likelihood:4.43913
# [6]	validation_0-breslow_likelihood:5.84969	validation_1-breslow_likelihood:4.46619
# [1]	validation_0-breslow_likelihood:5.84156	validation_1-breslow_likelihood:4.45871
# [79]	validation_0-breslow_likelihood:5.74667	validation_1-breslow_likelihood:4.46021
# [7]	validation_0-breslow_likelihood:5.84553	validation_1-breslow_likelihood:4.46610
# [2]	validation_0-breslow_likelihood:5.84068	validation_1-breslow_likelihood:4.45947
# [38]	validation_0-breslow_likelihood:5.74329	validation_1-breslow_likelihood:4.43927
# [38]	validation_0-breslow_likelihood:5.81165	validation_1-breslow_likelihood:4.41783
# [3]	validation_0-breslow_likelihood:5.84045	validation_1-breslow_likelihood:4.45950
# [8]	validation_0-breslow_likelihood:5.84375	validation_1-breslow_likelihood:4.46364
# [4]	validation_0-breslow_likelihood:5.83973	validation_1-breslow_likelihood:4.45943
# [9]	validation_0-breslow_likelihood:5.83852	validation_1-breslow_likelihood:4.46175
# [5]	validation_0-breslow_likelihood:5.83953	validation_1-breslow_likelihood:4.45940
# [10]	validation_0-breslow_likelihood:5.83783	validation_1-breslow_likelihood:4.46229
# [6]	validation_0-breslow_likelihood:5.83924	validation_1-breslow_likelihood:4.45931
# [39]	validation_0-breslow_likelihood:5.81076	validation_1-breslow_likelihood:4.41717
# [80]	validation_0-breslow_likelihood:5.74556	validation_1-breslow_likelihood:4.46033
# [11]	validation_0-breslow_likelihood:5.83717	validation_1-breslow_likelihood:4.46212
# [7]	validation_0-breslow_likelihood:5.83871	validation_1-breslow_likelihood:4.45928
# [39]	validation_0-breslow_likelihood:5.74257	validation_1-breslow_likelihood:4.43908
# [12]	validation_0-breslow_likelihood:5.83716	validation_1-breslow_likelihood:4.46204
# [8]	validation_0-breslow_likelihood:5.83629	validation_1-breslow_likelihood:4.45766
# [13]	validation_0-breslow_likelihood:5.83707	validation_1-breslow_likelihood:4.46190
# [40]	validation_0-breslow_likelihood:5.74222	validation_1-breslow_likelihood:4.43892
# [9]	validation_0-breslow_likelihood:5.83530	validation_1-breslow_likelihood:4.45712
# [81]	validation_0-breslow_likelihood:5.74229	validation_1-breslow_likelihood:4.46035
# [40]	validation_0-breslow_likelihood:5.80632	validation_1-breslow_likelihood:4.41542
# [10]	validation_0-breslow_likelihood:5.83496	validation_1-breslow_likelihood:4.45673
# [41]	validation_0-breslow_likelihood:5.80614	validation_1-breslow_likelihood:4.41512
# [82]	validation_0-breslow_likelihood:5.74139	validation_1-breslow_likelihood:4.46014
# [11]	validation_0-breslow_likelihood:5.83417	validation_1-breslow_likelihood:4.45710
# [14]	validation_0-breslow_likelihood:5.82892	validation_1-breslow_likelihood:4.45970
# [41]	validation_0-breslow_likelihood:5.74040	validation_1-breslow_likelihood:4.43863
# [12]	validation_0-breslow_likelihood:5.83114	validation_1-breslow_likelihood:4.45533
# [42]	validation_0-breslow_likelihood:5.80461	validation_1-breslow_likelihood:4.41438
# [83]	validation_0-breslow_likelihood:5.74067	validation_1-breslow_likelihood:4.45981
# [13]	validation_0-breslow_likelihood:5.83042	validation_1-breslow_likelihood:4.45539
# [43]	validation_0-breslow_likelihood:5.80395	validation_1-breslow_likelihood:4.41412
# [14]	validation_0-breslow_likelihood:5.82948	validation_1-breslow_likelihood:4.45543
# [42]	validation_0-breslow_likelihood:5.73615	validation_1-breslow_likelihood:4.43864
# [15]	validation_0-breslow_likelihood:5.82867	validation_1-breslow_likelihood:4.45953
# [84]	validation_0-breslow_likelihood:5.73515	validation_1-breslow_likelihood:4.45693
# [15]	validation_0-breslow_likelihood:5.82932	validation_1-breslow_likelihood:4.45544
# [44]	validation_0-breslow_likelihood:5.80255	validation_1-breslow_likelihood:4.41399
# [16]	validation_0-breslow_likelihood:5.82643	validation_1-breslow_likelihood:4.45791
# [16]	validation_0-breslow_likelihood:5.82740	validation_1-breslow_likelihood:4.45426
# [85]	validation_0-breslow_likelihood:5.73356	validation_1-breslow_likelihood:4.45690
# [17]	validation_0-breslow_likelihood:5.82730	validation_1-breslow_likelihood:4.45401
# [45]	validation_0-breslow_likelihood:5.79570	validation_1-breslow_likelihood:4.41064
# [43]	validation_0-breslow_likelihood:5.73604	validation_1-breslow_likelihood:4.43877
# [17]	validation_0-breslow_likelihood:5.82421	validation_1-breslow_likelihood:4.45584
# [46]	validation_0-breslow_likelihood:5.79438	validation_1-breslow_likelihood:4.41095
# [86]	validation_0-breslow_likelihood:5.73161	validation_1-breslow_likelihood:4.45678
# [18]	validation_0-breslow_likelihood:5.81685	validation_1-breslow_likelihood:4.45460
# [44]	validation_0-breslow_likelihood:5.73360	validation_1-breslow_likelihood:4.43896
# [19]	validation_0-breslow_likelihood:5.81685	validation_1-breslow_likelihood:4.45460
# [87]	validation_0-breslow_likelihood:5.73155	validation_1-breslow_likelihood:4.45676
# [47]	validation_0-breslow_likelihood:5.79120	validation_1-breslow_likelihood:4.40961
# [45]	validation_0-breslow_likelihood:5.73074	validation_1-breslow_likelihood:4.43935
# [18]	validation_0-breslow_likelihood:5.82660	validation_1-breslow_likelihood:4.45371
# [48]	validation_0-breslow_likelihood:5.78868	validation_1-breslow_likelihood:4.40918
# [46]	validation_0-breslow_likelihood:5.72898	validation_1-breslow_likelihood:4.43905
# [20]	validation_0-breslow_likelihood:5.81286	validation_1-breslow_likelihood:4.45239
# [49]	validation_0-breslow_likelihood:5.78254	validation_1-breslow_likelihood:4.40794
# [47]	validation_0-breslow_likelihood:5.72346	validation_1-breslow_likelihood:4.43920
# [21]	validation_0-breslow_likelihood:5.80982	validation_1-breslow_likelihood:4.45067
# [50]	validation_0-breslow_likelihood:5.78226	validation_1-breslow_likelihood:4.40768
# [48]	validation_0-breslow_likelihood:5.72077	validation_1-breslow_likelihood:4.43740
# [19]	validation_0-breslow_likelihood:5.82606	validation_1-breslow_likelihood:4.45429
# [22]	validation_0-breslow_likelihood:5.80897	validation_1-breslow_likelihood:4.45107
# [49]	validation_0-breslow_likelihood:5.71650	validation_1-breslow_likelihood:4.43660
# [23]	validation_0-breslow_likelihood:5.80629	validation_1-breslow_likelihood:4.44952
# [50]	validation_0-breslow_likelihood:5.71640	validation_1-breslow_likelihood:4.43689
# [51]	validation_0-breslow_likelihood:5.77943	validation_1-breslow_likelihood:4.40699
# [51]	validation_0-breslow_likelihood:5.71539	validation_1-breslow_likelihood:4.43704
# [20]	validation_0-breslow_likelihood:5.82344	validation_1-breslow_likelihood:4.45309
# [52]	validation_0-breslow_likelihood:5.77918	validation_1-breslow_likelihood:4.40710
# [52]	validation_0-breslow_likelihood:5.71531	validation_1-breslow_likelihood:4.43701
# [53]	validation_0-breslow_likelihood:5.77657	validation_1-breslow_likelihood:4.40627
# [54]	validation_0-breslow_likelihood:5.77649	validation_1-breslow_likelihood:4.40630
# [21]	validation_0-breslow_likelihood:5.82315	validation_1-breslow_likelihood:4.45324
# [53]	validation_0-breslow_likelihood:5.71375	validation_1-breslow_likelihood:4.43585
# [55]	validation_0-breslow_likelihood:5.77492	validation_1-breslow_likelihood:4.40502
# [54]	validation_0-breslow_likelihood:5.71375	validation_1-breslow_likelihood:4.43585
# [24]	validation_0-breslow_likelihood:5.80016	validation_1-breslow_likelihood:4.44700
# [56]	validation_0-breslow_likelihood:5.77335	validation_1-breslow_likelihood:4.40488
# [22]	validation_0-breslow_likelihood:5.82046	validation_1-breslow_likelihood:4.45148
# [25]	validation_0-breslow_likelihood:5.80013	validation_1-breslow_likelihood:4.44697
# [55]	validation_0-breslow_likelihood:5.70735	validation_1-breslow_likelihood:4.43594[57]	validation_0-breslow_likelihood:5.77085	validation_1-breslow_likelihood:4.40422
#
# [26]	validation_0-breslow_likelihood:5.79966	validation_1-breslow_likelihood:4.44651
# [58]	validation_0-breslow_likelihood:5.76997	validation_1-breslow_likelihood:4.40383
# [56]	validation_0-breslow_likelihood:5.70485	validation_1-breslow_likelihood:4.43645
# [27]	validation_0-breslow_likelihood:5.79727	validation_1-breslow_likelihood:4.44457
# [59]	validation_0-breslow_likelihood:5.76834	validation_1-breslow_likelihood:4.40275
# [57]	validation_0-breslow_likelihood:5.70445	validation_1-breslow_likelihood:4.43621
# [60]	validation_0-breslow_likelihood:5.76836	validation_1-breslow_likelihood:4.40283
# [58]	validation_0-breslow_likelihood:5.70388	validation_1-breslow_likelihood:4.43597
# [28]	validation_0-breslow_likelihood:5.79608	validation_1-breslow_likelihood:4.44420
# [61]	validation_0-breslow_likelihood:5.76779	validation_1-breslow_likelihood:4.40257
# [29]	validation_0-breslow_likelihood:5.79608	validation_1-breslow_likelihood:4.44420
# [59]	validation_0-breslow_likelihood:5.70130	validation_1-breslow_likelihood:4.43637
# [30]	validation_0-breslow_likelihood:5.79400	validation_1-breslow_likelihood:4.44370
# [60]	validation_0-breslow_likelihood:5.70035	validation_1-breslow_likelihood:4.43632
# [62]	validation_0-breslow_likelihood:5.76411	validation_1-breslow_likelihood:4.40152
# [61]	validation_0-breslow_likelihood:5.70011	validation_1-breslow_likelihood:4.43652
# [63]	validation_0-breslow_likelihood:5.76277	validation_1-breslow_likelihood:4.40151
# [31]	validation_0-breslow_likelihood:5.78848	validation_1-breslow_likelihood:4.44306
# [64]	validation_0-breslow_likelihood:5.76217	validation_1-breslow_likelihood:4.40109
# [62]	validation_0-breslow_likelihood:5.69932	validation_1-breslow_likelihood:4.43665
# [32]	validation_0-breslow_likelihood:5.78606	validation_1-breslow_likelihood:4.44135
# [65]	validation_0-breslow_likelihood:5.76139	validation_1-breslow_likelihood:4.40042
# [33]	validation_0-breslow_likelihood:5.78189	validation_1-breslow_likelihood:4.43928
# [66]	validation_0-breslow_likelihood:5.76124	validation_1-breslow_likelihood:4.40030
# [63]	validation_0-breslow_likelihood:5.69871	validation_1-breslow_likelihood:4.43704
# [67]	validation_0-breslow_likelihood:5.76101	validation_1-breslow_likelihood:4.39990
# [68]	validation_0-breslow_likelihood:5.75711	validation_1-breslow_likelihood:4.39871
# [34]	validation_0-breslow_likelihood:5.77569	validation_1-breslow_likelihood:4.43940
# [69]	validation_0-breslow_likelihood:5.75687	validation_1-breslow_likelihood:4.39862
# [35]	validation_0-breslow_likelihood:5.77364	validation_1-breslow_likelihood:4.43777
# [70]	validation_0-breslow_likelihood:5.75326	validation_1-breslow_likelihood:4.39610
# [36]	validation_0-breslow_likelihood:5.77293	validation_1-breslow_likelihood:4.43745
# [71]	validation_0-breslow_likelihood:5.75005	validation_1-breslow_likelihood:4.39520
# [37]	validation_0-breslow_likelihood:5.76930	validation_1-breslow_likelihood:4.43654
# [72]	validation_0-breslow_likelihood:5.74866	validation_1-breslow_likelihood:4.39537
# [38]	validation_0-breslow_likelihood:5.76930	validation_1-breslow_likelihood:4.43652
# [73]	validation_0-breslow_likelihood:5.74520	validation_1-breslow_likelihood:4.39525
# [39]	validation_0-breslow_likelihood:5.76855	validation_1-breslow_likelihood:4.43563
# [74]	validation_0-breslow_likelihood:5.74518	validation_1-breslow_likelihood:4.39517
# [40]	validation_0-breslow_likelihood:5.76837	validation_1-breslow_likelihood:4.43564
# [75]	validation_0-breslow_likelihood:5.74381	validation_1-breslow_likelihood:4.39491
# [41]	validation_0-breslow_likelihood:5.76636	validation_1-breslow_likelihood:4.43597
# [76]	validation_0-breslow_likelihood:5.74160	validation_1-breslow_likelihood:4.39352
# [42]	validation_0-breslow_likelihood:5.76298	validation_1-breslow_likelihood:4.43659
# [77]	validation_0-breslow_likelihood:5.74150	validation_1-breslow_likelihood:4.39345
# [43]	validation_0-breslow_likelihood:5.76297	validation_1-breslow_likelihood:4.43651
# [78]	validation_0-breslow_likelihood:5.74137	validation_1-breslow_likelihood:4.39336
# [79]	validation_0-breslow_likelihood:5.74112	validation_1-breslow_likelihood:4.39329
# [44]	validation_0-breslow_likelihood:5.75997	validation_1-breslow_likelihood:4.43508
# [80]	validation_0-breslow_likelihood:5.73982	validation_1-breslow_likelihood:4.39261
# [45]	validation_0-breslow_likelihood:5.75674	validation_1-breslow_likelihood:4.43492
# [81]	validation_0-breslow_likelihood:5.73672	validation_1-breslow_likelihood:4.39285
# [46]	validation_0-breslow_likelihood:5.75592	validation_1-breslow_likelihood:4.43608
# [47]	validation_0-breslow_likelihood:5.75075	validation_1-breslow_likelihood:4.43662
# [82]	validation_0-breslow_likelihood:5.73551	validation_1-breslow_likelihood:4.39363
# [48]	validation_0-breslow_likelihood:5.74743	validation_1-breslow_likelihood:4.43451
# [83]	validation_0-breslow_likelihood:5.73485	validation_1-breslow_likelihood:4.39328
# [49]	validation_0-breslow_likelihood:5.74177	validation_1-breslow_likelihood:4.43448
# [84]	validation_0-breslow_likelihood:5.72974	validation_1-breslow_likelihood:4.39298
# [50]	validation_0-breslow_likelihood:5.74174	validation_1-breslow_likelihood:4.43446
# [85]	validation_0-breslow_likelihood:5.72777	validation_1-breslow_likelihood:4.39233
# [51]	validation_0-breslow_likelihood:5.74098	validation_1-breslow_likelihood:4.43516
# [86]	validation_0-breslow_likelihood:5.72660	validation_1-breslow_likelihood:4.39206
# [52]	validation_0-breslow_likelihood:5.74097	validation_1-breslow_likelihood:4.43515
# [87]	validation_0-breslow_likelihood:5.72637	validation_1-breslow_likelihood:4.39216
# [53]	validation_0-breslow_likelihood:5.73871	validation_1-breslow_likelihood:4.43394
# [54]	validation_0-breslow_likelihood:5.73871	validation_1-breslow_likelihood:4.43394
# [55]	validation_0-breslow_likelihood:5.73233	validation_1-breslow_likelihood:4.43320
# [56]	validation_0-breslow_likelihood:5.72944	validation_1-breslow_likelihood:4.43166
# [57]	validation_0-breslow_likelihood:5.72828	validation_1-breslow_likelihood:4.43143
# [58]	validation_0-breslow_likelihood:5.72772	validation_1-breslow_likelihood:4.43116
# [59]	validation_0-breslow_likelihood:5.72606	validation_1-breslow_likelihood:4.43067
# [60]	validation_0-breslow_likelihood:5.72499	validation_1-breslow_likelihood:4.42986
# [61]	validation_0-breslow_likelihood:5.72460	validation_1-breslow_likelihood:4.42983
# [62]	validation_0-breslow_likelihood:5.72389	validation_1-breslow_likelihood:4.42988
# [63]	validation_0-breslow_likelihood:5.72340	validation_1-breslow_likelihood:4.42954
# [64]	validation_0-breslow_likelihood:5.72065	validation_1-breslow_likelihood:4.42836
# [65]	validation_0-breslow_likelihood:5.71604	validation_1-breslow_likelihood:4.42681
# [66]	validation_0-breslow_likelihood:5.71544	validation_1-breslow_likelihood:4.42692
# [67]	validation_0-breslow_likelihood:5.71399	validation_1-breslow_likelihood:4.42708
# [68]	validation_0-breslow_likelihood:5.70752	validation_1-breslow_likelihood:4.42530
# [69]	validation_0-breslow_likelihood:5.70231	validation_1-breslow_likelihood:4.42638
# [70]	validation_0-breslow_likelihood:5.69905	validation_1-breslow_likelihood:4.42592
# [71]	validation_0-breslow_likelihood:5.69853	validation_1-breslow_likelihood:4.42570
# [72]	validation_0-breslow_likelihood:5.69604	validation_1-breslow_likelihood:4.42463
# [73]	validation_0-breslow_likelihood:5.69483	validation_1-breslow_likelihood:4.42411
# [74]	validation_0-breslow_likelihood:5.69351	validation_1-breslow_likelihood:4.42303
# [75]	validation_0-breslow_likelihood:5.69259	validation_1-breslow_likelihood:4.42300
# [76]	validation_0-breslow_likelihood:5.68827	validation_1-breslow_likelihood:4.42333
# [77]	validation_0-breslow_likelihood:5.68773	validation_1-breslow_likelihood:4.42281
# [78]	validation_0-breslow_likelihood:5.68773	validation_1-breslow_likelihood:4.42275
# [79]	validation_0-breslow_likelihood:5.68373	validation_1-breslow_likelihood:4.42152
# [80]	validation_0-breslow_likelihood:5.68099	validation_1-breslow_likelihood:4.42107
# [81]	validation_0-breslow_likelihood:5.67911	validation_1-breslow_likelihood:4.41995
# [82]	validation_0-breslow_likelihood:5.67650	validation_1-breslow_likelihood:4.42075
# [83]	validation_0-breslow_likelihood:5.67161	validation_1-breslow_likelihood:4.42049
# [84]	validation_0-breslow_likelihood:5.67147	validation_1-breslow_likelihood:4.42048
# [85]	validation_0-breslow_likelihood:5.66846	validation_1-breslow_likelihood:4.42066
# [86]	validation_0-breslow_likelihood:5.66798	validation_1-breslow_likelihood:4.42100
# [87]	validation_0-breslow_likelihood:5.66794	validation_1-breslow_likelihood:4.42098
# [0]	validation_0-breslow_likelihood:6.11573	validation_1-breslow_likelihood:4.80350
# [1]	validation_0-breslow_likelihood:6.11467	validation_1-breslow_likelihood:4.80319
# [2]	validation_0-breslow_likelihood:6.11458	validation_1-breslow_likelihood:4.80316
# [3]	validation_0-breslow_likelihood:6.11159	validation_1-breslow_likelihood:4.80136
# [4]	validation_0-breslow_likelihood:6.11017	validation_1-breslow_likelihood:4.80038
# [5]	validation_0-breslow_likelihood:6.10620	validation_1-breslow_likelihood:4.79851
# [6]	validation_0-breslow_likelihood:6.10221	validation_1-breslow_likelihood:4.79792
# [7]	validation_0-breslow_likelihood:6.10157	validation_1-breslow_likelihood:4.79769
# [8]	validation_0-breslow_likelihood:6.09950	validation_1-breslow_likelihood:4.79797
# [9]	validation_0-breslow_likelihood:6.09950	validation_1-breslow_likelihood:4.79797
# [10]	validation_0-breslow_likelihood:6.09848	validation_1-breslow_likelihood:4.79704
# [11]	validation_0-breslow_likelihood:6.09222	validation_1-breslow_likelihood:4.79604
# [12]	validation_0-breslow_likelihood:6.09107	validation_1-breslow_likelihood:4.79444
# [13]	validation_0-breslow_likelihood:6.08751	validation_1-breslow_likelihood:4.79420
# [14]	validation_0-breslow_likelihood:6.08705	validation_1-breslow_likelihood:4.79377
# [15]	validation_0-breslow_likelihood:6.08361	validation_1-breslow_likelihood:4.79288
# [16]	validation_0-breslow_likelihood:6.08312	validation_1-breslow_likelihood:4.79228
# [17]	validation_0-breslow_likelihood:6.08307	validation_1-breslow_likelihood:4.79219
# [18]	validation_0-breslow_likelihood:6.08071	validation_1-breslow_likelihood:4.78982
# [19]	validation_0-breslow_likelihood:6.07475	validation_1-breslow_likelihood:4.78829
# [20]	validation_0-breslow_likelihood:6.07079	validation_1-breslow_likelihood:4.78679
# [21]	validation_0-breslow_likelihood:6.07079	validation_1-breslow_likelihood:4.78679
# [22]	validation_0-breslow_likelihood:6.06491	validation_1-breslow_likelihood:4.78414
# [23]	validation_0-breslow_likelihood:6.05929	validation_1-breslow_likelihood:4.78200
# [24]	validation_0-breslow_likelihood:6.05783	validation_1-breslow_likelihood:4.78076
# [25]	validation_0-breslow_likelihood:6.05682	validation_1-breslow_likelihood:4.77951
# [26]	validation_0-breslow_likelihood:6.05360	validation_1-breslow_likelihood:4.77866
# [27]	validation_0-breslow_likelihood:6.04899	validation_1-breslow_likelihood:4.77783
# [28]	validation_0-breslow_likelihood:6.04800	validation_1-breslow_likelihood:4.77639
# [29]	validation_0-breslow_likelihood:6.04644	validation_1-breslow_likelihood:4.77534
# [30]	validation_0-breslow_likelihood:6.04495	validation_1-breslow_likelihood:4.77519
# [31]	validation_0-breslow_likelihood:6.04394	validation_1-breslow_likelihood:4.77583
# [32]	validation_0-breslow_likelihood:6.04364	validation_1-breslow_likelihood:4.77571
# [33]	validation_0-breslow_likelihood:6.04266	validation_1-breslow_likelihood:4.77643
# [34]	validation_0-breslow_likelihood:6.04183	validation_1-breslow_likelihood:4.77606
# [35]	validation_0-breslow_likelihood:6.04165	validation_1-breslow_likelihood:4.77598
# [36]	validation_0-breslow_likelihood:6.03859	validation_1-breslow_likelihood:4.77665
# [37]	validation_0-breslow_likelihood:6.03712	validation_1-breslow_likelihood:4.77726
# [38]	validation_0-breslow_likelihood:6.03564	validation_1-breslow_likelihood:4.77683
# [39]	validation_0-breslow_likelihood:6.03414	validation_1-breslow_likelihood:4.77583
# Concordance Index 0.6648873042722188
# Integrated Brier Score: 0.16726587749056157
# durations 0.76666665 337.03333
# Concordance Index 0.5868021110273401
# Integrated Brier Score: 0.18292591104342787
# (1522, 9) <class 'pandas.core.frame.DataFrame'>
# (1522,) <class 'pandas.core.series.Series'>
# (381, 9) <class 'pandas.core.frame.DataFrame'>
# (381,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:5.88206	validation_1-breslow_likelihood:4.60720
# [1]	validation_0-breslow_likelihood:5.87755	validation_1-breslow_likelihood:4.60419
# [2]	validation_0-breslow_likelihood:5.85654	validation_1-breslow_likelihood:4.60449
# [3]	validation_0-breslow_likelihood:5.85584	validation_1-breslow_likelihood:4.60378
# [4]	validation_0-breslow_likelihood:5.84213	validation_1-breslow_likelihood:4.60372
# [5]	validation_0-breslow_likelihood:5.83171	validation_1-breslow_likelihood:4.60012
# [6]	validation_0-breslow_likelihood:5.81749	validation_1-breslow_likelihood:4.61750
# [7]	validation_0-breslow_likelihood:5.81749	validation_1-breslow_likelihood:4.61743
# [0]	validation_0-breslow_likelihood:5.86101	validation_1-breslow_likelihood:4.49834
# [8]	validation_0-breslow_likelihood:5.80864	validation_1-breslow_likelihood:4.61322
# [1]	validation_0-breslow_likelihood:5.84114	validation_1-breslow_likelihood:4.49326
# [2]	validation_0-breslow_likelihood:5.83915	validation_1-breslow_likelihood:4.49573
# [9]	validation_0-breslow_likelihood:5.79330	validation_1-breslow_likelihood:4.62126
# [3]	validation_0-breslow_likelihood:5.83797	validation_1-breslow_likelihood:4.49535
# [4]	validation_0-breslow_likelihood:5.83072	validation_1-breslow_likelihood:4.49118
# [10]	validation_0-breslow_likelihood:5.77533	validation_1-breslow_likelihood:4.62701
# [5]	validation_0-breslow_likelihood:5.81755	validation_1-breslow_likelihood:4.49307
# [0]	validation_0-breslow_likelihood:5.84669	validation_1-breslow_likelihood:4.52226
# [11]	validation_0-breslow_likelihood:5.77470	validation_1-breslow_likelihood:4.62671
# [6]	validation_0-breslow_likelihood:5.79736	validation_1-breslow_likelihood:4.48469
# [1]	validation_0-breslow_likelihood:5.82484	validation_1-breslow_likelihood:4.52004
# [12]	validation_0-breslow_likelihood:5.74589	validation_1-breslow_likelihood:4.64616
# [2]	validation_0-breslow_likelihood:5.82332	validation_1-breslow_likelihood:4.52202
# [3]	validation_0-breslow_likelihood:5.82282	validation_1-breslow_likelihood:4.52210
# [0]	validation_0-breslow_likelihood:5.70874	validation_1-breslow_likelihood:4.76677
# [13]	validation_0-breslow_likelihood:5.74589	validation_1-breslow_likelihood:4.64617
# [7]	validation_0-breslow_likelihood:5.79704	validation_1-breslow_likelihood:4.48801
# [4]	validation_0-breslow_likelihood:5.80243	validation_1-breslow_likelihood:4.50340
# [1]	validation_0-breslow_likelihood:5.66298	validation_1-breslow_likelihood:4.76969
# [8]	validation_0-breslow_likelihood:5.79656	validation_1-breslow_likelihood:4.48996
# [5]	validation_0-breslow_likelihood:5.78885	validation_1-breslow_likelihood:4.49294
# [2]	validation_0-breslow_likelihood:5.66292	validation_1-breslow_likelihood:4.77188
# [14]	validation_0-breslow_likelihood:5.72722	validation_1-breslow_likelihood:4.65042
# [9]	validation_0-breslow_likelihood:5.79656	validation_1-breslow_likelihood:4.48988
# [6]	validation_0-breslow_likelihood:5.76612	validation_1-breslow_likelihood:4.49275
# [0]	validation_0-breslow_likelihood:5.71959	validation_1-breslow_likelihood:5.06581
# [3]	validation_0-breslow_likelihood:5.53836	validation_1-breslow_likelihood:4.96110
# [15]	validation_0-breslow_likelihood:5.72687	validation_1-breslow_likelihood:4.64962
# [7]	validation_0-breslow_likelihood:5.76690	validation_1-breslow_likelihood:4.49029
# [10]	validation_0-breslow_likelihood:5.76787	validation_1-breslow_likelihood:4.46920
# [1]	validation_0-breslow_likelihood:5.67623	validation_1-breslow_likelihood:5.13690
# [4]	validation_0-breslow_likelihood:5.51330	validation_1-breslow_likelihood:4.93558
# [2]	validation_0-breslow_likelihood:5.67623	validation_1-breslow_likelihood:5.13692
# [8]	validation_0-breslow_likelihood:5.76105	validation_1-breslow_likelihood:4.48439
# [11]	validation_0-breslow_likelihood:5.76744	validation_1-breslow_likelihood:4.46879
# [9]	validation_0-breslow_likelihood:5.76103	validation_1-breslow_likelihood:4.48429
# [5]	validation_0-breslow_likelihood:5.49310	validation_1-breslow_likelihood:4.96611
# [3]	validation_0-breslow_likelihood:5.46179	validation_1-breslow_likelihood:5.34499
# [12]	validation_0-breslow_likelihood:5.76244	validation_1-breslow_likelihood:4.46535
# [10]	validation_0-breslow_likelihood:5.73402	validation_1-breslow_likelihood:4.51378
# [6]	validation_0-breslow_likelihood:5.46060	validation_1-breslow_likelihood:5.16588
# [4]	validation_0-breslow_likelihood:5.43861	validation_1-breslow_likelihood:5.32781
# [11]	validation_0-breslow_likelihood:5.73229	validation_1-breslow_likelihood:4.51195
# [13]	validation_0-breslow_likelihood:5.74387	validation_1-breslow_likelihood:4.47603
# [7]	validation_0-breslow_likelihood:5.43915	validation_1-breslow_likelihood:5.16603
# [5]	validation_0-breslow_likelihood:5.41225	validation_1-breslow_likelihood:5.33538
# [12]	validation_0-breslow_likelihood:5.72243	validation_1-breslow_likelihood:4.51552
# [6]	validation_0-breslow_likelihood:5.36423	validation_1-breslow_likelihood:5.36721
# [14]	validation_0-breslow_likelihood:5.73101	validation_1-breslow_likelihood:4.47738
# [13]	validation_0-breslow_likelihood:5.70398	validation_1-breslow_likelihood:4.51583
# [0]	validation_0-breslow_likelihood:5.64871	validation_1-breslow_likelihood:4.66059
# [8]	validation_0-breslow_likelihood:5.24978	validation_1-breslow_likelihood:5.43744
# [7]	validation_0-breslow_likelihood:5.34007	validation_1-breslow_likelihood:5.54411
# ...
# [78]	validation_0-breslow_likelihood:7.40473	validation_1-breslow_likelihood:6.04040
# [80]	validation_0-breslow_likelihood:7.40248	validation_1-breslow_likelihood:6.03373
# [73]	validation_0-breslow_likelihood:7.40079	validation_1-breslow_likelihood:6.05726
# [79]	validation_0-breslow_likelihood:7.39890	validation_1-breslow_likelihood:6.02450
# [74]	validation_0-breslow_likelihood:7.39762	validation_1-breslow_likelihood:6.05417
# [80]	validation_0-breslow_likelihood:7.39890	validation_1-breslow_likelihood:6.02449
# [81]	validation_0-breslow_likelihood:7.40246	validation_1-breslow_likelihood:6.03372
# [79]	validation_0-breslow_likelihood:7.40422	validation_1-breslow_likelihood:6.04014
# [74]	validation_0-breslow_likelihood:7.40059	validation_1-breslow_likelihood:6.05716
# [75]	validation_0-breslow_likelihood:7.39721	validation_1-breslow_likelihood:6.05402
# [80]	validation_0-breslow_likelihood:7.40419	validation_1-breslow_likelihood:6.04013
# [81]	validation_0-breslow_likelihood:7.39888	validation_1-breslow_likelihood:6.02450
# [82]	validation_0-breslow_likelihood:7.40225	validation_1-breslow_likelihood:6.03377
# [75]	validation_0-breslow_likelihood:7.40041	validation_1-breslow_likelihood:6.05712
# [76]	validation_0-breslow_likelihood:7.39692	validation_1-breslow_likelihood:6.05388
# [81]	validation_0-breslow_likelihood:7.40413	validation_1-breslow_likelihood:6.04007
# [82]	validation_0-breslow_likelihood:7.39873	validation_1-breslow_likelihood:6.02449
# [83]	validation_0-breslow_likelihood:7.40188	validation_1-breslow_likelihood:6.03367
# [76]	validation_0-breslow_likelihood:7.39978	validation_1-breslow_likelihood:6.05678
# [77]	validation_0-breslow_likelihood:7.39658	validation_1-breslow_likelihood:6.05379
# [82]	validation_0-breslow_likelihood:7.40394	validation_1-breslow_likelihood:6.04000
# [83]	validation_0-breslow_likelihood:7.39844	validation_1-breslow_likelihood:6.02432
# [84]	validation_0-breslow_likelihood:7.40155	validation_1-breslow_likelihood:6.03361
# [77]	validation_0-breslow_likelihood:7.39947	validation_1-breslow_likelihood:6.05658
# [78]	validation_0-breslow_likelihood:7.39635	validation_1-breslow_likelihood:6.05368
# [83]	validation_0-breslow_likelihood:7.40355	validation_1-breslow_likelihood:6.03993
# [84]	validation_0-breslow_likelihood:7.39797	validation_1-breslow_likelihood:6.02405
# [85]	validation_0-breslow_likelihood:7.40142	validation_1-breslow_likelihood:6.03362
# [78]	validation_0-breslow_likelihood:7.39916	validation_1-breslow_likelihood:6.05642
# [79]	validation_0-breslow_likelihood:7.39590	validation_1-breslow_likelihood:6.05338
# [84]	validation_0-breslow_likelihood:7.40326	validation_1-breslow_likelihood:6.03967
# [85]	validation_0-breslow_likelihood:7.39785	validation_1-breslow_likelihood:6.02407
# [86]	validation_0-breslow_likelihood:7.40114	validation_1-breslow_likelihood:6.03345
# [80]	validation_0-breslow_likelihood:7.39587	validation_1-breslow_likelihood:6.05338
# [79]	validation_0-breslow_likelihood:7.39887	validation_1-breslow_likelihood:6.05623
# [85]	validation_0-breslow_likelihood:7.40310	validation_1-breslow_likelihood:6.03963
# [86]	validation_0-breslow_likelihood:7.39750	validation_1-breslow_likelihood:6.02399
# [87]	validation_0-breslow_likelihood:7.40094	validation_1-breslow_likelihood:6.03328
# [81]	validation_0-breslow_likelihood:7.39583	validation_1-breslow_likelihood:6.05342
# [80]	validation_0-breslow_likelihood:7.39848	validation_1-breslow_likelihood:6.05628
# [86]	validation_0-breslow_likelihood:7.40285	validation_1-breslow_likelihood:6.03958
# [88]	validation_0-breslow_likelihood:7.40094	validation_1-breslow_likelihood:6.03328
# [87]	validation_0-breslow_likelihood:7.39729	validation_1-breslow_likelihood:6.02380
# [82]	validation_0-breslow_likelihood:7.39570	validation_1-breslow_likelihood:6.05347
# [81]	validation_0-breslow_likelihood:7.39813	validation_1-breslow_likelihood:6.05626
# [87]	validation_0-breslow_likelihood:7.40258	validation_1-breslow_likelihood:6.03948
# [88]	validation_0-breslow_likelihood:7.39729	validation_1-breslow_likelihood:6.02380
# [89]	validation_0-breslow_likelihood:7.40076	validation_1-breslow_likelihood:6.03334
# [83]	validation_0-breslow_likelihood:7.39542	validation_1-breslow_likelihood:6.05341
# [82]	validation_0-breslow_likelihood:7.39797	validation_1-breslow_likelihood:6.05619
# [88]	validation_0-breslow_likelihood:7.40257	validation_1-breslow_likelihood:6.03947
# [89]	validation_0-breslow_likelihood:7.39707	validation_1-breslow_likelihood:6.02371
# [90]	validation_0-breslow_likelihood:7.40022	validation_1-breslow_likelihood:6.03336
# [84]	validation_0-breslow_likelihood:7.39510	validation_1-breslow_likelihood:6.05319
# [83]	validation_0-breslow_likelihood:7.39773	validation_1-breslow_likelihood:6.05609
# [89]	validation_0-breslow_likelihood:7.40237	validation_1-breslow_likelihood:6.03943
# [91]	validation_0-breslow_likelihood:7.40017	validation_1-breslow_likelihood:6.03335
# [90]	validation_0-breslow_likelihood:7.39665	validation_1-breslow_likelihood:6.02363
# [85]	validation_0-breslow_likelihood:7.39493	validation_1-breslow_likelihood:6.05313
# [84]	validation_0-breslow_likelihood:7.39748	validation_1-breslow_likelihood:6.05587
# [90]	validation_0-breslow_likelihood:7.40203	validation_1-breslow_likelihood:6.03922
# [91]	validation_0-breslow_likelihood:7.39660	validation_1-breslow_likelihood:6.02354
# [92]	validation_0-breslow_likelihood:7.39969	validation_1-breslow_likelihood:6.03313
# [85]	validation_0-breslow_likelihood:7.39736	validation_1-breslow_likelihood:6.05576
# [86]	validation_0-breslow_likelihood:7.39466	validation_1-breslow_likelihood:6.05295
# [91]	validation_0-breslow_likelihood:7.40195	validation_1-breslow_likelihood:6.03917
# [93]	validation_0-breslow_likelihood:7.39966	validation_1-breslow_likelihood:6.03310
# [92]	validation_0-breslow_likelihood:7.39624	validation_1-breslow_likelihood:6.02336
# [86]	validation_0-breslow_likelihood:7.39705	validation_1-breslow_likelihood:6.05555
# [87]	validation_0-breslow_likelihood:7.39449	validation_1-breslow_likelihood:6.05281
# [92]	validation_0-breslow_likelihood:7.40159	validation_1-breslow_likelihood:6.03898
# [93]	validation_0-breslow_likelihood:7.39622	validation_1-breslow_likelihood:6.02336
# [94]	validation_0-breslow_likelihood:7.39942	validation_1-breslow_likelihood:6.03303
# [88]	validation_0-breslow_likelihood:7.39448	validation_1-breslow_likelihood:6.05281
# [93]	validation_0-breslow_likelihood:7.40155	validation_1-breslow_likelihood:6.03894
# [87]	validation_0-breslow_likelihood:7.39685	validation_1-breslow_likelihood:6.05549
# [94]	validation_0-breslow_likelihood:7.39598	validation_1-breslow_likelihood:6.02331
# [89]	validation_0-breslow_likelihood:7.39431	validation_1-breslow_likelihood:6.05284
# [94]	validation_0-breslow_likelihood:7.40132	validation_1-breslow_likelihood:6.03872
# [88]	validation_0-breslow_likelihood:7.39654	validation_1-breslow_likelihood:6.05531
# [90]	validation_0-breslow_likelihood:7.39396	validation_1-breslow_likelihood:6.05266
# [89]	validation_0-breslow_likelihood:7.39620	validation_1-breslow_likelihood:6.05524
# [91]	validation_0-breslow_likelihood:7.39391	validation_1-breslow_likelihood:6.05261
# [90]	validation_0-breslow_likelihood:7.39557	validation_1-breslow_likelihood:6.05490
# [92]	validation_0-breslow_likelihood:7.39348	validation_1-breslow_likelihood:6.05248
# [91]	validation_0-breslow_likelihood:7.39545	validation_1-breslow_likelihood:6.05484
# [93]	validation_0-breslow_likelihood:7.39343	validation_1-breslow_likelihood:6.05251
# [92]	validation_0-breslow_likelihood:7.39511	validation_1-breslow_likelihood:6.05480
# [94]	validation_0-breslow_likelihood:7.39316	validation_1-breslow_likelihood:6.05242
# [93]	validation_0-breslow_likelihood:7.39511	validation_1-breslow_likelihood:6.05480
# [94]	validation_0-breslow_likelihood:7.39443	validation_1-breslow_likelihood:6.05442
# [0]	validation_0-breslow_likelihood:7.65507	validation_1-breslow_likelihood:6.24279
# [1]	validation_0-breslow_likelihood:7.65478	validation_1-breslow_likelihood:6.24276
# [2]	validation_0-breslow_likelihood:7.65399	validation_1-breslow_likelihood:6.24218
# [3]	validation_0-breslow_likelihood:7.65383	validation_1-breslow_likelihood:6.24229
# [4]	validation_0-breslow_likelihood:7.65342	validation_1-breslow_likelihood:6.24210
# [5]	validation_0-breslow_likelihood:7.65272	validation_1-breslow_likelihood:6.24170
# [6]	validation_0-breslow_likelihood:7.65240	validation_1-breslow_likelihood:6.24146
# [7]	validation_0-breslow_likelihood:7.65186	validation_1-breslow_likelihood:6.24110
# [8]	validation_0-breslow_likelihood:7.65137	validation_1-breslow_likelihood:6.24077
# [9]	validation_0-breslow_likelihood:7.65116	validation_1-breslow_likelihood:6.24078
# [10]	validation_0-breslow_likelihood:7.65094	validation_1-breslow_likelihood:6.24053
# [11]	validation_0-breslow_likelihood:7.65006	validation_1-breslow_likelihood:6.23999
# [12]	validation_0-breslow_likelihood:7.64956	validation_1-breslow_likelihood:6.23968
# [13]	validation_0-breslow_likelihood:7.64896	validation_1-breslow_likelihood:6.23926
# [14]	validation_0-breslow_likelihood:7.64863	validation_1-breslow_likelihood:6.23907
# [15]	validation_0-breslow_likelihood:7.64859	validation_1-breslow_likelihood:6.23909
# [16]	validation_0-breslow_likelihood:7.64820	validation_1-breslow_likelihood:6.23886
# [17]	validation_0-breslow_likelihood:7.64781	validation_1-breslow_likelihood:6.23861
# [18]	validation_0-breslow_likelihood:7.64747	validation_1-breslow_likelihood:6.23839
# [19]	validation_0-breslow_likelihood:7.64718	validation_1-breslow_likelihood:6.23839
# [20]	validation_0-breslow_likelihood:7.64698	validation_1-breslow_likelihood:6.23838
# [21]	validation_0-breslow_likelihood:7.64676	validation_1-breslow_likelihood:6.23831
# [22]	validation_0-breslow_likelihood:7.64620	validation_1-breslow_likelihood:6.23804
# [23]	validation_0-breslow_likelihood:7.64576	validation_1-breslow_likelihood:6.23777
# [24]	validation_0-breslow_likelihood:7.64557	validation_1-breslow_likelihood:6.23765
# [25]	validation_0-breslow_likelihood:7.64531	validation_1-breslow_likelihood:6.23752
# [26]	validation_0-breslow_likelihood:7.64529	validation_1-breslow_likelihood:6.23752
# [27]	validation_0-breslow_likelihood:7.64526	validation_1-breslow_likelihood:6.23751
# [28]	validation_0-breslow_likelihood:7.64523	validation_1-breslow_likelihood:6.23749
# [29]	validation_0-breslow_likelihood:7.64439	validation_1-breslow_likelihood:6.23710
# [30]	validation_0-breslow_likelihood:7.64398	validation_1-breslow_likelihood:6.23692
# [31]	validation_0-breslow_likelihood:7.64340	validation_1-breslow_likelihood:6.23665
# [32]	validation_0-breslow_likelihood:7.64336	validation_1-breslow_likelihood:6.23661
# [33]	validation_0-breslow_likelihood:7.64295	validation_1-breslow_likelihood:6.23634
# [34]	validation_0-breslow_likelihood:7.64259	validation_1-breslow_likelihood:6.23606
# [35]	validation_0-breslow_likelihood:7.64222	validation_1-breslow_likelihood:6.23583
# [36]	validation_0-breslow_likelihood:7.64206	validation_1-breslow_likelihood:6.23578
# [37]	validation_0-breslow_likelihood:7.64175	validation_1-breslow_likelihood:6.23588
# [38]	validation_0-breslow_likelihood:7.64158	validation_1-breslow_likelihood:6.23590
# [39]	validation_0-breslow_likelihood:7.64114	validation_1-breslow_likelihood:6.23573
# [40]	validation_0-breslow_likelihood:7.64070	validation_1-breslow_likelihood:6.23545
# [41]	validation_0-breslow_likelihood:7.64048	validation_1-breslow_likelihood:6.23536
# [42]	validation_0-breslow_likelihood:7.64026	validation_1-breslow_likelihood:6.23517
# [43]	validation_0-breslow_likelihood:7.63986	validation_1-breslow_likelihood:6.23514
# [44]	validation_0-breslow_likelihood:7.63953	validation_1-breslow_likelihood:6.23522
# [45]	validation_0-breslow_likelihood:7.63937	validation_1-breslow_likelihood:6.23517
# [46]	validation_0-breslow_likelihood:7.63890	validation_1-breslow_likelihood:6.23488
# [47]	validation_0-breslow_likelihood:7.63838	validation_1-breslow_likelihood:6.23458
# [48]	validation_0-breslow_likelihood:7.63802	validation_1-breslow_likelihood:6.23432
# [49]	validation_0-breslow_likelihood:7.63741	validation_1-breslow_likelihood:6.23410
# [50]	validation_0-breslow_likelihood:7.63725	validation_1-breslow_likelihood:6.23414
# [51]	validation_0-breslow_likelihood:7.63701	validation_1-breslow_likelihood:6.23419
# [52]	validation_0-breslow_likelihood:7.63670	validation_1-breslow_likelihood:6.23423
# [53]	validation_0-breslow_likelihood:7.63668	validation_1-breslow_likelihood:6.23422
# [54]	validation_0-breslow_likelihood:7.63666	validation_1-breslow_likelihood:6.23420
# [55]	validation_0-breslow_likelihood:7.63651	validation_1-breslow_likelihood:6.23409
# [56]	validation_0-breslow_likelihood:7.63649	validation_1-breslow_likelihood:6.23407
# [57]	validation_0-breslow_likelihood:7.63605	validation_1-breslow_likelihood:6.23386
# [58]	validation_0-breslow_likelihood:7.63586	validation_1-breslow_likelihood:6.23373
# [59]	validation_0-breslow_likelihood:7.63558	validation_1-breslow_likelihood:6.23356
# [60]	validation_0-breslow_likelihood:7.63547	validation_1-breslow_likelihood:6.23352
# [61]	validation_0-breslow_likelihood:7.63512	validation_1-breslow_likelihood:6.23333
# [62]	validation_0-breslow_likelihood:7.63458	validation_1-breslow_likelihood:6.23322
# [63]	validation_0-breslow_likelihood:7.63429	validation_1-breslow_likelihood:6.23300
# [64]	validation_0-breslow_likelihood:7.63392	validation_1-breslow_likelihood:6.23286
# [65]	validation_0-breslow_likelihood:7.63387	validation_1-breslow_likelihood:6.23288
# [66]	validation_0-breslow_likelihood:7.63355	validation_1-breslow_likelihood:6.23264
# [67]	validation_0-breslow_likelihood:7.63325	validation_1-breslow_likelihood:6.23246
# [68]	validation_0-breslow_likelihood:7.63284	validation_1-breslow_likelihood:6.23224
# [69]	validation_0-breslow_likelihood:7.63264	validation_1-breslow_likelihood:6.23221
# [70]	validation_0-breslow_likelihood:7.63249	validation_1-breslow_likelihood:6.23211
# [71]	validation_0-breslow_likelihood:7.63200	validation_1-breslow_likelihood:6.23196
# [72]	validation_0-breslow_likelihood:7.63186	validation_1-breslow_likelihood:6.23199
# [73]	validation_0-breslow_likelihood:7.63148	validation_1-breslow_likelihood:6.23171
# [74]	validation_0-breslow_likelihood:7.63105	validation_1-breslow_likelihood:6.23148
# [75]	validation_0-breslow_likelihood:7.63075	validation_1-breslow_likelihood:6.23131
# [76]	validation_0-breslow_likelihood:7.63028	validation_1-breslow_likelihood:6.23119
# [77]	validation_0-breslow_likelihood:7.63007	validation_1-breslow_likelihood:6.23105
# [78]	validation_0-breslow_likelihood:7.62955	validation_1-breslow_likelihood:6.23079
# [79]	validation_0-breslow_likelihood:7.62926	validation_1-breslow_likelihood:6.23066
# [80]	validation_0-breslow_likelihood:7.62914	validation_1-breslow_likelihood:6.23062
# [81]	validation_0-breslow_likelihood:7.62889	validation_1-breslow_likelihood:6.23046
# [82]	validation_0-breslow_likelihood:7.62882	validation_1-breslow_likelihood:6.23051
# [83]	validation_0-breslow_likelihood:7.62847	validation_1-breslow_likelihood:6.23036
# [84]	validation_0-breslow_likelihood:7.62832	validation_1-breslow_likelihood:6.23028
# [85]	validation_0-breslow_likelihood:7.62830	validation_1-breslow_likelihood:6.23031
# [86]	validation_0-breslow_likelihood:7.62799	validation_1-breslow_likelihood:6.23015
# [87]	validation_0-breslow_likelihood:7.62787	validation_1-breslow_likelihood:6.23002
# [88]	validation_0-breslow_likelihood:7.62745	validation_1-breslow_likelihood:6.22983
# [89]	validation_0-breslow_likelihood:7.62706	validation_1-breslow_likelihood:6.22970
# [90]	validation_0-breslow_likelihood:7.62673	validation_1-breslow_likelihood:6.22961
# [91]	validation_0-breslow_likelihood:7.62649	validation_1-breslow_likelihood:6.22947
# [92]	validation_0-breslow_likelihood:7.62624	validation_1-breslow_likelihood:6.22950
# [93]	validation_0-breslow_likelihood:7.62590	validation_1-breslow_likelihood:6.22935
# [94]	validation_0-breslow_likelihood:7.62552	validation_1-breslow_likelihood:6.22939
# Concordance Index 0.6070535214866692
# Integrated Brier Score: 0.20626273423092747
# durations 3.0 2029.0
# Concordance Index 0.6014809010312103
# Integrated Brier Score: 0.2065472139137903

# %% [markdown]
# ## TCGA Train, Test, Evaluation

# %%
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
'pca__n_components': [8, 10, 12, 14, 16]
}

# %%
cancer_types = ['BLCA',
    'BRCA',
    'HNSC',
    'KIRC',
    'LGG',
    'LIHC',
    'LUAD',
    'LUSC',
    'OV',
    'STAD']


for idx, cancer_type in enumerate(cancer_types):
    model = 'xgbsurv_breslow_'
    # get name of current dataset
    data = load_tcga(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", cancer_type=cancer_type, as_frame=True)
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()
    filename = data.filename
    dataset_name = filename.split('_')[0]
    X, y = sort_X_y_pandas(X, y)

    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            #(OneHotEncoder(sparse_output=False), make_column_selector(dtype_include=['category', 'object']))
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='breslow_objective',
        eval_metric='breslow_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    
    pipe = Pipeline([('scaler',ct),
                    ('pca', PCA()),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=2, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        print(X_train.shape, type(X_train))
        print(y_train.shape, type(y_train))
        print(X_test.shape, type(X_test))
        print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_breslow(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_breslow(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# Out:
# (324, 20531) <class 'pandas.core.frame.DataFrame'>
# (324,) <class 'pandas.core.series.Series'>
# (82, 20531) <class 'pandas.core.frame.DataFrame'>
# (82,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:4.23220	validation_1-breslow_likelihood:3.17639
# [1]	validation_0-breslow_likelihood:4.13138	validation_1-breslow_likelihood:3.12117
# [2]	validation_0-breslow_likelihood:4.10251	validation_1-breslow_likelihood:3.24152
# [3]	validation_0-breslow_likelihood:4.06283	validation_1-breslow_likelihood:3.27751
# [4]	validation_0-breslow_likelihood:3.96997	validation_1-breslow_likelihood:3.34330
# [5]	validation_0-breslow_likelihood:3.93729	validation_1-breslow_likelihood:3.36013
# [6]	validation_0-breslow_likelihood:3.89891	validation_1-breslow_likelihood:3.34272
# [7]	validation_0-breslow_likelihood:3.85069	validation_1-breslow_likelihood:3.43695
# [8]	validation_0-breslow_likelihood:3.79533	validation_1-breslow_likelihood:3.40617
# [9]	validation_0-breslow_likelihood:3.73514	validation_1-breslow_likelihood:3.58653
# [10]	validation_0-breslow_likelihood:3.69756	validation_1-breslow_likelihood:3.72883
# [11]	validation_0-breslow_likelihood:3.63982	validation_1-breslow_likelihood:3.74788
# [0]	validation_0-breslow_likelihood:4.32913	validation_1-breslow_likelihood:3.12371
# [1]	validation_0-breslow_likelihood:4.32394	validation_1-breslow_likelihood:3.11593
# [2]	validation_0-breslow_likelihood:4.30560	validation_1-breslow_likelihood:3.12006
# [3]	validation_0-breslow_likelihood:4.29616	validation_1-breslow_likelihood:3.11443
# [4]	validation_0-breslow_likelihood:4.28670	validation_1-breslow_likelihood:3.11369
# [5]	validation_0-breslow_likelihood:4.27172	validation_1-breslow_likelihood:3.10482
# [6]	validation_0-breslow_likelihood:4.25422	validation_1-breslow_likelihood:3.11640
# [7]	validation_0-breslow_likelihood:4.25451	validation_1-breslow_likelihood:3.11704
# [8]	validation_0-breslow_likelihood:4.24722	validation_1-breslow_likelihood:3.12738
# [9]	validation_0-breslow_likelihood:4.23966	validation_1-breslow_likelihood:3.13025
# [10]	validation_0-breslow_likelihood:4.23489	validation_1-breslow_likelihood:3.12720
# [11]	validation_0-breslow_likelihood:4.22330	validation_1-breslow_likelihood:3.13625
# [12]	validation_0-breslow_likelihood:4.20549	validation_1-breslow_likelihood:3.14221
# [13]	validation_0-breslow_likelihood:4.19745	validation_1-breslow_likelihood:3.13076
# [14]	validation_0-breslow_likelihood:4.18784	validation_1-breslow_likelihood:3.13210
# [15]	validation_0-breslow_likelihood:4.18198	validation_1-breslow_likelihood:3.13015
# [0]	validation_0-breslow_likelihood:4.10032	validation_1-breslow_likelihood:3.01642
# [1]	validation_0-breslow_likelihood:4.03685	validation_1-breslow_likelihood:3.08510
# [2]	validation_0-breslow_likelihood:3.96470	validation_1-breslow_likelihood:3.04959
# [3]	validation_0-breslow_likelihood:3.89980	validation_1-breslow_likelihood:3.10514
# [4]	validation_0-breslow_likelihood:3.85480	validation_1-breslow_likelihood:3.41186
# [5]	validation_0-breslow_likelihood:3.79870	validation_1-breslow_likelihood:3.34492
# [6]	validation_0-breslow_likelihood:3.76893	validation_1-breslow_likelihood:3.33139
# [7]	validation_0-breslow_likelihood:3.72994	validation_1-breslow_likelihood:3.30585
# [8]	validation_0-breslow_likelihood:3.69877	validation_1-breslow_likelihood:3.30672
# [9]	validation_0-breslow_likelihood:3.65063	validation_1-breslow_likelihood:3.22981
# [0]	validation_0-breslow_likelihood:4.25770	validation_1-breslow_likelihood:3.23887
# [1]	validation_0-breslow_likelihood:4.20034	validation_1-breslow_likelihood:3.29221
# [2]	validation_0-breslow_likelihood:4.18231	validation_1-breslow_likelihood:3.36097
# [3]	validation_0-breslow_likelihood:4.14546	validation_1-breslow_likelihood:3.22147
# [4]	validation_0-breslow_likelihood:4.11181	validation_1-breslow_likelihood:3.25860
# [5]	validation_0-breslow_likelihood:4.04637	validation_1-breslow_likelihood:3.28492
# [6]	validation_0-breslow_likelihood:4.00948	validation_1-breslow_likelihood:3.29724
# [7]	validation_0-breslow_likelihood:3.95433	validation_1-breslow_likelihood:3.29456
# [8]	validation_0-breslow_likelihood:3.92510	validation_1-breslow_likelihood:3.37934
# [9]	validation_0-breslow_likelihood:3.83893	validation_1-breslow_likelihood:3.46851
# [10]	validation_0-breslow_likelihood:3.77772	validation_1-breslow_likelihood:3.45156
# [11]	validation_0-breslow_likelihood:3.71749	validation_1-breslow_likelihood:3.40629
# [12]	validation_0-breslow_likelihood:3.66192	validation_1-breslow_likelihood:3.50114
# [13]	validation_0-breslow_likelihood:3.62311	validation_1-breslow_likelihood:3.40481
# [0]	validation_0-breslow_likelihood:4.35074	validation_1-breslow_likelihood:3.18599
# [1]	validation_0-breslow_likelihood:4.34374	validation_1-breslow_likelihood:3.18118
# [2]	validation_0-breslow_likelihood:4.33380	validation_1-breslow_likelihood:3.18251
# [3]	validation_0-breslow_likelihood:4.31919	validation_1-breslow_likelihood:3.16035
# [4]	validation_0-breslow_likelihood:4.30936	validation_1-breslow_likelihood:3.16007
# [5]	validation_0-breslow_likelihood:4.29776	validation_1-breslow_likelihood:3.16018
# [6]	validation_0-breslow_likelihood:4.28725	validation_1-breslow_likelihood:3.14946
# [7]	validation_0-breslow_likelihood:4.28055	validation_1-breslow_likelihood:3.14582
# [8]	validation_0-breslow_likelihood:4.26713	validation_1-breslow_likelihood:3.14354
# [9]	validation_0-breslow_likelihood:4.25373	validation_1-breslow_likelihood:3.13822
# [10]	validation_0-breslow_likelihood:4.24311	validation_1-breslow_likelihood:3.13337
# [11]	validation_0-breslow_likelihood:4.23947	validation_1-breslow_likelihood:3.13740
# [12]	validation_0-breslow_likelihood:4.23192	validation_1-breslow_likelihood:3.12832
# [13]	validation_0-breslow_likelihood:4.22369	validation_1-breslow_likelihood:3.13145
# [14]	validation_0-breslow_likelihood:4.21590	validation_1-breslow_likelihood:3.11539
# [15]	validation_0-breslow_likelihood:4.20255	validation_1-breslow_likelihood:3.11449
# [16]	validation_0-breslow_likelihood:4.19472	validation_1-breslow_likelihood:3.11489
# [17]	validation_0-breslow_likelihood:4.18972	validation_1-breslow_likelihood:3.12778
# [18]	validation_0-breslow_likelihood:4.18199	validation_1-breslow_likelihood:3.11441
# [0]	validation_0-breslow_likelihood:4.28530	validation_1-breslow_likelihood:3.01357
# [19]	validation_0-breslow_likelihood:4.17936	validation_1-breslow_likelihood:3.11130
# [1]	validation_0-breslow_likelihood:4.15855	validation_1-breslow_likelihood:3.01030
# [20]	validation_0-breslow_likelihood:4.17038	validation_1-breslow_likelihood:3.11118
# [2]	validation_0-breslow_likelihood:4.08345	validation_1-breslow_likelihood:3.03330
# [21]	validation_0-breslow_likelihood:4.16148	validation_1-breslow_likelihood:3.10690
# [3]	validation_0-breslow_likelihood:4.06188	validation_1-breslow_likelihood:3.00701
# [4]	validation_0-breslow_likelihood:4.00700	validation_1-breslow_likelihood:2.93587
# [22]	validation_0-breslow_likelihood:4.15533	validation_1-breslow_likelihood:3.10821
# [5]	validation_0-breslow_likelihood:3.96907	validation_1-breslow_likelihood:2.97038
# [23]	validation_0-breslow_likelihood:4.14837	validation_1-breslow_likelihood:3.09699
# [6]	validation_0-breslow_likelihood:3.88600	validation_1-breslow_likelihood:2.90089
# [24]	validation_0-breslow_likelihood:4.13941	validation_1-breslow_likelihood:3.09231
# [7]	validation_0-breslow_likelihood:3.83002	validation_1-breslow_likelihood:2.87621
# [25]	validation_0-breslow_likelihood:4.12968	validation_1-breslow_likelihood:3.08914
# [8]	validation_0-breslow_likelihood:3.78183	validation_1-breslow_likelihood:2.82948
# [26]	validation_0-breslow_likelihood:4.12161	validation_1-breslow_likelihood:3.10115
# [9]	validation_0-breslow_likelihood:3.76557	validation_1-breslow_likelihood:2.80448
# [10]	validation_0-breslow_likelihood:3.71130	validation_1-breslow_likelihood:2.81057
# [27]	validation_0-breslow_likelihood:4.10985	validation_1-breslow_likelihood:3.08982
# [11]	validation_0-breslow_likelihood:3.63910	validation_1-breslow_likelihood:2.90423
# [28]	validation_0-breslow_likelihood:4.10614	validation_1-breslow_likelihood:3.09462
# [12]	validation_0-breslow_likelihood:3.57541	validation_1-breslow_likelihood:2.96574
# [29]	validation_0-breslow_likelihood:4.09751	validation_1-breslow_likelihood:3.07648
# [13]	validation_0-breslow_likelihood:3.56169	validation_1-breslow_likelihood:3.07660
# [30]	validation_0-breslow_likelihood:4.08812	validation_1-breslow_likelihood:3.08291
# [14]	validation_0-breslow_likelihood:3.53429	validation_1-breslow_likelihood:3.20277
# [31]	validation_0-breslow_likelihood:4.08542	validation_1-breslow_likelihood:3.08201
# [15]	validation_0-breslow_likelihood:3.49911	validation_1-breslow_likelihood:3.20704
# [32]	validation_0-breslow_likelihood:4.07990	validation_1-breslow_likelihood:3.08731
# [16]	validation_0-breslow_likelihood:3.46676	validation_1-breslow_likelihood:3.21555
# [33]	validation_0-breslow_likelihood:4.07566	validation_1-breslow_likelihood:3.08981
# [17]	validation_0-breslow_likelihood:3.44622	validation_1-breslow_likelihood:3.27240
# [34]	validation_0-breslow_likelihood:4.06723	validation_1-breslow_likelihood:3.09156
# [18]	validation_0-breslow_likelihood:3.36716	validation_1-breslow_likelihood:3.19462
# [0]	validation_0-breslow_likelihood:4.34531	validation_1-breslow_likelihood:2.97060
# [0]	validation_0-breslow_likelihood:4.34822	validation_1-breslow_likelihood:2.96419
# [1]	validation_0-breslow_likelihood:4.32754	validation_1-breslow_likelihood:2.98990
# [1]	validation_0-breslow_likelihood:4.33593	validation_1-breslow_likelihood:2.96655
# [2]	validation_0-breslow_likelihood:4.31949	validation_1-breslow_likelihood:2.99780
# [3]	validation_0-breslow_likelihood:4.30616	validation_1-breslow_likelihood:2.98797
# [2]	validation_0-breslow_likelihood:4.32357	validation_1-breslow_likelihood:2.95417
# [4]	validation_0-breslow_likelihood:4.29306	validation_1-breslow_likelihood:2.98408
# [3]	validation_0-breslow_likelihood:4.31890	validation_1-breslow_likelihood:2.94618
# [5]	validation_0-breslow_likelihood:4.27732	validation_1-breslow_likelihood:2.98381
# [4]	validation_0-breslow_likelihood:4.30827	validation_1-breslow_likelihood:2.94851
# [6]	validation_0-breslow_likelihood:4.25816	validation_1-breslow_likelihood:2.97623
# [5]	validation_0-breslow_likelihood:4.29802	validation_1-breslow_likelihood:2.95642
# [7]	validation_0-breslow_likelihood:4.25306	validation_1-breslow_likelihood:2.96584
# [6]	validation_0-breslow_likelihood:4.27659	validation_1-breslow_likelihood:2.94551
# [8]	validation_0-breslow_likelihood:4.24207	validation_1-breslow_likelihood:2.96294
# [7]	validation_0-breslow_likelihood:4.26293	validation_1-breslow_likelihood:2.94477
# [9]	validation_0-breslow_likelihood:4.22162	validation_1-breslow_likelihood:2.96258
# [8]	validation_0-breslow_likelihood:4.25855	validation_1-breslow_likelihood:2.94506
# [10]	validation_0-breslow_likelihood:4.21467	validation_1-breslow_likelihood:2.96781
# [9]	validation_0-breslow_likelihood:4.24818	validation_1-breslow_likelihood:2.93583
# [11]	validation_0-breslow_likelihood:4.21105	validation_1-breslow_likelihood:2.96377
# [10]	validation_0-breslow_likelihood:4.24309	validation_1-breslow_likelihood:2.91921
# [12]	validation_0-breslow_likelihood:4.20483	validation_1-breslow_likelihood:2.96970
# [11]	validation_0-breslow_likelihood:4.23569	validation_1-breslow_likelihood:2.92234
# [13]	validation_0-breslow_likelihood:4.19058	validation_1-breslow_likelihood:2.96880
# [12]	validation_0-breslow_likelihood:4.22981	validation_1-breslow_likelihood:2.92926
# [14]	validation_0-breslow_likelihood:4.18980	validation_1-breslow_likelihood:2.96648
# [13]	validation_0-breslow_likelihood:4.22964	validation_1-breslow_likelihood:2.92784
# [15]	validation_0-breslow_likelihood:4.18301	validation_1-breslow_likelihood:2.94884
# [14]	validation_0-breslow_likelihood:4.21898	validation_1-breslow_likelihood:2.91995
# [16]	validation_0-breslow_likelihood:4.17600	validation_1-breslow_likelihood:2.94251
# [15]	validation_0-breslow_likelihood:4.21461	validation_1-breslow_likelihood:2.93206
# [17]	validation_0-breslow_likelihood:4.16027	validation_1-breslow_likelihood:2.93920
# [16]	validation_0-breslow_likelihood:4.20489	validation_1-breslow_likelihood:2.92900
# [18]	validation_0-breslow_likelihood:4.15494	validation_1-breslow_likelihood:2.92953
# [17]	validation_0-breslow_likelihood:4.19677	validation_1-breslow_likelihood:2.93464
# [0]	validation_0-breslow_likelihood:4.26174	validation_1-breslow_likelihood:2.94741
# [19]	validation_0-breslow_likelihood:4.13964	validation_1-breslow_likelihood:2.92956
# [18]	validation_0-breslow_likelihood:4.19032	validation_1-breslow_likelihood:2.94052
# [20]	validation_0-breslow_likelihood:4.12724	validation_1-breslow_likelihood:2.93008
# [19]	validation_0-breslow_likelihood:4.18357	validation_1-breslow_likelihood:2.94365
# [21]	validation_0-breslow_likelihood:4.11529	validation_1-breslow_likelihood:2.93665
# [1]	validation_0-breslow_likelihood:4.25468	validation_1-breslow_likelihood:2.95180
# [22]	validation_0-breslow_likelihood:4.10903	validation_1-breslow_likelihood:2.93977
# [23]	validation_0-breslow_likelihood:4.09851	validation_1-breslow_likelihood:2.92995
# [2]	validation_0-breslow_likelihood:4.24725	validation_1-breslow_likelihood:2.94944
# [24]	validation_0-breslow_likelihood:4.09210	validation_1-breslow_likelihood:2.92746
# [25]	validation_0-breslow_likelihood:4.08683	validation_1-breslow_likelihood:2.92414
# [26]	validation_0-breslow_likelihood:4.07737	validation_1-breslow_likelihood:2.93961
# [3]	validation_0-breslow_likelihood:4.23332	validation_1-breslow_likelihood:2.95820
# [27]	validation_0-breslow_likelihood:4.06768	validation_1-breslow_likelihood:2.93491
# [4]	validation_0-breslow_likelihood:4.22051	validation_1-breslow_likelihood:2.96520
# [28]	validation_0-breslow_likelihood:4.05605	validation_1-breslow_likelihood:2.93268
# [5]	validation_0-breslow_likelihood:4.20828	validation_1-breslow_likelihood:2.94385
# [29]	validation_0-breslow_likelihood:4.04824	validation_1-breslow_likelihood:2.92274
# [6]	validation_0-breslow_likelihood:4.19984	validation_1-breslow_likelihood:2.94593
# [30]	validation_0-breslow_likelihood:4.04372	validation_1-breslow_likelihood:2.92316
# [7]	validation_0-breslow_likelihood:4.19205	validation_1-breslow_likelihood:2.94692
# [31]	validation_0-breslow_likelihood:4.03747	validation_1-breslow_likelihood:2.91475
# [8]	validation_0-breslow_likelihood:4.17471	validation_1-breslow_likelihood:2.95805
# [32]	validation_0-breslow_likelihood:4.03579	validation_1-breslow_likelihood:2.91266
# [9]	validation_0-breslow_likelihood:4.16366	validation_1-breslow_likelihood:2.95595
# [33]	validation_0-breslow_likelihood:4.02765	validation_1-breslow_likelihood:2.90933
# [34]	validation_0-breslow_likelihood:4.02281	validation_1-breslow_likelihood:2.90106
# [10]	validation_0-breslow_likelihood:4.15240	validation_1-breslow_likelihood:2.95149
# [11]	validation_0-breslow_likelihood:4.14083	validation_1-breslow_likelihood:2.96312
# [12]	validation_0-breslow_likelihood:4.12958	validation_1-breslow_likelihood:2.95579
# [13]	validation_0-breslow_likelihood:4.11639	validation_1-breslow_likelihood:2.94996
# [14]	validation_0-breslow_likelihood:4.11282	validation_1-breslow_likelihood:2.95175
# [0]	validation_0-breslow_likelihood:4.28368	validation_1-breslow_likelihood:3.06222
# [1]	validation_0-breslow_likelihood:4.20442	validation_1-breslow_likelihood:3.07325
# [2]	validation_0-breslow_likelihood:4.16563	validation_1-breslow_likelihood:3.07975
# [3]	validation_0-breslow_likelihood:4.04248	validation_1-breslow_likelihood:3.07787
# [4]	validation_0-breslow_likelihood:3.91372	validation_1-breslow_likelihood:3.21752
# [5]	validation_0-breslow_likelihood:3.88991	validation_1-breslow_likelihood:3.32314
# [6]	validation_0-breslow_likelihood:3.85688	validation_1-breslow_likelihood:3.51490
# [7]	validation_0-breslow_likelihood:3.77102	validation_1-breslow_likelihood:3.60375
# [8]	validation_0-breslow_likelihood:3.72167	validation_1-breslow_likelihood:3.43996
# [9]	validation_0-breslow_likelihood:3.65398	validation_1-breslow_likelihood:3.63083
# [10]	validation_0-breslow_likelihood:3.61915	validation_1-breslow_likelihood:3.65721
# [0]	validation_0-breslow_likelihood:4.68746	validation_1-breslow_likelihood:3.25535
# [1]	validation_0-breslow_likelihood:4.68233	validation_1-breslow_likelihood:3.26250
# [2]	validation_0-breslow_likelihood:4.67031	validation_1-breslow_likelihood:3.27128
# [3]	validation_0-breslow_likelihood:4.66177	validation_1-breslow_likelihood:3.27886
# [4]	validation_0-breslow_likelihood:4.64757	validation_1-breslow_likelihood:3.28192
# [5]	validation_0-breslow_likelihood:4.64637	validation_1-breslow_likelihood:3.29934
# [6]	validation_0-breslow_likelihood:4.64307	validation_1-breslow_likelihood:3.29262
# [7]	validation_0-breslow_likelihood:4.62948	validation_1-breslow_likelihood:3.28937
# [8]	validation_0-breslow_likelihood:4.61836	validation_1-breslow_likelihood:3.29534
# [9]	validation_0-breslow_likelihood:4.60949	validation_1-breslow_likelihood:3.28867
# [10]	validation_0-breslow_likelihood:4.59997	validation_1-breslow_likelihood:3.29299
# Concordance Index 0.5425347542313507
# Integrated Brier Score: 0.2098212904699255
# durations 17.0 4343.0
# Concordance Index 0.4154696132596685
# Integrated Brier Score: 0.2234261585689805
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:4.27994	validation_1-breslow_likelihood:3.02919
# [1]	validation_0-breslow_likelihood:4.22051	validation_1-breslow_likelihood:3.02435
# [2]	validation_0-breslow_likelihood:4.20428	validation_1-breslow_likelihood:3.04306
# [3]	validation_0-breslow_likelihood:4.19342	validation_1-breslow_likelihood:3.10195
# [4]	validation_0-breslow_likelihood:4.16392	validation_1-breslow_likelihood:3.09541
# [5]	validation_0-breslow_likelihood:4.16526	validation_1-breslow_likelihood:3.09016
# [6]	validation_0-breslow_likelihood:4.14390	validation_1-breslow_likelihood:3.06664
# [7]	validation_0-breslow_likelihood:4.12527	validation_1-breslow_likelihood:3.10356
# [8]	validation_0-breslow_likelihood:4.08450	validation_1-breslow_likelihood:3.14363
# [9]	validation_0-breslow_likelihood:4.05814	validation_1-breslow_likelihood:3.17082
# [10]	validation_0-breslow_likelihood:4.04245	validation_1-breslow_likelihood:3.15913
# [11]	validation_0-breslow_likelihood:4.02887	validation_1-breslow_likelihood:3.18548
# [0]	validation_0-breslow_likelihood:4.44883	validation_1-breslow_likelihood:3.03867
# [1]	validation_0-breslow_likelihood:4.44766	validation_1-breslow_likelihood:3.03844
# [2]	validation_0-breslow_likelihood:4.44644	validation_1-breslow_likelihood:3.03816
# [3]	validation_0-breslow_likelihood:4.44546	validation_1-breslow_likelihood:3.03800
# [4]	validation_0-breslow_likelihood:4.44417	validation_1-breslow_likelihood:3.03761
# [5]	validation_0-breslow_likelihood:4.44303	validation_1-breslow_likelihood:3.03712
# [6]	validation_0-breslow_likelihood:4.44188	validation_1-breslow_likelihood:3.03715
# [7]	validation_0-breslow_likelihood:4.44070	validation_1-breslow_likelihood:3.03728
# [8]	validation_0-breslow_likelihood:4.43955	validation_1-breslow_likelihood:3.03707
# [9]	validation_0-breslow_likelihood:4.43835	validation_1-breslow_likelihood:3.03645
# [10]	validation_0-breslow_likelihood:4.43721	validation_1-breslow_likelihood:3.03599
# [11]	validation_0-breslow_likelihood:4.43610	validation_1-breslow_likelihood:3.03588
# [12]	validation_0-breslow_likelihood:4.43493	validation_1-breslow_likelihood:3.03571
# [13]	validation_0-breslow_likelihood:4.43364	validation_1-breslow_likelihood:3.03584
# [14]	validation_0-breslow_likelihood:4.43243	validation_1-breslow_likelihood:3.03587
# [15]	validation_0-breslow_likelihood:4.43113	validation_1-breslow_likelihood:3.03572
# [16]	validation_0-breslow_likelihood:4.42998	validation_1-breslow_likelihood:3.03538
# [17]	validation_0-breslow_likelihood:4.42879	validation_1-breslow_likelihood:3.03507
# [18]	validation_0-breslow_likelihood:4.42764	validation_1-breslow_likelihood:3.03522
# [19]	validation_0-breslow_likelihood:4.42648	validation_1-breslow_likelihood:3.03499
# [20]	validation_0-breslow_likelihood:4.42530	validation_1-breslow_likelihood:3.03510
# [21]	validation_0-breslow_likelihood:4.42402	validation_1-breslow_likelihood:3.03514
# [22]	validation_0-breslow_likelihood:4.42276	validation_1-breslow_likelihood:3.03498
# [23]	validation_0-breslow_likelihood:4.42160	validation_1-breslow_likelihood:3.03477
# [24]	validation_0-breslow_likelihood:4.42043	validation_1-breslow_likelihood:3.03482
# [25]	validation_0-breslow_likelihood:4.41909	validation_1-breslow_likelihood:3.03457
# [26]	validation_0-breslow_likelihood:4.41802	validation_1-breslow_likelihood:3.03423
# [27]	validation_0-breslow_likelihood:4.41686	validation_1-breslow_likelihood:3.03416
# [28]	validation_0-breslow_likelihood:4.41560	validation_1-breslow_likelihood:3.03390
# [29]	validation_0-breslow_likelihood:4.41456	validation_1-breslow_likelihood:3.03369
# [0]	validation_0-breslow_likelihood:4.42778	validation_1-breslow_likelihood:3.19094
# [1]	validation_0-breslow_likelihood:4.37959	validation_1-breslow_likelihood:3.13508
# [2]	validation_0-breslow_likelihood:4.33739	validation_1-breslow_likelihood:3.14411
# [3]	validation_0-breslow_likelihood:4.31684	validation_1-breslow_likelihood:3.12455
# [4]	validation_0-breslow_likelihood:4.30323	validation_1-breslow_likelihood:3.20323
# [5]	validation_0-breslow_likelihood:4.28262	validation_1-breslow_likelihood:3.17424
# [6]	validation_0-breslow_likelihood:4.26971	validation_1-breslow_likelihood:3.13824
# [7]	validation_0-breslow_likelihood:4.23322	validation_1-breslow_likelihood:3.14521
# [8]	validation_0-breslow_likelihood:4.23334	validation_1-breslow_likelihood:3.16572
# [0]	validation_0-breslow_likelihood:4.32774	validation_1-breslow_likelihood:3.02108
# [9]	validation_0-breslow_likelihood:4.21803	validation_1-breslow_likelihood:3.19635
# [10]	validation_0-breslow_likelihood:4.21050	validation_1-breslow_likelihood:3.20960
# [1]	validation_0-breslow_likelihood:4.32661	validation_1-breslow_likelihood:3.02087
# [11]	validation_0-breslow_likelihood:4.19703	validation_1-breslow_likelihood:3.15431
# [12]	validation_0-breslow_likelihood:4.17623	validation_1-breslow_likelihood:3.17842
# [2]	validation_0-breslow_likelihood:4.32544	validation_1-breslow_likelihood:3.02123
# [13]	validation_0-breslow_likelihood:4.14600	validation_1-breslow_likelihood:3.11302
# [3]	validation_0-breslow_likelihood:4.32438	validation_1-breslow_likelihood:3.02131
# [14]	validation_0-breslow_likelihood:4.12875	validation_1-breslow_likelihood:3.05421
# [15]	validation_0-breslow_likelihood:4.12423	validation_1-breslow_likelihood:3.05933
# [4]	validation_0-breslow_likelihood:4.32331	validation_1-breslow_likelihood:3.02104
# [16]	validation_0-breslow_likelihood:4.10465	validation_1-breslow_likelihood:3.02937
# [17]	validation_0-breslow_likelihood:4.09987	validation_1-breslow_likelihood:3.01124
# [5]	validation_0-breslow_likelihood:4.32225	validation_1-breslow_likelihood:3.02063
# [18]	validation_0-breslow_likelihood:4.08986	validation_1-breslow_likelihood:3.02111
# [6]	validation_0-breslow_likelihood:4.32116	validation_1-breslow_likelihood:3.02047
# [19]	validation_0-breslow_likelihood:4.09121	validation_1-breslow_likelihood:2.99966
# [20]	validation_0-breslow_likelihood:4.05441	validation_1-breslow_likelihood:3.03259
# [7]	validation_0-breslow_likelihood:4.31999	validation_1-breslow_likelihood:3.02002
# [21]	validation_0-breslow_likelihood:4.04988	validation_1-breslow_likelihood:3.07498
# [22]	validation_0-breslow_likelihood:4.02094	validation_1-breslow_likelihood:3.05320
# [8]	validation_0-breslow_likelihood:4.31884	validation_1-breslow_likelihood:3.01984
# [23]	validation_0-breslow_likelihood:4.00878	validation_1-breslow_likelihood:3.01799
# [9]	validation_0-breslow_likelihood:4.31765	validation_1-breslow_likelihood:3.01955
# [24]	validation_0-breslow_likelihood:3.98923	validation_1-breslow_likelihood:3.00346
# [25]	validation_0-breslow_likelihood:3.97504	validation_1-breslow_likelihood:3.00475
# [10]	validation_0-breslow_likelihood:4.31668	validation_1-breslow_likelihood:3.01928
# [26]	validation_0-breslow_likelihood:3.96658	validation_1-breslow_likelihood:3.02038
# [11]	validation_0-breslow_likelihood:4.31562	validation_1-breslow_likelihood:3.01914
# [27]	validation_0-breslow_likelihood:3.95526	validation_1-breslow_likelihood:3.04431
# [28]	validation_0-breslow_likelihood:3.94857	validation_1-breslow_likelihood:3.02207
# [29]	validation_0-breslow_likelihood:3.93268	validation_1-breslow_likelihood:3.02770
# [12]	validation_0-breslow_likelihood:4.31460	validation_1-breslow_likelihood:3.01873
# [13]	validation_0-breslow_likelihood:4.31352	validation_1-breslow_likelihood:3.01876
# [14]	validation_0-breslow_likelihood:4.31242	validation_1-breslow_likelihood:3.01838
# [15]	validation_0-breslow_likelihood:4.31121	validation_1-breslow_likelihood:3.01871
# [16]	validation_0-breslow_likelihood:4.31016	validation_1-breslow_likelihood:3.01875
# [17]	validation_0-breslow_likelihood:4.30907	validation_1-breslow_likelihood:3.01851
# [18]	validation_0-breslow_likelihood:4.30814	validation_1-breslow_likelihood:3.01832
# [19]	validation_0-breslow_likelihood:4.30702	validation_1-breslow_likelihood:3.01813
# [20]	validation_0-breslow_likelihood:4.30597	validation_1-breslow_likelihood:3.01811
# [21]	validation_0-breslow_likelihood:4.30482	validation_1-breslow_likelihood:3.01836
# [22]	validation_0-breslow_likelihood:4.30379	validation_1-breslow_likelihood:3.01828
# [23]	validation_0-breslow_likelihood:4.30265	validation_1-breslow_likelihood:3.01813
# [24]	validation_0-breslow_likelihood:4.30159	validation_1-breslow_likelihood:3.01784
# [25]	validation_0-breslow_likelihood:4.30052	validation_1-breslow_likelihood:3.01802
# [26]	validation_0-breslow_likelihood:4.29939	validation_1-breslow_likelihood:3.01829
# [27]	validation_0-breslow_likelihood:4.29837	validation_1-breslow_likelihood:3.01819
# [28]	validation_0-breslow_likelihood:4.29733	validation_1-breslow_likelihood:3.01824
# [29]	validation_0-breslow_likelihood:4.29622	validation_1-breslow_likelihood:3.01820
# [0]	validation_0-breslow_likelihood:4.32765	validation_1-breslow_likelihood:3.00918
# [0]	validation_0-breslow_likelihood:4.27649	validation_1-breslow_likelihood:2.94974
# [0]	validation_0-breslow_likelihood:4.47208	validation_1-breslow_likelihood:3.18182
# [1]	validation_0-breslow_likelihood:4.47102	validation_1-breslow_likelihood:3.18141
# [1]	validation_0-breslow_likelihood:4.32648	validation_1-breslow_likelihood:3.00871
# [1]	validation_0-breslow_likelihood:4.25478	validation_1-breslow_likelihood:2.95087
# [2]	validation_0-breslow_likelihood:4.46985	validation_1-breslow_likelihood:3.18117
# [2]	validation_0-breslow_likelihood:4.24179	validation_1-breslow_likelihood:2.93897
# [2]	validation_0-breslow_likelihood:4.32529	validation_1-breslow_likelihood:3.00834
# [3]	validation_0-breslow_likelihood:4.21540	validation_1-breslow_likelihood:2.93084
# [3]	validation_0-breslow_likelihood:4.46853	validation_1-breslow_likelihood:3.18126
# [4]	validation_0-breslow_likelihood:4.19858	validation_1-breslow_likelihood:2.93373
# [3]	validation_0-breslow_likelihood:4.32419	validation_1-breslow_likelihood:3.00809
# [5]	validation_0-breslow_likelihood:4.15718	validation_1-breslow_likelihood:2.98509
# [6]	validation_0-breslow_likelihood:4.13942	validation_1-breslow_likelihood:2.98365
# [4]	validation_0-breslow_likelihood:4.32300	validation_1-breslow_likelihood:3.00812
# [7]	validation_0-breslow_likelihood:4.09595	validation_1-breslow_likelihood:3.08508
# [5]	validation_0-breslow_likelihood:4.32195	validation_1-breslow_likelihood:3.00813
# [8]	validation_0-breslow_likelihood:4.05479	validation_1-breslow_likelihood:3.09191
# [9]	validation_0-breslow_likelihood:4.04262	validation_1-breslow_likelihood:3.11822
# [6]	validation_0-breslow_likelihood:4.32076	validation_1-breslow_likelihood:3.00793
# [10]	validation_0-breslow_likelihood:4.03900	validation_1-breslow_likelihood:3.11798
# [7]	validation_0-breslow_likelihood:4.31951	validation_1-breslow_likelihood:3.00754
# [11]	validation_0-breslow_likelihood:4.03460	validation_1-breslow_likelihood:3.12534
# [12]	validation_0-breslow_likelihood:4.02847	validation_1-breslow_likelihood:3.10928
# [8]	validation_0-breslow_likelihood:4.31846	validation_1-breslow_likelihood:3.00709
# [4]	validation_0-breslow_likelihood:4.46737	validation_1-breslow_likelihood:3.18099
# [5]	validation_0-breslow_likelihood:4.46629	validation_1-breslow_likelihood:3.18051
# [9]	validation_0-breslow_likelihood:4.31730	validation_1-breslow_likelihood:3.00662
# [6]	validation_0-breslow_likelihood:4.46514	validation_1-breslow_likelihood:3.17998
# [13]	validation_0-breslow_likelihood:4.01469	validation_1-breslow_likelihood:3.12968
# [10]	validation_0-breslow_likelihood:4.31597	validation_1-breslow_likelihood:3.00663
# [7]	validation_0-breslow_likelihood:4.46382	validation_1-breslow_likelihood:3.17926
# [11]	validation_0-breslow_likelihood:4.31494	validation_1-breslow_likelihood:3.00635
# [8]	validation_0-breslow_likelihood:4.46272	validation_1-breslow_likelihood:3.17902
# [12]	validation_0-breslow_likelihood:4.31382	validation_1-breslow_likelihood:3.00606
# [9]	validation_0-breslow_likelihood:4.46166	validation_1-breslow_likelihood:3.17843
# [13]	validation_0-breslow_likelihood:4.31261	validation_1-breslow_likelihood:3.00599
# [10]	validation_0-breslow_likelihood:4.46050	validation_1-breslow_likelihood:3.17810
# [14]	validation_0-breslow_likelihood:4.31152	validation_1-breslow_likelihood:3.00574
# [11]	validation_0-breslow_likelihood:4.45934	validation_1-breslow_likelihood:3.17816
# [15]	validation_0-breslow_likelihood:4.31031	validation_1-breslow_likelihood:3.00542
# [12]	validation_0-breslow_likelihood:4.45812	validation_1-breslow_likelihood:3.17795
# [16]	validation_0-breslow_likelihood:4.30916	validation_1-breslow_likelihood:3.00535
# [13]	validation_0-breslow_likelihood:4.45698	validation_1-breslow_likelihood:3.17781
# [17]	validation_0-breslow_likelihood:4.30806	validation_1-breslow_likelihood:3.00520
# [14]	validation_0-breslow_likelihood:4.45585	validation_1-breslow_likelihood:3.17737
# [18]	validation_0-breslow_likelihood:4.30698	validation_1-breslow_likelihood:3.00481
# [15]	validation_0-breslow_likelihood:4.45468	validation_1-breslow_likelihood:3.17686
# [19]	validation_0-breslow_likelihood:4.30574	validation_1-breslow_likelihood:3.00468
# [16]	validation_0-breslow_likelihood:4.45347	validation_1-breslow_likelihood:3.17638
# [20]	validation_0-breslow_likelihood:4.30466	validation_1-breslow_likelihood:3.00462
# [17]	validation_0-breslow_likelihood:4.45224	validation_1-breslow_likelihood:3.17639
# [21]	validation_0-breslow_likelihood:4.30353	validation_1-breslow_likelihood:3.00450
# [18]	validation_0-breslow_likelihood:4.45099	validation_1-breslow_likelihood:3.17647
# [22]	validation_0-breslow_likelihood:4.30239	validation_1-breslow_likelihood:3.00413
# [19]	validation_0-breslow_likelihood:4.44993	validation_1-breslow_likelihood:3.17585
# [23]	validation_0-breslow_likelihood:4.30133	validation_1-breslow_likelihood:3.00413
# [20]	validation_0-breslow_likelihood:4.44877	validation_1-breslow_likelihood:3.17565
# [24]	validation_0-breslow_likelihood:4.30020	validation_1-breslow_likelihood:3.00428
# [21]	validation_0-breslow_likelihood:4.44755	validation_1-breslow_likelihood:3.17554
# [25]	validation_0-breslow_likelihood:4.29894	validation_1-breslow_likelihood:3.00425
# [22]	validation_0-breslow_likelihood:4.44640	validation_1-breslow_likelihood:3.17581
# [26]	validation_0-breslow_likelihood:4.29781	validation_1-breslow_likelihood:3.00422
# [23]	validation_0-breslow_likelihood:4.44518	validation_1-breslow_likelihood:3.17582
# [27]	validation_0-breslow_likelihood:4.29673	validation_1-breslow_likelihood:3.00414
# [28]	validation_0-breslow_likelihood:4.29553	validation_1-breslow_likelihood:3.00366
# [24]	validation_0-breslow_likelihood:4.44414	validation_1-breslow_likelihood:3.17563
# [25]	validation_0-breslow_likelihood:4.44302	validation_1-breslow_likelihood:3.17587
# [26]	validation_0-breslow_likelihood:4.44171	validation_1-breslow_likelihood:3.17555
# [27]	validation_0-breslow_likelihood:4.44053	validation_1-breslow_likelihood:3.17543
# [28]	validation_0-breslow_likelihood:4.43938	validation_1-breslow_likelihood:3.17544
# [29]	validation_0-breslow_likelihood:4.43821	validation_1-breslow_likelihood:3.17479
# [29]	validation_0-breslow_likelihood:4.29447	validation_1-breslow_likelihood:3.00334
# [0]	validation_0-breslow_likelihood:4.33928	validation_1-breslow_likelihood:3.22086
# [1]	validation_0-breslow_likelihood:4.33817	validation_1-breslow_likelihood:3.22057
# [2]	validation_0-breslow_likelihood:4.33704	validation_1-breslow_likelihood:3.22013
# [3]	validation_0-breslow_likelihood:4.33591	validation_1-breslow_likelihood:3.21990
# [4]	validation_0-breslow_likelihood:4.33476	validation_1-breslow_likelihood:3.22006
# [5]	validation_0-breslow_likelihood:4.33354	validation_1-breslow_likelihood:3.21956
# [6]	validation_0-breslow_likelihood:4.33241	validation_1-breslow_likelihood:3.21928
# [7]	validation_0-breslow_likelihood:4.33117	validation_1-breslow_likelihood:3.21919
# [8]	validation_0-breslow_likelihood:4.33003	validation_1-breslow_likelihood:3.21946
# [9]	validation_0-breslow_likelihood:4.32880	validation_1-breslow_likelihood:3.21937
# [10]	validation_0-breslow_likelihood:4.32770	validation_1-breslow_likelihood:3.21936
# [11]	validation_0-breslow_likelihood:4.32654	validation_1-breslow_likelihood:3.21906
# [12]	validation_0-breslow_likelihood:4.32532	validation_1-breslow_likelihood:3.21860
# [13]	validation_0-breslow_likelihood:4.32414	validation_1-breslow_likelihood:3.21836
# [0]	validation_0-breslow_likelihood:4.41269	validation_1-breslow_likelihood:2.99066
# [14]	validation_0-breslow_likelihood:4.32314	validation_1-breslow_likelihood:3.21848
# [1]	validation_0-breslow_likelihood:4.38619	validation_1-breslow_likelihood:3.00452
# [2]	validation_0-breslow_likelihood:4.36877	validation_1-breslow_likelihood:2.98662
# [15]	validation_0-breslow_likelihood:4.32196	validation_1-breslow_likelihood:3.21812
# [3]	validation_0-breslow_likelihood:4.36300	validation_1-breslow_likelihood:2.99528
# [16]	validation_0-breslow_likelihood:4.32081	validation_1-breslow_likelihood:3.21794
# [4]	validation_0-breslow_likelihood:4.33585	validation_1-breslow_likelihood:3.02567
# [5]	validation_0-breslow_likelihood:4.28896	validation_1-breslow_likelihood:2.97180
# [17]	validation_0-breslow_likelihood:4.31972	validation_1-breslow_likelihood:3.21772
# [6]	validation_0-breslow_likelihood:4.27416	validation_1-breslow_likelihood:2.95284
# [18]	validation_0-breslow_likelihood:4.31852	validation_1-breslow_likelihood:3.21748
# [7]	validation_0-breslow_likelihood:4.22336	validation_1-breslow_likelihood:3.00443
# [8]	validation_0-breslow_likelihood:4.17304	validation_1-breslow_likelihood:2.99161
# [19]	validation_0-breslow_likelihood:4.31739	validation_1-breslow_likelihood:3.21736
# [9]	validation_0-breslow_likelihood:4.15257	validation_1-breslow_likelihood:3.00107
# [20]	validation_0-breslow_likelihood:4.31637	validation_1-breslow_likelihood:3.21727
# [10]	validation_0-breslow_likelihood:4.12710	validation_1-breslow_likelihood:3.00483
# [11]	validation_0-breslow_likelihood:4.10978	validation_1-breslow_likelihood:2.97071
# [21]	validation_0-breslow_likelihood:4.31520	validation_1-breslow_likelihood:3.21712
# [12]	validation_0-breslow_likelihood:4.08183	validation_1-breslow_likelihood:2.98545
# [13]	validation_0-breslow_likelihood:4.07738	validation_1-breslow_likelihood:3.01169
# [22]	validation_0-breslow_likelihood:4.31419	validation_1-breslow_likelihood:3.21720
# [14]	validation_0-breslow_likelihood:4.05600	validation_1-breslow_likelihood:3.00323
# [23]	validation_0-breslow_likelihood:4.31300	validation_1-breslow_likelihood:3.21710
# [15]	validation_0-breslow_likelihood:4.05525	validation_1-breslow_likelihood:3.02028
# [24]	validation_0-breslow_likelihood:4.31202	validation_1-breslow_likelihood:3.21712
# [25]	validation_0-breslow_likelihood:4.31084	validation_1-breslow_likelihood:3.21708
# [26]	validation_0-breslow_likelihood:4.30975	validation_1-breslow_likelihood:3.21687
# [27]	validation_0-breslow_likelihood:4.30870	validation_1-breslow_likelihood:3.21707
# [28]	validation_0-breslow_likelihood:4.30756	validation_1-breslow_likelihood:3.21727
# [29]	validation_0-breslow_likelihood:4.30642	validation_1-breslow_likelihood:3.21719
# [0]	validation_0-breslow_likelihood:4.27873	validation_1-breslow_likelihood:3.23675
# [1]	validation_0-breslow_likelihood:4.23381	validation_1-breslow_likelihood:3.28263
# [2]	validation_0-breslow_likelihood:4.22559	validation_1-breslow_likelihood:3.32984
# [3]	validation_0-breslow_likelihood:4.20580	validation_1-breslow_likelihood:3.30826
# [4]	validation_0-breslow_likelihood:4.19968	validation_1-breslow_likelihood:3.30191
# [5]	validation_0-breslow_likelihood:4.18158	validation_1-breslow_likelihood:3.29486
# [6]	validation_0-breslow_likelihood:4.14583	validation_1-breslow_likelihood:3.26485
# [7]	validation_0-breslow_likelihood:4.13159	validation_1-breslow_likelihood:3.33606
# [8]	validation_0-breslow_likelihood:4.08520	validation_1-breslow_likelihood:3.35651
# [9]	validation_0-breslow_likelihood:4.07706	validation_1-breslow_likelihood:3.38829
# [0]	validation_0-breslow_likelihood:4.52511	validation_1-breslow_likelihood:3.28565
# [1]	validation_0-breslow_likelihood:4.50478	validation_1-breslow_likelihood:3.33039
# [2]	validation_0-breslow_likelihood:4.48116	validation_1-breslow_likelihood:3.33310
# [3]	validation_0-breslow_likelihood:4.46058	validation_1-breslow_likelihood:3.32762
# [4]	validation_0-breslow_likelihood:4.44745	validation_1-breslow_likelihood:3.27757
# [5]	validation_0-breslow_likelihood:4.42274	validation_1-breslow_likelihood:3.30111
# [6]	validation_0-breslow_likelihood:4.40599	validation_1-breslow_likelihood:3.33860
# [7]	validation_0-breslow_likelihood:4.38888	validation_1-breslow_likelihood:3.33168
# [8]	validation_0-breslow_likelihood:4.37990	validation_1-breslow_likelihood:3.31081
# [9]	validation_0-breslow_likelihood:4.35738	validation_1-breslow_likelihood:3.32508
# [10]	validation_0-breslow_likelihood:4.32669	validation_1-breslow_likelihood:3.37460
# [11]	validation_0-breslow_likelihood:4.30046	validation_1-breslow_likelihood:3.35496
# [12]	validation_0-breslow_likelihood:4.28836	validation_1-breslow_likelihood:3.42146
# [13]	validation_0-breslow_likelihood:4.27566	validation_1-breslow_likelihood:3.43841
# [14]	validation_0-breslow_likelihood:4.24479	validation_1-breslow_likelihood:3.45253
# Concordance Index 0.6010387683175663
# Integrated Brier Score: 0.18787137343644222
# durations 15.0 3817.0
# Concordance Index 0.5805570726379028
# Integrated Brier Score: 0.2418351584322114
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:4.37914	validation_1-breslow_likelihood:3.04494
# [1]	validation_0-breslow_likelihood:4.37641	validation_1-breslow_likelihood:3.04373
# [2]	validation_0-breslow_likelihood:4.36806	validation_1-breslow_likelihood:3.03815
# [3]	validation_0-breslow_likelihood:4.36680	validation_1-breslow_likelihood:3.03718
# [4]	validation_0-breslow_likelihood:4.35612	validation_1-breslow_likelihood:3.03536
# [5]	validation_0-breslow_likelihood:4.35448	validation_1-breslow_likelihood:3.03437
# [6]	validation_0-breslow_likelihood:4.35105	validation_1-breslow_likelihood:3.03494
# [7]	validation_0-breslow_likelihood:4.35100	validation_1-breslow_likelihood:3.03668
# [8]	validation_0-breslow_likelihood:4.34881	validation_1-breslow_likelihood:3.03236
# [9]	validation_0-breslow_likelihood:4.34464	validation_1-breslow_likelihood:3.03159
# [10]	validation_0-breslow_likelihood:4.34341	validation_1-breslow_likelihood:3.03383
# [0]	validation_0-breslow_likelihood:4.40973	validation_1-breslow_likelihood:3.19591
# [1]	validation_0-breslow_likelihood:4.40743	validation_1-breslow_likelihood:3.18760
# [2]	validation_0-breslow_likelihood:4.40312	validation_1-breslow_likelihood:3.17890
# [3]	validation_0-breslow_likelihood:4.39891	validation_1-breslow_likelihood:3.17187
# [4]	validation_0-breslow_likelihood:4.39083	validation_1-breslow_likelihood:3.17221
# [5]	validation_0-breslow_likelihood:4.38861	validation_1-breslow_likelihood:3.17651
# [6]	validation_0-breslow_likelihood:4.38480	validation_1-breslow_likelihood:3.17300
# [7]	validation_0-breslow_likelihood:4.38179	validation_1-breslow_likelihood:3.17196
# [8]	validation_0-breslow_likelihood:4.37581	validation_1-breslow_likelihood:3.17258
# [9]	validation_0-breslow_likelihood:4.37096	validation_1-breslow_likelihood:3.17109
# [10]	validation_0-breslow_likelihood:4.36772	validation_1-breslow_likelihood:3.16352
# [0]	validation_0-breslow_likelihood:4.38818	validation_1-breslow_likelihood:3.08751
# [1]	validation_0-breslow_likelihood:4.38542	validation_1-breslow_likelihood:3.09020
# [2]	validation_0-breslow_likelihood:4.38237	validation_1-breslow_likelihood:3.08993
# [3]	validation_0-breslow_likelihood:4.37871	validation_1-breslow_likelihood:3.08752
# [4]	validation_0-breslow_likelihood:4.37400	validation_1-breslow_likelihood:3.08571
# [5]	validation_0-breslow_likelihood:4.37079	validation_1-breslow_likelihood:3.07678
# [6]	validation_0-breslow_likelihood:4.36762	validation_1-breslow_likelihood:3.07430
# [7]	validation_0-breslow_likelihood:4.36242	validation_1-breslow_likelihood:3.07398
# [8]	validation_0-breslow_likelihood:4.35564	validation_1-breslow_likelihood:3.07126
# [9]	validation_0-breslow_likelihood:4.34953	validation_1-breslow_likelihood:3.07166
# [10]	validation_0-breslow_likelihood:4.34622	validation_1-breslow_likelihood:3.06847
# [0]	validation_0-breslow_likelihood:4.46347	validation_1-breslow_likelihood:2.93233
# [0]	validation_0-breslow_likelihood:4.41350	validation_1-breslow_likelihood:3.19328
# [1]	validation_0-breslow_likelihood:4.46103	validation_1-breslow_likelihood:2.93485
# [2]	validation_0-breslow_likelihood:4.45421	validation_1-breslow_likelihood:2.93242
# [3]	validation_0-breslow_likelihood:4.44797	validation_1-breslow_likelihood:2.93098
# [1]	validation_0-breslow_likelihood:4.41326	validation_1-breslow_likelihood:3.19321
# [4]	validation_0-breslow_likelihood:4.44343	validation_1-breslow_likelihood:2.92785
# [5]	validation_0-breslow_likelihood:4.43601	validation_1-breslow_likelihood:2.92888
# [2]	validation_0-breslow_likelihood:4.41314	validation_1-breslow_likelihood:3.19306[6]	validation_0-breslow_likelihood:4.43089	validation_1-breslow_likelihood:2.92575
#
# [7]	validation_0-breslow_likelihood:4.42708	validation_1-breslow_likelihood:2.92555
# [8]	validation_0-breslow_likelihood:4.42460	validation_1-breslow_likelihood:2.91677
# [3]	validation_0-breslow_likelihood:4.41292	validation_1-breslow_likelihood:3.19303
# [9]	validation_0-breslow_likelihood:4.42001	validation_1-breslow_likelihood:2.90674
# [10]	validation_0-breslow_likelihood:4.41707	validation_1-breslow_likelihood:2.90717
# [4]	validation_0-breslow_likelihood:4.41268	validation_1-breslow_likelihood:3.19298
# [5]	validation_0-breslow_likelihood:4.41253	validation_1-breslow_likelihood:3.19306
# [6]	validation_0-breslow_likelihood:4.41235	validation_1-breslow_likelihood:3.19313
# [7]	validation_0-breslow_likelihood:4.41210	validation_1-breslow_likelihood:3.19311
# [0]	validation_0-breslow_likelihood:4.43131	validation_1-breslow_likelihood:3.09848
# [8]	validation_0-breslow_likelihood:4.41188	validation_1-breslow_likelihood:3.19303
# [1]	validation_0-breslow_likelihood:4.42893	validation_1-breslow_likelihood:3.09720
# [2]	validation_0-breslow_likelihood:4.41880	validation_1-breslow_likelihood:3.08975
# [9]	validation_0-breslow_likelihood:4.41151	validation_1-breslow_likelihood:3.19297
# [3]	validation_0-breslow_likelihood:4.41567	validation_1-breslow_likelihood:3.09390
# [4]	validation_0-breslow_likelihood:4.40522	validation_1-breslow_likelihood:3.08497
# [5]	validation_0-breslow_likelihood:4.40130	validation_1-breslow_likelihood:3.08811
# [10]	validation_0-breslow_likelihood:4.41121	validation_1-breslow_likelihood:3.19292
# [6]	validation_0-breslow_likelihood:4.39942	validation_1-breslow_likelihood:3.08882
# [7]	validation_0-breslow_likelihood:4.39533	validation_1-breslow_likelihood:3.09272
# [11]	validation_0-breslow_likelihood:4.41095	validation_1-breslow_likelihood:3.19293
# [8]	validation_0-breslow_likelihood:4.38796	validation_1-breslow_likelihood:3.09808
# [9]	validation_0-breslow_likelihood:4.38489	validation_1-breslow_likelihood:3.09953
# [12]	validation_0-breslow_likelihood:4.41062	validation_1-breslow_likelihood:3.19292
# [10]	validation_0-breslow_likelihood:4.37803	validation_1-breslow_likelihood:3.09321
# [13]	validation_0-breslow_likelihood:4.41036	validation_1-breslow_likelihood:3.19285
# [14]	validation_0-breslow_likelihood:4.41011	validation_1-breslow_likelihood:3.19278
# [15]	validation_0-breslow_likelihood:4.40992	validation_1-breslow_likelihood:3.19277
# [16]	validation_0-breslow_likelihood:4.40978	validation_1-breslow_likelihood:3.19286
# [17]	validation_0-breslow_likelihood:4.40957	validation_1-breslow_likelihood:3.19273
# [18]	validation_0-breslow_likelihood:4.40935	validation_1-breslow_likelihood:3.19281
# [19]	validation_0-breslow_likelihood:4.40914	validation_1-breslow_likelihood:3.19276
# [20]	validation_0-breslow_likelihood:4.40894	validation_1-breslow_likelihood:3.19282
# [21]	validation_0-breslow_likelihood:4.40867	validation_1-breslow_likelihood:3.19272
# [22]	validation_0-breslow_likelihood:4.40844	validation_1-breslow_likelihood:3.19270
# [23]	validation_0-breslow_likelihood:4.40824	validation_1-breslow_likelihood:3.19257
# [24]	validation_0-breslow_likelihood:4.40803	validation_1-breslow_likelihood:3.19257
# [25]	validation_0-breslow_likelihood:4.40783	validation_1-breslow_likelihood:3.19258
# [26]	validation_0-breslow_likelihood:4.40769	validation_1-breslow_likelihood:3.19259
# [27]	validation_0-breslow_likelihood:4.40744	validation_1-breslow_likelihood:3.19253
# [28]	validation_0-breslow_likelihood:4.40726	validation_1-breslow_likelihood:3.19255
# [29]	validation_0-breslow_likelihood:4.40705	validation_1-breslow_likelihood:3.19258
# [30]	validation_0-breslow_likelihood:4.40684	validation_1-breslow_likelihood:3.19260
# [31]	validation_0-breslow_likelihood:4.40660	validation_1-breslow_likelihood:3.19258
# [32]	validation_0-breslow_likelihood:4.40635	validation_1-breslow_likelihood:3.19252
# [33]	validation_0-breslow_likelihood:4.40602	validation_1-breslow_likelihood:3.19246
# [34]	validation_0-breslow_likelihood:4.40573	validation_1-breslow_likelihood:3.19248
# [35]	validation_0-breslow_likelihood:4.40555	validation_1-breslow_likelihood:3.19245
# [36]	validation_0-breslow_likelihood:4.40536	validation_1-breslow_likelihood:3.19244
# [37]	validation_0-breslow_likelihood:4.40509	validation_1-breslow_likelihood:3.19235
# [38]	validation_0-breslow_likelihood:4.40477	validation_1-breslow_likelihood:3.19223
# [39]	validation_0-breslow_likelihood:4.40447	validation_1-breslow_likelihood:3.19223
# [40]	validation_0-breslow_likelihood:4.40426	validation_1-breslow_likelihood:3.19216
# [41]	validation_0-breslow_likelihood:4.40414	validation_1-breslow_likelihood:3.19217
# [42]	validation_0-breslow_likelihood:4.40376	validation_1-breslow_likelihood:3.19208
# [43]	validation_0-breslow_likelihood:4.40338	validation_1-breslow_likelihood:3.19204
# [44]	validation_0-breslow_likelihood:4.40313	validation_1-breslow_likelihood:3.19195
# [45]	validation_0-breslow_likelihood:4.40293	validation_1-breslow_likelihood:3.19199
# [46]	validation_0-breslow_likelihood:4.40259	validation_1-breslow_likelihood:3.19204
# [47]	validation_0-breslow_likelihood:4.40228	validation_1-breslow_likelihood:3.19199
# [48]	validation_0-breslow_likelihood:4.40193	validation_1-breslow_likelihood:3.19195
# [49]	validation_0-breslow_likelihood:4.40171	validation_1-breslow_likelihood:3.19191
# [50]	validation_0-breslow_likelihood:4.40150	validation_1-breslow_likelihood:3.19190
# [51]	validation_0-breslow_likelihood:4.40125	validation_1-breslow_likelihood:3.19205
# [52]	validation_0-breslow_likelihood:4.40103	validation_1-breslow_likelihood:3.19202
# [53]	validation_0-breslow_likelihood:4.40084	validation_1-breslow_likelihood:3.19195
# [0]	validation_0-breslow_likelihood:4.38226	validation_1-breslow_likelihood:3.04600[54]	validation_0-breslow_likelihood:4.40055	validation_1-breslow_likelihood:3.19188
#
# [55]	validation_0-breslow_likelihood:4.40036	validation_1-breslow_likelihood:3.19186
# ...
# [2]	validation_0-breslow_likelihood:4.09139	validation_1-breslow_likelihood:2.78796
# [3]	validation_0-breslow_likelihood:4.02670	validation_1-breslow_likelihood:2.77698
# [4]	validation_0-breslow_likelihood:3.98947	validation_1-breslow_likelihood:2.76659
# [5]	validation_0-breslow_likelihood:3.96834	validation_1-breslow_likelihood:2.78950
# [6]	validation_0-breslow_likelihood:3.92873	validation_1-breslow_likelihood:2.79819
# [7]	validation_0-breslow_likelihood:3.90043	validation_1-breslow_likelihood:2.81012
# [8]	validation_0-breslow_likelihood:3.87530	validation_1-breslow_likelihood:2.82405
# [9]	validation_0-breslow_likelihood:3.84163	validation_1-breslow_likelihood:2.80332
# [10]	validation_0-breslow_likelihood:3.78677	validation_1-breslow_likelihood:2.81981
# [11]	validation_0-breslow_likelihood:3.75019	validation_1-breslow_likelihood:2.84303
# [12]	validation_0-breslow_likelihood:3.71793	validation_1-breslow_likelihood:2.84331
# [13]	validation_0-breslow_likelihood:3.69004	validation_1-breslow_likelihood:2.81881
# [14]	validation_0-breslow_likelihood:3.66550	validation_1-breslow_likelihood:2.82979
# [0]	validation_0-breslow_likelihood:4.37192	validation_1-breslow_likelihood:3.03622
# [1]	validation_0-breslow_likelihood:4.37192	validation_1-breslow_likelihood:3.03622
# [2]	validation_0-breslow_likelihood:4.37192	validation_1-breslow_likelihood:3.03622
# [3]	validation_0-breslow_likelihood:4.37192	validation_1-breslow_likelihood:3.03622
# [4]	validation_0-breslow_likelihood:4.37192	validation_1-breslow_likelihood:3.03622
# [5]	validation_0-breslow_likelihood:4.37192	validation_1-breslow_likelihood:3.03622
# [6]	validation_0-breslow_likelihood:4.37192	validation_1-breslow_likelihood:3.03622
# [7]	validation_0-breslow_likelihood:4.37192	validation_1-breslow_likelihood:3.03622
# [8]	validation_0-breslow_likelihood:4.37192	validation_1-breslow_likelihood:3.03622
# [9]	validation_0-breslow_likelihood:4.37192	validation_1-breslow_likelihood:3.03622
# [10]	validation_0-breslow_likelihood:4.37192	validation_1-breslow_likelihood:3.03622
# [0]	validation_0-breslow_likelihood:4.55573	validation_1-breslow_likelihood:3.25913
# [1]	validation_0-breslow_likelihood:4.55573	validation_1-breslow_likelihood:3.25913
# [2]	validation_0-breslow_likelihood:4.55573	validation_1-breslow_likelihood:3.25913
# [3]	validation_0-breslow_likelihood:4.55573	validation_1-breslow_likelihood:3.25913
# [4]	validation_0-breslow_likelihood:4.55573	validation_1-breslow_likelihood:3.25913
# [5]	validation_0-breslow_likelihood:4.55573	validation_1-breslow_likelihood:3.25913
# [6]	validation_0-breslow_likelihood:4.55573	validation_1-breslow_likelihood:3.25913
# [7]	validation_0-breslow_likelihood:4.55573	validation_1-breslow_likelihood:3.25913
# [8]	validation_0-breslow_likelihood:4.55573	validation_1-breslow_likelihood:3.25913
# [9]	validation_0-breslow_likelihood:4.55573	validation_1-breslow_likelihood:3.25913
# [10]	validation_0-breslow_likelihood:4.55572	validation_1-breslow_likelihood:3.25907
# [11]	validation_0-breslow_likelihood:4.55572	validation_1-breslow_likelihood:3.25907
# [12]	validation_0-breslow_likelihood:4.55572	validation_1-breslow_likelihood:3.25907
# [13]	validation_0-breslow_likelihood:4.55572	validation_1-breslow_likelihood:3.25907
# [14]	validation_0-breslow_likelihood:4.55572	validation_1-breslow_likelihood:3.25907
# [15]	validation_0-breslow_likelihood:4.55572	validation_1-breslow_likelihood:3.25907
# [16]	validation_0-breslow_likelihood:4.55572	validation_1-breslow_likelihood:3.25907
# [17]	validation_0-breslow_likelihood:4.55572	validation_1-breslow_likelihood:3.25907
# [18]	validation_0-breslow_likelihood:4.55572	validation_1-breslow_likelihood:3.25907
# [19]	validation_0-breslow_likelihood:4.55572	validation_1-breslow_likelihood:3.25907
# [20]	validation_0-breslow_likelihood:4.55572	validation_1-breslow_likelihood:3.25907
# Concordance Index 0.0
# Integrated Brier Score: 0.21995005368127918
# durations 3.0 2197.0
# Concordance Index 0.0
# Integrated Brier Score: 0.20996955712669696
# (312, 19076) <class 'pandas.core.frame.DataFrame'>
# (312,) <class 'pandas.core.series.Series'>
# (77, 19076) <class 'pandas.core.frame.DataFrame'>
# (77,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:4.25630	validation_1-breslow_likelihood:2.91797
# [1]	validation_0-breslow_likelihood:4.24903	validation_1-breslow_likelihood:2.92034
# [2]	validation_0-breslow_likelihood:4.24323	validation_1-breslow_likelihood:2.92168
# [3]	validation_0-breslow_likelihood:4.23982	validation_1-breslow_likelihood:2.91901
# [4]	validation_0-breslow_likelihood:4.23232	validation_1-breslow_likelihood:2.91970
# [5]	validation_0-breslow_likelihood:4.23102	validation_1-breslow_likelihood:2.91721
# [6]	validation_0-breslow_likelihood:4.22451	validation_1-breslow_likelihood:2.92020
# [7]	validation_0-breslow_likelihood:4.21552	validation_1-breslow_likelihood:2.91953
# [8]	validation_0-breslow_likelihood:4.20910	validation_1-breslow_likelihood:2.92000
# [9]	validation_0-breslow_likelihood:4.20449	validation_1-breslow_likelihood:2.92168
# [10]	validation_0-breslow_likelihood:4.20031	validation_1-breslow_likelihood:2.91921
# [11]	validation_0-breslow_likelihood:4.19390	validation_1-breslow_likelihood:2.91928
# [12]	validation_0-breslow_likelihood:4.18984	validation_1-breslow_likelihood:2.91924
# [0]	validation_0-breslow_likelihood:4.42056	validation_1-breslow_likelihood:2.96737
# [1]	validation_0-breslow_likelihood:4.41530	validation_1-breslow_likelihood:2.96869
# [0]	validation_0-breslow_likelihood:4.24572	validation_1-breslow_likelihood:2.91404
# [1]	validation_0-breslow_likelihood:4.24318	validation_1-breslow_likelihood:2.91280
# [2]	validation_0-breslow_likelihood:4.40953	validation_1-breslow_likelihood:2.97188
# [2]	validation_0-breslow_likelihood:4.23423	validation_1-breslow_likelihood:2.91481
# [3]	validation_0-breslow_likelihood:4.40223	validation_1-breslow_likelihood:2.97319
# [3]	validation_0-breslow_likelihood:4.23050	validation_1-breslow_likelihood:2.91523
# [4]	validation_0-breslow_likelihood:4.22395	validation_1-breslow_likelihood:2.91441
# [4]	validation_0-breslow_likelihood:4.39432	validation_1-breslow_likelihood:2.97508
# [5]	validation_0-breslow_likelihood:4.38688	validation_1-breslow_likelihood:2.97421
# [5]	validation_0-breslow_likelihood:4.22058	validation_1-breslow_likelihood:2.91722
# [6]	validation_0-breslow_likelihood:4.38314	validation_1-breslow_likelihood:2.97047
# [7]	validation_0-breslow_likelihood:4.37890	validation_1-breslow_likelihood:2.97078
# [6]	validation_0-breslow_likelihood:4.21131	validation_1-breslow_likelihood:2.91581
# [7]	validation_0-breslow_likelihood:4.20677	validation_1-breslow_likelihood:2.91353
# [8]	validation_0-breslow_likelihood:4.37466	validation_1-breslow_likelihood:2.97177
# [9]	validation_0-breslow_likelihood:4.37042	validation_1-breslow_likelihood:2.97029
# [8]	validation_0-breslow_likelihood:4.20068	validation_1-breslow_likelihood:2.91213
# [10]	validation_0-breslow_likelihood:4.36606	validation_1-breslow_likelihood:2.97113
# [9]	validation_0-breslow_likelihood:4.19566	validation_1-breslow_likelihood:2.90662
# [10]	validation_0-breslow_likelihood:4.19213	validation_1-breslow_likelihood:2.90775
# [11]	validation_0-breslow_likelihood:4.18517	validation_1-breslow_likelihood:2.91175
# [12]	validation_0-breslow_likelihood:4.17607	validation_1-breslow_likelihood:2.91281
# [0]	validation_0-breslow_likelihood:4.32375	validation_1-breslow_likelihood:2.93939
# [1]	validation_0-breslow_likelihood:4.30039	validation_1-breslow_likelihood:2.94674
# [2]	validation_0-breslow_likelihood:4.26225	validation_1-breslow_likelihood:3.00324
# [3]	validation_0-breslow_likelihood:4.26980	validation_1-breslow_likelihood:3.02800
# [4]	validation_0-breslow_likelihood:4.26272	validation_1-breslow_likelihood:3.02872
# [5]	validation_0-breslow_likelihood:4.22480	validation_1-breslow_likelihood:3.05544
# [6]	validation_0-breslow_likelihood:4.19697	validation_1-breslow_likelihood:3.02538
# [7]	validation_0-breslow_likelihood:4.20149	validation_1-breslow_likelihood:3.08084
# [8]	validation_0-breslow_likelihood:4.20986	validation_1-breslow_likelihood:3.14718
# [9]	validation_0-breslow_likelihood:4.16033	validation_1-breslow_likelihood:3.13424
# [10]	validation_0-breslow_likelihood:4.12432	validation_1-breslow_likelihood:3.11433
# [0]	validation_0-breslow_likelihood:4.23015	validation_1-breslow_likelihood:2.93388
# [1]	validation_0-breslow_likelihood:4.27238	validation_1-breslow_likelihood:2.95613
# [2]	validation_0-breslow_likelihood:4.22934	validation_1-breslow_likelihood:2.98498
# [0]	validation_0-breslow_likelihood:4.36557	validation_1-breslow_likelihood:2.83591
# [1]	validation_0-breslow_likelihood:4.40153	validation_1-breslow_likelihood:2.87341
# [3]	validation_0-breslow_likelihood:4.25665	validation_1-breslow_likelihood:2.96629
# [2]	validation_0-breslow_likelihood:4.38156	validation_1-breslow_likelihood:2.86192
# [3]	validation_0-breslow_likelihood:4.36651	validation_1-breslow_likelihood:2.91993
# [4]	validation_0-breslow_likelihood:4.18994	validation_1-breslow_likelihood:3.03186
# [4]	validation_0-breslow_likelihood:4.36528	validation_1-breslow_likelihood:2.90987
# [5]	validation_0-breslow_likelihood:4.15298	validation_1-breslow_likelihood:3.01313
# [6]	validation_0-breslow_likelihood:4.10419	validation_1-breslow_likelihood:3.05411
# [5]	validation_0-breslow_likelihood:4.32309	validation_1-breslow_likelihood:2.96078
# [6]	validation_0-breslow_likelihood:4.31557	validation_1-breslow_likelihood:2.97493
# [7]	validation_0-breslow_likelihood:4.07668	validation_1-breslow_likelihood:3.09154
# [7]	validation_0-breslow_likelihood:4.33496	validation_1-breslow_likelihood:3.05161
# [8]	validation_0-breslow_likelihood:4.05293	validation_1-breslow_likelihood:3.12499
# [8]	validation_0-breslow_likelihood:4.28838	validation_1-breslow_likelihood:3.04761
# [9]	validation_0-breslow_likelihood:4.00838	validation_1-breslow_likelihood:3.18742
# [9]	validation_0-breslow_likelihood:4.25669	validation_1-breslow_likelihood:3.00868
# [10]	validation_0-breslow_likelihood:4.02196	validation_1-breslow_likelihood:3.23702
# [10]	validation_0-breslow_likelihood:4.23108	validation_1-breslow_likelihood:2.99521
# [0]	validation_0-breslow_likelihood:4.35904	validation_1-breslow_likelihood:2.91707
# [1]	validation_0-breslow_likelihood:4.35464	validation_1-breslow_likelihood:2.91776
# [2]	validation_0-breslow_likelihood:4.35090	validation_1-breslow_likelihood:2.91750
# [3]	validation_0-breslow_likelihood:4.34581	validation_1-breslow_likelihood:2.91456
# [4]	validation_0-breslow_likelihood:4.34136	validation_1-breslow_likelihood:2.91238
# [5]	validation_0-breslow_likelihood:4.33667	validation_1-breslow_likelihood:2.91024
# [6]	validation_0-breslow_likelihood:4.32993	validation_1-breslow_likelihood:2.91442
# [7]	validation_0-breslow_likelihood:4.32752	validation_1-breslow_likelihood:2.91344
# [8]	validation_0-breslow_likelihood:4.32293	validation_1-breslow_likelihood:2.91607
# [9]	validation_0-breslow_likelihood:4.31813	validation_1-breslow_likelihood:2.91789
# [10]	validation_0-breslow_likelihood:4.31423	validation_1-breslow_likelihood:2.92174
# [11]	validation_0-breslow_likelihood:4.30873	validation_1-breslow_likelihood:2.92693
# [12]	validation_0-breslow_likelihood:4.30406	validation_1-breslow_likelihood:2.92859
# [0]	validation_0-breslow_likelihood:4.42421	validation_1-breslow_likelihood:2.96540
# [1]	validation_0-breslow_likelihood:4.44758	validation_1-breslow_likelihood:2.97371
# [2]	validation_0-breslow_likelihood:4.42814	validation_1-breslow_likelihood:2.99456
# [3]	validation_0-breslow_likelihood:4.41531	validation_1-breslow_likelihood:3.01679
# [4]	validation_0-breslow_likelihood:4.38904	validation_1-breslow_likelihood:3.06857
# [5]	validation_0-breslow_likelihood:4.35717	validation_1-breslow_likelihood:3.03524
# [6]	validation_0-breslow_likelihood:4.41195	validation_1-breslow_likelihood:2.95223
# [7]	validation_0-breslow_likelihood:4.44168	validation_1-breslow_likelihood:2.94499
# [8]	validation_0-breslow_likelihood:4.45515	validation_1-breslow_likelihood:3.05010
# [9]	validation_0-breslow_likelihood:4.43806	validation_1-breslow_likelihood:3.10106
# [10]	validation_0-breslow_likelihood:4.38079	validation_1-breslow_likelihood:3.03043
# [11]	validation_0-breslow_likelihood:4.33084	validation_1-breslow_likelihood:2.93046
# [12]	validation_0-breslow_likelihood:4.32922	validation_1-breslow_likelihood:2.96887
# [13]	validation_0-breslow_likelihood:4.38906	validation_1-breslow_likelihood:3.09660
# [14]	validation_0-breslow_likelihood:4.38489	validation_1-breslow_likelihood:3.04035
# [15]	validation_0-breslow_likelihood:4.40600	validation_1-breslow_likelihood:3.04101
# [16]	validation_0-breslow_likelihood:4.41191	validation_1-breslow_likelihood:3.09391
# [17]	validation_0-breslow_likelihood:4.34547	validation_1-breslow_likelihood:3.05023
# [18]	validation_0-breslow_likelihood:4.30097	validation_1-breslow_likelihood:3.09733
# [19]	validation_0-breslow_likelihood:4.27412	validation_1-breslow_likelihood:3.22108
# [20]	validation_0-breslow_likelihood:4.23973	validation_1-breslow_likelihood:3.19921
# [21]	validation_0-breslow_likelihood:4.22832	validation_1-breslow_likelihood:3.19624
# [0]	validation_0-breslow_likelihood:4.36382	validation_1-breslow_likelihood:2.79339
# [1]	validation_0-breslow_likelihood:4.35801	validation_1-breslow_likelihood:2.79236
# [2]	validation_0-breslow_likelihood:4.35451	validation_1-breslow_likelihood:2.78870
# [3]	validation_0-breslow_likelihood:4.34730	validation_1-breslow_likelihood:2.79111
# [4]	validation_0-breslow_likelihood:4.34058	validation_1-breslow_likelihood:2.79185
# [5]	validation_0-breslow_likelihood:4.33486	validation_1-breslow_likelihood:2.79243
# [6]	validation_0-breslow_likelihood:4.32769	validation_1-breslow_likelihood:2.79208
# [7]	validation_0-breslow_likelihood:4.32462	validation_1-breslow_likelihood:2.79094
# [8]	validation_0-breslow_likelihood:4.31824	validation_1-breslow_likelihood:2.79131
# [9]	validation_0-breslow_likelihood:4.31212	validation_1-breslow_likelihood:2.79179
# [10]	validation_0-breslow_likelihood:4.30735	validation_1-breslow_likelihood:2.79234
# [11]	validation_0-breslow_likelihood:4.30370	validation_1-breslow_likelihood:2.79310
# [0]	validation_0-breslow_likelihood:4.23428	validation_1-breslow_likelihood:2.94630
# [1]	validation_0-breslow_likelihood:4.25265	validation_1-breslow_likelihood:3.04757
# [2]	validation_0-breslow_likelihood:4.23457	validation_1-breslow_likelihood:3.04091
# [3]	validation_0-breslow_likelihood:4.23934	validation_1-breslow_likelihood:3.06845
# [4]	validation_0-breslow_likelihood:4.16006	validation_1-breslow_likelihood:3.01829
# [5]	validation_0-breslow_likelihood:4.18612	validation_1-breslow_likelihood:2.99712
# [6]	validation_0-breslow_likelihood:4.16030	validation_1-breslow_likelihood:2.98361
# [7]	validation_0-breslow_likelihood:4.13874	validation_1-breslow_likelihood:3.04793
# [8]	validation_0-breslow_likelihood:4.16047	validation_1-breslow_likelihood:3.03313
# [9]	validation_0-breslow_likelihood:4.14880	validation_1-breslow_likelihood:3.00106
# [0]	validation_0-breslow_likelihood:4.55859	validation_1-breslow_likelihood:3.37176
# [1]	validation_0-breslow_likelihood:4.55090	validation_1-breslow_likelihood:3.37492
# [2]	validation_0-breslow_likelihood:4.54232	validation_1-breslow_likelihood:3.37484
# [3]	validation_0-breslow_likelihood:4.53636	validation_1-breslow_likelihood:3.37182
# [4]	validation_0-breslow_likelihood:4.53074	validation_1-breslow_likelihood:3.37656
# [5]	validation_0-breslow_likelihood:4.52469	validation_1-breslow_likelihood:3.37673
# [6]	validation_0-breslow_likelihood:4.51789	validation_1-breslow_likelihood:3.37856
# [7]	validation_0-breslow_likelihood:4.51567	validation_1-breslow_likelihood:3.37792
# [8]	validation_0-breslow_likelihood:4.50960	validation_1-breslow_likelihood:3.37564
# [9]	validation_0-breslow_likelihood:4.50265	validation_1-breslow_likelihood:3.37576
# [10]	validation_0-breslow_likelihood:4.49722	validation_1-breslow_likelihood:3.37522
# Concordance Index 0.48440437532045805
# Integrated Brier Score: 0.2044273163165405
# durations 8.0 3519.0
# Concordance Index 0.41324503311258276
# Integrated Brier Score: 0.23117738653698783
