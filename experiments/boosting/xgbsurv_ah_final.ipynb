# %% [markdown]
# ## XGBSurv AH Benchmark

# %%
from xgbsurv.datasets import (load_metabric, load_flchain, load_rgbsg, load_support, load_tcga)
from xgbsurv import XGBSurv
from xgbsurv.evaluation import cindex_censored, ibs
from xgbsurv.models.utils import sort_X_y
import os
import numpy as np
import pandas as pd
from scipy.stats import uniform as scuniform
from scipy.stats import randint as scrandint
from scipy.stats import loguniform as scloguniform 
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, LabelBinarizer, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.decomposition import PCA
# import models
from xgbsurv.models.eh_ah_final import ah_likelihood, get_cumulative_hazard_function_ah
from pycox.evaluation import EvalSurv
from xgbsurv.models.utils import sort_X_y_pandas, transform_back, transform
from xgbsurv.preprocessing.dataset_preprocessing import discretizer_df

# %% [markdown]
# ## Set Parameters

# %%
# set parameters
n_outer_splits = 5
n_inner_splits = 5
rand_state = 42
n_iter = 50 #0
early_stopping_rounds=10
base_score = 0.0
validation_size = 0.2

# set seed for scipy
np.random.seed(rand_state)

# Define parameter grid for random forest classifier
param_grid = {
#'estimator__reg_alpha': scloguniform(1e-10,1.0),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1.0), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.01,1.0), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,4000), # corresponds to num_rounds
#'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
}

# %% [markdown]
# ## Custom Splitting

# %%
class CustomSplit(StratifiedKFold):
    def __init__(self, n_splits=5, shuffle=True, random_state=None):
        super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)

    def split(self, X, y, groups=None):
        try:
            if y.shape[1]>1:
                y = y[:,0]
        except:
            pass
        bins = np.sign(y)
        return super().split(X, bins, groups=groups)

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

outer_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)
inner_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)

# %% [markdown]
# ## Scoring Function

# %%
scoring_function = make_scorer(ah_likelihood, greater_is_better=False) #changed here

# %% [markdown]
# ## Set Model & Train Test Evaluate

# %%
data_set_fns = [load_metabric, load_flchain, load_rgbsg, load_support] #, load_flchain, load_rgbsg, load_support, load_tcga]
data_set_fns_str = ['load_metabric', 'load_flchain', 'load_rgbsg', 'load_support'] 
one_hot_dict = {'load_flchain': ['mgus'], 'load_support':['cancer', 'race'], 'load_rgbsg':['grade']}
agg_metrics_cindex = []
agg_metrics_ibs = []

for idx, dataset in enumerate(data_set_fns):
    model = 'xgbsurv_ah_'
    # get name of current dataset
    data = dataset(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=True)
    filename = data.filename
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()

    print(data_set_fns_str[idx])
    #if data_set_fns_str[idx] in one_hot_dict.keys():
    #   X = pd.get_dummies(X, columns=one_hot_dict[data_set_fns_str[idx]])
    #print(X)
    X, y = sort_X_y_pandas(X, y)
    #print(X.dtypes)
    dataset_name = filename.split('_')[0]
    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            (StandardScaler(), make_column_selector(dtype_include=['float32'])),
            (OneHotEncoder(sparse_output=False, handle_unknown='infrequent_if_exist'), make_column_selector(dtype_include=['category', 'object'])),
            remainder='passthrough')
    
    estimator = XGBSurv(
        objective='ah_objective',
        eval_metric='ah_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score,
        verbose=0 
        )
    pipe = Pipeline([('scaler',ct),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=n_iter, refit=True, random_state=rand_state)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        #print(X_train.shape, type(X_train))
        #print(y_train.shape, type(y_train))
        #print(y_test.shape, type(y_test))
        #print(X_test.shape, type(X_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        #np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        #np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        #np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        #np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=validation_size)

        best_preds_train = rs.best_estimator_.predict(X_train)
        print('best_preds_train',best_preds_train)
        print('best_preds_train',best_preds_test)
        best_preds_test = rs.best_estimator_.predict(X_test)
        np.savetxt('predictions/'+model+'best_preds_train_'+str(i)+'_'+filename, best_preds_train, delimiter=',')
        np.savetxt('predictions/'+model+'best_preds_test_'+str(i)+'_'+filename, best_preds_test, delimiter=',')


        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_ah(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_ah(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
    # cindex
    df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                            'cindex_train_mean':df_outer_scores['cindex_train_'+dataset_name].mean(),
                                            'cindex_train_std':df_outer_scores['cindex_train_'+dataset_name].std(),
                                            'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                            'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })
    # IBS
    df_agg_metrics_ibs = pd.DataFrame({'dataset':[dataset_name],
                                            'ibs_train_mean':df_outer_scores['ibs_train_'+dataset_name].mean(),
                                            'ibs_train_std':df_outer_scores['ibs_train_'+dataset_name].std(),
                                            'ibs_test_mean':df_outer_scores['ibs_test_'+dataset_name].mean(),
                                            'ibs_test_std':df_outer_scores['ibs_test_'+dataset_name].std() })
    agg_metrics_cindex.append(df_agg_metrics_cindex)
    agg_metrics_ibs.append(df_agg_metrics_ibs)

df_final_ah_1_cindex = pd.concat([df for df in agg_metrics_cindex]).round(4)
df_final_ah_1_cindex.to_csv('metrics/final_gbdt_ah_1_cindex.csv', index=False)
df_final_ah_1_cindex.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_ah_1_cindex.csv', index=False)  #


df_final_ah_1_ibs = pd.concat([df for df in agg_metrics_ibs]).round(4)
df_final_ah_1_ibs.to_csv('metrics/final_gbdt_ah_1_ibs.csv', index=False)
df_final_ah_1_ibs.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_ah_1_ibs.csv', index=False)
# Out:
# load_metabric
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [11]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [11]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [12]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [11]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [13]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [10]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [12]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [14]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [13]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [14]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [11]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [12]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [13]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [14]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [10]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [15]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [11]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [11]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [10]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [10]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [11]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [10]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [10]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [11]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [12]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [10]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# ...
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [12]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [10]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [13]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [10]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [14]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [11]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [11]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [12]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [0]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [1]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [2]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [2]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [3]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [10]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [5]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [0]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [1]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [1]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [2]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [3]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [1]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [3]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [10]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [4]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [2]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [4]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [5]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [3]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [5]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [6]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [4]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [6]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [5]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [10]	validation_0-ah_likelihood:3.11997	validation_1-ah_likelihood:3.12090
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [7]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [9]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [6]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [11]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [8]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [10]	validation_0-ah_likelihood:3.12059	validation_1-ah_likelihood:3.13320
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [7]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [9]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [10]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [8]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [10]	validation_0-ah_likelihood:3.12483	validation_1-ah_likelihood:3.12258
# [11]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [9]	validation_0-ah_likelihood:3.11915	validation_1-ah_likelihood:3.12026
# [12]	validation_0-ah_likelihood:3.12022	validation_1-ah_likelihood:3.11857
# [0]	validation_0-ah_likelihood:3.11666	validation_1-ah_likelihood:3.12739
# [1]	validation_0-ah_likelihood:3.11666	validation_1-ah_likelihood:3.12739
# [2]	validation_0-ah_likelihood:3.11666	validation_1-ah_likelihood:3.12739
# [3]	validation_0-ah_likelihood:3.11666	validation_1-ah_likelihood:3.12739
# [4]	validation_0-ah_likelihood:3.11666	validation_1-ah_likelihood:3.12739
# [5]	validation_0-ah_likelihood:3.11666	validation_1-ah_likelihood:3.12739
# [6]	validation_0-ah_likelihood:3.11666	validation_1-ah_likelihood:3.12739
# [7]	validation_0-ah_likelihood:3.11666	validation_1-ah_likelihood:3.12739
# [8]	validation_0-ah_likelihood:3.11666	validation_1-ah_likelihood:3.12739
# [9]	validation_0-ah_likelihood:3.11666	validation_1-ah_likelihood:3.12739
# best_preds_train [-8.113163e-07 -8.113163e-07 -8.113163e-07 ... -8.113163e-07 -8.113163e-07
#  -8.113163e-07]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 71
#      69 best_preds_train = rs.best_estimator_.predict(X_train)
#      70 print('best_preds_train',best_preds_train)
# ---> 71 print('best_preds_train',best_preds_test)
#      72 best_preds_test = rs.best_estimator_.predict(X_test)
#      73 np.savetxt('predictions/'+model+'best_preds_train_'+str(i)+'_'+filename, best_preds_train, delimiter=',')
#
# NameError: name 'best_preds_test' is not defined

# %%
rs.best_estimator_.predict(X_train)
# Out:
# array([-8.113163e-07, -8.113163e-07, -8.113163e-07, ..., -8.113163e-07,
#        -8.113163e-07, -8.113163e-07], dtype=float32)

# %%
X_train.dtypes
# Out:
# MKI67                float32
# EGFR                 float32
# PGR                  float32
# ERBB2                float32
# hormone_treatment      uint8
# radiotherapy           uint8
# chemotherapy           uint8
# ER_positive            uint8
# age                  float32
# dtype: object

# %% [markdown]
# ## TCGA Train, Test, Evaluation

# %%
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
'pca__n_components': [8, 16, 32, 64]
}

# %%
cancer_types = ['BLCA',
    'BRCA',
    'HNSC',
    'KIRC',
    'LGG',
    'LIHC',
    'LUAD',
    'LUSC',
    'OV',
    'STAD']
agg_metrics_cindex = []
agg_metrics_ibs = []


for idx, cancer_type in enumerate(cancer_types):
    model = 'xgbsurv_ah_'
    # get name of current dataset
    data = load_tcga(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", cancer_type=cancer_type, as_frame=True)
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()
    filename = data.filename
    dataset_name = filename.split('_')[0]
    X, y = sort_X_y_pandas(X, y)

    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='ah_objective',
        eval_metric='ah_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    
    pipe = Pipeline([('scaler',ct),
                    ('pca', PCA()),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=n_iter, refit=True, random_state=rand_state)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        #print(y_train.shape, type(y_train))
        #print(X_train.shape, type(X_train))
        #print(X_test.shape, type(X_test))
        #print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_ah(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_ah(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
            # cindex
    df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                            'cindex_train_mean':df_outer_scores['cindex_train_'+dataset_name].mean(),
                                            'cindex_train_std':df_outer_scores['cindex_train_'+dataset_name].std(),
                                            'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                            'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })
    # IBS
    df_agg_metrics_ibs = pd.DataFrame({'dataset':[dataset_name],
                                            'ibs_train_mean':df_outer_scores['ibs_train_'+dataset_name].mean(),
                                            'ibs_train_std':df_outer_scores['ibs_train_'+dataset_name].std(),
                                            'ibs_test_mean':df_outer_scores['ibs_test_'+dataset_name].mean(),
                                            'ibs_test_std':df_outer_scores['ibs_test_'+dataset_name].std() })

    agg_metrics_cindex.append(df_agg_metrics_cindex)
    agg_metrics_ibs.append(df_agg_metrics_ibs)
# Out:
# [0]	validation_0-ah_likelihood:3.23300	validation_1-ah_likelihood:3.26245
# [1]	validation_0-ah_likelihood:3.23300	validation_1-ah_likelihood:3.26245
# [0]	validation_0-ah_likelihood:3.29353	validation_1-ah_likelihood:3.32973
# [0]	validation_0-ah_likelihood:3.29353	validation_1-ah_likelihood:3.32973
# [1]	validation_0-ah_likelihood:3.29353	validation_1-ah_likelihood:3.32973
# [1]	validation_0-ah_likelihood:3.29353	validation_1-ah_likelihood:3.32973
# [2]	validation_0-ah_likelihood:3.23300	validation_1-ah_likelihood:3.26245
# [2]	validation_0-ah_likelihood:3.29353	validation_1-ah_likelihood:3.32973
# [2]	validation_0-ah_likelihood:3.29353	validation_1-ah_likelihood:3.32973
# [3]	validation_0-ah_likelihood:3.29353	validation_1-ah_likelihood:3.32973
#
	validation_0-ah_likelihood:3.20451	validation_1-ah_likelihood:3.23474
# [6]	validation_0-ah_likelihood:3.20450	validation_1-ah_likelihood:3.23474
# [7]	validation_0-ah_likelihood:3.20450	validation_1-ah_likelihood:3.23474
# [8]	validation_0-ah_likelihood:3.20451	validation_1-ah_likelihood:3.23474
# [9]	validation_0-ah_likelihood:3.20451	validation_1-ah_likelihood:3.23474
# [10]	validation_0-ah_likelihood:3.20451	validation_1-ah_likelihood:3.23474
# [0]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [1]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [2]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [3]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [4]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [5]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [6]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [7]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [8]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [9]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [0]	validation_0-ah_likelihood:3.17882	validation_1-ah_likelihood:3.22095
# [1]	validation_0-ah_likelihood:3.17882	validation_1-ah_likelihood:3.22095
# [2]	validation_0-ah_likelihood:3.17882	validation_1-ah_likelihood:3.22095
# [3]	validation_0-ah_likelihood:3.17882	validation_1-ah_likelihood:3.22095
# [4]	validation_0-ah_likelihood:3.17882	validation_1-ah_likelihood:3.22095
# [5]	validation_0-ah_likelihood:3.17882	validation_1-ah_likelihood:3.22095
# [6]	validation_0-ah_likelihood:3.17882	validation_1-ah_likelihood:3.22095
# [7]	validation_0-ah_likelihood:3.17882	validation_1-ah_likelihood:3.22095
# [8]	validation_0-ah_likelihood:3.17882	validation_1-ah_likelihood:3.22095
# [9]	validation_0-ah_likelihood:3.17882	validation_1-ah_likelihood:3.22095
# [10]	validation_0-ah_likelihood:3.17882	validation_1-ah_likelihood:3.22095
# [0]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [1]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [2]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [3]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [4]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [5]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [6]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [7]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [8]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [9]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [10]	validation_0-ah_likelihood:3.17112	validation_1-ah_likelihood:3.22085
# [0]	validation_0-ah_likelihood:3.14511	validation_1-ah_likelihood:3.19123
# [1]	validation_0-ah_likelihood:3.14511	validation_1-ah_likelihood:3.19123
# [2]	validation_0-ah_likelihood:3.14511	validation_1-ah_likelihood:3.19123
# [3]	validation_0-ah_likelihood:3.14511	validation_1-ah_likelihood:3.19123
# [4]	validation_0-ah_likelihood:3.14511	validation_1-ah_likelihood:3.19123
# [5]	validation_0-ah_likelihood:3.14511	validation_1-ah_likelihood:3.19123
# [6]	validation_0-ah_likelihood:3.14511	validation_1-ah_likelihood:3.19123
# [7]	validation_0-ah_likelihood:3.14511	validation_1-ah_likelihood:3.19123
# [8]	validation_0-ah_likelihood:3.14511	validation_1-ah_likelihood:3.19123
# [9]	validation_0-ah_likelihood:3.14511	validation_1-ah_likelihood:3.19123
# [10]	validation_0-ah_likelihood:3.14511	validation_1-ah_likelihood:3.19123
# [0]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [1]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [2]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [3]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [4]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [5]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [6]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [7]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [8]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [9]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [10]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [11]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [12]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# [13]	validation_0-ah_likelihood:3.13961	validation_1-ah_likelihood:3.32405
# Concordance Index 0.0
# Integrated Brier Score: 0.5660700451280688
# durations 13.0 3432.0
# Concordance Index 0.0
# Integrated Brier Score: 0.47875833581725
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 65
#      62 np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
#      63 np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
# ---> 65 np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
#      66 np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')
#      68 np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
#
# File <__array_function__ internals>:180, in savetxt(*args, **kwargs)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/numpy/lib/npyio.py:1595, in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1591         except TypeError as e:
#    1592             raise TypeError("Mismatch between array dtype ('%s') and "
#    1593                             "format specifier ('%s')"
#    1594                             % (str(X.dtype), format)) from e
# -> 1595         fh.write(v)
#    1597 if len(footer) > 0:
#    1598     footer = footer.replace('\n', '\n' + comments)
#
# KeyboardInterrupt:

# %%
df_final_ah_1_cindex = pd.concat([df for df in agg_metrics_cindex]).round(4)
df_final_ah_1_cindex.to_csv('metrics/final_gbdt_tcga_ah_1_cindex.csv', index=False)
df_final_ah_1_cindex.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_tcga_ah_1_cindex.csv', index=False)  #
df_final_ah_1_cindex
# Out:
#     dataset  cindex_train_mean  cindex_train_std  cindex_test_mean  \
# 0  METABRIC                0.0               0.0               0.0
#
#    cindex_test_std
# 0              0.0

# %%
df_final_ah_1_ibs = pd.concat([df for df in agg_metrics_ibs]).round(4)
df_final_ah_1_ibs.to_csv('metrics/final_gbdt_tcga_ah_1_ibs.csv', index=False)
df_final_ah_1_ibs.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_tcga_ah_1_ibs.csv', index=False) 
df_final_ah_1_ibs
# Out:
#   dataset  ibs_train_mean  ibs_train_std  ibs_test_mean  ibs_test_std
# 0    BLCA          0.2090         0.0047         0.2224        0.0066
# 0    BRCA          0.1854         0.0027         0.1962        0.0097
# 0    HNSC          0.1803         0.0054         0.2038        0.0062
# 0    KIRC          0.1969         0.0026         0.1998        0.0065
# 0     LGG          0.1690         0.0054         0.1912        0.0127
# 0    LIHC          0.2023         0.0074         0.2181        0.0136
# 0    LUAD          0.1851         0.0046         0.1990        0.0108
# 0    LUSC          0.1892         0.0039         0.2037        0.0119
# 0      OV          0.1266         0.0077         0.1442        0.0183
# 0    STAD          0.2056         0.0038         0.2166        0.0081
