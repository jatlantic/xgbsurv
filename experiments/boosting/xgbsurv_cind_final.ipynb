# %%
## XGBSurv Cind Benchmark

# %%
from xgbsurv.datasets import (load_metabric, load_flchain, load_rgbsg, load_support, load_tcga)
from xgbsurv import XGBSurv
from xgbsurv.evaluation import cindex_censored, ibs
from xgbsurv.models.utils import sort_X_y
import os
import numpy as np
import pandas as pd
from scipy.stats import uniform as scuniform
from scipy.stats import randint as scrandint
from scipy.stats import loguniform as scloguniform 
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, LabelBinarizer, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.decomposition import PCA
# import models
from xgbsurv.models.breslow_final import breslow_likelihood,get_cumulative_hazard_function_breslow
from xgbsurv.models.cind_final import cind_loss

from pycox.evaluation import EvalSurv
from xgbsurv.models.utils import sort_X_y_pandas, transform_back, transform
from xgbsurv.preprocessing.dataset_preprocessing import discretizer_df

# %% [markdown]
# ## Set Parameters

# %%
# set parameters
n_outer_splits = 5
n_inner_splits = 5
rand_state = 42
n_iter = 1,#50
early_stopping_rounds=10
base_score = 0.0

# Define parameter grid for random forest classifier
param_grid = {
#'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
# cind works only with very low learning rate
'estimator__learning_rate': scloguniform(0.01,1.0), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,8000),
#'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
}

# %% [markdown]
# ## Custom Splitting

# %%
class CustomSplit(StratifiedKFold):
    def __init__(self, n_splits=5, shuffle=True, random_state=None):
        super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)

    def split(self, X, y, groups=None):
        try:
            if y.shape[1]>1:
                y = y[:,0]
        except:
            pass
        bins = np.sign(y)
        return super().split(X, bins, groups=groups)

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

outer_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)
inner_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)

# %%
## Scoring Function

# %%
scoring_function = make_scorer(cind_loss, greater_is_better=False)

# %%
## Set Model & Train Test Evaluate

# %%
data_set_fns = [load_metabric,  load_flchain, load_rgbsg, load_support] #, load_flchain, load_rgbsg, load_support, load_tcga]
data_set_fns_str = ['load_metabric', 'load_flchain', 'load_rgbsg', 'load_support'] 
one_hot_dict = {'load_flchain': ['mgus'], 'load_support':['cancer'], 'load_rgbsg':['grade']}

agg_metrics_cindex = []
agg_metrics_ibs = []

for idx, dataset in enumerate(data_set_fns):
    model = 'xgbsurv_cind_'
    # get name of current dataset
    data = dataset(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=True)
    filename = data.filename
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()

    print(data_set_fns_str[idx])
    if data_set_fns_str[idx] in one_hot_dict.keys():
        X = pd.get_dummies(X, columns=one_hot_dict[data_set_fns_str[idx]])
    X, y = sort_X_y_pandas(X, y)
    #print(X.dtypes)
    dataset_name = filename.split('_')[0]
    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            #(OneHotEncoder(sparse_output=False), make_column_selector(dtype_include=['category', 'object']))
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='cind_objective',
        eval_metric='cind_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    pipe = Pipeline([('scaler',ct),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=2, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        print(X_train.shape, type(X_train))
        print(y_train.shape, type(y_train))
        print(X_test.shape, type(X_test))
        print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        #np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        #np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        #np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        #np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cindex_score_train = cindex_censored(y_train, best_preds_train)
            print('Concordance Index',cindex_score_train)
            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            #outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            
        try:

            cindex_score_test = cindex_censored(y_test,best_preds_test)


            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]

        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]

            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/xgbsurv_cind_metric_summary_'+str(i)+'_'+filename, index=False)
    # cindex
    df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                            'cindex_train_mean':df_outer_scores['cindex_train_'+dataset_name].mean(),
                                            'cindex_train_std':df_outer_scores['cindex_train_'+dataset_name].std(),
                                            'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                            'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })


    agg_metrics_cindex.append(df_agg_metrics_cindex)

df_final_cind_1_cindex = pd.concat([df for df in agg_metrics_cindex]).round(4)
df_final_cind_1_cindex.to_csv('metrics/final_gbdt_cind_1_cindex.csv', index=False)
df_final_cind_1_cindex.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_cind_1_cindex.csv', index=False)  #
df_final_cind_1_cindex
# Out:
# load_metabric
# (1522, 9) <class 'pandas.core.frame.DataFrame'>
# (1522,) <class 'pandas.core.series.Series'>
# (381, 9) <class 'pandas.core.frame.DataFrame'>
# (381,) <class 'pandas.core.series.Series'>
# [0]	validation_0-cind_loss:-282.26306	validation_1-cind_loss:-70.49092
# [0]	validation_0-cind_loss:-291.59255	validation_1-cind_loss:-71.27930
# [0]	validation_0-cind_loss:-282.63040	validation_1-cind_loss:-70.53056
# [0]	validation_0-cind_loss:-282.61372	validation_1-cind_loss:-70.51151
# [0]	validation_0-cind_loss:-291.02362	validation_1-cind_loss:-71.93473
# [0]	validation_0-cind_loss:-291.96172	validation_1-cind_loss:-71.43569
# [0]	validation_0-cind_loss:-282.21944	validation_1-cind_loss:-70.55330
# [1]	validation_0-cind_loss:-283.78273	validation_1-cind_loss:-70.61300
# [1]	validation_0-cind_loss:-294.06985	validation_1-cind_loss:-71.80454
# [1]	validation_0-cind_loss:-283.88622	validation_1-cind_loss:-70.60574
# [1]	validation_0-cind_loss:-283.81500	validation_1-cind_loss:-70.81695
# [0]	validation_0-cind_loss:-282.64648	validation_1-cind_loss:-70.51265
# [0]	validation_0-cind_loss:-290.93932	validation_1-cind_loss:-71.22446
# [1]	validation_0-cind_loss:-295.30627	validation_1-cind_loss:-71.91754
# [1]	validation_0-cind_loss:-283.96573	validation_1-cind_loss:-70.58911
# [1]	validation_0-cind_loss:-292.77189	validation_1-cind_loss:-72.08872
# [0]	validation_0-cind_loss:-291.42386	validation_1-cind_loss:-71.33101
# [2]	validation_0-cind_loss:-306.47063	validation_1-cind_loss:-72.30483
# [2]	validation_0-cind_loss:-285.11723	validation_1-cind_loss:-70.79938
# [2]	validation_0-cind_loss:-284.52254	validation_1-cind_loss:-70.64160
# [1]	validation_0-cind_loss:-293.60822	validation_1-cind_loss:-71.89983
# [1]	validation_0-cind_loss:-283.74255	validation_1-cind_loss:-70.55111
# [2]	validation_0-cind_loss:-284.14498	validation_1-cind_loss:-70.90625
# [1]	validation_0-cind_loss:-293.00963	validation_1-cind_loss:-71.50447
# [2]	validation_0-cind_loss:-307.84057	validation_1-cind_loss:-72.29593
# [2]	validation_0-cind_loss:-285.11534	validation_1-cind_loss:-70.84361
# [2]	validation_0-cind_loss:-295.96111	validation_1-cind_loss:-72.23665
# [3]	validation_0-cind_loss:-323.82449	validation_1-cind_loss:-74.14446
# [3]	validation_0-cind_loss:-286.95439	validation_1-cind_loss:-71.02879
# [3]	validation_0-cind_loss:-285.82016	validation_1-cind_loss:-70.70036
# [3]	validation_0-cind_loss:-286.56641	validation_1-cind_loss:-71.14218
# [2]	validation_0-cind_loss:-284.97835	validation_1-cind_loss:-70.81196
# [3]	validation_0-cind_loss:-285.06476	validation_1-cind_loss:-71.07988
# [2]	validation_0-cind_loss:-305.19502	validation_1-cind_loss:-73.04252
# [3]	validation_0-cind_loss:-329.13948	validation_1-cind_loss:-72.87204
# [2]	validation_0-cind_loss:-297.88818	validation_1-cind_loss:-71.55121
# [3]	validation_0-cind_loss:-296.92755	validation_1-cind_loss:-72.40097
# [4]	validation_0-cind_loss:-287.18171	validation_1-cind_loss:-71.21182
# [4]	validation_0-cind_loss:-287.55606	validation_1-cind_loss:-71.11375
# [4]	validation_0-cind_loss:-287.40944	validation_1-cind_loss:-70.61768
# [4]	validation_0-cind_loss:-325.06565	validation_1-cind_loss:-74.26361
# [4]	validation_0-cind_loss:-330.15619	validation_1-cind_loss:-73.11719
# [4]	validation_0-cind_loss:-286.30552	validation_1-cind_loss:-71.12369
# [3]	validation_0-cind_loss:-324.08273	validation_1-cind_loss:-73.77687
# [3]	validation_0-cind_loss:-299.15292	validation_1-cind_loss:-71.72683
# [3]	validation_0-cind_loss:-286.77430	validation_1-cind_loss:-71.16908
# [5]	validation_0-cind_loss:-288.53384	validation_1-cind_loss:-71.43808
# [5]	validation_0-cind_loss:-331.94368	validation_1-cind_loss:-74.29211
# [4]	validation_0-cind_loss:-305.49546	validation_1-cind_loss:-73.24701
# [5]	validation_0-cind_loss:-337.99864	validation_1-cind_loss:-73.39392
# [5]	validation_0-cind_loss:-289.33046	validation_1-cind_loss:-71.31915
# [4]	validation_0-cind_loss:-325.53756	validation_1-cind_loss:-73.89189
# [5]	validation_0-cind_loss:-290.05086	validation_1-cind_loss:-70.85183
# [4]	validation_0-cind_loss:-287.41088	validation_1-cind_loss:-71.22389
# [5]	validation_0-cind_loss:-289.56025	validation_1-cind_loss:-71.40794
# [4]	validation_0-cind_loss:-307.10422	validation_1-cind_loss:-72.50812
# [6]	validation_0-cind_loss:-290.41264	validation_1-cind_loss:-71.50040
# [6]	validation_0-cind_loss:-341.41179	validation_1-cind_loss:-73.38836
# [6]	validation_0-cind_loss:-291.32608	validation_1-cind_loss:-71.35860
# [6]	validation_0-cind_loss:-334.10026	validation_1-cind_loss:-74.38695
# [6]	validation_0-cind_loss:-290.13056	validation_1-cind_loss:-70.87900
# [5]	validation_0-cind_loss:-332.53746	validation_1-cind_loss:-73.69522
# [5]	validation_0-cind_loss:-288.94314	validation_1-cind_loss:-71.32136
# [5]	validation_0-cind_loss:-324.10241	validation_1-cind_loss:-73.85990
# [7]	validation_0-cind_loss:-292.43592	validation_1-cind_loss:-71.78451
# [7]	validation_0-cind_loss:-358.10586	validation_1-cind_loss:-73.90252
# [6]	validation_0-cind_loss:-289.62844	validation_1-cind_loss:-71.42601
# [5]	validation_0-cind_loss:-326.18145	validation_1-cind_loss:-73.34383
# [7]	validation_0-cind_loss:-293.72046	validation_1-cind_loss:-71.59246
# [7]	validation_0-cind_loss:-346.78417	validation_1-cind_loss:-74.70272
# [7]	validation_0-cind_loss:-292.75377	validation_1-cind_loss:-71.12641
# [8]	validation_0-cind_loss:-293.45846	validation_1-cind_loss:-71.88243
# [7]	validation_0-cind_loss:-292.82188	validation_1-cind_loss:-71.82336
# [6]	validation_0-cind_loss:-335.52186	validation_1-cind_loss:-73.49026
# [6]	validation_0-cind_loss:-325.01226	validation_1-cind_loss:-73.92790
# [8]	validation_0-cind_loss:-360.96215	validation_1-cind_loss:-74.49215
# [6]	validation_0-cind_loss:-326.71395	validation_1-cind_loss:-73.49204
# [8]	validation_0-cind_loss:-294.69022	validation_1-cind_loss:-71.76363
# [8]	validation_0-cind_loss:-349.98592	validation_1-cind_loss:-75.32704
# [6]	validation_0-cind_loss:-290.67086	validation_1-cind_loss:-71.28981
# [9]	validation_0-cind_loss:-294.91275	validation_1-cind_loss:-72.15943
# [8]	validation_0-cind_loss:-293.17478	validation_1-cind_loss:-71.85292
# [9]	validation_0-cind_loss:-362.97046	validation_1-cind_loss:-74.85720
# [8]	validation_0-cind_loss:-293.10458	validation_1-cind_loss:-71.13438
# [7]	validation_0-cind_loss:-325.73062	validation_1-cind_loss:-73.99239
# [7]	validation_0-cind_loss:-350.14749	validation_1-cind_loss:-74.06526
# [7]	validation_0-cind_loss:-327.25159	validation_1-cind_loss:-73.58764
# [7]	validation_0-cind_loss:-292.65721	validation_1-cind_loss:-71.70030
# [9]	validation_0-cind_loss:-351.74739	validation_1-cind_loss:-75.78276
# [9]	validation_0-cind_loss:-296.18946	validation_1-cind_loss:-72.10276
# [10]	validation_0-cind_loss:-295.11326	validation_1-cind_loss:-72.18047
# [10]	validation_0-cind_loss:-365.09418	validation_1-cind_loss:-74.85978
# [9]	validation_0-cind_loss:-294.33974	validation_1-cind_loss:-72.01889
# [9]	validation_0-cind_loss:-294.22333	validation_1-cind_loss:-71.10150
# [8]	validation_0-cind_loss:-328.18436	validation_1-cind_loss:-73.58504
# [8]	validation_0-cind_loss:-326.81861	validation_1-cind_loss:-74.08494
# [8]	validation_0-cind_loss:-353.05686	validation_1-cind_loss:-74.76955
# [10]	validation_0-cind_loss:-296.35622	validation_1-cind_loss:-72.12386
# [10]	validation_0-cind_loss:-353.53212	validation_1-cind_loss:-76.13568
# [8]	validation_0-cind_loss:-293.76966	validation_1-cind_loss:-71.77222
# [11]	validation_0-cind_loss:-297.69057	validation_1-cind_loss:-72.53445
# [11]	validation_0-cind_loss:-365.82172	validation_1-cind_loss:-74.98634
# [10]	validation_0-cind_loss:-296.84402	validation_1-cind_loss:-72.45363
# [9]	validation_0-cind_loss:-328.31981	validation_1-cind_loss:-73.63541
# [9]	validation_0-cind_loss:-326.96094	validation_1-cind_loss:-74.12660
# [10]	validation_0-cind_loss:-296.83018	validation_1-cind_loss:-71.33036
# [11]	validation_0-cind_loss:-354.16316	validation_1-cind_loss:-76.17999
# [11]	validation_0-cind_loss:-299.06312	validation_1-cind_loss:-72.47522
# [9]	validation_0-cind_loss:-355.12666	validation_1-cind_loss:-75.38410
# [12]	validation_0-cind_loss:-366.04497	validation_1-cind_loss:-75.06895
# [9]	validation_0-cind_loss:-295.17391	validation_1-cind_loss:-72.22816
# [11]	validation_0-cind_loss:-298.04916	validation_1-cind_loss:-72.67147
# [12]	validation_0-cind_loss:-298.85420	validation_1-cind_loss:-72.54582
# [10]	validation_0-cind_loss:-338.32691	validation_1-cind_loss:-74.99490
# [10]	validation_0-cind_loss:-337.69741	validation_1-cind_loss:-74.27386
# [12]	validation_0-cind_loss:-300.46008	validation_1-cind_loss:-72.57612
# [11]	validation_0-cind_loss:-297.91718	validation_1-cind_loss:-71.62332
# [12]	validation_0-cind_loss:-354.41603	validation_1-cind_loss:-76.19839
# [10]	validation_0-cind_loss:-356.87772	validation_1-cind_loss:-75.37508
# [13]	validation_0-cind_loss:-371.71100	validation_1-cind_loss:-75.33743
# [12]	validation_0-cind_loss:-298.29450	validation_1-cind_loss:-72.71675
# [10]	validation_0-cind_loss:-295.40479	validation_1-cind_loss:-72.24403
# [13]	validation_0-cind_loss:-299.98678	validation_1-cind_loss:-72.80670
# [11]	validation_0-cind_loss:-341.48117	validation_1-cind_loss:-75.68702
# [13]	validation_0-cind_loss:-301.70580	validation_1-cind_loss:-72.81430
# [11]	validation_0-cind_loss:-340.91821	validation_1-cind_loss:-74.79132
# [13]	validation_0-cind_loss:-358.60990	validation_1-cind_loss:-76.59461
# [12]	validation_0-cind_loss:-298.11031	validation_1-cind_loss:-71.68020
# [11]	validation_0-cind_loss:-357.41304	validation_1-cind_loss:-75.23198
# [14]	validation_0-cind_loss:-373.16773	validation_1-cind_loss:-75.50665
# [14]	validation_0-cind_loss:-301.30777	validation_1-cind_loss:-72.73625
# [11]	validation_0-cind_loss:-298.03636	validation_1-cind_loss:-72.70431
# [13]	validation_0-cind_loss:-300.76244	validation_1-cind_loss:-73.08416
# [12]	validation_0-cind_loss:-345.94937	validation_1-cind_loss:-75.73324
# [14]	validation_0-cind_loss:-303.36678	validation_1-cind_loss:-72.86218
# [14]	validation_0-cind_loss:-359.67152	validation_1-cind_loss:-76.65671
# [12]	validation_0-cind_loss:-345.79552	validation_1-cind_loss:-76.64676
# [15]	validation_0-cind_loss:-375.44719	validation_1-cind_loss:-76.07472
# [13]	validation_0-cind_loss:-300.24270	validation_1-cind_loss:-72.03695
# [12]	validation_0-cind_loss:-357.55618	validation_1-cind_loss:-75.26134
# [15]	validation_0-cind_loss:-303.74196	validation_1-cind_loss:-72.95549
# [13]	validation_0-cind_loss:-350.45141	validation_1-cind_loss:-76.37515
# [14]	validation_0-cind_loss:-301.02292	validation_1-cind_loss:-73.15567
# [12]	validation_0-cind_loss:-299.37644	validation_1-cind_loss:-72.69606
# [15]	validation_0-cind_loss:-305.81136	validation_1-cind_loss:-73.23443
# [13]	validation_0-cind_loss:-350.26163	validation_1-cind_loss:-77.28555
# [15]	validation_0-cind_loss:-362.75086	validation_1-cind_loss:-77.13633
# [13]	validation_0-cind_loss:-361.85962	validation_1-cind_loss:-75.68492
# [14]	validation_0-cind_loss:-300.81254	validation_1-cind_loss:-72.07795
# [13]	validation_0-cind_loss:-300.55270	validation_1-cind_loss:-73.05330
# [16]	validation_0-cind_loss:-375.55623	validation_1-cind_loss:-76.07792
# [15]	validation_0-cind_loss:-302.99593	validation_1-cind_loss:-73.51878
# [16]	validation_0-cind_loss:-362.83576	validation_1-cind_loss:-77.18428
# [16]	validation_0-cind_loss:-304.49145	validation_1-cind_loss:-73.04311
# [14]	validation_0-cind_loss:-351.98279	validation_1-cind_loss:-77.42969
# [14]	validation_0-cind_loss:-351.35566	validation_1-cind_loss:-76.42141
# [16]	validation_0-cind_loss:-306.77576	validation_1-cind_loss:-73.33175
# [14]	validation_0-cind_loss:-362.96280	validation_1-cind_loss:-75.88686
# [17]	validation_0-cind_loss:-376.89834	validation_1-cind_loss:-76.06266
# [14]	validation_0-cind_loss:-302.35826	validation_1-cind_loss:-73.06506
# [17]	validation_0-cind_loss:-364.05068	validation_1-cind_loss:-77.29763
# [16]	validation_0-cind_loss:-304.60241	validation_1-cind_loss:-73.62609
# [15]	validation_0-cind_loss:-302.41431	validation_1-cind_loss:-72.35578
# [15]	validation_0-cind_loss:-360.23437	validation_1-cind_loss:-77.85234
# [17]	validation_0-cind_loss:-308.25907	validation_1-cind_loss:-73.55221
# [15]	validation_0-cind_loss:-359.94385	validation_1-cind_loss:-77.13369
# [17]	validation_0-cind_loss:-305.63377	validation_1-cind_loss:-73.25420
# [18]	validation_0-cind_loss:-378.82628	validation_1-cind_loss:-76.24314
# [15]	validation_0-cind_loss:-365.40213	validation_1-cind_loss:-76.57082
# [15]	validation_0-cind_loss:-304.64860	validation_1-cind_loss:-73.46459
# [18]	validation_0-cind_loss:-366.05312	validation_1-cind_loss:-77.43099
# [16]	validation_0-cind_loss:-304.16655	validation_1-cind_loss:-72.49113
# [17]	validation_0-cind_loss:-305.43210	validation_1-cind_loss:-73.64181
# [16]	validation_0-cind_loss:-360.23770	validation_1-cind_loss:-77.85667
# [18]	validation_0-cind_loss:-306.23751	validation_1-cind_loss:-73.35153
# [18]	validation_0-cind_loss:-308.79951	validation_1-cind_loss:-73.68514
# [16]	validation_0-cind_loss:-360.05707	validation_1-cind_loss:-77.11456
# [19]	validation_0-cind_loss:-390.83180	validation_1-cind_loss:-77.64965
# [16]	validation_0-cind_loss:-365.46307	validation_1-cind_loss:-76.57790
# [19]	validation_0-cind_loss:-379.75262	validation_1-cind_loss:-78.16747
# [16]	validation_0-cind_loss:-305.33343	validation_1-cind_loss:-73.51265
# [18]	validation_0-cind_loss:-308.22519	validation_1-cind_loss:-74.13213
# [17]	validation_0-cind_loss:-305.07553	validation_1-cind_loss:-72.51523
# [19]	validation_0-cind_loss:-310.49927	validation_1-cind_loss:-73.72594
# [17]	validation_0-cind_loss:-361.56675	validation_1-cind_loss:-77.03967
# [19]	validation_0-cind_loss:-307.62591	validation_1-cind_loss:-73.43379
# [17]	validation_0-cind_loss:-361.33650	validation_1-cind_loss:-78.04312
# [17]	validation_0-cind_loss:-366.76824	validation_1-cind_loss:-76.59382
# [20]	validation_0-cind_loss:-395.39569	validation_1-cind_loss:-78.20922
# [17]	validation_0-cind_loss:-306.69824	validation_1-cind_loss:-73.59881
# [20]	validation_0-cind_loss:-384.20984	validation_1-cind_loss:-78.48708
# [19]	validation_0-cind_loss:-309.49060	validation_1-cind_loss:-74.31929
# [18]	validation_0-cind_loss:-307.60333	validation_1-cind_loss:-72.74700
# [20]	validation_0-cind_loss:-309.01759	validation_1-cind_loss:-73.77777
# [20]	validation_0-cind_loss:-312.43329	validation_1-cind_loss:-73.95255
# [18]	validation_0-cind_loss:-365.08224	validation_1-cind_loss:-77.24868
# [18]	validation_0-cind_loss:-365.18197	validation_1-cind_loss:-78.70362
# [18]	validation_0-cind_loss:-368.95682	validation_1-cind_loss:-76.84420
# [18]	validation_0-cind_loss:-307.34240	validation_1-cind_loss:-73.69773
# [21]	validation_0-cind_loss:-406.38487	validation_1-cind_loss:-78.20561
# [21]	validation_0-cind_loss:-311.69369	validation_1-cind_loss:-74.09055
# [19]	validation_0-cind_loss:-309.25318	validation_1-cind_loss:-72.84557
# [21]	validation_0-cind_loss:-393.71184	validation_1-cind_loss:-79.20537
# [20]	validation_0-cind_loss:-310.70858	validation_1-cind_loss:-74.59200
# [21]	validation_0-cind_loss:-315.06010	validation_1-cind_loss:-74.26292
# [19]	validation_0-cind_loss:-366.56268	validation_1-cind_loss:-78.58417
# [19]	validation_0-cind_loss:-366.46929	validation_1-cind_loss:-77.24647
# [19]	validation_0-cind_loss:-384.40610	validation_1-cind_loss:-77.96694
# [19]	validation_0-cind_loss:-309.30404	validation_1-cind_loss:-73.74214
# [22]	validation_0-cind_loss:-406.41067	validation_1-cind_loss:-78.22728
# [22]	validation_0-cind_loss:-312.98744	validation_1-cind_loss:-74.10677
# [20]	validation_0-cind_loss:-310.57538	validation_1-cind_loss:-73.09338
# [22]	validation_0-cind_loss:-393.73137	validation_1-cind_loss:-79.20200
# [21]	validation_0-cind_loss:-313.04695	validation_1-cind_loss:-75.02717
# [20]	validation_0-cind_loss:-372.86569	validation_1-cind_loss:-77.95082
# [20]	validation_0-cind_loss:-372.85782	validation_1-cind_loss:-79.17587
# [22]	validation_0-cind_loss:-316.40803	validation_1-cind_loss:-74.33373
# [20]	validation_0-cind_loss:-388.60938	validation_1-cind_loss:-78.39536
# [20]	validation_0-cind_loss:-310.75579	validation_1-cind_loss:-74.00462
# [21]	validation_0-cind_loss:-313.17262	validation_1-cind_loss:-73.62164
# [23]	validation_0-cind_loss:-406.42208	validation_1-cind_loss:-78.23745
# [23]	validation_0-cind_loss:-314.99199	validation_1-cind_loss:-74.36455
# [23]	validation_0-cind_loss:-393.77164	validation_1-cind_loss:-79.19389
# [21]	validation_0-cind_loss:-400.42495	validation_1-cind_loss:-78.88040
# [22]	validation_0-cind_loss:-314.18637	validation_1-cind_loss:-75.18773
# [21]	validation_0-cind_loss:-381.30978	validation_1-cind_loss:-78.40016
# [21]	validation_0-cind_loss:-382.84449	validation_1-cind_loss:-80.00705
# [23]	validation_0-cind_loss:-318.27426	validation_1-cind_loss:-74.54197
# [21]	validation_0-cind_loss:-313.00326	validation_1-cind_loss:-74.41429
# [24]	validation_0-cind_loss:-406.90145	validation_1-cind_loss:-78.27633
# [22]	validation_0-cind_loss:-313.98355	validation_1-cind_loss:-73.62775
# [24]	validation_0-cind_loss:-316.48882	validation_1-cind_loss:-74.65552
# [24]	validation_0-cind_loss:-394.52528	validation_1-cind_loss:-79.46267
# [23]	validation_0-cind_loss:-314.80987	validation_1-cind_loss:-75.27110
# [22]	validation_0-cind_loss:-382.67275	validation_1-cind_loss:-78.38977
# [22]	validation_0-cind_loss:-400.44380	validation_1-cind_loss:-78.88107
# [22]	validation_0-cind_loss:-314.07826	validation_1-cind_loss:-74.46341
# [25]	validation_0-cind_loss:-407.63815	validation_1-cind_loss:-78.37800
# [23]	validation_0-cind_loss:-314.96506	validation_1-cind_loss:-73.72244
# [24]	validation_0-cind_loss:-319.72012	validation_1-cind_loss:-74.79893
# [25]	validation_0-cind_loss:-395.33497	validation_1-cind_loss:-79.48752
# [25]	validation_0-cind_loss:-318.03861	validation_1-cind_loss:-74.94145
# [22]	validation_0-cind_loss:-385.15365	validation_1-cind_loss:-80.27393
# [23]	validation_0-cind_loss:-400.46576	validation_1-cind_loss:-78.88177
# [25]	validation_0-cind_loss:-321.24854	validation_1-cind_loss:-75.04842
# [23]	validation_0-cind_loss:-388.05541	validation_1-cind_loss:-78.46092
# [24]	validation_0-cind_loss:-315.87511	validation_1-cind_loss:-75.28520
# [26]	validation_0-cind_loss:-407.77439	validation_1-cind_loss:-78.34626
# [23]	validation_0-cind_loss:-316.00008	validation_1-cind_loss:-74.76332
# [24]	validation_0-cind_loss:-315.90902	validation_1-cind_loss:-73.74998
# [26]	validation_0-cind_loss:-395.51301	validation_1-cind_loss:-79.60996
# [23]	validation_0-cind_loss:-390.61351	validation_1-cind_loss:-80.88080
# [26]	validation_0-cind_loss:-318.20929	validation_1-cind_loss:-74.99795
# [24]	validation_0-cind_loss:-401.09699	validation_1-cind_loss:-79.18142
# [25]	validation_0-cind_loss:-317.00170	validation_1-cind_loss:-75.45738
# [25]	validation_0-cind_loss:-317.37591	validation_1-cind_loss:-73.72985
# [24]	validation_0-cind_loss:-389.29145	validation_1-cind_loss:-78.61855
# [27]	validation_0-cind_loss:-398.80467	validation_1-cind_loss:-79.84788
# [26]	validation_0-cind_loss:-321.53478	validation_1-cind_loss:-75.10101
# [27]	validation_0-cind_loss:-410.72056	validation_1-cind_loss:-78.85183
# [24]	validation_0-cind_loss:-317.51765	validation_1-cind_loss:-75.00647
# [24]	validation_0-cind_loss:-392.20615	validation_1-cind_loss:-81.27193
# [27]	validation_0-cind_loss:-320.18534	validation_1-cind_loss:-75.35630
# [25]	validation_0-cind_loss:-402.03614	validation_1-cind_loss:-79.33209
# [26]	validation_0-cind_loss:-318.03636	validation_1-cind_loss:-75.60075
# [27]	validation_0-cind_loss:-323.40458	validation_1-cind_loss:-75.33059
# [28]	validation_0-cind_loss:-410.86069	validation_1-cind_loss:-78.85283
# [25]	validation_0-cind_loss:-391.86396	validation_1-cind_loss:-78.79002
# [26]	validation_0-cind_loss:-318.55857	validation_1-cind_loss:-73.67829
# [25]	validation_0-cind_loss:-318.97796	validation_1-cind_loss:-75.35435
# [28]	validation_0-cind_loss:-398.91303	validation_1-cind_loss:-79.87436
# [25]	validation_0-cind_loss:-394.68296	validation_1-cind_loss:-81.44347
# [28]	validation_0-cind_loss:-320.74425	validation_1-cind_loss:-75.45051
# [29]	validation_0-cind_loss:-411.72773	validation_1-cind_loss:-78.74281
# [26]	validation_0-cind_loss:-402.19226	validation_1-cind_loss:-79.38982
# [28]	validation_0-cind_loss:-324.16176	validation_1-cind_loss:-75.52934
# [27]	validation_0-cind_loss:-319.04745	validation_1-cind_loss:-75.63980
# [26]	validation_0-cind_loss:-319.18616	validation_1-cind_loss:-75.39946
# [26]	validation_0-cind_loss:-394.45517	validation_1-cind_loss:-79.54491
# [26]	validation_0-cind_loss:-397.45819	validation_1-cind_loss:-81.87361
# [29]	validation_0-cind_loss:-400.06117	validation_1-cind_loss:-80.09445
# [27]	validation_0-cind_loss:-319.63567	validation_1-cind_loss:-73.69882
# [27]	validation_0-cind_loss:-405.51688	validation_1-cind_loss:-79.78812
# [29]	validation_0-cind_loss:-323.38121	validation_1-cind_loss:-75.81144
# [30]	validation_0-cind_loss:-411.75743	validation_1-cind_loss:-78.74569
# [29]	validation_0-cind_loss:-326.97120	validation_1-cind_loss:-75.84544
# [27]	validation_0-cind_loss:-321.03690	validation_1-cind_loss:-75.74957
# [28]	validation_0-cind_loss:-320.30445	validation_1-cind_loss:-75.68370
# [30]	validation_0-cind_loss:-400.09717	validation_1-cind_loss:-80.09711
# [28]	validation_0-cind_loss:-320.98496	validation_1-cind_loss:-73.80323
# [27]	validation_0-cind_loss:-394.69893	validation_1-cind_loss:-79.62014
# [27]	validation_0-cind_loss:-397.87147	validation_1-cind_loss:-81.80619
# [30]	validation_0-cind_loss:-325.78952	validation_1-cind_loss:-76.21035
# [28]	validation_0-cind_loss:-405.68454	validation_1-cind_loss:-79.84217
# [30]	validation_0-cind_loss:-329.72468	validation_1-cind_loss:-76.16420
# [31]	validation_0-cind_loss:-400.25580	validation_1-cind_loss:-80.18906
# [31]	validation_0-cind_loss:-411.91617	validation_1-cind_loss:-78.76257
# [29]	validation_0-cind_loss:-323.49795	validation_1-cind_loss:-74.11043
# [31]	validation_0-cind_loss:-327.48583	validation_1-cind_loss:-76.16186
# [29]	validation_0-cind_loss:-406.13977	validation_1-cind_loss:-79.85957
# [29]	validation_0-cind_loss:-322.95766	validation_1-cind_loss:-76.14366
# [31]	validation_0-cind_loss:-331.10067	validation_1-cind_loss:-76.11175
# [28]	validation_0-cind_loss:-321.68302	validation_1-cind_loss:-75.82707
# [32]	validation_0-cind_loss:-400.62211	validation_1-cind_loss:-80.32119
# [28]	validation_0-cind_loss:-397.04413	validation_1-cind_loss:-79.45223
# [28]	validation_0-cind_loss:-400.05361	validation_1-cind_loss:-81.99292
# [32]	validation_0-cind_loss:-329.70805	validation_1-cind_loss:-76.41135
# [32]	validation_0-cind_loss:-412.34958	validation_1-cind_loss:-78.71899
# [30]	validation_0-cind_loss:-323.56684	validation_1-cind_loss:-74.10111
# [30]	validation_0-cind_loss:-322.96234	validation_1-cind_loss:-76.14982
# [32]	validation_0-cind_loss:-333.22433	validation_1-cind_loss:-76.44145
# [29]	validation_0-cind_loss:-324.06088	validation_1-cind_loss:-76.23822
# [30]	validation_0-cind_loss:-406.20783	validation_1-cind_loss:-79.88603
# [33]	validation_0-cind_loss:-406.03178	validation_1-cind_loss:-80.37525
# [31]	validation_0-cind_loss:-323.69439	validation_1-cind_loss:-74.07495
# [29]	validation_0-cind_loss:-401.38984	validation_1-cind_loss:-82.26605
# [33]	validation_0-cind_loss:-417.72565	validation_1-cind_loss:-79.35750
# [29]	validation_0-cind_loss:-398.04433	validation_1-cind_loss:-79.54991
# [33]	validation_0-cind_loss:-332.14326	validation_1-cind_loss:-76.55318
# [33]	validation_0-cind_loss:-335.04252	validation_1-cind_loss:-76.57517
# [31]	validation_0-cind_loss:-323.06979	validation_1-cind_loss:-76.16872
# [30]	validation_0-cind_loss:-326.24836	validation_1-cind_loss:-76.45355
# [31]	validation_0-cind_loss:-406.31765	validation_1-cind_loss:-79.94065
# [30]	validation_0-cind_loss:-403.81847	validation_1-cind_loss:-82.17401
# [34]	validation_0-cind_loss:-409.42208	validation_1-cind_loss:-80.33982
# [34]	validation_0-cind_loss:-420.13173	validation_1-cind_loss:-79.21178
# [32]	validation_0-cind_loss:-323.77762	validation_1-cind_loss:-74.06326
# [34]	validation_0-cind_loss:-332.36441	validation_1-cind_loss:-76.55172
# [30]	validation_0-cind_loss:-400.82670	validation_1-cind_loss:-79.40150
# [31]	validation_0-cind_loss:-327.81928	validation_1-cind_loss:-76.64653
# [32]	validation_0-cind_loss:-323.06974	validation_1-cind_loss:-76.16866
# [34]	validation_0-cind_loss:-335.21794	validation_1-cind_loss:-76.57272
# [32]	validation_0-cind_loss:-406.66691	validation_1-cind_loss:-79.88792
# [35]	validation_0-cind_loss:-412.17413	validation_1-cind_loss:-80.77531
# [31]	validation_0-cind_loss:-405.02683	validation_1-cind_loss:-82.43186
# [33]	validation_0-cind_loss:-326.38264	validation_1-cind_loss:-74.47021
# [32]	validation_0-cind_loss:-330.07187	validation_1-cind_loss:-77.08242
# [35]	validation_0-cind_loss:-422.83158	validation_1-cind_loss:-79.33202
# [35]	validation_0-cind_loss:-332.75896	validation_1-cind_loss:-76.59684
# [31]	validation_0-cind_loss:-402.48297	validation_1-cind_loss:-79.49409
# [35]	validation_0-cind_loss:-335.45002	validation_1-cind_loss:-76.60020
# [33]	validation_0-cind_loss:-325.76998	validation_1-cind_loss:-76.64070
# [33]	validation_0-cind_loss:-412.32653	validation_1-cind_loss:-80.22241
# [36]	validation_0-cind_loss:-412.19578	validation_1-cind_loss:-80.78022
# [34]	validation_0-cind_loss:-327.52757	validation_1-cind_loss:-74.46492
# [32]	validation_0-cind_loss:-407.21860	validation_1-cind_loss:-82.03676
# [36]	validation_0-cind_loss:-332.75866	validation_1-cind_loss:-76.59738
# [36]	validation_0-cind_loss:-422.84532	validation_1-cind_loss:-79.33170
# [32]	validation_0-cind_loss:-406.05817	validation_1-cind_loss:-79.69794
# [33]	validation_0-cind_loss:-331.95597	validation_1-cind_loss:-77.44142
# [36]	validation_0-cind_loss:-335.45863	validation_1-cind_loss:-76.60370
# [34]	validation_0-cind_loss:-414.60562	validation_1-cind_loss:-80.03141
# [34]	validation_0-cind_loss:-326.90004	validation_1-cind_loss:-76.67241
# [37]	validation_0-cind_loss:-421.02140	validation_1-cind_loss:-81.03605
# [33]	validation_0-cind_loss:-407.88383	validation_1-cind_loss:-82.17256
# [35]	validation_0-cind_loss:-327.69509	validation_1-cind_loss:-74.44473
# [37]	validation_0-cind_loss:-333.04587	validation_1-cind_loss:-76.62052
# [37]	validation_0-cind_loss:-430.45427	validation_1-cind_loss:-79.78656
# [34]	validation_0-cind_loss:-332.15718	validation_1-cind_loss:-77.44713
# [35]	validation_0-cind_loss:-327.06297	validation_1-cind_loss:-76.68811
# [33]	validation_0-cind_loss:-406.90163	validation_1-cind_loss:-79.99762
# [38]	validation_0-cind_loss:-421.19089	validation_1-cind_loss:-81.07166
# [37]	validation_0-cind_loss:-335.76926	validation_1-cind_loss:-76.66377
# [35]	validation_0-cind_loss:-417.03818	validation_1-cind_loss:-80.17964
# [36]	validation_0-cind_loss:-328.70695	validation_1-cind_loss:-74.76277
# [34]	validation_0-cind_loss:-408.41226	validation_1-cind_loss:-82.32941
# [38]	validation_0-cind_loss:-430.57795	validation_1-cind_loss:-79.83908
# [38]	validation_0-cind_loss:-333.71704	validation_1-cind_loss:-76.67675
# [35]	validation_0-cind_loss:-332.50155	validation_1-cind_loss:-77.50510
# [34]	validation_0-cind_loss:-407.34587	validation_1-cind_loss:-79.84551
# [36]	validation_0-cind_loss:-328.41056	validation_1-cind_loss:-76.90158
# [36]	validation_0-cind_loss:-417.07762	validation_1-cind_loss:-80.18682
# [38]	validation_0-cind_loss:-336.45776	validation_1-cind_loss:-76.84962
# [37]	validation_0-cind_loss:-328.77294	validation_1-cind_loss:-74.78752
# [39]	validation_0-cind_loss:-422.52540	validation_1-cind_loss:-81.09715
# [35]	validation_0-cind_loss:-409.16919	validation_1-cind_loss:-82.20348
# [39]	validation_0-cind_loss:-334.27807	validation_1-cind_loss:-76.76603
# [39]	validation_0-cind_loss:-431.88739	validation_1-cind_loss:-79.80395
# [36]	validation_0-cind_loss:-332.50175	validation_1-cind_loss:-77.50626
# [35]	validation_0-cind_loss:-408.08462	validation_1-cind_loss:-79.84972
# [37]	validation_0-cind_loss:-328.44612	validation_1-cind_loss:-76.91206
# [37]	validation_0-cind_loss:-428.26475	validation_1-cind_loss:-80.40445
# [39]	validation_0-cind_loss:-336.87471	validation_1-cind_loss:-76.93399
# [38]	validation_0-cind_loss:-329.75455	validation_1-cind_loss:-74.77465
# [40]	validation_0-cind_loss:-430.75803	validation_1-cind_loss:-81.90254
# [40]	validation_0-cind_loss:-334.59197	validation_1-cind_loss:-76.76592
# [36]	validation_0-cind_loss:-412.28974	validation_1-cind_loss:-82.54198
# [40]	validation_0-cind_loss:-439.72822	validation_1-cind_loss:-80.67627
# [37]	validation_0-cind_loss:-332.79367	validation_1-cind_loss:-77.54720
# [38]	validation_0-cind_loss:-428.39068	validation_1-cind_loss:-80.46822
# [36]	validation_0-cind_loss:-410.53956	validation_1-cind_loss:-79.42841
# [38]	validation_0-cind_loss:-329.52492	validation_1-cind_loss:-77.09272
# [40]	validation_0-cind_loss:-337.09720	validation_1-cind_loss:-76.91632
# [41]	validation_0-cind_loss:-430.95327	validation_1-cind_loss:-81.92248
# [41]	validation_0-cind_loss:-336.21715	validation_1-cind_loss:-76.99686
# [39]	validation_0-cind_loss:-331.32050	validation_1-cind_loss:-75.05544
# [41]	validation_0-cind_loss:-439.87300	validation_1-cind_loss:-80.72012
# [37]	validation_0-cind_loss:-416.56308	validation_1-cind_loss:-82.85655
# [38]	validation_0-cind_loss:-333.50240	validation_1-cind_loss:-77.64749
# [42]	validation_0-cind_loss:-431.01209	validation_1-cind_loss:-81.92857
# [37]	validation_0-cind_loss:-416.81175	validation_1-cind_loss:-79.63905
# [39]	validation_0-cind_loss:-330.93590	validation_1-cind_loss:-77.47964
# [41]	validation_0-cind_loss:-339.00731	validation_1-cind_loss:-77.19348
# [42]	validation_0-cind_loss:-439.98382	validation_1-cind_loss:-80.74433
# [42]	validation_0-cind_loss:-337.05076	validation_1-cind_loss:-77.05855
# [40]	validation_0-cind_loss:-332.02657	validation_1-cind_loss:-75.07408
# [39]	validation_0-cind_loss:-429.16934	validation_1-cind_loss:-80.57262
# [38]	validation_0-cind_loss:-416.83519	validation_1-cind_loss:-82.73320
# [39]	validation_0-cind_loss:-333.95153	validation_1-cind_loss:-77.68808
# [43]	validation_0-cind_loss:-431.06228	validation_1-cind_loss:-81.95601
# [38]	validation_0-cind_loss:-417.02629	validation_1-cind_loss:-79.61119
# [42]	validation_0-cind_loss:-339.65852	validation_1-cind_loss:-77.32542
# [43]	validation_0-cind_loss:-338.24651	validation_1-cind_loss:-77.03055
# [40]	validation_0-cind_loss:-434.65558	validation_1-cind_loss:-80.30224
# [40]	validation_0-cind_loss:-331.40047	validation_1-cind_loss:-77.53457
# [41]	validation_0-cind_loss:-332.45846	validation_1-cind_loss:-75.09856
# [43]	validation_0-cind_loss:-440.04714	validation_1-cind_loss:-80.76696
# [44]	validation_0-cind_loss:-431.63587	validation_1-cind_loss:-82.01451
# [39]	validation_0-cind_loss:-417.44133	validation_1-cind_loss:-79.69579
# [39]	validation_0-cind_loss:-417.14898	validation_1-cind_loss:-82.90538
# [40]	validation_0-cind_loss:-334.11587	validation_1-cind_loss:-77.69851
# [41]	validation_0-cind_loss:-434.82976	validation_1-cind_loss:-80.31194
# [43]	validation_0-cind_loss:-340.53434	validation_1-cind_loss:-77.39373
# [44]	validation_0-cind_loss:-338.29368	validation_1-cind_loss:-77.05721
# [41]	validation_0-cind_loss:-331.87892	validation_1-cind_loss:-77.68177
# [42]	validation_0-cind_loss:-332.60780	validation_1-cind_loss:-75.14661
# [44]	validation_0-cind_loss:-440.56075	validation_1-cind_loss:-80.91742
# [42]	validation_0-cind_loss:-434.91550	validation_1-cind_loss:-80.32107
# [40]	validation_0-cind_loss:-420.51746	validation_1-cind_loss:-82.84515
# [43]	validation_0-cind_loss:-434.98604	validation_1-cind_loss:-80.32524
# [45]	validation_0-cind_loss:-339.38831	validation_1-cind_loss:-77.02345
# [40]	validation_0-cind_loss:-421.87924	validation_1-cind_loss:-80.10202
# [45]	validation_0-cind_loss:-441.30568	validation_1-cind_loss:-80.93588
# [43]	validation_0-cind_loss:-332.73559	validation_1-cind_loss:-75.15729
# [44]	validation_0-cind_loss:-340.58826	validation_1-cind_loss:-77.39310
# [42]	validation_0-cind_loss:-332.04620	validation_1-cind_loss:-77.71890
# [41]	validation_0-cind_loss:-335.79920	validation_1-cind_loss:-77.94730
# [45]	validation_0-cind_loss:-432.97105	validation_1-cind_loss:-82.02709
# [41]	validation_0-cind_loss:-421.20169	validation_1-cind_loss:-82.85634
# [46]	validation_0-cind_loss:-340.16481	validation_1-cind_loss:-77.08533
# [44]	validation_0-cind_loss:-435.80840	validation_1-cind_loss:-80.38845
# [41]	validation_0-cind_loss:-422.72550	validation_1-cind_loss:-79.97018
# [45]	validation_0-cind_loss:-341.79604	validation_1-cind_loss:-77.48434
# [46]	validation_0-cind_loss:-441.42174	validation_1-cind_loss:-80.99774
# [44]	validation_0-cind_loss:-334.94374	validation_1-cind_loss:-75.57647
# [43]	validation_0-cind_loss:-332.14294	validation_1-cind_loss:-77.75194
# [42]	validation_0-cind_loss:-336.58367	validation_1-cind_loss:-78.04169
# [46]	validation_0-cind_loss:-433.17183	validation_1-cind_loss:-82.19700
# [42]	validation_0-cind_loss:-421.86341	validation_1-cind_loss:-82.93126
# [47]	validation_0-cind_loss:-341.26374	validation_1-cind_loss:-77.31242
# [45]	validation_0-cind_loss:-436.73396	validation_1-cind_loss:-80.25642
# [42]	validation_0-cind_loss:-423.59472	validation_1-cind_loss:-79.94931
# [47]	validation_0-cind_loss:-442.03632	validation_1-cind_loss:-81.03080
# [46]	validation_0-cind_loss:-342.70267	validation_1-cind_loss:-77.55958
# [44]	validation_0-cind_loss:-334.32661	validation_1-cind_loss:-78.14303
# [45]	validation_0-cind_loss:-336.29158	validation_1-cind_loss:-75.63210
# [47]	validation_0-cind_loss:-434.04528	validation_1-cind_loss:-82.37468
# [43]	validation_0-cind_loss:-337.66415	validation_1-cind_loss:-78.12925
# [43]	validation_0-cind_loss:-424.42512	validation_1-cind_loss:-83.39006
# [46]	validation_0-cind_loss:-436.85771	validation_1-cind_loss:-80.34226
# [43]	validation_0-cind_loss:-426.14881	validation_1-cind_loss:-80.12357
# [48]	validation_0-cind_loss:-341.62849	validation_1-cind_loss:-77.39066
# [47]	validation_0-cind_loss:-343.69610	validation_1-cind_loss:-77.67597
# [48]	validation_0-cind_loss:-443.26262	validation_1-cind_loss:-80.92553
# [48]	validation_0-cind_loss:-436.95851	validation_1-cind_loss:-82.25816
# [46]	validation_0-cind_loss:-338.45779	validation_1-cind_loss:-75.95985
# [44]	validation_0-cind_loss:-425.81338	validation_1-cind_loss:-83.70397
# [44]	validation_0-cind_loss:-337.68774	validation_1-cind_loss:-78.13101
# [45]	validation_0-cind_loss:-335.31016	validation_1-cind_loss:-78.17417
# [48]	validation_0-cind_loss:-344.17867	validation_1-cind_loss:-77.66841
# [49]	validation_0-cind_loss:-446.54415	validation_1-cind_loss:-80.52789
# [49]	validation_0-cind_loss:-343.21123	validation_1-cind_loss:-77.69757
# [47]	validation_0-cind_loss:-437.51646	validation_1-cind_loss:-80.10287
# [44]	validation_0-cind_loss:-428.43831	validation_1-cind_loss:-80.10215
# [49]	validation_0-cind_loss:-441.74788	validation_1-cind_loss:-81.80128
# [47]	validation_0-cind_loss:-339.88277	validation_1-cind_loss:-75.96102
# [46]	validation_0-cind_loss:-337.30517	validation_1-cind_loss:-78.57306
# [45]	validation_0-cind_loss:-425.96876	validation_1-cind_loss:-83.72409
# [45]	validation_0-cind_loss:-339.04721	validation_1-cind_loss:-78.19195
# [50]	validation_0-cind_loss:-448.76984	validation_1-cind_loss:-81.02158
# [49]	validation_0-cind_loss:-345.74801	validation_1-cind_loss:-77.93501
# [50]	validation_0-cind_loss:-343.59147	validation_1-cind_loss:-77.76634
# [45]	validation_0-cind_loss:-428.72754	validation_1-cind_loss:-80.06185
# [48]	validation_0-cind_loss:-438.98741	validation_1-cind_loss:-80.33743
# [50]	validation_0-cind_loss:-442.79100	validation_1-cind_loss:-82.12402
# [48]	validation_0-cind_loss:-341.54220	validation_1-cind_loss:-76.30379
# [47]	validation_0-cind_loss:-338.73363	validation_1-cind_loss:-78.80902
# [50]	validation_0-cind_loss:-346.14009	validation_1-cind_loss:-77.98250
# [46]	validation_0-cind_loss:-339.93751	validation_1-cind_loss:-78.28546
# [46]	validation_0-cind_loss:-431.63122	validation_1-cind_loss:-84.40844
# [51]	validation_0-cind_loss:-448.84077	validation_1-cind_loss:-81.02543
# [51]	validation_0-cind_loss:-344.31533	validation_1-cind_loss:-77.97902
# [46]	validation_0-cind_loss:-433.69564	validation_1-cind_loss:-80.51225
# [49]	validation_0-cind_loss:-442.70861	validation_1-cind_loss:-80.32736
# [49]	validation_0-cind_loss:-343.12781	validation_1-cind_loss:-76.63481
# [47]	validation_0-cind_loss:-341.10684	validation_1-cind_loss:-78.29286
# [51]	validation_0-cind_loss:-442.83179	validation_1-cind_loss:-82.15764
# [48]	validation_0-cind_loss:-340.50247	validation_1-cind_loss:-79.07706
# [51]	validation_0-cind_loss:-346.90946	validation_1-cind_loss:-78.11011
# [52]	validation_0-cind_loss:-448.84137	validation_1-cind_loss:-81.02690
# [47]	validation_0-cind_loss:-434.80846	validation_1-cind_loss:-84.51771
# [52]	validation_0-cind_loss:-345.19544	validation_1-cind_loss:-77.81439
# [47]	validation_0-cind_loss:-436.38039	validation_1-cind_loss:-80.32241
# [52]	validation_0-cind_loss:-442.83331	validation_1-cind_loss:-82.16906
# [48]	validation_0-cind_loss:-341.61962	validation_1-cind_loss:-78.29776
# [50]	validation_0-cind_loss:-344.44945	validation_1-cind_loss:-76.56801
# [52]	validation_0-cind_loss:-347.87474	validation_1-cind_loss:-78.21295
# [49]	validation_0-cind_loss:-342.52160	validation_1-cind_loss:-79.38103
# [53]	validation_0-cind_loss:-449.70968	validation_1-cind_loss:-81.04918
# [48]	validation_0-cind_loss:-434.96626	validation_1-cind_loss:-84.61302
# [53]	validation_0-cind_loss:-347.02664	validation_1-cind_loss:-78.24904
# [48]	validation_0-cind_loss:-436.60109	validation_1-cind_loss:-80.45728
# [49]	validation_0-cind_loss:-343.26688	validation_1-cind_loss:-78.65506
# [53]	validation_0-cind_loss:-443.56577	validation_1-cind_loss:-82.34545
# [51]	validation_0-cind_loss:-344.98076	validation_1-cind_loss:-76.54697
# [54]	validation_0-cind_loss:-450.01816	validation_1-cind_loss:-81.09287
# [53]	validation_0-cind_loss:-349.81747	validation_1-cind_loss:-78.42598
# [50]	validation_0-cind_loss:-343.36088	validation_1-cind_loss:-79.39652
# [54]	validation_0-cind_loss:-347.81236	validation_1-cind_loss:-78.49438
# [49]	validation_0-cind_loss:-435.15219	validation_1-cind_loss:-84.79470
# [50]	validation_0-cind_loss:-343.81758	validation_1-cind_loss:-78.65847
# [54]	validation_0-cind_loss:-443.93049	validation_1-cind_loss:-82.39551
# [49]	validation_0-cind_loss:-436.81054	validation_1-cind_loss:-80.51269
# [52]	validation_0-cind_loss:-346.44746	validation_1-cind_loss:-76.69074
# [55]	validation_0-cind_loss:-450.07311	validation_1-cind_loss:-81.12300
# [50]	validation_0-cind_loss:-435.21041	validation_1-cind_loss:-84.74191
# [54]	validation_0-cind_loss:-350.93811	validation_1-cind_loss:-78.65289
# [51]	validation_0-cind_loss:-343.80407	validation_1-cind_loss:-79.35661
# [55]	validation_0-cind_loss:-348.00611	validation_1-cind_loss:-78.51296
# [51]	validation_0-cind_loss:-344.89251	validation_1-cind_loss:-78.89971
# [50]	validation_0-cind_loss:-436.86486	validation_1-cind_loss:-80.52929
# [55]	validation_0-cind_loss:-443.97137	validation_1-cind_loss:-82.42914
# [53]	validation_0-cind_loss:-348.17709	validation_1-cind_loss:-77.06082
# [55]	validation_0-cind_loss:-351.19444	validation_1-cind_loss:-78.67678
# [56]	validation_0-cind_loss:-454.07059	validation_1-cind_loss:-80.64192
# [56]	validation_0-cind_loss:-348.82109	validation_1-cind_loss:-78.73448
# [51]	validation_0-cind_loss:-435.31775	validation_1-cind_loss:-84.80039
# [52]	validation_0-cind_loss:-345.53382	validation_1-cind_loss:-79.49517
# [52]	validation_0-cind_loss:-345.77677	validation_1-cind_loss:-78.94257
# [51]	validation_0-cind_loss:-436.97255	validation_1-cind_loss:-80.59678
# [56]	validation_0-cind_loss:-448.66707	validation_1-cind_loss:-82.69236
# [54]	validation_0-cind_loss:-349.57419	validation_1-cind_loss:-77.16492
# [53]	validation_0-cind_loss:-347.31851	validation_1-cind_loss:-79.90923
# [52]	validation_0-cind_loss:-436.68746	validation_1-cind_loss:-84.82477
# [56]	validation_0-cind_loss:-352.10280	validation_1-cind_loss:-78.87169
# [57]	validation_0-cind_loss:-455.37626	validation_1-cind_loss:-80.68121
# [57]	validation_0-cind_loss:-349.58620	validation_1-cind_loss:-78.77079
# [53]	validation_0-cind_loss:-347.85449	validation_1-cind_loss:-79.41268
# [52]	validation_0-cind_loss:-438.32984	validation_1-cind_loss:-80.84771
# [57]	validation_0-cind_loss:-450.60154	validation_1-cind_loss:-82.77555
# [55]	validation_0-cind_loss:-349.65141	validation_1-cind_loss:-77.14194
# [57]	validation_0-cind_loss:-352.86176	validation_1-cind_loss:-78.92422
# [54]	validation_0-cind_loss:-348.20398	validation_1-cind_loss:-80.07045
# [53]	validation_0-cind_loss:-442.63946	validation_1-cind_loss:-85.24745
# [58]	validation_0-cind_loss:-455.56505	validation_1-cind_loss:-80.73969
# [58]	validation_0-cind_loss:-350.63628	validation_1-cind_loss:-79.00217
# [54]	validation_0-cind_loss:-349.09117	validation_1-cind_loss:-79.68956
# [53]	validation_0-cind_loss:-444.19638	validation_1-cind_loss:-81.39739
# [58]	validation_0-cind_loss:-450.78915	validation_1-cind_loss:-82.77981
# [56]	validation_0-cind_loss:-350.08763	validation_1-cind_loss:-77.15879
# [55]	validation_0-cind_loss:-348.27790	validation_1-cind_loss:-80.09025
# [58]	validation_0-cind_loss:-353.62468	validation_1-cind_loss:-78.86814
# [59]	validation_0-cind_loss:-457.19752	validation_1-cind_loss:-80.59077
# [55]	validation_0-cind_loss:-349.38618	validation_1-cind_loss:-79.73535
# [54]	validation_0-cind_loss:-445.16134	validation_1-cind_loss:-85.07565
# [59]	validation_0-cind_loss:-351.77432	validation_1-cind_loss:-78.87222
# [59]	validation_0-cind_loss:-451.93209	validation_1-cind_loss:-82.65100
# [54]	validation_0-cind_loss:-446.75142	validation_1-cind_loss:-81.25630
# [57]	validation_0-cind_loss:-350.57711	validation_1-cind_loss:-77.16232
# [59]	validation_0-cind_loss:-354.80667	validation_1-cind_loss:-78.85100
# [56]	validation_0-cind_loss:-348.83470	validation_1-cind_loss:-80.13879
# [60]	validation_0-cind_loss:-457.20631	validation_1-cind_loss:-80.59389
# [55]	validation_0-cind_loss:-445.71112	validation_1-cind_loss:-85.11038
# [60]	validation_0-cind_loss:-352.31709	validation_1-cind_loss:-78.88068
# [56]	validation_0-cind_loss:-350.27700	validation_1-cind_loss:-79.99760
# [60]	validation_0-cind_loss:-451.94117	validation_1-cind_loss:-82.66288
# [55]	validation_0-cind_loss:-447.01097	validation_1-cind_loss:-81.45683
# [58]	validation_0-cind_loss:-351.91653	validation_1-cind_loss:-77.47079
# [56]	validation_0-cind_loss:-449.33150	validation_1-cind_loss:-81.70955
# [57]	validation_0-cind_loss:-349.21205	validation_1-cind_loss:-80.22120
# [61]	validation_0-cind_loss:-352.73145	validation_1-cind_loss:-78.87676
# [56]	validation_0-cind_loss:-446.71115	validation_1-cind_loss:-84.92120
# [61]	validation_0-cind_loss:-457.25793	validation_1-cind_loss:-80.62263
# [61]	validation_0-cind_loss:-451.98359	validation_1-cind_loss:-82.69080
# [57]	validation_0-cind_loss:-350.78441	validation_1-cind_loss:-80.07489
# [60]	validation_0-cind_loss:-355.49859	validation_1-cind_loss:-78.83662
# [59]	validation_0-cind_loss:-352.84033	validation_1-cind_loss:-77.50506
# [58]	validation_0-cind_loss:-350.56082	validation_1-cind_loss:-80.46769
# [57]	validation_0-cind_loss:-449.48015	validation_1-cind_loss:-81.68735
# [62]	validation_0-cind_loss:-354.56331	validation_1-cind_loss:-79.26297
# [58]	validation_0-cind_loss:-351.57997	validation_1-cind_loss:-80.11417
# [61]	validation_0-cind_loss:-355.79236	validation_1-cind_loss:-78.87055
# [62]	validation_0-cind_loss:-453.24468	validation_1-cind_loss:-83.07129
# [62]	validation_0-cind_loss:-458.22706	validation_1-cind_loss:-80.89143
# [57]	validation_0-cind_loss:-446.86328	validation_1-cind_loss:-85.07386
# [60]	validation_0-cind_loss:-352.91255	validation_1-cind_loss:-77.48299
# [59]	validation_0-cind_loss:-351.54445	validation_1-cind_loss:-80.54273
# [58]	validation_0-cind_loss:-449.48021	validation_1-cind_loss:-81.69030
# [63]	validation_0-cind_loss:-355.09094	validation_1-cind_loss:-79.28521
# [63]	validation_0-cind_loss:-453.28463	validation_1-cind_loss:-83.07414
# [59]	validation_0-cind_loss:-352.65361	validation_1-cind_loss:-80.14395
# [58]	validation_0-cind_loss:-446.86398	validation_1-cind_loss:-85.06909
# [62]	validation_0-cind_loss:-357.73285	validation_1-cind_loss:-79.10786
# [63]	validation_0-cind_loss:-458.29676	validation_1-cind_loss:-80.83330
# [59]	validation_0-cind_loss:-449.62835	validation_1-cind_loss:-81.65638
# [61]	validation_0-cind_loss:-354.33447	validation_1-cind_loss:-77.59907
# [60]	validation_0-cind_loss:-351.62660	validation_1-cind_loss:-80.55410
# [64]	validation_0-cind_loss:-355.71228	validation_1-cind_loss:-79.38721
# [64]	validation_0-cind_loss:-459.47560	validation_1-cind_loss:-80.83267
# [59]	validation_0-cind_loss:-447.01452	validation_1-cind_loss:-85.09540
# [63]	validation_0-cind_loss:-358.29766	validation_1-cind_loss:-79.23456
# [64]	validation_0-cind_loss:-456.48445	validation_1-cind_loss:-82.80441
# [60]	validation_0-cind_loss:-353.19752	validation_1-cind_loss:-80.13780
# [62]	validation_0-cind_loss:-354.59019	validation_1-cind_loss:-77.69425
# [65]	validation_0-cind_loss:-356.83883	validation_1-cind_loss:-79.64466
# [60]	validation_0-cind_loss:-451.40752	validation_1-cind_loss:-81.60540
# [60]	validation_0-cind_loss:-448.05105	validation_1-cind_loss:-85.36361
# [61]	validation_0-cind_loss:-353.06820	validation_1-cind_loss:-80.97111
# [65]	validation_0-cind_loss:-459.92199	validation_1-cind_loss:-80.76804
# [64]	validation_0-cind_loss:-358.89591	validation_1-cind_loss:-79.29264
# [61]	validation_0-cind_loss:-353.58902	validation_1-cind_loss:-80.18942
# [65]	validation_0-cind_loss:-456.95675	validation_1-cind_loss:-82.74517
# [63]	validation_0-cind_loss:-355.90389	validation_1-cind_loss:-77.82967
# [61]	validation_0-cind_loss:-452.16335	validation_1-cind_loss:-81.75952
# [66]	validation_0-cind_loss:-357.26764	validation_1-cind_loss:-79.81298
# [65]	validation_0-cind_loss:-360.06127	validation_1-cind_loss:-79.45533
# [61]	validation_0-cind_loss:-448.58798	validation_1-cind_loss:-85.61556
# [62]	validation_0-cind_loss:-353.37508	validation_1-cind_loss:-81.08318
# [66]	validation_0-cind_loss:-458.33253	validation_1-cind_loss:-82.85017
# [62]	validation_0-cind_loss:-355.59188	validation_1-cind_loss:-80.59078
# [64]	validation_0-cind_loss:-355.97240	validation_1-cind_loss:-77.80735
# [62]	validation_0-cind_loss:-458.03681	validation_1-cind_loss:-81.95353
# [67]	validation_0-cind_loss:-358.64135	validation_1-cind_loss:-79.74376
# [66]	validation_0-cind_loss:-360.54372	validation_1-cind_loss:-79.60768
# [63]	validation_0-cind_loss:-354.78623	validation_1-cind_loss:-81.34344
# [62]	validation_0-cind_loss:-454.30144	validation_1-cind_loss:-85.70555
# [67]	validation_0-cind_loss:-460.92120	validation_1-cind_loss:-82.59855
# [63]	validation_0-cind_loss:-356.16670	validation_1-cind_loss:-80.58083
# [65]	validation_0-cind_loss:-357.58745	validation_1-cind_loss:-77.97583
# [63]	validation_0-cind_loss:-458.03681	validation_1-cind_loss:-81.95353
# [68]	validation_0-cind_loss:-359.42237	validation_1-cind_loss:-79.97126
# [67]	validation_0-cind_loss:-361.93844	validation_1-cind_loss:-79.63488
# [64]	validation_0-cind_loss:-354.86685	validation_1-cind_loss:-81.35330
# [63]	validation_0-cind_loss:-454.44490	validation_1-cind_loss:-85.67217
# [68]	validation_0-cind_loss:-462.63048	validation_1-cind_loss:-82.13393
# [64]	validation_0-cind_loss:-356.86199	validation_1-cind_loss:-80.62139
# [64]	validation_0-cind_loss:-458.10275	validation_1-cind_loss:-82.07383
# [66]	validation_0-cind_loss:-358.68532	validation_1-cind_loss:-78.14952
# [69]	validation_0-cind_loss:-360.75439	validation_1-cind_loss:-80.15972
# [68]	validation_0-cind_loss:-363.16743	validation_1-cind_loss:-79.78502
# [65]	validation_0-cind_loss:-356.15137	validation_1-cind_loss:-81.47473
# [65]	validation_0-cind_loss:-357.79650	validation_1-cind_loss:-80.88568
# [64]	validation_0-cind_loss:-454.58849	validation_1-cind_loss:-85.76023
# [69]	validation_0-cind_loss:-463.13548	validation_1-cind_loss:-81.97338
# [67]	validation_0-cind_loss:-359.84919	validation_1-cind_loss:-78.29367
# [65]	validation_0-cind_loss:-460.99170	validation_1-cind_loss:-82.04711
# [70]	validation_0-cind_loss:-361.70972	validation_1-cind_loss:-80.34068
# [66]	validation_0-cind_loss:-357.51525	validation_1-cind_loss:-81.65292
# [66]	validation_0-cind_loss:-358.29217	validation_1-cind_loss:-81.07730
# [69]	validation_0-cind_loss:-364.29073	validation_1-cind_loss:-79.95999
# [65]	validation_0-cind_loss:-455.87015	validation_1-cind_loss:-85.70051
# [70]	validation_0-cind_loss:-463.56689	validation_1-cind_loss:-82.01828
# [68]	validation_0-cind_loss:-361.27824	validation_1-cind_loss:-78.41465
# [67]	validation_0-cind_loss:-359.34228	validation_1-cind_loss:-80.98371
# [67]	validation_0-cind_loss:-358.78112	validation_1-cind_loss:-81.87429
# ...
# [62]	validation_0-cind_loss:-597.50162	validation_1-cind_loss:-148.42023
# [66]	validation_0-cind_loss:-609.96337	validation_1-cind_loss:-150.48249
# [63]	validation_0-cind_loss:-884.27577	validation_1-cind_loss:-207.13742
# [62]	validation_0-cind_loss:-597.85993	validation_1-cind_loss:-149.38661
# [64]	validation_0-cind_loss:-889.55504	validation_1-cind_loss:-207.70852
# [64]	validation_0-cind_loss:-600.70813	validation_1-cind_loss:-148.54335
# [63]	validation_0-cind_loss:-599.49986	validation_1-cind_loss:-147.92852
# [63]	validation_0-cind_loss:-879.28853	validation_1-cind_loss:-211.54800
# [67]	validation_0-cind_loss:-879.07904	validation_1-cind_loss:-213.22372
# [64]	validation_0-cind_loss:-886.04955	validation_1-cind_loss:-204.20066
# [63]	validation_0-cind_loss:-597.51050	validation_1-cind_loss:-148.41912
# [67]	validation_0-cind_loss:-610.37945	validation_1-cind_loss:-150.57835
# [64]	validation_0-cind_loss:-884.43596	validation_1-cind_loss:-207.17104
# [63]	validation_0-cind_loss:-597.86851	validation_1-cind_loss:-149.38781
# [65]	validation_0-cind_loss:-890.82287	validation_1-cind_loss:-208.12312
# [65]	validation_0-cind_loss:-601.38503	validation_1-cind_loss:-148.68453
# [68]	validation_0-cind_loss:-880.01587	validation_1-cind_loss:-213.27197
# [64]	validation_0-cind_loss:-599.55401	validation_1-cind_loss:-147.93312
# [65]	validation_0-cind_loss:-886.87245	validation_1-cind_loss:-204.23479
# [64]	validation_0-cind_loss:-879.61243	validation_1-cind_loss:-211.53705
# [68]	validation_0-cind_loss:-611.84680	validation_1-cind_loss:-150.92587
# [64]	validation_0-cind_loss:-597.52684	validation_1-cind_loss:-148.42321
# [65]	validation_0-cind_loss:-884.74767	validation_1-cind_loss:-207.22543
# [66]	validation_0-cind_loss:-892.59459	validation_1-cind_loss:-208.53889
# [64]	validation_0-cind_loss:-597.88769	validation_1-cind_loss:-149.39273
# [66]	validation_0-cind_loss:-602.19794	validation_1-cind_loss:-148.85149
# [65]	validation_0-cind_loss:-600.17791	validation_1-cind_loss:-148.07924
# [69]	validation_0-cind_loss:-880.38784	validation_1-cind_loss:-213.27876
# [66]	validation_0-cind_loss:-887.87340	validation_1-cind_loss:-204.35070
# [65]	validation_0-cind_loss:-880.13203	validation_1-cind_loss:-211.64349
# [69]	validation_0-cind_loss:-613.60419	validation_1-cind_loss:-151.33032
# [65]	validation_0-cind_loss:-598.15473	validation_1-cind_loss:-148.54552
# [67]	validation_0-cind_loss:-893.74398	validation_1-cind_loss:-208.67550
# [66]	validation_0-cind_loss:-885.76341	validation_1-cind_loss:-207.33159
# [65]	validation_0-cind_loss:-598.47328	validation_1-cind_loss:-149.56623
# [67]	validation_0-cind_loss:-602.57643	validation_1-cind_loss:-148.96423
# [70]	validation_0-cind_loss:-880.74596	validation_1-cind_loss:-213.21858
# [66]	validation_0-cind_loss:-881.11255	validation_1-cind_loss:-211.87159
# [66]	validation_0-cind_loss:-600.90364	validation_1-cind_loss:-148.23927
# [67]	validation_0-cind_loss:-888.65577	validation_1-cind_loss:-204.52262
# [70]	validation_0-cind_loss:-614.36945	validation_1-cind_loss:-151.45589
# [66]	validation_0-cind_loss:-598.89233	validation_1-cind_loss:-148.69106
# [66]	validation_0-cind_loss:-599.18322	validation_1-cind_loss:-149.76383
# [68]	validation_0-cind_loss:-894.35580	validation_1-cind_loss:-208.81238
# [68]	validation_0-cind_loss:-604.07750	validation_1-cind_loss:-149.31467
# [67]	validation_0-cind_loss:-886.57118	validation_1-cind_loss:-207.59027
# [71]	validation_0-cind_loss:-880.93168	validation_1-cind_loss:-213.20602
# [67]	validation_0-cind_loss:-882.30281	validation_1-cind_loss:-212.10401
# [68]	validation_0-cind_loss:-889.86551	validation_1-cind_loss:-204.79773
# [67]	validation_0-cind_loss:-601.37447	validation_1-cind_loss:-148.32335
# [71]	validation_0-cind_loss:-615.03843	validation_1-cind_loss:-151.58785
# [67]	validation_0-cind_loss:-599.33122	validation_1-cind_loss:-148.79336
# [69]	validation_0-cind_loss:-895.26789	validation_1-cind_loss:-208.84041
# [68]	validation_0-cind_loss:-887.32000	validation_1-cind_loss:-207.81516
# [67]	validation_0-cind_loss:-599.63615	validation_1-cind_loss:-149.89390
# [69]	validation_0-cind_loss:-604.09533	validation_1-cind_loss:-149.32326
# [72]	validation_0-cind_loss:-881.91601	validation_1-cind_loss:-213.41272
# [68]	validation_0-cind_loss:-883.50803	validation_1-cind_loss:-212.39630
# [68]	validation_0-cind_loss:-602.81645	validation_1-cind_loss:-148.67509
# [69]	validation_0-cind_loss:-890.71506	validation_1-cind_loss:-204.84878
# [72]	validation_0-cind_loss:-615.94997	validation_1-cind_loss:-151.74792
# [68]	validation_0-cind_loss:-600.73825	validation_1-cind_loss:-149.15656
# [70]	validation_0-cind_loss:-605.89714	validation_1-cind_loss:-149.73273
# [69]	validation_0-cind_loss:-888.12234	validation_1-cind_loss:-207.79649
# [70]	validation_0-cind_loss:-895.71465	validation_1-cind_loss:-209.07963
# [68]	validation_0-cind_loss:-601.10185	validation_1-cind_loss:-150.27544
# [73]	validation_0-cind_loss:-882.08916	validation_1-cind_loss:-213.38827
# [69]	validation_0-cind_loss:-884.28916	validation_1-cind_loss:-212.47652
# [69]	validation_0-cind_loss:-602.85903	validation_1-cind_loss:-148.67867
# [70]	validation_0-cind_loss:-891.01472	validation_1-cind_loss:-204.77312
# [73]	validation_0-cind_loss:-617.84688	validation_1-cind_loss:-152.15742
# [69]	validation_0-cind_loss:-600.75771	validation_1-cind_loss:-149.16144
# [71]	validation_0-cind_loss:-606.58264	validation_1-cind_loss:-149.86778
# [71]	validation_0-cind_loss:-896.04467	validation_1-cind_loss:-209.06944
# [69]	validation_0-cind_loss:-601.11835	validation_1-cind_loss:-150.27969
# [70]	validation_0-cind_loss:-888.18851	validation_1-cind_loss:-207.74098
# [74]	validation_0-cind_loss:-882.92848	validation_1-cind_loss:-213.58236
# [70]	validation_0-cind_loss:-884.56351	validation_1-cind_loss:-212.52695
# [70]	validation_0-cind_loss:-604.70500	validation_1-cind_loss:-149.06110
# [71]	validation_0-cind_loss:-891.16752	validation_1-cind_loss:-204.84779
# [74]	validation_0-cind_loss:-617.86687	validation_1-cind_loss:-152.16262
# [70]	validation_0-cind_loss:-602.46878	validation_1-cind_loss:-149.59013
# [70]	validation_0-cind_loss:-602.91724	validation_1-cind_loss:-150.70882
# [72]	validation_0-cind_loss:-897.38913	validation_1-cind_loss:-209.24017
# [72]	validation_0-cind_loss:-606.61288	validation_1-cind_loss:-149.87889
# [75]	validation_0-cind_loss:-883.66838	validation_1-cind_loss:-213.79507
# [71]	validation_0-cind_loss:-888.32742	validation_1-cind_loss:-207.75615
# [71]	validation_0-cind_loss:-884.65906	validation_1-cind_loss:-212.53822
# [72]	validation_0-cind_loss:-891.70461	validation_1-cind_loss:-204.95254
# [71]	validation_0-cind_loss:-605.35669	validation_1-cind_loss:-149.19623
# [75]	validation_0-cind_loss:-618.31095	validation_1-cind_loss:-152.26628
# [71]	validation_0-cind_loss:-603.08492	validation_1-cind_loss:-149.71050
# [76]	validation_0-cind_loss:-884.23656	validation_1-cind_loss:-213.89453
# [71]	validation_0-cind_loss:-603.46193	validation_1-cind_loss:-150.85852
# [73]	validation_0-cind_loss:-607.16652	validation_1-cind_loss:-149.99049
# [73]	validation_0-cind_loss:-898.34547	validation_1-cind_loss:-209.44233
# [72]	validation_0-cind_loss:-889.33857	validation_1-cind_loss:-207.88430
# [72]	validation_0-cind_loss:-885.57694	validation_1-cind_loss:-212.64755
# [72]	validation_0-cind_loss:-605.40822	validation_1-cind_loss:-149.20284
# [76]	validation_0-cind_loss:-618.35135	validation_1-cind_loss:-152.27543
# [73]	validation_0-cind_loss:-892.03659	validation_1-cind_loss:-204.99855
# [72]	validation_0-cind_loss:-603.48366	validation_1-cind_loss:-150.86327
# [74]	validation_0-cind_loss:-607.99182	validation_1-cind_loss:-150.16102
# [72]	validation_0-cind_loss:-603.12925	validation_1-cind_loss:-149.71417
# [77]	validation_0-cind_loss:-884.81132	validation_1-cind_loss:-213.91051
# [73]	validation_0-cind_loss:-889.37901	validation_1-cind_loss:-207.92544
# [74]	validation_0-cind_loss:-898.70529	validation_1-cind_loss:-209.24787
# [73]	validation_0-cind_loss:-886.09615	validation_1-cind_loss:-212.66430
# [73]	validation_0-cind_loss:-605.91208	validation_1-cind_loss:-149.31926
# [77]	validation_0-cind_loss:-619.19970	validation_1-cind_loss:-152.44028
# [74]	validation_0-cind_loss:-892.81419	validation_1-cind_loss:-205.22118
# [73]	validation_0-cind_loss:-603.96134	validation_1-cind_loss:-150.98910
# [78]	validation_0-cind_loss:-885.39561	validation_1-cind_loss:-214.03194
# [73]	validation_0-cind_loss:-603.63768	validation_1-cind_loss:-149.81978
# [75]	validation_0-cind_loss:-608.68533	validation_1-cind_loss:-150.29015
# [75]	validation_0-cind_loss:-900.00113	validation_1-cind_loss:-209.66967
# [74]	validation_0-cind_loss:-890.32687	validation_1-cind_loss:-208.13497
# [74]	validation_0-cind_loss:-886.73760	validation_1-cind_loss:-212.83729
# [74]	validation_0-cind_loss:-606.57842	validation_1-cind_loss:-149.46188
# [78]	validation_0-cind_loss:-620.63579	validation_1-cind_loss:-152.76341
# [75]	validation_0-cind_loss:-893.74292	validation_1-cind_loss:-205.43956
# [74]	validation_0-cind_loss:-604.58921	validation_1-cind_loss:-151.14506
# [74]	validation_0-cind_loss:-604.39166	validation_1-cind_loss:-149.96591
# [79]	validation_0-cind_loss:-885.78139	validation_1-cind_loss:-214.13696
# [76]	validation_0-cind_loss:-610.30437	validation_1-cind_loss:-150.69857
# [76]	validation_0-cind_loss:-900.15298	validation_1-cind_loss:-209.61107
# [75]	validation_0-cind_loss:-891.06752	validation_1-cind_loss:-208.31262
# [75]	validation_0-cind_loss:-887.71813	validation_1-cind_loss:-212.89073
# [75]	validation_0-cind_loss:-607.14727	validation_1-cind_loss:-149.58450
# [79]	validation_0-cind_loss:-622.29865	validation_1-cind_loss:-153.14733
# [76]	validation_0-cind_loss:-894.62212	validation_1-cind_loss:-205.52548
# [75]	validation_0-cind_loss:-605.09148	validation_1-cind_loss:-151.28755
# [80]	validation_0-cind_loss:-886.73100	validation_1-cind_loss:-214.24708
# [75]	validation_0-cind_loss:-605.00443	validation_1-cind_loss:-150.08730
# [77]	validation_0-cind_loss:-901.11988	validation_1-cind_loss:-209.69274
# [77]	validation_0-cind_loss:-612.04827	validation_1-cind_loss:-151.09961
# [76]	validation_0-cind_loss:-891.74528	validation_1-cind_loss:-208.35996
# [76]	validation_0-cind_loss:-888.59977	validation_1-cind_loss:-213.09084
# [76]	validation_0-cind_loss:-608.89060	validation_1-cind_loss:-149.95327
# [80]	validation_0-cind_loss:-624.11715	validation_1-cind_loss:-153.54340
# [77]	validation_0-cind_loss:-895.30114	validation_1-cind_loss:-205.64068
# [76]	validation_0-cind_loss:-606.77965	validation_1-cind_loss:-151.71299
# [76]	validation_0-cind_loss:-606.60297	validation_1-cind_loss:-150.49709
# [78]	validation_0-cind_loss:-613.74904	validation_1-cind_loss:-151.46252
# [78]	validation_0-cind_loss:-902.01132	validation_1-cind_loss:-209.72916
# [81]	validation_0-cind_loss:-887.57126	validation_1-cind_loss:-214.34476
# [77]	validation_0-cind_loss:-892.01954	validation_1-cind_loss:-208.36317
# [77]	validation_0-cind_loss:-889.23333	validation_1-cind_loss:-213.11110
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 66
#      58 np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
#      60 #np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
#      61 #np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')
#      62
#      63 #np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
#      64 #np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')
# ---> 66 rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
#      67 best_preds_train = rs.best_estimator_.predict(X_train)
#      68 best_preds_test = rs.best_estimator_.predict(X_test)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1768, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1766 def _run_search(self, evaluate_candidates):
#    1767     """Search n_iter candidates from param_distributions"""
# -> 1768     evaluate_candidates(
#    1769         ParameterSampler(
#    1770             self.param_distributions, self.n_iter, random_state=self.random_state
#    1771         )
#    1772     )
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
pd.DataFrame(outer_scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.DataFrame(outer_scores)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/pandas/core/internals/construction.py:481, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     477     else:
#     478         # dtype check to exclude e.g. range objects, scalars
#     479         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 481 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/pandas/core/internals/construction.py:115, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     112 if verify_integrity:
#     113     # figure out the index, if necessary
#     114     if index is None:
# --> 115         index = _extract_index(arrays)
#     116     else:
#     117         index = ensure_index(index)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/pandas/core/internals/construction.py:655, in _extract_index(data)
#     653 lengths = list(set(raw_lengths))
#     654 if len(lengths) > 1:
# --> 655     raise ValueError("All arrays must be of the same length")
#     657 if have_dicts:
#     658     raise ValueError(
#     659         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     660     )
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# ## TCGA Train, Test, Evaluation

# %%
param_grid = {
#'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.01,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,8000), # corresponds to num_rounds
#'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
'pca__n_components': [8, 10, 12, 14, 16]
}

# %%
cancer_types = ['BLCA',
    'BRCA',
    'HNSC',
    'KIRC',
    'LGG',
    'LIHC',
    'LUAD',
    'LUSC',
    'OV',
    'STAD']

agg_metrics_cindex = []
agg_metrics_ibs = []

for idx, cancer_type in enumerate(cancer_types):
    model = 'xgbsurv_cind_'
    # get name of current dataset
    data = load_tcga(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", cancer_type=cancer_type, as_frame=True)
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()
    filename = data.filename
    dataset_name = filename.split('_')[0]
    X, y = sort_X_y_pandas(X, y)

    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            #(OneHotEncoder(sparse_output=False), make_column_selector(dtype_include=['category', 'object']))
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='cind_objective',
        eval_metric='cind_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    
    pipe = Pipeline([('scaler',ct),
                    ('pca', PCA()),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=2, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        print(X_train.shape, type(X_train))
        print(y_train.shape, type(y_train))
        print(X_test.shape, type(X_test))
        print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        #np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        #np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        #np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        #np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:

        
            cindex_score_train = cindex_censored(y_train, best_preds_train)
            print('Concordance Index',cindex_score_train)
            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            #outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            
        try:

            cindex_score_test = cindex_censored(y_test,best_preds_test)


            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]

        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]

            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/metric_summary_'+str(i)+'_'+filename, index=False)
    # cindex
    df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                            'cindex_train_mean':df_outer_scores['cindex_train_'+dataset_name].mean(),
                                            'cindex_train_std':df_outer_scores['cindex_train_'+dataset_name].std(),
                                            'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                            'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })


    agg_metrics_cindex.append(df_agg_metrics_cindex)

df_final_cind_1_cindex = pd.concat([df for df in agg_metrics_cindex]).round(4)
df_final_cind_1_cindex.to_csv('metrics/final_gbdt_tcga_cind_1_cindex.csv', index=False)
df_final_cind_1_cindex.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_tcga_cind_1_cindex.csv', index=False)  #
df_final_cind_1_cindex
# Out:
# (324, 20531) <class 'pandas.core.frame.DataFrame'>
# (324,) <class 'pandas.core.series.Series'>
# (82, 20531) <class 'pandas.core.frame.DataFrame'>
# (82,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:4.23220	validation_1-breslow_likelihood:3.17639
# [1]	validation_0-breslow_likelihood:4.13138	validation_1-breslow_likelihood:3.12117
# [2]	validation_0-breslow_likelihood:4.10251	validation_1-breslow_likelihood:3.24152
# [3]	validation_0-breslow_likelihood:4.06283	validation_1-breslow_likelihood:3.27751
# [4]	validation_0-breslow_likelihood:3.96997	validation_1-breslow_likelihood:3.34330
# [5]	validation_0-breslow_likelihood:3.93729	validation_1-breslow_likelihood:3.36013
# [6]	validation_0-breslow_likelihood:3.89891	validation_1-breslow_likelihood:3.34272
# [7]	validation_0-breslow_likelihood:3.85069	validation_1-breslow_likelihood:3.43695
# [8]	validation_0-breslow_likelihood:3.79533	validation_1-breslow_likelihood:3.40617
# [9]	validation_0-breslow_likelihood:3.73514	validation_1-breslow_likelihood:3.58653
# [10]	validation_0-breslow_likelihood:3.69756	validation_1-breslow_likelihood:3.72883
# [11]	validation_0-breslow_likelihood:3.63982	validation_1-breslow_likelihood:3.74788
# [0]	validation_0-breslow_likelihood:4.32913	validation_1-breslow_likelihood:3.12371
# [1]	validation_0-breslow_likelihood:4.32394	validation_1-breslow_likelihood:3.11593
# [2]	validation_0-breslow_likelihood:4.30560	validation_1-breslow_likelihood:3.12006
# [3]	validation_0-breslow_likelihood:4.29616	validation_1-breslow_likelihood:3.11443
# [4]	validation_0-breslow_likelihood:4.28670	validation_1-breslow_likelihood:3.11369
# [5]	validation_0-breslow_likelihood:4.27172	validation_1-breslow_likelihood:3.10482
# [6]	validation_0-breslow_likelihood:4.25422	validation_1-breslow_likelihood:3.11640
# [7]	validation_0-breslow_likelihood:4.25451	validation_1-breslow_likelihood:3.11704
# [8]	validation_0-breslow_likelihood:4.24722	validation_1-breslow_likelihood:3.12738
# [9]	validation_0-breslow_likelihood:4.23966	validation_1-breslow_likelihood:3.13025
# [10]	validation_0-breslow_likelihood:4.23489	validation_1-breslow_likelihood:3.12720
# [11]	validation_0-breslow_likelihood:4.22330	validation_1-breslow_likelihood:3.13625
# [12]	validation_0-breslow_likelihood:4.20549	validation_1-breslow_likelihood:3.14221
# [13]	validation_0-breslow_likelihood:4.19745	validation_1-breslow_likelihood:3.13076
# [14]	validation_0-breslow_likelihood:4.18784	validation_1-breslow_likelihood:3.13210
# [15]	validation_0-breslow_likelihood:4.18198	validation_1-breslow_likelihood:3.13015
# [0]	validation_0-breslow_likelihood:4.10032	validation_1-breslow_likelihood:3.01642
# [1]	validation_0-breslow_likelihood:4.03685	validation_1-breslow_likelihood:3.08510
# [2]	validation_0-breslow_likelihood:3.96470	validation_1-breslow_likelihood:3.04959
# [3]	validation_0-breslow_likelihood:3.89980	validation_1-breslow_likelihood:3.10514
# [4]	validation_0-breslow_likelihood:3.85480	validation_1-breslow_likelihood:3.41186
# [5]	validation_0-breslow_likelihood:3.79870	validation_1-breslow_likelihood:3.34492
# [6]	validation_0-breslow_likelihood:3.76893	validation_1-breslow_likelihood:3.33139
# [7]	validation_0-breslow_likelihood:3.72994	validation_1-breslow_likelihood:3.30585
# [8]	validation_0-breslow_likelihood:3.69877	validation_1-breslow_likelihood:3.30672
# [9]	validation_0-breslow_likelihood:3.65063	validation_1-breslow_likelihood:3.22981
# [0]	validation_0-breslow_likelihood:4.25770	validation_1-breslow_likelihood:3.23887
# [1]	validation_0-breslow_likelihood:4.20034	validation_1-breslow_likelihood:3.29221
# [2]	validation_0-breslow_likelihood:4.18231	validation_1-breslow_likelihood:3.36097
# [3]	validation_0-breslow_likelihood:4.14546	validation_1-breslow_likelihood:3.22147
# [4]	validation_0-breslow_likelihood:4.11181	validation_1-breslow_likelihood:3.25860
# [5]	validation_0-breslow_likelihood:4.04637	validation_1-breslow_likelihood:3.28492
# [6]	validation_0-breslow_likelihood:4.00948	validation_1-breslow_likelihood:3.29724
# [7]	validation_0-breslow_likelihood:3.95433	validation_1-breslow_likelihood:3.29456
# [8]	validation_0-breslow_likelihood:3.92510	validation_1-breslow_likelihood:3.37934
# [9]	validation_0-breslow_likelihood:3.83893	validation_1-breslow_likelihood:3.46851
# [10]	validation_0-breslow_likelihood:3.77772	validation_1-breslow_likelihood:3.45156
# [11]	validation_0-breslow_likelihood:3.71749	validation_1-breslow_likelihood:3.40629
# [12]	validation_0-breslow_likelihood:3.66192	validation_1-breslow_likelihood:3.50114
# [13]	validation_0-breslow_likelihood:3.62311	validation_1-breslow_likelihood:3.40481
# [0]	validation_0-breslow_likelihood:4.35074	validation_1-breslow_likelihood:3.18599
# [1]	validation_0-breslow_likelihood:4.34374	validation_1-breslow_likelihood:3.18118
# [2]	validation_0-breslow_likelihood:4.33380	validation_1-breslow_likelihood:3.18251
# [3]	validation_0-breslow_likelihood:4.31919	validation_1-breslow_likelihood:3.16035
# [4]	validation_0-breslow_likelihood:4.30936	validation_1-breslow_likelihood:3.16007
# [5]	validation_0-breslow_likelihood:4.29776	validation_1-breslow_likelihood:3.16018
# [6]	validation_0-breslow_likelihood:4.28725	validation_1-breslow_likelihood:3.14946
# [7]	validation_0-breslow_likelihood:4.28055	validation_1-breslow_likelihood:3.14582
# [8]	validation_0-breslow_likelihood:4.26713	validation_1-breslow_likelihood:3.14354
# [9]	validation_0-breslow_likelihood:4.25373	validation_1-breslow_likelihood:3.13822
# [10]	validation_0-breslow_likelihood:4.24311	validation_1-breslow_likelihood:3.13337
# [11]	validation_0-breslow_likelihood:4.23947	validation_1-breslow_likelihood:3.13740
# [12]	validation_0-breslow_likelihood:4.23192	validation_1-breslow_likelihood:3.12832
# [13]	validation_0-breslow_likelihood:4.22369	validation_1-breslow_likelihood:3.13145
# [14]	validation_0-breslow_likelihood:4.21590	validation_1-breslow_likelihood:3.11539
# [15]	validation_0-breslow_likelihood:4.20255	validation_1-breslow_likelihood:3.11449
# [16]	validation_0-breslow_likelihood:4.19472	validation_1-breslow_likelihood:3.11489
# [17]	validation_0-breslow_likelihood:4.18972	validation_1-breslow_likelihood:3.12778
# [18]	validation_0-breslow_likelihood:4.18199	validation_1-breslow_likelihood:3.11441
# [0]	validation_0-breslow_likelihood:4.28530	validation_1-breslow_likelihood:3.01357
# [19]	validation_0-breslow_likelihood:4.17936	validation_1-breslow_likelihood:3.11130
# [1]	validation_0-breslow_likelihood:4.15855	validation_1-breslow_likelihood:3.01030
# [20]	validation_0-breslow_likelihood:4.17038	validation_1-breslow_likelihood:3.11118
# [2]	validation_0-breslow_likelihood:4.08345	validation_1-breslow_likelihood:3.03330
# [21]	validation_0-breslow_likelihood:4.16148	validation_1-breslow_likelihood:3.10690
# [3]	validation_0-breslow_likelihood:4.06188	validation_1-breslow_likelihood:3.00701
# [4]	validation_0-breslow_likelihood:4.00700	validation_1-breslow_likelihood:2.93587
# [22]	validation_0-breslow_likelihood:4.15533	validation_1-breslow_likelihood:3.10821
# [5]	validation_0-breslow_likelihood:3.96907	validation_1-breslow_likelihood:2.97038
# [23]	validation_0-breslow_likelihood:4.14837	validation_1-breslow_likelihood:3.09699
# [6]	validation_0-breslow_likelihood:3.88600	validation_1-breslow_likelihood:2.90089
# [24]	validation_0-breslow_likelihood:4.13941	validation_1-breslow_likelihood:3.09231
# [7]	validation_0-breslow_likelihood:3.83002	validation_1-breslow_likelihood:2.87621
# [25]	validation_0-breslow_likelihood:4.12968	validation_1-breslow_likelihood:3.08914
# [8]	validation_0-breslow_likelihood:3.78183	validation_1-breslow_likelihood:2.82948
# [26]	validation_0-breslow_likelihood:4.12161	validation_1-breslow_likelihood:3.10115
# [9]	validation_0-breslow_likelihood:3.76557	validation_1-breslow_likelihood:2.80448
# [10]	validation_0-breslow_likelihood:3.71130	validation_1-breslow_likelihood:2.81057
# [27]	validation_0-breslow_likelihood:4.10985	validation_1-breslow_likelihood:3.08982
# [11]	validation_0-breslow_likelihood:3.63910	validation_1-breslow_likelihood:2.90423
# [28]	validation_0-breslow_likelihood:4.10614	validation_1-breslow_likelihood:3.09462
# [12]	validation_0-breslow_likelihood:3.57541	validation_1-breslow_likelihood:2.96574
# [29]	validation_0-breslow_likelihood:4.09751	validation_1-breslow_likelihood:3.07648
# [13]	validation_0-breslow_likelihood:3.56169	validation_1-breslow_likelihood:3.07660
# [30]	validation_0-breslow_likelihood:4.08812	validation_1-breslow_likelihood:3.08291
# [14]	validation_0-breslow_likelihood:3.53429	validation_1-breslow_likelihood:3.20277
# [31]	validation_0-breslow_likelihood:4.08542	validation_1-breslow_likelihood:3.08201
# [15]	validation_0-breslow_likelihood:3.49911	validation_1-breslow_likelihood:3.20704
# [32]	validation_0-breslow_likelihood:4.07990	validation_1-breslow_likelihood:3.08731
# [16]	validation_0-breslow_likelihood:3.46676	validation_1-breslow_likelihood:3.21555
# [33]	validation_0-breslow_likelihood:4.07566	validation_1-breslow_likelihood:3.08981
# [17]	validation_0-breslow_likelihood:3.44622	validation_1-breslow_likelihood:3.27240
# [34]	validation_0-breslow_likelihood:4.06723	validation_1-breslow_likelihood:3.09156
# [18]	validation_0-breslow_likelihood:3.36716	validation_1-breslow_likelihood:3.19462
# [0]	validation_0-breslow_likelihood:4.34531	validation_1-breslow_likelihood:2.97060
# [0]	validation_0-breslow_likelihood:4.34822	validation_1-breslow_likelihood:2.96419
# [1]	validation_0-breslow_likelihood:4.32754	validation_1-breslow_likelihood:2.98990
# [1]	validation_0-breslow_likelihood:4.33593	validation_1-breslow_likelihood:2.96655
# [2]	validation_0-breslow_likelihood:4.31949	validation_1-breslow_likelihood:2.99780
# [3]	validation_0-breslow_likelihood:4.30616	validation_1-breslow_likelihood:2.98797
# [2]	validation_0-breslow_likelihood:4.32357	validation_1-breslow_likelihood:2.95417
# [4]	validation_0-breslow_likelihood:4.29306	validation_1-breslow_likelihood:2.98408
# [3]	validation_0-breslow_likelihood:4.31890	validation_1-breslow_likelihood:2.94618
# [5]	validation_0-breslow_likelihood:4.27732	validation_1-breslow_likelihood:2.98381
# [4]	validation_0-breslow_likelihood:4.30827	validation_1-breslow_likelihood:2.94851
# [6]	validation_0-breslow_likelihood:4.25816	validation_1-breslow_likelihood:2.97623
# [5]	validation_0-breslow_likelihood:4.29802	validation_1-breslow_likelihood:2.95642
# [7]	validation_0-breslow_likelihood:4.25306	validation_1-breslow_likelihood:2.96584
# [6]	validation_0-breslow_likelihood:4.27659	validation_1-breslow_likelihood:2.94551
# [8]	validation_0-breslow_likelihood:4.24207	validation_1-breslow_likelihood:2.96294
# [7]	validation_0-breslow_likelihood:4.26293	validation_1-breslow_likelihood:2.94477
# [9]	validation_0-breslow_likelihood:4.22162	validation_1-breslow_likelihood:2.96258
# [8]	validation_0-breslow_likelihood:4.25855	validation_1-breslow_likelihood:2.94506
# [10]	validation_0-breslow_likelihood:4.21467	validation_1-breslow_likelihood:2.96781
# [9]	validation_0-breslow_likelihood:4.24818	validation_1-breslow_likelihood:2.93583
# [11]	validation_0-breslow_likelihood:4.21105	validation_1-breslow_likelihood:2.96377
# [10]	validation_0-breslow_likelihood:4.24309	validation_1-breslow_likelihood:2.91921
# [12]	validation_0-breslow_likelihood:4.20483	validation_1-breslow_likelihood:2.96970
# [11]	validation_0-breslow_likelihood:4.23569	validation_1-breslow_likelihood:2.92234
# [13]	validation_0-breslow_likelihood:4.19058	validation_1-breslow_likelihood:2.96880
# [12]	validation_0-breslow_likelihood:4.22981	validation_1-breslow_likelihood:2.92926
# [14]	validation_0-breslow_likelihood:4.18980	validation_1-breslow_likelihood:2.96648
# [13]	validation_0-breslow_likelihood:4.22964	validation_1-breslow_likelihood:2.92784
# [15]	validation_0-breslow_likelihood:4.18301	validation_1-breslow_likelihood:2.94884
# [14]	validation_0-breslow_likelihood:4.21898	validation_1-breslow_likelihood:2.91995
# [16]	validation_0-breslow_likelihood:4.17600	validation_1-breslow_likelihood:2.94251
# [15]	validation_0-breslow_likelihood:4.21461	validation_1-breslow_likelihood:2.93206
# [17]	validation_0-breslow_likelihood:4.16027	validation_1-breslow_likelihood:2.93920
# [16]	validation_0-breslow_likelihood:4.20489	validation_1-breslow_likelihood:2.92900
# [18]	validation_0-breslow_likelihood:4.15494	validation_1-breslow_likelihood:2.92953
# [17]	validation_0-breslow_likelihood:4.19677	validation_1-breslow_likelihood:2.93464
# [0]	validation_0-breslow_likelihood:4.26174	validation_1-breslow_likelihood:2.94741
# [19]	validation_0-breslow_likelihood:4.13964	validation_1-breslow_likelihood:2.92956
# [18]	validation_0-breslow_likelihood:4.19032	validation_1-breslow_likelihood:2.94052
# [20]	validation_0-breslow_likelihood:4.12724	validation_1-breslow_likelihood:2.93008
# [19]	validation_0-breslow_likelihood:4.18357	validation_1-breslow_likelihood:2.94365
# [21]	validation_0-breslow_likelihood:4.11529	validation_1-breslow_likelihood:2.93665
# [1]	validation_0-breslow_likelihood:4.25468	validation_1-breslow_likelihood:2.95180
# [22]	validation_0-breslow_likelihood:4.10903	validation_1-breslow_likelihood:2.93977
# [23]	validation_0-breslow_likelihood:4.09851	validation_1-breslow_likelihood:2.92995
# [2]	validation_0-breslow_likelihood:4.24725	validation_1-breslow_likelihood:2.94944
# [24]	validation_0-breslow_likelihood:4.09210	validation_1-breslow_likelihood:2.92746
# [25]	validation_0-breslow_likelihood:4.08683	validation_1-breslow_likelihood:2.92414
# [26]	validation_0-breslow_likelihood:4.07737	validation_1-breslow_likelihood:2.93961
# [3]	validation_0-breslow_likelihood:4.23332	validation_1-breslow_likelihood:2.95820
# [27]	validation_0-breslow_likelihood:4.06768	validation_1-breslow_likelihood:2.93491
# [4]	validation_0-breslow_likelihood:4.22051	validation_1-breslow_likelihood:2.96520
# [28]	validation_0-breslow_likelihood:4.05605	validation_1-breslow_likelihood:2.93268
# [5]	validation_0-breslow_likelihood:4.20828	validation_1-breslow_likelihood:2.94385
# [29]	validation_0-breslow_likelihood:4.04824	validation_1-breslow_likelihood:2.92274
# [6]	validation_0-breslow_likelihood:4.19984	validation_1-breslow_likelihood:2.94593
# [30]	validation_0-breslow_likelihood:4.04372	validation_1-breslow_likelihood:2.92316
# [7]	validation_0-breslow_likelihood:4.19205	validation_1-breslow_likelihood:2.94692
# [31]	validation_0-breslow_likelihood:4.03747	validation_1-breslow_likelihood:2.91475
# [8]	validation_0-breslow_likelihood:4.17471	validation_1-breslow_likelihood:2.95805
# [32]	validation_0-breslow_likelihood:4.03579	validation_1-breslow_likelihood:2.91266
# [9]	validation_0-breslow_likelihood:4.16366	validation_1-breslow_likelihood:2.95595
# [33]	validation_0-breslow_likelihood:4.02765	validation_1-breslow_likelihood:2.90933
# [34]	validation_0-breslow_likelihood:4.02281	validation_1-breslow_likelihood:2.90106
# [10]	validation_0-breslow_likelihood:4.15240	validation_1-breslow_likelihood:2.95149
# [11]	validation_0-breslow_likelihood:4.14083	validation_1-breslow_likelihood:2.96312
# [12]	validation_0-breslow_likelihood:4.12958	validation_1-breslow_likelihood:2.95579
# [13]	validation_0-breslow_likelihood:4.11639	validation_1-breslow_likelihood:2.94996
# [14]	validation_0-breslow_likelihood:4.11282	validation_1-breslow_likelihood:2.95175
# [0]	validation_0-breslow_likelihood:4.28368	validation_1-breslow_likelihood:3.06222
# [1]	validation_0-breslow_likelihood:4.20442	validation_1-breslow_likelihood:3.07325
# [2]	validation_0-breslow_likelihood:4.16563	validation_1-breslow_likelihood:3.07975
# [3]	validation_0-breslow_likelihood:4.04248	validation_1-breslow_likelihood:3.07787
# [4]	validation_0-breslow_likelihood:3.91372	validation_1-breslow_likelihood:3.21752
# [5]	validation_0-breslow_likelihood:3.88991	validation_1-breslow_likelihood:3.32314
# [6]	validation_0-breslow_likelihood:3.85688	validation_1-breslow_likelihood:3.51490
# [7]	validation_0-breslow_likelihood:3.77102	validation_1-breslow_likelihood:3.60375
# [8]	validation_0-breslow_likelihood:3.72167	validation_1-breslow_likelihood:3.43996
# [9]	validation_0-breslow_likelihood:3.65398	validation_1-breslow_likelihood:3.63083
# [10]	validation_0-breslow_likelihood:3.61915	validation_1-breslow_likelihood:3.65721
# [0]	validation_0-breslow_likelihood:4.68746	validation_1-breslow_likelihood:3.25535
# [1]	validation_0-breslow_likelihood:4.68233	validation_1-breslow_likelihood:3.26250
# [2]	validation_0-breslow_likelihood:4.67031	validation_1-breslow_likelihood:3.27128
# [3]	validation_0-breslow_likelihood:4.66177	validation_1-breslow_likelihood:3.27886
# [4]	validation_0-breslow_likelihood:4.64757	validation_1-breslow_likelihood:3.28192
# [5]	validation_0-breslow_likelihood:4.64637	validation_1-breslow_likelihood:3.29934
# [6]	validation_0-breslow_likelihood:4.64307	validation_1-breslow_likelihood:3.29262
# [7]	validation_0-breslow_likelihood:4.62948	validation_1-breslow_likelihood:3.28937
# [8]	validation_0-breslow_likelihood:4.61836	validation_1-breslow_likelihood:3.29534
# [9]	validation_0-breslow_likelihood:4.60949	validation_1-breslow_likelihood:3.28867
# [10]	validation_0-breslow_likelihood:4.59997	validation_1-breslow_likelihood:3.29299
# Concordance Index 0.5425347542313507
# Integrated Brier Score: 0.2098212904699255
# durations 17.0 4343.0
# Concordance Index 0.4154696132596685
# Integrated Brier Score: 0.2234261585689805
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:4.27994	validation_1-breslow_likelihood:3.02919
# [1]	validation_0-breslow_likelihood:4.22051	validation_1-breslow_likelihood:3.02435
# [2]	validation_0-breslow_likelihood:4.20428	validation_1-breslow_likelihood:3.04306
# [3]	validation_0-breslow_likelihood:4.19342	validation_1-breslow_likelihood:3.10195
# [4]	validation_0-breslow_likelihood:4.16392	validation_1-breslow_likelihood:3.09541
# [5]	validation_0-breslow_likelihood:4.16526	validation_1-breslow_likelihood:3.09016
# [6]	validation_0-breslow_likelihood:4.14390	validation_1-breslow_likelihood:3.06664
# [7]	validation_0-breslow_likelihood:4.12527	validation_1-breslow_likelihood:3.10356
# [8]	validation_0-breslow_likelihood:4.08450	validation_1-breslow_likelihood:3.14363
# [9]	validation_0-breslow_likelihood:4.05814	validation_1-breslow_likelihood:3.17082
# [10]	validation_0-breslow_likelihood:4.04245	validation_1-breslow_likelihood:3.15913
# [11]	validation_0-breslow_likelihood:4.02887	validation_1-breslow_likelihood:3.18548
# [0]	validation_0-breslow_likelihood:4.44883	validation_1-breslow_likelihood:3.03867
# [1]	validation_0-breslow_likelihood:4.44766	validation_1-breslow_likelihood:3.03844
# [2]	validation_0-breslow_likelihood:4.44644	validation_1-breslow_likelihood:3.03816
# [3]	validation_0-breslow_likelihood:4.44546	validation_1-breslow_likelihood:3.03800
# [4]	validation_0-breslow_likelihood:4.44417	validation_1-breslow_likelihood:3.03761
# [5]	validation_0-breslow_likelihood:4.44303	validation_1-breslow_likelihood:3.03712
# [6]	validation_0-breslow_likelihood:4.44188	validation_1-breslow_likelihood:3.03715
# [7]	validation_0-breslow_likelihood:4.44070	validation_1-breslow_likelihood:3.03728
# [8]	validation_0-breslow_likelihood:4.43955	validation_1-breslow_likelihood:3.03707
# [9]	validation_0-breslow_likelihood:4.43835	validation_1-breslow_likelihood:3.03645
# [10]	validation_0-breslow_likelihood:4.43721	validation_1-breslow_likelihood:3.03599
# [11]	validation_0-breslow_likelihood:4.43610	validation_1-breslow_likelihood:3.03588
# [12]	validation_0-breslow_likelihood:4.43493	validation_1-breslow_likelihood:3.03571
# [13]	validation_0-breslow_likelihood:4.43364	validation_1-breslow_likelihood:3.03584
# [14]	validation_0-breslow_likelihood:4.43243	validation_1-breslow_likelihood:3.03587
# [15]	validation_0-breslow_likelihood:4.43113	validation_1-breslow_likelihood:3.03572
# [16]	validation_0-breslow_likelihood:4.42998	validation_1-breslow_likelihood:3.03538
# [17]	validation_0-breslow_likelihood:4.42879	validation_1-breslow_likelihood:3.03507
# [18]	validation_0-breslow_likelihood:4.42764	validation_1-breslow_likelihood:3.03522
# [19]	validation_0-breslow_likelihood:4.42648	validation_1-breslow_likelihood:3.03499
# [20]	validation_0-breslow_likelihood:4.42530	validation_1-breslow_likelihood:3.03510
# [21]	validation_0-breslow_likelihood:4.42402	validation_1-breslow_likelihood:3.03514
# [22]	validation_0-breslow_likelihood:4.42276	validation_1-breslow_likelihood:3.03498
# [23]	validation_0-breslow_likelihood:4.42160	validation_1-breslow_likelihood:3.03477
# [24]	validation_0-breslow_likelihood:4.42043	validation_1-breslow_likelihood:3.03482
# [25]	validation_0-breslow_likelihood:4.41909	validation_1-breslow_likelihood:3.03457
# [26]	validation_0-breslow_likelihood:4.41802	validation_1-breslow_likelihood:3.03423
# [27]	validation_0-breslow_likelihood:4.41686	validation_1-breslow_likelihood:3.03416
# [28]	validation_0-breslow_likelihood:4.41560	validation_1-breslow_likelihood:3.03390
# [29]	validation_0-breslow_likelihood:4.41456	validation_1-breslow_likelihood:3.03369
# [0]	validation_0-breslow_likelihood:4.42778	validation_1-breslow_likelihood:3.19094
# [1]	validation_0-breslow_likelihood:4.37959	validation_1-breslow_likelihood:3.13508
# [2]	validation_0-breslow_likelihood:4.33739	validation_1-breslow_likelihood:3.14411
# [3]	validation_0-breslow_likelihood:4.31684	validation_1-breslow_likelihood:3.12455
# [4]	validation_0-breslow_likelihood:4.30323	validation_1-breslow_likelihood:3.20323
# [5]	validation_0-breslow_likelihood:4.28262	validation_1-breslow_likelihood:3.17424
# [6]	validation_0-breslow_likelihood:4.26971	validation_1-breslow_likelihood:3.13824
# [7]	validation_0-breslow_likelihood:4.23322	validation_1-breslow_likelihood:3.14521
# [8]	validation_0-breslow_likelihood:4.23334	validation_1-breslow_likelihood:3.16572
# [0]	validation_0-breslow_likelihood:4.32774	validation_1-breslow_likelihood:3.02108
# [9]	validation_0-breslow_likelihood:4.21803	validation_1-breslow_likelihood:3.19635
# [10]	validation_0-breslow_likelihood:4.21050	validation_1-breslow_likelihood:3.20960
# [1]	validation_0-breslow_likelihood:4.32661	validation_1-breslow_likelihood:3.02087
# [11]	validation_0-breslow_likelihood:4.19703	validation_1-breslow_likelihood:3.15431
# [12]	validation_0-breslow_likelihood:4.17623	validation_1-breslow_likelihood:3.17842
# [2]	validation_0-breslow_likelihood:4.32544	validation_1-breslow_likelihood:3.02123
# [13]	validation_0-breslow_likelihood:4.14600	validation_1-breslow_likelihood:3.11302
# [3]	validation_0-breslow_likelihood:4.32438	validation_1-breslow_likelihood:3.02131
# [14]	validation_0-breslow_likelihood:4.12875	validation_1-breslow_likelihood:3.05421
# [15]	validation_0-breslow_likelihood:4.12423	validation_1-breslow_likelihood:3.05933
# [4]	validation_0-breslow_likelihood:4.32331	validation_1-breslow_likelihood:3.02104
# [16]	validation_0-breslow_likelihood:4.10465	validation_1-breslow_likelihood:3.02937
# [17]	validation_0-breslow_likelihood:4.09987	validation_1-breslow_likelihood:3.01124
# [5]	validation_0-breslow_likelihood:4.32225	validation_1-breslow_likelihood:3.02063
# [18]	validation_0-breslow_likelihood:4.08986	validation_1-breslow_likelihood:3.02111
# [6]	validation_0-breslow_likelihood:4.32116	validation_1-breslow_likelihood:3.02047
# [19]	validation_0-breslow_likelihood:4.09121	validation_1-breslow_likelihood:2.99966
# [20]	validation_0-breslow_likelihood:4.05441	validation_1-breslow_likelihood:3.03259
# [7]	validation_0-breslow_likelihood:4.31999	validation_1-breslow_likelihood:3.02002
# [21]	validation_0-breslow_likelihood:4.04988	validation_1-breslow_likelihood:3.07498
# [22]	validation_0-breslow_likelihood:4.02094	validation_1-breslow_likelihood:3.05320
# [8]	validation_0-breslow_likelihood:4.31884	validation_1-breslow_likelihood:3.01984
# [23]	validation_0-breslow_likelihood:4.00878	validation_1-breslow_likelihood:3.01799
# [9]	validation_0-breslow_likelihood:4.31765	validation_1-breslow_likelihood:3.01955
# [24]	validation_0-breslow_likelihood:3.98923	validation_1-breslow_likelihood:3.00346
# [25]	validation_0-breslow_likelihood:3.97504	validation_1-breslow_likelihood:3.00475
# [10]	validation_0-breslow_likelihood:4.31668	validation_1-breslow_likelihood:3.01928
# [26]	validation_0-breslow_likelihood:3.96658	validation_1-breslow_likelihood:3.02038
# [11]	validation_0-breslow_likelihood:4.31562	validation_1-breslow_likelihood:3.01914
# [27]	validation_0-breslow_likelihood:3.95526	validation_1-breslow_likelihood:3.04431
# [28]	validation_0-breslow_likelihood:3.94857	validation_1-breslow_likelihood:3.02207
# [29]	validation_0-breslow_likelihood:3.93268	validation_1-breslow_likelihood:3.02770
# [12]	validation_0-breslow_likelihood:4.31460	validation_1-breslow_likelihood:3.01873
# [13]	validation_0-breslow_likelihood:4.31352	validation_1-breslow_likelihood:3.01876
# [14]	validation_0-breslow_likelihood:4.31242	validation_1-breslow_likelihood:3.01838
# [15]	validation_0-breslow_likelihood:4.31121	validation_1-breslow_likelihood:3.01871
# [16]	validation_0-breslow_likelihood:4.31016	validation_1-breslow_likelihood:3.01875
# [17]	validation_0-breslow_likelihood:4.30907	validation_1-breslow_likelihood:3.01851
# [18]	validation_0-breslow_likelihood:4.30814	validation_1-breslow_likelihood:3.01832
# [19]	validation_0-breslow_likelihood:4.30702	validation_1-breslow_likelihood:3.01813
# [20]	validation_0-breslow_likelihood:4.30597	validation_1-breslow_likelihood:3.01811
# [21]	validation_0-breslow_likelihood:4.30482	validation_1-breslow_likelihood:3.01836
# [22]	validation_0-breslow_likelihood:4.30379	validation_1-breslow_likelihood:3.01828
# [23]	validation_0-breslow_likelihood:4.30265	validation_1-breslow_likelihood:3.01813
# [24]	validation_0-breslow_likelihood:4.30159	validation_1-breslow_likelihood:3.01784
# [25]	validation_0-breslow_likelihood:4.30052	validation_1-breslow_likelihood:3.01802
# [26]	validation_0-breslow_likelihood:4.29939	validation_1-breslow_likelihood:3.01829
# [27]	validation_0-breslow_likelihood:4.29837	validation_1-breslow_likelihood:3.01819
# [28]	validation_0-breslow_likelihood:4.29733	validation_1-breslow_likelihood:3.01824
# [29]	validation_0-breslow_likelihood:4.29622	validation_1-breslow_likelihood:3.01820
# [0]	validation_0-breslow_likelihood:4.32765	validation_1-breslow_likelihood:3.00918
# [0]	validation_0-breslow_likelihood:4.27649	validation_1-breslow_likelihood:2.94974
# [0]	validation_0-breslow_likelihood:4.47208	validation_1-breslow_likelihood:3.18182
# [1]	validation_0-breslow_likelihood:4.47102	validation_1-breslow_likelihood:3.18141
# [1]	validation_0-breslow_likelihood:4.32648	validation_1-breslow_likelihood:3.00871
# [1]	validation_0-breslow_likelihood:4.25478	validation_1-breslow_likelihood:2.95087
# [2]	validation_0-breslow_likelihood:4.46985	validation_1-breslow_likelihood:3.18117
# [2]	validation_0-breslow_likelihood:4.24179	validation_1-breslow_likelihood:2.93897
# [2]	validation_0-breslow_likelihood:4.32529	validation_1-breslow_likelihood:3.00834
# [3]	validation_0-breslow_likelihood:4.21540	validation_1-breslow_likelihood:2.93084
# [3]	validation_0-breslow_likelihood:4.46853	validation_1-breslow_likelihood:3.18126
# [4]	validation_0-breslow_likelihood:4.19858	validation_1-breslow_likelihood:2.93373
# [3]	validation_0-breslow_likelihood:4.32419	validation_1-breslow_likelihood:3.00809
# [5]	validation_0-breslow_likelihood:4.15718	validation_1-breslow_likelihood:2.98509
# [6]	validation_0-breslow_likelihood:4.13942	validation_1-breslow_likelihood:2.98365
# [4]	validation_0-breslow_likelihood:4.32300	validation_1-breslow_likelihood:3.00812
# [7]	validation_0-breslow_likelihood:4.09595	validation_1-breslow_likelihood:3.08508
# [5]	validation_0-breslow_likelihood:4.32195	validation_1-breslow_likelihood:3.00813
# [8]	validation_0-breslow_likelihood:4.05479	validation_1-breslow_likelihood:3.09191
# [9]	validation_0-breslow_likelihood:4.04262	validation_1-breslow_likelihood:3.11822
# [6]	validation_0-breslow_likelihood:4.32076	validation_1-breslow_likelihood:3.00793
# [10]	validation_0-breslow_likelihood:4.03900	validation_1-breslow_likelihood:3.11798
# [7]	validation_0-breslow_likelihood:4.31951	validation_1-breslow_likelihood:3.00754
# [11]	validation_0-breslow_likelihood:4.03460	validation_1-breslow_likelihood:3.12534
# [12]	validation_0-breslow_likelihood:4.02847	validation_1-breslow_likelihood:3.10928
# [8]	validation_0-breslow_likelihood:4.31846	validation_1-breslow_likelihood:3.00709
# [4]	validation_0-breslow_likelihood:4.46737	validation_1-breslow_likelihood:3.18099
# [5]	validation_0-breslow_likelihood:4.46629	validation_1-breslow_likelihood:3.18051
# [9]	validation_0-breslow_likelihood:4.31730	validation_1-breslow_likelihood:3.00662
# [6]	validation_0-breslow_likelihood:4.46514	validation_1-breslow_likelihood:3.17998
# [13]	validation_0-breslow_likelihood:4.01469	validation_1-breslow_likelihood:3.12968
# [10]	validation_0-breslow_likelihood:4.31597	validation_1-breslow_likelihood:3.00663
# [7]	validation_0-breslow_likelihood:4.46382	validation_1-breslow_likelihood:3.17926
# [11]	validation_0-breslow_likelihood:4.31494	validation_1-breslow_likelihood:3.00635
# [8]	validation_0-breslow_likelihood:4.46272	validation_1-breslow_likelihood:3.17902
# [12]	validation_0-breslow_likelihood:4.31382	validation_1-breslow_likelihood:3.00606
# [9]	validation_0-breslow_likelihood:4.46166	validation_1-breslow_likelihood:3.17843
# [13]	validation_0-breslow_likelihood:4.31261	validation_1-breslow_likelihood:3.00599
# [10]	validation_0-breslow_likelihood:4.46050	validation_1-breslow_likelihood:3.17810
# [14]	validation_0-breslow_likelihood:4.31152	validation_1-breslow_likelihood:3.00574
# [11]	validation_0-breslow_likelihood:4.45934	validation_1-breslow_likelihood:3.17816
# [15]	validation_0-breslow_likelihood:4.31031	validation_1-breslow_likelihood:3.00542
# [12]	validation_0-breslow_likelihood:4.45812	validation_1-breslow_likelihood:3.17795
# [16]	validation_0-breslow_likelihood:4.30916	validation_1-breslow_likelihood:3.00535
# [13]	validation_0-breslow_likelihood:4.45698	validation_1-breslow_likelihood:3.17781
# [17]	validation_0-breslow_likelihood:4.30806	validation_1-breslow_likelihood:3.00520
# [14]	validation_0-breslow_likelihood:4.45585	validation_1-breslow_likelihood:3.17737
# [18]	validation_0-breslow_likelihood:4.30698	validation_1-breslow_likelihood:3.00481
# [15]	validation_0-breslow_likelihood:4.45468	validation_1-breslow_likelihood:3.17686
# [19]	validation_0-breslow_likelihood:4.30574	validation_1-breslow_likelihood:3.00468
# [16]	validation_0-breslow_likelihood:4.45347	validation_1-breslow_likelihood:3.17638
# [20]	validation_0-breslow_likelihood:4.30466	validation_1-breslow_likelihood:3.00462
# [17]	validation_0-breslow_likelihood:4.45224	validation_1-breslow_likelihood:3.17639
# [21]	validation_0-breslow_likelihood:4.30353	validation_1-breslow_likelihood:3.00450
# [18]	validation_0-breslow_likelihood:4.45099	validation_1-breslow_likelihood:3.17647
# [22]	validation_0-breslow_likelihood:4.30239	validation_1-breslow_likelihood:3.00413
# [19]	validation_0-breslow_likelihood:4.44993	validation_1-breslow_likelihood:3.17585
# [23]	validation_0-breslow_likelihood:4.30133	validation_1-breslow_likelihood:3.00413
# [20]	validation_0-breslow_likelihood:4.44877	validation_1-breslow_likelihood:3.17565
# [24]	validation_0-breslow_likelihood:4.30020	validation_1-breslow_likelihood:3.00428
# [21]	validation_0-breslow_likelihood:4.44755	validation_1-breslow_likelihood:3.17554
# [25]	validation_0-breslow_likelihood:4.29894	validation_1-breslow_likelihood:3.00425
# [22]	validation_0-breslow_likelihood:4.44640	validation_1-breslow_likelihood:3.17581
# [26]	validation_0-breslow_likelihood:4.29781	validation_1-breslow_likelihood:3.00422
# [23]	validation_0-breslow_likelihood:4.44518	validation_1-breslow_likelihood:3.17582
# [27]	validation_0-breslow_likelihood:4.29673	validation_1-breslow_likelihood:3.00414
# [28]	validation_0-breslow_likelihood:4.29553	validation_1-breslow_likelihood:3.00366
# [24]	validation_0-breslow_likelihood:4.44414	validation_1-breslow_likelihood:3.17563
# [25]	validation_0-breslow_likelihood:4.44302	validation_1-breslow_likelihood:3.17587
# [26]	validation_0-breslow_likelihood:4.44171	validation_1-breslow_likelihood:3.17555
# [27]	validation_0-breslow_likelihood:4.44053	validation_1-breslow_likelihood:3.17543
# [28]	validation_0-breslow_likelihood:4.43938	validation_1-breslow_likelihood:3.17544
# [29]	validation_0-breslow_likelihood:4.43821	validation_1-breslow_likelihood:3.17479
# [29]	validation_0-breslow_likelihood:4.29447	validation_1-breslow_likelihood:3.00334
# [0]	validation_0-breslow_likelihood:4.33928	validation_1-breslow_likelihood:3.22086
# [1]	validation_0-breslow_likelihood:4.33817	validation_1-breslow_likelihood:3.22057
# [2]	validation_0-breslow_likelihood:4.33704	validation_1-breslow_likelihood:3.22013
# [3]	validation_0-breslow_likelihood:4.33591	validation_1-breslow_likelihood:3.21990
# [4]	validation_0-breslow_likelihood:4.33476	validation_1-breslow_likelihood:3.22006
# [5]	validation_0-breslow_likelihood:4.33354	validation_1-breslow_likelihood:3.21956
# [6]	validation_0-breslow_likelihood:4.33241	validation_1-breslow_likelihood:3.21928
# [7]	validation_0-breslow_likelihood:4.33117	validation_1-breslow_likelihood:3.21919
# [8]	validation_0-breslow_likelihood:4.33003	validation_1-breslow_likelihood:3.21946
# [9]	validation_0-breslow_likelihood:4.32880	validation_1-breslow_likelihood:3.21937
# [10]	validation_0-breslow_likelihood:4.32770	validation_1-breslow_likelihood:3.21936
# [11]	validation_0-breslow_likelihood:4.32654	validation_1-breslow_likelihood:3.21906
# [12]	validation_0-breslow_likelihood:4.32532	validation_1-breslow_likelihood:3.21860
# [13]	validation_0-breslow_likelihood:4.32414	validation_1-breslow_likelihood:3.21836
# [0]	validation_0-breslow_likelihood:4.41269	validation_1-breslow_likelihood:2.99066
# [14]	validation_0-breslow_likelihood:4.32314	validation_1-breslow_likelihood:3.21848
# [1]	validation_0-breslow_likelihood:4.38619	validation_1-breslow_likelihood:3.00452
# [2]	validation_0-breslow_likelihood:4.36877	validation_1-breslow_likelihood:2.98662
# [15]	validation_0-breslow_likelihood:4.32196	validation_1-breslow_likelihood:3.21812
# [3]	validation_0-breslow_likelihood:4.36300	validation_1-breslow_likelihood:2.99528
# [16]	validation_0-breslow_likelihood:4.32081	validation_1-breslow_likelihood:3.21794
# [4]	validation_0-breslow_likelihood:4.33585	validation_1-breslow_likelihood:3.02567
# [5]	validation_0-breslow_likelihood:4.28896	validation_1-breslow_likelihood:2.97180
# [17]	validation_0-breslow_likelihood:4.31972	validation_1-breslow_likelihood:3.21772
# [6]	validation_0-breslow_likelihood:4.27416	validation_1-breslow_likelihood:2.95284
# [18]	validation_0-breslow_likelihood:4.31852	validation_1-breslow_likelihood:3.21748
# [7]	validation_0-breslow_likelihood:4.22336	validation_1-breslow_likelihood:3.00443
# [8]	validation_0-breslow_likelihood:4.17304	validation_1-breslow_likelihood:2.99161
# [19]	validation_0-breslow_likelihood:4.31739	validation_1-breslow_likelihood:3.21736
# [9]	validation_0-breslow_likelihood:4.15257	validation_1-breslow_likelihood:3.00107
# [20]	validation_0-breslow_likelihood:4.31637	validation_1-breslow_likelihood:3.21727
# [10]	validation_0-breslow_likelihood:4.12710	validation_1-breslow_likelihood:3.00483
# [11]	validation_0-breslow_likelihood:4.10978	validation_1-breslow_likelihood:2.97071
# [21]	validation_0-breslow_likelihood:4.31520	validation_1-breslow_likelihood:3.21712
# [12]	validation_0-breslow_likelihood:4.08183	validation_1-breslow_likelihood:2.98545
# [13]	validation_0-breslow_likelihood:4.07738	validation_1-breslow_likelihood:3.01169
# [22]	validation_0-breslow_likelihood:4.31419	validation_1-breslow_likelihood:3.21720
# [14]	validation_0-breslow_likelihood:4.05600	validation_1-breslow_likelihood:3.00323
# [23]	validation_0-breslow_likelihood:4.31300	validation_1-breslow_likelihood:3.21710
# [15]	validation_0-breslow_likelihood:4.05525	validation_1-breslow_likelihood:3.02028
# [24]	validation_0-breslow_likelihood:4.31202	validation_1-breslow_likelihood:3.21712
# [25]	validation_0-breslow_likelihood:4.31084	validation_1-breslow_likelihood:3.21708
# [26]	validation_0-breslow_likelihood:4.30975	validation_1-breslow_likelihood:3.21687
# [27]	validation_0-breslow_likelihood:4.30870	validation_1-breslow_likelihood:3.21707
# [28]	validation_0-breslow_likelihood:4.30756	validation_1-breslow_likelihood:3.21727
# [29]	validation_0-breslow_likelihood:4.30642	validation_1-breslow_likelihood:3.21719
# [0]	validation_0-breslow_likelihood:4.27873	validation_1-breslow_likelihood:3.23675
# [1]	validation_0-breslow_likelihood:4.23381	validation_1-breslow_likelihood:3.28263
# [2]	validation_0-breslow_likelihood:4.22559	validation_1-breslow_likelihood:3.32984
# [3]	validation_0-breslow_likelihood:4.20580	validation_1-breslow_likelihood:3.30826
# [4]	validation_0-breslow_likelihood:4.19968	validation_1-breslow_likelihood:3.30191
# [5]	validation_0-breslow_likelihood:4.18158	validation_1-breslow_likelihood:3.29486
# [6]	validation_0-breslow_likelihood:4.14583	validation_1-breslow_likelihood:3.26485
# [7]	validation_0-breslow_likelihood:4.13159	validation_1-breslow_likelihood:3.33606
# [8]	validation_0-breslow_likelihood:4.08520	validation_1-breslow_likelihood:3.35651
# [9]	validation_0-breslow_likelihood:4.07706	validation_1-breslow_likelihood:3.38829
# [0]	validation_0-breslow_likelihood:4.52511	validation_1-breslow_likelihood:3.28565
# [1]	validation_0-breslow_likelihood:4.50478	validation_1-breslow_likelihood:3.33039
# [2]	validation_0-breslow_likelihood:4.48116	validation_1-breslow_likelihood:3.33310
# [3]	validation_0-breslow_likelihood:4.46058	validation_1-breslow_likelihood:3.32762
# [4]	validation_0-breslow_likelihood:4.44745	validation_1-breslow_likelihood:3.27757
# [5]	validation_0-breslow_likelihood:4.42274	validation_1-breslow_likelihood:3.30111
# [6]	validation_0-breslow_likelihood:4.40599	validation_1-breslow_likelihood:3.33860
# [7]	validation_0-breslow_likelihood:4.38888	validation_1-breslow_likelihood:3.33168
# [8]	validation_0-breslow_likelihood:4.37990	validation_1-breslow_likelihood:3.31081
# [9]	validation_0-breslow_likelihood:4.35738	validation_1-breslow_likelihood:3.32508
# [10]	validation_0-breslow_likelihood:4.32669	validation_1-breslow_likelihood:3.37460
# [11]	validation_0-breslow_likelihood:4.30046	validation_1-breslow_likelihood:3.35496
# [12]	validation_0-breslow_likelihood:4.28836	validation_1-breslow_likelihood:3.42146
# [13]	validation_0-breslow_likelihood:4.27566	validation_1-breslow_likelihood:3.43841
# [14]	validation_0-breslow_likelihood:4.24479	validation_1-breslow_likelihood:3.45253
# Concordance Index 0.6010387683175663
# Integrated Brier Score: 0.18787137343644222
# durations 15.0 3817.0
# Concordance Index 0.5805570726379028
# Integrated Brier Score: 0.2418351584322114
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-breslow_likelihood:4.37914	validation_1-breslow_likelihood:3.04494
# [1]	validation_0-breslow_likelihood:4.37641	validation_1-breslow_likelihood:3.04373
# [2]	validation_0-breslow_likelihood:4.36806	validation_1-breslow_likelihood:3.03815
# [3]	validation_0-breslow_likelihood:4.36680	validation_1-breslow_likelihood:3.03718
# [4]	validation_0-breslow_likelihood:4.35612	validation_1-breslow_likelihood:3.03536
# [5]	validation_0-breslow_likelihood:4.35448	validation_1-breslow_likelihood:3.03437
# [6]	validation_0-breslow_likelihood:4.35105	validation_1-breslow_likelihood:3.03494
# [7]	validation_0-breslow_likelihood:4.35100	validation_1-breslow_likelihood:3.03668
# [8]	validation_0-breslow_likelihood:4.34881	validation_1-breslow_likelihood:3.03236
# [9]	validation_0-breslow_likelihood:4.34464	validation_1-breslow_likelihood:3.03159
# [10]	validation_0-breslow_likelihood:4.34341	validation_1-breslow_likelihood:3.03383
# [0]	validation_0-breslow_likelihood:4.40973	validation_1-breslow_likelihood:3.19591
# [1]	validation_0-breslow_likelihood:4.40743	validation_1-breslow_likelihood:3.18760
# [2]	validation_0-breslow_likelihood:4.40312	validation_1-breslow_likelihood:3.17890
# [3]	validation_0-breslow_likelihood:4.39891	validation_1-breslow_likelihood:3.17187
# [4]	validation_0-breslow_likelihood:4.39083	validation_1-breslow_likelihood:3.17221
# [5]	validation_0-breslow_likelihood:4.38861	validation_1-breslow_likelihood:3.17651
# [6]	validation_0-breslow_likelihood:4.38480	validation_1-breslow_likelihood:3.17300
# [7]	validation_0-breslow_likelihood:4.38179	validation_1-breslow_likelihood:3.17196
# [8]	validation_0-breslow_likelihood:4.37581	validation_1-breslow_likelihood:3.17258
# [9]	validation_0-breslow_likelihood:4.37096	validation_1-breslow_likelihood:3.17109
# [10]	validation_0-breslow_likelihood:4.36772	validation_1-breslow_likelihood:3.16352
# [0]	validation_0-breslow_likelihood:4.38818	validation_1-breslow_likelihood:3.08751
# [1]	validation_0-breslow_likelihood:4.38542	validation_1-breslow_likelihood:3.09020
# [2]	validation_0-breslow_likelihood:4.38237	validation_1-breslow_likelihood:3.08993
# [3]	validation_0-breslow_likelihood:4.37871	validation_1-breslow_likelihood:3.08752
# [4]	validation_0-breslow_likelihood:4.37400	validation_1-breslow_likelihood:3.08571
# [5]	validation_0-breslow_likelihood:4.37079	validation_1-breslow_likelihood:3.07678
# [6]	validation_0-breslow_likelihood:4.36762	validation_1-breslow_likelihood:3.07430
# [7]	validation_0-breslow_likelihood:4.36242	validation_1-breslow_likelihood:3.07398
# [8]	validation_0-breslow_likelihood:4.35564	validation_1-breslow_likelihood:3.07126
# [9]	validation_0-breslow_likelihood:4.34953	validation_1-breslow_likelihood:3.07166
# [10]	validation_0-breslow_likelihood:4.34622	validation_1-breslow_likelihood:3.06847
# [0]	validation_0-breslow_likelihood:4.46347	validation_1-breslow_likelihood:2.93233
# [0]	validation_0-breslow_likelihood:4.41350	validation_1-breslow_likelihood:3.19328
# [1]	validation_0-breslow_likelihood:4.46103	validation_1-breslow_likelihood:2.93485
# [2]	validation_0-breslow_likelihood:4.45421	validation_1-breslow_likelihood:2.93242
# [3]	validation_0-breslow_likelihood:4.44797	validation_1-breslow_likelihood:2.93098
# [1]	validation_0-breslow_likelihood:4.41326	validation_1-breslow_likelihood:3.19321
# [4]	validation_0-breslow_likelihood:4.44343	validation_1-breslow_likelihood:2.92785
# [5]	validation_0-breslow_likelihood:4.43601	validation_1-breslow_likelihood:2.92888
# [2]	validation_0-breslow_likelihood:4.41314	validation_1-breslow_likelihood:3.19306[6]	validation_0-breslow_likelihood:4.43089	validation_1-breslow_likelihood:2.92575
#
# [7]	validation_0-breslow_likelihood:4.42708	validation_1-breslow_likelihood:2.92555
# [8]	validation_0-breslow_likelihood:4.42460	validation_1-breslow_likelihood:2.91677
# [3]	validation_0-breslow_likelihood:4.41292	validation_1-breslow_likelihood:3.19303
# [9]	validation_0-breslow_likelihood:4.42001	validation_1-breslow_likelihood:2.90674
# [10]	validation_0-breslow_likelihood:4.41707	validation_1-breslow_likelihood:2.90717
# [4]	validation_0-breslow_likelihood:4.41268	validation_1-breslow_likelihood:3.19298
# [5]	validation_0-breslow_likelihood:4.41253	validation_1-breslow_likelihood:3.19306
# [6]	validation_0-breslow_likelihood:4.41235	validation_1-breslow_likelihood:3.19313
# [7]	validation_0-breslow_likelihood:4.41210	validation_1-breslow_likelihood:3.19311
# [0]	validation_0-breslow_likelihood:4.43131	validation_1-breslow_likelihood:3.09848
# [8]	validation_0-breslow_likelihood:4.41188	validation_1-breslow_likelihood:3.19303
# [1]	validation_0-breslow_likelihood:4.42893	validation_1-breslow_likelihood:3.09720
# [2]	validation_0-breslow_likelihood:4.41880	validation_1-breslow_likelihood:3.08975
# [9]	validation_0-breslow_likelihood:4.41151	validation_1-breslow_likelihood:3.19297
# [3]	validation_0-breslow_likelihood:4.41567	validation_1-breslow_likelihood:3.09390
# [4]	validation_0-breslow_likelihood:4.40522	validation_1-breslow_likelihood:3.08497
# [5]	validation_0-breslow_likelihood:4.40130	validation_1-breslow_likelihood:3.08811
# [10]	validation_0-breslow_likelihood:4.41121	validation_1-breslow_likelihood:3.19292
# [6]	validation_0-breslow_likelihood:4.39942	validation_1-breslow_likelihood:3.08882
# [7]	validation_0-breslow_likelihood:4.39533	validation_1-breslow_likelihood:3.09272
# [11]	validation_0-breslow_likelihood:4.41095	validation_1-breslow_likelihood:3.19293
# [8]	validation_0-breslow_likelihood:4.38796	validation_1-breslow_likelihood:3.09808
# [9]	validation_0-breslow_likelihood:4.38489	validation_1-breslow_likelihood:3.09953
# [12]	validation_0-breslow_likelihood:4.41062	validation_1-breslow_likelihood:3.19292
# [10]	validation_0-breslow_likelihood:4.37803	validation_1-breslow_likelihood:3.09321
# [13]	validation_0-breslow_likelihood:4.41036	validation_1-breslow_likelihood:3.19285
# [14]	validation_0-breslow_likelihood:4.41011	validation_1-breslow_likelihood:3.19278
# [15]	validation_0-breslow_likelihood:4.40992	validation_1-breslow_likelihood:3.19277
# [16]	validation_0-breslow_likelihood:4.40978	validation_1-breslow_likelihood:3.19286
# [17]	validation_0-breslow_likelihood:4.40957	validation_1-breslow_likelihood:3.19273
# [18]	validation_0-breslow_likelihood:4.40935	validation_1-breslow_likelihood:3.19281
# [19]	validation_0-breslow_likelihood:4.40914	validation_1-breslow_likelihood:3.19276
# [20]	validation_0-breslow_likelihood:4.40894	validation_1-breslow_likelihood:3.19282
# [21]	validation_0-breslow_likelihood:4.40867	validation_1-breslow_likelihood:3.19272
# [22]	validation_0-breslow_likelihood:4.40844	validation_1-breslow_likelihood:3.19270
# [23]	validation_0-breslow_likelihood:4.40824	validation_1-breslow_likelihood:3.19257
# [24]	validation_0-breslow_likelihood:4.40803	validation_1-breslow_likelihood:3.19257
# [25]	validation_0-breslow_likelihood:4.40783	validation_1-breslow_likelihood:3.19258
# [26]	validation_0-breslow_likelihood:4.40769	validation_1-breslow_likelihood:3.19259
# [27]	validation_0-breslow_likelihood:4.40744	validation_1-breslow_likelihood:3.19253
# [28]	validation_0-breslow_likelihood:4.40726	validation_1-breslow_likelihood:3.19255
# [29]	validation_0-breslow_likelihood:4.40705	validation_1-breslow_likelihood:3.19258
# [30]	validation_0-breslow_likelihood:4.40684	validation_1-breslow_likelihood:3.19260
# [31]	validation_0-breslow_likelihood:4.40660	validation_1-breslow_likelihood:3.19258
# [32]	validation_0-breslow_likelihood:4.40635	validation_1-breslow_likelihood:3.19252
# [33]	validation_0-breslow_likelihood:4.40602	validation_1-breslow_likelihood:3.19246
# [34]	validation_0-breslow_likelihood:4.40573	validation_1-breslow_likelihood:3.19248
# [35]	validation_0-breslow_likelihood:4.40555	validation_1-breslow_likelihood:3.19245
# [36]	validation_0-breslow_likelihood:4.40536	validation_1-breslow_likelihood:3.19244
# [37]	validation_0-breslow_likelihood:4.40509	validation_1-breslow_likelihood:3.19235
# [38]	validation_0-breslow_likelihood:4.40477	validation_1-breslow_likelihood:3.19223
# [39]	validation_0-breslow_likelihood:4.40447	validation_1-breslow_likelihood:3.19223
# [40]	validation_0-breslow_likelihood:4.40426	validation_1-breslow_likelihood:3.19216
# [41]	validation_0-breslow_likelihood:4.40414	validation_1-breslow_likelihood:3.19217
# [42]	validation_0-breslow_likelihood:4.40376	validation_1-breslow_likelihood:3.19208
# [43]	validation_0-breslow_likelihood:4.40338	validation_1-breslow_likelihood:3.19204
# [44]	validation_0-breslow_likelihood:4.40313	validation_1-breslow_likelihood:3.19195
# [45]	validation_0-breslow_likelihood:4.40293	validation_1-breslow_likelihood:3.19199
# [46]	validation_0-breslow_likelihood:4.40259	validation_1-breslow_likelihood:3.19204
# [47]	validation_0-breslow_likelihood:4.40228	validation_1-breslow_likelihood:3.19199
# [48]	validation_0-breslow_likelihood:4.40193	validation_1-breslow_likelihood:3.19195
# [49]	validation_0-breslow_likelihood:4.40171	validation_1-breslow_likelihood:3.19191
# [50]	validation_0-breslow_likelihood:4.40150	validation_1-breslow_likelihood:3.19190
# [51]	validation_0-breslow_likelihood:4.40125	validation_1-breslow_likelihood:3.19205
# [52]	validation_0-breslow_likelihood:4.40103	validation_1-breslow_likelihood:3.19202
# [53]	validation_0-breslow_likelihood:4.40084	validation_1-breslow_likelihood:3.19195
# [0]	validation_0-breslow_likelihood:4.38226	validation_1-breslow_likelihood:3.04600[54]	validation_0-breslow_likelihood:4.40055	validation_1-breslow_likelihood:3.19188
#
# [55]	validation_0-breslow_likelihood:4.40036	validation_1-breslow_likelihood:3.19186
# ...
# [7]	validation_0-breslow_likelihood:4.81254	validation_1-breslow_likelihood:3.98992
# [8]	validation_0-breslow_likelihood:4.76797	validation_1-breslow_likelihood:3.99153
# [9]	validation_0-breslow_likelihood:4.72451	validation_1-breslow_likelihood:3.98586
# [0]	validation_0-breslow_likelihood:5.33418	validation_1-breslow_likelihood:3.71201
# [1]	validation_0-breslow_likelihood:5.28171	validation_1-breslow_likelihood:3.72586
# [0]	validation_0-breslow_likelihood:5.14355	validation_1-breslow_likelihood:4.10251
# [2]	validation_0-breslow_likelihood:5.23108	validation_1-breslow_likelihood:3.73753
# [1]	validation_0-breslow_likelihood:5.09424	validation_1-breslow_likelihood:4.09824
# [3]	validation_0-breslow_likelihood:5.17823	validation_1-breslow_likelihood:3.75490
# [2]	validation_0-breslow_likelihood:5.04697	validation_1-breslow_likelihood:4.09434
# [4]	validation_0-breslow_likelihood:5.13066	validation_1-breslow_likelihood:3.75681
# [5]	validation_0-breslow_likelihood:5.08260	validation_1-breslow_likelihood:3.77261
# [6]	validation_0-breslow_likelihood:5.03852	validation_1-breslow_likelihood:3.77068
# [3]	validation_0-breslow_likelihood:4.99875	validation_1-breslow_likelihood:4.09554
# [7]	validation_0-breslow_likelihood:4.99018	validation_1-breslow_likelihood:3.77379
# [8]	validation_0-breslow_likelihood:4.94766	validation_1-breslow_likelihood:3.77980
# [9]	validation_0-breslow_likelihood:4.90217	validation_1-breslow_likelihood:3.78930
# [4]	validation_0-breslow_likelihood:4.95416	validation_1-breslow_likelihood:4.09936
# [10]	validation_0-breslow_likelihood:4.85668	validation_1-breslow_likelihood:3.79636
# [5]	validation_0-breslow_likelihood:4.90492	validation_1-breslow_likelihood:4.08918
# [6]	validation_0-breslow_likelihood:4.85656	validation_1-breslow_likelihood:4.09047
# [7]	validation_0-breslow_likelihood:4.81088	validation_1-breslow_likelihood:4.08467
# [8]	validation_0-breslow_likelihood:4.76652	validation_1-breslow_likelihood:4.07904
# [0]	validation_0-breslow_likelihood:5.23909	validation_1-breslow_likelihood:3.90759
# [9]	validation_0-breslow_likelihood:4.72107	validation_1-breslow_likelihood:4.07401
# [1]	validation_0-breslow_likelihood:5.19242	validation_1-breslow_likelihood:3.90449
# [10]	validation_0-breslow_likelihood:4.67642	validation_1-breslow_likelihood:4.07767
# [2]	validation_0-breslow_likelihood:5.14673	validation_1-breslow_likelihood:3.90666
# [11]	validation_0-breslow_likelihood:4.63294	validation_1-breslow_likelihood:4.08777
# [3]	validation_0-breslow_likelihood:5.09806	validation_1-breslow_likelihood:3.90586
# [4]	validation_0-breslow_likelihood:5.04926	validation_1-breslow_likelihood:3.90983
# [5]	validation_0-breslow_likelihood:4.99836	validation_1-breslow_likelihood:3.90970
# [12]	validation_0-breslow_likelihood:4.59334	validation_1-breslow_likelihood:4.09464
# [6]	validation_0-breslow_likelihood:4.95122	validation_1-breslow_likelihood:3.90543
# [13]	validation_0-breslow_likelihood:4.55201	validation_1-breslow_likelihood:4.08874
# [7]	validation_0-breslow_likelihood:4.90369	validation_1-breslow_likelihood:3.89003
# [14]	validation_0-breslow_likelihood:4.50983	validation_1-breslow_likelihood:4.08732
# [8]	validation_0-breslow_likelihood:4.85750	validation_1-breslow_likelihood:3.89244
# [15]	validation_0-breslow_likelihood:4.46844	validation_1-breslow_likelihood:4.09119
# [9]	validation_0-breslow_likelihood:4.81118	validation_1-breslow_likelihood:3.90103
# [16]	validation_0-breslow_likelihood:4.43140	validation_1-breslow_likelihood:4.09634
# [17]	validation_0-breslow_likelihood:4.39084	validation_1-breslow_likelihood:4.09654
# [18]	validation_0-breslow_likelihood:4.35089	validation_1-breslow_likelihood:4.10852
# [19]	validation_0-breslow_likelihood:4.31325	validation_1-breslow_likelihood:4.10933
# [10]	validation_0-breslow_likelihood:4.76308	validation_1-breslow_likelihood:3.90433
# [11]	validation_0-breslow_likelihood:4.72001	validation_1-breslow_likelihood:3.90344
# [12]	validation_0-breslow_likelihood:4.67429	validation_1-breslow_likelihood:3.89908
# [13]	validation_0-breslow_likelihood:4.63077	validation_1-breslow_likelihood:3.89965
# [14]	validation_0-breslow_likelihood:4.58929	validation_1-breslow_likelihood:3.89600
# [15]	validation_0-breslow_likelihood:4.54550	validation_1-breslow_likelihood:3.88569
# [16]	validation_0-breslow_likelihood:4.50221	validation_1-breslow_likelihood:3.87366
# [17]	validation_0-breslow_likelihood:4.46078	validation_1-breslow_likelihood:3.87510
# [18]	validation_0-breslow_likelihood:4.41743	validation_1-breslow_likelihood:3.87075
# [19]	validation_0-breslow_likelihood:4.37980	validation_1-breslow_likelihood:3.87229
# [20]	validation_0-breslow_likelihood:4.34169	validation_1-breslow_likelihood:3.87571
# [21]	validation_0-breslow_likelihood:4.30230	validation_1-breslow_likelihood:3.88098
# [22]	validation_0-breslow_likelihood:4.26617	validation_1-breslow_likelihood:3.88868
# [23]	validation_0-breslow_likelihood:4.22860	validation_1-breslow_likelihood:3.89486
# [24]	validation_0-breslow_likelihood:4.19569	validation_1-breslow_likelihood:3.89912
# [25]	validation_0-breslow_likelihood:4.16096	validation_1-breslow_likelihood:3.89122
# [26]	validation_0-breslow_likelihood:4.12765	validation_1-breslow_likelihood:3.89343
# [27]	validation_0-breslow_likelihood:4.09374	validation_1-breslow_likelihood:3.87781
# [0]	validation_0-breslow_likelihood:5.22252	validation_1-breslow_likelihood:3.85819
# [1]	validation_0-breslow_likelihood:5.16888	validation_1-breslow_likelihood:3.85270
# [2]	validation_0-breslow_likelihood:5.12257	validation_1-breslow_likelihood:3.85198
# [3]	validation_0-breslow_likelihood:5.07088	validation_1-breslow_likelihood:3.85033
# [4]	validation_0-breslow_likelihood:5.02239	validation_1-breslow_likelihood:3.83851
# [5]	validation_0-breslow_likelihood:4.97464	validation_1-breslow_likelihood:3.83500
# [6]	validation_0-breslow_likelihood:4.92544	validation_1-breslow_likelihood:3.84018
# [7]	validation_0-breslow_likelihood:4.87609	validation_1-breslow_likelihood:3.83964
# [8]	validation_0-breslow_likelihood:4.82838	validation_1-breslow_likelihood:3.83668
# [9]	validation_0-breslow_likelihood:4.78092	validation_1-breslow_likelihood:3.83420
# [10]	validation_0-breslow_likelihood:4.73422	validation_1-breslow_likelihood:3.84221
# [11]	validation_0-breslow_likelihood:4.68657	validation_1-breslow_likelihood:3.84085
# [12]	validation_0-breslow_likelihood:4.64286	validation_1-breslow_likelihood:3.84335
# [13]	validation_0-breslow_likelihood:4.60027	validation_1-breslow_likelihood:3.84260
# [14]	validation_0-breslow_likelihood:4.55712	validation_1-breslow_likelihood:3.84855
# [15]	validation_0-breslow_likelihood:4.51938	validation_1-breslow_likelihood:3.85023
# [16]	validation_0-breslow_likelihood:4.47724	validation_1-breslow_likelihood:3.85673
# [17]	validation_0-breslow_likelihood:4.43239	validation_1-breslow_likelihood:3.85979
# [18]	validation_0-breslow_likelihood:4.38993	validation_1-breslow_likelihood:3.86163
# [19]	validation_0-breslow_likelihood:4.35020	validation_1-breslow_likelihood:3.86428
# [0]	validation_0-breslow_likelihood:5.38676	validation_1-breslow_likelihood:3.70022
# [1]	validation_0-breslow_likelihood:5.38676	validation_1-breslow_likelihood:3.69940
# [2]	validation_0-breslow_likelihood:5.38676	validation_1-breslow_likelihood:3.69723
# [3]	validation_0-breslow_likelihood:5.38676	validation_1-breslow_likelihood:3.69701
# [4]	validation_0-breslow_likelihood:5.39048	validation_1-breslow_likelihood:3.68224
# [5]	validation_0-breslow_likelihood:5.39048	validation_1-breslow_likelihood:3.68152
# [6]	validation_0-breslow_likelihood:5.39048	validation_1-breslow_likelihood:3.68285
# [7]	validation_0-breslow_likelihood:5.39101	validation_1-breslow_likelihood:3.68755
# [8]	validation_0-breslow_likelihood:5.39101	validation_1-breslow_likelihood:3.68850
# [9]	validation_0-breslow_likelihood:5.39101	validation_1-breslow_likelihood:3.68986
# [10]	validation_0-breslow_likelihood:5.39101	validation_1-breslow_likelihood:3.68697
# [11]	validation_0-breslow_likelihood:5.39101	validation_1-breslow_likelihood:3.68552
# [12]	validation_0-breslow_likelihood:5.39101	validation_1-breslow_likelihood:3.68648
# [13]	validation_0-breslow_likelihood:5.39101	validation_1-breslow_likelihood:3.68470
# [14]	validation_0-breslow_likelihood:5.37007	validation_1-breslow_likelihood:3.71651
# [15]	validation_0-breslow_likelihood:5.37007	validation_1-breslow_likelihood:3.71593
# [0]	validation_0-breslow_likelihood:5.27037	validation_1-breslow_likelihood:3.86763
# [0]	validation_0-breslow_likelihood:5.19930	validation_1-breslow_likelihood:3.95177
# [1]	validation_0-breslow_likelihood:5.27066	validation_1-breslow_likelihood:3.86763
# [1]	validation_0-breslow_likelihood:5.19913	validation_1-breslow_likelihood:3.95119
# [2]	validation_0-breslow_likelihood:5.26986	validation_1-breslow_likelihood:3.86763
# [2]	validation_0-breslow_likelihood:5.19868	validation_1-breslow_likelihood:3.94966
# [3]	validation_0-breslow_likelihood:5.26978	validation_1-breslow_likelihood:3.86763
# [3]	validation_0-breslow_likelihood:5.19847	validation_1-breslow_likelihood:3.94896
# [4]	validation_0-breslow_likelihood:5.26303	validation_1-breslow_likelihood:3.87344
# [5]	validation_0-breslow_likelihood:5.26339	validation_1-breslow_likelihood:3.87344
# [6]	validation_0-breslow_likelihood:5.26352	validation_1-breslow_likelihood:3.87344
# [4]	validation_0-breslow_likelihood:5.18140	validation_1-breslow_likelihood:3.92808
# [7]	validation_0-breslow_likelihood:5.25905	validation_1-breslow_likelihood:3.86713
# [5]	validation_0-breslow_likelihood:5.18190	validation_1-breslow_likelihood:3.92977
# [8]	validation_0-breslow_likelihood:5.25941	validation_1-breslow_likelihood:3.86713
# [9]	validation_0-breslow_likelihood:5.26000	validation_1-breslow_likelihood:3.86713
# [6]	validation_0-breslow_likelihood:5.18174	validation_1-breslow_likelihood:3.92922
# [10]	validation_0-breslow_likelihood:5.25986	validation_1-breslow_likelihood:3.86713
# [11]	validation_0-breslow_likelihood:5.25942	validation_1-breslow_likelihood:3.86713
# [12]	validation_0-breslow_likelihood:5.25961	validation_1-breslow_likelihood:3.86713
# [13]	validation_0-breslow_likelihood:5.25966	validation_1-breslow_likelihood:3.86713
# [7]	validation_0-breslow_likelihood:5.17171	validation_1-breslow_likelihood:3.93641
# [14]	validation_0-breslow_likelihood:5.26005	validation_1-breslow_likelihood:3.86713
# [8]	validation_0-breslow_likelihood:5.17212	validation_1-breslow_likelihood:3.93780
# [15]	validation_0-breslow_likelihood:5.26058	validation_1-breslow_likelihood:3.86713
# [9]	validation_0-breslow_likelihood:5.17213	validation_1-breslow_likelihood:3.93782
# [16]	validation_0-breslow_likelihood:5.26029	validation_1-breslow_likelihood:3.86713
# [10]	validation_0-breslow_likelihood:5.17081	validation_1-breslow_likelihood:3.93331
# [17]	validation_0-breslow_likelihood:5.25952	validation_1-breslow_likelihood:3.86713
# [11]	validation_0-breslow_likelihood:5.17197	validation_1-breslow_likelihood:3.93728
# [12]	validation_0-breslow_likelihood:5.17146	validation_1-breslow_likelihood:3.93553
# [13]	validation_0-breslow_likelihood:5.17213	validation_1-breslow_likelihood:3.93783
# [0]	validation_0-breslow_likelihood:5.28898	validation_1-breslow_likelihood:3.90996
# [0]	validation_0-breslow_likelihood:5.19269	validation_1-breslow_likelihood:4.09314
# [1]	validation_0-breslow_likelihood:5.19306	validation_1-breslow_likelihood:4.09426
# [1]	validation_0-breslow_likelihood:5.28959	validation_1-breslow_likelihood:3.91181
# [2]	validation_0-breslow_likelihood:5.19284	validation_1-breslow_likelihood:4.09357
# [2]	validation_0-breslow_likelihood:5.28915	validation_1-breslow_likelihood:3.91048
# [3]	validation_0-breslow_likelihood:5.19244	validation_1-breslow_likelihood:4.09236
# [3]	validation_0-breslow_likelihood:5.28905	validation_1-breslow_likelihood:3.91017
# [4]	validation_0-breslow_likelihood:5.18149	validation_1-breslow_likelihood:4.07796
# [4]	validation_0-breslow_likelihood:5.28918	validation_1-breslow_likelihood:3.90393
# [5]	validation_0-breslow_likelihood:5.18193	validation_1-breslow_likelihood:4.07928
# [5]	validation_0-breslow_likelihood:5.28962	validation_1-breslow_likelihood:3.90527
# [6]	validation_0-breslow_likelihood:5.18155	validation_1-breslow_likelihood:4.07813
# [6]	validation_0-breslow_likelihood:5.29004	validation_1-breslow_likelihood:3.90655
# [7]	validation_0-breslow_likelihood:5.17019	validation_1-breslow_likelihood:4.06358
# [7]	validation_0-breslow_likelihood:5.27945	validation_1-breslow_likelihood:3.90835
# [8]	validation_0-breslow_likelihood:5.16997	validation_1-breslow_likelihood:4.06291
# [8]	validation_0-breslow_likelihood:5.27885	validation_1-breslow_likelihood:3.90651
# [9]	validation_0-breslow_likelihood:5.16906	validation_1-breslow_likelihood:4.06014
# [9]	validation_0-breslow_likelihood:5.27885	validation_1-breslow_likelihood:3.90651
# [10]	validation_0-breslow_likelihood:5.17013	validation_1-breslow_likelihood:4.06340
# [10]	validation_0-breslow_likelihood:5.27780	validation_1-breslow_likelihood:3.90331
# [11]	validation_0-breslow_likelihood:5.16898	validation_1-breslow_likelihood:4.05989
# [11]	validation_0-breslow_likelihood:5.27757	validation_1-breslow_likelihood:3.90261
# [12]	validation_0-breslow_likelihood:5.16826	validation_1-breslow_likelihood:4.05771
# [12]	validation_0-breslow_likelihood:5.27638	validation_1-breslow_likelihood:3.89901
# [13]	validation_0-breslow_likelihood:5.27661	validation_1-breslow_likelihood:3.89970
# [14]	validation_0-breslow_likelihood:5.27970	validation_1-breslow_likelihood:3.90735
# [13]	validation_0-breslow_likelihood:5.16850	validation_1-breslow_likelihood:4.05844
# [15]	validation_0-breslow_likelihood:5.27958	validation_1-breslow_likelihood:3.90698
# [14]	validation_0-breslow_likelihood:5.16919	validation_1-breslow_likelihood:4.06054
# [16]	validation_0-breslow_likelihood:5.27981	validation_1-breslow_likelihood:3.90768
# [15]	validation_0-breslow_likelihood:5.16873	validation_1-breslow_likelihood:4.05913
# [17]	validation_0-breslow_likelihood:5.27925	validation_1-breslow_likelihood:3.90598
# [16]	validation_0-breslow_likelihood:5.16886	validation_1-breslow_likelihood:4.05952
# [17]	validation_0-breslow_likelihood:5.16979	validation_1-breslow_likelihood:4.06236
# [18]	validation_0-breslow_likelihood:5.27938	validation_1-breslow_likelihood:3.90637
# [18]	validation_0-breslow_likelihood:5.16981	validation_1-breslow_likelihood:4.06242
# [19]	validation_0-breslow_likelihood:5.27960	validation_1-breslow_likelihood:3.90706
# [19]	validation_0-breslow_likelihood:5.17087	validation_1-breslow_likelihood:4.06563
# [20]	validation_0-breslow_likelihood:5.27947	validation_1-breslow_likelihood:3.90665
# [20]	validation_0-breslow_likelihood:5.17143	validation_1-breslow_likelihood:4.06735
# [21]	validation_0-breslow_likelihood:5.27836	validation_1-breslow_likelihood:3.90328
# [21]	validation_0-breslow_likelihood:5.17126	validation_1-breslow_likelihood:4.06682
# [22]	validation_0-breslow_likelihood:5.27878	validation_1-breslow_likelihood:3.90453
# [0]	validation_0-breslow_likelihood:5.39752	validation_1-breslow_likelihood:4.49599
# [1]	validation_0-breslow_likelihood:5.34947	validation_1-breslow_likelihood:4.49636
# [2]	validation_0-breslow_likelihood:5.30097	validation_1-breslow_likelihood:4.50282
# [3]	validation_0-breslow_likelihood:5.25292	validation_1-breslow_likelihood:4.50638
# [4]	validation_0-breslow_likelihood:5.20688	validation_1-breslow_likelihood:4.50974
# [5]	validation_0-breslow_likelihood:5.16143	validation_1-breslow_likelihood:4.51647
# [6]	validation_0-breslow_likelihood:5.11582	validation_1-breslow_likelihood:4.51380
# [7]	validation_0-breslow_likelihood:5.07031	validation_1-breslow_likelihood:4.51512
# [8]	validation_0-breslow_likelihood:5.02588	validation_1-breslow_likelihood:4.53758
# [9]	validation_0-breslow_likelihood:4.98477	validation_1-breslow_likelihood:4.54656
# Concordance Index 0.6307940047070482
# Integrated Brier Score: 0.19202003244323113
# durations 1.0 7106.0
# Concordance Index 0.42105263157894735
# Integrated Brier Score: 0.17947261824789554
# (865, 20531) <class 'pandas.core.frame.DataFrame'>
# (865,) <class 'pandas.core.series.Series'>
# (216, 20531) <class 'pandas.core.frame.DataFrame'>
# (216,) <class 'pandas.core.series.Series'>
