# %%
## XGBSurv EH Benchmark

# %%
from xgbsurv.datasets import (load_metabric, load_flchain, load_rgbsg, load_support, load_tcga)
from xgbsurv import XGBSurv
from xgbsurv.evaluation import cindex_censored, ibs
from xgbsurv.models.utils import sort_X_y
import os
import numpy as np
import pandas as pd
from scipy.stats import uniform as scuniform
from scipy.stats import randint as scrandint
from scipy.stats import loguniform as scloguniform 
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, LabelBinarizer, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.decomposition import PCA
# import models
from xgbsurv.models.breslow_final import breslow_likelihood,get_cumulative_hazard_function_breslow
from xgbsurv.models.eh_final import eh_likelihood
from pycox.evaluation import EvalSurv
from xgbsurv.models.utils import sort_X_y_pandas, transform_back, transform
from xgbsurv.preprocessing.dataset_preprocessing import discretizer_df

# %% [markdown]
# ## Set Parameters

# %%
# set parameters
n_outer_splits = 5
n_inner_splits = 5
rand_state = 42
n_iter = 100
n_iter_cind = 200
early_stopping_rounds=10
base_score = 0.0

# Define parameter grid for random forest classifier
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
}

# %% [markdown]
# ## Custom Splitting

# %%
class CustomSplit(StratifiedKFold):
    def __init__(self, n_splits=5, shuffle=True, random_state=None):
        super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)

    def split(self, X, y, groups=None):
        y = y.to_numpy()
        try:
            if y.shape[1]>1:
                y = y[:,0]
        except:
            pass
        bins = np.sign(y)
        #print('bins', bins.shape)
        return super().split(X, bins, groups=groups)

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

outer_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)
inner_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)

# %% [markdown]
# ## Scoring Function

# %%
scoring_function = make_scorer(eh_likelihood, greater_is_better=False)

# %% [markdown]
# ## Set Model & Train Test Evaluate

# %%
data_set_fns = [load_metabric,  load_flchain, load_rgbsg, load_support] #, load_flchain, load_rgbsg, load_support, load_tcga]
data_set_fns_str = ['load_metabric', 'load_flchain', 'load_rgbsg', 'load_support'] 
one_hot_dict = {'load_flchain': ['mgus'], 'load_support':['cancer'], 'load_rgbsg':['grade']}

for idx, dataset in enumerate(data_set_fns):
    model = 'xgbsurv_eh_'
    # get name of current dataset
    data = dataset(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=True)
    filename = data.filename
    X  = data.data
    y  = data.target #.astype(np.float32)
    X, y = sort_X_y_pandas(X, y)
    y = pd.concat([data.target,data.target], axis=1) #.values #.to_numpy()
    #print('x y shape', X.shape,y.shape)
    
    print(data_set_fns_str[idx])
    if data_set_fns_str[idx] in one_hot_dict.keys():
        X = pd.get_dummies(X, columns=one_hot_dict[data_set_fns_str[idx]])
    
    #print(X.dtypes)
    dataset_name = filename.split('_')[0]
    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            #(OneHotEncoder(sparse_output=False), make_column_selector(dtype_include=['category', 'object']))
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='eh_objective',
        eval_metric='eh_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    pipe = Pipeline([('scaler',ct),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=2, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        #print(X_train.shape, type(X_train))
        #print(y_train.shape, type(y_train))
        #print(X_test.shape, type(X_test))
        #print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
    #     try:
    #         cum_hazard_train = get_cumulative_hazard_function_breslow(
    #                 X_train.values, X_train.values, y_train.values, y_train.values,
    #                 best_preds_train.reshape(-1), best_preds_train.reshape(-1)
    #                 )

    #         df_survival_train = np.exp(-cum_hazard_train)
    #         durations_train, events_train = transform_back(y_train.values)
    #         time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
    #         ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
    #         print('Concordance Index',ev.concordance_td('antolini'))
    #         print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
    #         cindex_score_train = ev.concordance_td('antolini')
    #         ibs_score_train = ev.integrated_brier_score(time_grid_train)

    #         outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
    #         outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

    #     except:
    #         outer_scores['cindex_train_'+dataset_name] += [np.nan]
    #         outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
    #     try:
    #         cum_hazard_test = get_cumulative_hazard_function_breslow(
    #                 X_train.values, X_test.values, y_train.values, y_test.values,
    #                 best_preds_train.reshape(-1), best_preds_test.reshape(-1)
    #                 )
    #         df_survival_test = np.exp(-cum_hazard_test)
    #         durations_test, events_test = transform_back(y_test.values)
    #         print('durations',durations_test.min(), durations_test.max())
    #         time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
    #         ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
    #         print('Concordance Index',ev.concordance_td('antolini'))
    #         print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
    #         cindex_score_test = ev.concordance_td('antolini')
    #         ibs_score_test = ev.integrated_brier_score(time_grid_test)

    #         outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
    #         outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
    #     except: 
    #         outer_scores['cindex_test_'+dataset_name] += [np.nan]
    #         outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    # df_best_params = pd.DataFrame(best_params)
    # df_best_model = pd.DataFrame(best_model)
    # df_outer_scores = pd.DataFrame(outer_scores)
    # df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    # df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# Out:
# load_metabric
# bins (1903,)
# bins (1522,)
# [0]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [1]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [2]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [0]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [0]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [0]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [1]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [3]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [0]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [1]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [1]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [4]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [2]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [0]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [0]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [1]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [2]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [2]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [0]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [5]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [1]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [1]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [3]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [2]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [3]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [1]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [3]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [6]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [0]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [4]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [0]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [3]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [4]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [2]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [2]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [2]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [7]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [1]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [4]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [5]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [4]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [5]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [1]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [3]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [3]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [2]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [8]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [5]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [6]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [5]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [3]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [2]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [6]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [4]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [4]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [9]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [3]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [6]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [7]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [3]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [6]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [4]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [7]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [5]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [10]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [5]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [4]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [8]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [7]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [4]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [6]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [5]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [8]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [7]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [5]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [6]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [8]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [5]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [9]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [6]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [7]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [8]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [7]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [9]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [6]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [6]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [9]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [7]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [8]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [9]	validation_0-eh_likelihood:3.12291	validation_1-eh_likelihood:3.13984
# [8]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [7]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [10]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [7]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [10]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [9]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [8]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [8]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [9]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [8]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [10]	validation_0-eh_likelihood:3.09364	validation_1-eh_likelihood:3.22469
# [9]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [9]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [10]	validation_0-eh_likelihood:3.09031	validation_1-eh_likelihood:3.23914
# [9]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [10]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [10]	validation_0-eh_likelihood:3.12968	validation_1-eh_likelihood:3.08786
# [10]	validation_0-eh_likelihood:3.09534	validation_1-eh_likelihood:3.21812
# [0]	validation_0-eh_likelihood:3.07901	validation_1-eh_likelihood:3.28572
# [1]	validation_0-eh_likelihood:3.07901	validation_1-eh_likelihood:3.28572
# [2]	validation_0-eh_likelihood:3.07901	validation_1-eh_likelihood:3.28572
# [3]	validation_0-eh_likelihood:3.07901	validation_1-eh_likelihood:3.28572
# [4]	validation_0-eh_likelihood:3.07901	validation_1-eh_likelihood:3.28572
# [5]	validation_0-eh_likelihood:3.07901	validation_1-eh_likelihood:3.28572
# [6]	validation_0-eh_likelihood:3.07901	validation_1-eh_likelihood:3.28572
# [7]	validation_0-eh_likelihood:3.07901	validation_1-eh_likelihood:3.28572
# [8]	validation_0-eh_likelihood:3.07901	validation_1-eh_likelihood:3.28572
# [9]	validation_0-eh_likelihood:3.07901	validation_1-eh_likelihood:3.28572
# [10]	validation_0-eh_likelihood:3.07901	validation_1-eh_likelihood:3.28572
# bins (1522,)
# [0]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [0]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [0]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [0]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [0]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [0]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [0]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [1]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [1]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [0]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [1]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [1]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [1]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [1]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [1]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [2]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [1]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [2]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [2]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [2]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [2]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [2]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [2]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [3]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [2]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [3]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [3]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [3]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [3]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [3]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [3]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [4]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [4]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [4]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [4]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [3]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [4]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [4]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [4]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [5]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [5]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [5]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [5]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [4]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [5]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [5]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [5]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [6]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [6]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [6]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [5]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [6]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [6]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [6]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [6]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [7]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [7]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [7]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [6]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [7]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [7]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [7]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [7]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [8]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [8]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [8]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [8]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [8]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [7]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [8]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [9]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [8]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [9]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [9]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [9]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [9]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [9]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [8]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [9]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [10]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [10]	validation_0-eh_likelihood:3.11769	validation_1-eh_likelihood:3.17496
# [10]	validation_0-eh_likelihood:3.12139	validation_1-eh_likelihood:3.12259
# [10]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [10]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [9]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [10]	validation_0-eh_likelihood:3.14350	validation_1-eh_likelihood:3.03076
# [0]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [0]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [1]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [1]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [2]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [2]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [3]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [3]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [4]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [4]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [5]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [5]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [6]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [6]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [7]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [7]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [8]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [8]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [9]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [9]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [10]	validation_0-eh_likelihood:3.17366	validation_1-eh_likelihood:2.96079
# [10]	validation_0-eh_likelihood:3.14477	validation_1-eh_likelihood:3.03300
# [0]	validation_0-eh_likelihood:3.10869	validation_1-eh_likelihood:3.18232
# [1]	validation_0-eh_likelihood:3.10869	validation_1-eh_likelihood:3.18232
# [2]	validation_0-eh_likelihood:3.10869	validation_1-eh_likelihood:3.18232
# [3]	validation_0-eh_likelihood:3.10869	validation_1-eh_likelihood:3.18232
# [4]	validation_0-eh_likelihood:3.10869	validation_1-eh_likelihood:3.18232
# [5]	validation_0-eh_likelihood:3.10869	validation_1-eh_likelihood:3.18232
# [6]	validation_0-eh_likelihood:3.10869	validation_1-eh_likelihood:3.18232
# [7]	validation_0-eh_likelihood:3.10869	validation_1-eh_likelihood:3.18232
# [8]	validation_0-eh_likelihood:3.10869	validation_1-eh_likelihood:3.18232
# [9]	validation_0-eh_likelihood:3.10869	validation_1-eh_likelihood:3.18232
# bins (1522,)
# [0]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [0]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [0]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [0]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [0]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [0]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [0]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [1]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [1]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [0]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [0]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [1]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [0]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [1]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [1]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [1]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [1]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [2]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [1]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [1]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [2]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [2]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [1]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [2]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [2]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [2]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [2]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [3]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [2]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [2]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [3]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [3]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [3]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [2]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [3]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [3]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [3]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [4]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [3]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [3]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [4]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [4]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [4]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [4]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [3]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [4]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [5]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [4]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [5]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [4]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [4]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [5]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [5]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [5]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [4]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [6]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [5]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [5]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [6]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [6]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [7]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [6]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [5]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [6]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [5]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [6]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [6]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [7]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [5]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [7]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [8]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [7]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [7]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [6]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [6]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [7]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [9]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [8]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [8]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [7]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [6]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [8]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [7]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [7]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [8]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [8]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [10]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [9]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [9]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [8]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [7]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [8]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [9]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [9]	validation_0-eh_likelihood:3.13347	validation_1-eh_likelihood:3.08305
# [9]	validation_0-eh_likelihood:3.10884	validation_1-eh_likelihood:3.16637
# [8]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [10]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [8]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [9]	validation_0-eh_likelihood:3.15519	validation_1-eh_likelihood:3.01245
# [9]	validation_0-eh_likelihood:3.09744	validation_1-eh_likelihood:3.20978
# [9]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [9]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [10]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [10]	validation_0-eh_likelihood:3.12533	validation_1-eh_likelihood:3.09743
# [0]	validation_0-eh_likelihood:3.13403	validation_1-eh_likelihood:3.06110
# [1]	validation_0-eh_likelihood:3.13403	validation_1-eh_likelihood:3.06110
# [2]	validation_0-eh_likelihood:3.13403	validation_1-eh_likelihood:3.06110
# [3]	validation_0-eh_likelihood:3.13403	validation_1-eh_likelihood:3.06110
# [4]	validation_0-eh_likelihood:3.13403	validation_1-eh_likelihood:3.06110
# [5]	validation_0-eh_likelihood:3.13403	validation_1-eh_likelihood:3.06110
# [6]	validation_0-eh_likelihood:3.13403	validation_1-eh_likelihood:3.06110
# [7]	validation_0-eh_likelihood:3.13403	validation_1-eh_likelihood:3.06110
# [8]	validation_0-eh_likelihood:3.13403	validation_1-eh_likelihood:3.06110
# [9]	validation_0-eh_likelihood:3.13403	validation_1-eh_likelihood:3.06110
# bins (1523,)
# [0]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [0]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [0]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [0]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [0]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [0]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [0]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [0]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [1]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [0]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [0]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [1]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [1]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [1]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [1]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [1]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [1]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [1]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [2]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [1]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [1]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [2]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [2]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [2]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [2]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [2]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [2]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [2]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [3]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [2]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [3]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [2]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [3]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [3]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [3]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [3]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [3]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [4]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [3]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [4]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [3]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [3]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [4]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [4]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [4]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [4]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [4]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [5]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [4]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [4]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [4]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [5]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [5]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [5]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [5]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [6]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [5]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [5]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [5]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [6]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [5]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [5]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [6]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [6]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [6]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [7]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [6]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [6]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [7]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [6]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [6]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [7]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [6]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [7]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [7]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [8]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [8]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [7]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [7]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [7]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [8]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [7]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [8]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [7]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [8]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [9]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [9]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [8]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [8]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [8]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [9]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [8]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [8]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [9]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [9]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [10]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [9]	validation_0-eh_likelihood:3.10891	validation_1-eh_likelihood:3.15287
# [9]	validation_0-eh_likelihood:3.11802	validation_1-eh_likelihood:3.12520
# [10]	validation_0-eh_likelihood:3.09160	validation_1-eh_likelihood:3.24298
# [9]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [9]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [9]	validation_0-eh_likelihood:3.10085	validation_1-eh_likelihood:3.16326
# [10]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [10]	validation_0-eh_likelihood:3.10993	validation_1-eh_likelihood:3.17820
# [0]	validation_0-eh_likelihood:3.10592	validation_1-eh_likelihood:3.17059
# [1]	validation_0-eh_likelihood:3.10592	validation_1-eh_likelihood:3.17059
# [2]	validation_0-eh_likelihood:3.10592	validation_1-eh_likelihood:3.17059
# [3]	validation_0-eh_likelihood:3.10592	validation_1-eh_likelihood:3.17059
# [4]	validation_0-eh_likelihood:3.10592	validation_1-eh_likelihood:3.17059
# [5]	validation_0-eh_likelihood:3.10592	validation_1-eh_likelihood:3.17059
# [6]	validation_0-eh_likelihood:3.10592	validation_1-eh_likelihood:3.17059
# [7]	validation_0-eh_likelihood:3.10592	validation_1-eh_likelihood:3.17059
# [8]	validation_0-eh_likelihood:3.10592	validation_1-eh_likelihood:3.17059
# [9]	validation_0-eh_likelihood:3.10592	validation_1-eh_likelihood:3.17059
# [10]	validation_0-eh_likelihood:3.10592	validation_1-eh_likelihood:3.17059
# bins (1523,)
# [0]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [0]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [0]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [0]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [0]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [0]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [0]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [0]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [0]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [1]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [1]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [1]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [0]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [1]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [1]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [1]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [1]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [1]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [2]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [2]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [2]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [1]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [1]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [2]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [2]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [2]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [2]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [2]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [3]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [2]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [3]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [3]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [2]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [3]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [3]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [3]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [3]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [3]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [4]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [4]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [4]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [4]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [4]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [3]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [3]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [4]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [4]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [5]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [5]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [5]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [5]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [4]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [4]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [4]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [5]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [5]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [5]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [6]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [6]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [5]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [5]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [6]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [6]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [5]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [6]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [6]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [6]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [7]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [7]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [6]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [7]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [7]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [7]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [6]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [6]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [7]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [7]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [8]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [8]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [7]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [7]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [8]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [7]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [8]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [8]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [8]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [9]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [8]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [9]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [8]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [8]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [9]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [8]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [9]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [9]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [9]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [9]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [10]	validation_0-eh_likelihood:3.09473	validation_1-eh_likelihood:3.22401
# [9]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [9]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [10]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [9]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [10]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [10]	validation_0-eh_likelihood:3.07659	validation_1-eh_likelihood:3.24493
# [10]	validation_0-eh_likelihood:3.13529	validation_1-eh_likelihood:3.07445
# [10]	validation_0-eh_likelihood:3.13459	validation_1-eh_likelihood:3.05870
# [10]	validation_0-eh_likelihood:3.11532	validation_1-eh_likelihood:3.15418
# [0]	validation_0-eh_likelihood:3.08862	validation_1-eh_likelihood:3.23486
# [1]	validation_0-eh_likelihood:3.08862	validation_1-eh_likelihood:3.23486
# [2]	validation_0-eh_likelihood:3.08862	validation_1-eh_likelihood:3.23486
# [3]	validation_0-eh_likelihood:3.08862	validation_1-eh_likelihood:3.23486
# [4]	validation_0-eh_likelihood:3.08862	validation_1-eh_likelihood:3.23486
# [5]	validation_0-eh_likelihood:3.08862	validation_1-eh_likelihood:3.23486
# [6]	validation_0-eh_likelihood:3.08862	validation_1-eh_likelihood:3.23486
# [7]	validation_0-eh_likelihood:3.08862	validation_1-eh_likelihood:3.23486
# [8]	validation_0-eh_likelihood:3.08862	validation_1-eh_likelihood:3.23486
# [9]	validation_0-eh_likelihood:3.08862	validation_1-eh_likelihood:3.23486
# [10]	validation_0-eh_likelihood:3.08862	validation_1-eh_likelihood:3.23486
# load_flchain
# bins (7871,)
# bins (6296,)
# [0]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [0]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [0]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [0]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [0]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [0]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [0]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [0]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [0]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [0]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [1]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [1]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [1]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [1]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [1]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [1]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [1]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [1]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [1]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [1]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [2]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [2]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [2]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [2]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [2]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [2]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [2]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [2]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [2]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [3]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [3]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [3]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [2]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [3]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [3]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [3]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [3]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [3]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [4]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [3]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [4]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [4]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [4]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [4]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [4]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [4]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [3]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [4]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [5]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [4]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [5]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [5]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [5]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [5]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [5]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# [5]	validation_0-eh_likelihood:2.60433	validation_1-eh_likelihood:2.64234
# [4]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [5]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [6]	validation_0-eh_likelihood:2.57183	validation_1-eh_likelihood:2.77579
# [6]	validation_0-eh_likelihood:2.57092	validation_1-eh_likelihood:2.77779
# [5]	validation_0-eh_likelihood:2.60154	validation_1-eh_likelihood:2.65622
# [6]	validation_0-eh_likelihood:2.58997	validation_1-eh_likelihood:2.70122
# ...
# [2]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [2]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [2]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [3]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [3]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [3]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [3]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [3]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [3]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [3]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [4]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [4]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [4]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [4]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [4]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [4]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [4]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [5]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [5]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [5]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [5]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [5]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [5]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [5]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [6]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [6]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [0]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [0]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [6]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [6]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [6]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [6]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [6]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [0]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [7]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [1]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [7]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [1]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [7]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [7]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [7]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [7]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [7]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [1]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [8]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [2]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [8]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [2]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [8]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [8]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [8]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [8]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [2]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [8]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [9]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [9]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [3]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [3]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [9]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [9]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [9]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [9]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [9]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [3]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [10]	validation_0-eh_likelihood:3.92473	validation_1-eh_likelihood:3.93570
# [10]	validation_0-eh_likelihood:3.93664	validation_1-eh_likelihood:3.94031
# [4]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [4]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [10]	validation_0-eh_likelihood:3.92290	validation_1-eh_likelihood:3.88014
# [5]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [4]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [5]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [6]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [5]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [6]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [7]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [6]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [7]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [8]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [7]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [8]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [8]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [9]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [9]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [9]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [10]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [10]	validation_0-eh_likelihood:3.92149	validation_1-eh_likelihood:3.99897
# [10]	validation_0-eh_likelihood:3.95881	validation_1-eh_likelihood:3.81501
# [0]	validation_0-eh_likelihood:3.93175	validation_1-eh_likelihood:3.91830
# [1]	validation_0-eh_likelihood:3.93175	validation_1-eh_likelihood:3.91830
# [2]	validation_0-eh_likelihood:3.93175	validation_1-eh_likelihood:3.91830
# [3]	validation_0-eh_likelihood:3.93175	validation_1-eh_likelihood:3.91830
# [4]	validation_0-eh_likelihood:3.93175	validation_1-eh_likelihood:3.91830
# [5]	validation_0-eh_likelihood:3.93175	validation_1-eh_likelihood:3.91830
# [6]	validation_0-eh_likelihood:3.93175	validation_1-eh_likelihood:3.91830
# [7]	validation_0-eh_likelihood:3.93175	validation_1-eh_likelihood:3.91830
# [8]	validation_0-eh_likelihood:3.93175	validation_1-eh_likelihood:3.91830
# [9]	validation_0-eh_likelihood:3.93175	validation_1-eh_likelihood:3.91830
# [10]	validation_0-eh_likelihood:3.93175	validation_1-eh_likelihood:3.91830
# bins (7099,)
# [0]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [0]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [0]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [0]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [0]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [1]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [0]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [0]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [0]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [1]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [1]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [1]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [1]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [2]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [1]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [1]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [1]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [2]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [2]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [2]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [2]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [3]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [2]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [2]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [2]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [3]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [3]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [3]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [3]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [4]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [3]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [3]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [3]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [4]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [4]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [4]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [5]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [4]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [4]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [4]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [4]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [5]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [6]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [5]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [5]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [5]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [5]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [0]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [0]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [5]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [5]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [6]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [6]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [7]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [6]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [6]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [1]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [1]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [6]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [6]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [6]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [7]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [7]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [7]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [8]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [7]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [2]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [7]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [2]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [7]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [7]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [8]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [9]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [8]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [8]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [3]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [8]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [3]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [8]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [8]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [10]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [8]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [9]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [9]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [9]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [4]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [4]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [9]	validation_0-eh_likelihood:3.93844	validation_1-eh_likelihood:3.88904
# [9]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [9]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [9]	validation_0-eh_likelihood:3.95523	validation_1-eh_likelihood:3.77017
# [10]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [5]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [10]	validation_0-eh_likelihood:3.91949	validation_1-eh_likelihood:3.93136
# [5]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [10]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [6]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [6]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [7]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [7]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [8]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [8]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [9]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [9]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [10]	validation_0-eh_likelihood:3.94194	validation_1-eh_likelihood:3.87451
# [10]	validation_0-eh_likelihood:3.91028	validation_1-eh_likelihood:3.88859
# [0]	validation_0-eh_likelihood:3.93271	validation_1-eh_likelihood:3.87119
# [1]	validation_0-eh_likelihood:3.93271	validation_1-eh_likelihood:3.87119
# [2]	validation_0-eh_likelihood:3.93271	validation_1-eh_likelihood:3.87119
# [3]	validation_0-eh_likelihood:3.93271	validation_1-eh_likelihood:3.87119
# [4]	validation_0-eh_likelihood:3.93271	validation_1-eh_likelihood:3.87119
# [5]	validation_0-eh_likelihood:3.93271	validation_1-eh_likelihood:3.87119
# [6]	validation_0-eh_likelihood:3.93271	validation_1-eh_likelihood:3.87119
# [7]	validation_0-eh_likelihood:3.93271	validation_1-eh_likelihood:3.87119
# [8]	validation_0-eh_likelihood:3.93271	validation_1-eh_likelihood:3.87119
# [9]	validation_0-eh_likelihood:3.93271	validation_1-eh_likelihood:3.87119

# %% [markdown]
# ## TCGA Train, Test, Evaluation

# %%
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
'pca__n_components': [8, 10, 12, 14, 16]
}

# %%
cancer_types = ['BLCA',
    'BRCA',
    'HNSC',
    'KIRC',
    'LGG',
    'LIHC',
    'LUAD',
    'LUSC',
    'OV',
    'STAD']


for idx, cancer_type in enumerate(cancer_types):
    model = 'xgbsurv_breslow_'
    # get name of current dataset
    data = load_tcga(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", cancer_type=cancer_type, as_frame=True)
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()
    filename = data.filename
    dataset_name = filename.split('_')[0]
    X, y = sort_X_y_pandas(X, y)
    y = pd.concat([data.target,data.target], axis=1)
    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            #(OneHotEncoder(sparse_output=False), make_column_selector(dtype_include=['category', 'object']))
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='breslow_objective',
        eval_metric='breslow_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    
    pipe = Pipeline([('scaler',ct),
                    ('pca', PCA()),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=2, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        print(X_train.shape, type(X_train))
        print(y_train.shape, type(y_train))
        print(X_test.shape, type(X_test))
        print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_breslow(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_breslow(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# Out:
# bins (406,)
# (324, 20531) <class 'pandas.core.frame.DataFrame'>
# (324, 2) <class 'pandas.core.frame.DataFrame'>
# (82, 20531) <class 'pandas.core.frame.DataFrame'>
# (82, 2) <class 'pandas.core.frame.DataFrame'>
# bins (324,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 70
#      67 np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
#      68 np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')
# ---> 70 rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
#      71 best_preds_train = rs.best_estimator_.predict(X_train)
#      72 best_preds_test = rs.best_estimator_.predict(X_test)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1768, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1766 def _run_search(self, evaluate_candidates):
#    1767     """Search n_iter candidates from param_distributions"""
# -> 1768     evaluate_candidates(
#    1769         ParameterSampler(
#    1770             self.param_distributions, self.n_iter, random_state=self.random_state
#    1771         )
#    1772     )
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:851, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     844 elif len(out) != n_candidates * n_splits:
#     845     raise ValueError(
#     846         "cv.split and cv.get_n_splits returned "
#     847         "inconsistent results. Expected {} "
#     848         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     849     )
# --> 851 _warn_or_raise_about_fit_failures(out, self.error_score)
#     853 # For callable self.scoring, the return type is only know after
#     854 # calling. If the return type is a dictionary, the error scores
#     855 # can now be inserted with the correct key. The type checking
#     856 # of out will be done in `_insert_error_scores`.
#     857 if callable(self.scoring):
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:367, in _warn_or_raise_about_fit_failures(results, error_score)
#     360 if num_failed_fits == num_fits:
#     361     all_fits_failed_message = (
#     362         f"\nAll the {num_fits} fits failed.\n"
#     363         "It is very likely that your model is misconfigured.\n"
#     364         "You can try to debug the error by setting error_score='raise'.\n\n"
#     365         f"Below are more details about the failures:\n{fit_errors_summary}"
#     366     )
# --> 367     raise ValueError(all_fits_failed_message)
#     369 else:
#     370     some_fits_failed_message = (
#     371         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     372         "The score on these train-test partitions for these parameters"
#    (...)
#     376         f"Below are more details about the failures:\n{fit_errors_summary}"
#     377     )
#
# ValueError:
# All the 10 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgbsurv/base.py", line 94, in fit
#     return super(XGBSurv, self).fit(X_train, y_train, **kwargs)
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py", line 1025, in fit
#     self._Booster = train(
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/core.py", line 620, in inner_f
#     return func(**kwargs)
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/training.py", line 185, in train
#     bst.update(dtrain, i, obj)
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/core.py", line 1923, in update
#     grad, hess = fobj(pred, dtrain)
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py", line 107, in inner
#     return func(labels, preds)
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/numba/core/dispatcher.py", line 468, in _compile_for_args
#     error_rewrite(e, 'typing')
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/numba/core/dispatcher.py", line 409, in error_rewrite
#     raise e.with_traceback(None)
# numba.core.errors.TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# No implementation of function Function(<built-in function iadd>) found for signature:
#
#  >>> iadd(Literal[int](0), array(float32, 1d, C))
#
# There are 18 candidate implementations:
#      - Of which 16 did not match due to:
#      Overload of function 'iadd': File: <numerous>: Line N/A.
#        With argument(s): '(int64, array(float32, 1d, C))':
#       No match.
#      - Of which 2 did not match due to:
#      Operator Overload in function 'iadd': File: unknown: Line unknown.
#        With argument(s): '(int64, array(float32, 1d, C))':
#       No match for registered cases:
#        * (int64, int64) -> int64
#        * (int64, uint64) -> int64
#        * (uint64, int64) -> int64
#        * (uint64, uint64) -> uint64
#        * (float32, float32) -> float32
#        * (float64, float64) -> float64
#        * (complex64, complex64) -> complex64
#        * (complex128, complex128) -> complex128
#
# During: typing of intrinsic-call at /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgbsurv/models/breslow_final.py (119)
#
# File "../../../../miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgbsurv/models/breslow_final.py", line 119:
# def breslow_objective(y: npt.NDArray[float], log_partial_hazard: npt.NDArray[float]) -> tuple[npt.NDArray[float], npt.NDArray[float]]:
#     <source elided>
#
#     grad = np.empty(samples)
#     ^
