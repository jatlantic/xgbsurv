# %% [markdown]
# ## XGBSurv AFT Benchmark

# %%
from xgbsurv.datasets import (load_metabric, load_flchain, load_rgbsg, load_support, load_tcga)
from xgbsurv import XGBSurv
from xgbsurv.evaluation import cindex_censored, ibs
from xgbsurv.models.utils import sort_X_y
import os
import numpy as np
import pandas as pd
from scipy.stats import uniform as scuniform
from scipy.stats import randint as scrandint
from scipy.stats import loguniform as scloguniform 
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, LabelBinarizer, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.decomposition import PCA
# import models
from xgbsurv.models.eh_aft_final import aft_likelihood, get_cumulative_hazard_function_aft
from xgbsurv.models.eh_ah_final import ah_likelihood
from pycox.evaluation import EvalSurv
from xgbsurv.models.utils import sort_X_y_pandas, transform_back, transform
from xgbsurv.preprocessing.dataset_preprocessing import discretizer_df
from sklearn.utils.fixes import loguniform #https://scikit-learn.org/stable/modules/grid_search.html

# %% [markdown]
# ## Set Parameters

# %%
# set parameters
n_outer_splits = 5
n_inner_splits = 5
rand_state = 42
n_iter = 1 #50
early_stopping_rounds=10
base_score = 0.0
validation_size = 0.2

# set seed for scipy
np.random.seed(rand_state)

# Define parameter grid for random forest classifier
param_grid = {
#'estimator__reg_alpha': loguniform(1e-10,1.0),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': loguniform(1e-10,1.0), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': loguniform(0.01,1.0), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,4000), # corresponds to num_rounds 4000
#'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : loguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
}

# %% [markdown]
# ## Custom Splitting

# %%
class CustomSplit(StratifiedKFold):
    def __init__(self, n_splits=5, shuffle=True, random_state=None):
        super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)

    def split(self, X, y, groups=None):
        try:
            if y.shape[1]>1:
                y = y[:,0]
        except:
            pass
        bins = np.sign(y)
        return super().split(X, bins, groups=groups)

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

outer_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)
inner_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)

# %% [markdown]
# ## Scoring Function

# %%
#scoring_function = make_scorer(aft_likelihood, greater_is_better=True) # changed here

def custom_scoring_function(y_true, y_pred):

    if not isinstance(y_true, np.ndarray):
        y_true = y_true.values
    if not isinstance(y_pred, np.ndarray):
        y_pred = y_pred.values
    # change order of this later
    score = aft_likelihood(y_true, y_pred)
    return score

scoring_function = make_scorer(custom_scoring_function, greater_is_better=False)

# %% [markdown]
# ## Set Model & Train Test Evaluate

# %%
data_set_fns = [load_flchain] #load_metabric, load_flchain, load_rgbsg, load_support]
data_set_fns_str = ['load_metabric', 'load_flchain', 'load_rgbsg', 'load_support'] 
one_hot_dict = {'load_flchain': ['mgus'], 'load_support':['cancer', 'race'], 'load_rgbsg':['grade']}
agg_metrics_cindex = []
agg_metrics_ibs = []
agg_best_settings = []

for idx, dataset in enumerate(data_set_fns):
    model = 'xgbsurv_aft_'
    # get name of current dataset
    data = dataset(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=True)
    filename = data.filename
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()

    print(data_set_fns_str[idx])
    #if data_set_fns_str[idx] in one_hot_dict.keys():
    #   X = pd.get_dummies(X, columns=one_hot_dict[data_set_fns_str[idx]])
    #print(X)
    X, y = sort_X_y_pandas(X, y)
    #print(X.dtypes)
    dataset_name = filename.split('_')[0]
    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            (StandardScaler(), make_column_selector(dtype_include=['float32'], dtype_exclude=['category', 'object', 'int'])),
            #(OneHotEncoder(sparse_output=False, handle_unknown='infrequent_if_exist'), make_column_selector(dtype_include=['category', 'object'])),
            remainder='passthrough')
    
    estimator = XGBSurv(
        objective='aft_objective', 
        eval_metric='aft_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score,
        verbosity=1,
        )
    pipe = Pipeline([('scaler',ct),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=n_iter, refit=True, 
                             verbose = 3, random_state=rand_state)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        #print(X_train.shape, type(X_train))
        #print(y_train.shape, type(y_train))
        #print(y_test.shape, type(y_test))
        #print(X_test.shape, type(X_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        #np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        #np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        #np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        #np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=validation_size)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        #print(' best_preds_train', best_preds_train)
        #print(' best_preds_test', best_preds_test)
        np.savetxt('predictions/'+model+'best_preds_train_'+str(i)+'_'+filename, best_preds_train, delimiter=',')
        np.savetxt('predictions/'+model+'best_preds_test_'+str(i)+'_'+filename, best_preds_test, delimiter=',')


        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    # df_outer_scores = pd.DataFrame(outer_scores)
    df_best_settings = pd.concat([df_best_params,df_best_model])
    df_best_settings.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
    agg_best_settings.append(df_best_settings)

df_final_settings = pd.concat([df for df in agg_best_settings])
df_final_settings.to_csv('metrics/final_settings_gbdt_aft_1.csv', index=False)
# Out:
# load_metabric
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [0]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [0]	validation_0-aft_likelihood:2.61287	validation_1-aft_likelihood:2.61027
# [0]	validation_0-aft_likelihood:2.61237	validation_1-aft_likelihood:2.61036
# [0]	validation_0-aft_likelihood:2.61160	validation_1-aft_likelihood:2.61510
# [1]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [1]	validation_0-aft_likelihood:2.61287	validation_1-aft_likelihood:2.61027
# [1]	validation_0-aft_likelihood:2.61237	validation_1-aft_likelihood:2.61036
# [1]	validation_0-aft_likelihood:2.61160	validation_1-aft_likelihood:2.61510
# [2]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [2]	validation_0-aft_likelihood:2.61287	validation_1-aft_likelihood:2.61027
# [2]	validation_0-aft_likelihood:2.61237	validation_1-aft_likelihood:2.61036
# [0]	validation_0-aft_likelihood:2.61307	validation_1-aft_likelihood:2.60917
# [2]	validation_0-aft_likelihood:2.61160	validation_1-aft_likelihood:2.61510
# [3]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [3]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [3]	validation_0-aft_likelihood:2.61237	validation_1-aft_likelihood:2.61036
# [1]	validation_0-aft_likelihood:2.61307	validation_1-aft_likelihood:2.60917
# [3]	validation_0-aft_likelihood:2.61160	validation_1-aft_likelihood:2.61510
# [4]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [4]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [4]	validation_0-aft_likelihood:2.61237	validation_1-aft_likelihood:2.61036
# [2]	validation_0-aft_likelihood:2.61307	validation_1-aft_likelihood:2.60917
# [4]	validation_0-aft_likelihood:2.61160	validation_1-aft_likelihood:2.61510
# [5]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [5]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [5]	validation_0-aft_likelihood:2.61237	validation_1-aft_likelihood:2.61036
# [3]	validation_0-aft_likelihood:2.61307	validation_1-aft_likelihood:2.60917
# [5]	validation_0-aft_likelihood:2.61160	validation_1-aft_likelihood:2.61510
# [6]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [6]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [4]	validation_0-aft_likelihood:2.61307	validation_1-aft_likelihood:2.60917
# [6]	validation_0-aft_likelihood:2.61237	validation_1-aft_likelihood:2.61036
# [6]	validation_0-aft_likelihood:2.61160	validation_1-aft_likelihood:2.61510
# [7]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [7]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [5]	validation_0-aft_likelihood:2.61307	validation_1-aft_likelihood:2.60917
# [7]	validation_0-aft_likelihood:2.61160	validation_1-aft_likelihood:2.61510
# [7]	validation_0-aft_likelihood:2.61237	validation_1-aft_likelihood:2.61036
# [8]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [8]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [6]	validation_0-aft_likelihood:2.61307	validation_1-aft_likelihood:2.60917
# [8]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [8]	validation_0-aft_likelihood:2.61237	validation_1-aft_likelihood:2.61036
# [9]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [9]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [7]	validation_0-aft_likelihood:2.61307	validation_1-aft_likelihood:2.60917
# [9]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [9]	validation_0-aft_likelihood:2.61237	validation_1-aft_likelihood:2.61035
# [10]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [10]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [8]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [10]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [10]	validation_0-aft_likelihood:2.61237	validation_1-aft_likelihood:2.61035
# [11]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [11]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [11]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [9]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [11]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [12]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [12]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [12]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [10]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [12]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [13]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [13]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [13]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [11]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [13]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [14]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [14]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [14]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [12]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [14]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [15]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [15]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [15]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [13]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [15]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [16]	validation_0-aft_likelihood:2.61267	validation_1-aft_likelihood:2.61300
# [16]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [16]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [14]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [17]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61300
# [16]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [17]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [17]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [15]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [18]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [17]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [18]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [18]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [16]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [19]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [18]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [19]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [19]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [17]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [20]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [19]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [20]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [20]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [18]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [21]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [20]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [21]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [21]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [19]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [22]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [21]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [22]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [22]	validation_0-aft_likelihood:2.61286	validation_1-aft_likelihood:2.61026
# [20]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [23]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [22]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [23]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61510
# [23]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [21]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [24]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [23]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [24]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61509
# [24]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [22]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [25]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [24]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [25]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61509
# [25]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [23]	validation_0-aft_likelihood:2.61306	validation_1-aft_likelihood:2.60916
# [26]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [25]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [26]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61509
# [26]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [24]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60916
# [27]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [26]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [27]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61509
# [27]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [25]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60916
# [28]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [27]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [28]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61509
# [28]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [26]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60916
# [29]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [29]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61509
# [28]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [29]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [27]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [30]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [30]	validation_0-aft_likelihood:2.61159	validation_1-aft_likelihood:2.61509
# [29]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [30]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [28]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [31]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [31]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [30]	validation_0-aft_likelihood:2.61236	validation_1-aft_likelihood:2.61035
# [31]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [29]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [32]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [32]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [31]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61035
# [32]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [30]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [33]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [33]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [32]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61034
# [31]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [33]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [34]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [34]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [33]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61034
# [32]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [34]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [35]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [35]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [34]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61034
# [33]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [35]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [36]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [36]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [35]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61034
# [34]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [36]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [37]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [37]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [36]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61034
# [35]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [37]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [38]	validation_0-aft_likelihood:2.61266	validation_1-aft_likelihood:2.61299
# [38]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [37]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61034
# [36]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [38]	validation_0-aft_likelihood:2.61285	validation_1-aft_likelihood:2.61025
# [39]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61299
# [39]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [38]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61034
# [37]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [40]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [39]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61025
# [40]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [39]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61034
# [38]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [41]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [40]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61025
# [41]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [40]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61034
# [39]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [42]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [41]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61025
# [42]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61509
# [41]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61034
# [40]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [43]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [42]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61024
# [43]	validation_0-aft_likelihood:2.61158	validation_1-aft_likelihood:2.61508
# [42]	validation_0-aft_likelihood:2.61235	validation_1-aft_likelihood:2.61034
# [41]	validation_0-aft_likelihood:2.61305	validation_1-aft_likelihood:2.60915
# [44]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [43]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61024
# [44]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [42]	validation_0-aft_likelihood:2.61304	validation_1-aft_likelihood:2.60915
# [43]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61034
# [45]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [44]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61024
# [45]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [43]	validation_0-aft_likelihood:2.61304	validation_1-aft_likelihood:2.60915
# [44]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [46]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [45]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61024
# [46]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [44]	validation_0-aft_likelihood:2.61304	validation_1-aft_likelihood:2.60914
# [47]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [45]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [46]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61024
# [47]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [45]	validation_0-aft_likelihood:2.61304	validation_1-aft_likelihood:2.60914
# [48]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [46]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [48]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [47]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61024
# [46]	validation_0-aft_likelihood:2.61304	validation_1-aft_likelihood:2.60914
# [49]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [49]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [47]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [48]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61024
# [50]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [47]	validation_0-aft_likelihood:2.61304	validation_1-aft_likelihood:2.60914
# [50]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [48]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [49]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61024
# [51]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [48]	validation_0-aft_likelihood:2.61304	validation_1-aft_likelihood:2.60914
# [51]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [50]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61024
# [49]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [52]	validation_0-aft_likelihood:2.61265	validation_1-aft_likelihood:2.61298
# [49]	validation_0-aft_likelihood:2.61304	validation_1-aft_likelihood:2.60914
# [52]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [51]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61024
# [50]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [53]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61298
# [50]	validation_0-aft_likelihood:2.61304	validation_1-aft_likelihood:2.60914
# [53]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [52]	validation_0-aft_likelihood:2.61284	validation_1-aft_likelihood:2.61024
# [51]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [54]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61298
# [54]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [51]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60914
# [53]	validation_0-aft_likelihood:2.61283	validation_1-aft_likelihood:2.61024
# [52]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [55]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61298
# [55]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [52]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60914
# [54]	validation_0-aft_likelihood:2.61283	validation_1-aft_likelihood:2.61024
# [53]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [56]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61298
# [56]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [53]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60914
# [55]	validation_0-aft_likelihood:2.61283	validation_1-aft_likelihood:2.61023
# [54]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [57]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61298
# [57]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [54]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60914
# [56]	validation_0-aft_likelihood:2.61283	validation_1-aft_likelihood:2.61023
# [55]	validation_0-aft_likelihood:2.61234	validation_1-aft_likelihood:2.61033
# [58]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61298
# [58]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.61508
# [55]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60914
# [57]	validation_0-aft_likelihood:2.61283	validation_1-aft_likelihood:2.61023
# [56]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61033
# [59]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61298
# [59]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [56]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60914
# [58]	validation_0-aft_likelihood:2.61283	validation_1-aft_likelihood:2.61023
# [57]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61033
# [60]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61298
# [60]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [57]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60914
# [59]	validation_0-aft_likelihood:2.61283	validation_1-aft_likelihood:2.61023
# [58]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61033
# [61]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61298
# [61]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [58]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60914
# [60]	validation_0-aft_likelihood:2.61283	validation_1-aft_likelihood:2.61023
# [59]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [62]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61298
# [62]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [59]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60914
# [61]	validation_0-aft_likelihood:2.61283	validation_1-aft_likelihood:2.61023
# [60]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [63]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61297
# [63]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [60]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60914
# [62]	validation_0-aft_likelihood:2.61283	validation_1-aft_likelihood:2.61023
# [61]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [64]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [64]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61297
# [61]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60913
# [63]	validation_0-aft_likelihood:2.61283	validation_1-aft_likelihood:2.61023
# [62]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [65]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [65]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61297
# [62]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60913
# [64]	validation_0-aft_likelihood:2.61282	validation_1-aft_likelihood:2.61023
# [63]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [66]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [66]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61297
# [63]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60913
# [65]	validation_0-aft_likelihood:2.61282	validation_1-aft_likelihood:2.61023
# [64]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [67]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [67]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61297
# [64]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60913
# [66]	validation_0-aft_likelihood:2.61282	validation_1-aft_likelihood:2.61023
# [65]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [68]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [68]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61297
# [65]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60913
# [67]	validation_0-aft_likelihood:2.61282	validation_1-aft_likelihood:2.61023
# [69]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [66]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [69]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61297
# [66]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60913
# [68]	validation_0-aft_likelihood:2.61282	validation_1-aft_likelihood:2.61023
# [70]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [70]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61297
# [67]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [67]	validation_0-aft_likelihood:2.61303	validation_1-aft_likelihood:2.60913
# [69]	validation_0-aft_likelihood:2.61282	validation_1-aft_likelihood:2.61023
# [71]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [71]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61297
# [68]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [68]	validation_0-aft_likelihood:2.61302	validation_1-aft_likelihood:2.60913
# [70]	validation_0-aft_likelihood:2.61282	validation_1-aft_likelihood:2.61023
# [72]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [72]	validation_0-aft_likelihood:2.61264	validation_1-aft_likelihood:2.61297
# [69]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [69]	validation_0-aft_likelihood:2.61302	validation_1-aft_likelihood:2.60913
# [71]	validation_0-aft_likelihood:2.61282	validation_1-aft_likelihood:2.61023
# [73]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61507
# [73]	validation_0-aft_likelihood:2.61263	validation_1-aft_likelihood:2.61297
# [70]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [70]	validation_0-aft_likelihood:2.61302	validation_1-aft_likelihood:2.60913
# [72]	validation_0-aft_likelihood:2.61282	validation_1-aft_likelihood:2.61023
# [74]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.61506
# [CV 5/5] END estimator__colsample_bylevel=0.4370861069626263, estimator__colsample_bynode=0.9556428757689246, estimator__colsample_bytree=0.8659969709057025, estimator__learning_rate=0.15751320499779722, estimator__max_delta_step=6, estimator__max_depth=19, estimator__min_child_weight=0.16975698090861446, estimator__n_estimators=75, estimator__reg_lambda=0.045894586123264684, estimator__subsample=0.6051038616257767;, score=-2.611 total time=  23.2s
# [74]	validation_0-aft_likelihood:2.61263	validation_1-aft_likelihood:2.61297
# [71]	validation_0-aft_likelihood:2.61233	validation_1-aft_likelihood:2.61032
# [CV 1/5] END estimator__colsample_bylevel=0.4370861069626263, estimator__colsample_bynode=0.9556428757689246, estimator__colsample_bytree=0.8659969709057025, estimator__learning_rate=0.15751320499779722, estimator__max_delta_step=6, estimator__max_depth=19, estimator__min_child_weight=0.16975698090861446, estimator__n_estimators=75, estimator__reg_lambda=0.045894586123264684, estimator__subsample=0.6051038616257767;, score=-2.611 total time=  23.4s
# [71]	validation_0-aft_likelihood:2.61302	validation_1-aft_likelihood:2.60913
# [73]	validation_0-aft_likelihood:2.61282	validation_1-aft_likelihood:2.61022
# [72]	validation_0-aft_likelihood:2.61232	validation_1-aft_likelihood:2.61032
# [72]	validation_0-aft_likelihood:2.61302	validation_1-aft_likelihood:2.60913
# [74]	validation_0-aft_likelihood:2.61282	validation_1-aft_likelihood:2.61022
# [CV 3/5] END estimator__colsample_bylevel=0.4370861069626263, estimator__colsample_bynode=0.9556428757689246, estimator__colsample_bytree=0.8659969709057025, estimator__learning_rate=0.15751320499779722, estimator__max_delta_step=6, estimator__max_depth=19, estimator__min_child_weight=0.16975698090861446, estimator__n_estimators=75, estimator__reg_lambda=0.045894586123264684, estimator__subsample=0.6051038616257767;, score=-2.613 total time=  23.7s
# [73]	validation_0-aft_likelihood:2.61232	validation_1-aft_likelihood:2.61031
# [73]	validation_0-aft_likelihood:2.61302	validation_1-aft_likelihood:2.60913
# [74]	validation_0-aft_likelihood:2.61232	validation_1-aft_likelihood:2.61031
# [74]	validation_0-aft_likelihood:2.61302	validation_1-aft_likelihood:2.60913
# [CV 4/5] END estimator__colsample_bylevel=0.4370861069626263, estimator__colsample_bynode=0.9556428757689246, estimator__colsample_bytree=0.8659969709057025, estimator__learning_rate=0.15751320499779722, estimator__max_delta_step=6, estimator__max_depth=19, estimator__min_child_weight=0.16975698090861446, estimator__n_estimators=75, estimator__reg_lambda=0.045894586123264684, estimator__subsample=0.6051038616257767;, score=-2.610 total time=  24.2s
# [CV 2/5] END estimator__colsample_bylevel=0.4370861069626263, estimator__colsample_bynode=0.9556428757689246, estimator__colsample_bytree=0.8659969709057025, estimator__learning_rate=0.15751320499779722, estimator__max_delta_step=6, estimator__max_depth=19, estimator__min_child_weight=0.16975698090861446, estimator__n_estimators=75, estimator__reg_lambda=0.045894586123264684, estimator__subsample=0.6051038616257767;, score=-2.611 total time=  24.2s
# [0]	validation_0-aft_likelihood:2.61225	validation_1-aft_likelihood:2.61250
# [1]	validation_0-aft_likelihood:2.61225	validation_1-aft_likelihood:2.61250
# [2]	validation_0-aft_likelihood:2.61225	validation_1-aft_likelihood:2.61250
# [3]	validation_0-aft_likelihood:2.61225	validation_1-aft_likelihood:2.61250
# [4]	validation_0-aft_likelihood:2.61225	validation_1-aft_likelihood:2.61250
# [5]	validation_0-aft_likelihood:2.61225	validation_1-aft_likelihood:2.61250
# [6]	validation_0-aft_likelihood:2.61225	validation_1-aft_likelihood:2.61250
# [7]	validation_0-aft_likelihood:2.61225	validation_1-aft_likelihood:2.61249
# [8]	validation_0-aft_likelihood:2.61225	validation_1-aft_likelihood:2.61249
# [9]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [10]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [11]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [12]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [13]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [14]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [15]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [16]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [17]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [18]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [19]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [20]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [21]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [22]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [23]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [24]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [25]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [26]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61249
# [27]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61248
# [28]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61248
# [29]	validation_0-aft_likelihood:2.61224	validation_1-aft_likelihood:2.61248
# [30]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61248
# [31]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61248
# [32]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61248
# [33]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61248
# [34]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61248
# [35]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61248
# [36]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61248
# [37]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61248
# [38]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61248
# [39]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61248
# [40]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61247
# [41]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61247
# [42]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61247
# [43]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61247
# [44]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61247
# [45]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61247
# [46]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61247
# [47]	validation_0-aft_likelihood:2.61223	validation_1-aft_likelihood:2.61247
# [48]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [49]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [50]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [51]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [52]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [53]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [54]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [55]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [56]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [57]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [58]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [59]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [60]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [61]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [62]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [63]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [64]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [65]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [66]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [67]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [68]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [69]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61247
# [70]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61246
# [71]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61246
# [72]	validation_0-aft_likelihood:2.61222	validation_1-aft_likelihood:2.61246
# [73]	validation_0-aft_likelihood:2.61221	validation_1-aft_likelihood:2.61246
# [74]	validation_0-aft_likelihood:2.61221	validation_1-aft_likelihood:2.61246
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [0]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60955
# [1]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60955
# [2]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60955
# [3]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60955
# [4]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60955
# [5]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60955
# [6]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60954
# [7]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60954
# [8]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60954
# [9]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60954
# [10]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60954
# [11]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60954
# [12]	validation_0-aft_likelihood:2.61157	validation_1-aft_likelihood:2.60954
# [13]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [14]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [15]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [16]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [0]	validation_0-aft_likelihood:2.60988	validation_1-aft_likelihood:2.60677
# [0]	validation_0-aft_likelihood:2.61102	validation_1-aft_likelihood:2.61807
# [0]	validation_0-aft_likelihood:2.61173	validation_1-aft_likelihood:2.60961
# [0]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [17]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [1]	validation_0-aft_likelihood:2.60988	validation_1-aft_likelihood:2.60677
# [1]	validation_0-aft_likelihood:2.61102	validation_1-aft_likelihood:2.61807
# [1]	validation_0-aft_likelihood:2.61173	validation_1-aft_likelihood:2.60961
# [1]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [18]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [2]	validation_0-aft_likelihood:2.60988	validation_1-aft_likelihood:2.60677
# [2]	validation_0-aft_likelihood:2.61102	validation_1-aft_likelihood:2.61807
# [2]	validation_0-aft_likelihood:2.61173	validation_1-aft_likelihood:2.60961
# [2]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [19]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [3]	validation_0-aft_likelihood:2.60988	validation_1-aft_likelihood:2.60677
# [3]	validation_0-aft_likelihood:2.61102	validation_1-aft_likelihood:2.61807
# [3]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60961
# [20]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [3]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [4]	validation_0-aft_likelihood:2.60988	validation_1-aft_likelihood:2.60677
# [4]	validation_0-aft_likelihood:2.61102	validation_1-aft_likelihood:2.61807
# [4]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60961
# [21]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [4]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [5]	validation_0-aft_likelihood:2.60988	validation_1-aft_likelihood:2.60677
# [5]	validation_0-aft_likelihood:2.61102	validation_1-aft_likelihood:2.61807
# [5]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60961
# [22]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [5]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [6]	validation_0-aft_likelihood:2.60988	validation_1-aft_likelihood:2.60677
# [6]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61807
# [23]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [6]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60961
# [6]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [7]	validation_0-aft_likelihood:2.60988	validation_1-aft_likelihood:2.60677
# [7]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61807
# [24]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [7]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60961
# [7]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [8]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60677
# [8]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61807
# [25]	validation_0-aft_likelihood:2.61156	validation_1-aft_likelihood:2.60954
# [8]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [8]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [9]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60677
# [9]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61807
# [26]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [9]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [9]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [10]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60677
# [10]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61807
# [27]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [10]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [10]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [11]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60677
# [11]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61807
# [28]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [11]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [11]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [12]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [12]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61807
# [29]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [12]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [12]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61418
# [13]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [13]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61806
# [30]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [13]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [13]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61417
# [14]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [14]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61806
# [31]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [14]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [14]	validation_0-aft_likelihood:2.60975	validation_1-aft_likelihood:2.61417
# [15]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [15]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61806
# [32]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [15]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [15]	validation_0-aft_likelihood:2.60974	validation_1-aft_likelihood:2.61417
# [16]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [16]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61806
# [33]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [16]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [16]	validation_0-aft_likelihood:2.60974	validation_1-aft_likelihood:2.61417
# [17]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [17]	validation_0-aft_likelihood:2.61101	validation_1-aft_likelihood:2.61806
# [17]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [34]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [17]	validation_0-aft_likelihood:2.60974	validation_1-aft_likelihood:2.61417
# [18]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [18]	validation_0-aft_likelihood:2.61100	validation_1-aft_likelihood:2.61806
# [18]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [35]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [18]	validation_0-aft_likelihood:2.60974	validation_1-aft_likelihood:2.61417
# [19]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [19]	validation_0-aft_likelihood:2.61100	validation_1-aft_likelihood:2.61806
# [19]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [36]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [19]	validation_0-aft_likelihood:2.60974	validation_1-aft_likelihood:2.61417
# [20]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [20]	validation_0-aft_likelihood:2.61100	validation_1-aft_likelihood:2.61806
# [20]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [37]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [20]	validation_0-aft_likelihood:2.60974	validation_1-aft_likelihood:2.61417
# [21]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [21]	validation_0-aft_likelihood:2.61100	validation_1-aft_likelihood:2.61806
# [21]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [38]	validation_0-aft_likelihood:2.61155	validation_1-aft_likelihood:2.60953
# [21]	validation_0-aft_likelihood:2.60974	validation_1-aft_likelihood:2.61417
# [22]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [22]	validation_0-aft_likelihood:2.61100	validation_1-aft_likelihood:2.61806
# [22]	validation_0-aft_likelihood:2.61172	validation_1-aft_likelihood:2.60960
# [39]	validation_0-aft_likelihood:2.61154	validation_1-aft_likelihood:2.60953
# [22]	validation_0-aft_likelihood:2.60974	validation_1-aft_likelihood:2.61417
# [23]	validation_0-aft_likelihood:2.60987	validation_1-aft_likelihood:2.60676
# [23]	validation_0-aft_likelihood:2.61100	validation_1-aft_likelihood:2.61806
# [23]	validation_0-aft_likelihood:2.61171	validation_1-aft_likelihood:2.60960
# [40]	validation_0-aft_likelihood:2.61154	validation_1-aft_likelihood:2.60953
# [23]	validation_0-aft_likelihood:2.60974	validation_1-aft_likelihood:2.61417
# [24]	validation_0-aft_likelihood:2.61100	validation_1-aft_likelihood:2.61806
# [24]	validation_0-aft_likelihood:2.60986	validation_1-aft_likelihood:2.60676
# [24]	validation_0-aft_likelihood:2.61171	validation_1-aft_likelihood:2.60960
# [41]	validation_0-aft_likelihood:2.61154	validation_1-aft_likelihood:2.60952
# [24]	validation_0-aft_likelihood:2.60974	validation_1-aft_likelihood:2.61417
# [25]	validation_0-aft_likelihood:2.61100	validation_1-aft_likelihood:2.61806
# ...
# [51]	validation_0-aft_likelihood:2.61218	validation_1-aft_likelihood:2.60962
# [54]	validation_0-aft_likelihood:2.61013	validation_1-aft_likelihood:2.61562
# [54]	validation_0-aft_likelihood:2.61241	validation_1-aft_likelihood:2.60923
# [53]	validation_0-aft_likelihood:2.61042	validation_1-aft_likelihood:2.60637
# [53]	validation_0-aft_likelihood:2.61083	validation_1-aft_likelihood:2.61839
# [52]	validation_0-aft_likelihood:2.61218	validation_1-aft_likelihood:2.60962
# [55]	validation_0-aft_likelihood:2.61013	validation_1-aft_likelihood:2.61562
# [55]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60923
# [54]	validation_0-aft_likelihood:2.61042	validation_1-aft_likelihood:2.60637
# [54]	validation_0-aft_likelihood:2.61083	validation_1-aft_likelihood:2.61839
# [53]	validation_0-aft_likelihood:2.61218	validation_1-aft_likelihood:2.60962
# [56]	validation_0-aft_likelihood:2.61013	validation_1-aft_likelihood:2.61562
# [56]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60923
# [55]	validation_0-aft_likelihood:2.61042	validation_1-aft_likelihood:2.60637
# [55]	validation_0-aft_likelihood:2.61083	validation_1-aft_likelihood:2.61839
# [57]	validation_0-aft_likelihood:2.61013	validation_1-aft_likelihood:2.61562
# [54]	validation_0-aft_likelihood:2.61218	validation_1-aft_likelihood:2.60962
# [57]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60923
# [56]	validation_0-aft_likelihood:2.61042	validation_1-aft_likelihood:2.60637
# [56]	validation_0-aft_likelihood:2.61083	validation_1-aft_likelihood:2.61839
# [58]	validation_0-aft_likelihood:2.61013	validation_1-aft_likelihood:2.61562
# [55]	validation_0-aft_likelihood:2.61218	validation_1-aft_likelihood:2.60962
# [58]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60923
# [57]	validation_0-aft_likelihood:2.61042	validation_1-aft_likelihood:2.60637
# [57]	validation_0-aft_likelihood:2.61083	validation_1-aft_likelihood:2.61839
# [59]	validation_0-aft_likelihood:2.61013	validation_1-aft_likelihood:2.61562
# [56]	validation_0-aft_likelihood:2.61218	validation_1-aft_likelihood:2.60962
# [59]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [58]	validation_0-aft_likelihood:2.61042	validation_1-aft_likelihood:2.60637
# [58]	validation_0-aft_likelihood:2.61083	validation_1-aft_likelihood:2.61839
# [60]	validation_0-aft_likelihood:2.61013	validation_1-aft_likelihood:2.61562
# [57]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60962
# [60]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [59]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60637
# [59]	validation_0-aft_likelihood:2.61083	validation_1-aft_likelihood:2.61839
# [61]	validation_0-aft_likelihood:2.61013	validation_1-aft_likelihood:2.61562
# [58]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60962
# [61]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [60]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60637
# [62]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [60]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61839
# [59]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60962
# [62]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [61]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60637
# [63]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [61]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61839
# [60]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60962
# [63]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [62]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60637
# [64]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [62]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [61]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60962
# [64]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [63]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60637
# [65]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [63]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [65]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [62]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60961
# [64]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60637
# [66]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [64]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [66]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [63]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60961
# [65]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60637
# [67]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [65]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [67]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [64]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60961
# [66]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60637
# [68]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [66]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [68]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [65]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60961
# [67]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60637
# [69]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [69]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [67]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [66]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60961
# [68]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60637
# [70]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [70]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [68]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [67]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60961
# [69]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60636
# [71]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [71]	validation_0-aft_likelihood:2.61240	validation_1-aft_likelihood:2.60922
# [69]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [68]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60961
# [70]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60636
# [72]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [72]	validation_0-aft_likelihood:2.61239	validation_1-aft_likelihood:2.60922
# [70]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [69]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60961
# [71]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60636
# [73]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [73]	validation_0-aft_likelihood:2.61239	validation_1-aft_likelihood:2.60921
# [71]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [70]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60961
# [72]	validation_0-aft_likelihood:2.61041	validation_1-aft_likelihood:2.60636
# [74]	validation_0-aft_likelihood:2.61012	validation_1-aft_likelihood:2.61561
# [CV 3/5] END estimator__colsample_bylevel=0.4370861069626263, estimator__colsample_bynode=0.9556428757689246, estimator__colsample_bytree=0.8659969709057025, estimator__learning_rate=0.15751320499779722, estimator__max_delta_step=6, estimator__max_depth=19, estimator__min_child_weight=0.16975698090861446, estimator__n_estimators=75, estimator__reg_lambda=0.045894586123264684, estimator__subsample=0.6051038616257767;, score=-2.611 total time=  22.1s
# [74]	validation_0-aft_likelihood:2.61239	validation_1-aft_likelihood:2.60921
# [CV 1/5] END estimator__colsample_bylevel=0.4370861069626263, estimator__colsample_bynode=0.9556428757689246, estimator__colsample_bytree=0.8659969709057025, estimator__learning_rate=0.15751320499779722, estimator__max_delta_step=6, estimator__max_depth=19, estimator__min_child_weight=0.16975698090861446, estimator__n_estimators=75, estimator__reg_lambda=0.045894586123264684, estimator__subsample=0.6051038616257767;, score=-2.609 total time=  22.2s
# [72]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [71]	validation_0-aft_likelihood:2.61217	validation_1-aft_likelihood:2.60961
# [73]	validation_0-aft_likelihood:2.61040	validation_1-aft_likelihood:2.60636
# [73]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [72]	validation_0-aft_likelihood:2.61216	validation_1-aft_likelihood:2.60961
# [74]	validation_0-aft_likelihood:2.61040	validation_1-aft_likelihood:2.60636
# [CV 2/5] END estimator__colsample_bylevel=0.4370861069626263, estimator__colsample_bynode=0.9556428757689246, estimator__colsample_bytree=0.8659969709057025, estimator__learning_rate=0.15751320499779722, estimator__max_delta_step=6, estimator__max_depth=19, estimator__min_child_weight=0.16975698090861446, estimator__n_estimators=75, estimator__reg_lambda=0.045894586123264684, estimator__subsample=0.6051038616257767;, score=-2.614 total time=  22.6s
# [74]	validation_0-aft_likelihood:2.61082	validation_1-aft_likelihood:2.61838
# [CV 4/5] END estimator__colsample_bylevel=0.4370861069626263, estimator__colsample_bynode=0.9556428757689246, estimator__colsample_bytree=0.8659969709057025, estimator__learning_rate=0.15751320499779722, estimator__max_delta_step=6, estimator__max_depth=19, estimator__min_child_weight=0.16975698090861446, estimator__n_estimators=75, estimator__reg_lambda=0.045894586123264684, estimator__subsample=0.6051038616257767;, score=-2.606 total time=  22.8s
# [73]	validation_0-aft_likelihood:2.61216	validation_1-aft_likelihood:2.60961
# [74]	validation_0-aft_likelihood:2.61216	validation_1-aft_likelihood:2.60961
# [CV 5/5] END estimator__colsample_bylevel=0.4370861069626263, estimator__colsample_bynode=0.9556428757689246, estimator__colsample_bytree=0.8659969709057025, estimator__learning_rate=0.15751320499779722, estimator__max_delta_step=6, estimator__max_depth=19, estimator__min_child_weight=0.16975698090861446, estimator__n_estimators=75, estimator__reg_lambda=0.045894586123264684, estimator__subsample=0.6051038616257767;, score=-2.608 total time=  23.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/numba/core/serialize.py:29, in _numba_unpickle(address, bytedata, hashed)
#      26 _unpickled_memo = {}
# ---> 29 def _numba_unpickle(address, bytedata, hashed):
#      30     """Used by `numba_unpickle` from _helperlib.c
#      31
#      32     Parameters
#    (...)
#      41         unpickled object
#      42     """
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: _PyEval_EvalFrameDefault returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[12], line 70
#      62 np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
#      64 #np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
#      65 #np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')
#      66
#      67 #np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
#      68 #np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')
# ---> 70 rs.fit(X_train, y_train, estimator__eval_test_size=validation_size)
#      71 best_preds_train = rs.best_estimator_.predict(X_train)
#      72 best_preds_test = rs.best_estimator_.predict(X_test)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/sklearn/model_selection/_search.py:909, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     907 refit_start_time = time.time()
#     908 if y is not None:
# --> 909     self.best_estimator_.fit(X, y, **fit_params)
#     910 else:
#     911     self.best_estimator_.fit(X, **fit_params)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/sklearn/pipeline.py:405, in Pipeline.fit(self, X, y, **fit_params)
#     403     if self._final_estimator != "passthrough":
#     404         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 405         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     407 return self
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgbsurv/base.py:115, in XGBSurv.fit(self, X, y, eval_test_size, **kwargs)
#     112     eval_set = [(X_train, y_train),(X_test, y_test)]
#     113     kwargs['eval_set'] = eval_set
# --> 115     return super(XGBSurv, self).fit(X_train, y_train, **kwargs)
#     116 else:
#     117     X, y = self._sort_X_y(X,y)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py:1025, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1014     obj = None
#    1016 (
#    1017     model,
#    1018     metric,
#    (...)
#    1023     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1024 )
# -> 1025 self._Booster = train(
#    1026     params,
#    1027     train_dmatrix,
#    1028     self.get_num_boosting_rounds(),
#    1029     evals=evals,
#    1030     early_stopping_rounds=early_stopping_rounds,
#    1031     evals_result=evals_result,
#    1032     obj=obj,
#    1033     custom_metric=metric,
#    1034     verbose_eval=verbose,
#    1035     xgb_model=model,
#    1036     callbacks=callbacks,
#    1037 )
#    1039 self._set_evaluation_result(evals_result)
#    1040 return self
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/core.py:1923, in Booster.update(self, dtrain, iteration, fobj)
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
# -> 1923     grad, hess = fobj(pred, dtrain)
#    1924     self.boost(dtrain, grad, hess)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py:107, in _objective_decorator.<locals>.inner(preds, dmatrix)
#     105 """internal function"""
#     106 labels = dmatrix.get_label()
# --> 107 return func(labels, preds)
#
# SystemError: CPUDispatcher(<function aft_objective at 0x7f991249a5f0>) returned a result with an exception set

# %%
# df_final_aft_1_cindex = pd.concat([df for df in agg_metrics_cindex]).round(4)
# df_final_aft_1_cindex.to_csv('metrics/final_gbdt_aft_1_cindex.csv', index=False)
# df_final_aft_1_cindex.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_aft_1_cindex.csv', index=False)  #


# df_final_aft_1_ibs = pd.concat([df for df in agg_metrics_ibs]).round(4)
# df_final_aft_1_ibs.to_csv('metrics/final_gbdt_aft_1_ibs.csv', index=False)
# df_final_aft_1_ibs.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_aft_1_ibs.csv', index=False) 

best_preds_test
# Out:
# array([-1.0434934e-04,  9.2484122e-05, -1.0434934e-04, ...,
#        -9.4871895e-05, -1.0434934e-04, -1.0434934e-04], dtype=float32)

# %% [markdown]
# ## TCGA Train, Test, Evaluation

# %%
param_grid = {
#'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,1000), # corresponds to num_rounds
#'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
'pca__n_components': [8, 16, 32, 64]
}

# %%
cancer_types = ['BLCA',
    'BRCA',
    'HNSC',
    'KIRC',
    'LGG',
    'LIHC',
    'LUAD',
    'LUSC',
    'OV',
    'STAD']
agg_metrics_cindex = []
agg_metrics_ibs = []
agg_best_settings = []


for idx, cancer_type in enumerate(cancer_types):
    model = 'xgbsurv_aft_'
    # get name of current dataset
    data = load_tcga(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", cancer_type=cancer_type, as_frame=True)
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()
    filename = data.filename
    dataset_name = filename.split('_')[0]
    X, y = sort_X_y_pandas(X, y)

    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='aft_objective',
        eval_metric='aft_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score,
        verbose = 0
        )
    
    pipe = Pipeline([('scaler',ct),
                    ('pca', PCA()),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=n_iter, refit=True, random_state=rand_state)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        #print(y_train.shape, type(y_train))
        #print(X_train.shape, type(X_train))
        #print(X_test.shape, type(X_test))
        #print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        #np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        #np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        #np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        #np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        df_best_params = pd.DataFrame(best_params)
        df_best_model = pd.DataFrame(best_model)
        # df_outer_scores = pd.DataFrame(outer_scores)
        df_best_settings = pd.concat([df_best_params,df_best_model])
        df_best_settings.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
        
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]

        agg_best_settings.append(df_best_settings)

df_final_settings = pd.concat([df for df in agg_best_settings])
df_final_settings.to_csv('metrics/final_settings_gbdt_aft_tcga.csv', index=False)
# Out:
# [0]	validation_0-aft_likelihood:3.24891	validation_1-aft_likelihood:3.31404
# [1]	validation_0-aft_likelihood:3.24891	validation_1-aft_likelihood:3.31404
# [2]	validation_0-aft_likelihood:3.24891	validation_1-aft_likelihood:3.31404
# [0]	validation_0-aft_likelihood:3.23300	validation_1-aft_likelihood:3.26245
# [3]	validation_0-aft_likelihood:3.24891	validation_1-aft_likelihood:3.31404
# [1]	validation_0-aft_likelihood:3.23300	validation_1-aft_likelihood:3.26245
# [4]	validation_0-aft_likelihood:3.24891	validation_1-aft_likelihood:3.31404
# [2]	validation_0-aft_likelihood:3.23300	validation_1-aft_likelihood:3.26245
# [5]	validation_0-aft_likelihood:3.24891	validation_1-aft_likelihood:3.31404
# [3]	validation_0-aft_likelihood:3.23300	validation_1-aft_likelihood:3.26245
# [6]	validation_0-aft_likelihood:3.24891	validation_1-aft_likelihood:3.31404
# [0]	validation_0-aft_likelihood:3.24311	validation_1-aft_likelihood:3.30762
# [4]	validation_0-aft_likelihood:3.23300	validation_1-aft_likelihood:3.26245
# [7]	validation_0-aft_likelihood:3.24891	validation_1-aft_likelihood:3.31404
# [1]	validation_0-aft_likelihood:3.24311	validation_1-aft_likelihood:3.30762
# [5]	validation_0-aft_likelihood:3.23300	validation_1-aft_likelihood:3.26245
# [8]	validation_0-aft_likelihood:3.24891	validation_1-aft_likelihood:3.31404
# [2]	validation_0-aft_likelihood:3.24311	validation_1-aft_likelihood:3.30762
# [6]	validation_0-aft_likelihood:3.23300	validation_1-aft_likelihood:3.26245
# [9]	validation_0-aft_likelihood:3.24891	validation_1-aft_likelihood:3.31404
# [3]	validation_0-aft_likelihood:3.24311	validation_1-aft_likelihood:3.30762
# [7]	validation_0-aft_likelihood:3.23300	validation_1-aft_likelihood:3.26245
# [4]	validation_0-aft_likelihood:3.24311	validation_1-aft_likelihood:3.30762
# [8]	validation_0-aft_likelihood:3.23300	validation_1-aft_likelihood:3.26245
# [0]	validation_0-aft_likelihood:3.29353	validation_1-aft_likelihood:3.32973
# [5]	validation_0-aft_likelihood:3.24311	validation_1-aft_likelihood:3.30762
# [9]	validation_0-aft_likelihood:3.23300	validation_1-aft_likelihood:3.26245
# [1]	validation_0-aft_likelihood:3.29353	validation_1-aft_likelihood:3.32973
# [6]	validation_0-aft_likelihood:3.24311	validation_1-aft_likelihood:3.30762
# [2]	validation_0-aft_likelihood:3.29353	validation_1-aft_likelihood:3.32973
# [7]	validation_0-aft_likelihood:3.24311	validation_1-aft_likelihood:3.30762
# [3]	validation_0-aft_likelihood:3.29353	validation_1-aft_likelihood:3.32973
# [8]	validation_0-aft_likelihood:3.24311	validation_1-aft_likelihood:3.30762
# [4]	validation_0-aft_likelihood:3.29353	validation_1-aft_likelihood:3.32973
# [9]	validation_0-aft_likelihood:3.24311	validation_1-aft_likelihood:3.30762
# [5]	validation_0-aft_likelihood:3.29353	validation_1-aft_likelihood:3.32973
# [10]	validation_0-aft_likelihood:3.24311	validation_1-aft_likelihood:3.30762
# [6]	validation_0-aft_likelihood:3.29353	validation_1-aft_likelihood:3.32973
# [7]	validation_0-aft_likelihood:3.29353	validation_1-aft_likelihood:3.32973
# [8]	validation_0-aft_likelihood:3.29353	validation_1-aft_likelihood:3.32973
# [9]	validation_0-aft_likelihood:3.29353	validation_1-aft_likelihood:3.32973
# [0]	validation_0-aft_likelihood:3.28675	validation_1-aft_likelihood:3.31551
# [1]	validation_0-aft_likelihood:3.28675	validation_1-aft_likelihood:3.31551
# [2]	validation_0-aft_likelihood:3.28675	validation_1-aft_likelihood:3.31551
# [3]	validation_0-aft_likelihood:3.28675	validation_1-aft_likelihood:3.31551
# [4]	validation_0-aft_likelihood:3.28675	validation_1-aft_likelihood:3.31551
# [5]	validation_0-aft_likelihood:3.28675	validation_1-aft_likelihood:3.31551
# [6]	validation_0-aft_likelihood:3.28675	validation_1-aft_likelihood:3.31551
# [7]	validation_0-aft_likelihood:3.28675	validation_1-aft_likelihood:3.31551
# [8]	validation_0-aft_likelihood:3.28675	validation_1-aft_likelihood:3.31551
# [9]	validation_0-aft_likelihood:3.28675	validation_1-aft_likelihood:3.31551
# [10]	validation_0-aft_likelihood:3.28675	validation_1-aft_likelihood:3.31551
# [0]	validation_0-aft_likelihood:3.21803	validation_1-aft_likelihood:3.38659
# [1]	validation_0-aft_likelihood:3.21803	validation_1-aft_likelihood:3.38659
# [2]	validation_0-aft_likelihood:3.21803	validation_1-aft_likelihood:3.38659
# [3]	validation_0-aft_likelihood:3.21803	validation_1-aft_likelihood:3.38659
# [4]	validation_0-aft_likelihood:3.21803	validation_1-aft_likelihood:3.38659
# [5]	validation_0-aft_likelihood:3.21803	validation_1-aft_likelihood:3.38659
# [6]	validation_0-aft_likelihood:3.21803	validation_1-aft_likelihood:3.38659
# [7]	validation_0-aft_likelihood:3.21803	validation_1-aft_likelihood:3.38659
# [8]	validation_0-aft_likelihood:3.21803	validation_1-aft_likelihood:3.38659
# [9]	validation_0-aft_likelihood:3.21803	validation_1-aft_likelihood:3.38659
# [10]	validation_0-aft_likelihood:3.21803	validation_1-aft_likelihood:3.38659
# Concordance Index 0.0
# Integrated Brier Score: 0.21242246594965625
# durations 17.0 4343.0
# Concordance Index 0.0
# Integrated Brier Score: 0.22761647970064847
# [0]	validation_0-aft_likelihood:3.24387	validation_1-aft_likelihood:3.27611
# [1]	validation_0-aft_likelihood:3.24387	validation_1-aft_likelihood:3.27611
# [2]	validation_0-aft_likelihood:3.24387	validation_1-aft_likelihood:3.27611
# [3]	validation_0-aft_likelihood:3.24387	validation_1-aft_likelihood:3.27611
# [4]	validation_0-aft_likelihood:3.24387	validation_1-aft_likelihood:3.27611
# [5]	validation_0-aft_likelihood:3.24387	validation_1-aft_likelihood:3.27611
# [6]	validation_0-aft_likelihood:3.24387	validation_1-aft_likelihood:3.27611
# [7]	validation_0-aft_likelihood:3.24387	validation_1-aft_likelihood:3.27611
# [8]	validation_0-aft_likelihood:3.24387	validation_1-aft_likelihood:3.27611
# [9]	validation_0-aft_likelihood:3.24387	validation_1-aft_likelihood:3.27611
# [10]	validation_0-aft_likelihood:3.24387	validation_1-aft_likelihood:3.27611
# [0]	validation_0-aft_likelihood:3.28556	validation_1-aft_likelihood:3.28982
# [1]	validation_0-aft_likelihood:3.28556	validation_1-aft_likelihood:3.28982
# [2]	validation_0-aft_likelihood:3.28556	validation_1-aft_likelihood:3.28982
# [3]	validation_0-aft_likelihood:3.28556	validation_1-aft_likelihood:3.28982
# [4]	validation_0-aft_likelihood:3.28556	validation_1-aft_likelihood:3.28982
# [5]	validation_0-aft_likelihood:3.28556	validation_1-aft_likelihood:3.28982
# [6]	validation_0-aft_likelihood:3.28556	validation_1-aft_likelihood:3.28982
# [7]	validation_0-aft_likelihood:3.28556	validation_1-aft_likelihood:3.28982
# [8]	validation_0-aft_likelihood:3.28556	validation_1-aft_likelihood:3.28982
# [9]	validation_0-aft_likelihood:3.28556	validation_1-aft_likelihood:3.28982
# [0]	validation_0-aft_likelihood:3.23084	validation_1-aft_likelihood:3.26678
# [1]	validation_0-aft_likelihood:3.23084	validation_1-aft_likelihood:3.26678
# [2]	validation_0-aft_likelihood:3.23084	validation_1-aft_likelihood:3.26678
# [3]	validation_0-aft_likelihood:3.23084	validation_1-aft_likelihood:3.26678
# [4]	validation_0-aft_likelihood:3.23084	validation_1-aft_likelihood:3.26678
# [5]	validation_0-aft_likelihood:3.23084	validation_1-aft_likelihood:3.26678
# [6]	validation_0-aft_likelihood:3.23084	validation_1-aft_likelihood:3.26678
# [7]	validation_0-aft_likelihood:3.23084	validation_1-aft_likelihood:3.26678
# [0]	validation_0-aft_likelihood:3.21367	validation_1-aft_likelihood:3.24191
# [8]	validation_0-aft_likelihood:3.23084	validation_1-aft_likelihood:3.26678
# [1]	validation_0-aft_likelihood:3.21367	validation_1-aft_likelihood:3.24191
# [9]	validation_0-aft_likelihood:3.23084	validation_1-aft_likelihood:3.26678
# [2]	validation_0-aft_likelihood:3.21367	validation_1-aft_likelihood:3.24191
# [10]	validation_0-aft_likelihood:3.23084	validation_1-aft_likelihood:3.26678
# [3]	validation_0-aft_likelihood:3.21367	validation_1-aft_likelihood:3.24191
# [0]	validation_0-aft_likelihood:3.27963	validation_1-aft_likelihood:3.27850
# [4]	validation_0-aft_likelihood:3.21367	validation_1-aft_likelihood:3.24191
# [1]	validation_0-aft_likelihood:3.27963	validation_1-aft_likelihood:3.27850
# [5]	validation_0-aft_likelihood:3.21367	validation_1-aft_likelihood:3.24191
# [6]	validation_0-aft_likelihood:3.21367	validation_1-aft_likelihood:3.24191
# [2]	validation_0-aft_likelihood:3.27963	validation_1-aft_likelihood:3.27850
# [7]	validation_0-aft_likelihood:3.21367	validation_1-aft_likelihood:3.24191
# [3]	validation_0-aft_likelihood:3.27963	validation_1-aft_likelihood:3.27850
# [4]	validation_0-aft_likelihood:3.27963	validation_1-aft_likelihood:3.27850
# [8]	validation_0-aft_likelihood:3.21367	validation_1-aft_likelihood:3.24191
# [5]	validation_0-aft_likelihood:3.27963	validation_1-aft_likelihood:3.27850
# [9]	validation_0-aft_likelihood:3.21367	validation_1-aft_likelihood:3.24191
# [6]	validation_0-aft_likelihood:3.27963	validation_1-aft_likelihood:3.27850
# [7]	validation_0-aft_likelihood:3.27963	validation_1-aft_likelihood:3.27850
# [8]	validation_0-aft_likelihood:3.27963	validation_1-aft_likelihood:3.27850
# [9]	validation_0-aft_likelihood:3.27963	validation_1-aft_likelihood:3.27850
# [10]	validation_0-aft_likelihood:3.27963	validation_1-aft_likelihood:3.27850
# [0]	validation_0-aft_likelihood:3.19841	validation_1-aft_likelihood:3.43786
# [1]	validation_0-aft_likelihood:3.19841	validation_1-aft_likelihood:3.43786
# [2]	validation_0-aft_likelihood:3.19841	validation_1-aft_likelihood:3.43786
# [3]	validation_0-aft_likelihood:3.19841	validation_1-aft_likelihood:3.43786
# [4]	validation_0-aft_likelihood:3.19841	validation_1-aft_likelihood:3.43786
# [5]	validation_0-aft_likelihood:3.19841	validation_1-aft_likelihood:3.43786
# [6]	validation_0-aft_likelihood:3.19841	validation_1-aft_likelihood:3.43786
# [7]	validation_0-aft_likelihood:3.19841	validation_1-aft_likelihood:3.43786
# [8]	validation_0-aft_likelihood:3.19841	validation_1-aft_likelihood:3.43786
# [9]	validation_0-aft_likelihood:3.19841	validation_1-aft_likelihood:3.43786
# Concordance Index 0.0
# Integrated Brier Score: 0.2110265603250723
# durations 15.0 3817.0
# Concordance Index 0.0
# Integrated Brier Score: 0.22540540455598213
# [0]	validation_0-aft_likelihood:3.24156	validation_1-aft_likelihood:3.28021
# [0]	validation_0-aft_likelihood:3.24942	validation_1-aft_likelihood:3.28601
# [1]	validation_0-aft_likelihood:3.24156	validation_1-aft_likelihood:3.28021
# [1]	validation_0-aft_likelihood:3.24942	validation_1-aft_likelihood:3.28601
# [2]	validation_0-aft_likelihood:3.24156	validation_1-aft_likelihood:3.28021
# [2]	validation_0-aft_likelihood:3.24942	validation_1-aft_likelihood:3.28601
# [3]	validation_0-aft_likelihood:3.24156	validation_1-aft_likelihood:3.28021
# [3]	validation_0-aft_likelihood:3.24942	validation_1-aft_likelihood:3.28601
# [4]	validation_0-aft_likelihood:3.24156	validation_1-aft_likelihood:3.28021
# [5]	validation_0-aft_likelihood:3.24156	validation_1-aft_likelihood:3.28021
# [4]	validation_0-aft_likelihood:3.24942	validation_1-aft_likelihood:3.28601
# [6]	validation_0-aft_likelihood:3.24156	validation_1-aft_likelihood:3.28021
# [5]	validation_0-aft_likelihood:3.24942	validation_1-aft_likelihood:3.28601
# [7]	validation_0-aft_likelihood:3.24156	validation_1-aft_likelihood:3.28021
# [6]	validation_0-aft_likelihood:3.24942	validation_1-aft_likelihood:3.28601
# [0]	validation_0-aft_likelihood:3.22232	validation_1-aft_likelihood:3.25530
# [8]	validation_0-aft_likelihood:3.24156	validation_1-aft_likelihood:3.28021
# [1]	validation_0-aft_likelihood:3.22232	validation_1-aft_likelihood:3.25530
# [7]	validation_0-aft_likelihood:3.24942	validation_1-aft_likelihood:3.28601
# [2]	validation_0-aft_likelihood:3.22232	validation_1-aft_likelihood:3.25530
# [9]	validation_0-aft_likelihood:3.24156	validation_1-aft_likelihood:3.28021
# [8]	validation_0-aft_likelihood:3.24942	validation_1-aft_likelihood:3.28601
# [9]	validation_0-aft_likelihood:3.24942	validation_1-aft_likelihood:3.28601
# [3]	validation_0-aft_likelihood:3.22232	validation_1-aft_likelihood:3.25530
# [4]	validation_0-aft_likelihood:3.22232	validation_1-aft_likelihood:3.25530
# [5]	validation_0-aft_likelihood:3.22232	validation_1-aft_likelihood:3.25530
# [6]	validation_0-aft_likelihood:3.22232	validation_1-aft_likelihood:3.25530
# [7]	validation_0-aft_likelihood:3.22232	validation_1-aft_likelihood:3.25530
# [8]	validation_0-aft_likelihood:3.22232	validation_1-aft_likelihood:3.25530
# [9]	validation_0-aft_likelihood:3.22232	validation_1-aft_likelihood:3.25530
# [0]	validation_0-aft_likelihood:3.28475	validation_1-aft_likelihood:3.28573
# [1]	validation_0-aft_likelihood:3.28475	validation_1-aft_likelihood:3.28573
# [0]	validation_0-aft_likelihood:3.29045	validation_1-aft_likelihood:3.29482
# [2]	validation_0-aft_likelihood:3.28475	validation_1-aft_likelihood:3.28573
# [1]	validation_0-aft_likelihood:3.29045	validation_1-aft_likelihood:3.29482
# [3]	validation_0-aft_likelihood:3.28475	validation_1-aft_likelihood:3.28573
# [2]	validation_0-aft_likelihood:3.29045	validation_1-aft_likelihood:3.29482
# [4]	validation_0-aft_likelihood:3.28475	validation_1-aft_likelihood:3.28573
# [3]	validation_0-aft_likelihood:3.29045	validation_1-aft_likelihood:3.29482
# [5]	validation_0-aft_likelihood:3.28475	validation_1-aft_likelihood:3.28573
# [4]	validation_0-aft_likelihood:3.29045	validation_1-aft_likelihood:3.29482
# [6]	validation_0-aft_likelihood:3.28475	validation_1-aft_likelihood:3.28573
# [5]	validation_0-aft_likelihood:3.29045	validation_1-aft_likelihood:3.29482
# [7]	validation_0-aft_likelihood:3.28475	validation_1-aft_likelihood:3.28573
# [6]	validation_0-aft_likelihood:3.29045	validation_1-aft_likelihood:3.29482
# [8]	validation_0-aft_likelihood:3.28475	validation_1-aft_likelihood:3.28573
# [7]	validation_0-aft_likelihood:3.29045	validation_1-aft_likelihood:3.29482
# [9]	validation_0-aft_likelihood:3.28475	validation_1-aft_likelihood:3.28573
# [8]	validation_0-aft_likelihood:3.29045	validation_1-aft_likelihood:3.29482
# [10]	validation_0-aft_likelihood:3.28475	validation_1-aft_likelihood:3.28573
# [9]	validation_0-aft_likelihood:3.29045	validation_1-aft_likelihood:3.29482
# [0]	validation_0-aft_likelihood:3.20952	validation_1-aft_likelihood:3.40132
# [1]	validation_0-aft_likelihood:3.20952	validation_1-aft_likelihood:3.40132
# [2]	validation_0-aft_likelihood:3.20952	validation_1-aft_likelihood:3.40132
# [3]	validation_0-aft_likelihood:3.20952	validation_1-aft_likelihood:3.40132
# [4]	validation_0-aft_likelihood:3.20952	validation_1-aft_likelihood:3.40132
# [5]	validation_0-aft_likelihood:3.20952	validation_1-aft_likelihood:3.40132
# [6]	validation_0-aft_likelihood:3.20952	validation_1-aft_likelihood:3.40132
# [7]	validation_0-aft_likelihood:3.20952	validation_1-aft_likelihood:3.40132
# [8]	validation_0-aft_likelihood:3.20952	validation_1-aft_likelihood:3.40132
# [9]	validation_0-aft_likelihood:3.20952	validation_1-aft_likelihood:3.40132
# [10]	validation_0-aft_likelihood:3.20952	validation_1-aft_likelihood:3.40132
# Concordance Index 0.0
# Integrated Brier Score: 0.21139250910004184
# durations 59.0 5050.0
# Concordance Index 0.0
# Integrated Brier Score: 0.22364030430043763
# [0]	validation_0-aft_likelihood:3.23310	validation_1-aft_likelihood:3.29139
# [1]	validation_0-aft_likelihood:3.23310	validation_1-aft_likelihood:3.29139
# [2]	validation_0-aft_likelihood:3.23310	validation_1-aft_likelihood:3.29139
# [3]	validation_0-aft_likelihood:3.23310	validation_1-aft_likelihood:3.29139
# [4]	validation_0-aft_likelihood:3.23310	validation_1-aft_likelihood:3.29139
# [0]	validation_0-aft_likelihood:3.25012	validation_1-aft_likelihood:3.28827
# [5]	validation_0-aft_likelihood:3.23310	validation_1-aft_likelihood:3.29139
# [1]	validation_0-aft_likelihood:3.25012	validation_1-aft_likelihood:3.28827
# [6]	validation_0-aft_likelihood:3.23310	validation_1-aft_likelihood:3.29139
# [2]	validation_0-aft_likelihood:3.25012	validation_1-aft_likelihood:3.28827
# [7]	validation_0-aft_likelihood:3.23310	validation_1-aft_likelihood:3.29139
# [3]	validation_0-aft_likelihood:3.25012	validation_1-aft_likelihood:3.28827
# [8]	validation_0-aft_likelihood:3.23310	validation_1-aft_likelihood:3.29139
# [4]	validation_0-aft_likelihood:3.25012	validation_1-aft_likelihood:3.28827
# [9]	validation_0-aft_likelihood:3.23310	validation_1-aft_likelihood:3.29139
# [5]	validation_0-aft_likelihood:3.25012	validation_1-aft_likelihood:3.28827
# [6]	validation_0-aft_likelihood:3.25012	validation_1-aft_likelihood:3.28827
# [7]	validation_0-aft_likelihood:3.25012	validation_1-aft_likelihood:3.28827
# [8]	validation_0-aft_likelihood:3.25012	validation_1-aft_likelihood:3.28827
# [9]	validation_0-aft_likelihood:3.25012	validation_1-aft_likelihood:3.28827
# [0]	validation_0-aft_likelihood:3.20323	validation_1-aft_likelihood:3.25345
# [1]	validation_0-aft_likelihood:3.20323	validation_1-aft_likelihood:3.25345
# [0]	validation_0-aft_likelihood:3.26849	validation_1-aft_likelihood:3.30330
# [2]	validation_0-aft_likelihood:3.20323	validation_1-aft_likelihood:3.25345
# [1]	validation_0-aft_likelihood:3.26849	validation_1-aft_likelihood:3.30330
# [0]	validation_0-aft_likelihood:3.27671	validation_1-aft_likelihood:3.31862
# [3]	validation_0-aft_likelihood:3.20323	validation_1-aft_likelihood:3.25345
# [2]	validation_0-aft_likelihood:3.26849	validation_1-aft_likelihood:3.30330
# [1]	validation_0-aft_likelihood:3.27671	validation_1-aft_likelihood:3.31862
# [4]	validation_0-aft_likelihood:3.20323	validation_1-aft_likelihood:3.25345
# [3]	validation_0-aft_likelihood:3.26849	validation_1-aft_likelihood:3.30330
# [2]	validation_0-aft_likelihood:3.27671	validation_1-aft_likelihood:3.31862
# [5]	validation_0-aft_likelihood:3.20323	validation_1-aft_likelihood:3.25345
# [3]	validation_0-aft_likelihood:3.27671	validation_1-aft_likelihood:3.31862
# [4]	validation_0-aft_likelihood:3.26849	validation_1-aft_likelihood:3.30330
# [6]	validation_0-aft_likelihood:3.20323	validation_1-aft_likelihood:3.25345
# [4]	validation_0-aft_likelihood:3.27671	validation_1-aft_likelihood:3.31862
# [5]	validation_0-aft_likelihood:3.26849	validation_1-aft_likelihood:3.30330
# [7]	validation_0-aft_likelihood:3.20323	validation_1-aft_likelihood:3.25345
# [5]	validation_0-aft_likelihood:3.27671	validation_1-aft_likelihood:3.31862
# [6]	validation_0-aft_likelihood:3.26849	validation_1-aft_likelihood:3.30330
# [8]	validation_0-aft_likelihood:3.20323	validation_1-aft_likelihood:3.25345
# [6]	validation_0-aft_likelihood:3.27671	validation_1-aft_likelihood:3.31862
# [7]	validation_0-aft_likelihood:3.26849	validation_1-aft_likelihood:3.30330
# [9]	validation_0-aft_likelihood:3.20323	validation_1-aft_likelihood:3.25345
# [7]	validation_0-aft_likelihood:3.27671	validation_1-aft_likelihood:3.31862
# [8]	validation_0-aft_likelihood:3.26849	validation_1-aft_likelihood:3.30330
# [10]	validation_0-aft_likelihood:3.20323	validation_1-aft_likelihood:3.25345
# [8]	validation_0-aft_likelihood:3.27671	validation_1-aft_likelihood:3.31862
# [9]	validation_0-aft_likelihood:3.26849	validation_1-aft_likelihood:3.30330
# [9]	validation_0-aft_likelihood:3.27671	validation_1-aft_likelihood:3.31862
# [10]	validation_0-aft_likelihood:3.26849	validation_1-aft_likelihood:3.30330
# [10]	validation_0-aft_likelihood:3.27671	validation_1-aft_likelihood:3.31862
# [0]	validation_0-aft_likelihood:3.20148	validation_1-aft_likelihood:3.37705
# [1]	validation_0-aft_likelihood:3.20148	validation_1-aft_likelihood:3.37705
# [2]	validation_0-aft_likelihood:3.20148	validation_1-aft_likelihood:3.37705
# [3]	validation_0-aft_likelihood:3.20148	validation_1-aft_likelihood:3.37705
# [4]	validation_0-aft_likelihood:3.20148	validation_1-aft_likelihood:3.37705
# [5]	validation_0-aft_likelihood:3.20148	validation_1-aft_likelihood:3.37705
# [6]	validation_0-aft_likelihood:3.20148	validation_1-aft_likelihood:3.37705
# [7]	validation_0-aft_likelihood:3.20148	validation_1-aft_likelihood:3.37705
# [8]	validation_0-aft_likelihood:3.20148	validation_1-aft_likelihood:3.37705
# [9]	validation_0-aft_likelihood:3.20148	validation_1-aft_likelihood:3.37705
# [10]	validation_0-aft_likelihood:3.20148	validation_1-aft_likelihood:3.37705
# Concordance Index 0.0
# Integrated Brier Score: 0.2147647509312423
# durations 55.0 5041.0
# Concordance Index 0.0
# Integrated Brier Score: 0.2229162227199334
# [0]	validation_0-aft_likelihood:3.17112	validation_1-aft_likelihood:3.22085
# [1]	validation_0-aft_likelihood:3.17112	validation_1-aft_likelihood:3.22085
# [2]	validation_0-aft_likelihood:3.17112	validation_1-aft_likelihood:3.22085
# [3]	validation_0-aft_likelihood:3.17112	validation_1-aft_likelihood:3.22085
# [4]	validation_0-aft_likelihood:3.17112	validation_1-aft_likelihood:3.22085
# [5]	validation_0-aft_likelihood:3.17112	validation_1-aft_likelihood:3.22085
# [6]	validation_0-aft_likelihood:3.17112	validation_1-aft_likelihood:3.22085
# [7]	validation_0-aft_likelihood:3.17112	validation_1-aft_likelihood:3.22085
# [8]	validation_0-aft_likelihood:3.17112	validation_1-aft_likelihood:3.22085
# [9]	validation_0-aft_likelihood:3.17112	validation_1-aft_likelihood:3.22085
# [0]	validation_0-aft_likelihood:3.20450	validation_1-aft_likelihood:3.23474
# [1]	validation_0-aft_likelihood:3.20450	validation_1-aft_likelihood:3.23474
# [2]	validation_0-aft_likelihood:3.20450	validation_1-aft_likelihood:3.23474
# [3]	validation_0-aft_likelihood:3.20450	validation_1-aft_likelihood:3.23474
# [4]	validation_0-aft_likelihood:3.20450	validation_1-aft_likelihood:3.23474
# [5]	validation_0-aft_likelihood:3.20450	validation_1-aft_likelihood:3.23474
# [6]	validation_0-aft_likelihood:3.20450	validation_1-aft_likelihood:3.23474
# [7]	validation_0-aft_likelihood:3.20450	validation_1-aft_likelihood:3.23474
# [8]	validation_0-aft_likelihood:3.20450	validation_1-aft_likelihood:3.23474
# [9]	validation_0-aft_likelihood:3.20450	validation_1-aft_likelihood:3.23474
# [0]	validation_0-aft_likelihood:3.21306	validation_1-aft_likelihood:3.24394
# [0]	validation_0-aft_likelihood:3.14511	validation_1-aft_likelihood:3.19122
# [1]	validation_0-aft_likelihood:3.14511	validation_1-aft_likelihood:3.19122
# [1]	validation_0-aft_likelihood:3.21306	validation_1-aft_likelihood:3.24394
# [2]	validation_0-aft_likelihood:3.14511	validation_1-aft_likelihood:3.19122
# [2]	validation_0-aft_likelihood:3.21306	validation_1-aft_likelihood:3.24394
# [3]	validation_0-aft_likelihood:3.14511	validation_1-aft_likelihood:3.19122
# [3]	validation_0-aft_likelihood:3.21306	validation_1-aft_likelihood:3.24394
# [4]	validation_0-aft_likelihood:3.14511	validation_1-aft_likelihood:3.19122
# [4]	validation_0-aft_likelihood:3.21306	validation_1-aft_likelihood:3.24394
# [5]	validation_0-aft_likelihood:3.14511	validation_1-aft_likelihood:3.19122
# [5]	validation_0-aft_likelihood:3.21306	validation_1-aft_likelihood:3.24394
# [6]	validation_0-aft_likelihood:3.14511	validation_1-aft_likelihood:3.19122
# [6]	validation_0-aft_likelihood:3.21306	validation_1-aft_likelihood:3.24394
# [7]	validation_0-aft_likelihood:3.14511	validation_1-aft_likelihood:3.19122
# [7]	validation_0-aft_likelihood:3.21306	validation_1-aft_likelihood:3.24394
# [8]	validation_0-aft_likelihood:3.14511	validation_1-aft_likelihood:3.19122
# [8]	validation_0-aft_likelihood:3.21306	validation_1-aft_likelihood:3.24394
# [9]	validation_0-aft_likelihood:3.14511	validation_1-aft_likelihood:3.19122
# [9]	validation_0-aft_likelihood:3.21306	validation_1-aft_likelihood:3.24394
# [0]	validation_0-aft_likelihood:3.17882	validation_1-aft_likelihood:3.22095
# [1]	validation_0-aft_likelihood:3.17882	validation_1-aft_likelihood:3.22095
# [2]	validation_0-aft_likelihood:3.17882	validation_1-aft_likelihood:3.22095
# [3]	validation_0-aft_likelihood:3.17882	validation_1-aft_likelihood:3.22095
# [4]	validation_0-aft_likelihood:3.17882	validation_1-aft_likelihood:3.22095
# [5]	validation_0-aft_likelihood:3.17882	validation_1-aft_likelihood:3.22095
# [6]	validation_0-aft_likelihood:3.17882	validation_1-aft_likelihood:3.22095
# [7]	validation_0-aft_likelihood:3.17882	validation_1-aft_likelihood:3.22095
# [8]	validation_0-aft_likelihood:3.17882	validation_1-aft_likelihood:3.22095
# [9]	validation_0-aft_likelihood:3.17882	validation_1-aft_likelihood:3.22095
# [0]	validation_0-aft_likelihood:3.13961	validation_1-aft_likelihood:3.32405
# [1]	validation_0-aft_likelihood:3.13961	validation_1-aft_likelihood:3.32405
# [2]	validation_0-aft_likelihood:3.13961	validation_1-aft_likelihood:3.32405
# [3]	validation_0-aft_likelihood:3.13961	validation_1-aft_likelihood:3.32405
# [4]	validation_0-aft_likelihood:3.13961	validation_1-aft_likelihood:3.32405
# [5]	validation_0-aft_likelihood:3.13961	validation_1-aft_likelihood:3.32405
# [6]	validation_0-aft_likelihood:3.13961	validation_1-aft_likelihood:3.32405
# [7]	validation_0-aft_likelihood:3.13961	validation_1-aft_likelihood:3.32405
# [8]	validation_0-aft_likelihood:3.13961	validation_1-aft_likelihood:3.32405
# [9]	validation_0-aft_likelihood:3.13961	validation_1-aft_likelihood:3.32405
# Concordance Index 0.0
# Integrated Brier Score: 0.2209335809321062
# durations 13.0 3432.0
# Concordance Index 0.0
# Integrated Brier Score: 0.2114720246327344
# [0]	validation_0-aft_likelihood:1.26396	validation_1-aft_likelihood:1.24268
# [1]	validation_0-aft_likelihood:1.26396	validation_1-aft_likelihood:1.24268
# [2]	validation_0-aft_likelihood:1.26396	validation_1-aft_likelihood:1.24268
# [3]	validation_0-aft_likelihood:1.26396	validation_1-aft_likelihood:1.24268
# [4]	validation_0-aft_likelihood:1.26396	validation_1-aft_likelihood:1.24268
# [5]	validation_0-aft_likelihood:1.26396	validation_1-aft_likelihood:1.24268
# [6]	validation_0-aft_likelihood:1.26396	validation_1-aft_likelihood:1.24268
# [7]	validation_0-aft_likelihood:1.26396	validation_1-aft_likelihood:1.24268
# [8]	validation_0-aft_likelihood:1.26396	validation_1-aft_likelihood:1.24268
# [9]	validation_0-aft_likelihood:1.26396	validation_1-aft_likelihood:1.24268
# [0]	validation_0-aft_likelihood:1.26524	validation_1-aft_likelihood:1.24596
# [1]	validation_0-aft_likelihood:1.26524	validation_1-aft_likelihood:1.24596
# [2]	validation_0-aft_likelihood:1.26524	validation_1-aft_likelihood:1.24596
# [3]	validation_0-aft_likelihood:1.26524	validation_1-aft_likelihood:1.24596
# [4]	validation_0-aft_likelihood:1.26524	validation_1-aft_likelihood:1.24596
# [5]	validation_0-aft_likelihood:1.26524	validation_1-aft_likelihood:1.24596
# [6]	validation_0-aft_likelihood:1.26524	validation_1-aft_likelihood:1.24596
# [7]	validation_0-aft_likelihood:1.26524	validation_1-aft_likelihood:1.24596
# [8]	validation_0-aft_likelihood:1.26524	validation_1-aft_likelihood:1.24596
# [9]	validation_0-aft_likelihood:1.26524	validation_1-aft_likelihood:1.24596
# [10]	validation_0-aft_likelihood:1.26524	validation_1-aft_likelihood:1.24596
# [0]	validation_0-aft_likelihood:1.26276	validation_1-aft_likelihood:1.23891
# [1]	validation_0-aft_likelihood:1.26276	validation_1-aft_likelihood:1.23891
# [2]	validation_0-aft_likelihood:1.26276	validation_1-aft_likelihood:1.23891
# [3]	validation_0-aft_likelihood:1.26276	validation_1-aft_likelihood:1.23891
# [4]	validation_0-aft_likelihood:1.26276	validation_1-aft_likelihood:1.23891
# [5]	validation_0-aft_likelihood:1.26276	validation_1-aft_likelihood:1.23891
# [0]	validation_0-aft_likelihood:1.26289	validation_1-aft_likelihood:1.24000
# [0]	validation_0-aft_likelihood:1.26555	validation_1-aft_likelihood:1.24016
# [6]	validation_0-aft_likelihood:1.26276	validation_1-aft_likelihood:1.23891
# [1]	validation_0-aft_likelihood:1.26289	validation_1-aft_likelihood:1.24000
# [1]	validation_0-aft_likelihood:1.26555	validation_1-aft_likelihood:1.24016
# [7]	validation_0-aft_likelihood:1.26276	validation_1-aft_likelihood:1.23891
# [2]	validation_0-aft_likelihood:1.26289	validation_1-aft_likelihood:1.24000
# [2]	validation_0-aft_likelihood:1.26555	validation_1-aft_likelihood:1.24016
# [8]	validation_0-aft_likelihood:1.26276	validation_1-aft_likelihood:1.23891
# [3]	validation_0-aft_likelihood:1.26289	validation_1-aft_likelihood:1.24000
# [3]	validation_0-aft_likelihood:1.26555	validation_1-aft_likelihood:1.24016
# [9]	validation_0-aft_likelihood:1.26276	validation_1-aft_likelihood:1.23891
# [4]	validation_0-aft_likelihood:1.26289	validation_1-aft_likelihood:1.24000
# [4]	validation_0-aft_likelihood:1.26555	validation_1-aft_likelihood:1.24016
# [10]	validation_0-aft_likelihood:1.26276	validation_1-aft_likelihood:1.23891
# [5]	validation_0-aft_likelihood:1.26289	validation_1-aft_likelihood:1.24000
# [5]	validation_0-aft_likelihood:1.26555	validation_1-aft_likelihood:1.24016
# [6]	validation_0-aft_likelihood:1.26289	validation_1-aft_likelihood:1.24000
# [6]	validation_0-aft_likelihood:1.26555	validation_1-aft_likelihood:1.24016
# [7]	validation_0-aft_likelihood:1.26289	validation_1-aft_likelihood:1.24000
# [7]	validation_0-aft_likelihood:1.26555	validation_1-aft_likelihood:1.24016
# [8]	validation_0-aft_likelihood:1.26289	validation_1-aft_likelihood:1.24000
# [8]	validation_0-aft_likelihood:1.26555	validation_1-aft_likelihood:1.24016
# [9]	validation_0-aft_likelihood:1.26289	validation_1-aft_likelihood:1.24000
# [9]	validation_0-aft_likelihood:1.26555	validation_1-aft_likelihood:1.24016
# [10]	validation_0-aft_likelihood:1.26289	validation_1-aft_likelihood:1.24000
# [0]	validation_0-aft_likelihood:1.26013	validation_1-aft_likelihood:1.25748
# [1]	validation_0-aft_likelihood:1.26013	validation_1-aft_likelihood:1.25748
# [2]	validation_0-aft_likelihood:1.26013	validation_1-aft_likelihood:1.25748
# [3]	validation_0-aft_likelihood:1.26013	validation_1-aft_likelihood:1.25748
# [4]	validation_0-aft_likelihood:1.26013	validation_1-aft_likelihood:1.25748
# [5]	validation_0-aft_likelihood:1.26013	validation_1-aft_likelihood:1.25748
# [6]	validation_0-aft_likelihood:1.26013	validation_1-aft_likelihood:1.25748
# [7]	validation_0-aft_likelihood:1.26013	validation_1-aft_likelihood:1.25748
# [8]	validation_0-aft_likelihood:1.26013	validation_1-aft_likelihood:1.25748
# [9]	validation_0-aft_likelihood:1.26013	validation_1-aft_likelihood:1.25748
# Concordance Index 0.0
# Integrated Brier Score: 0.18942192491231727
# durations 5.0 8605.0
# Concordance Index 0.0
# Integrated Brier Score: 0.20785378208409078
# [0]	validation_0-aft_likelihood:1.27633	validation_1-aft_likelihood:1.24230
# [1]	validation_0-aft_likelihood:1.27633	validation_1-aft_likelihood:1.24230
# [2]	validation_0-aft_likelihood:1.27633	validation_1-aft_likelihood:1.24230
# [3]	validation_0-aft_likelihood:1.27633	validation_1-aft_likelihood:1.24230
# [4]	validation_0-aft_likelihood:1.27633	validation_1-aft_likelihood:1.24230
# [5]	validation_0-aft_likelihood:1.27633	validation_1-aft_likelihood:1.24230
# [6]	validation_0-aft_likelihood:1.27633	validation_1-aft_likelihood:1.24230
# [7]	validation_0-aft_likelihood:1.27633	validation_1-aft_likelihood:1.24230
# [8]	validation_0-aft_likelihood:1.27633	validation_1-aft_likelihood:1.24230
# [9]	validation_0-aft_likelihood:1.27633	validation_1-aft_likelihood:1.24230
# [0]	validation_0-aft_likelihood:1.27702	validation_1-aft_likelihood:1.24425
# [1]	validation_0-aft_likelihood:1.27702	validation_1-aft_likelihood:1.24425
# [2]	validation_0-aft_likelihood:1.27702	validation_1-aft_likelihood:1.24425
# [3]	validation_0-aft_likelihood:1.27702	validation_1-aft_likelihood:1.24425
# [0]	validation_0-aft_likelihood:1.27719	validation_1-aft_likelihood:1.24539
# [4]	validation_0-aft_likelihood:1.27702	validation_1-aft_likelihood:1.24425
# [1]	validation_0-aft_likelihood:1.27719	validation_1-aft_likelihood:1.24539
# [5]	validation_0-aft_likelihood:1.27702	validation_1-aft_likelihood:1.24425
# [2]	validation_0-aft_likelihood:1.27719	validation_1-aft_likelihood:1.24539
# [0]	validation_0-aft_likelihood:1.27605	validation_1-aft_likelihood:1.24357
# [6]	validation_0-aft_likelihood:1.27702	validation_1-aft_likelihood:1.24425
# [3]	validation_0-aft_likelihood:1.27719	validation_1-aft_likelihood:1.24539
# [1]	validation_0-aft_likelihood:1.27605	validation_1-aft_likelihood:1.24357
# [7]	validation_0-aft_likelihood:1.27702	validation_1-aft_likelihood:1.24425
# [0]	validation_0-aft_likelihood:1.26657	validation_1-aft_likelihood:1.24485
# [2]	validation_0-aft_likelihood:1.27605	validation_1-aft_likelihood:1.24357
# [8]	validation_0-aft_likelihood:1.27702	validation_1-aft_likelihood:1.24425
# [4]	validation_0-aft_likelihood:1.27719	validation_1-aft_likelihood:1.24539
# [3]	validation_0-aft_likelihood:1.27605	validation_1-aft_likelihood:1.24357
# [9]	validation_0-aft_likelihood:1.27702	validation_1-aft_likelihood:1.24425
# [1]	validation_0-aft_likelihood:1.26657	validation_1-aft_likelihood:1.24485
# [5]	validation_0-aft_likelihood:1.27719	validation_1-aft_likelihood:1.24539
# [2]	validation_0-aft_likelihood:1.26657	validation_1-aft_likelihood:1.24485
# [4]	validation_0-aft_likelihood:1.27605	validation_1-aft_likelihood:1.24357
# [6]	validation_0-aft_likelihood:1.27719	validation_1-aft_likelihood:1.24539
# [3]	validation_0-aft_likelihood:1.26657	validation_1-aft_likelihood:1.24485
# [7]	validation_0-aft_likelihood:1.27719	validation_1-aft_likelihood:1.24539
# [5]	validation_0-aft_likelihood:1.27605	validation_1-aft_likelihood:1.24357
# [4]	validation_0-aft_likelihood:1.26657	validation_1-aft_likelihood:1.24485
# [5]	validation_0-aft_likelihood:1.26657	validation_1-aft_likelihood:1.24485
# [6]	validation_0-aft_likelihood:1.27605	validation_1-aft_likelihood:1.24357
# [6]	validation_0-aft_likelihood:1.26657	validation_1-aft_likelihood:1.24485
# [8]	validation_0-aft_likelihood:1.27719	validation_1-aft_likelihood:1.24539
# [7]	validation_0-aft_likelihood:1.27605	validation_1-aft_likelihood:1.24357
# [7]	validation_0-aft_likelihood:1.26657	validation_1-aft_likelihood:1.24485
# [9]	validation_0-aft_likelihood:1.27719	validation_1-aft_likelihood:1.24539
# [8]	validation_0-aft_likelihood:1.27605	validation_1-aft_likelihood:1.24357
# [8]	validation_0-aft_likelihood:1.26657	validation_1-aft_likelihood:1.24485
# [10]	validation_0-aft_likelihood:1.27719	validation_1-aft_likelihood:1.24539
# [9]	validation_0-aft_likelihood:1.27605	validation_1-aft_likelihood:1.24357
# [9]	validation_0-aft_likelihood:1.26657	validation_1-aft_likelihood:1.24485
# [10]	validation_0-aft_likelihood:1.27605	validation_1-aft_likelihood:1.24357
# [10]	validation_0-aft_likelihood:1.26657	validation_1-aft_likelihood:1.24485
# [0]	validation_0-aft_likelihood:1.27190	validation_1-aft_likelihood:1.25740
# [1]	validation_0-aft_likelihood:1.27190	validation_1-aft_likelihood:1.25740
# [2]	validation_0-aft_likelihood:1.27190	validation_1-aft_likelihood:1.25740
# [3]	validation_0-aft_likelihood:1.27190	validation_1-aft_likelihood:1.25740
# [4]	validation_0-aft_likelihood:1.27190	validation_1-aft_likelihood:1.25740
# [5]	validation_0-aft_likelihood:1.27190	validation_1-aft_likelihood:1.25740
# [6]	validation_0-aft_likelihood:1.27190	validation_1-aft_likelihood:1.25740
# [7]	validation_0-aft_likelihood:1.27190	validation_1-aft_likelihood:1.25740
# [8]	validation_0-aft_likelihood:1.27190	validation_1-aft_likelihood:1.25740
# [9]	validation_0-aft_likelihood:1.27190	validation_1-aft_likelihood:1.25740
# [10]	validation_0-aft_likelihood:1.27190	validation_1-aft_likelihood:1.25740
# Concordance Index 0.0
# Integrated Brier Score: 0.19486194945694102
# durations 5.0 8008.0
# Concordance Index 0.0
# Integrated Brier Score: 0.19692513570352557
# [0]	validation_0-aft_likelihood:1.27542	validation_1-aft_likelihood:1.24480
# [1]	validation_0-aft_likelihood:1.27542	validation_1-aft_likelihood:1.24480
# [2]	validation_0-aft_likelihood:1.27542	validation_1-aft_likelihood:1.24480
# [3]	validation_0-aft_likelihood:1.27542	validation_1-aft_likelihood:1.24480
# [4]	validation_0-aft_likelihood:1.27542	validation_1-aft_likelihood:1.24480
# [5]	validation_0-aft_likelihood:1.27542	validation_1-aft_likelihood:1.24480
# [6]	validation_0-aft_likelihood:1.27542	validation_1-aft_likelihood:1.24480
# [7]	validation_0-aft_likelihood:1.27542	validation_1-aft_likelihood:1.24480
# [8]	validation_0-aft_likelihood:1.27542	validation_1-aft_likelihood:1.24480
# [9]	validation_0-aft_likelihood:1.27542	validation_1-aft_likelihood:1.24480
# [0]	validation_0-aft_likelihood:1.27277	validation_1-aft_likelihood:1.23752
# [1]	validation_0-aft_likelihood:1.27277	validation_1-aft_likelihood:1.23752
# [2]	validation_0-aft_likelihood:1.27277	validation_1-aft_likelihood:1.23752
# [3]	validation_0-aft_likelihood:1.27277	validation_1-aft_likelihood:1.23752
# [4]	validation_0-aft_likelihood:1.27277	validation_1-aft_likelihood:1.23752
# [5]	validation_0-aft_likelihood:1.27277	validation_1-aft_likelihood:1.23752
# [0]	validation_0-aft_likelihood:1.27604	validation_1-aft_likelihood:1.24019
# [6]	validation_0-aft_likelihood:1.27277	validation_1-aft_likelihood:1.23752
# [1]	validation_0-aft_likelihood:1.27604	validation_1-aft_likelihood:1.24019
# [7]	validation_0-aft_likelihood:1.27277	validation_1-aft_likelihood:1.23752
# [2]	validation_0-aft_likelihood:1.27604	validation_1-aft_likelihood:1.24019
# [8]	validation_0-aft_likelihood:1.27277	validation_1-aft_likelihood:1.23752
# [3]	validation_0-aft_likelihood:1.27604	validation_1-aft_likelihood:1.24019
# [9]	validation_0-aft_likelihood:1.27277	validation_1-aft_likelihood:1.23752
# [4]	validation_0-aft_likelihood:1.27604	validation_1-aft_likelihood:1.24019
# [10]	validation_0-aft_likelihood:1.27277	validation_1-aft_likelihood:1.23752
# [5]	validation_0-aft_likelihood:1.27604	validation_1-aft_likelihood:1.24019
# [6]	validation_0-aft_likelihood:1.27604	validation_1-aft_likelihood:1.24019
# [7]	validation_0-aft_likelihood:1.27604	validation_1-aft_likelihood:1.24019
# [8]	validation_0-aft_likelihood:1.27604	validation_1-aft_likelihood:1.24019
# [9]	validation_0-aft_likelihood:1.27604	validation_1-aft_likelihood:1.24019
# [0]	validation_0-aft_likelihood:1.26457	validation_1-aft_likelihood:1.24353
# [10]	validation_0-aft_likelihood:1.27604	validation_1-aft_likelihood:1.24019
# [1]	validation_0-aft_likelihood:1.26457	validation_1-aft_likelihood:1.24353
# [2]	validation_0-aft_likelihood:1.26457	validation_1-aft_likelihood:1.24353
# [3]	validation_0-aft_likelihood:1.26457	validation_1-aft_likelihood:1.24353
# [4]	validation_0-aft_likelihood:1.26457	validation_1-aft_likelihood:1.24353
# [5]	validation_0-aft_likelihood:1.26457	validation_1-aft_likelihood:1.24353
# [0]	validation_0-aft_likelihood:1.27349	validation_1-aft_likelihood:1.24036
# [6]	validation_0-aft_likelihood:1.26457	validation_1-aft_likelihood:1.24353
# [1]	validation_0-aft_likelihood:1.27349	validation_1-aft_likelihood:1.24036
# [7]	validation_0-aft_likelihood:1.26457	validation_1-aft_likelihood:1.24353
# [2]	validation_0-aft_likelihood:1.27349	validation_1-aft_likelihood:1.24036
# [8]	validation_0-aft_likelihood:1.26457	validation_1-aft_likelihood:1.24353
# [3]	validation_0-aft_likelihood:1.27349	validation_1-aft_likelihood:1.24036
# [9]	validation_0-aft_likelihood:1.26457	validation_1-aft_likelihood:1.24353
# [4]	validation_0-aft_likelihood:1.27349	validation_1-aft_likelihood:1.24036
# [10]	validation_0-aft_likelihood:1.26457	validation_1-aft_likelihood:1.24353
# [5]	validation_0-aft_likelihood:1.27349	validation_1-aft_likelihood:1.24036
# [6]	validation_0-aft_likelihood:1.27349	validation_1-aft_likelihood:1.24036
# [7]	validation_0-aft_likelihood:1.27349	validation_1-aft_likelihood:1.24036
# [8]	validation_0-aft_likelihood:1.27349	validation_1-aft_likelihood:1.24036
# [9]	validation_0-aft_likelihood:1.27349	validation_1-aft_likelihood:1.24036
# [0]	validation_0-aft_likelihood:1.27029	validation_1-aft_likelihood:1.25655
# [1]	validation_0-aft_likelihood:1.27029	validation_1-aft_likelihood:1.25655
# [2]	validation_0-aft_likelihood:1.27029	validation_1-aft_likelihood:1.25655
# [3]	validation_0-aft_likelihood:1.27029	validation_1-aft_likelihood:1.25655
# [4]	validation_0-aft_likelihood:1.27029	validation_1-aft_likelihood:1.25655
# [5]	validation_0-aft_likelihood:1.27029	validation_1-aft_likelihood:1.25655
# [6]	validation_0-aft_likelihood:1.27029	validation_1-aft_likelihood:1.25655
# [7]	validation_0-aft_likelihood:1.27029	validation_1-aft_likelihood:1.25655
# [8]	validation_0-aft_likelihood:1.27029	validation_1-aft_likelihood:1.25655
# [9]	validation_0-aft_likelihood:1.27029	validation_1-aft_likelihood:1.25655
# [10]	validation_0-aft_likelihood:1.27029	validation_1-aft_likelihood:1.25655
# Concordance Index 0.0
# Integrated Brier Score: 0.19194798366374036
# durations 5.0 8556.0
# Concordance Index 0.0
# Integrated Brier Score: 0.20184469664251345
# [0]	validation_0-aft_likelihood:1.27158	validation_1-aft_likelihood:1.23967
# [1]	validation_0-aft_likelihood:1.27158	validation_1-aft_likelihood:1.23967
# [2]	validation_0-aft_likelihood:1.27158	validation_1-aft_likelihood:1.23967
# [3]	validation_0-aft_likelihood:1.27158	validation_1-aft_likelihood:1.23967
# [4]	validation_0-aft_likelihood:1.27158	validation_1-aft_likelihood:1.23967
# [5]	validation_0-aft_likelihood:1.27158	validation_1-aft_likelihood:1.23967
# [6]	validation_0-aft_likelihood:1.27158	validation_1-aft_likelihood:1.23967
# [0]	validation_0-aft_likelihood:1.27312	validation_1-aft_likelihood:1.23911
# [7]	validation_0-aft_likelihood:1.27158	validation_1-aft_likelihood:1.23967
# [1]	validation_0-aft_likelihood:1.27312	validation_1-aft_likelihood:1.23911
# [8]	validation_0-aft_likelihood:1.27158	validation_1-aft_likelihood:1.23967
# [2]	validation_0-aft_likelihood:1.27312	validation_1-aft_likelihood:1.23911
# [9]	validation_0-aft_likelihood:1.27158	validation_1-aft_likelihood:1.23967
# [0]	validation_0-aft_likelihood:1.26946	validation_1-aft_likelihood:1.23609
# [3]	validation_0-aft_likelihood:1.27312	validation_1-aft_likelihood:1.23911
# [10]	validation_0-aft_likelihood:1.27158	validation_1-aft_likelihood:1.23967
# [1]	validation_0-aft_likelihood:1.26946	validation_1-aft_likelihood:1.23609
# [4]	validation_0-aft_likelihood:1.27312	validation_1-aft_likelihood:1.23911
# [2]	validation_0-aft_likelihood:1.26946	validation_1-aft_likelihood:1.23609
# [0]	validation_0-aft_likelihood:1.26914	validation_1-aft_likelihood:1.23751
# [5]	validation_0-aft_likelihood:1.27312	validation_1-aft_likelihood:1.23911
# [3]	validation_0-aft_likelihood:1.26946	validation_1-aft_likelihood:1.23609
# [1]	validation_0-aft_likelihood:1.26914	validation_1-aft_likelihood:1.23751
# [6]	validation_0-aft_likelihood:1.27312	validation_1-aft_likelihood:1.23911
# [4]	validation_0-aft_likelihood:1.26946	validation_1-aft_likelihood:1.23609
# [2]	validation_0-aft_likelihood:1.26914	validation_1-aft_likelihood:1.23751
# [7]	validation_0-aft_likelihood:1.27312	validation_1-aft_likelihood:1.23911
# [5]	validation_0-aft_likelihood:1.26946	validation_1-aft_likelihood:1.23609
# [0]	validation_0-aft_likelihood:1.26078	validation_1-aft_likelihood:1.23902
# [3]	validation_0-aft_likelihood:1.26914	validation_1-aft_likelihood:1.23751
# [8]	validation_0-aft_likelihood:1.27312	validation_1-aft_likelihood:1.23911
# [6]	validation_0-aft_likelihood:1.26946	validation_1-aft_likelihood:1.23609
# [1]	validation_0-aft_likelihood:1.26078	validation_1-aft_likelihood:1.23902
# [2]	validation_0-aft_likelihood:1.26078	validation_1-aft_likelihood:1.23902
# [4]	validation_0-aft_likelihood:1.26914	validation_1-aft_likelihood:1.23751
# [9]	validation_0-aft_likelihood:1.27312	validation_1-aft_likelihood:1.23911
# [3]	validation_0-aft_likelihood:1.26078	validation_1-aft_likelihood:1.23902
# [10]	validation_0-aft_likelihood:1.27312	validation_1-aft_likelihood:1.23911
# [4]	validation_0-aft_likelihood:1.26078	validation_1-aft_likelihood:1.23902
# [5]	validation_0-aft_likelihood:1.26078	validation_1-aft_likelihood:1.23902
# [7]	validation_0-aft_likelihood:1.26946	validation_1-aft_likelihood:1.23609
# [6]	validation_0-aft_likelihood:1.26078	validation_1-aft_likelihood:1.23902
# [5]	validation_0-aft_likelihood:1.26914	validation_1-aft_likelihood:1.23751
# [8]	validation_0-aft_likelihood:1.26946	validation_1-aft_likelihood:1.23609
# [7]	validation_0-aft_likelihood:1.26078	validation_1-aft_likelihood:1.23902
# [6]	validation_0-aft_likelihood:1.26914	validation_1-aft_likelihood:1.23751
# [9]	validation_0-aft_likelihood:1.26946	validation_1-aft_likelihood:1.23609
# [8]	validation_0-aft_likelihood:1.26078	validation_1-aft_likelihood:1.23902
# [7]	validation_0-aft_likelihood:1.26914	validation_1-aft_likelihood:1.23751
# [10]	validation_0-aft_likelihood:1.26946	validation_1-aft_likelihood:1.23609
# [9]	validation_0-aft_likelihood:1.26078	validation_1-aft_likelihood:1.23902
# [8]	validation_0-aft_likelihood:1.26914	validation_1-aft_likelihood:1.23751
# [9]	validation_0-aft_likelihood:1.26914	validation_1-aft_likelihood:1.23751
# [0]	validation_0-aft_likelihood:1.26561	validation_1-aft_likelihood:1.25166
# [1]	validation_0-aft_likelihood:1.26561	validation_1-aft_likelihood:1.25166
# [2]	validation_0-aft_likelihood:1.26561	validation_1-aft_likelihood:1.25166
# [3]	validation_0-aft_likelihood:1.26561	validation_1-aft_likelihood:1.25166
# [4]	validation_0-aft_likelihood:1.26561	validation_1-aft_likelihood:1.25166
# [5]	validation_0-aft_likelihood:1.26561	validation_1-aft_likelihood:1.25166
# [6]	validation_0-aft_likelihood:1.26561	validation_1-aft_likelihood:1.25166
# [7]	validation_0-aft_likelihood:1.26561	validation_1-aft_likelihood:1.25166
# [8]	validation_0-aft_likelihood:1.26561	validation_1-aft_likelihood:1.25166
# [9]	validation_0-aft_likelihood:1.26561	validation_1-aft_likelihood:1.25166
# [10]	validation_0-aft_likelihood:1.26561	validation_1-aft_likelihood:1.25166
# Concordance Index 0.0
# Integrated Brier Score: 0.19890367914012216
# durations 1.0 7106.0
# Concordance Index 0.0
# Integrated Brier Score: 0.18362430455093925
# [0]	validation_0-aft_likelihood:1.26404	validation_1-aft_likelihood:1.24073
# [1]	validation_0-aft_likelihood:1.26404	validation_1-aft_likelihood:1.24073
# [2]	validation_0-aft_likelihood:1.26404	validation_1-aft_likelihood:1.24073
# [3]	validation_0-aft_likelihood:1.26404	validation_1-aft_likelihood:1.24073
# [4]	validation_0-aft_likelihood:1.26404	validation_1-aft_likelihood:1.24073
# [5]	validation_0-aft_likelihood:1.26404	validation_1-aft_likelihood:1.24073
# [6]	validation_0-aft_likelihood:1.26404	validation_1-aft_likelihood:1.24073
# [7]	validation_0-aft_likelihood:1.26404	validation_1-aft_likelihood:1.24073
# [0]	validation_0-aft_likelihood:1.27350	validation_1-aft_likelihood:1.23994
# [8]	validation_0-aft_likelihood:1.26404	validation_1-aft_likelihood:1.24073
# [1]	validation_0-aft_likelihood:1.27350	validation_1-aft_likelihood:1.23994
# [9]	validation_0-aft_likelihood:1.26404	validation_1-aft_likelihood:1.24073
# [2]	validation_0-aft_likelihood:1.27350	validation_1-aft_likelihood:1.23994
# [3]	validation_0-aft_likelihood:1.27350	validation_1-aft_likelihood:1.23994
# [4]	validation_0-aft_likelihood:1.27350	validation_1-aft_likelihood:1.23994
# [5]	validation_0-aft_likelihood:1.27350	validation_1-aft_likelihood:1.23994
# [6]	validation_0-aft_likelihood:1.27350	validation_1-aft_likelihood:1.23994
# [0]	validation_0-aft_likelihood:1.27320	validation_1-aft_likelihood:1.23951
# [7]	validation_0-aft_likelihood:1.27350	validation_1-aft_likelihood:1.23994
# [0]	validation_0-aft_likelihood:1.27587	validation_1-aft_likelihood:1.24510
# [1]	validation_0-aft_likelihood:1.27320	validation_1-aft_likelihood:1.23951
# [8]	validation_0-aft_likelihood:1.27350	validation_1-aft_likelihood:1.23994
# [1]	validation_0-aft_likelihood:1.27587	validation_1-aft_likelihood:1.24510
# [2]	validation_0-aft_likelihood:1.27320	validation_1-aft_likelihood:1.23951
# [9]	validation_0-aft_likelihood:1.27350	validation_1-aft_likelihood:1.23994
# [2]	validation_0-aft_likelihood:1.27587	validation_1-aft_likelihood:1.24510
# [3]	validation_0-aft_likelihood:1.27320	validation_1-aft_likelihood:1.23951
# [10]	validation_0-aft_likelihood:1.27350	validation_1-aft_likelihood:1.23994
# [3]	validation_0-aft_likelihood:1.27587	validation_1-aft_likelihood:1.24510
# [4]	validation_0-aft_likelihood:1.27320	validation_1-aft_likelihood:1.23951
# [4]	validation_0-aft_likelihood:1.27587	validation_1-aft_likelihood:1.24510
# [5]	validation_0-aft_likelihood:1.27320	validation_1-aft_likelihood:1.23951
# [5]	validation_0-aft_likelihood:1.27587	validation_1-aft_likelihood:1.24510
# [6]	validation_0-aft_likelihood:1.27320	validation_1-aft_likelihood:1.23951
# [6]	validation_0-aft_likelihood:1.27587	validation_1-aft_likelihood:1.24510
# [7]	validation_0-aft_likelihood:1.27320	validation_1-aft_likelihood:1.23951
# [7]	validation_0-aft_likelihood:1.27587	validation_1-aft_likelihood:1.24510
# [8]	validation_0-aft_likelihood:1.27320	validation_1-aft_likelihood:1.23951
# [8]	validation_0-aft_likelihood:1.27587	validation_1-aft_likelihood:1.24510
# [9]	validation_0-aft_likelihood:1.27320	validation_1-aft_likelihood:1.23951
# [9]	validation_0-aft_likelihood:1.27587	validation_1-aft_likelihood:1.24510
# [0]	validation_0-aft_likelihood:1.27543	validation_1-aft_likelihood:1.23976
# [1]	validation_0-aft_likelihood:1.27543	validation_1-aft_likelihood:1.23976
# [2]	validation_0-aft_likelihood:1.27543	validation_1-aft_likelihood:1.23976
# [3]	validation_0-aft_likelihood:1.27543	validation_1-aft_likelihood:1.23976
# [4]	validation_0-aft_likelihood:1.27543	validation_1-aft_likelihood:1.23976
# ...
# [8]	validation_0-aft_likelihood:3.22296	validation_1-aft_likelihood:3.20820
# [9]	validation_0-aft_likelihood:3.22296	validation_1-aft_likelihood:3.20820
# [10]	validation_0-aft_likelihood:3.22296	validation_1-aft_likelihood:3.20820
# [0]	validation_0-aft_likelihood:3.22644	validation_1-aft_likelihood:3.23232
# [1]	validation_0-aft_likelihood:3.22644	validation_1-aft_likelihood:3.23232
# [2]	validation_0-aft_likelihood:3.22644	validation_1-aft_likelihood:3.23232
# [3]	validation_0-aft_likelihood:3.22644	validation_1-aft_likelihood:3.23232
# [4]	validation_0-aft_likelihood:3.22644	validation_1-aft_likelihood:3.23232
# [5]	validation_0-aft_likelihood:3.22644	validation_1-aft_likelihood:3.23232
# [6]	validation_0-aft_likelihood:3.22644	validation_1-aft_likelihood:3.23232
# [7]	validation_0-aft_likelihood:3.22644	validation_1-aft_likelihood:3.23232
# [8]	validation_0-aft_likelihood:3.22644	validation_1-aft_likelihood:3.23232
# [9]	validation_0-aft_likelihood:3.22644	validation_1-aft_likelihood:3.23232
# [10]	validation_0-aft_likelihood:3.22644	validation_1-aft_likelihood:3.23232
# [0]	validation_0-aft_likelihood:3.21699	validation_1-aft_likelihood:3.32019
# [1]	validation_0-aft_likelihood:3.21699	validation_1-aft_likelihood:3.32019
# [2]	validation_0-aft_likelihood:3.21699	validation_1-aft_likelihood:3.32019
# [3]	validation_0-aft_likelihood:3.21699	validation_1-aft_likelihood:3.32019
# [4]	validation_0-aft_likelihood:3.21699	validation_1-aft_likelihood:3.32019
# [5]	validation_0-aft_likelihood:3.21699	validation_1-aft_likelihood:3.32019
# [6]	validation_0-aft_likelihood:3.21699	validation_1-aft_likelihood:3.32019
# [7]	validation_0-aft_likelihood:3.21699	validation_1-aft_likelihood:3.32019
# [8]	validation_0-aft_likelihood:3.21699	validation_1-aft_likelihood:3.32019
# [9]	validation_0-aft_likelihood:3.21699	validation_1-aft_likelihood:3.32019
# [10]	validation_0-aft_likelihood:3.21699	validation_1-aft_likelihood:3.32019
# Concordance Index 0.0
# Integrated Brier Score: 0.19092913332848863
# durations 14.0 4282.0
# Concordance Index 0.0
# Integrated Brier Score: 0.19712618256108988
# [0]	validation_0-aft_likelihood:3.20373	validation_1-aft_likelihood:3.19394
# [1]	validation_0-aft_likelihood:3.20373	validation_1-aft_likelihood:3.19394
# [2]	validation_0-aft_likelihood:3.20373	validation_1-aft_likelihood:3.19394
# [3]	validation_0-aft_likelihood:3.20373	validation_1-aft_likelihood:3.19394
# [4]	validation_0-aft_likelihood:3.20373	validation_1-aft_likelihood:3.19394
# [5]	validation_0-aft_likelihood:3.20373	validation_1-aft_likelihood:3.19394
# [6]	validation_0-aft_likelihood:3.20373	validation_1-aft_likelihood:3.19394
# [7]	validation_0-aft_likelihood:3.20373	validation_1-aft_likelihood:3.19394
# [8]	validation_0-aft_likelihood:3.20373	validation_1-aft_likelihood:3.19394
# [9]	validation_0-aft_likelihood:3.20373	validation_1-aft_likelihood:3.19394
# [10]	validation_0-aft_likelihood:3.20373	validation_1-aft_likelihood:3.19394
# [0]	validation_0-aft_likelihood:3.20187	validation_1-aft_likelihood:3.19140
# [1]	validation_0-aft_likelihood:3.20187	validation_1-aft_likelihood:3.19140
# [2]	validation_0-aft_likelihood:3.20187	validation_1-aft_likelihood:3.19140
# [3]	validation_0-aft_likelihood:3.20187	validation_1-aft_likelihood:3.19140
# [4]	validation_0-aft_likelihood:3.20187	validation_1-aft_likelihood:3.19140
# [5]	validation_0-aft_likelihood:3.20187	validation_1-aft_likelihood:3.19140
# [6]	validation_0-aft_likelihood:3.20187	validation_1-aft_likelihood:3.19140
# [0]	validation_0-aft_likelihood:3.21106	validation_1-aft_likelihood:3.24720
# [7]	validation_0-aft_likelihood:3.20187	validation_1-aft_likelihood:3.19140
# [8]	validation_0-aft_likelihood:3.20187	validation_1-aft_likelihood:3.19140
# [1]	validation_0-aft_likelihood:3.21106	validation_1-aft_likelihood:3.24720
# [9]	validation_0-aft_likelihood:3.20187	validation_1-aft_likelihood:3.19140
# [2]	validation_0-aft_likelihood:3.21106	validation_1-aft_likelihood:3.24720
# [10]	validation_0-aft_likelihood:3.20187	validation_1-aft_likelihood:3.19140
# [3]	validation_0-aft_likelihood:3.21106	validation_1-aft_likelihood:3.24720
# [4]	validation_0-aft_likelihood:3.21106	validation_1-aft_likelihood:3.24720
# [5]	validation_0-aft_likelihood:3.21106	validation_1-aft_likelihood:3.24720
# [6]	validation_0-aft_likelihood:3.21106	validation_1-aft_likelihood:3.24720
# [7]	validation_0-aft_likelihood:3.21106	validation_1-aft_likelihood:3.24720
# [8]	validation_0-aft_likelihood:3.21106	validation_1-aft_likelihood:3.24720
# [9]	validation_0-aft_likelihood:3.21106	validation_1-aft_likelihood:3.24720
# [0]	validation_0-aft_likelihood:3.22516	validation_1-aft_likelihood:3.26945
# [1]	validation_0-aft_likelihood:3.22516	validation_1-aft_likelihood:3.26945
# [2]	validation_0-aft_likelihood:3.22516	validation_1-aft_likelihood:3.26945
# [3]	validation_0-aft_likelihood:3.22516	validation_1-aft_likelihood:3.26945
# [0]	validation_0-aft_likelihood:3.20499	validation_1-aft_likelihood:3.20201
# [4]	validation_0-aft_likelihood:3.22516	validation_1-aft_likelihood:3.26945
# [1]	validation_0-aft_likelihood:3.20499	validation_1-aft_likelihood:3.20201
# [5]	validation_0-aft_likelihood:3.22516	validation_1-aft_likelihood:3.26945
# [2]	validation_0-aft_likelihood:3.20499	validation_1-aft_likelihood:3.20201
# [6]	validation_0-aft_likelihood:3.22516	validation_1-aft_likelihood:3.26945
# [3]	validation_0-aft_likelihood:3.20499	validation_1-aft_likelihood:3.20201
# [7]	validation_0-aft_likelihood:3.22516	validation_1-aft_likelihood:3.26945
# [4]	validation_0-aft_likelihood:3.20499	validation_1-aft_likelihood:3.20201
# [8]	validation_0-aft_likelihood:3.22516	validation_1-aft_likelihood:3.26945
# [5]	validation_0-aft_likelihood:3.20499	validation_1-aft_likelihood:3.20201
# [9]	validation_0-aft_likelihood:3.22516	validation_1-aft_likelihood:3.26945
# [6]	validation_0-aft_likelihood:3.20499	validation_1-aft_likelihood:3.20201
# [7]	validation_0-aft_likelihood:3.20499	validation_1-aft_likelihood:3.20201
# [8]	validation_0-aft_likelihood:3.20499	validation_1-aft_likelihood:3.20201
# [9]	validation_0-aft_likelihood:3.20499	validation_1-aft_likelihood:3.20201
# [10]	validation_0-aft_likelihood:3.20499	validation_1-aft_likelihood:3.20201
# [0]	validation_0-aft_likelihood:3.19791	validation_1-aft_likelihood:3.29175
# [1]	validation_0-aft_likelihood:3.19791	validation_1-aft_likelihood:3.29175
# [2]	validation_0-aft_likelihood:3.19791	validation_1-aft_likelihood:3.29175
# [3]	validation_0-aft_likelihood:3.19791	validation_1-aft_likelihood:3.29175
# [4]	validation_0-aft_likelihood:3.19791	validation_1-aft_likelihood:3.29175
# [5]	validation_0-aft_likelihood:3.19791	validation_1-aft_likelihood:3.29175
# [6]	validation_0-aft_likelihood:3.19791	validation_1-aft_likelihood:3.29175
# [7]	validation_0-aft_likelihood:3.19791	validation_1-aft_likelihood:3.29175
# [8]	validation_0-aft_likelihood:3.19791	validation_1-aft_likelihood:3.29175
# [9]	validation_0-aft_likelihood:3.19791	validation_1-aft_likelihood:3.29175
# [10]	validation_0-aft_likelihood:3.19791	validation_1-aft_likelihood:3.29175
# Concordance Index 0.0
# Integrated Brier Score: 0.188209632445943
# durations 11.0 6417.0
# Concordance Index 0.0
# Integrated Brier Score: 0.20439465853083982
# [0]	validation_0-aft_likelihood:3.23798	validation_1-aft_likelihood:3.28695
# [1]	validation_0-aft_likelihood:3.23798	validation_1-aft_likelihood:3.28695
# [2]	validation_0-aft_likelihood:3.23798	validation_1-aft_likelihood:3.28695
# [3]	validation_0-aft_likelihood:3.23798	validation_1-aft_likelihood:3.28695
# [4]	validation_0-aft_likelihood:3.23798	validation_1-aft_likelihood:3.28695
# [5]	validation_0-aft_likelihood:3.23798	validation_1-aft_likelihood:3.28695
# [6]	validation_0-aft_likelihood:3.23798	validation_1-aft_likelihood:3.28695
# [7]	validation_0-aft_likelihood:3.23798	validation_1-aft_likelihood:3.28695
# [8]	validation_0-aft_likelihood:3.23798	validation_1-aft_likelihood:3.28695
# [0]	validation_0-aft_likelihood:3.26472	validation_1-aft_likelihood:3.32049
# [9]	validation_0-aft_likelihood:3.23798	validation_1-aft_likelihood:3.28695
# [1]	validation_0-aft_likelihood:3.26472	validation_1-aft_likelihood:3.32049
# [10]	validation_0-aft_likelihood:3.23798	validation_1-aft_likelihood:3.28695
# [2]	validation_0-aft_likelihood:3.26472	validation_1-aft_likelihood:3.32049
# [0]	validation_0-aft_likelihood:3.25531	validation_1-aft_likelihood:3.30543
# [3]	validation_0-aft_likelihood:3.26472	validation_1-aft_likelihood:3.32049
# [1]	validation_0-aft_likelihood:3.25531	validation_1-aft_likelihood:3.30543
# [4]	validation_0-aft_likelihood:3.26472	validation_1-aft_likelihood:3.32049
# [2]	validation_0-aft_likelihood:3.25531	validation_1-aft_likelihood:3.30543
# [5]	validation_0-aft_likelihood:3.26472	validation_1-aft_likelihood:3.32049
# [3]	validation_0-aft_likelihood:3.25531	validation_1-aft_likelihood:3.30543
# [6]	validation_0-aft_likelihood:3.26472	validation_1-aft_likelihood:3.32049
# [4]	validation_0-aft_likelihood:3.25531	validation_1-aft_likelihood:3.30543
# [7]	validation_0-aft_likelihood:3.26472	validation_1-aft_likelihood:3.32049
# [5]	validation_0-aft_likelihood:3.25531	validation_1-aft_likelihood:3.30543
# [8]	validation_0-aft_likelihood:3.26472	validation_1-aft_likelihood:3.32049
# [6]	validation_0-aft_likelihood:3.25531	validation_1-aft_likelihood:3.30543
# [9]	validation_0-aft_likelihood:3.26472	validation_1-aft_likelihood:3.32049
# [7]	validation_0-aft_likelihood:3.25531	validation_1-aft_likelihood:3.30543
# [10]	validation_0-aft_likelihood:3.26472	validation_1-aft_likelihood:3.32049
# [8]	validation_0-aft_likelihood:3.25531	validation_1-aft_likelihood:3.30543
# [9]	validation_0-aft_likelihood:3.25531	validation_1-aft_likelihood:3.30543
# [0]	validation_0-aft_likelihood:3.23185	validation_1-aft_likelihood:3.33049
# [1]	validation_0-aft_likelihood:3.23185	validation_1-aft_likelihood:3.33049
# [2]	validation_0-aft_likelihood:3.23185	validation_1-aft_likelihood:3.33049
# [3]	validation_0-aft_likelihood:3.23185	validation_1-aft_likelihood:3.33049
# [4]	validation_0-aft_likelihood:3.23185	validation_1-aft_likelihood:3.33049
# [5]	validation_0-aft_likelihood:3.23185	validation_1-aft_likelihood:3.33049
# [6]	validation_0-aft_likelihood:3.23185	validation_1-aft_likelihood:3.33049
# [7]	validation_0-aft_likelihood:3.23185	validation_1-aft_likelihood:3.33049
# [8]	validation_0-aft_likelihood:3.23185	validation_1-aft_likelihood:3.33049
# [9]	validation_0-aft_likelihood:3.23185	validation_1-aft_likelihood:3.33049
# [0]	validation_0-aft_likelihood:3.18754	validation_1-aft_likelihood:3.25253
# [1]	validation_0-aft_likelihood:3.18754	validation_1-aft_likelihood:3.25253
# [2]	validation_0-aft_likelihood:3.18754	validation_1-aft_likelihood:3.25253
# [3]	validation_0-aft_likelihood:3.18754	validation_1-aft_likelihood:3.25253
# [4]	validation_0-aft_likelihood:3.18754	validation_1-aft_likelihood:3.25253
# [5]	validation_0-aft_likelihood:3.18754	validation_1-aft_likelihood:3.25253
# [6]	validation_0-aft_likelihood:3.18754	validation_1-aft_likelihood:3.25253
# [7]	validation_0-aft_likelihood:3.18754	validation_1-aft_likelihood:3.25253
# [8]	validation_0-aft_likelihood:3.18754	validation_1-aft_likelihood:3.25253
# [9]	validation_0-aft_likelihood:3.18754	validation_1-aft_likelihood:3.25253
# [0]	validation_0-aft_likelihood:3.22684	validation_1-aft_likelihood:3.35506
# [1]	validation_0-aft_likelihood:3.22684	validation_1-aft_likelihood:3.35506
# [2]	validation_0-aft_likelihood:3.22684	validation_1-aft_likelihood:3.35506
# [3]	validation_0-aft_likelihood:3.22684	validation_1-aft_likelihood:3.35506
# [4]	validation_0-aft_likelihood:3.22684	validation_1-aft_likelihood:3.35506
# [5]	validation_0-aft_likelihood:3.22684	validation_1-aft_likelihood:3.35506
# [6]	validation_0-aft_likelihood:3.22684	validation_1-aft_likelihood:3.35506
# [7]	validation_0-aft_likelihood:3.22684	validation_1-aft_likelihood:3.35506
# [8]	validation_0-aft_likelihood:3.22684	validation_1-aft_likelihood:3.35506
# [9]	validation_0-aft_likelihood:3.22684	validation_1-aft_likelihood:3.35506
# Concordance Index 0.0
# Integrated Brier Score: 0.1779167242358877
# durations 2.0 5480.0
# Concordance Index 0.0
# Integrated Brier Score: 0.2129633221954963
# [0]	validation_0-aft_likelihood:3.19451	validation_1-aft_likelihood:3.19000
# [1]	validation_0-aft_likelihood:3.19451	validation_1-aft_likelihood:3.19000
# [2]	validation_0-aft_likelihood:3.19451	validation_1-aft_likelihood:3.19000
# [3]	validation_0-aft_likelihood:3.19451	validation_1-aft_likelihood:3.19000
# [4]	validation_0-aft_likelihood:3.19451	validation_1-aft_likelihood:3.19000
# [0]	validation_0-aft_likelihood:3.21839	validation_1-aft_likelihood:3.24450
# [5]	validation_0-aft_likelihood:3.19451	validation_1-aft_likelihood:3.19000
# [1]	validation_0-aft_likelihood:3.21839	validation_1-aft_likelihood:3.24450
# [6]	validation_0-aft_likelihood:3.19451	validation_1-aft_likelihood:3.19000
# [2]	validation_0-aft_likelihood:3.21839	validation_1-aft_likelihood:3.24450
# [7]	validation_0-aft_likelihood:3.19451	validation_1-aft_likelihood:3.19000
# [3]	validation_0-aft_likelihood:3.21839	validation_1-aft_likelihood:3.24450
# [8]	validation_0-aft_likelihood:3.19451	validation_1-aft_likelihood:3.19000
# [4]	validation_0-aft_likelihood:3.21839	validation_1-aft_likelihood:3.24450
# [9]	validation_0-aft_likelihood:3.19451	validation_1-aft_likelihood:3.19000
# [5]	validation_0-aft_likelihood:3.21839	validation_1-aft_likelihood:3.24450
# [6]	validation_0-aft_likelihood:3.21839	validation_1-aft_likelihood:3.24450
# [7]	validation_0-aft_likelihood:3.21839	validation_1-aft_likelihood:3.24450
# [8]	validation_0-aft_likelihood:3.21839	validation_1-aft_likelihood:3.24450
# [9]	validation_0-aft_likelihood:3.21839	validation_1-aft_likelihood:3.24450
# [0]	validation_0-aft_likelihood:3.19339	validation_1-aft_likelihood:3.19161
# [1]	validation_0-aft_likelihood:3.19339	validation_1-aft_likelihood:3.19161
# [0]	validation_0-aft_likelihood:3.20257	validation_1-aft_likelihood:3.21152
# [2]	validation_0-aft_likelihood:3.19339	validation_1-aft_likelihood:3.19161
# [3]	validation_0-aft_likelihood:3.19339	validation_1-aft_likelihood:3.19161
# [1]	validation_0-aft_likelihood:3.20257	validation_1-aft_likelihood:3.21152
# [2]	validation_0-aft_likelihood:3.20257	validation_1-aft_likelihood:3.21152
# [4]	validation_0-aft_likelihood:3.19339	validation_1-aft_likelihood:3.19161
# [3]	validation_0-aft_likelihood:3.20257	validation_1-aft_likelihood:3.21152
# [5]	validation_0-aft_likelihood:3.19339	validation_1-aft_likelihood:3.19161
# [0]	validation_0-aft_likelihood:3.21471	validation_1-aft_likelihood:3.26949
# [4]	validation_0-aft_likelihood:3.20257	validation_1-aft_likelihood:3.21152
# [6]	validation_0-aft_likelihood:3.19339	validation_1-aft_likelihood:3.19161
# [1]	validation_0-aft_likelihood:3.21471	validation_1-aft_likelihood:3.26949
# [5]	validation_0-aft_likelihood:3.20257	validation_1-aft_likelihood:3.21152
# [7]	validation_0-aft_likelihood:3.19339	validation_1-aft_likelihood:3.19161
# [2]	validation_0-aft_likelihood:3.21471	validation_1-aft_likelihood:3.26949
# [6]	validation_0-aft_likelihood:3.20257	validation_1-aft_likelihood:3.21152
# [3]	validation_0-aft_likelihood:3.21471	validation_1-aft_likelihood:3.26949
# [8]	validation_0-aft_likelihood:3.19339	validation_1-aft_likelihood:3.19161
# [7]	validation_0-aft_likelihood:3.20257	validation_1-aft_likelihood:3.21152
# [4]	validation_0-aft_likelihood:3.21471	validation_1-aft_likelihood:3.26949
# [9]	validation_0-aft_likelihood:3.19339	validation_1-aft_likelihood:3.19161
# [8]	validation_0-aft_likelihood:3.20257	validation_1-aft_likelihood:3.21152
# [5]	validation_0-aft_likelihood:3.21471	validation_1-aft_likelihood:3.26949
# [9]	validation_0-aft_likelihood:3.20257	validation_1-aft_likelihood:3.21152
# [6]	validation_0-aft_likelihood:3.21471	validation_1-aft_likelihood:3.26949
# [10]	validation_0-aft_likelihood:3.20257	validation_1-aft_likelihood:3.21152
# [7]	validation_0-aft_likelihood:3.21471	validation_1-aft_likelihood:3.26949
# [8]	validation_0-aft_likelihood:3.21471	validation_1-aft_likelihood:3.26949
# [9]	validation_0-aft_likelihood:3.21471	validation_1-aft_likelihood:3.26949
# [10]	validation_0-aft_likelihood:3.21471	validation_1-aft_likelihood:3.26949
# [0]	validation_0-aft_likelihood:3.18324	validation_1-aft_likelihood:3.33347

# %%
df_final_aft_1_cindex = pd.concat([df for df in agg_metrics_cindex]).round(4)
df_final_aft_1_cindex.to_csv('metrics/final_gbdt_tcga_aft_1_cindex.csv', index=False)
df_final_aft_1_cindex.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_tcga_aft_1_cindex.csv', index=False)  #
df_final_aft_1_cindex
# Out:
#   dataset  cindex_train_mean  cindex_train_std  cindex_test_mean  \
# 0    BLCA             0.7440            0.0122            0.5822
# 0    BRCA             0.8445            0.0161            0.5264
# 0    HNSC             0.7756            0.0118            0.5219
# 0    KIRC             0.8115            0.0121            0.6186
# 0     LGG             0.8461            0.0136            0.7583
# 0    LIHC             0.7482            0.0622            0.5116
# 0    LUAD             0.7718            0.0075            0.5470
# 0    LUSC             0.6836            0.0810            0.4753
# 0      OV             0.5916            0.0198            0.4774
# 0    STAD             0.6990            0.1153            0.4875
#
#    cindex_test_std
# 0           0.0175
# 0           0.0513
# 0           0.0441
# 0           0.0546
# 0           0.0493
# 0           0.0510
# 0           0.0468
# 0           0.0590
# 0           0.0339
# 0           0.0582

# %%
df_final_aft_1_ibs = pd.concat([df for df in agg_metrics_ibs]).round(4)
df_final_aft_1_ibs.to_csv('metrics/final_gbdt_tcga_aft_1_ibs.csv', index=False)
df_final_aft_1_ibs.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_tcga_aft_1_ibs.csv', index=False) 
df_final_aft_1_ibs
# Out:
#   dataset  ibs_train_mean  ibs_train_std  ibs_test_mean  ibs_test_std
# 0    BLCA          0.2090         0.0047         0.2224        0.0066
# 0    BRCA          0.1854         0.0027         0.1962        0.0097
# 0    HNSC          0.1803         0.0054         0.2038        0.0062
# 0    KIRC          0.1969         0.0026         0.1998        0.0065
# 0     LGG          0.1690         0.0054         0.1912        0.0127
# 0    LIHC          0.2023         0.0074         0.2181        0.0136
# 0    LUAD          0.1851         0.0046         0.1990        0.0108
# 0    LUSC          0.1892         0.0039         0.2037        0.0119
# 0      OV          0.1266         0.0077         0.1442        0.0183
# 0    STAD          0.2056         0.0038         0.2166        0.0081
