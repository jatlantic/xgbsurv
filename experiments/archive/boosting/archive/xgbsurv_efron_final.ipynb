# %%
## XGBSurv Breslow Benchmark

# %%
from xgbsurv.datasets import (load_metabric, load_flchain, load_rgbsg, load_support, load_tcga)
from xgbsurv import XGBSurv
from xgbsurv.evaluation import cindex_censored, ibs
from xgbsurv.models.utils import sort_X_y
import os
import numpy as np
import pandas as pd
from scipy.stats import uniform as scuniform
from scipy.stats import randint as scrandint
from scipy.stats import loguniform as scloguniform 
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, LabelBinarizer, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.decomposition import PCA
# import models
from xgbsurv.models.efron_final import efron_likelihood, get_cumulative_hazard_function_efron
from pycox.evaluation import EvalSurv
from xgbsurv.models.utils import sort_X_y_pandas, transform_back, transform
from xgbsurv.preprocessing.dataset_preprocessing import discretizer_df

# %% [markdown]
# ## Set Parameters

# %%
# set parameters
n_outer_splits = 5
n_inner_splits = 5
rand_state = 42
n_iter = 100
n_iter_cind = 200
early_stopping_rounds=10
base_score = 0.0

# Define parameter grid for random forest classifier
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
}

# %% [markdown]
# ## Custom Splitting

# %%
class CustomSplit(StratifiedKFold):
    def __init__(self, n_splits=5, shuffle=True, random_state=None):
        super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)

    def split(self, X, y, groups=None):
        try:
            if y.shape[1]>1:
                y = y[:,0]
        except:
            pass
        bins = np.sign(y)
        return super().split(X, bins, groups=groups)

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

outer_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)
inner_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)

# %%
## Scoring Function

# %%
scoring_function = make_scorer(efron_likelihood, greater_is_better=False)

# %%
## Set Model & Train Test Evaluate

# %%
data_set_fns = [load_metabric,  load_flchain, load_rgbsg, load_support] #, load_flchain, load_rgbsg, load_support, load_tcga]
data_set_fns_str = ['load_metabric', 'load_flchain', 'load_rgbsg', 'load_support'] 
one_hot_dict = {'load_flchain': ['mgus'], 'load_support':['cancer'], 'load_rgbsg':['grade']}

for idx, dataset in enumerate(data_set_fns):
    model = 'xgbsurv_efron_'
    # get name of current dataset
    data = dataset(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=True)
    filename = data.filename
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()

    print(data_set_fns_str[idx])
    if data_set_fns_str[idx] in one_hot_dict.keys():
        X = pd.get_dummies(X, columns=one_hot_dict[data_set_fns_str[idx]])
    X, y = sort_X_y_pandas(X, y)
    #print(X.dtypes)
    dataset_name = filename.split('_')[0]
    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            #(OneHotEncoder(sparse_output=False), make_column_selector(dtype_include=['category', 'object']))
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='efron_objective',
        eval_metric='efron_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    pipe = Pipeline([('scaler',ct),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=2, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        print(X_train.shape, type(X_train))
        print(y_train.shape, type(y_train))
        print(X_test.shape, type(X_test))
        print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_efron(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_efron(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# Out:
# load_metabric
# (1522, 9) <class 'pandas.core.frame.DataFrame'>
# (1522,) <class 'pandas.core.series.Series'>
# (381, 9) <class 'pandas.core.frame.DataFrame'>
# (381,) <class 'pandas.core.series.Series'>
# [0]	validation_0-efron_likelihood:3280.96684	validation_1-efron_likelihood:665.85311
# [1]	validation_0-efron_likelihood:3278.50731	validation_1-efron_likelihood:665.79379
# [2]	validation_0-efron_likelihood:3276.01910	validation_1-efron_likelihood:665.00339
# [0]	validation_0-efron_likelihood:3305.20448	validation_1-efron_likelihood:628.64989
# [3]	validation_0-efron_likelihood:3273.67351	validation_1-efron_likelihood:664.72478
# [1]	validation_0-efron_likelihood:3300.60090	validation_1-efron_likelihood:627.63314
# [4]	validation_0-efron_likelihood:3270.22303	validation_1-efron_likelihood:664.05953
# [2]	validation_0-efron_likelihood:3296.31636	validation_1-efron_likelihood:626.56154
# [5]	validation_0-efron_likelihood:3266.60775	validation_1-efron_likelihood:664.26913
# [3]	validation_0-efron_likelihood:3295.75432	validation_1-efron_likelihood:626.30400
# [4]	validation_0-efron_likelihood:3293.12632	validation_1-efron_likelihood:626.05029
# [0]	validation_0-efron_likelihood:3310.09183	validation_1-efron_likelihood:632.58180
# [5]	validation_0-efron_likelihood:3290.43125	validation_1-efron_likelihood:625.49301
# [1]	validation_0-efron_likelihood:3309.71846	validation_1-efron_likelihood:632.57980
# [2]	validation_0-efron_likelihood:3309.69411	validation_1-efron_likelihood:632.57965
# [3]	validation_0-efron_likelihood:3309.65852	validation_1-efron_likelihood:632.57767
# [4]	validation_0-efron_likelihood:3309.49979	validation_1-efron_likelihood:632.54726
# [5]	validation_0-efron_likelihood:3309.35478	validation_1-efron_likelihood:632.53486
# [6]	validation_0-efron_likelihood:3309.00452	validation_1-efron_likelihood:632.49360
# [7]	validation_0-efron_likelihood:3308.99200	validation_1-efron_likelihood:632.49261
# [8]	validation_0-efron_likelihood:3308.91954	validation_1-efron_likelihood:632.48040
# [9]	validation_0-efron_likelihood:3308.91954	validation_1-efron_likelihood:632.48040
# [10]	validation_0-efron_likelihood:3308.01145	validation_1-efron_likelihood:632.46965
# [11]	validation_0-efron_likelihood:3307.97055	validation_1-efron_likelihood:632.46168
# [12]	validation_0-efron_likelihood:3307.83351	validation_1-efron_likelihood:632.43483
# [13]	validation_0-efron_likelihood:3307.55122	validation_1-efron_likelihood:632.39295
# [14]	validation_0-efron_likelihood:3307.13189	validation_1-efron_likelihood:632.37639
# [15]	validation_0-efron_likelihood:3307.01056	validation_1-efron_likelihood:632.35177
# [16]	validation_0-efron_likelihood:3306.95376	validation_1-efron_likelihood:632.34139
# [0]	validation_0-efron_likelihood:3284.19724	validation_1-efron_likelihood:666.10750
# [17]	validation_0-efron_likelihood:3306.87752	validation_1-efron_likelihood:632.32735
# [1]	validation_0-efron_likelihood:3283.90916	validation_1-efron_likelihood:666.09903
# [18]	validation_0-efron_likelihood:3306.41363	validation_1-efron_likelihood:632.28484
# [2]	validation_0-efron_likelihood:3283.87542	validation_1-efron_likelihood:666.09973
# [19]	validation_0-efron_likelihood:3306.37051	validation_1-efron_likelihood:632.27621
# [3]	validation_0-efron_likelihood:3283.83361	validation_1-efron_likelihood:666.09816
# [20]	validation_0-efron_likelihood:3306.29097	validation_1-efron_likelihood:632.26545
# [4]	validation_0-efron_likelihood:3283.67497	validation_1-efron_likelihood:666.08366
# [0]	validation_0-efron_likelihood:3308.15833	validation_1-efron_likelihood:629.23299
# [5]	validation_0-efron_likelihood:3283.54212	validation_1-efron_likelihood:666.07377
# [21]	validation_0-efron_likelihood:3305.67841	validation_1-efron_likelihood:632.21926
# [1]	validation_0-efron_likelihood:3308.10429	validation_1-efron_likelihood:629.22078
# [6]	validation_0-efron_likelihood:3283.12492	validation_1-efron_likelihood:666.04039
# [22]	validation_0-efron_likelihood:3305.38287	validation_1-efron_likelihood:632.20564
# [7]	validation_0-efron_likelihood:3283.08071	validation_1-efron_likelihood:666.03706
# [2]	validation_0-efron_likelihood:3307.59336	validation_1-efron_likelihood:629.23911
# [23]	validation_0-efron_likelihood:3305.33600	validation_1-efron_likelihood:632.19811
# [8]	validation_0-efron_likelihood:3283.03619	validation_1-efron_likelihood:666.02771
# [3]	validation_0-efron_likelihood:3307.56860	validation_1-efron_likelihood:629.23366
# [24]	validation_0-efron_likelihood:3305.33080	validation_1-efron_likelihood:632.19481
# [9]	validation_0-efron_likelihood:3283.03316	validation_1-efron_likelihood:666.02734
# [25]	validation_0-efron_likelihood:3305.14555	validation_1-efron_likelihood:632.18253
# [4]	validation_0-efron_likelihood:3307.16080	validation_1-efron_likelihood:629.20788
# [10]	validation_0-efron_likelihood:3282.11125	validation_1-efron_likelihood:665.98450
# [26]	validation_0-efron_likelihood:3305.09565	validation_1-efron_likelihood:632.17259
# [11]	validation_0-efron_likelihood:3282.08345	validation_1-efron_likelihood:665.98102
# [12]	validation_0-efron_likelihood:3281.96658	validation_1-efron_likelihood:665.95264
# [27]	validation_0-efron_likelihood:3305.03970	validation_1-efron_likelihood:632.16567
# [5]	validation_0-efron_likelihood:3307.06003	validation_1-efron_likelihood:629.17779
# [13]	validation_0-efron_likelihood:3281.68950	validation_1-efron_likelihood:665.92757
# [0]	validation_0-efron_likelihood:3260.26380	validation_1-efron_likelihood:678.89243
# [28]	validation_0-efron_likelihood:3304.91316	validation_1-efron_likelihood:632.14944
# [14]	validation_0-efron_likelihood:3281.34224	validation_1-efron_likelihood:665.93191
# [29]	validation_0-efron_likelihood:3304.90422	validation_1-efron_likelihood:632.14933
# [1]	validation_0-efron_likelihood:3260.04806	validation_1-efron_likelihood:678.88483
# [15]	validation_0-efron_likelihood:3281.22516	validation_1-efron_likelihood:665.90298
# [30]	validation_0-efron_likelihood:3304.86374	validation_1-efron_likelihood:632.14126
# [2]	validation_0-efron_likelihood:3260.01879	validation_1-efron_likelihood:678.88258
# [16]	validation_0-efron_likelihood:3281.19618	validation_1-efron_likelihood:665.89446
# [31]	validation_0-efron_likelihood:3304.83832	validation_1-efron_likelihood:632.13422
# [3]	validation_0-efron_likelihood:3260.00316	validation_1-efron_likelihood:678.88627
# [6]	validation_0-efron_likelihood:3306.72069	validation_1-efron_likelihood:629.18688
# [17]	validation_0-efron_likelihood:3281.12671	validation_1-efron_likelihood:665.88216
# [32]	validation_0-efron_likelihood:3304.37887	validation_1-efron_likelihood:632.10355
# [4]	validation_0-efron_likelihood:3259.77380	validation_1-efron_likelihood:678.85939
# [18]	validation_0-efron_likelihood:3280.44562	validation_1-efron_likelihood:665.85914
# [33]	validation_0-efron_likelihood:3304.25177	validation_1-efron_likelihood:632.09084
# [5]	validation_0-efron_likelihood:3259.65301	validation_1-efron_likelihood:678.85993
# [7]	validation_0-efron_likelihood:3306.69465	validation_1-efron_likelihood:629.18193
# [19]	validation_0-efron_likelihood:3280.42360	validation_1-efron_likelihood:665.85326
# [34]	validation_0-efron_likelihood:3304.11307	validation_1-efron_likelihood:632.06631
# [6]	validation_0-efron_likelihood:3259.20861	validation_1-efron_likelihood:678.81917
# [20]	validation_0-efron_likelihood:3280.37249	validation_1-efron_likelihood:665.84459
# [35]	validation_0-efron_likelihood:3304.09751	validation_1-efron_likelihood:632.06440
# [7]	validation_0-efron_likelihood:3259.18115	validation_1-efron_likelihood:678.81621
# [8]	validation_0-efron_likelihood:3259.15472	validation_1-efron_likelihood:678.81925
# [36]	validation_0-efron_likelihood:3303.49892	validation_1-efron_likelihood:632.03354
# [21]	validation_0-efron_likelihood:3279.64089	validation_1-efron_likelihood:665.77862
# [8]	validation_0-efron_likelihood:3306.55244	validation_1-efron_likelihood:629.19484
# [9]	validation_0-efron_likelihood:3259.15472	validation_1-efron_likelihood:678.81925
# [22]	validation_0-efron_likelihood:3279.28993	validation_1-efron_likelihood:665.71921
# [37]	validation_0-efron_likelihood:3302.74552	validation_1-efron_likelihood:631.99502
# [23]	validation_0-efron_likelihood:3279.23771	validation_1-efron_likelihood:665.71309
# [38]	validation_0-efron_likelihood:3302.71931	validation_1-efron_likelihood:631.98889
# [24]	validation_0-efron_likelihood:3279.22622	validation_1-efron_likelihood:665.71094[10]	validation_0-efron_likelihood:3258.17299	validation_1-efron_likelihood:678.78815
#
# [9]	validation_0-efron_likelihood:3305.57908	validation_1-efron_likelihood:629.18760
# [11]	validation_0-efron_likelihood:3258.16120	validation_1-efron_likelihood:678.78870
# [25]	validation_0-efron_likelihood:3279.06822	validation_1-efron_likelihood:665.71243
# [39]	validation_0-efron_likelihood:3302.49090	validation_1-efron_likelihood:631.95195
# [10]	validation_0-efron_likelihood:3305.09355	validation_1-efron_likelihood:629.18245
# [12]	validation_0-efron_likelihood:3257.96647	validation_1-efron_likelihood:678.75564
# [26]	validation_0-efron_likelihood:3278.97426	validation_1-efron_likelihood:665.70292
# [11]	validation_0-efron_likelihood:3305.03116	validation_1-efron_likelihood:629.17457
# [40]	validation_0-efron_likelihood:3302.08137	validation_1-efron_likelihood:631.93355
# [27]	validation_0-efron_likelihood:3278.91344	validation_1-efron_likelihood:665.68916
# [13]	validation_0-efron_likelihood:3257.57468	validation_1-efron_likelihood:678.71199
# [12]	validation_0-efron_likelihood:3304.68777	validation_1-efron_likelihood:629.12800
# [28]	validation_0-efron_likelihood:3278.78627	validation_1-efron_likelihood:665.66692
# [41]	validation_0-efron_likelihood:3301.64312	validation_1-efron_likelihood:631.89203
# [14]	validation_0-efron_likelihood:3257.18393	validation_1-efron_likelihood:678.73561
# [13]	validation_0-efron_likelihood:3304.66824	validation_1-efron_likelihood:629.12204
# [29]	validation_0-efron_likelihood:3278.77949	validation_1-efron_likelihood:665.66934
# [15]	validation_0-efron_likelihood:3257.05490	validation_1-efron_likelihood:678.71903
# [30]	validation_0-efron_likelihood:3278.75274	validation_1-efron_likelihood:665.66621
# [42]	validation_0-efron_likelihood:3301.58680	validation_1-efron_likelihood:631.88305
# [16]	validation_0-efron_likelihood:3257.02852	validation_1-efron_likelihood:678.71343
# [31]	validation_0-efron_likelihood:3278.70760	validation_1-efron_likelihood:665.66087
# [14]	validation_0-efron_likelihood:3303.74530	validation_1-efron_likelihood:629.15221
# [17]	validation_0-efron_likelihood:3256.97395	validation_1-efron_likelihood:678.70721
# [15]	validation_0-efron_likelihood:3303.74530	validation_1-efron_likelihood:629.15221
# [32]	validation_0-efron_likelihood:3278.29167	validation_1-efron_likelihood:665.62257
# [18]	validation_0-efron_likelihood:3256.40253	validation_1-efron_likelihood:678.67844
# [16]	validation_0-efron_likelihood:3303.59729	validation_1-efron_likelihood:629.11300
# [33]	validation_0-efron_likelihood:3278.21289	validation_1-efron_likelihood:665.60871
# [43]	validation_0-efron_likelihood:3301.58680	validation_1-efron_likelihood:631.88305
# [19]	validation_0-efron_likelihood:3256.39685	validation_1-efron_likelihood:678.67795
# [17]	validation_0-efron_likelihood:3303.46340	validation_1-efron_likelihood:629.11366
# [34]	validation_0-efron_likelihood:3278.09175	validation_1-efron_likelihood:665.58318
# [20]	validation_0-efron_likelihood:3256.37178	validation_1-efron_likelihood:678.68240
# [44]	validation_0-efron_likelihood:3301.51109	validation_1-efron_likelihood:631.87455
# [35]	validation_0-efron_likelihood:3278.06898	validation_1-efron_likelihood:665.57688
# [18]	validation_0-efron_likelihood:3303.32387	validation_1-efron_likelihood:629.10708
# [21]	validation_0-efron_likelihood:3255.73286	validation_1-efron_likelihood:678.67648
# [19]	validation_0-efron_likelihood:3303.32387	validation_1-efron_likelihood:629.10708
# [45]	validation_0-efron_likelihood:3301.15747	validation_1-efron_likelihood:631.86180
# [36]	validation_0-efron_likelihood:3277.43963	validation_1-efron_likelihood:665.53253
# [46]	validation_0-efron_likelihood:3301.07297	validation_1-efron_likelihood:631.84308
# [22]	validation_0-efron_likelihood:3255.33000	validation_1-efron_likelihood:678.66676
# [20]	validation_0-efron_likelihood:3302.99200	validation_1-efron_likelihood:629.07153
# [23]	validation_0-efron_likelihood:3255.27466	validation_1-efron_likelihood:678.66634[47]	validation_0-efron_likelihood:3300.97986	validation_1-efron_likelihood:631.83523
#
# [37]	validation_0-efron_likelihood:3276.58551	validation_1-efron_likelihood:665.51287
# [21]	validation_0-efron_likelihood:3302.94792	validation_1-efron_likelihood:629.07480
# [24]	validation_0-efron_likelihood:3255.27466	validation_1-efron_likelihood:678.66634
# [48]	validation_0-efron_likelihood:3300.92575	validation_1-efron_likelihood:631.83712
# [25]	validation_0-efron_likelihood:3255.14576	validation_1-efron_likelihood:678.67140
# [22]	validation_0-efron_likelihood:3302.12259	validation_1-efron_likelihood:629.03602
# [49]	validation_0-efron_likelihood:3300.81478	validation_1-efron_likelihood:631.82656
# [38]	validation_0-efron_likelihood:3276.56972	validation_1-efron_likelihood:665.50841
# [23]	validation_0-efron_likelihood:3301.93822	validation_1-efron_likelihood:629.01198
# [50]	validation_0-efron_likelihood:3300.75974	validation_1-efron_likelihood:631.81612
# [39]	validation_0-efron_likelihood:3276.36234	validation_1-efron_likelihood:665.46458
# [26]	validation_0-efron_likelihood:3255.08439	validation_1-efron_likelihood:678.67978
# [24]	validation_0-efron_likelihood:3301.64074	validation_1-efron_likelihood:629.02117
# [25]	validation_0-efron_likelihood:3301.61488	validation_1-efron_likelihood:629.01968
# [27]	validation_0-efron_likelihood:3255.04590	validation_1-efron_likelihood:678.67408
# [40]	validation_0-efron_likelihood:3276.08810	validation_1-efron_likelihood:665.45799
# [51]	validation_0-efron_likelihood:3300.60042	validation_1-efron_likelihood:631.82550
# [28]	validation_0-efron_likelihood:3254.93743	validation_1-efron_likelihood:678.67965
# [41]	validation_0-efron_likelihood:3275.45238	validation_1-efron_likelihood:665.43139
# [26]	validation_0-efron_likelihood:3300.66805	validation_1-efron_likelihood:628.99316
# [29]	validation_0-efron_likelihood:3254.93521	validation_1-efron_likelihood:678.67840
# [42]	validation_0-efron_likelihood:3275.42819	validation_1-efron_likelihood:665.42317
# [27]	validation_0-efron_likelihood:3300.63575	validation_1-efron_likelihood:628.99198
# [52]	validation_0-efron_likelihood:3300.59083	validation_1-efron_likelihood:631.82541
# [30]	validation_0-efron_likelihood:3254.92426	validation_1-efron_likelihood:678.67904
# [43]	validation_0-efron_likelihood:3275.42555	validation_1-efron_likelihood:665.42285
# [28]	validation_0-efron_likelihood:3300.59672	validation_1-efron_likelihood:628.98955
# [31]	validation_0-efron_likelihood:3254.88161	validation_1-efron_likelihood:678.67635
# [44]	validation_0-efron_likelihood:3275.34905	validation_1-efron_likelihood:665.41735
# [29]	validation_0-efron_likelihood:3300.54438	validation_1-efron_likelihood:628.98319
# [32]	validation_0-efron_likelihood:3254.48884	validation_1-efron_likelihood:678.69479
# [53]	validation_0-efron_likelihood:3300.48717	validation_1-efron_likelihood:631.81076
# [45]	validation_0-efron_likelihood:3274.96471	validation_1-efron_likelihood:665.40016
# [30]	validation_0-efron_likelihood:3300.48196	validation_1-efron_likelihood:628.97906
# [46]	validation_0-efron_likelihood:3274.87604	validation_1-efron_likelihood:665.37573
# [54]	validation_0-efron_likelihood:3300.21253	validation_1-efron_likelihood:631.76571
# [31]	validation_0-efron_likelihood:3300.28954	validation_1-efron_likelihood:628.94568
# [47]	validation_0-efron_likelihood:3274.75352	validation_1-efron_likelihood:665.37428
# [55]	validation_0-efron_likelihood:3299.68494	validation_1-efron_likelihood:631.74013
# [48]	validation_0-efron_likelihood:3274.69525	validation_1-efron_likelihood:665.37067
# [49]	validation_0-efron_likelihood:3274.55591	validation_1-efron_likelihood:665.35773
# [32]	validation_0-efron_likelihood:3299.30295	validation_1-efron_likelihood:628.88571
# [56]	validation_0-efron_likelihood:3299.13236	validation_1-efron_likelihood:631.77622
# [50]	validation_0-efron_likelihood:3274.50828	validation_1-efron_likelihood:665.34797
# [33]	validation_0-efron_likelihood:3299.29607	validation_1-efron_likelihood:628.88280
# [34]	validation_0-efron_likelihood:3299.10925	validation_1-efron_likelihood:628.88138
# [57]	validation_0-efron_likelihood:3298.18395	validation_1-efron_likelihood:631.72353
# [51]	validation_0-efron_likelihood:3274.38621	validation_1-efron_likelihood:665.33555
# [52]	validation_0-efron_likelihood:3274.37904	validation_1-efron_likelihood:665.33821
# [35]	validation_0-efron_likelihood:3298.17557	validation_1-efron_likelihood:628.82913
# [58]	validation_0-efron_likelihood:3298.04454	validation_1-efron_likelihood:631.71841
# [53]	validation_0-efron_likelihood:3274.27010	validation_1-efron_likelihood:665.31426
# [36]	validation_0-efron_likelihood:3298.12231	validation_1-efron_likelihood:628.82482
# [54]	validation_0-efron_likelihood:3273.95210	validation_1-efron_likelihood:665.29566
# [37]	validation_0-efron_likelihood:3297.55521	validation_1-efron_likelihood:628.77684
# [55]	validation_0-efron_likelihood:3273.34595	validation_1-efron_likelihood:665.28536
# [38]	validation_0-efron_likelihood:3297.28433	validation_1-efron_likelihood:628.73578
# [56]	validation_0-efron_likelihood:3272.81994	validation_1-efron_likelihood:665.26577
# [59]	validation_0-efron_likelihood:3297.83474	validation_1-efron_likelihood:631.70620
# [39]	validation_0-efron_likelihood:3297.28433	validation_1-efron_likelihood:628.73578
# [40]	validation_0-efron_likelihood:3297.25760	validation_1-efron_likelihood:628.73692
# [60]	validation_0-efron_likelihood:3297.80880	validation_1-efron_likelihood:631.69927
# [57]	validation_0-efron_likelihood:3271.85644	validation_1-efron_likelihood:665.25225
# [61]	validation_0-efron_likelihood:3297.67751	validation_1-efron_likelihood:631.68946
# [58]	validation_0-efron_likelihood:3271.75775	validation_1-efron_likelihood:665.24131
# [41]	validation_0-efron_likelihood:3296.24002	validation_1-efron_likelihood:628.72023
# [62]	validation_0-efron_likelihood:3297.54598	validation_1-efron_likelihood:631.67345
# [59]	validation_0-efron_likelihood:3271.48222	validation_1-efron_likelihood:665.20223
# [63]	validation_0-efron_likelihood:3297.11814	validation_1-efron_likelihood:631.66190
# [60]	validation_0-efron_likelihood:3271.46490	validation_1-efron_likelihood:665.19718
# [64]	validation_0-efron_likelihood:3297.07184	validation_1-efron_likelihood:631.65234
# [61]	validation_0-efron_likelihood:3271.28592	validation_1-efron_likelihood:665.18512
# [42]	validation_0-efron_likelihood:3296.21489	validation_1-efron_likelihood:628.71223
# [65]	validation_0-efron_likelihood:3297.03435	validation_1-efron_likelihood:631.64501
# [62]	validation_0-efron_likelihood:3271.13434	validation_1-efron_likelihood:665.17074
# [43]	validation_0-efron_likelihood:3296.03902	validation_1-efron_likelihood:628.66969
# [63]	validation_0-efron_likelihood:3270.66768	validation_1-efron_likelihood:665.13967
# [44]	validation_0-efron_likelihood:3296.03901	validation_1-efron_likelihood:628.66969
# [64]	validation_0-efron_likelihood:3270.61607	validation_1-efron_likelihood:665.13982
# [66]	validation_0-efron_likelihood:3296.61493	validation_1-efron_likelihood:631.64803
# [45]	validation_0-efron_likelihood:3295.89858	validation_1-efron_likelihood:628.66509
# [65]	validation_0-efron_likelihood:3270.58870	validation_1-efron_likelihood:665.13683
# [46]	validation_0-efron_likelihood:3295.81388	validation_1-efron_likelihood:628.66593
# [66]	validation_0-efron_likelihood:3270.20901	validation_1-efron_likelihood:665.10716
# [0]	validation_0-efron_likelihood:3252.23403	validation_1-efron_likelihood:658.79389
# [47]	validation_0-efron_likelihood:3295.76859	validation_1-efron_likelihood:628.66333
# [67]	validation_0-efron_likelihood:3295.69531	validation_1-efron_likelihood:631.62497
# [48]	validation_0-efron_likelihood:3295.66495	validation_1-efron_likelihood:628.62944
# [1]	validation_0-efron_likelihood:3252.18594	validation_1-efron_likelihood:658.78430
# [67]	validation_0-efron_likelihood:3269.32371	validation_1-efron_likelihood:665.11736
# [68]	validation_0-efron_likelihood:3295.68388	validation_1-efron_likelihood:631.62576
# [49]	validation_0-efron_likelihood:3295.61992	validation_1-efron_likelihood:628.62967
# [2]	validation_0-efron_likelihood:3251.75719	validation_1-efron_likelihood:658.76901
# [68]	validation_0-efron_likelihood:3269.31443	validation_1-efron_likelihood:665.11960
# [50]	validation_0-efron_likelihood:3295.61882	validation_1-efron_likelihood:628.62877
# [69]	validation_0-efron_likelihood:3295.51429	validation_1-efron_likelihood:631.60033
# [3]	validation_0-efron_likelihood:3251.72776	validation_1-efron_likelihood:658.76737
# [69]	validation_0-efron_likelihood:3269.15782	validation_1-efron_likelihood:665.08088
# [70]	validation_0-efron_likelihood:3295.41490	validation_1-efron_likelihood:631.58022
# [70]	validation_0-efron_likelihood:3269.06067	validation_1-efron_likelihood:665.06858
# [4]	validation_0-efron_likelihood:3251.33550	validation_1-efron_likelihood:658.75394
# [51]	validation_0-efron_likelihood:3294.80372	validation_1-efron_likelihood:628.62895
# [71]	validation_0-efron_likelihood:3268.94137	validation_1-efron_likelihood:665.05282
# [5]	validation_0-efron_likelihood:3251.23405	validation_1-efron_likelihood:658.73296
# [52]	validation_0-efron_likelihood:3294.43385	validation_1-efron_likelihood:628.61171
# [72]	validation_0-efron_likelihood:3268.77893	validation_1-efron_likelihood:665.03223
# [71]	validation_0-efron_likelihood:3295.30135	validation_1-efron_likelihood:631.55533
# [6]	validation_0-efron_likelihood:3250.94105	validation_1-efron_likelihood:658.74431
# [53]	validation_0-efron_likelihood:3294.37448	validation_1-efron_likelihood:628.60320
# [73]	validation_0-efron_likelihood:3268.24111	validation_1-efron_likelihood:664.98208
# [7]	validation_0-efron_likelihood:3250.91530	validation_1-efron_likelihood:658.74173
# [54]	validation_0-efron_likelihood:3294.10813	validation_1-efron_likelihood:628.57444
# [8]	validation_0-efron_likelihood:3250.77130	validation_1-efron_likelihood:658.73282
# [55]	validation_0-efron_likelihood:3293.86659	validation_1-efron_likelihood:628.53924
# [72]	validation_0-efron_likelihood:3295.12430	validation_1-efron_likelihood:631.52792
# [0]	validation_0-efron_likelihood:3258.18517	validation_1-efron_likelihood:679.25003
# [9]	validation_0-efron_likelihood:3249.80660	validation_1-efron_likelihood:658.66757
# [10]	validation_0-efron_likelihood:3249.32150	validation_1-efron_likelihood:658.65549
# [1]	validation_0-efron_likelihood:3256.91627	validation_1-efron_likelihood:679.27614
# [73]	validation_0-efron_likelihood:3294.61950	validation_1-efron_likelihood:631.49944
# [11]	validation_0-efron_likelihood:3249.26784	validation_1-efron_likelihood:658.65746
# [56]	validation_0-efron_likelihood:3292.92999	validation_1-efron_likelihood:628.46238
# [12]	validation_0-efron_likelihood:3248.83936	validation_1-efron_likelihood:658.62183
# [2]	validation_0-efron_likelihood:3253.30016	validation_1-efron_likelihood:679.57271
# [57]	validation_0-efron_likelihood:3292.90330	validation_1-efron_likelihood:628.45331
# [13]	validation_0-efron_likelihood:3248.81739	validation_1-efron_likelihood:658.62089
# [3]	validation_0-efron_likelihood:3250.07278	validation_1-efron_likelihood:679.76585
# [58]	validation_0-efron_likelihood:3292.89655	validation_1-efron_likelihood:628.45041
# [59]	validation_0-efron_likelihood:3292.81423	validation_1-efron_likelihood:628.43944
# [4]	validation_0-efron_likelihood:3245.90819	validation_1-efron_likelihood:678.81040
# [14]	validation_0-efron_likelihood:3247.85110	validation_1-efron_likelihood:658.59533
# [60]	validation_0-efron_likelihood:3292.74817	validation_1-efron_likelihood:628.43667
# [15]	validation_0-efron_likelihood:3247.84771	validation_1-efron_likelihood:658.59458
# [5]	validation_0-efron_likelihood:3243.91259	validation_1-efron_likelihood:678.82153
# [16]	validation_0-efron_likelihood:3247.68726	validation_1-efron_likelihood:658.58387[61]	validation_0-efron_likelihood:3292.67250	validation_1-efron_likelihood:628.43272
#
# [62]	validation_0-efron_likelihood:3292.67250	validation_1-efron_likelihood:628.43272
# [17]	validation_0-efron_likelihood:3247.59043	validation_1-efron_likelihood:658.58412
# [63]	validation_0-efron_likelihood:3292.51811	validation_1-efron_likelihood:628.43547
# [18]	validation_0-efron_likelihood:3247.44596	validation_1-efron_likelihood:658.58401
# [19]	validation_0-efron_likelihood:3247.44162	validation_1-efron_likelihood:658.58403
# [64]	validation_0-efron_likelihood:3292.45554	validation_1-efron_likelihood:628.43573
# [20]	validation_0-efron_likelihood:3247.07037	validation_1-efron_likelihood:658.56442
# [65]	validation_0-efron_likelihood:3292.03113	validation_1-efron_likelihood:628.42135
# [0]	validation_0-efron_likelihood:3250.23265	validation_1-efron_likelihood:658.60394
# [21]	validation_0-efron_likelihood:3247.00959	validation_1-efron_likelihood:658.56492
# [66]	validation_0-efron_likelihood:3291.97962	validation_1-efron_likelihood:628.42024
# [22]	validation_0-efron_likelihood:3246.18219	validation_1-efron_likelihood:658.55278
# [1]	validation_0-efron_likelihood:3245.59432	validation_1-efron_likelihood:657.76707
# [67]	validation_0-efron_likelihood:3291.95774	validation_1-efron_likelihood:628.42211
# [23]	validation_0-efron_likelihood:3245.97735	validation_1-efron_likelihood:658.51474
# [68]	validation_0-efron_likelihood:3291.82829	validation_1-efron_likelihood:628.42519
# [2]	validation_0-efron_likelihood:3240.82521	validation_1-efron_likelihood:657.08526
# [24]	validation_0-efron_likelihood:3245.52256	validation_1-efron_likelihood:658.51394
# [3]	validation_0-efron_likelihood:3240.05214	validation_1-efron_likelihood:656.99235
# [69]	validation_0-efron_likelihood:3291.40831	validation_1-efron_likelihood:628.42994
# [25]	validation_0-efron_likelihood:3245.50046	validation_1-efron_likelihood:658.51305
# [70]	validation_0-efron_likelihood:3291.36351	validation_1-efron_likelihood:628.43045
# [4]	validation_0-efron_likelihood:3236.21574	validation_1-efron_likelihood:656.57120
# [71]	validation_0-efron_likelihood:3291.26696	validation_1-efron_likelihood:628.40627
# [26]	validation_0-efron_likelihood:3244.63993	validation_1-efron_likelihood:658.51440
# [27]	validation_0-efron_likelihood:3244.60175	validation_1-efron_likelihood:658.51714[5]	validation_0-efron_likelihood:3232.14319	validation_1-efron_likelihood:655.41963
#
# [72]	validation_0-efron_likelihood:3290.88416	validation_1-efron_likelihood:628.42546
# [28]	validation_0-efron_likelihood:3244.56952	validation_1-efron_likelihood:658.51870
# [73]	validation_0-efron_likelihood:3290.84632	validation_1-efron_likelihood:628.41432
# [29]	validation_0-efron_likelihood:3244.52187	validation_1-efron_likelihood:658.51695
# [30]	validation_0-efron_likelihood:3244.44458	validation_1-efron_likelihood:658.51052
# [31]	validation_0-efron_likelihood:3244.23266	validation_1-efron_likelihood:658.48733
# [32]	validation_0-efron_likelihood:3243.20831	validation_1-efron_likelihood:658.44220
# [33]	validation_0-efron_likelihood:3243.19904	validation_1-efron_likelihood:658.44283
# [34]	validation_0-efron_likelihood:3243.00995	validation_1-efron_likelihood:658.42412
# [35]	validation_0-efron_likelihood:3242.06320	validation_1-efron_likelihood:658.40645
# [36]	validation_0-efron_likelihood:3242.03035	validation_1-efron_likelihood:658.41245
# [37]	validation_0-efron_likelihood:3241.61126	validation_1-efron_likelihood:658.39930
# [38]	validation_0-efron_likelihood:3241.25025	validation_1-efron_likelihood:658.37094
# [39]	validation_0-efron_likelihood:3241.24683	validation_1-efron_likelihood:658.37018
# [40]	validation_0-efron_likelihood:3241.21224	validation_1-efron_likelihood:658.36870
# [41]	validation_0-efron_likelihood:3240.22893	validation_1-efron_likelihood:658.36366
# [42]	validation_0-efron_likelihood:3240.18309	validation_1-efron_likelihood:658.36408
# [43]	validation_0-efron_likelihood:3239.97668	validation_1-efron_likelihood:658.34017
# [44]	validation_0-efron_likelihood:3239.97284	validation_1-efron_likelihood:658.34025
# [45]	validation_0-efron_likelihood:3239.89006	validation_1-efron_likelihood:658.34191
# [46]	validation_0-efron_likelihood:3239.76530	validation_1-efron_likelihood:658.34112
# [47]	validation_0-efron_likelihood:3239.72252	validation_1-efron_likelihood:658.33876
# [48]	validation_0-efron_likelihood:3239.62883	validation_1-efron_likelihood:658.32186
# [49]	validation_0-efron_likelihood:3239.56908	validation_1-efron_likelihood:658.31732
# [50]	validation_0-efron_likelihood:3239.56598	validation_1-efron_likelihood:658.31662
# [51]	validation_0-efron_likelihood:3238.85318	validation_1-efron_likelihood:658.28607
# [52]	validation_0-efron_likelihood:3238.45955	validation_1-efron_likelihood:658.25859
# [53]	validation_0-efron_likelihood:3238.38996	validation_1-efron_likelihood:658.25259
# [54]	validation_0-efron_likelihood:3238.11502	validation_1-efron_likelihood:658.23619
# [55]	validation_0-efron_likelihood:3237.88904	validation_1-efron_likelihood:658.23469
# [56]	validation_0-efron_likelihood:3236.90837	validation_1-efron_likelihood:658.18892
# [57]	validation_0-efron_likelihood:3236.86544	validation_1-efron_likelihood:658.18244
# [58]	validation_0-efron_likelihood:3236.85691	validation_1-efron_likelihood:658.18310
# [59]	validation_0-efron_likelihood:3236.72936	validation_1-efron_likelihood:658.18518
# [60]	validation_0-efron_likelihood:3236.65452	validation_1-efron_likelihood:658.18252
# [61]	validation_0-efron_likelihood:3236.57792	validation_1-efron_likelihood:658.19135
# [62]	validation_0-efron_likelihood:3236.57380	validation_1-efron_likelihood:658.19145
# [63]	validation_0-efron_likelihood:3236.43216	validation_1-efron_likelihood:658.19321
# [64]	validation_0-efron_likelihood:3236.33879	validation_1-efron_likelihood:658.19588
# [65]	validation_0-efron_likelihood:3235.94092	validation_1-efron_likelihood:658.20194
# [66]	validation_0-efron_likelihood:3235.85194	validation_1-efron_likelihood:658.19795
# [0]	validation_0-efron_likelihood:3307.87494	validation_1-efron_likelihood:632.22550
# [1]	validation_0-efron_likelihood:3305.77639	validation_1-efron_likelihood:631.58623
# [2]	validation_0-efron_likelihood:3303.17169	validation_1-efron_likelihood:631.02723
# [3]	validation_0-efron_likelihood:3302.04256	validation_1-efron_likelihood:631.12435
# [4]	validation_0-efron_likelihood:3298.65921	validation_1-efron_likelihood:630.24054
# [5]	validation_0-efron_likelihood:3296.60045	validation_1-efron_likelihood:629.95398
# [0]	validation_0-efron_likelihood:4245.22557	validation_1-efron_likelihood:896.96819
# [1]	validation_0-efron_likelihood:4243.47424	validation_1-efron_likelihood:896.64370
# [2]	validation_0-efron_likelihood:4239.14196	validation_1-efron_likelihood:895.00661
# [3]	validation_0-efron_likelihood:4232.96088	validation_1-efron_likelihood:894.16429
# [4]	validation_0-efron_likelihood:4228.74690	validation_1-efron_likelihood:893.64996
# [5]	validation_0-efron_likelihood:4226.65041	validation_1-efron_likelihood:892.85082
# Concordance Index 0.6086943485984554
# Integrated Brier Score: 0.17029565421191736
# durations 0.76666665 337.03333
# Concordance Index 0.5686480695210507
# Integrated Brier Score: 0.18321345899488384
# (1522, 9) <class 'pandas.core.frame.DataFrame'>
# (1522,) <class 'pandas.core.series.Series'>
# (381, 9) <class 'pandas.core.frame.DataFrame'>
# (381,) <class 'pandas.core.series.Series'>
# [0]	validation_0-efron_likelihood:3374.43211	validation_1-efron_likelihood:613.27048
# [1]	validation_0-efron_likelihood:3373.38814	validation_1-efron_likelihood:613.06731
# [2]	validation_0-efron_likelihood:3371.49413	validation_1-efron_likelihood:612.64704
# [3]	validation_0-efron_likelihood:3370.76671	validation_1-efron_likelihood:612.59857
# [0]	validation_0-efron_likelihood:3311.22617	validation_1-efron_likelihood:650.26886
# [4]	validation_0-efron_likelihood:3369.42577	validation_1-efron_likelihood:612.34979
# [1]	validation_0-efron_likelihood:3309.91472	validation_1-efron_likelihood:650.02016
# [5]	validation_0-efron_likelihood:3367.82357	validation_1-efron_likelihood:612.18034
# [2]	validation_0-efron_likelihood:3308.42066	validation_1-efron_likelihood:649.84057
# [6]	validation_0-efron_likelihood:3366.82550	validation_1-efron_likelihood:612.28975
# [3]	validation_0-efron_likelihood:3307.54502	validation_1-efron_likelihood:649.75224
# [7]	validation_0-efron_likelihood:3364.90382	validation_1-efron_likelihood:611.96187
# [4]	validation_0-efron_likelihood:3306.45702	validation_1-efron_likelihood:649.60452
# [8]	validation_0-efron_likelihood:3363.51985	validation_1-efron_likelihood:611.67059
# [0]	validation_0-efron_likelihood:3311.92241	validation_1-efron_likelihood:642.17691
# [5]	validation_0-efron_likelihood:3305.30505	validation_1-efron_likelihood:649.38697
# [9]	validation_0-efron_likelihood:3362.56824	validation_1-efron_likelihood:611.57298
# [1]	validation_0-efron_likelihood:3311.00581	validation_1-efron_likelihood:641.88011
# [6]	validation_0-efron_likelihood:3304.17581	validation_1-efron_likelihood:649.18228
# [2]	validation_0-efron_likelihood:3310.85170	validation_1-efron_likelihood:641.84001
# [10]	validation_0-efron_likelihood:3361.39370	validation_1-efron_likelihood:611.48552
# [7]	validation_0-efron_likelihood:3302.11626	validation_1-efron_likelihood:648.94927
# [0]	validation_0-efron_likelihood:3329.46586	validation_1-efron_likelihood:623.11446[11]	validation_0-efron_likelihood:3359.97588	validation_1-efron_likelihood:611.28443
#
# [3]	validation_0-efron_likelihood:3309.92378	validation_1-efron_likelihood:641.90347
# [8]	validation_0-efron_likelihood:3300.12600	validation_1-efron_likelihood:648.77913
# [4]	validation_0-efron_likelihood:3309.76777	validation_1-efron_likelihood:641.93001
# [1]	validation_0-efron_likelihood:3328.38161	validation_1-efron_likelihood:622.98279
# [12]	validation_0-efron_likelihood:3358.48865	validation_1-efron_likelihood:611.22667
# [9]	validation_0-efron_likelihood:3298.84830	validation_1-efron_likelihood:648.64315
# [2]	validation_0-efron_likelihood:3326.79301	validation_1-efron_likelihood:622.70246
# [5]	validation_0-efron_likelihood:3308.53584	validation_1-efron_likelihood:641.82808
# [13]	validation_0-efron_likelihood:3357.56738	validation_1-efron_likelihood:611.25285
# [10]	validation_0-efron_likelihood:3297.36033	validation_1-efron_likelihood:648.54073[0]	validation_0-efron_likelihood:3343.19049	validation_1-efron_likelihood:633.39190
#
# [3]	validation_0-efron_likelihood:3325.88430	validation_1-efron_likelihood:622.60473
# [6]	validation_0-efron_likelihood:3307.66219	validation_1-efron_likelihood:641.79164
# [11]	validation_0-efron_likelihood:3296.48472	validation_1-efron_likelihood:648.47440
# [14]	validation_0-efron_likelihood:3356.14372	validation_1-efron_likelihood:610.90452
# [4]	validation_0-efron_likelihood:3325.10026	validation_1-efron_likelihood:622.53012
# [7]	validation_0-efron_likelihood:3306.20365	validation_1-efron_likelihood:641.63847
# [1]	validation_0-efron_likelihood:3342.70108	validation_1-efron_likelihood:633.37843
# [12]	validation_0-efron_likelihood:3295.16419	validation_1-efron_likelihood:648.31443
# [5]	validation_0-efron_likelihood:3324.21582	validation_1-efron_likelihood:622.45089
# [8]	validation_0-efron_likelihood:3305.08355	validation_1-efron_likelihood:641.49672
# [13]	validation_0-efron_likelihood:3293.74420	validation_1-efron_likelihood:648.13738
# [0]	validation_0-efron_likelihood:3374.74918	validation_1-efron_likelihood:613.35070
# [6]	validation_0-efron_likelihood:3323.26644	validation_1-efron_likelihood:622.44696
# [15]	validation_0-efron_likelihood:3355.08070	validation_1-efron_likelihood:610.62731
# [2]	validation_0-efron_likelihood:3342.12628	validation_1-efron_likelihood:633.32785
# [9]	validation_0-efron_likelihood:3304.07138	validation_1-efron_likelihood:641.31854
# [14]	validation_0-efron_likelihood:3292.83088	validation_1-efron_likelihood:648.08265
# [7]	validation_0-efron_likelihood:3322.11570	validation_1-efron_likelihood:622.17204
# [10]	validation_0-efron_likelihood:3302.54312	validation_1-efron_likelihood:641.51328
# [1]	validation_0-efron_likelihood:3374.16051	validation_1-efron_likelihood:613.33002
# [15]	validation_0-efron_likelihood:3291.68833	validation_1-efron_likelihood:647.91896
# [8]	validation_0-efron_likelihood:3320.86972	validation_1-efron_likelihood:621.92744
# [16]	validation_0-efron_likelihood:3353.79603	validation_1-efron_likelihood:610.41390
# [3]	validation_0-efron_likelihood:3341.81882	validation_1-efron_likelihood:633.31705
# [11]	validation_0-efron_likelihood:3302.02230	validation_1-efron_likelihood:641.41441
# [16]	validation_0-efron_likelihood:3289.85310	validation_1-efron_likelihood:647.87478
# [9]	validation_0-efron_likelihood:3319.85986	validation_1-efron_likelihood:621.84018
# [17]	validation_0-efron_likelihood:3352.75579	validation_1-efron_likelihood:610.27827
# [2]	validation_0-efron_likelihood:3373.56010	validation_1-efron_likelihood:613.32280
# [12]	validation_0-efron_likelihood:3300.98434	validation_1-efron_likelihood:641.33038
# [10]	validation_0-efron_likelihood:3319.05711	validation_1-efron_likelihood:621.68530
# [13]	validation_0-efron_likelihood:3299.98170	validation_1-efron_likelihood:641.20828
# [18]	validation_0-efron_likelihood:3351.57438	validation_1-efron_likelihood:610.05825
# [0]	validation_0-efron_likelihood:3311.65161	validation_1-efron_likelihood:650.30773
# [17]	validation_0-efron_likelihood:3288.97473	validation_1-efron_likelihood:647.84944
# [4]	validation_0-efron_likelihood:3341.25582	validation_1-efron_likelihood:633.29102
# [3]	validation_0-efron_likelihood:3373.27408	validation_1-efron_likelihood:613.33231
# [11]	validation_0-efron_likelihood:3318.47864	validation_1-efron_likelihood:621.72821
# [19]	validation_0-efron_likelihood:3349.85710	validation_1-efron_likelihood:609.76850
# [14]	validation_0-efron_likelihood:3299.31811	validation_1-efron_likelihood:641.18773
# [18]	validation_0-efron_likelihood:3287.83049	validation_1-efron_likelihood:647.79555
# [1]	validation_0-efron_likelihood:3311.27094	validation_1-efron_likelihood:650.25299
# [12]	validation_0-efron_likelihood:3317.53434	validation_1-efron_likelihood:621.58400
# [15]	validation_0-efron_likelihood:3298.33495	validation_1-efron_likelihood:641.00926
# [5]	validation_0-efron_likelihood:3340.60871	validation_1-efron_likelihood:633.28165
# [19]	validation_0-efron_likelihood:3287.03175	validation_1-efron_likelihood:647.70330
# [4]	validation_0-efron_likelihood:3372.69100	validation_1-efron_likelihood:613.30747
# [13]	validation_0-efron_likelihood:3316.98108	validation_1-efron_likelihood:621.37339
# [6]	validation_0-efron_likelihood:3340.47110	validation_1-efron_likelihood:633.27217
# [16]	validation_0-efron_likelihood:3297.38142	validation_1-efron_likelihood:640.76400
# [2]	validation_0-efron_likelihood:3310.76500	validation_1-efron_likelihood:650.23624
# [14]	validation_0-efron_likelihood:3315.96445	validation_1-efron_likelihood:621.26960
# [0]	validation_0-efron_likelihood:3312.36655	validation_1-efron_likelihood:642.23365
# [17]	validation_0-efron_likelihood:3296.91810	validation_1-efron_likelihood:640.71687
# [5]	validation_0-efron_likelihood:3372.15904	validation_1-efron_likelihood:613.28643
# [15]	validation_0-efron_likelihood:3314.87409	validation_1-efron_likelihood:621.11992
# [3]	validation_0-efron_likelihood:3310.49561	validation_1-efron_likelihood:650.23179
# [18]	validation_0-efron_likelihood:3296.42480	validation_1-efron_likelihood:640.74099
# [1]	validation_0-efron_likelihood:3312.10593	validation_1-efron_likelihood:642.22280
# [6]	validation_0-efron_likelihood:3371.99687	validation_1-efron_likelihood:613.28687
# [16]	validation_0-efron_likelihood:3314.18684	validation_1-efron_likelihood:621.04906
# [19]	validation_0-efron_likelihood:3295.95030	validation_1-efron_likelihood:640.73125
# [2]	validation_0-efron_likelihood:3311.54358	validation_1-efron_likelihood:642.18371
# [4]	validation_0-efron_likelihood:3309.87916	validation_1-efron_likelihood:650.18055
# [17]	validation_0-efron_likelihood:3313.16974	validation_1-efron_likelihood:620.91009
# [18]	validation_0-efron_likelihood:3312.48770	validation_1-efron_likelihood:620.77338
# [3]	validation_0-efron_likelihood:3311.13848	validation_1-efron_likelihood:642.18718
# [5]	validation_0-efron_likelihood:3309.38432	validation_1-efron_likelihood:650.17965
# [19]	validation_0-efron_likelihood:3311.77758	validation_1-efron_likelihood:620.72043
# [4]	validation_0-efron_likelihood:3310.64415	validation_1-efron_likelihood:642.18091
# [6]	validation_0-efron_likelihood:3308.88536	validation_1-efron_likelihood:650.17965
# [5]	validation_0-efron_likelihood:3310.13526	validation_1-efron_likelihood:642.18053
# [6]	validation_0-efron_likelihood:3309.69058	validation_1-efron_likelihood:642.20074
# [0]	validation_0-efron_likelihood:3329.59720	validation_1-efron_likelihood:623.27772
# [1]	validation_0-efron_likelihood:3329.23128	validation_1-efron_likelihood:623.23602
# [2]	validation_0-efron_likelihood:3328.67370	validation_1-efron_likelihood:623.23915
# [3]	validation_0-efron_likelihood:3328.28493	validation_1-efron_likelihood:623.21722
# [4]	validation_0-efron_likelihood:3327.77023	validation_1-efron_likelihood:623.17176
# [5]	validation_0-efron_likelihood:3327.24683	validation_1-efron_likelihood:623.14531
# [6]	validation_0-efron_likelihood:3326.74532	validation_1-efron_likelihood:623.12527
# [0]	validation_0-efron_likelihood:3342.24989	validation_1-efron_likelihood:633.19506
# [1]	validation_0-efron_likelihood:3341.26732	validation_1-efron_likelihood:632.92441
# [2]	validation_0-efron_likelihood:3339.69831	validation_1-efron_likelihood:632.57617
# [3]	validation_0-efron_likelihood:3338.77505	validation_1-efron_likelihood:632.44692
# [4]	validation_0-efron_likelihood:3337.88921	validation_1-efron_likelihood:632.32121
# [5]	validation_0-efron_likelihood:3336.31231	validation_1-efron_likelihood:632.16061
# [6]	validation_0-efron_likelihood:3335.37936	validation_1-efron_likelihood:632.01598
# [7]	validation_0-efron_likelihood:3334.24777	validation_1-efron_likelihood:632.01696
# [8]	validation_0-efron_likelihood:3333.24503	validation_1-efron_likelihood:631.90628
# [9]	validation_0-efron_likelihood:3332.40487	validation_1-efron_likelihood:631.90658
# [10]	validation_0-efron_likelihood:3331.23193	validation_1-efron_likelihood:631.78575
# [11]	validation_0-efron_likelihood:3330.21089	validation_1-efron_likelihood:631.71089
# [12]	validation_0-efron_likelihood:3329.53694	validation_1-efron_likelihood:631.68918
# [13]	validation_0-efron_likelihood:3328.78249	validation_1-efron_likelihood:631.82849
# [14]	validation_0-efron_likelihood:3327.49784	validation_1-efron_likelihood:631.79616
# [15]	validation_0-efron_likelihood:3326.74309	validation_1-efron_likelihood:631.63098
# [16]	validation_0-efron_likelihood:3325.60565	validation_1-efron_likelihood:631.56258
# [17]	validation_0-efron_likelihood:3324.83578	validation_1-efron_likelihood:631.49514
# [18]	validation_0-efron_likelihood:3324.04118	validation_1-efron_likelihood:631.42985
# [19]	validation_0-efron_likelihood:3322.97495	validation_1-efron_likelihood:631.14244
# [0]	validation_0-efron_likelihood:4270.86189	validation_1-efron_likelihood:849.35777
# [1]	validation_0-efron_likelihood:4269.40057	validation_1-efron_likelihood:849.14636
# [2]	validation_0-efron_likelihood:4267.76259	validation_1-efron_likelihood:848.77019
# [3]	validation_0-efron_likelihood:4265.95141	validation_1-efron_likelihood:848.41473
# [4]	validation_0-efron_likelihood:4264.78004	validation_1-efron_likelihood:848.36647
# [5]	validation_0-efron_likelihood:4264.30838	validation_1-efron_likelihood:848.21275
# [6]	validation_0-efron_likelihood:4263.30499	validation_1-efron_likelihood:848.06295
# [7]	validation_0-efron_likelihood:4262.66474	validation_1-efron_likelihood:847.92214
# [8]	validation_0-efron_likelihood:4262.05332	validation_1-efron_likelihood:847.86635
# [9]	validation_0-efron_likelihood:4260.91779	validation_1-efron_likelihood:847.79103
# [10]	validation_0-efron_likelihood:4259.59241	validation_1-efron_likelihood:847.65986
# [11]	validation_0-efron_likelihood:4258.58062	validation_1-efron_likelihood:847.58550
# [12]	validation_0-efron_likelihood:4257.36918	validation_1-efron_likelihood:847.47594
# [13]	validation_0-efron_likelihood:4256.17596	validation_1-efron_likelihood:847.23135
# [14]	validation_0-efron_likelihood:4254.83616	validation_1-efron_likelihood:847.05527
# [15]	validation_0-efron_likelihood:4253.88553	validation_1-efron_likelihood:846.88080
# [16]	validation_0-efron_likelihood:4252.72701	validation_1-efron_likelihood:846.85463
# [17]	validation_0-efron_likelihood:4251.93822	validation_1-efron_likelihood:846.85019
# [18]	validation_0-efron_likelihood:4250.79656	validation_1-efron_likelihood:846.63924
# [19]	validation_0-efron_likelihood:4249.24614	validation_1-efron_likelihood:846.50349
# Concordance Index 0.6261532049428701
# Integrated Brier Score: 0.17243770193745228
# durations 0.1 330.36667
# Concordance Index 0.5858915612893075
# Integrated Brier Score: 0.1805453401461445
# (1522, 9) <class 'pandas.core.frame.DataFrame'>
# (1522,) <class 'pandas.core.series.Series'>
# (381, 9) <class 'pandas.core.frame.DataFrame'>
# (381,) <class 'pandas.core.series.Series'>
# [0]	validation_0-efron_likelihood:3309.88185	validation_1-efron_likelihood:626.49718
# [1]	validation_0-efron_likelihood:3304.05410	validation_1-efron_likelihood:630.06811
# [2]	validation_0-efron_likelihood:3552.72685	validation_1-efron_likelihood:755.14536
# [3]	validation_0-efron_likelihood:3562.27201	validation_1-efron_likelihood:769.64969
# [4]	validation_0-efron_likelihood:3578.89161	validation_1-efron_likelihood:772.41312
# [5]	validation_0-efron_likelihood:3420.92358	validation_1-efron_likelihood:741.29264
# [6]	validation_0-efron_likelihood:3402.38488	validation_1-efron_likelihood:746.70047
# [0]	validation_0-efron_likelihood:3297.96897	validation_1-efron_likelihood:658.58937
# [1]	validation_0-efron_likelihood:3290.60336	validation_1-efron_likelihood:661.28917
# [7]	validation_0-efron_likelihood:3411.75228	validation_1-efron_likelihood:754.12525
# [2]	validation_0-efron_likelihood:3287.17463	validation_1-efron_likelihood:683.00200
# [8]	validation_0-efron_likelihood:3377.97406	validation_1-efron_likelihood:744.93146
# [0]	validation_0-efron_likelihood:3288.67607	validation_1-efron_likelihood:668.56933
# [3]	validation_0-efron_likelihood:3279.70426	validation_1-efron_likelihood:680.75842
# [9]	validation_0-efron_likelihood:3377.97406	validation_1-efron_likelihood:744.93147
# [4]	validation_0-efron_likelihood:3279.70426	validation_1-efron_likelihood:680.75842
# [1]	validation_0-efron_likelihood:3280.15994	validation_1-efron_likelihood:668.29206
# [2]	validation_0-efron_likelihood:3273.41164	validation_1-efron_likelihood:668.73866
# [5]	validation_0-efron_likelihood:3275.04409	validation_1-efron_likelihood:688.90363
# [3]	validation_0-efron_likelihood:3265.76074	validation_1-efron_likelihood:671.64190
# [6]	validation_0-efron_likelihood:3268.83816	validation_1-efron_likelihood:685.97418
# [7]	validation_0-efron_likelihood:3266.16106	validation_1-efron_likelihood:684.91472
# [4]	validation_0-efron_likelihood:3254.08269	validation_1-efron_likelihood:678.63496
# [5]	validation_0-efron_likelihood:3254.08269	validation_1-efron_likelihood:678.63496
# [8]	validation_0-efron_likelihood:3242.96004	validation_1-efron_likelihood:684.34831
# [9]	validation_0-efron_likelihood:3243.20933	validation_1-efron_likelihood:684.74805
# [6]	validation_0-efron_likelihood:3231.58741	validation_1-efron_likelihood:677.37442
# [7]	validation_0-efron_likelihood:3230.53460	validation_1-efron_likelihood:702.27731
# [8]	validation_0-efron_likelihood:3230.53461	validation_1-efron_likelihood:702.27731
# [9]	validation_0-efron_likelihood:3230.53461	validation_1-efron_likelihood:702.27731
# [10]	validation_0-efron_likelihood:3218.15362	validation_1-efron_likelihood:710.32134
# [0]	validation_0-efron_likelihood:3340.67731	validation_1-efron_likelihood:605.20780
# [1]	validation_0-efron_likelihood:3348.90963	validation_1-efron_likelihood:604.73732
# [2]	validation_0-efron_likelihood:3347.60831	validation_1-efron_likelihood:607.38173
# [3]	validation_0-efron_likelihood:3339.49533	validation_1-efron_likelihood:606.69368
# [0]	validation_0-efron_likelihood:3307.05962	validation_1-efron_likelihood:637.04466
# ...
# [33]	validation_0-efron_likelihood:22915.46794	validation_1-efron_likelihood:4588.85197
# [31]	validation_0-efron_likelihood:22741.48273	validation_1-efron_likelihood:4739.46385
# [29]	validation_0-efron_likelihood:22723.69314	validation_1-efron_likelihood:4764.39259
# [30]	validation_0-efron_likelihood:22772.74415	validation_1-efron_likelihood:4692.10199
# [37]	validation_0-efron_likelihood:22780.63729	validation_1-efron_likelihood:4679.84795
# [30]	validation_0-efron_likelihood:22721.82066	validation_1-efron_likelihood:4764.11245
# [34]	validation_0-efron_likelihood:22913.74830	validation_1-efron_likelihood:4588.46245
# [31]	validation_0-efron_likelihood:22771.30046	validation_1-efron_likelihood:4691.75311
# [32]	validation_0-efron_likelihood:22739.31157	validation_1-efron_likelihood:4739.32131
# [38]	validation_0-efron_likelihood:22777.06431	validation_1-efron_likelihood:4679.54875
# [31]	validation_0-efron_likelihood:22719.53994	validation_1-efron_likelihood:4763.70624
# [32]	validation_0-efron_likelihood:22768.68977	validation_1-efron_likelihood:4691.03556
# [35]	validation_0-efron_likelihood:22911.30539	validation_1-efron_likelihood:4587.98106
# [33]	validation_0-efron_likelihood:22737.20321	validation_1-efron_likelihood:4739.17736
# [39]	validation_0-efron_likelihood:22773.45336	validation_1-efron_likelihood:4679.10583
# [32]	validation_0-efron_likelihood:22716.41845	validation_1-efron_likelihood:4763.19631
# [33]	validation_0-efron_likelihood:22764.75221	validation_1-efron_likelihood:4690.75469
# [36]	validation_0-efron_likelihood:22908.56501	validation_1-efron_likelihood:4587.63685
# [34]	validation_0-efron_likelihood:22735.20231	validation_1-efron_likelihood:4738.98244
# [40]	validation_0-efron_likelihood:22771.23423	validation_1-efron_likelihood:4679.49276
# [33]	validation_0-efron_likelihood:22714.68666	validation_1-efron_likelihood:4762.79079
# [34]	validation_0-efron_likelihood:22763.41534	validation_1-efron_likelihood:4690.41998
# [37]	validation_0-efron_likelihood:22906.61099	validation_1-efron_likelihood:4587.46144
# [35]	validation_0-efron_likelihood:22732.95423	validation_1-efron_likelihood:4738.64241
# [41]	validation_0-efron_likelihood:22769.90928	validation_1-efron_likelihood:4679.48364
# [34]	validation_0-efron_likelihood:22710.19308	validation_1-efron_likelihood:4762.13575
# [35]	validation_0-efron_likelihood:22761.65520	validation_1-efron_likelihood:4690.29007
# [38]	validation_0-efron_likelihood:22903.59714	validation_1-efron_likelihood:4586.98723
# [36]	validation_0-efron_likelihood:22730.22713	validation_1-efron_likelihood:4738.06631
# [42]	validation_0-efron_likelihood:22767.76788	validation_1-efron_likelihood:4679.90277
# [35]	validation_0-efron_likelihood:22707.79126	validation_1-efron_likelihood:4761.73245
# [36]	validation_0-efron_likelihood:22759.03426	validation_1-efron_likelihood:4689.75749
# [39]	validation_0-efron_likelihood:22900.31234	validation_1-efron_likelihood:4587.08934
# [37]	validation_0-efron_likelihood:22727.07929	validation_1-efron_likelihood:4737.97748
# [43]	validation_0-efron_likelihood:22767.03929	validation_1-efron_likelihood:4680.08289
# [36]	validation_0-efron_likelihood:22704.11380	validation_1-efron_likelihood:4762.22933
# [37]	validation_0-efron_likelihood:22756.73429	validation_1-efron_likelihood:4689.84472
# [40]	validation_0-efron_likelihood:22898.95470	validation_1-efron_likelihood:4587.16601
# [38]	validation_0-efron_likelihood:22724.60482	validation_1-efron_likelihood:4737.59663
# [44]	validation_0-efron_likelihood:22763.97332	validation_1-efron_likelihood:4680.18734
# [37]	validation_0-efron_likelihood:22701.71137	validation_1-efron_likelihood:4761.49294
# [38]	validation_0-efron_likelihood:22755.42201	validation_1-efron_likelihood:4689.62332
# [41]	validation_0-efron_likelihood:22896.72476	validation_1-efron_likelihood:4586.73693
# [39]	validation_0-efron_likelihood:22722.47511	validation_1-efron_likelihood:4737.56061
# [45]	validation_0-efron_likelihood:22761.88278	validation_1-efron_likelihood:4679.87172
# [38]	validation_0-efron_likelihood:22699.73813	validation_1-efron_likelihood:4761.17001
# [39]	validation_0-efron_likelihood:22754.39155	validation_1-efron_likelihood:4689.72879
# [42]	validation_0-efron_likelihood:22894.72661	validation_1-efron_likelihood:4586.31073
# [40]	validation_0-efron_likelihood:22720.76009	validation_1-efron_likelihood:4737.34264
# [46]	validation_0-efron_likelihood:22758.88452	validation_1-efron_likelihood:4679.83957
# [39]	validation_0-efron_likelihood:22697.78129	validation_1-efron_likelihood:4761.11690
# [40]	validation_0-efron_likelihood:22752.77207	validation_1-efron_likelihood:4689.63025
# [43]	validation_0-efron_likelihood:22892.40910	validation_1-efron_likelihood:4586.54123
# [41]	validation_0-efron_likelihood:22719.66937	validation_1-efron_likelihood:4737.10887
# [47]	validation_0-efron_likelihood:22757.11346	validation_1-efron_likelihood:4679.56516
# [41]	validation_0-efron_likelihood:22751.05238	validation_1-efron_likelihood:4689.38948
# [40]	validation_0-efron_likelihood:22695.71116	validation_1-efron_likelihood:4761.06410
# [44]	validation_0-efron_likelihood:22890.68071	validation_1-efron_likelihood:4586.34059
# [42]	validation_0-efron_likelihood:22717.82906	validation_1-efron_likelihood:4737.09569
# [48]	validation_0-efron_likelihood:22754.88104	validation_1-efron_likelihood:4679.87263
# [42]	validation_0-efron_likelihood:22749.07222	validation_1-efron_likelihood:4689.68614
# [41]	validation_0-efron_likelihood:22693.89917	validation_1-efron_likelihood:4761.16824
# [43]	validation_0-efron_likelihood:22716.00412	validation_1-efron_likelihood:4736.69624
# [45]	validation_0-efron_likelihood:22887.62857	validation_1-efron_likelihood:4586.37749
# [49]	validation_0-efron_likelihood:22752.70007	validation_1-efron_likelihood:4679.89297
# [43]	validation_0-efron_likelihood:22746.09326	validation_1-efron_likelihood:4690.10824
# [42]	validation_0-efron_likelihood:22692.75087	validation_1-efron_likelihood:4761.24329
# [46]	validation_0-efron_likelihood:22885.15810	validation_1-efron_likelihood:4586.10543
# [44]	validation_0-efron_likelihood:22713.37684	validation_1-efron_likelihood:4736.70338
# [44]	validation_0-efron_likelihood:22743.73274	validation_1-efron_likelihood:4690.04320
# [47]	validation_0-efron_likelihood:22883.50101	validation_1-efron_likelihood:4586.35701
# [43]	validation_0-efron_likelihood:22690.88505	validation_1-efron_likelihood:4760.90029
# [45]	validation_0-efron_likelihood:22711.89837	validation_1-efron_likelihood:4737.08382
# [45]	validation_0-efron_likelihood:22741.52112	validation_1-efron_likelihood:4689.48762
# [48]	validation_0-efron_likelihood:22880.81997	validation_1-efron_likelihood:4586.60862
# [44]	validation_0-efron_likelihood:22689.08846	validation_1-efron_likelihood:4760.48131
# [46]	validation_0-efron_likelihood:22707.70656	validation_1-efron_likelihood:4736.57108
# [46]	validation_0-efron_likelihood:22738.31607	validation_1-efron_likelihood:4689.09889
# [49]	validation_0-efron_likelihood:22877.58367	validation_1-efron_likelihood:4586.58674
# [45]	validation_0-efron_likelihood:22687.59864	validation_1-efron_likelihood:4760.60542
# [47]	validation_0-efron_likelihood:22706.08153	validation_1-efron_likelihood:4736.47279
# [47]	validation_0-efron_likelihood:22737.62144	validation_1-efron_likelihood:4688.93157
# [50]	validation_0-efron_likelihood:22876.17072	validation_1-efron_likelihood:4586.48398
# [46]	validation_0-efron_likelihood:22684.96081	validation_1-efron_likelihood:4760.15021
# [48]	validation_0-efron_likelihood:22704.32105	validation_1-efron_likelihood:4736.63029
# [48]	validation_0-efron_likelihood:22735.74930	validation_1-efron_likelihood:4688.80457
# [51]	validation_0-efron_likelihood:22874.40643	validation_1-efron_likelihood:4586.43580
# [47]	validation_0-efron_likelihood:22683.09828	validation_1-efron_likelihood:4759.70093
# [49]	validation_0-efron_likelihood:22702.21614	validation_1-efron_likelihood:4736.23121
# [49]	validation_0-efron_likelihood:22734.67114	validation_1-efron_likelihood:4688.40915
# [52]	validation_0-efron_likelihood:22872.15531	validation_1-efron_likelihood:4586.22241
# [48]	validation_0-efron_likelihood:22681.29554	validation_1-efron_likelihood:4759.79432
# [50]	validation_0-efron_likelihood:22700.75861	validation_1-efron_likelihood:4736.09968
# [50]	validation_0-efron_likelihood:22733.15834	validation_1-efron_likelihood:4688.56789
# [53]	validation_0-efron_likelihood:22867.71143	validation_1-efron_likelihood:4585.84114
# [49]	validation_0-efron_likelihood:22679.81042	validation_1-efron_likelihood:4759.70034
# [51]	validation_0-efron_likelihood:22699.28635	validation_1-efron_likelihood:4736.12439
# [51]	validation_0-efron_likelihood:22730.83061	validation_1-efron_likelihood:4688.36386
# [50]	validation_0-efron_likelihood:22678.78576	validation_1-efron_likelihood:4759.51370
# [54]	validation_0-efron_likelihood:22866.51052	validation_1-efron_likelihood:4585.81944
# [52]	validation_0-efron_likelihood:22698.35367	validation_1-efron_likelihood:4736.07931
# [52]	validation_0-efron_likelihood:22729.85380	validation_1-efron_likelihood:4688.46517
# [55]	validation_0-efron_likelihood:22864.08385	validation_1-efron_likelihood:4585.81541
# [51]	validation_0-efron_likelihood:22677.53082	validation_1-efron_likelihood:4759.54383
# [53]	validation_0-efron_likelihood:22695.63968	validation_1-efron_likelihood:4735.70225
# [53]	validation_0-efron_likelihood:22726.77905	validation_1-efron_likelihood:4688.64682
# [56]	validation_0-efron_likelihood:22861.77745	validation_1-efron_likelihood:4585.98368
# [52]	validation_0-efron_likelihood:22673.95732	validation_1-efron_likelihood:4759.55102
# [54]	validation_0-efron_likelihood:22694.65290	validation_1-efron_likelihood:4735.32401
# [54]	validation_0-efron_likelihood:22724.30487	validation_1-efron_likelihood:4688.78827
# [57]	validation_0-efron_likelihood:22861.04222	validation_1-efron_likelihood:4585.91007
# [53]	validation_0-efron_likelihood:22671.59743	validation_1-efron_likelihood:4759.62842
# [55]	validation_0-efron_likelihood:22692.91877	validation_1-efron_likelihood:4735.65442
# [55]	validation_0-efron_likelihood:22721.40918	validation_1-efron_likelihood:4689.19651
# [58]	validation_0-efron_likelihood:22859.90517	validation_1-efron_likelihood:4585.83738
# [54]	validation_0-efron_likelihood:22670.69114	validation_1-efron_likelihood:4759.75255
# [56]	validation_0-efron_likelihood:22690.87154	validation_1-efron_likelihood:4735.35125
# [56]	validation_0-efron_likelihood:22719.48785	validation_1-efron_likelihood:4689.24477
# [55]	validation_0-efron_likelihood:22668.84120	validation_1-efron_likelihood:4759.71139
# [57]	validation_0-efron_likelihood:22689.83811	validation_1-efron_likelihood:4735.54001
# [57]	validation_0-efron_likelihood:22717.97769	validation_1-efron_likelihood:4689.40311
# [56]	validation_0-efron_likelihood:22667.33537	validation_1-efron_likelihood:4759.77465
# [58]	validation_0-efron_likelihood:22687.97971	validation_1-efron_likelihood:4735.52105
# [58]	validation_0-efron_likelihood:22717.13161	validation_1-efron_likelihood:4689.32099
# [57]	validation_0-efron_likelihood:22664.89614	validation_1-efron_likelihood:4760.08025
# [58]	validation_0-efron_likelihood:22663.97402	validation_1-efron_likelihood:4759.94555
# [0]	validation_0-efron_likelihood:29606.78548	validation_1-efron_likelihood:5991.37601
# [1]	validation_0-efron_likelihood:29600.60421	validation_1-efron_likelihood:5990.31817
# [2]	validation_0-efron_likelihood:29588.92242	validation_1-efron_likelihood:5989.27968
# [3]	validation_0-efron_likelihood:29580.05173	validation_1-efron_likelihood:5988.20568
# [4]	validation_0-efron_likelihood:29571.92213	validation_1-efron_likelihood:5987.66365
# [5]	validation_0-efron_likelihood:29564.73554	validation_1-efron_likelihood:5986.99412
# [6]	validation_0-efron_likelihood:29557.75415	validation_1-efron_likelihood:5986.17735
# [7]	validation_0-efron_likelihood:29552.53862	validation_1-efron_likelihood:5985.83539
# [8]	validation_0-efron_likelihood:29548.87681	validation_1-efron_likelihood:5985.13063
# [9]	validation_0-efron_likelihood:29542.50571	validation_1-efron_likelihood:5984.79415
# [10]	validation_0-efron_likelihood:29535.66686	validation_1-efron_likelihood:5983.58377
# [11]	validation_0-efron_likelihood:29529.19376	validation_1-efron_likelihood:5983.08481
# [12]	validation_0-efron_likelihood:29523.55453	validation_1-efron_likelihood:5982.51186
# [13]	validation_0-efron_likelihood:29517.68346	validation_1-efron_likelihood:5981.79137
# [14]	validation_0-efron_likelihood:29513.47449	validation_1-efron_likelihood:5981.55828
# [15]	validation_0-efron_likelihood:29509.75218	validation_1-efron_likelihood:5981.19138
# [16]	validation_0-efron_likelihood:29507.17050	validation_1-efron_likelihood:5980.88196
# [17]	validation_0-efron_likelihood:29501.48056	validation_1-efron_likelihood:5980.65788
# [18]	validation_0-efron_likelihood:29496.74130	validation_1-efron_likelihood:5980.02478
# [19]	validation_0-efron_likelihood:29493.01243	validation_1-efron_likelihood:5979.82425
# [20]	validation_0-efron_likelihood:29489.03580	validation_1-efron_likelihood:5979.70524
# [21]	validation_0-efron_likelihood:29485.84263	validation_1-efron_likelihood:5979.61631
# [22]	validation_0-efron_likelihood:29481.90432	validation_1-efron_likelihood:5979.44455
# [23]	validation_0-efron_likelihood:29476.84424	validation_1-efron_likelihood:5979.17307
# [24]	validation_0-efron_likelihood:29473.00071	validation_1-efron_likelihood:5978.57819
# [25]	validation_0-efron_likelihood:29468.97038	validation_1-efron_likelihood:5977.98124
# [26]	validation_0-efron_likelihood:29465.17325	validation_1-efron_likelihood:5977.71472
# [27]	validation_0-efron_likelihood:29462.60261	validation_1-efron_likelihood:5977.23479
# [28]	validation_0-efron_likelihood:29460.23385	validation_1-efron_likelihood:5976.74495
# [29]	validation_0-efron_likelihood:29454.99295	validation_1-efron_likelihood:5976.57023
# [30]	validation_0-efron_likelihood:29451.39374	validation_1-efron_likelihood:5976.43435
# [31]	validation_0-efron_likelihood:29446.83757	validation_1-efron_likelihood:5975.86676
# [32]	validation_0-efron_likelihood:29443.15219	validation_1-efron_likelihood:5975.71923
# [33]	validation_0-efron_likelihood:29439.84689	validation_1-efron_likelihood:5975.74450
# [34]	validation_0-efron_likelihood:29435.73978	validation_1-efron_likelihood:5975.35750
# [35]	validation_0-efron_likelihood:29432.34332	validation_1-efron_likelihood:5974.90114
# [36]	validation_0-efron_likelihood:29429.04249	validation_1-efron_likelihood:5974.90433
# [37]	validation_0-efron_likelihood:29424.91616	validation_1-efron_likelihood:5974.28057
# [38]	validation_0-efron_likelihood:29422.76697	validation_1-efron_likelihood:5973.93033
# [39]	validation_0-efron_likelihood:29420.18888	validation_1-efron_likelihood:5973.88290
# [40]	validation_0-efron_likelihood:29416.71453	validation_1-efron_likelihood:5973.43618
# [41]	validation_0-efron_likelihood:29415.30872	validation_1-efron_likelihood:5973.48643
# [42]	validation_0-efron_likelihood:29413.90883	validation_1-efron_likelihood:5973.30119
# [43]	validation_0-efron_likelihood:29411.90241	validation_1-efron_likelihood:5973.80203
# [44]	validation_0-efron_likelihood:29408.94142	validation_1-efron_likelihood:5973.93096
# [45]	validation_0-efron_likelihood:29406.73322	validation_1-efron_likelihood:5974.49967
# [46]	validation_0-efron_likelihood:29403.80119	validation_1-efron_likelihood:5974.21695
# [47]	validation_0-efron_likelihood:29401.14710	validation_1-efron_likelihood:5974.30673
# [48]	validation_0-efron_likelihood:29398.38157	validation_1-efron_likelihood:5974.39018
# [49]	validation_0-efron_likelihood:29395.98452	validation_1-efron_likelihood:5974.54093
# [50]	validation_0-efron_likelihood:29393.62589	validation_1-efron_likelihood:5973.92844
# [51]	validation_0-efron_likelihood:29390.82376	validation_1-efron_likelihood:5973.84387
# [52]	validation_0-efron_likelihood:29389.58040	validation_1-efron_likelihood:5973.84133
# Concordance Index 0.6130399273262339
# Integrated Brier Score: 0.19858922515830418
# durations 3.0 2029.0
# Concordance Index 0.6073439670295517
# Integrated Brier Score: 0.19986893379663473

# %% [markdown]
# ## TCGA Train, Test, Evaluation

# %%
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
'pca__n_components': [8, 10, 12, 14, 16]
}

# %%
cancer_types = ['BLCA',
    'BRCA',
    'HNSC',
    'KIRC',
    'LGG',
    'LIHC',
    'LUAD',
    'LUSC',
    'OV',
    'STAD']


for idx, cancer_type in enumerate(cancer_types):
    model = 'xgbsurv_efron_'
    # get name of current dataset
    data = load_tcga(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", cancer_type=cancer_type, as_frame=True)
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()
    filename = data.filename
    dataset_name = filename.split('_')[0]
    X, y = sort_X_y_pandas(X, y)

    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            #(OneHotEncoder(sparse_output=False), make_column_selector(dtype_include=['category', 'object']))
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='efron_objective',
        eval_metric='efron_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    
    pipe = Pipeline([('scaler',ct),
                    ('pca', PCA()),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=2, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        print(X_train.shape, type(X_train))
        print(y_train.shape, type(y_train))
        print(X_test.shape, type(X_test))
        print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_efron(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_efron(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# Out:
# (324, 20531) <class 'pandas.core.frame.DataFrame'>
# (324,) <class 'pandas.core.series.Series'>
# (82, 20531) <class 'pandas.core.frame.DataFrame'>
# (82,) <class 'pandas.core.series.Series'>
# [0]	validation_0-efron_likelihood:379.14216	validation_1-efron_likelihood:80.56820
# [1]	validation_0-efron_likelihood:379.08282	validation_1-efron_likelihood:80.56922
# [0]	validation_0-efron_likelihood:377.57382	validation_1-efron_likelihood:80.44842
# [1]	validation_0-efron_likelihood:377.08840	validation_1-efron_likelihood:80.40506
# [2]	validation_0-efron_likelihood:376.29215	validation_1-efron_likelihood:80.53417
# [3]	validation_0-efron_likelihood:376.36442	validation_1-efron_likelihood:80.44768
# [4]	validation_0-efron_likelihood:375.77510	validation_1-efron_likelihood:80.41483
# [5]	validation_0-efron_likelihood:374.86584	validation_1-efron_likelihood:80.31396
# [6]	validation_0-efron_likelihood:374.51533	validation_1-efron_likelihood:80.47315
# [7]	validation_0-efron_likelihood:374.08302	validation_1-efron_likelihood:80.49801
# [8]	validation_0-efron_likelihood:373.53241	validation_1-efron_likelihood:80.53417
# [9]	validation_0-efron_likelihood:372.71926	validation_1-efron_likelihood:80.48541
# [10]	validation_0-efron_likelihood:372.06706	validation_1-efron_likelihood:80.50336
# [11]	validation_0-efron_likelihood:371.61601	validation_1-efron_likelihood:80.56563
# [12]	validation_0-efron_likelihood:370.94140	validation_1-efron_likelihood:80.57171
# [13]	validation_0-efron_likelihood:370.43511	validation_1-efron_likelihood:80.61164
# [14]	validation_0-efron_likelihood:369.81836	validation_1-efron_likelihood:80.52209
# [15]	validation_0-efron_likelihood:369.48113	validation_1-efron_likelihood:80.61713
# [0]	validation_0-efron_likelihood:377.99008	validation_1-efron_likelihood:80.37229
# [1]	validation_0-efron_likelihood:377.21394	validation_1-efron_likelihood:80.54004
# [2]	validation_0-efron_likelihood:376.26352	validation_1-efron_likelihood:80.31147
# [3]	validation_0-efron_likelihood:375.06335	validation_1-efron_likelihood:80.04179
# [4]	validation_0-efron_likelihood:374.76509	validation_1-efron_likelihood:80.03114
# [5]	validation_0-efron_likelihood:374.46866	validation_1-efron_likelihood:79.95687
# [6]	validation_0-efron_likelihood:373.65082	validation_1-efron_likelihood:79.88496
# [7]	validation_0-efron_likelihood:373.24185	validation_1-efron_likelihood:79.79414
# [8]	validation_0-efron_likelihood:373.49541	validation_1-efron_likelihood:79.77559
# [9]	validation_0-efron_likelihood:372.27717	validation_1-efron_likelihood:79.58019
# [10]	validation_0-efron_likelihood:371.92871	validation_1-efron_likelihood:79.51969
# [11]	validation_0-efron_likelihood:371.37498	validation_1-efron_likelihood:79.38143
# [12]	validation_0-efron_likelihood:371.23726	validation_1-efron_likelihood:79.43854
# [13]	validation_0-efron_likelihood:369.89380	validation_1-efron_likelihood:79.32003
# [14]	validation_0-efron_likelihood:369.61830	validation_1-efron_likelihood:79.06453
# [15]	validation_0-efron_likelihood:369.03462	validation_1-efron_likelihood:78.98462
# [16]	validation_0-efron_likelihood:368.14513	validation_1-efron_likelihood:78.84715
# [17]	validation_0-efron_likelihood:366.76347	validation_1-efron_likelihood:79.04917
# [18]	validation_0-efron_likelihood:366.07542	validation_1-efron_likelihood:78.86353
# [19]	validation_0-efron_likelihood:365.11087	validation_1-efron_likelihood:78.92715
# [20]	validation_0-efron_likelihood:364.96962	validation_1-efron_likelihood:78.83320
# [21]	validation_0-efron_likelihood:364.73132	validation_1-efron_likelihood:78.76543
# [22]	validation_0-efron_likelihood:364.46847	validation_1-efron_likelihood:78.53883
# [23]	validation_0-efron_likelihood:363.84119	validation_1-efron_likelihood:78.61404
# [24]	validation_0-efron_likelihood:363.36270	validation_1-efron_likelihood:78.56858
# [25]	validation_0-efron_likelihood:362.97860	validation_1-efron_likelihood:78.51607
# [26]	validation_0-efron_likelihood:362.05756	validation_1-efron_likelihood:78.67157
# [27]	validation_0-efron_likelihood:361.80004	validation_1-efron_likelihood:78.56463
# [28]	validation_0-efron_likelihood:360.50888	validation_1-efron_likelihood:78.80761
# [29]	validation_0-efron_likelihood:359.75625	validation_1-efron_likelihood:78.78220
# [30]	validation_0-efron_likelihood:359.37380	validation_1-efron_likelihood:78.76144
# [31]	validation_0-efron_likelihood:359.33236	validation_1-efron_likelihood:78.82682
# [32]	validation_0-efron_likelihood:358.95967	validation_1-efron_likelihood:78.82306
# [33]	validation_0-efron_likelihood:358.66117	validation_1-efron_likelihood:78.80376
# [34]	validation_0-efron_likelihood:358.33795	validation_1-efron_likelihood:78.98887
# [0]	validation_0-efron_likelihood:392.26541	validation_1-efron_likelihood:72.99929
# [1]	validation_0-efron_likelihood:392.20373	validation_1-efron_likelihood:72.99483
# [0]	validation_0-efron_likelihood:372.31554	validation_1-efron_likelihood:77.24066
# [1]	validation_0-efron_likelihood:372.25787	validation_1-efron_likelihood:77.23748
# [0]	validation_0-efron_likelihood:378.87921	validation_1-efron_likelihood:80.49166
# [1]	validation_0-efron_likelihood:378.83927	validation_1-efron_likelihood:80.49076
# [0]	validation_0-efron_likelihood:391.91902	validation_1-efron_likelihood:72.83894
# [1]	validation_0-efron_likelihood:391.21691	validation_1-efron_likelihood:72.50707
# [2]	validation_0-efron_likelihood:390.65954	validation_1-efron_likelihood:72.42128
# [3]	validation_0-efron_likelihood:390.58533	validation_1-efron_likelihood:72.33044
# [4]	validation_0-efron_likelihood:389.98535	validation_1-efron_likelihood:72.47132
# [5]	validation_0-efron_likelihood:389.00294	validation_1-efron_likelihood:72.22131
# [6]	validation_0-efron_likelihood:388.54369	validation_1-efron_likelihood:72.12634
# [0]	validation_0-efron_likelihood:373.71587	validation_1-efron_likelihood:86.66483
# [7]	validation_0-efron_likelihood:388.01592	validation_1-efron_likelihood:71.99329
# [8]	validation_0-efron_likelihood:387.34753	validation_1-efron_likelihood:72.05108
# [9]	validation_0-efron_likelihood:386.99994	validation_1-efron_likelihood:72.18604
# [1]	validation_0-efron_likelihood:373.67133	validation_1-efron_likelihood:86.65820
# [10]	validation_0-efron_likelihood:386.63930	validation_1-efron_likelihood:72.01233
# [11]	validation_0-efron_likelihood:386.15287	validation_1-efron_likelihood:71.90828
# [12]	validation_0-efron_likelihood:384.91412	validation_1-efron_likelihood:71.78810
# [13]	validation_0-efron_likelihood:384.65124	validation_1-efron_likelihood:71.70264
# [14]	validation_0-efron_likelihood:384.31455	validation_1-efron_likelihood:71.11020
# [15]	validation_0-efron_likelihood:383.65791	validation_1-efron_likelihood:70.95868
# [16]	validation_0-efron_likelihood:382.77469	validation_1-efron_likelihood:71.05880
# [17]	validation_0-efron_likelihood:382.18000	validation_1-efron_likelihood:71.25769
# [18]	validation_0-efron_likelihood:381.51553	validation_1-efron_likelihood:71.07532
# [19]	validation_0-efron_likelihood:380.97223	validation_1-efron_likelihood:70.92806
# [20]	validation_0-efron_likelihood:380.20335	validation_1-efron_likelihood:71.08276
# [21]	validation_0-efron_likelihood:380.23960	validation_1-efron_likelihood:71.05215
# [22]	validation_0-efron_likelihood:380.13774	validation_1-efron_likelihood:71.01118
# [23]	validation_0-efron_likelihood:379.80973	validation_1-efron_likelihood:71.10396
# [24]	validation_0-efron_likelihood:379.66460	validation_1-efron_likelihood:71.12162
# [25]	validation_0-efron_likelihood:379.34912	validation_1-efron_likelihood:70.85472
# [26]	validation_0-efron_likelihood:378.81924	validation_1-efron_likelihood:70.64279
# [27]	validation_0-efron_likelihood:378.65122	validation_1-efron_likelihood:70.67774
# [28]	validation_0-efron_likelihood:378.25901	validation_1-efron_likelihood:70.29153
# [29]	validation_0-efron_likelihood:378.11231	validation_1-efron_likelihood:70.23733
# [30]	validation_0-efron_likelihood:377.12754	validation_1-efron_likelihood:70.42824
# [0]	validation_0-efron_likelihood:371.60980	validation_1-efron_likelihood:77.09884
# [31]	validation_0-efron_likelihood:376.79161	validation_1-efron_likelihood:70.53475
# [1]	validation_0-efron_likelihood:371.16750	validation_1-efron_likelihood:77.09554
# [32]	validation_0-efron_likelihood:376.52341	validation_1-efron_likelihood:70.52148
# [33]	validation_0-efron_likelihood:376.34307	validation_1-efron_likelihood:70.35201
# [2]	validation_0-efron_likelihood:370.84548	validation_1-efron_likelihood:77.04856
# [34]	validation_0-efron_likelihood:375.70582	validation_1-efron_likelihood:70.38108
# [35]	validation_0-efron_likelihood:375.46517	validation_1-efron_likelihood:70.30357
# [36]	validation_0-efron_likelihood:375.01142	validation_1-efron_likelihood:70.41719
# [3]	validation_0-efron_likelihood:370.55247	validation_1-efron_likelihood:76.90660
# [37]	validation_0-efron_likelihood:374.46001	validation_1-efron_likelihood:70.48783
# [38]	validation_0-efron_likelihood:374.36214	validation_1-efron_likelihood:70.39142
# [39]	validation_0-efron_likelihood:374.21790	validation_1-efron_likelihood:70.30149
# [4]	validation_0-efron_likelihood:369.50074	validation_1-efron_likelihood:76.99621
# [5]	validation_0-efron_likelihood:368.79626	validation_1-efron_likelihood:76.94694[0]	validation_0-efron_likelihood:373.18345	validation_1-efron_likelihood:86.75886
#
# [1]	validation_0-efron_likelihood:372.86311	validation_1-efron_likelihood:86.73640
# [2]	validation_0-efron_likelihood:372.03216	validation_1-efron_likelihood:86.82534
# [6]	validation_0-efron_likelihood:368.65261	validation_1-efron_likelihood:77.01616
# [3]	validation_0-efron_likelihood:371.46826	validation_1-efron_likelihood:86.80830
# [4]	validation_0-efron_likelihood:371.05277	validation_1-efron_likelihood:86.87085
# [5]	validation_0-efron_likelihood:370.50747	validation_1-efron_likelihood:86.79349
# [7]	validation_0-efron_likelihood:368.23408	validation_1-efron_likelihood:76.99353
# [6]	validation_0-efron_likelihood:370.20248	validation_1-efron_likelihood:86.61360
# [7]	validation_0-efron_likelihood:369.93143	validation_1-efron_likelihood:86.70488
# [8]	validation_0-efron_likelihood:369.49594	validation_1-efron_likelihood:86.89863
# [8]	validation_0-efron_likelihood:367.29100	validation_1-efron_likelihood:76.98677
# [9]	validation_0-efron_likelihood:369.18906	validation_1-efron_likelihood:86.81583
# [10]	validation_0-efron_likelihood:368.15493	validation_1-efron_likelihood:86.59970
# [9]	validation_0-efron_likelihood:366.54630	validation_1-efron_likelihood:76.99607
# [11]	validation_0-efron_likelihood:367.59580	validation_1-efron_likelihood:86.47372
# [12]	validation_0-efron_likelihood:367.63587	validation_1-efron_likelihood:86.58424
# [13]	validation_0-efron_likelihood:367.24235	validation_1-efron_likelihood:86.64328
# [10]	validation_0-efron_likelihood:365.66292	validation_1-efron_likelihood:76.81617
# [14]	validation_0-efron_likelihood:366.25980	validation_1-efron_likelihood:87.07189
# [15]	validation_0-efron_likelihood:366.13893	validation_1-efron_likelihood:87.01309
# [16]	validation_0-efron_likelihood:365.58305	validation_1-efron_likelihood:86.93112
# [11]	validation_0-efron_likelihood:365.22654	validation_1-efron_likelihood:76.84815
# [17]	validation_0-efron_likelihood:365.14275	validation_1-efron_likelihood:86.83808
# [18]	validation_0-efron_likelihood:364.83869	validation_1-efron_likelihood:86.79931
# [12]	validation_0-efron_likelihood:364.46068	validation_1-efron_likelihood:76.90176
# [19]	validation_0-efron_likelihood:364.16010	validation_1-efron_likelihood:86.80188
# [20]	validation_0-efron_likelihood:363.88300	validation_1-efron_likelihood:86.99970
# [13]	validation_0-efron_likelihood:364.06024	validation_1-efron_likelihood:76.80730
# [14]	validation_0-efron_likelihood:363.70895	validation_1-efron_likelihood:76.64253
# [15]	validation_0-efron_likelihood:363.63498	validation_1-efron_likelihood:76.74101
# [16]	validation_0-efron_likelihood:363.20531	validation_1-efron_likelihood:76.79369
# [17]	validation_0-efron_likelihood:362.76645	validation_1-efron_likelihood:76.64390
# [18]	validation_0-efron_likelihood:362.28711	validation_1-efron_likelihood:76.35438
# [19]	validation_0-efron_likelihood:361.70094	validation_1-efron_likelihood:76.31902
# [20]	validation_0-efron_likelihood:360.75333	validation_1-efron_likelihood:76.45444
# [21]	validation_0-efron_likelihood:360.15432	validation_1-efron_likelihood:76.51373
# [22]	validation_0-efron_likelihood:359.74839	validation_1-efron_likelihood:76.48873
# [23]	validation_0-efron_likelihood:359.23187	validation_1-efron_likelihood:76.63078
# [24]	validation_0-efron_likelihood:358.43719	validation_1-efron_likelihood:76.52779
# [25]	validation_0-efron_likelihood:357.80076	validation_1-efron_likelihood:76.64454
# [26]	validation_0-efron_likelihood:356.85364	validation_1-efron_likelihood:76.30726
# [27]	validation_0-efron_likelihood:356.41227	validation_1-efron_likelihood:76.33369
# [28]	validation_0-efron_likelihood:356.24551	validation_1-efron_likelihood:76.61863
# [29]	validation_0-efron_likelihood:355.84641	validation_1-efron_likelihood:76.72590
# [30]	validation_0-efron_likelihood:355.31602	validation_1-efron_likelihood:76.58863
# [31]	validation_0-efron_likelihood:354.67816	validation_1-efron_likelihood:76.49861
# [32]	validation_0-efron_likelihood:354.28773	validation_1-efron_likelihood:76.34257
# [33]	validation_0-efron_likelihood:354.12201	validation_1-efron_likelihood:76.30782
# [34]	validation_0-efron_likelihood:353.80100	validation_1-efron_likelihood:76.32309
# [35]	validation_0-efron_likelihood:353.84041	validation_1-efron_likelihood:76.34180
# [36]	validation_0-efron_likelihood:353.38205	validation_1-efron_likelihood:76.34294
# [0]	validation_0-efron_likelihood:548.62351	validation_1-efron_likelihood:80.88323
# [1]	validation_0-efron_likelihood:548.54484	validation_1-efron_likelihood:80.87525
# Concordance Index 0.6610494487259855
# Integrated Brier Score: 0.21213563979498773
# durations 17.0 4343.0
# Concordance Index 0.5900552486187846
# Integrated Brier Score: 0.22797639424587976
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-efron_likelihood:424.36926	validation_1-efron_likelihood:60.37370
# [1]	validation_0-efron_likelihood:424.30027	validation_1-efron_likelihood:60.37833
# [2]	validation_0-efron_likelihood:424.30825	validation_1-efron_likelihood:60.37827
# [3]	validation_0-efron_likelihood:424.14305	validation_1-efron_likelihood:60.36534
# [4]	validation_0-efron_likelihood:424.22000	validation_1-efron_likelihood:60.37074
# [5]	validation_0-efron_likelihood:424.19752	validation_1-efron_likelihood:60.37426
# [6]	validation_0-efron_likelihood:424.15298	validation_1-efron_likelihood:60.38703
# [7]	validation_0-efron_likelihood:424.10361	validation_1-efron_likelihood:60.39270
# [8]	validation_0-efron_likelihood:423.99903	validation_1-efron_likelihood:60.44080
# [9]	validation_0-efron_likelihood:423.97426	validation_1-efron_likelihood:60.41541
# [10]	validation_0-efron_likelihood:423.95561	validation_1-efron_likelihood:60.42658
# [11]	validation_0-efron_likelihood:423.92892	validation_1-efron_likelihood:60.42658
# [12]	validation_0-efron_likelihood:423.90733	validation_1-efron_likelihood:60.41225
# [0]	validation_0-efron_likelihood:395.19598	validation_1-efron_likelihood:73.68658
# [1]	validation_0-efron_likelihood:395.15786	validation_1-efron_likelihood:73.70181
# [2]	validation_0-efron_likelihood:395.04877	validation_1-efron_likelihood:73.73605
# [3]	validation_0-efron_likelihood:395.10824	validation_1-efron_likelihood:73.73235
# [4]	validation_0-efron_likelihood:395.01646	validation_1-efron_likelihood:73.73745
# [5]	validation_0-efron_likelihood:394.92619	validation_1-efron_likelihood:73.73802
# [6]	validation_0-efron_likelihood:394.85761	validation_1-efron_likelihood:73.73141
# [7]	validation_0-efron_likelihood:394.70113	validation_1-efron_likelihood:73.74569
# [8]	validation_0-efron_likelihood:394.65587	validation_1-efron_likelihood:73.75002
# [9]	validation_0-efron_likelihood:394.45641	validation_1-efron_likelihood:73.76312
# [10]	validation_0-efron_likelihood:394.40380	validation_1-efron_likelihood:73.76662
# [0]	validation_0-efron_likelihood:411.17497	validation_1-efron_likelihood:60.02802
# [1]	validation_0-efron_likelihood:411.13466	validation_1-efron_likelihood:60.04410
# [2]	validation_0-efron_likelihood:411.02283	validation_1-efron_likelihood:60.05328
# [3]	validation_0-efron_likelihood:411.00026	validation_1-efron_likelihood:60.04574
# [4]	validation_0-efron_likelihood:410.91977	validation_1-efron_likelihood:60.02941
# [5]	validation_0-efron_likelihood:410.91510	validation_1-efron_likelihood:60.02683
# [6]	validation_0-efron_likelihood:410.77684	validation_1-efron_likelihood:59.98741
# [7]	validation_0-efron_likelihood:410.76956	validation_1-efron_likelihood:59.95454
# [8]	validation_0-efron_likelihood:410.68804	validation_1-efron_likelihood:59.95112
# [9]	validation_0-efron_likelihood:410.56958	validation_1-efron_likelihood:59.94557
# [10]	validation_0-efron_likelihood:410.51741	validation_1-efron_likelihood:59.88542
# [11]	validation_0-efron_likelihood:410.45245	validation_1-efron_likelihood:59.87081
# [12]	validation_0-efron_likelihood:410.33857	validation_1-efron_likelihood:59.85469
# [13]	validation_0-efron_likelihood:410.38570	validation_1-efron_likelihood:59.86705
# [14]	validation_0-efron_likelihood:410.29306	validation_1-efron_likelihood:59.85701
# [15]	validation_0-efron_likelihood:410.26428	validation_1-efron_likelihood:59.85057
# [16]	validation_0-efron_likelihood:410.24979	validation_1-efron_likelihood:59.86684
# [17]	validation_0-efron_likelihood:410.24777	validation_1-efron_likelihood:59.86157
# [18]	validation_0-efron_likelihood:410.20208	validation_1-efron_likelihood:59.86042
# [19]	validation_0-efron_likelihood:410.13075	validation_1-efron_likelihood:59.84064
# [20]	validation_0-efron_likelihood:410.02622	validation_1-efron_likelihood:59.81145
# [21]	validation_0-efron_likelihood:409.94784	validation_1-efron_likelihood:59.78149
# [22]	validation_0-efron_likelihood:409.91940	validation_1-efron_likelihood:59.78880
# [23]	validation_0-efron_likelihood:409.86381	validation_1-efron_likelihood:59.78842
# [24]	validation_0-efron_likelihood:409.81635	validation_1-efron_likelihood:59.80019
# [25]	validation_0-efron_likelihood:409.77466	validation_1-efron_likelihood:59.79173
# [26]	validation_0-efron_likelihood:409.73302	validation_1-efron_likelihood:59.79152
# [27]	validation_0-efron_likelihood:409.70287	validation_1-efron_likelihood:59.77687
# [28]	validation_0-efron_likelihood:409.69632	validation_1-efron_likelihood:59.79530
# [0]	validation_0-efron_likelihood:411.11372	validation_1-efron_likelihood:60.00552
# [1]	validation_0-efron_likelihood:410.93667	validation_1-efron_likelihood:59.97709
# [2]	validation_0-efron_likelihood:410.80996	validation_1-efron_likelihood:59.97744
# [3]	validation_0-efron_likelihood:410.77656	validation_1-efron_likelihood:59.99293
# [29]	validation_0-efron_likelihood:409.63853	validation_1-efron_likelihood:59.79447
# [4]	validation_0-efron_likelihood:410.77656	validation_1-efron_likelihood:59.99293
# [5]	validation_0-efron_likelihood:410.46209	validation_1-efron_likelihood:59.89963
# [6]	validation_0-efron_likelihood:410.43611	validation_1-efron_likelihood:59.88013
# [7]	validation_0-efron_likelihood:410.05752	validation_1-efron_likelihood:59.73284
# [30]	validation_0-efron_likelihood:409.51266	validation_1-efron_likelihood:59.77281
# [8]	validation_0-efron_likelihood:410.02556	validation_1-efron_likelihood:59.73392
# [9]	validation_0-efron_likelihood:409.68098	validation_1-efron_likelihood:59.62802
# [10]	validation_0-efron_likelihood:409.53694	validation_1-efron_likelihood:59.63089
# [31]	validation_0-efron_likelihood:409.52709	validation_1-efron_likelihood:59.77376
# [11]	validation_0-efron_likelihood:409.45602	validation_1-efron_likelihood:59.56250
# [12]	validation_0-efron_likelihood:409.48126	validation_1-efron_likelihood:59.55495
# [13]	validation_0-efron_likelihood:409.44028	validation_1-efron_likelihood:59.52331
# [32]	validation_0-efron_likelihood:409.51778	validation_1-efron_likelihood:59.76251
# [14]	validation_0-efron_likelihood:409.17620	validation_1-efron_likelihood:59.40836
# [15]	validation_0-efron_likelihood:409.16972	validation_1-efron_likelihood:59.36432
# [33]	validation_0-efron_likelihood:409.48823	validation_1-efron_likelihood:59.76210
# [16]	validation_0-efron_likelihood:409.03880	validation_1-efron_likelihood:59.34127
# [17]	validation_0-efron_likelihood:408.84084	validation_1-efron_likelihood:59.37749
# [18]	validation_0-efron_likelihood:408.62992	validation_1-efron_likelihood:59.39316
# [34]	validation_0-efron_likelihood:409.40501	validation_1-efron_likelihood:59.74422
# [19]	validation_0-efron_likelihood:408.66310	validation_1-efron_likelihood:59.38894
# [20]	validation_0-efron_likelihood:408.52308	validation_1-efron_likelihood:59.39306
# [21]	validation_0-efron_likelihood:408.48326	validation_1-efron_likelihood:59.36189
# [0]	validation_0-efron_likelihood:424.45079	validation_1-efron_likelihood:60.39522
# [35]	validation_0-efron_likelihood:409.30198	validation_1-efron_likelihood:59.71935
# [22]	validation_0-efron_likelihood:408.47150	validation_1-efron_likelihood:59.35872
# [1]	validation_0-efron_likelihood:424.51001	validation_1-efron_likelihood:60.37732
# [23]	validation_0-efron_likelihood:408.42885	validation_1-efron_likelihood:59.39207
# [2]	validation_0-efron_likelihood:424.29621	validation_1-efron_likelihood:60.29880
# [24]	validation_0-efron_likelihood:408.04155	validation_1-efron_likelihood:59.32092
# [36]	validation_0-efron_likelihood:409.29301	validation_1-efron_likelihood:59.72877
# [25]	validation_0-efron_likelihood:407.97579	validation_1-efron_likelihood:59.34143
# [26]	validation_0-efron_likelihood:407.80366	validation_1-efron_likelihood:59.38292
# [3]	validation_0-efron_likelihood:424.26233	validation_1-efron_likelihood:60.31600
# [27]	validation_0-efron_likelihood:407.81302	validation_1-efron_likelihood:59.39853
# [37]	validation_0-efron_likelihood:409.29956	validation_1-efron_likelihood:59.67290
# [4]	validation_0-efron_likelihood:424.22494	validation_1-efron_likelihood:60.33984
# [28]	validation_0-efron_likelihood:407.78546	validation_1-efron_likelihood:59.38265
# [38]	validation_0-efron_likelihood:409.28743	validation_1-efron_likelihood:59.71794
# [5]	validation_0-efron_likelihood:424.03107	validation_1-efron_likelihood:60.19954
# [29]	validation_0-efron_likelihood:407.67689	validation_1-efron_likelihood:59.27431
# [6]	validation_0-efron_likelihood:423.95239	validation_1-efron_likelihood:60.20546[39]	validation_0-efron_likelihood:409.24405	validation_1-efron_likelihood:59.71473
#
# [30]	validation_0-efron_likelihood:407.68644	validation_1-efron_likelihood:59.30334
# [7]	validation_0-efron_likelihood:423.67503	validation_1-efron_likelihood:60.06715
# [40]	validation_0-efron_likelihood:409.19293	validation_1-efron_likelihood:59.72456
# [31]	validation_0-efron_likelihood:407.53397	validation_1-efron_likelihood:59.32119
# [8]	validation_0-efron_likelihood:423.60286	validation_1-efron_likelihood:60.05683
# [41]	validation_0-efron_likelihood:409.19630	validation_1-efron_likelihood:59.77557
# [32]	validation_0-efron_likelihood:407.46906	validation_1-efron_likelihood:59.32811
# [42]	validation_0-efron_likelihood:409.16906	validation_1-efron_likelihood:59.76474
# [9]	validation_0-efron_likelihood:423.42665	validation_1-efron_likelihood:59.97494
# [33]	validation_0-efron_likelihood:407.40968	validation_1-efron_likelihood:59.29056
# [43]	validation_0-efron_likelihood:409.07418	validation_1-efron_likelihood:59.71969
# [10]	validation_0-efron_likelihood:423.34362	validation_1-efron_likelihood:59.97288
# [34]	validation_0-efron_likelihood:407.31047	validation_1-efron_likelihood:59.27903
# [44]	validation_0-efron_likelihood:408.98568	validation_1-efron_likelihood:59.70261[35]	validation_0-efron_likelihood:407.16539	validation_1-efron_likelihood:59.26635
#
# [11]	validation_0-efron_likelihood:423.26556	validation_1-efron_likelihood:59.95408
# [36]	validation_0-efron_likelihood:407.13073	validation_1-efron_likelihood:59.25990
# [45]	validation_0-efron_likelihood:408.93364	validation_1-efron_likelihood:59.69168
# [12]	validation_0-efron_likelihood:423.22006	validation_1-efron_likelihood:59.91403
# [37]	validation_0-efron_likelihood:406.95250	validation_1-efron_likelihood:59.26896
# [46]	validation_0-efron_likelihood:408.89732	validation_1-efron_likelihood:59.68529
# [13]	validation_0-efron_likelihood:423.16634	validation_1-efron_likelihood:59.85513
# [38]	validation_0-efron_likelihood:406.69611	validation_1-efron_likelihood:59.16814
# [14]	validation_0-efron_likelihood:422.88822	validation_1-efron_likelihood:59.72972
# [39]	validation_0-efron_likelihood:406.74735	validation_1-efron_likelihood:59.17036
# [15]	validation_0-efron_likelihood:422.88778	validation_1-efron_likelihood:59.73628
# [16]	validation_0-efron_likelihood:422.91644	validation_1-efron_likelihood:59.78209
# [40]	validation_0-efron_likelihood:406.66238	validation_1-efron_likelihood:59.23145
# [17]	validation_0-efron_likelihood:422.87874	validation_1-efron_likelihood:59.77188
# [41]	validation_0-efron_likelihood:406.65419	validation_1-efron_likelihood:59.24622
# [18]	validation_0-efron_likelihood:422.80581	validation_1-efron_likelihood:59.75384
# [42]	validation_0-efron_likelihood:406.56340	validation_1-efron_likelihood:59.23587
# [19]	validation_0-efron_likelihood:422.72669	validation_1-efron_likelihood:59.73521
# [43]	validation_0-efron_likelihood:406.56883	validation_1-efron_likelihood:59.22115
# [20]	validation_0-efron_likelihood:422.64857	validation_1-efron_likelihood:59.80813
# [44]	validation_0-efron_likelihood:406.45978	validation_1-efron_likelihood:59.18707
# [21]	validation_0-efron_likelihood:422.67998	validation_1-efron_likelihood:59.79225
# [45]	validation_0-efron_likelihood:406.43937	validation_1-efron_likelihood:59.17857
# [22]	validation_0-efron_likelihood:422.69029	validation_1-efron_likelihood:59.76145
# [46]	validation_0-efron_likelihood:406.36029	validation_1-efron_likelihood:59.20379
# [23]	validation_0-efron_likelihood:422.53160	validation_1-efron_likelihood:59.79961
# [47]	validation_0-efron_likelihood:406.35937	validation_1-efron_likelihood:59.16986
# [24]	validation_0-efron_likelihood:422.36228	validation_1-efron_likelihood:59.66286
# [25]	validation_0-efron_likelihood:422.28072	validation_1-efron_likelihood:59.66237
# [26]	validation_0-efron_likelihood:422.25409	validation_1-efron_likelihood:59.65682
# [27]	validation_0-efron_likelihood:422.20797	validation_1-efron_likelihood:59.61939
# [28]	validation_0-efron_likelihood:422.23831	validation_1-efron_likelihood:59.63507
# [29]	validation_0-efron_likelihood:422.14919	validation_1-efron_likelihood:59.61691
# [30]	validation_0-efron_likelihood:422.10035	validation_1-efron_likelihood:59.67164
# [31]	validation_0-efron_likelihood:422.00254	validation_1-efron_likelihood:59.61477
# [32]	validation_0-efron_likelihood:421.93705	validation_1-efron_likelihood:59.61503
# [33]	validation_0-efron_likelihood:421.85066	validation_1-efron_likelihood:59.64019
# [34]	validation_0-efron_likelihood:421.64459	validation_1-efron_likelihood:59.56321
# [35]	validation_0-efron_likelihood:421.69205	validation_1-efron_likelihood:59.59368
# [36]	validation_0-efron_likelihood:421.56061	validation_1-efron_likelihood:59.61612
# [37]	validation_0-efron_likelihood:421.49828	validation_1-efron_likelihood:59.59324
# [38]	validation_0-efron_likelihood:421.31105	validation_1-efron_likelihood:59.49348
# [39]	validation_0-efron_likelihood:421.21940	validation_1-efron_likelihood:59.45679
# [40]	validation_0-efron_likelihood:421.09656	validation_1-efron_likelihood:59.43586
# [41]	validation_0-efron_likelihood:421.09395	validation_1-efron_likelihood:59.38922
# [42]	validation_0-efron_likelihood:420.88887	validation_1-efron_likelihood:59.29614
# [43]	validation_0-efron_likelihood:420.88887	validation_1-efron_likelihood:59.29614
# [44]	validation_0-efron_likelihood:420.76506	validation_1-efron_likelihood:59.21917
# [45]	validation_0-efron_likelihood:420.66634	validation_1-efron_likelihood:59.22537
# [46]	validation_0-efron_likelihood:420.52622	validation_1-efron_likelihood:59.22688
# [47]	validation_0-efron_likelihood:420.52622	validation_1-efron_likelihood:59.22688
# [0]	validation_0-efron_likelihood:395.00367	validation_1-efron_likelihood:73.61308
# [48]	validation_0-efron_likelihood:420.44029	validation_1-efron_likelihood:59.20857
# [1]	validation_0-efron_likelihood:395.00323	validation_1-efron_likelihood:73.60948
# [49]	validation_0-efron_likelihood:420.41628	validation_1-efron_likelihood:59.22802
# [50]	validation_0-efron_likelihood:420.31164	validation_1-efron_likelihood:59.23027[2]	validation_0-efron_likelihood:394.56960	validation_1-efron_likelihood:73.60429
#
# [51]	validation_0-efron_likelihood:420.07663	validation_1-efron_likelihood:59.18536
# [3]	validation_0-efron_likelihood:394.48156	validation_1-efron_likelihood:73.60967
# [52]	validation_0-efron_likelihood:419.99286	validation_1-efron_likelihood:59.12364
# [4]	validation_0-efron_likelihood:394.48156	validation_1-efron_likelihood:73.60967
# [53]	validation_0-efron_likelihood:419.83269	validation_1-efron_likelihood:59.06637
# [5]	validation_0-efron_likelihood:394.30230	validation_1-efron_likelihood:73.57060
# [54]	validation_0-efron_likelihood:419.72877	validation_1-efron_likelihood:59.04555
# [6]	validation_0-efron_likelihood:394.24473	validation_1-efron_likelihood:73.62937
# [55]	validation_0-efron_likelihood:419.48196	validation_1-efron_likelihood:59.09385
# [7]	validation_0-efron_likelihood:394.06729	validation_1-efron_likelihood:73.57889
# [56]	validation_0-efron_likelihood:419.23406	validation_1-efron_likelihood:59.14691
# [8]	validation_0-efron_likelihood:393.96336	validation_1-efron_likelihood:73.62559
# [9]	validation_0-efron_likelihood:393.77448	validation_1-efron_likelihood:73.58510
# [10]	validation_0-efron_likelihood:393.64159	validation_1-efron_likelihood:73.60894
# [11]	validation_0-efron_likelihood:393.64159	validation_1-efron_likelihood:73.60894
# [57]	validation_0-efron_likelihood:419.16379	validation_1-efron_likelihood:59.14977
# [12]	validation_0-efron_likelihood:393.55838	validation_1-efron_likelihood:73.60492
# [58]	validation_0-efron_likelihood:419.16379	validation_1-efron_likelihood:59.14977
# [13]	validation_0-efron_likelihood:393.46448	validation_1-efron_likelihood:73.62910
# [59]	validation_0-efron_likelihood:419.17170	validation_1-efron_likelihood:59.12617
# [14]	validation_0-efron_likelihood:393.46448	validation_1-efron_likelihood:73.62910
# [60]	validation_0-efron_likelihood:419.00807	validation_1-efron_likelihood:59.07397
# [61]	validation_0-efron_likelihood:419.00808	validation_1-efron_likelihood:59.07397
# [62]	validation_0-efron_likelihood:418.93226	validation_1-efron_likelihood:59.00256
# [63]	validation_0-efron_likelihood:418.87001	validation_1-efron_likelihood:58.99404
# [64]	validation_0-efron_likelihood:418.89469	validation_1-efron_likelihood:58.95054
# [65]	validation_0-efron_likelihood:418.70453	validation_1-efron_likelihood:58.83721
# [66]	validation_0-efron_likelihood:418.63746	validation_1-efron_likelihood:58.86341
# [67]	validation_0-efron_likelihood:418.53610	validation_1-efron_likelihood:58.82062
# [68]	validation_0-efron_likelihood:418.43962	validation_1-efron_likelihood:58.81435
# [69]	validation_0-efron_likelihood:418.42399	validation_1-efron_likelihood:58.81079
# [70]	validation_0-efron_likelihood:418.39005	validation_1-efron_likelihood:58.75077
# [71]	validation_0-efron_likelihood:418.31962	validation_1-efron_likelihood:58.77348
# [72]	validation_0-efron_likelihood:418.35266	validation_1-efron_likelihood:58.77697
# [73]	validation_0-efron_likelihood:418.26963	validation_1-efron_likelihood:58.79290
# [74]	validation_0-efron_likelihood:418.12810	validation_1-efron_likelihood:58.79290
# [75]	validation_0-efron_likelihood:418.11605	validation_1-efron_likelihood:58.78372
# [76]	validation_0-efron_likelihood:418.20535	validation_1-efron_likelihood:58.77742
# [77]	validation_0-efron_likelihood:418.13029	validation_1-efron_likelihood:58.79516
# [78]	validation_0-efron_likelihood:418.10675	validation_1-efron_likelihood:58.76924
# [79]	validation_0-efron_likelihood:418.10675	validation_1-efron_likelihood:58.76924
# [0]	validation_0-efron_likelihood:389.58408	validation_1-efron_likelihood:71.85300
# [1]	validation_0-efron_likelihood:389.52520	validation_1-efron_likelihood:71.85594
# [2]	validation_0-efron_likelihood:389.51212	validation_1-efron_likelihood:71.78745
# [3]	validation_0-efron_likelihood:389.50468	validation_1-efron_likelihood:71.77828
# [4]	validation_0-efron_likelihood:389.35239	validation_1-efron_likelihood:71.69027
# [5]	validation_0-efron_likelihood:389.31614	validation_1-efron_likelihood:71.67753
# [6]	validation_0-efron_likelihood:389.25502	validation_1-efron_likelihood:71.66432
# [7]	validation_0-efron_likelihood:389.10739	validation_1-efron_likelihood:71.61289
# [8]	validation_0-efron_likelihood:389.21919	validation_1-efron_likelihood:71.53951
# [9]	validation_0-efron_likelihood:389.13584	validation_1-efron_likelihood:71.51027
# [10]	validation_0-efron_likelihood:389.10908	validation_1-efron_likelihood:71.48212
# [11]	validation_0-efron_likelihood:389.11456	validation_1-efron_likelihood:71.49701
# [12]	validation_0-efron_likelihood:389.12569	validation_1-efron_likelihood:71.50449
# [13]	validation_0-efron_likelihood:389.09182	validation_1-efron_likelihood:71.49212
# [14]	validation_0-efron_likelihood:389.05869	validation_1-efron_likelihood:71.46578
# [15]	validation_0-efron_likelihood:388.98509	validation_1-efron_likelihood:71.44292
# [16]	validation_0-efron_likelihood:388.96666	validation_1-efron_likelihood:71.42196
# [17]	validation_0-efron_likelihood:388.91110	validation_1-efron_likelihood:71.42354
# [18]	validation_0-efron_likelihood:388.88531	validation_1-efron_likelihood:71.42307
# [19]	validation_0-efron_likelihood:388.85290	validation_1-efron_likelihood:71.41906
# [20]	validation_0-efron_likelihood:388.81230	validation_1-efron_likelihood:71.41478
# [21]	validation_0-efron_likelihood:388.73701	validation_1-efron_likelihood:71.40300
# [22]	validation_0-efron_likelihood:388.78100	validation_1-efron_likelihood:71.44069
# [23]	validation_0-efron_likelihood:388.67181	validation_1-efron_likelihood:71.41596
# [24]	validation_0-efron_likelihood:388.63029	validation_1-efron_likelihood:71.38514
# [25]	validation_0-efron_likelihood:388.55511	validation_1-efron_likelihood:71.37320
# [26]	validation_0-efron_likelihood:388.38685	validation_1-efron_likelihood:71.37959
# [27]	validation_0-efron_likelihood:388.33201	validation_1-efron_likelihood:71.38277
# [28]	validation_0-efron_likelihood:388.28280	validation_1-efron_likelihood:71.39515
# [29]	validation_0-efron_likelihood:388.24188	validation_1-efron_likelihood:71.38274
# [30]	validation_0-efron_likelihood:388.14229	validation_1-efron_likelihood:71.35717
# [31]	validation_0-efron_likelihood:388.09942	validation_1-efron_likelihood:71.35356
# [32]	validation_0-efron_likelihood:388.05281	validation_1-efron_likelihood:71.34666
# [33]	validation_0-efron_likelihood:387.99099	validation_1-efron_likelihood:71.30308
# [34]	validation_0-efron_likelihood:387.98209	validation_1-efron_likelihood:71.30108
# [35]	validation_0-efron_likelihood:387.92591	validation_1-efron_likelihood:71.30054
# [36]	validation_0-efron_likelihood:387.91808	validation_1-efron_likelihood:71.28393
# [37]	validation_0-efron_likelihood:387.93856	validation_1-efron_likelihood:71.17680
# [38]	validation_0-efron_likelihood:387.77628	validation_1-efron_likelihood:71.25933
# [39]	validation_0-efron_likelihood:387.76819	validation_1-efron_likelihood:71.22798
# [40]	validation_0-efron_likelihood:387.62009	validation_1-efron_likelihood:71.19108
# [41]	validation_0-efron_likelihood:387.62843	validation_1-efron_likelihood:71.20823
# [42]	validation_0-efron_likelihood:387.60095	validation_1-efron_likelihood:71.18228
# [43]	validation_0-efron_likelihood:387.54255	validation_1-efron_likelihood:71.16781
# [0]	validation_0-efron_likelihood:417.84900	validation_1-efron_likelihood:63.47391
# [1]	validation_0-efron_likelihood:417.67303	validation_1-efron_likelihood:63.48553
# [44]	validation_0-efron_likelihood:387.45832	validation_1-efron_likelihood:71.15989
# [2]	validation_0-efron_likelihood:417.46335	validation_1-efron_likelihood:63.46376
# [45]	validation_0-efron_likelihood:387.40496	validation_1-efron_likelihood:71.16578
# [46]	validation_0-efron_likelihood:387.32669	validation_1-efron_likelihood:71.17623
# [3]	validation_0-efron_likelihood:417.33372	validation_1-efron_likelihood:63.43699
# [4]	validation_0-efron_likelihood:417.35841	validation_1-efron_likelihood:63.50717
# [5]	validation_0-efron_likelihood:417.28821	validation_1-efron_likelihood:63.49209
# [6]	validation_0-efron_likelihood:417.24224	validation_1-efron_likelihood:63.56544
# [7]	validation_0-efron_likelihood:417.18010	validation_1-efron_likelihood:63.54893
# [8]	validation_0-efron_likelihood:417.13513	validation_1-efron_likelihood:63.58242
# [9]	validation_0-efron_likelihood:416.97918	validation_1-efron_likelihood:63.54780
# [10]	validation_0-efron_likelihood:416.97100	validation_1-efron_likelihood:63.59273
# [11]	validation_0-efron_likelihood:416.87285	validation_1-efron_likelihood:63.56873
# [12]	validation_0-efron_likelihood:416.81496	validation_1-efron_likelihood:63.52638
# [0]	validation_0-efron_likelihood:417.76330	validation_1-efron_likelihood:63.39294
# [1]	validation_0-efron_likelihood:417.71741	validation_1-efron_likelihood:63.46798
# [2]	validation_0-efron_likelihood:417.69072	validation_1-efron_likelihood:63.46567
# [3]	validation_0-efron_likelihood:417.65209	validation_1-efron_likelihood:63.47720
# [4]	validation_0-efron_likelihood:417.43634	validation_1-efron_likelihood:63.40248
# [5]	validation_0-efron_likelihood:417.43000	validation_1-efron_likelihood:63.42592
# [6]	validation_0-efron_likelihood:417.35044	validation_1-efron_likelihood:63.42417
# [7]	validation_0-efron_likelihood:417.26615	validation_1-efron_likelihood:63.43028
# [8]	validation_0-efron_likelihood:417.21883	validation_1-efron_likelihood:63.39380
# [9]	validation_0-efron_likelihood:417.13284	validation_1-efron_likelihood:63.35437
# [10]	validation_0-efron_likelihood:417.11455	validation_1-efron_likelihood:63.38029
# [11]	validation_0-efron_likelihood:417.10452	validation_1-efron_likelihood:63.39547
# [12]	validation_0-efron_likelihood:417.09751	validation_1-efron_likelihood:63.40094
# [13]	validation_0-efron_likelihood:417.10077	validation_1-efron_likelihood:63.41425
# [14]	validation_0-efron_likelihood:416.94846	validation_1-efron_likelihood:63.38451
# [15]	validation_0-efron_likelihood:416.90798	validation_1-efron_likelihood:63.36868
# [16]	validation_0-efron_likelihood:416.90823	validation_1-efron_likelihood:63.38358
# [17]	validation_0-efron_likelihood:416.79540	validation_1-efron_likelihood:63.38411
# [18]	validation_0-efron_likelihood:416.75940	validation_1-efron_likelihood:63.40835
# [0]	validation_0-efron_likelihood:389.66056	validation_1-efron_likelihood:71.79936
# [1]	validation_0-efron_likelihood:389.63373	validation_1-efron_likelihood:71.73877
# [2]	validation_0-efron_likelihood:389.45028	validation_1-efron_likelihood:71.66309
# [3]	validation_0-efron_likelihood:389.29247	validation_1-efron_likelihood:71.75270
# [4]	validation_0-efron_likelihood:389.21816	validation_1-efron_likelihood:71.78518
# [5]	validation_0-efron_likelihood:389.26102	validation_1-efron_likelihood:71.80001
# [6]	validation_0-efron_likelihood:389.15024	validation_1-efron_likelihood:71.81025
# [7]	validation_0-efron_likelihood:389.03596	validation_1-efron_likelihood:71.77841
# [8]	validation_0-efron_likelihood:389.04926	validation_1-efron_likelihood:71.81499
# [9]	validation_0-efron_likelihood:389.10478	validation_1-efron_likelihood:71.85073
# [10]	validation_0-efron_likelihood:389.03350	validation_1-efron_likelihood:71.81434
# [11]	validation_0-efron_likelihood:389.06841	validation_1-efron_likelihood:71.81598
# [0]	validation_0-efron_likelihood:550.78833	validation_1-efron_likelihood:73.15625
# [1]	validation_0-efron_likelihood:550.54605	validation_1-efron_likelihood:73.10350
# [2]	validation_0-efron_likelihood:550.54582	validation_1-efron_likelihood:73.10957
# [3]	validation_0-efron_likelihood:550.32763	validation_1-efron_likelihood:73.08852
# [4]	validation_0-efron_likelihood:550.31427	validation_1-efron_likelihood:73.07970
# [5]	validation_0-efron_likelihood:550.27192	validation_1-efron_likelihood:73.05430
# [6]	validation_0-efron_likelihood:550.26624	validation_1-efron_likelihood:73.03480
# [7]	validation_0-efron_likelihood:550.23337	validation_1-efron_likelihood:73.03233
# [8]	validation_0-efron_likelihood:550.21289	validation_1-efron_likelihood:73.03769
# [9]	validation_0-efron_likelihood:550.07520	validation_1-efron_likelihood:73.02546
# [10]	validation_0-efron_likelihood:550.03320	validation_1-efron_likelihood:73.11085
# [11]	validation_0-efron_likelihood:549.96075	validation_1-efron_likelihood:73.06980
# [12]	validation_0-efron_likelihood:549.88045	validation_1-efron_likelihood:73.10532
# [13]	validation_0-efron_likelihood:549.82208	validation_1-efron_likelihood:73.08060
# [14]	validation_0-efron_likelihood:549.82666	validation_1-efron_likelihood:73.11329
# [15]	validation_0-efron_likelihood:549.79808	validation_1-efron_likelihood:73.13683
# [16]	validation_0-efron_likelihood:549.77743	validation_1-efron_likelihood:73.14875
# [17]	validation_0-efron_likelihood:549.80757	validation_1-efron_likelihood:73.11246
# [18]	validation_0-efron_likelihood:549.76499	validation_1-efron_likelihood:73.11974
# [19]	validation_0-efron_likelihood:549.72347	validation_1-efron_likelihood:73.11365
# Concordance Index 0.6179558523465034
# Integrated Brier Score: 0.20858610684817797
# durations 15.0 3817.0
# Concordance Index 0.5363189513926816
# Integrated Brier Score: 0.2237939370856262
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-efron_likelihood:412.36543	validation_1-efron_likelihood:64.76864
# [1]	validation_0-efron_likelihood:412.15779	validation_1-efron_likelihood:64.72124
# [2]	validation_0-efron_likelihood:411.95976	validation_1-efron_likelihood:64.71952
# [3]	validation_0-efron_likelihood:411.71690	validation_1-efron_likelihood:64.67915
# [4]	validation_0-efron_likelihood:411.59702	validation_1-efron_likelihood:64.67244
# [5]	validation_0-efron_likelihood:411.50039	validation_1-efron_likelihood:64.66428
# [6]	validation_0-efron_likelihood:411.31112	validation_1-efron_likelihood:64.63564
# [7]	validation_0-efron_likelihood:411.13534	validation_1-efron_likelihood:64.62748
# [8]	validation_0-efron_likelihood:411.01099	validation_1-efron_likelihood:64.62655
# [9]	validation_0-efron_likelihood:410.83194	validation_1-efron_likelihood:64.60334
# [10]	validation_0-efron_likelihood:410.50524	validation_1-efron_likelihood:64.54580
# [0]	validation_0-efron_likelihood:406.69781	validation_1-efron_likelihood:66.73819
# [11]	validation_0-efron_likelihood:410.38445	validation_1-efron_likelihood:64.53447
# [1]	validation_0-efron_likelihood:406.52570	validation_1-efron_likelihood:66.76079
# [12]	validation_0-efron_likelihood:410.26102	validation_1-efron_likelihood:64.52632
# [2]	validation_0-efron_likelihood:406.33344	validation_1-efron_likelihood:66.73417
# [13]	validation_0-efron_likelihood:410.17875	validation_1-efron_likelihood:64.50900
# [3]	validation_0-efron_likelihood:406.15418	validation_1-efron_likelihood:66.76698
# [14]	validation_0-efron_likelihood:409.98867	validation_1-efron_likelihood:64.50006
# [4]	validation_0-efron_likelihood:405.95138	validation_1-efron_likelihood:66.68589
# [15]	validation_0-efron_likelihood:409.87617	validation_1-efron_likelihood:64.52509
# [5]	validation_0-efron_likelihood:405.72615	validation_1-efron_likelihood:66.63637
# [16]	validation_0-efron_likelihood:409.71563	validation_1-efron_likelihood:64.50199
# [6]	validation_0-efron_likelihood:405.49560	validation_1-efron_likelihood:66.56571
# [17]	validation_0-efron_likelihood:409.63987	validation_1-efron_likelihood:64.50948
# [7]	validation_0-efron_likelihood:405.29333	validation_1-efron_likelihood:66.53270
# [18]	validation_0-efron_likelihood:409.53359	validation_1-efron_likelihood:64.53644
# [8]	validation_0-efron_likelihood:405.07439	validation_1-efron_likelihood:66.53618
# [19]	validation_0-efron_likelihood:409.35586	validation_1-efron_likelihood:64.53526
# [9]	validation_0-efron_likelihood:404.84956	validation_1-efron_likelihood:66.47357
# [20]	validation_0-efron_likelihood:409.24304	validation_1-efron_likelihood:64.53293
# [10]	validation_0-efron_likelihood:404.68552	validation_1-efron_likelihood:66.48475
# [21]	validation_0-efron_likelihood:409.12390	validation_1-efron_likelihood:64.53288
# [22]	validation_0-efron_likelihood:409.00796	validation_1-efron_likelihood:64.55151
# [23]	validation_0-efron_likelihood:408.74958	validation_1-efron_likelihood:64.50964
# [24]	validation_0-efron_likelihood:408.53873	validation_1-efron_likelihood:64.48060
# [25]	validation_0-efron_likelihood:408.44442	validation_1-efron_likelihood:64.49799
# [26]	validation_0-efron_likelihood:408.32643	validation_1-efron_likelihood:64.52332
# [27]	validation_0-efron_likelihood:408.18507	validation_1-efron_likelihood:64.52398
# [11]	validation_0-efron_likelihood:404.51095	validation_1-efron_likelihood:66.46615
# [28]	validation_0-efron_likelihood:407.98324	validation_1-efron_likelihood:64.47256
# [12]	validation_0-efron_likelihood:404.33647	validation_1-efron_likelihood:66.41861
# [29]	validation_0-efron_likelihood:407.79522	validation_1-efron_likelihood:64.42594
# [13]	validation_0-efron_likelihood:404.17688	validation_1-efron_likelihood:66.42638
# [30]	validation_0-efron_likelihood:407.72275	validation_1-efron_likelihood:64.42865
# [14]	validation_0-efron_likelihood:404.02744	validation_1-efron_likelihood:66.42991[31]	validation_0-efron_likelihood:407.52148	validation_1-efron_likelihood:64.41055
#
# [32]	validation_0-efron_likelihood:407.37023	validation_1-efron_likelihood:64.39572
# [15]	validation_0-efron_likelihood:403.80132	validation_1-efron_likelihood:66.46187
# [33]	validation_0-efron_likelihood:407.26131	validation_1-efron_likelihood:64.37821
# [16]	validation_0-efron_likelihood:403.63619	validation_1-efron_likelihood:66.43431
# [34]	validation_0-efron_likelihood:407.15060	validation_1-efron_likelihood:64.35282
# [17]	validation_0-efron_likelihood:403.45962	validation_1-efron_likelihood:66.41330
# [35]	validation_0-efron_likelihood:407.01227	validation_1-efron_likelihood:64.34077
# [18]	validation_0-efron_likelihood:403.31041	validation_1-efron_likelihood:66.38335
# [36]	validation_0-efron_likelihood:406.79719	validation_1-efron_likelihood:64.33455
# [19]	validation_0-efron_likelihood:403.18331	validation_1-efron_likelihood:66.37295
# [20]	validation_0-efron_likelihood:403.01399	validation_1-efron_likelihood:66.34711[37]	validation_0-efron_likelihood:406.62276	validation_1-efron_likelihood:64.33400
#
# [38]	validation_0-efron_likelihood:406.46060	validation_1-efron_likelihood:64.33560
# [21]	validation_0-efron_likelihood:402.80056	validation_1-efron_likelihood:66.37035
# [39]	validation_0-efron_likelihood:406.31784	validation_1-efron_likelihood:64.31818
# [22]	validation_0-efron_likelihood:402.63597	validation_1-efron_likelihood:66.31570
# [40]	validation_0-efron_likelihood:406.21998	validation_1-efron_likelihood:64.30378
# [23]	validation_0-efron_likelihood:402.40382	validation_1-efron_likelihood:66.28774
# [41]	validation_0-efron_likelihood:406.03242	validation_1-efron_likelihood:64.26806
# [24]	validation_0-efron_likelihood:402.18754	validation_1-efron_likelihood:66.25022
# [42]	validation_0-efron_likelihood:405.91465	validation_1-efron_likelihood:64.28713
# [25]	validation_0-efron_likelihood:401.97522	validation_1-efron_likelihood:66.26580
# [43]	validation_0-efron_likelihood:405.67144	validation_1-efron_likelihood:64.28121
# [26]	validation_0-efron_likelihood:401.85211	validation_1-efron_likelihood:66.24226
# [44]	validation_0-efron_likelihood:405.56412	validation_1-efron_likelihood:64.30229
# [27]	validation_0-efron_likelihood:401.71115	validation_1-efron_likelihood:66.21325
# [45]	validation_0-efron_likelihood:405.43769	validation_1-efron_likelihood:64.31180
# [28]	validation_0-efron_likelihood:401.50681	validation_1-efron_likelihood:66.23154
# [46]	validation_0-efron_likelihood:405.28209	validation_1-efron_likelihood:64.28029
# ...
# [6]	validation_0-efron_likelihood:322.96987	validation_1-efron_likelihood:75.02175
# [7]	validation_0-efron_likelihood:321.63627	validation_1-efron_likelihood:74.89409
# [8]	validation_0-efron_likelihood:320.99351	validation_1-efron_likelihood:75.33679
# [9]	validation_0-efron_likelihood:318.96495	validation_1-efron_likelihood:75.26085
# [10]	validation_0-efron_likelihood:317.30911	validation_1-efron_likelihood:75.03872
# [0]	validation_0-efron_likelihood:323.50560	validation_1-efron_likelihood:68.03485
# [1]	validation_0-efron_likelihood:322.13244	validation_1-efron_likelihood:68.05342
# [2]	validation_0-efron_likelihood:320.47294	validation_1-efron_likelihood:67.99821
# [3]	validation_0-efron_likelihood:318.87708	validation_1-efron_likelihood:68.38906
# [4]	validation_0-efron_likelihood:317.32293	validation_1-efron_likelihood:68.61353
# [5]	validation_0-efron_likelihood:315.77546	validation_1-efron_likelihood:68.91678
# [6]	validation_0-efron_likelihood:313.75712	validation_1-efron_likelihood:68.32666
# [7]	validation_0-efron_likelihood:313.50078	validation_1-efron_likelihood:68.71946
# [8]	validation_0-efron_likelihood:310.63913	validation_1-efron_likelihood:67.96464
# [9]	validation_0-efron_likelihood:309.52588	validation_1-efron_likelihood:67.67436
# [10]	validation_0-efron_likelihood:307.94617	validation_1-efron_likelihood:68.24095
# [11]	validation_0-efron_likelihood:306.70359	validation_1-efron_likelihood:68.51906
# [12]	validation_0-efron_likelihood:305.17641	validation_1-efron_likelihood:68.44159
# [13]	validation_0-efron_likelihood:303.75349	validation_1-efron_likelihood:68.67513
# [14]	validation_0-efron_likelihood:302.64461	validation_1-efron_likelihood:69.31619
# [15]	validation_0-efron_likelihood:301.74410	validation_1-efron_likelihood:69.52530
# [16]	validation_0-efron_likelihood:301.20405	validation_1-efron_likelihood:68.80971
# [17]	validation_0-efron_likelihood:300.36426	validation_1-efron_likelihood:70.39910
# [18]	validation_0-efron_likelihood:299.79718	validation_1-efron_likelihood:70.37043
# [0]	validation_0-efron_likelihood:458.20256	validation_1-efron_likelihood:79.36800
# [1]	validation_0-efron_likelihood:455.38939	validation_1-efron_likelihood:79.46538
# [2]	validation_0-efron_likelihood:454.27417	validation_1-efron_likelihood:80.20726
# [3]	validation_0-efron_likelihood:452.21185	validation_1-efron_likelihood:80.50111
# [4]	validation_0-efron_likelihood:451.87774	validation_1-efron_likelihood:80.97441
# [5]	validation_0-efron_likelihood:450.69305	validation_1-efron_likelihood:81.56663
# [6]	validation_0-efron_likelihood:449.64509	validation_1-efron_likelihood:82.53027
# [7]	validation_0-efron_likelihood:448.58826	validation_1-efron_likelihood:83.18548
# [8]	validation_0-efron_likelihood:446.61067	validation_1-efron_likelihood:82.51491
# [9]	validation_0-efron_likelihood:444.74123	validation_1-efron_likelihood:82.99275
# [10]	validation_0-efron_likelihood:442.03172	validation_1-efron_likelihood:83.31516
# Concordance Index 0.27645558861028474
# Integrated Brier Score: 0.21720971303562303
# durations 3.0 2197.0
# Concordance Index 0.13980716253443526
# Integrated Brier Score: 0.2152236904541686
# (312, 19076) <class 'pandas.core.frame.DataFrame'>
# (312,) <class 'pandas.core.series.Series'>
# (77, 19076) <class 'pandas.core.frame.DataFrame'>
# (77,) <class 'pandas.core.series.Series'>
# [0]	validation_0-efron_likelihood:330.19922	validation_1-efron_likelihood:65.11558
# [1]	validation_0-efron_likelihood:326.26275	validation_1-efron_likelihood:64.42759
# [2]	validation_0-efron_likelihood:322.31509	validation_1-efron_likelihood:64.01981
# [3]	validation_0-efron_likelihood:319.90501	validation_1-efron_likelihood:64.02771
# [4]	validation_0-efron_likelihood:317.79351	validation_1-efron_likelihood:64.01669
# [5]	validation_0-efron_likelihood:316.87423	validation_1-efron_likelihood:63.97363
# [6]	validation_0-efron_likelihood:312.58053	validation_1-efron_likelihood:64.39912
# [7]	validation_0-efron_likelihood:311.77630	validation_1-efron_likelihood:64.57218
# [8]	validation_0-efron_likelihood:310.91703	validation_1-efron_likelihood:64.59352
# [9]	validation_0-efron_likelihood:309.35497	validation_1-efron_likelihood:63.97304
# [10]	validation_0-efron_likelihood:307.27019	validation_1-efron_likelihood:64.35723
# [11]	validation_0-efron_likelihood:306.38272	validation_1-efron_likelihood:64.77213
# [12]	validation_0-efron_likelihood:305.15370	validation_1-efron_likelihood:64.83837
# [13]	validation_0-efron_likelihood:303.31409	validation_1-efron_likelihood:65.00591
# [14]	validation_0-efron_likelihood:302.62761	validation_1-efron_likelihood:65.43313
# [15]	validation_0-efron_likelihood:300.34147	validation_1-efron_likelihood:65.49684
# [16]	validation_0-efron_likelihood:299.47684	validation_1-efron_likelihood:65.84738
# [17]	validation_0-efron_likelihood:297.89717	validation_1-efron_likelihood:66.39549
# [18]	validation_0-efron_likelihood:297.02786	validation_1-efron_likelihood:66.28465
# [19]	validation_0-efron_likelihood:296.13181	validation_1-efron_likelihood:66.35826
# [0]	validation_0-efron_likelihood:347.90095	validation_1-efron_likelihood:56.07794
# [1]	validation_0-efron_likelihood:345.43423	validation_1-efron_likelihood:56.95394
# [0]	validation_0-efron_likelihood:321.95023	validation_1-efron_likelihood:69.84658
# [1]	validation_0-efron_likelihood:320.07223	validation_1-efron_likelihood:70.66189
# [2]	validation_0-efron_likelihood:341.68482	validation_1-efron_likelihood:57.45064
# [2]	validation_0-efron_likelihood:316.96363	validation_1-efron_likelihood:71.47603
# [3]	validation_0-efron_likelihood:338.01216	validation_1-efron_likelihood:58.40122
# [3]	validation_0-efron_likelihood:316.13938	validation_1-efron_likelihood:71.97106
# [4]	validation_0-efron_likelihood:336.40406	validation_1-efron_likelihood:58.14242
# [5]	validation_0-efron_likelihood:335.57883	validation_1-efron_likelihood:58.39897
# [6]	validation_0-efron_likelihood:333.16076	validation_1-efron_likelihood:58.63490
# [7]	validation_0-efron_likelihood:330.53186	validation_1-efron_likelihood:58.55393
# [8]	validation_0-efron_likelihood:328.96246	validation_1-efron_likelihood:58.51455
# [9]	validation_0-efron_likelihood:327.54339	validation_1-efron_likelihood:58.22545
# [10]	validation_0-efron_likelihood:326.45912	validation_1-efron_likelihood:58.94362
# [4]	validation_0-efron_likelihood:314.57022	validation_1-efron_likelihood:71.40564
# [5]	validation_0-efron_likelihood:314.66777	validation_1-efron_likelihood:70.63504
# [6]	validation_0-efron_likelihood:311.79739	validation_1-efron_likelihood:71.31246
# [7]	validation_0-efron_likelihood:308.57669	validation_1-efron_likelihood:70.40923
# [8]	validation_0-efron_likelihood:308.29012	validation_1-efron_likelihood:70.61294
# [9]	validation_0-efron_likelihood:305.55921	validation_1-efron_likelihood:70.28074
# [10]	validation_0-efron_likelihood:303.48253	validation_1-efron_likelihood:70.65565
# [0]	validation_0-efron_likelihood:332.96789	validation_1-efron_likelihood:67.87863
# [1]	validation_0-efron_likelihood:332.09249	validation_1-efron_likelihood:68.83436
# [2]	validation_0-efron_likelihood:332.34640	validation_1-efron_likelihood:68.90211
# [3]	validation_0-efron_likelihood:330.90201	validation_1-efron_likelihood:69.15342
# [4]	validation_0-efron_likelihood:329.31232	validation_1-efron_likelihood:68.60262
# [5]	validation_0-efron_likelihood:327.57802	validation_1-efron_likelihood:68.82707
# [6]	validation_0-efron_likelihood:324.81982	validation_1-efron_likelihood:69.37506
# [7]	validation_0-efron_likelihood:321.28046	validation_1-efron_likelihood:70.29642
# [8]	validation_0-efron_likelihood:318.88656	validation_1-efron_likelihood:70.45302
# [9]	validation_0-efron_likelihood:317.70951	validation_1-efron_likelihood:70.74457
# [0]	validation_0-efron_likelihood:340.17193	validation_1-efron_likelihood:71.19521
# [1]	validation_0-efron_likelihood:348.46710	validation_1-efron_likelihood:71.06776
# [2]	validation_0-efron_likelihood:347.13799	validation_1-efron_likelihood:71.26117
# [3]	validation_0-efron_likelihood:350.41349	validation_1-efron_likelihood:75.37042
# [4]	validation_0-efron_likelihood:351.74816	validation_1-efron_likelihood:74.91491
# [5]	validation_0-efron_likelihood:353.47504	validation_1-efron_likelihood:75.28906
# [6]	validation_0-efron_likelihood:357.78430	validation_1-efron_likelihood:79.76148
# [7]	validation_0-efron_likelihood:369.14086	validation_1-efron_likelihood:81.33390
# [8]	validation_0-efron_likelihood:362.60853	validation_1-efron_likelihood:76.52432
# [9]	validation_0-efron_likelihood:354.36471	validation_1-efron_likelihood:77.57997
# [10]	validation_0-efron_likelihood:351.16132	validation_1-efron_likelihood:78.06927
# [11]	validation_0-efron_likelihood:347.82005	validation_1-efron_likelihood:81.96027
# [0]	validation_0-efron_likelihood:341.68131	validation_1-efron_likelihood:66.26189
# [1]	validation_0-efron_likelihood:338.85861	validation_1-efron_likelihood:66.07009
# [2]	validation_0-efron_likelihood:337.17703	validation_1-efron_likelihood:66.69495
# [3]	validation_0-efron_likelihood:335.37109	validation_1-efron_likelihood:66.55314
# [4]	validation_0-efron_likelihood:331.50824	validation_1-efron_likelihood:66.35661
# [5]	validation_0-efron_likelihood:327.49826	validation_1-efron_likelihood:65.95013
# [6]	validation_0-efron_likelihood:325.26917	validation_1-efron_likelihood:66.70628
# [7]	validation_0-efron_likelihood:323.55962	validation_1-efron_likelihood:67.14644
# [8]	validation_0-efron_likelihood:323.28463	validation_1-efron_likelihood:66.76578
# [9]	validation_0-efron_likelihood:322.44139	validation_1-efron_likelihood:65.81570
# [10]	validation_0-efron_likelihood:321.13427	validation_1-efron_likelihood:65.80622
# [11]	validation_0-efron_likelihood:317.36906	validation_1-efron_likelihood:66.56791
# [12]	validation_0-efron_likelihood:315.84854	validation_1-efron_likelihood:66.22165
# [13]	validation_0-efron_likelihood:314.06464	validation_1-efron_likelihood:66.31770
# [14]	validation_0-efron_likelihood:313.72298	validation_1-efron_likelihood:66.32577
# [15]	validation_0-efron_likelihood:312.44563	validation_1-efron_likelihood:67.20458
# [16]	validation_0-efron_likelihood:311.21999	validation_1-efron_likelihood:66.87277
# [17]	validation_0-efron_likelihood:309.89078	validation_1-efron_likelihood:66.41661
# [18]	validation_0-efron_likelihood:308.51188	validation_1-efron_likelihood:66.41494
# [19]	validation_0-efron_likelihood:307.23388	validation_1-efron_likelihood:67.18872
# [0]	validation_0-efron_likelihood:344.06704	validation_1-efron_likelihood:69.30913
# [1]	validation_0-efron_likelihood:354.75730	validation_1-efron_likelihood:73.76862
# [2]	validation_0-efron_likelihood:354.88164	validation_1-efron_likelihood:73.44156
# [3]	validation_0-efron_likelihood:358.43999	validation_1-efron_likelihood:72.67667
# [4]	validation_0-efron_likelihood:366.78953	validation_1-efron_likelihood:75.73662
# [5]	validation_0-efron_likelihood:369.11521	validation_1-efron_likelihood:74.02052
# [6]	validation_0-efron_likelihood:365.03643	validation_1-efron_likelihood:71.69770
# [7]	validation_0-efron_likelihood:365.78246	validation_1-efron_likelihood:72.26502
# [8]	validation_0-efron_likelihood:366.19419	validation_1-efron_likelihood:71.66431
# [9]	validation_0-efron_likelihood:365.76175	validation_1-efron_likelihood:72.23605
# [10]	validation_0-efron_likelihood:363.44883	validation_1-efron_likelihood:74.14086
# [0]	validation_0-efron_likelihood:349.25865	validation_1-efron_likelihood:55.96000
# [1]	validation_0-efron_likelihood:349.64489	validation_1-efron_likelihood:56.13198
# [2]	validation_0-efron_likelihood:349.99590	validation_1-efron_likelihood:55.58175
# [3]	validation_0-efron_likelihood:347.53433	validation_1-efron_likelihood:59.64802
# [4]	validation_0-efron_likelihood:347.53433	validation_1-efron_likelihood:59.64802
# [5]	validation_0-efron_likelihood:349.48873	validation_1-efron_likelihood:60.92949
# [6]	validation_0-efron_likelihood:351.00991	validation_1-efron_likelihood:60.16330
# [7]	validation_0-efron_likelihood:359.04364	validation_1-efron_likelihood:59.70452
# [8]	validation_0-efron_likelihood:356.63592	validation_1-efron_likelihood:61.04769
# [9]	validation_0-efron_likelihood:358.32160	validation_1-efron_likelihood:58.41456
# [10]	validation_0-efron_likelihood:368.40026	validation_1-efron_likelihood:61.20860
# [11]	validation_0-efron_likelihood:369.26308	validation_1-efron_likelihood:60.70938
# [12]	validation_0-efron_likelihood:364.37219	validation_1-efron_likelihood:62.56094
# [0]	validation_0-efron_likelihood:330.20076	validation_1-efron_likelihood:65.11952
# [1]	validation_0-efron_likelihood:330.20076	validation_1-efron_likelihood:65.11952
# [2]	validation_0-efron_likelihood:328.21397	validation_1-efron_likelihood:62.91461
# [3]	validation_0-efron_likelihood:324.55794	validation_1-efron_likelihood:66.67022
# [4]	validation_0-efron_likelihood:326.68050	validation_1-efron_likelihood:69.76259
# [5]	validation_0-efron_likelihood:326.13295	validation_1-efron_likelihood:70.59048
# [6]	validation_0-efron_likelihood:326.25439	validation_1-efron_likelihood:69.99301
# [7]	validation_0-efron_likelihood:327.61161	validation_1-efron_likelihood:69.89929
# [8]	validation_0-efron_likelihood:327.81020	validation_1-efron_likelihood:66.17140
# [9]	validation_0-efron_likelihood:342.50612	validation_1-efron_likelihood:68.64196
# [10]	validation_0-efron_likelihood:347.03714	validation_1-efron_likelihood:69.54903
# [11]	validation_0-efron_likelihood:356.03464	validation_1-efron_likelihood:70.76211
# [12]	validation_0-efron_likelihood:351.27490	validation_1-efron_likelihood:70.96484
# [0]	validation_0-efron_likelihood:324.36231	validation_1-efron_likelihood:69.56985
# [1]	validation_0-efron_likelihood:325.06886	validation_1-efron_likelihood:69.95526
# [2]	validation_0-efron_likelihood:323.82039	validation_1-efron_likelihood:68.94410
# [3]	validation_0-efron_likelihood:336.05264	validation_1-efron_likelihood:71.83106
# [4]	validation_0-efron_likelihood:338.34704	validation_1-efron_likelihood:73.21290
# [5]	validation_0-efron_likelihood:339.98801	validation_1-efron_likelihood:78.52741
# [6]	validation_0-efron_likelihood:340.54781	validation_1-efron_likelihood:81.61206
# [7]	validation_0-efron_likelihood:335.62823	validation_1-efron_likelihood:82.79939
# [8]	validation_0-efron_likelihood:339.62112	validation_1-efron_likelihood:78.25437
# [9]	validation_0-efron_likelihood:340.53426	validation_1-efron_likelihood:77.85303
# [10]	validation_0-efron_likelihood:354.29438	validation_1-efron_likelihood:81.28555
# [11]	validation_0-efron_likelihood:433.63649	validation_1-efron_likelihood:100.78208
# [0]	validation_0-efron_likelihood:444.39885	validation_1-efron_likelihood:90.98820
# [1]	validation_0-efron_likelihood:439.97793	validation_1-efron_likelihood:90.99502
# [2]	validation_0-efron_likelihood:438.65876	validation_1-efron_likelihood:90.56697
# [3]	validation_0-efron_likelihood:437.35236	validation_1-efron_likelihood:90.83566
# [4]	validation_0-efron_likelihood:432.60255	validation_1-efron_likelihood:90.95671
# [5]	validation_0-efron_likelihood:430.67716	validation_1-efron_likelihood:91.40226
# [6]	validation_0-efron_likelihood:427.91465	validation_1-efron_likelihood:90.47397
# [7]	validation_0-efron_likelihood:425.40317	validation_1-efron_likelihood:90.11042
# [8]	validation_0-efron_likelihood:422.77872	validation_1-efron_likelihood:90.50239
# [9]	validation_0-efron_likelihood:421.94368	validation_1-efron_likelihood:90.30743
# [10]	validation_0-efron_likelihood:417.25432	validation_1-efron_likelihood:91.79866
# [11]	validation_0-efron_likelihood:415.49535	validation_1-efron_likelihood:90.66327
# [12]	validation_0-efron_likelihood:414.39289	validation_1-efron_likelihood:90.80616
# [13]	validation_0-efron_likelihood:412.63009	validation_1-efron_likelihood:90.29156
# [14]	validation_0-efron_likelihood:411.43836	validation_1-efron_likelihood:90.32789
# [15]	validation_0-efron_likelihood:407.97278	validation_1-efron_likelihood:90.94728
# [16]	validation_0-efron_likelihood:405.38321	validation_1-efron_likelihood:92.89870
# Concordance Index 0.6769782943086652
# Integrated Brier Score: 0.1703866241614836
# durations 8.0 3519.0
# Concordance Index 0.5013245033112583
# Integrated Brier Score: 0.20527803274783793
