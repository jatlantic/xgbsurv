# %% [markdown]
# ## XGBSurv EH Benchmark

# %%
from xgbsurv.datasets import (load_metabric, load_flchain, load_rgbsg, load_support, load_tcga)
from xgbsurv import XGBSurv
from xgbsurv.evaluation import cindex_censored, ibs
from xgbsurv.models.utils import sort_X_y
import os
import numpy as np
import pandas as pd
from scipy.stats import uniform as scuniform
from scipy.stats import randint as scrandint
from scipy.stats import loguniform as scloguniform 
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, LabelBinarizer, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.decomposition import PCA
# import models
from xgbsurv.models.eh_final import eh_likelihood, get_cumulative_hazard_function_eh
from pycox.evaluation import EvalSurv
from xgbsurv.models.utils import sort_X_y, sort_X_y_pandas, transform_back, transform
from xgbsurv.preprocessing.dataset_preprocessing import discretizer_df
from sklearn.utils.fixes import loguniform

# %% [markdown]
# ## Set Path

# %%
current_path = os.getcwd()  # Get the current working directory path
two_levels_up = os.path.abspath(os.path.join(current_path, "..", ".."))
data_path = two_levels_up+'/xgbsurv/datasets/data/'

# %% [markdown]
# ## Set Parameters

# %%
# set parameters
n_outer_splits = 5
n_inner_splits = 5
rand_state = 42
n_iter = 1 #50 #0
early_stopping_rounds=10
base_score = 0.0
validation_size = 0.2
model = 'eh_'

# set seed for scipy
np.random.seed(rand_state)

# Define parameter grid for random forest classifier
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,40), # corresponds to num_rounds
'estimator__gamma': loguniform(0.001,1.0),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
}

# %% [markdown]
# ## Custom Splitting

# %%
class CustomSplit(StratifiedKFold):
    def __init__(self, n_splits=5, shuffle=True, random_state=None):
        super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)

    def split(self, X, y, groups=None):
        try:
            #if y.shape[1]>1:
            if y.ndim>1:
                y = y[:,0]
        except:
            pass
        try:
            if y.ndim>1:
                    y = y.iloc[:,0]
        except:
            pass
        bins = np.sign(y)
        return super().split(X, bins, groups=groups)

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

outer_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)
inner_custom_cv = CustomSplit(n_splits=n_outer_splits )#shuffle=True, random_state=rand_state

# %% [markdown]
# ## Scoring Function

# %%
scoring_function = make_scorer(eh_likelihood, greater_is_better=False)

#scoring_function = make_scorer(aft_likelihood, greater_is_better=False) #changed here
def custom_scoring_function(y_true, y_pred):

        if not isinstance(y_true, np.ndarray):
            y_true = y_true.values
        if not isinstance(y_pred, np.ndarray):
            y_pred = y_pred.values
        # change order of this later
        score = eh_likelihood(y_true, y_pred)
        return score #.numpy()

scoring_function = make_scorer(custom_scoring_function, greater_is_better=False)

# %%
## Set Basic Elements

ct = make_column_transformer(
        (StandardScaler(), make_column_selector(dtype_include=['float32'])),
        #(OneHotEncoder(sparse_output=False, handle_unknown='infrequent_if_exist'), make_column_selector(dtype_include=['category', 'object'])),
        remainder='passthrough')

estimator = XGBSurv(
    objective='eh_objective',
    eval_metric='eh_loss',
    random_state=rand_state, 
    disable_default_eval_metric=True,
    early_stopping_rounds=early_stopping_rounds, 
    base_score=base_score,
                    )
pipe = Pipeline([('scaler',ct),
                ('estimator', estimator)])
    
rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=n_iter, refit=True, 
                             random_state=rand_state, verbose=1,
                             error_score = 'raise')

# %%
## Save Results

# %%
metrics_sum = {}
agg_metrics_cindex = []
agg_metrics_ibs = []

# %% [markdown]
# ## METABRIC

# %%
data = load_metabric(path=data_path, as_frame=True)
filename = data.filename
dataset_name = filename.split('_')[0]
best_params = {'best_params_'+dataset_name:[]}
best_model = {'best_model_'+dataset_name:[]}
outer_scores = {'cindex_test_'+dataset_name:[],'ibs_test_'+dataset_name:[]}
X  = data.data 
y = data.target 
y = pd.concat([y,y], axis=1)
y.columns = ['target1', 'target2']
for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold

        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)
        rs.fit(X_train, y_train, estimator__eval_test_size=validation_size, estimator__verbose=0)
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [rs.best_estimator_.get_params]
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)

        np.savetxt('predictions/'+model+'best_preds_train_'+str(i)+'_'+filename, best_preds_train, delimiter=',')
        np.savetxt('predictions/'+model+'best_preds_test_'+str(i)+'_'+filename, best_preds_test, delimiter=',')

        cum_hazard_test = get_cumulative_hazard_function_eh(
                X_train.values, X_test.values, y_train.values, y_test.values,
                best_preds_train, best_preds_test
                )
        df_survival_test = np.exp(-cum_hazard_test)
        durations_test, events_test = transform_back(y_test.values[:,0])
        time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
        ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
        print('Concordance Index Test',ev.concordance_td('antolini'))
        print('Integrated Brier Score Test',ev.integrated_brier_score(time_grid_test))
        cindex_score_test = ev.concordance_td('antolini')
        ibs_score_test = ev.integrated_brier_score(time_grid_test)
        outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
        outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
df_best_params = pd.DataFrame(best_params)
df_best_model = pd.DataFrame(best_model)
df_outer_scores = pd.DataFrame(outer_scores)
df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# cindex
df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                        'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                        'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })
# IBS
df_agg_metrics_ibs = pd.DataFrame({'dataset':[dataset_name],
                                        'ibs_test_mean':df_outer_scores['ibs_test_'+dataset_name].mean(),
                                        'ibs_test_std':df_outer_scores['ibs_test_'+dataset_name].std() })
agg_metrics_cindex.append(df_agg_metrics_cindex)
agg_metrics_ibs.append(df_agg_metrics_ibs)
metrics_sum[model+dataset_name] = df_metrics
# Out:
# 2d
# Values have been sorted!
# 2d
# Values have been sorted!
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# integration_values.shape[0] 1315
# Concordance Index Test 0.6051545573588349
# Integrated Brier Score Test 0.18794617113315845
# 2d
# Values have been sorted!
# 2d
# Values have been sorted!
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# integration_values.shape[0] 1513
# Concordance Index Test 0.6064032724340696
# Integrated Brier Score Test 0.18499940653868646
# 2d
# Values have been sorted!
# 2d
# Values have been sorted!
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# integration_values.shape[0] 1738
# Concordance Index Test 0.6262117637729715
# Integrated Brier Score Test 0.1926349623925296
# 2d
# Values have been sorted!
# 2d
# Values have been sorted!
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# integration_values.shape[0] 1485
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 34
#      31 np.savetxt('predictions/'+model+'best_preds_train_'+str(i)+'_'+filename, best_preds_train, delimiter=',')
#      32 np.savetxt('predictions/'+model+'best_preds_test_'+str(i)+'_'+filename, best_preds_test, delimiter=',')
# ---> 34 cum_hazard_test = get_cumulative_hazard_function_eh(
#      35         X_train.values, X_test.values, y_train.values, y_test.values,
#      36         best_preds_train, best_preds_test
#      37         )
#      38 df_survival_test = np.exp(-cum_hazard_test)
#      39 durations_test, events_test = transform_back(y_test.values[:,0])
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/xgbsurv/models/eh_final.py:696, in get_cumulative_hazard_function_eh(X_train, X_test, y_train, y_test, predictor_train, predictor_test)
#     692 print('integration_values.shape[0]',integration_values.shape[0])
#     693 for _ in range(1, integration_values.shape[0]):
#     694     integration_values[_] = (
#     695         integration_values[_ - 1]
# --> 696         + quadrature(
#     697             func=hazard_function_integrate,
#     698             a=integration_times[_ - 1],
#     699             b=integration_times[_],
#     700             vec_func=False,
#     701         )[0]
#     702     )
#     704 for _ in range(n_samples):
#     705     cumulative_hazard[_] = (
#     706         integration_values[
#     707             np.digitize(
#    (...)
#     713         / theta[_, 0]
#     714     )
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/scipy/integrate/_quadrature.py:365, in quadrature(func, a, b, args, tol, rtol, maxiter, vec_func, miniter)
#     363 maxiter = max(miniter+1, maxiter)
#     364 for n in range(miniter, maxiter+1):
# --> 365     newval = fixed_quad(vfunc, a, b, (), n)[0]
#     366     err = abs(newval-val)
#     367     val = newval
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/scipy/integrate/_quadrature.py:245, in fixed_quad(func, a, b, args, n)
#     242     raise ValueError("Gaussian quadrature is only available for "
#     243                      "finite limits.")
#     244 y = (b-a)*(x+1)/2.0 + a
# --> 245 return (b-a)/2.0 * np.sum(w*func(y, *args), axis=-1), None
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/scipy/integrate/_quadrature.py:288, in vectorize1.<locals>.vfunc(x)
#     286 output[0] = y0
#     287 for i in range(1, n):
# --> 288     output[i] = func(x[i], *args)
#     289 return output
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/xgbsurv/models/eh_final.py:670, in get_cumulative_hazard_function_eh.<locals>.hazard_function_integrate(s)
#     669 def hazard_function_integrate(s):
# --> 670     return baseline_hazard_estimator_eh(
#     671         time=s,
#     672         time_train=time_train,
#     673         event_train=event_train,
#     674         predictor_train=predictor_train,
#     675     )
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/xgbsurv/models/eh_final.py:625, in baseline_hazard_estimator_eh(time, time_train, event_train, predictor_train)
#     623     denominator += h_prefactor[_] * gaussian_integrated_kernel(difference)
#     624     if event_train[_]:
# --> 625         numerator += gaussian_kernel(difference)
#     626 numerator = inverse_bandwidth_sample_size * numerator
#     627 denominator = inverse_sample_size * denominator
#
# KeyboardInterrupt:

# %% [markdown]
# ## FLCHAIN

# %%
data = load_flchain(path=data_path, as_frame=True)
filename = data.filename
dataset_name = filename.split('_')[0]
best_params = {'best_params_'+dataset_name:[]}
best_model = {'best_model_'+dataset_name:[]}
outer_scores = {'cindex_test_'+dataset_name:[],'ibs_test_'+dataset_name:[]}
X  = data.data 
y = data.target 
y = pd.concat([y,y], axis=1)
y.columns = ['target1', 'target2']
for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold

        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)
        rs.fit(X_train, y_train, estimator__eval_test_size=validation_size, estimator__verbose=0)
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [rs.best_estimator_.get_params]
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)

        np.savetxt('predictions/'+model+'best_preds_train_'+str(i)+'_'+filename, best_preds_train, delimiter=',')
        np.savetxt('predictions/'+model+'best_preds_test_'+str(i)+'_'+filename, best_preds_test, delimiter=',')

        cum_hazard_test = get_cumulative_hazard_function_eh(
                X_train.values, X_test.values, y_train.values, y_test.values,
                best_preds_train, best_preds_test
                )
        df_survival_test = np.exp(-cum_hazard_test)
        durations_test, events_test = transform_back(y_test.values[:,0])
        time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
        ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
        print('Concordance Index Test',ev.concordance_td('antolini'))
        print('Integrated Brier Score Test',ev.integrated_brier_score(time_grid_test))
        cindex_score_test = ev.concordance_td('antolini')
        ibs_score_test = ev.integrated_brier_score(time_grid_test)
        outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
        outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
df_best_params = pd.DataFrame(best_params)
df_best_model = pd.DataFrame(best_model)
df_outer_scores = pd.DataFrame(outer_scores)
df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# cindex
df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                        'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                        'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })
# IBS
df_agg_metrics_ibs = pd.DataFrame({'dataset':[dataset_name],
                                        'ibs_test_mean':df_outer_scores['ibs_test_'+dataset_name].mean(),
                                        'ibs_test_std':df_outer_scores['ibs_test_'+dataset_name].std() })
agg_metrics_cindex.append(df_agg_metrics_cindex)
agg_metrics_ibs.append(df_agg_metrics_ibs)
metrics_sum[model+dataset_name] = df_metrics

# %% [markdown]
# ## RGBSG

# %%
data = load_rgbsg(path=data_path, as_frame=True)
filename = data.filename
dataset_name = filename.split('_')[0]
best_params = {'best_params_'+dataset_name:[]}
best_model = {'best_model_'+dataset_name:[]}
outer_scores = {'cindex_test_'+dataset_name:[],'ibs_test_'+dataset_name:[]}
X  = data.data 
y = data.target 
y = pd.concat([y,y], axis=1)
y.columns = ['target1', 'target2']
for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold

        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)
        rs.fit(X_train, y_train, estimator__eval_test_size=validation_size, estimator__verbose=0)
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [rs.best_estimator_.get_params]
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)

        np.savetxt('predictions/'+model+'best_preds_train_'+str(i)+'_'+filename, best_preds_train, delimiter=',')
        np.savetxt('predictions/'+model+'best_preds_test_'+str(i)+'_'+filename, best_preds_test, delimiter=',')

        cum_hazard_test = get_cumulative_hazard_function_eh(
                X_train.values, X_test.values, y_train.values, y_test.values,
                best_preds_train, best_preds_test
                )
        df_survival_test = np.exp(-cum_hazard_test)
        durations_test, events_test = transform_back(y_test.values[:,0])
        time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
        ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
        print('Concordance Index Test',ev.concordance_td('antolini'))
        print('Integrated Brier Score Test',ev.integrated_brier_score(time_grid_test))
        cindex_score_test = ev.concordance_td('antolini')
        ibs_score_test = ev.integrated_brier_score(time_grid_test)
        outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
        outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
df_best_params = pd.DataFrame(best_params)
df_best_model = pd.DataFrame(best_model)
df_outer_scores = pd.DataFrame(outer_scores)
df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# cindex
df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                        'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                        'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })
# IBS
df_agg_metrics_ibs = pd.DataFrame({'dataset':[dataset_name],
                                        'ibs_test_mean':df_outer_scores['ibs_test_'+dataset_name].mean(),
                                        'ibs_test_std':df_outer_scores['ibs_test_'+dataset_name].std() })
agg_metrics_cindex.append(df_agg_metrics_cindex)
agg_metrics_ibs.append(df_agg_metrics_ibs)
metrics_sum[model+dataset_name] = df_metrics

# %%
## SUPPORT

# %%
data = load_support(path=data_path, as_frame=True)
filename = data.filename
dataset_name = filename.split('_')[0]
best_params = {'best_params_'+dataset_name:[]}
best_model = {'best_model_'+dataset_name:[]}
outer_scores = {'cindex_test_'+dataset_name:[],'ibs_test_'+dataset_name:[]}
X  = data.data 
y = data.target 
y = pd.concat([y,y], axis=1)
y.columns = ['target1', 'target2']
for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold

        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)
        rs.fit(X_train, y_train, estimator__eval_test_size=validation_size, estimator__verbose=0)
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [rs.best_estimator_.get_params]
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)

        np.savetxt('predictions/'+model+'best_preds_train_'+str(i)+'_'+filename, best_preds_train, delimiter=',')
        np.savetxt('predictions/'+model+'best_preds_test_'+str(i)+'_'+filename, best_preds_test, delimiter=',')

        cum_hazard_test = get_cumulative_hazard_function_eh(
                X_train.values, X_test.values, y_train.values, y_test.values,
                best_preds_train, best_preds_test
                )
        df_survival_test = np.exp(-cum_hazard_test)
        durations_test, events_test = transform_back(y_test.values[:,0])
        time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
        ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
        print('Concordance Index Test',ev.concordance_td('antolini'))
        print('Integrated Brier Score Test',ev.integrated_brier_score(time_grid_test))
        cindex_score_test = ev.concordance_td('antolini')
        ibs_score_test = ev.integrated_brier_score(time_grid_test)
        outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
        outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
df_best_params = pd.DataFrame(best_params)
df_best_model = pd.DataFrame(best_model)
df_outer_scores = pd.DataFrame(outer_scores)
df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# cindex
df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                        'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                        'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })
# IBS
df_agg_metrics_ibs = pd.DataFrame({'dataset':[dataset_name],
                                        'ibs_test_mean':df_outer_scores['ibs_test_'+dataset_name].mean(),
                                        'ibs_test_std':df_outer_scores['ibs_test_'+dataset_name].std() })
agg_metrics_cindex.append(df_agg_metrics_cindex)
agg_metrics_ibs.append(df_agg_metrics_ibs)
metrics_sum[model+dataset_name] = df_metrics

# %%
durations_test, events_test = transform_back(y_test.values[:,0])
df_survival_test
# Out:
#                  0         1         2         3         4         5    \
# 0.766667    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1.766667    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2.400000    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2.533333    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 5.066667    0.996091  0.996144  0.996171  0.995482  0.995230  0.996218
# ...              ...       ...       ...       ...       ...       ...
# 296.866669  0.255709  0.261741  0.263207  0.205819  0.190055  0.267344
# 307.633331  0.242254  0.248127  0.249802  0.193200  0.177494  0.253686
# 318.200012  0.229448  0.235878  0.236872  0.181726  0.167008  0.241080
# 335.600006  0.210975  0.216628  0.217416  0.164388  0.149863  0.221516
# 337.033325  0.209446  0.214658  0.216383  0.162923  0.148357  0.219860
#
#                  6         7         8         9    ...       371       372  \
# 0.766667    1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 1.766667    1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 2.400000    1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 2.533333    1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 5.066667    0.996729  0.995073  0.996724  0.995632  ...  0.996362  0.995931
# ...              ...       ...       ...       ...  ...       ...       ...
# 296.866669  0.317183  0.176312  0.318913  0.214946  ...  0.278027  0.241700
# 307.633331  0.302936  0.164665  0.305228  0.202158  ...  0.264582  0.228386
# 318.200012  0.289581  0.154305  0.291660  0.190316  ...  0.251564  0.216204
# 335.600006  0.269100  0.137716  0.271039  0.172412  ...  0.232678  0.197266
# 337.033325  0.268404  0.136287  0.269937  0.171488  ...  0.230361  0.195722
#
#                  373       374       375       376       377       378  \
# 0.766667    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1.766667    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2.400000    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2.533333    1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 5.066667    0.996787  0.995797  0.995990  0.996609  0.996304  0.995907
# ...              ...       ...       ...       ...       ...       ...
# 296.866669  0.323125  0.230536  0.244580  0.305344  0.271432  0.238843
# 307.633331  0.309309  0.217495  0.231356  0.291242  0.257561  0.225809
# 318.200012  0.295928  0.205260  0.218868  0.277893  0.245234  0.213245
# 335.600006  0.274790  0.188211  0.200379  0.257748  0.226216  0.194749
# 337.033325  0.274790  0.185891  0.198410  0.256963  0.223733  0.193109
#
#                  379       380
# 0.766667    1.000000  1.000000
# 1.766667    1.000000  1.000000
# 2.400000    1.000000  1.000000
# 2.533333    1.000000  1.000000
# 5.066667    0.996513  0.996546
# ...              ...       ...
# 296.866669  0.293077  0.300484
# 307.633331  0.279250  0.286171
# 318.200012  0.265772  0.273244
# 335.600006  0.246095  0.252811
# 337.033325  0.244286  0.251400
#
# [381 rows x 381 columns]

# %%
y_test
# Out:
#         target1     target2
# 0     -0.766667   -0.766667
# 1     -1.766667   -1.766667
# 2     -2.400000   -2.400000
# 3     -2.533333   -2.533333
# 4      5.066667    5.066667
# ..          ...         ...
# 376 -296.866669 -296.866669
# 377 -307.633331 -307.633331
# 378 -318.200012 -318.200012
# 379  335.600006  335.600006
# 380 -337.033325 -337.033325
#
# [381 rows x 2 columns]

# %%
ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')

# %% [markdown]
# ## Set Model & Train Test Evaluate

# %%
data_set_fns = [load_metabric,  load_flchain, load_rgbsg, load_support] #, load_flchain, load_rgbsg, load_support, load_tcga]
data_set_fns_str = ['load_metabric', 'load_flchain', 'load_rgbsg', 'load_support'] 
one_hot_dict = {'load_flchain': ['mgus'], 'load_support':['cancer', 'race'], 'load_rgbsg':['grade']}
agg_metrics_cindex = []
agg_metrics_ibs = []

for idx, dataset in enumerate([load_metabric]):#data_set_fns
    model = 'xgbsurv_eh_'
    # get name of current dataset
    data = dataset(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=True)
    filename = data.filename
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()
    X, y = sort_X_y_pandas(X, y)
    y = pd.concat([y,y], axis=1)
    print(data_set_fns_str[idx])
    #if data_set_fns_str[idx] in one_hot_dict.keys():
    #   X = pd.get_dummies(X, columns=one_hot_dict[data_set_fns_str[idx]])

    dataset_name = filename.split('_')[0]
    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            (StandardScaler(), make_column_selector(dtype_include=['float32'])),
            #(OneHotEncoder(sparse_output=False, handle_unknown='infrequent_if_exist'), make_column_selector(dtype_include=['category', 'object'])),
            remainder='passthrough')
    
    estimator = XGBSurv(
        objective='eh_objective',
        eval_metric='eh_loss',
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score,
        random_state=rand_state, 
                        )
    pipe = Pipeline([('scaler',ct),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=n_iter, refit=True, random_state=rand_state)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)
        # print('input',X_train, y_train)
        # print(X_train.shape, type(X_train))
        # print(y_train.shape, type(y_train))
        # print(y_test.shape, type(y_test))
        # print(X_test.shape, type(X_test))
        # # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        #np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        #np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        #np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        #np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train.values, estimator__eval_test_size=validation_size)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        np.savetxt('predictions/'+model+'best_preds_train_'+str(i)+'_'+filename, best_preds_train, delimiter=',')
        np.savetxt('predictions/'+model+'best_preds_test_'+str(i)+'_'+filename, best_preds_test, delimiter=',')


        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_eh(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train, best_preds_train
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_eh(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train, best_preds_test
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
    # cindex
    df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                            'cindex_train_mean':df_outer_scores['cindex_train_'+dataset_name].mean(),
                                            'cindex_train_std':df_outer_scores['cindex_train_'+dataset_name].std(),
                                            'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                            'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })
    # IBS
    df_agg_metrics_ibs = pd.DataFrame({'dataset':[dataset_name],
                                            'ibs_train_mean':df_outer_scores['ibs_train_'+dataset_name].mean(),
                                            'ibs_train_std':df_outer_scores['ibs_train_'+dataset_name].std(),
                                            'ibs_test_mean':df_outer_scores['ibs_test_'+dataset_name].mean(),
                                            'ibs_test_std':df_outer_scores['ibs_test_'+dataset_name].std() })
    agg_metrics_cindex.append(df_agg_metrics_cindex)
    agg_metrics_ibs.append(df_agg_metrics_ibs)

df_final_breslow_1_cindex = pd.concat([df for df in agg_metrics_cindex]).round(4)
df_final_breslow_1_cindex.to_csv('metrics/final_gbdt_eh_1_cindex.csv', index=False)
df_final_breslow_1_cindex.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_eh_1_cindex.csv', index=False)  #


df_final_breslow_1_ibs = pd.concat([df for df in agg_metrics_ibs]).round(4)
df_final_breslow_1_ibs.to_csv('metrics/final_gbdt_eh_1_ibs.csv', index=False)
df_final_breslow_1_ibs.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_eh_1_ibs.csv', index=False)
# Out:
# load_metabric
# [0]	validation_0-eh_likelihood:1762.92477	validation_1-eh_likelihood:439.71873
# [0]	validation_0-eh_likelihood:1760.03405	validation_1-eh_likelihood:441.78919
# [0]	validation_0-eh_likelihood:1765.52884	validation_1-eh_likelihood:440.28058
# [1]	validation_0-eh_likelihood:1762.86759	validation_1-eh_likelihood:439.70309
# [0]	validation_0-eh_likelihood:1759.67685	validation_1-eh_likelihood:440.04797
# [0]	validation_0-eh_likelihood:1762.31200	validation_1-eh_likelihood:439.95551
# [1]	validation_0-eh_likelihood:1760.03405	validation_1-eh_likelihood:441.78919
# [1]	validation_0-eh_likelihood:1765.48037	validation_1-eh_likelihood:440.27266
# [1]	validation_0-eh_likelihood:1759.67132	validation_1-eh_likelihood:440.04563
# [2]	validation_0-eh_likelihood:1762.86051	validation_1-eh_likelihood:439.70033
# [1]	validation_0-eh_likelihood:1762.23113	validation_1-eh_likelihood:439.94790
# [2]	validation_0-eh_likelihood:1760.00994	validation_1-eh_likelihood:441.78479
# [2]	validation_0-eh_likelihood:1765.48758	validation_1-eh_likelihood:440.26506
# [2]	validation_0-eh_likelihood:1759.66946	validation_1-eh_likelihood:440.05038
# [3]	validation_0-eh_likelihood:1762.85838	validation_1-eh_likelihood:439.70109
# [2]	validation_0-eh_likelihood:1762.19979	validation_1-eh_likelihood:439.94655
# [3]	validation_0-eh_likelihood:1760.02629	validation_1-eh_likelihood:441.78244
# [3]	validation_0-eh_likelihood:1765.44021	validation_1-eh_likelihood:440.26063
# [3]	validation_0-eh_likelihood:1759.65629	validation_1-eh_likelihood:440.04675
# [4]	validation_0-eh_likelihood:1762.79528	validation_1-eh_likelihood:439.68655
# [3]	validation_0-eh_likelihood:1762.15535	validation_1-eh_likelihood:439.93299
# [4]	validation_0-eh_likelihood:1760.04068	validation_1-eh_likelihood:441.78148
# [4]	validation_0-eh_likelihood:1765.40021	validation_1-eh_likelihood:440.25340
# [4]	validation_0-eh_likelihood:1759.64310	validation_1-eh_likelihood:440.04060
# [4]	validation_0-eh_likelihood:1762.12919	validation_1-eh_likelihood:439.92105
# [5]	validation_0-eh_likelihood:1762.73513	validation_1-eh_likelihood:439.67443
# [5]	validation_0-eh_likelihood:1760.02013	validation_1-eh_likelihood:441.78439
# [5]	validation_0-eh_likelihood:1765.35123	validation_1-eh_likelihood:440.24705
# [5]	validation_0-eh_likelihood:1759.60650	validation_1-eh_likelihood:440.03423
# [5]	validation_0-eh_likelihood:1762.03885	validation_1-eh_likelihood:439.89515
# [6]	validation_0-eh_likelihood:1762.73513	validation_1-eh_likelihood:439.67443
# [6]	validation_0-eh_likelihood:1760.02013	validation_1-eh_likelihood:441.78439
# [6]	validation_0-eh_likelihood:1765.35123	validation_1-eh_likelihood:440.24705
# [6]	validation_0-eh_likelihood:1762.00951	validation_1-eh_likelihood:439.89197
# [7]	validation_0-eh_likelihood:1762.68429	validation_1-eh_likelihood:439.66065
# [6]	validation_0-eh_likelihood:1759.55153	validation_1-eh_likelihood:440.02076
# [7]	validation_0-eh_likelihood:1760.02013	validation_1-eh_likelihood:441.78439
# [7]	validation_0-eh_likelihood:1765.26405	validation_1-eh_likelihood:440.24023
# [8]	validation_0-eh_likelihood:1762.63484	validation_1-eh_likelihood:439.64193
# [7]	validation_0-eh_likelihood:1759.53370	validation_1-eh_likelihood:440.01381
# [7]	validation_0-eh_likelihood:1761.87608	validation_1-eh_likelihood:439.85661
# [8]	validation_0-eh_likelihood:1759.99940	validation_1-eh_likelihood:441.78553
# [9]	validation_0-eh_likelihood:1762.55648	validation_1-eh_likelihood:439.63429
# [8]	validation_0-eh_likelihood:1765.17223	validation_1-eh_likelihood:440.22348
# [8]	validation_0-eh_likelihood:1761.80556	validation_1-eh_likelihood:439.83364
# [8]	validation_0-eh_likelihood:1759.49871	validation_1-eh_likelihood:440.00454
# [9]	validation_0-eh_likelihood:1759.99940	validation_1-eh_likelihood:441.78553
# [10]	validation_0-eh_likelihood:1762.54296	validation_1-eh_likelihood:439.63075
# [9]	validation_0-eh_likelihood:1765.16297	validation_1-eh_likelihood:440.21923
# [9]	validation_0-eh_likelihood:1761.71651	validation_1-eh_likelihood:439.80914
# [9]	validation_0-eh_likelihood:1759.49871	validation_1-eh_likelihood:440.00454
# [10]	validation_0-eh_likelihood:1759.91993	validation_1-eh_likelihood:441.76134
# [11]	validation_0-eh_likelihood:1762.43695	validation_1-eh_likelihood:439.60516
# [10]	validation_0-eh_likelihood:1765.16650	validation_1-eh_likelihood:440.21810
# [10]	validation_0-eh_likelihood:1759.39414	validation_1-eh_likelihood:439.98551
# [10]	validation_0-eh_likelihood:1761.68906	validation_1-eh_likelihood:439.80358
# [11]	validation_0-eh_likelihood:1759.91993	validation_1-eh_likelihood:441.76134
# [12]	validation_0-eh_likelihood:1762.38293	validation_1-eh_likelihood:439.59102
# [11]	validation_0-eh_likelihood:1759.39414	validation_1-eh_likelihood:439.98551
# [11]	validation_0-eh_likelihood:1765.08057	validation_1-eh_likelihood:440.20281
# [11]	validation_0-eh_likelihood:1761.62846	validation_1-eh_likelihood:439.78642
# [12]	validation_0-eh_likelihood:1759.91362	validation_1-eh_likelihood:441.76067
# [13]	validation_0-eh_likelihood:1762.34918	validation_1-eh_likelihood:439.58161
# [12]	validation_0-eh_likelihood:1759.39854	validation_1-eh_likelihood:439.98297
# [12]	validation_0-eh_likelihood:1765.08021	validation_1-eh_likelihood:440.20202
# [12]	validation_0-eh_likelihood:1761.59263	validation_1-eh_likelihood:439.77343
# [13]	validation_0-eh_likelihood:1759.83590	validation_1-eh_likelihood:441.74190
# [14]	validation_0-eh_likelihood:1762.35815	validation_1-eh_likelihood:439.58336
# [13]	validation_0-eh_likelihood:1759.36947	validation_1-eh_likelihood:439.97430
# [13]	validation_0-eh_likelihood:1765.07670	validation_1-eh_likelihood:440.19995
# [13]	validation_0-eh_likelihood:1761.56689	validation_1-eh_likelihood:439.77097
# [14]	validation_0-eh_likelihood:1759.81338	validation_1-eh_likelihood:441.73108
# [15]	validation_0-eh_likelihood:1762.34498	validation_1-eh_likelihood:439.58297
# [14]	validation_0-eh_likelihood:1759.33716	validation_1-eh_likelihood:439.96989
# [14]	validation_0-eh_likelihood:1765.08876	validation_1-eh_likelihood:440.20075
# [14]	validation_0-eh_likelihood:1761.54706	validation_1-eh_likelihood:439.76927
# [15]	validation_0-eh_likelihood:1759.79840	validation_1-eh_likelihood:441.73544
# [16]	validation_0-eh_likelihood:1762.28508	validation_1-eh_likelihood:439.56729
# [15]	validation_0-eh_likelihood:1759.33716	validation_1-eh_likelihood:439.96989
# [15]	validation_0-eh_likelihood:1765.09160	validation_1-eh_likelihood:440.20332
# [15]	validation_0-eh_likelihood:1761.54706	validation_1-eh_likelihood:439.76927
# [16]	validation_0-eh_likelihood:1759.81848	validation_1-eh_likelihood:441.73569
# [17]	validation_0-eh_likelihood:1762.24143	validation_1-eh_likelihood:439.55478
# [16]	validation_0-eh_likelihood:1759.28124	validation_1-eh_likelihood:439.96149
# [16]	validation_0-eh_likelihood:1765.00541	validation_1-eh_likelihood:440.19127
# [16]	validation_0-eh_likelihood:1761.48669	validation_1-eh_likelihood:439.75622
# [17]	validation_0-eh_likelihood:1759.81848	validation_1-eh_likelihood:441.73569
# [18]	validation_0-eh_likelihood:1762.20860	validation_1-eh_likelihood:439.55446
# [17]	validation_0-eh_likelihood:1759.24927	validation_1-eh_likelihood:439.95895
# [17]	validation_0-eh_likelihood:1764.98710	validation_1-eh_likelihood:440.18541
# [17]	validation_0-eh_likelihood:1761.43368	validation_1-eh_likelihood:439.73691
# [18]	validation_0-eh_likelihood:1759.81410	validation_1-eh_likelihood:441.73575
# [19]	validation_0-eh_likelihood:1762.20860	validation_1-eh_likelihood:439.55446
# [18]	validation_0-eh_likelihood:1759.24927	validation_1-eh_likelihood:439.95895
# [18]	validation_0-eh_likelihood:1764.95846	validation_1-eh_likelihood:440.18192
# [18]	validation_0-eh_likelihood:1761.38630	validation_1-eh_likelihood:439.72474
# [19]	validation_0-eh_likelihood:1759.83136	validation_1-eh_likelihood:441.72668
# [20]	validation_0-eh_likelihood:1762.17982	validation_1-eh_likelihood:439.54870
# [19]	validation_0-eh_likelihood:1759.24927	validation_1-eh_likelihood:439.95895
# [19]	validation_0-eh_likelihood:1764.94455	validation_1-eh_likelihood:440.17756
# [19]	validation_0-eh_likelihood:1761.38630	validation_1-eh_likelihood:439.72474
# [20]	validation_0-eh_likelihood:1759.80697	validation_1-eh_likelihood:441.72375
# [21]	validation_0-eh_likelihood:1762.15756	validation_1-eh_likelihood:439.53776
# [20]	validation_0-eh_likelihood:1759.24927	validation_1-eh_likelihood:439.95895
# [20]	validation_0-eh_likelihood:1761.38630	validation_1-eh_likelihood:439.72474
# [20]	validation_0-eh_likelihood:1764.92907	validation_1-eh_likelihood:440.17871
# [21]	validation_0-eh_likelihood:1759.75440	validation_1-eh_likelihood:441.70897
# [22]	validation_0-eh_likelihood:1762.13658	validation_1-eh_likelihood:439.52725
# [21]	validation_0-eh_likelihood:1759.16393	validation_1-eh_likelihood:439.94500
# [21]	validation_0-eh_likelihood:1761.34390	validation_1-eh_likelihood:439.71507
# [21]	validation_0-eh_likelihood:1764.89642	validation_1-eh_likelihood:440.17202
# [22]	validation_0-eh_likelihood:1759.71742	validation_1-eh_likelihood:441.71096
# [23]	validation_0-eh_likelihood:1762.13658	validation_1-eh_likelihood:439.52725
# [22]	validation_0-eh_likelihood:1759.16393	validation_1-eh_likelihood:439.94500
# [22]	validation_0-eh_likelihood:1761.32555	validation_1-eh_likelihood:439.71693
# [22]	validation_0-eh_likelihood:1764.89642	validation_1-eh_likelihood:440.17202
# [23]	validation_0-eh_likelihood:1759.71742	validation_1-eh_likelihood:441.71096
# [24]	validation_0-eh_likelihood:1762.13047	validation_1-eh_likelihood:439.52396
# [23]	validation_0-eh_likelihood:1759.16393	validation_1-eh_likelihood:439.94500
# [23]	validation_0-eh_likelihood:1761.32953	validation_1-eh_likelihood:439.72064
# [23]	validation_0-eh_likelihood:1764.86633	validation_1-eh_likelihood:440.17365
# [24]	validation_0-eh_likelihood:1759.67629	validation_1-eh_likelihood:441.70213
# [25]	validation_0-eh_likelihood:1762.09328	validation_1-eh_likelihood:439.51633
# [24]	validation_0-eh_likelihood:1759.12523	validation_1-eh_likelihood:439.93327
# [24]	validation_0-eh_likelihood:1764.86633	validation_1-eh_likelihood:440.17365
# [24]	validation_0-eh_likelihood:1761.27781	validation_1-eh_likelihood:439.70534
# [25]	validation_0-eh_likelihood:1759.61245	validation_1-eh_likelihood:441.70445
# [26]	validation_0-eh_likelihood:1762.08092	validation_1-eh_likelihood:439.51156
# [25]	validation_0-eh_likelihood:1759.02151	validation_1-eh_likelihood:439.91227
# [25]	validation_0-eh_likelihood:1764.80086	validation_1-eh_likelihood:440.16833
# [25]	validation_0-eh_likelihood:1761.26816	validation_1-eh_likelihood:439.70062
# [26]	validation_0-eh_likelihood:1759.60091	validation_1-eh_likelihood:441.70259
# [27]	validation_0-eh_likelihood:1762.05419	validation_1-eh_likelihood:439.50897
# [26]	validation_0-eh_likelihood:1758.99598	validation_1-eh_likelihood:439.90810
# [26]	validation_0-eh_likelihood:1761.20237	validation_1-eh_likelihood:439.68921
# [26]	validation_0-eh_likelihood:1764.75691	validation_1-eh_likelihood:440.16069
# [27]	validation_0-eh_likelihood:1759.60505	validation_1-eh_likelihood:441.69937
# [28]	validation_0-eh_likelihood:1762.02877	validation_1-eh_likelihood:439.50605
# [27]	validation_0-eh_likelihood:1758.99839	validation_1-eh_likelihood:439.90685
# [27]	validation_0-eh_likelihood:1761.19044	validation_1-eh_likelihood:439.68529
# [27]	validation_0-eh_likelihood:1764.74264	validation_1-eh_likelihood:440.16189
# [28]	validation_0-eh_likelihood:1759.57177	validation_1-eh_likelihood:441.69602
# [29]	validation_0-eh_likelihood:1762.02877	validation_1-eh_likelihood:439.50605
# [28]	validation_0-eh_likelihood:1758.94358	validation_1-eh_likelihood:439.89298
# [28]	validation_0-eh_likelihood:1761.16444	validation_1-eh_likelihood:439.68277
# [28]	validation_0-eh_likelihood:1764.73141	validation_1-eh_likelihood:440.14993
# [29]	validation_0-eh_likelihood:1759.55357	validation_1-eh_likelihood:441.70111
# [30]	validation_0-eh_likelihood:1761.98865	validation_1-eh_likelihood:439.49529
# [29]	validation_0-eh_likelihood:1758.89765	validation_1-eh_likelihood:439.88224
# [29]	validation_0-eh_likelihood:1761.14676	validation_1-eh_likelihood:439.68201
# [29]	validation_0-eh_likelihood:1764.70072	validation_1-eh_likelihood:440.14825
# [30]	validation_0-eh_likelihood:1759.49988	validation_1-eh_likelihood:441.69707
# [31]	validation_0-eh_likelihood:1761.98865	validation_1-eh_likelihood:439.49529
# [30]	validation_0-eh_likelihood:1758.83403	validation_1-eh_likelihood:439.86901
# [30]	validation_0-eh_likelihood:1761.11966	validation_1-eh_likelihood:439.67287
# [30]	validation_0-eh_likelihood:1764.68169	validation_1-eh_likelihood:440.13280
# [31]	validation_0-eh_likelihood:1759.41302	validation_1-eh_likelihood:441.67699
# [32]	validation_0-eh_likelihood:1761.97622	validation_1-eh_likelihood:439.49075
# [31]	validation_0-eh_likelihood:1758.74211	validation_1-eh_likelihood:439.85532
# [31]	validation_0-eh_likelihood:1761.11966	validation_1-eh_likelihood:439.67287
# [31]	validation_0-eh_likelihood:1764.68169	validation_1-eh_likelihood:440.13280
# [32]	validation_0-eh_likelihood:1759.37370	validation_1-eh_likelihood:441.66706
# [33]	validation_0-eh_likelihood:1761.94564	validation_1-eh_likelihood:439.47957
# [32]	validation_0-eh_likelihood:1758.62688	validation_1-eh_likelihood:439.82592
# [32]	validation_0-eh_likelihood:1761.04252	validation_1-eh_likelihood:439.65402
# [32]	validation_0-eh_likelihood:1764.69285	validation_1-eh_likelihood:440.13334
# [33]	validation_0-eh_likelihood:1759.32980	validation_1-eh_likelihood:441.65262
# [33]	validation_0-eh_likelihood:1758.55120	validation_1-eh_likelihood:439.81413
# [34]	validation_0-eh_likelihood:1761.93928	validation_1-eh_likelihood:439.47968
# [33]	validation_0-eh_likelihood:1761.01134	validation_1-eh_likelihood:439.64316
# [33]	validation_0-eh_likelihood:1764.71173	validation_1-eh_likelihood:440.13330
# [34]	validation_0-eh_likelihood:1759.29940	validation_1-eh_likelihood:441.64852
# [34]	validation_0-eh_likelihood:1758.52036	validation_1-eh_likelihood:439.80970
# [35]	validation_0-eh_likelihood:1761.87054	validation_1-eh_likelihood:439.47094
# [34]	validation_0-eh_likelihood:1760.98856	validation_1-eh_likelihood:439.63926
# [34]	validation_0-eh_likelihood:1764.69920	validation_1-eh_likelihood:440.13525
# [35]	validation_0-eh_likelihood:1759.30064	validation_1-eh_likelihood:441.62797
# [35]	validation_0-eh_likelihood:1758.53940	validation_1-eh_likelihood:439.81448
# [36]	validation_0-eh_likelihood:1761.85029	validation_1-eh_likelihood:439.46932
# [35]	validation_0-eh_likelihood:1760.90686	validation_1-eh_likelihood:439.62079
# [35]	validation_0-eh_likelihood:1764.59867	validation_1-eh_likelihood:440.12345
# [36]	validation_0-eh_likelihood:1759.28452	validation_1-eh_likelihood:441.63161
# [36]	validation_0-eh_likelihood:1758.50062	validation_1-eh_likelihood:439.80658
# [37]	validation_0-eh_likelihood:1761.86701	validation_1-eh_likelihood:439.48132
# [36]	validation_0-eh_likelihood:1760.86116	validation_1-eh_likelihood:439.61116
# [36]	validation_0-eh_likelihood:1764.55262	validation_1-eh_likelihood:440.11518
# [37]	validation_0-eh_likelihood:1759.26145	validation_1-eh_likelihood:441.61396
# [37]	validation_0-eh_likelihood:1758.46830	validation_1-eh_likelihood:439.80090
# [38]	validation_0-eh_likelihood:1761.78537	validation_1-eh_likelihood:439.45622
# [37]	validation_0-eh_likelihood:1760.79089	validation_1-eh_likelihood:439.60375
# [37]	validation_0-eh_likelihood:1764.50707	validation_1-eh_likelihood:440.09886
# [38]	validation_0-eh_likelihood:1759.18719	validation_1-eh_likelihood:441.60080
# [38]	validation_0-eh_likelihood:1758.43203	validation_1-eh_likelihood:439.78752
# [39]	validation_0-eh_likelihood:1761.75887	validation_1-eh_likelihood:439.44935
# [38]	validation_0-eh_likelihood:1760.72343	validation_1-eh_likelihood:439.59359
# [38]	validation_0-eh_likelihood:1764.44524	validation_1-eh_likelihood:440.09663
# [39]	validation_0-eh_likelihood:1759.18920	validation_1-eh_likelihood:441.60629
# [39]	validation_0-eh_likelihood:1758.39441	validation_1-eh_likelihood:439.78404
# [40]	validation_0-eh_likelihood:1761.73236	validation_1-eh_likelihood:439.45001
# [39]	validation_0-eh_likelihood:1760.74547	validation_1-eh_likelihood:439.60278
# [39]	validation_0-eh_likelihood:1764.44524	validation_1-eh_likelihood:440.09663
# [40]	validation_0-eh_likelihood:1759.13441	validation_1-eh_likelihood:441.59859
# [40]	validation_0-eh_likelihood:1758.32662	validation_1-eh_likelihood:439.76970
# [41]	validation_0-eh_likelihood:1761.66247	validation_1-eh_likelihood:439.43294
# [40]	validation_0-eh_likelihood:1760.73219	validation_1-eh_likelihood:439.60418
# [40]	validation_0-eh_likelihood:1764.44032	validation_1-eh_likelihood:440.09521
# [41]	validation_0-eh_likelihood:1759.07026	validation_1-eh_likelihood:441.59425
# [41]	validation_0-eh_likelihood:1758.27196	validation_1-eh_likelihood:439.75475
# [42]	validation_0-eh_likelihood:1761.65165	validation_1-eh_likelihood:439.43523
# [41]	validation_0-eh_likelihood:1760.68944	validation_1-eh_likelihood:439.60248
# [41]	validation_0-eh_likelihood:1764.34960	validation_1-eh_likelihood:440.07897
# [42]	validation_0-eh_likelihood:1759.05456	validation_1-eh_likelihood:441.59492
# [42]	validation_0-eh_likelihood:1758.20864	validation_1-eh_likelihood:439.73792
# [43]	validation_0-eh_likelihood:1761.60087	validation_1-eh_likelihood:439.41713
# [42]	validation_0-eh_likelihood:1760.65864	validation_1-eh_likelihood:439.59370
# [42]	validation_0-eh_likelihood:1764.32174	validation_1-eh_likelihood:440.07625
# [43]	validation_0-eh_likelihood:1759.04760	validation_1-eh_likelihood:441.59422
# [43]	validation_0-eh_likelihood:1758.15546	validation_1-eh_likelihood:439.72846
# [44]	validation_0-eh_likelihood:1761.57747	validation_1-eh_likelihood:439.41775
# [43]	validation_0-eh_likelihood:1760.61179	validation_1-eh_likelihood:439.58177
# [43]	validation_0-eh_likelihood:1764.27323	validation_1-eh_likelihood:440.06381
# [44]	validation_0-eh_likelihood:1758.95899	validation_1-eh_likelihood:441.57609
# [44]	validation_0-eh_likelihood:1758.09467	validation_1-eh_likelihood:439.71547
# [45]	validation_0-eh_likelihood:1761.50947	validation_1-eh_likelihood:439.40588
# [44]	validation_0-eh_likelihood:1760.57939	validation_1-eh_likelihood:439.57984
# [44]	validation_0-eh_likelihood:1764.24834	validation_1-eh_likelihood:440.06207
# [45]	validation_0-eh_likelihood:1758.92191	validation_1-eh_likelihood:441.57437
# [45]	validation_0-eh_likelihood:1758.07228	validation_1-eh_likelihood:439.71314
# [46]	validation_0-eh_likelihood:1761.48866	validation_1-eh_likelihood:439.40104
# [45]	validation_0-eh_likelihood:1760.51293	validation_1-eh_likelihood:439.56833
# [45]	validation_0-eh_likelihood:1764.15651	validation_1-eh_likelihood:440.04776
# [46]	validation_0-eh_likelihood:1758.90594	validation_1-eh_likelihood:441.57767
# [46]	validation_0-eh_likelihood:1758.07228	validation_1-eh_likelihood:439.71314
# [47]	validation_0-eh_likelihood:1761.42514	validation_1-eh_likelihood:439.38110
# [46]	validation_0-eh_likelihood:1760.46995	validation_1-eh_likelihood:439.55878
# [46]	validation_0-eh_likelihood:1764.13032	validation_1-eh_likelihood:440.04086
# [47]	validation_0-eh_likelihood:1758.88139	validation_1-eh_likelihood:441.56715
# [47]	validation_0-eh_likelihood:1758.04777	validation_1-eh_likelihood:439.71339
# [48]	validation_0-eh_likelihood:1761.39290	validation_1-eh_likelihood:439.37392
# [47]	validation_0-eh_likelihood:1760.41704	validation_1-eh_likelihood:439.55081
# [47]	validation_0-eh_likelihood:1764.08538	validation_1-eh_likelihood:440.03368
# [48]	validation_0-eh_likelihood:1758.88139	validation_1-eh_likelihood:441.56715
# [48]	validation_0-eh_likelihood:1758.01687	validation_1-eh_likelihood:439.70997
# [49]	validation_0-eh_likelihood:1761.31411	validation_1-eh_likelihood:439.35516
# [48]	validation_0-eh_likelihood:1760.38022	validation_1-eh_likelihood:439.53290
# [49]	validation_0-eh_likelihood:1758.84840	validation_1-eh_likelihood:441.56234[49]	validation_0-eh_likelihood:1757.99853	validation_1-eh_likelihood:439.70631
#
# [48]	validation_0-eh_likelihood:1764.06234	validation_1-eh_likelihood:440.03728
# [50]	validation_0-eh_likelihood:1761.25256	validation_1-eh_likelihood:439.34004
# [49]	validation_0-eh_likelihood:1760.38022	validation_1-eh_likelihood:439.53290
# [50]	validation_0-eh_likelihood:1758.81984	validation_1-eh_likelihood:441.55584[50]	validation_0-eh_likelihood:1757.96513	validation_1-eh_likelihood:439.70034
#
# [49]	validation_0-eh_likelihood:1764.02614	validation_1-eh_likelihood:440.02836
# [51]	validation_0-eh_likelihood:1761.16459	validation_1-eh_likelihood:439.32410
# [50]	validation_0-eh_likelihood:1760.31365	validation_1-eh_likelihood:439.51905
# [51]	validation_0-eh_likelihood:1757.90876	validation_1-eh_likelihood:439.68831
# [51]	validation_0-eh_likelihood:1758.71671	validation_1-eh_likelihood:441.52779
# [50]	validation_0-eh_likelihood:1763.93583	validation_1-eh_likelihood:440.01403
# [52]	validation_0-eh_likelihood:1761.16459	validation_1-eh_likelihood:439.32410
# [51]	validation_0-eh_likelihood:1760.24089	validation_1-eh_likelihood:439.49953
# [52]	validation_0-eh_likelihood:1757.88858	validation_1-eh_likelihood:439.68371
# [52]	validation_0-eh_likelihood:1758.68419	validation_1-eh_likelihood:441.53022
# [51]	validation_0-eh_likelihood:1763.83148	validation_1-eh_likelihood:440.00070
# [53]	validation_0-eh_likelihood:1761.11513	validation_1-eh_likelihood:439.31335
# [52]	validation_0-eh_likelihood:1760.24856	validation_1-eh_likelihood:439.49057
# [53]	validation_0-eh_likelihood:1757.86333	validation_1-eh_likelihood:439.68363
# [53]	validation_0-eh_likelihood:1758.68108	validation_1-eh_likelihood:441.53662
# [54]	validation_0-eh_likelihood:1761.05350	validation_1-eh_likelihood:439.29594
# [52]	validation_0-eh_likelihood:1763.83191	validation_1-eh_likelihood:440.00297
# [53]	validation_0-eh_likelihood:1760.24856	validation_1-eh_likelihood:439.49057
# [54]	validation_0-eh_likelihood:1757.84153	validation_1-eh_likelihood:439.67408
# [54]	validation_0-eh_likelihood:1758.61408	validation_1-eh_likelihood:441.53802
# [55]	validation_0-eh_likelihood:1761.02758	validation_1-eh_likelihood:439.27969
# [53]	validation_0-eh_likelihood:1763.72599	validation_1-eh_likelihood:439.98629
# [54]	validation_0-eh_likelihood:1760.22834	validation_1-eh_likelihood:439.47941
# [55]	validation_0-eh_likelihood:1757.83989	validation_1-eh_likelihood:439.67450
# [55]	validation_0-eh_likelihood:1758.60588	validation_1-eh_likelihood:441.53282
# [56]	validation_0-eh_likelihood:1760.96294	validation_1-eh_likelihood:439.26474
# [54]	validation_0-eh_likelihood:1763.63771	validation_1-eh_likelihood:439.97078
# [55]	validation_0-eh_likelihood:1760.22491	validation_1-eh_likelihood:439.47614
# [56]	validation_0-eh_likelihood:1757.82256	validation_1-eh_likelihood:439.67044
# [56]	validation_0-eh_likelihood:1758.60516	validation_1-eh_likelihood:441.52767
# [57]	validation_0-eh_likelihood:1760.89551	validation_1-eh_likelihood:439.24638
# [55]	validation_0-eh_likelihood:1763.55682	validation_1-eh_likelihood:439.95467
# [56]	validation_0-eh_likelihood:1760.17587	validation_1-eh_likelihood:439.47506
# [57]	validation_0-eh_likelihood:1757.79217	validation_1-eh_likelihood:439.66257
# [57]	validation_0-eh_likelihood:1758.56690	validation_1-eh_likelihood:441.52382
# [58]	validation_0-eh_likelihood:1760.88963	validation_1-eh_likelihood:439.25077
# [56]	validation_0-eh_likelihood:1763.51015	validation_1-eh_likelihood:439.94568
# [57]	validation_0-eh_likelihood:1760.13046	validation_1-eh_likelihood:439.46421
# [58]	validation_0-eh_likelihood:1757.70716	validation_1-eh_likelihood:439.64502
# [58]	validation_0-eh_likelihood:1758.47220	validation_1-eh_likelihood:441.51281
# [59]	validation_0-eh_likelihood:1760.81657	validation_1-eh_likelihood:439.24023
# [57]	validation_0-eh_likelihood:1763.48459	validation_1-eh_likelihood:439.93769
# [58]	validation_0-eh_likelihood:1760.11354	validation_1-eh_likelihood:439.47007
# [59]	validation_0-eh_likelihood:1757.69628	validation_1-eh_likelihood:439.64141
# [59]	validation_0-eh_likelihood:1758.45535	validation_1-eh_likelihood:441.51110
# [60]	validation_0-eh_likelihood:1760.81657	validation_1-eh_likelihood:439.24023
# [58]	validation_0-eh_likelihood:1763.44905	validation_1-eh_likelihood:439.93165
# [59]	validation_0-eh_likelihood:1760.11354	validation_1-eh_likelihood:439.47007
# [60]	validation_0-eh_likelihood:1757.68101	validation_1-eh_likelihood:439.63357
# [60]	validation_0-eh_likelihood:1758.36157	validation_1-eh_likelihood:441.49186
# [61]	validation_0-eh_likelihood:1760.81224	validation_1-eh_likelihood:439.24250
# [59]	validation_0-eh_likelihood:1763.35843	validation_1-eh_likelihood:439.91476
# [60]	validation_0-eh_likelihood:1760.07799	validation_1-eh_likelihood:439.46927
# [61]	validation_0-eh_likelihood:1757.58870	validation_1-eh_likelihood:439.61226
# [61]	validation_0-eh_likelihood:1758.27542	validation_1-eh_likelihood:441.47269
# [60]	validation_0-eh_likelihood:1763.38398	validation_1-eh_likelihood:439.91755
# [62]	validation_0-eh_likelihood:1760.75486	validation_1-eh_likelihood:439.23001
# [61]	validation_0-eh_likelihood:1760.03988	validation_1-eh_likelihood:439.46197
# [62]	validation_0-eh_likelihood:1757.56232	validation_1-eh_likelihood:439.61013
# [62]	validation_0-eh_likelihood:1758.24634	validation_1-eh_likelihood:441.48037
# [61]	validation_0-eh_likelihood:1763.33045	validation_1-eh_likelihood:439.91400
# [63]	validation_0-eh_likelihood:1760.75486	validation_1-eh_likelihood:439.23001
# [62]	validation_0-eh_likelihood:1759.95296	validation_1-eh_likelihood:439.44786
# [63]	validation_0-eh_likelihood:1757.56232	validation_1-eh_likelihood:439.61013
# [63]	validation_0-eh_likelihood:1758.17152	validation_1-eh_likelihood:441.46394
# [62]	validation_0-eh_likelihood:1763.26359	validation_1-eh_likelihood:439.89401
# [64]	validation_0-eh_likelihood:1760.66716	validation_1-eh_likelihood:439.23029
# [63]	validation_0-eh_likelihood:1759.91050	validation_1-eh_likelihood:439.44807
# [64]	validation_0-eh_likelihood:1757.56311	validation_1-eh_likelihood:439.60736
# [64]	validation_0-eh_likelihood:1758.11393	validation_1-eh_likelihood:441.44728
# [63]	validation_0-eh_likelihood:1763.22509	validation_1-eh_likelihood:439.89362
# [65]	validation_0-eh_likelihood:1760.60371	validation_1-eh_likelihood:439.21522
# [64]	validation_0-eh_likelihood:1759.88162	validation_1-eh_likelihood:439.44356
# [65]	validation_0-eh_likelihood:1757.55239	validation_1-eh_likelihood:439.60171
# [65]	validation_0-eh_likelihood:1758.09597	validation_1-eh_likelihood:441.45259
# [64]	validation_0-eh_likelihood:1763.14511	validation_1-eh_likelihood:439.87455
# [66]	validation_0-eh_likelihood:1760.59522	validation_1-eh_likelihood:439.21360
# [65]	validation_0-eh_likelihood:1759.84516	validation_1-eh_likelihood:439.43329
# [66]	validation_0-eh_likelihood:1757.53058	validation_1-eh_likelihood:439.59687
# [66]	validation_0-eh_likelihood:1758.09037	validation_1-eh_likelihood:441.43815
# [65]	validation_0-eh_likelihood:1763.14511	validation_1-eh_likelihood:439.87455
# [67]	validation_0-eh_likelihood:1760.57241	validation_1-eh_likelihood:439.19874
# [66]	validation_0-eh_likelihood:1759.79572	validation_1-eh_likelihood:439.42061
# [67]	validation_0-eh_likelihood:1757.45793	validation_1-eh_likelihood:439.57867
# [67]	validation_0-eh_likelihood:1758.07980	validation_1-eh_likelihood:441.44475
# [66]	validation_0-eh_likelihood:1763.15814	validation_1-eh_likelihood:439.87775
# [68]	validation_0-eh_likelihood:1760.54999	validation_1-eh_likelihood:439.19165
# [67]	validation_0-eh_likelihood:1759.73656	validation_1-eh_likelihood:439.40441
# [68]	validation_0-eh_likelihood:1757.36238	validation_1-eh_likelihood:439.56534
# [68]	validation_0-eh_likelihood:1758.03968	validation_1-eh_likelihood:441.42687
# [67]	validation_0-eh_likelihood:1763.08620	validation_1-eh_likelihood:439.86421
# [68]	validation_0-eh_likelihood:1759.73064	validation_1-eh_likelihood:439.40621
# [69]	validation_0-eh_likelihood:1760.54999	validation_1-eh_likelihood:439.19165
# [69]	validation_0-eh_likelihood:1757.33694	validation_1-eh_likelihood:439.56088
# [69]	validation_0-eh_likelihood:1758.01870	validation_1-eh_likelihood:441.42000
# [68]	validation_0-eh_likelihood:1763.06729	validation_1-eh_likelihood:439.85580
# [69]	validation_0-eh_likelihood:1759.73609	validation_1-eh_likelihood:439.41066
# [70]	validation_0-eh_likelihood:1760.54999	validation_1-eh_likelihood:439.19165
# [70]	validation_0-eh_likelihood:1757.28906	validation_1-eh_likelihood:439.54824
# [70]	validation_0-eh_likelihood:1757.93685	validation_1-eh_likelihood:441.40348
# [69]	validation_0-eh_likelihood:1763.03774	validation_1-eh_likelihood:439.84316
# [70]	validation_0-eh_likelihood:1759.73915	validation_1-eh_likelihood:439.41127
# [71]	validation_0-eh_likelihood:1760.52517	validation_1-eh_likelihood:439.18261
# [71]	validation_0-eh_likelihood:1757.28906	validation_1-eh_likelihood:439.54824
# [71]	validation_0-eh_likelihood:1757.88452	validation_1-eh_likelihood:441.38590
# [70]	validation_0-eh_likelihood:1762.98149	validation_1-eh_likelihood:439.82988
# [71]	validation_0-eh_likelihood:1759.75324	validation_1-eh_likelihood:439.41656
# [72]	validation_0-eh_likelihood:1760.46100	validation_1-eh_likelihood:439.16584
# [72]	validation_0-eh_likelihood:1757.27918	validation_1-eh_likelihood:439.54461
# [72]	validation_0-eh_likelihood:1757.88452	validation_1-eh_likelihood:441.38590
# [71]	validation_0-eh_likelihood:1762.98149	validation_1-eh_likelihood:439.82988
# [73]	validation_0-eh_likelihood:1760.44535	validation_1-eh_likelihood:439.16382
# [72]	validation_0-eh_likelihood:1759.75324	validation_1-eh_likelihood:439.41656
# [73]	validation_0-eh_likelihood:1757.23594	validation_1-eh_likelihood:439.53001
# [73]	validation_0-eh_likelihood:1757.78617	validation_1-eh_likelihood:441.36683
# [72]	validation_0-eh_likelihood:1762.92218	validation_1-eh_likelihood:439.82060
# [74]	validation_0-eh_likelihood:1760.40529	validation_1-eh_likelihood:439.15043
# [73]	validation_0-eh_likelihood:1759.74735	validation_1-eh_likelihood:439.41769
# [74]	validation_0-eh_likelihood:1757.20803	validation_1-eh_likelihood:439.52844
# [74]	validation_0-eh_likelihood:1757.75623	validation_1-eh_likelihood:441.36023
# [73]	validation_0-eh_likelihood:1762.90138	validation_1-eh_likelihood:439.81937
# [74]	validation_0-eh_likelihood:1759.64611	validation_1-eh_likelihood:439.40208
# [75]	validation_0-eh_likelihood:1760.40529	validation_1-eh_likelihood:439.15043
# [75]	validation_0-eh_likelihood:1757.13588	validation_1-eh_likelihood:439.51517
# [75]	validation_0-eh_likelihood:1757.69747	validation_1-eh_likelihood:441.34174
# [74]	validation_0-eh_likelihood:1762.83049	validation_1-eh_likelihood:439.81154
# [76]	validation_0-eh_likelihood:1760.34480	validation_1-eh_likelihood:439.13035
# [75]	validation_0-eh_likelihood:1759.63628	validation_1-eh_likelihood:439.40814
# [76]	validation_0-eh_likelihood:1757.10091	validation_1-eh_likelihood:439.51172
# [76]	validation_0-eh_likelihood:1757.61027	validation_1-eh_likelihood:441.32397
# [75]	validation_0-eh_likelihood:1762.80645	validation_1-eh_likelihood:439.80691
# [77]	validation_0-eh_likelihood:1760.31665	validation_1-eh_likelihood:439.12548
# [76]	validation_0-eh_likelihood:1759.61200	validation_1-eh_likelihood:439.40229
# [77]	validation_0-eh_likelihood:1756.99726	validation_1-eh_likelihood:439.48913
# [77]	validation_0-eh_likelihood:1757.49764	validation_1-eh_likelihood:441.30986
# [76]	validation_0-eh_likelihood:1762.70234	validation_1-eh_likelihood:439.79080
# [77]	validation_0-eh_likelihood:1759.58427	validation_1-eh_likelihood:439.39808
# [78]	validation_0-eh_likelihood:1760.31665	validation_1-eh_likelihood:439.12548
# [78]	validation_0-eh_likelihood:1756.97280	validation_1-eh_likelihood:439.47832
# [78]	validation_0-eh_likelihood:1757.48909	validation_1-eh_likelihood:441.31609
# [77]	validation_0-eh_likelihood:1762.64174	validation_1-eh_likelihood:439.78269
# [78]	validation_0-eh_likelihood:1759.54763	validation_1-eh_likelihood:439.39127
# [79]	validation_0-eh_likelihood:1760.30925	validation_1-eh_likelihood:439.12403
# [79]	validation_0-eh_likelihood:1756.94764	validation_1-eh_likelihood:439.47353
# [79]	validation_0-eh_likelihood:1757.44080	validation_1-eh_likelihood:441.31979
# [78]	validation_0-eh_likelihood:1762.63040	validation_1-eh_likelihood:439.78415
# [80]	validation_0-eh_likelihood:1760.28710	validation_1-eh_likelihood:439.11167
# [79]	validation_0-eh_likelihood:1759.51584	validation_1-eh_likelihood:439.38294
# [80]	validation_0-eh_likelihood:1756.91073	validation_1-eh_likelihood:439.46066
# [80]	validation_0-eh_likelihood:1757.44080	validation_1-eh_likelihood:441.31979
# [79]	validation_0-eh_likelihood:1762.60529	validation_1-eh_likelihood:439.78329
# [81]	validation_0-eh_likelihood:1760.24482	validation_1-eh_likelihood:439.10117
# [80]	validation_0-eh_likelihood:1759.46394	validation_1-eh_likelihood:439.36689
# [81]	validation_0-eh_likelihood:1756.87825	validation_1-eh_likelihood:439.45526
# [81]	validation_0-eh_likelihood:1757.39912	validation_1-eh_likelihood:441.32091
# [80]	validation_0-eh_likelihood:1762.58302	validation_1-eh_likelihood:439.78483
# [81]	validation_0-eh_likelihood:1759.46394	validation_1-eh_likelihood:439.36689
# [82]	validation_0-eh_likelihood:1760.22861	validation_1-eh_likelihood:439.09310
# [82]	validation_0-eh_likelihood:1756.85124	validation_1-eh_likelihood:439.45341
# [82]	validation_0-eh_likelihood:1757.32749	validation_1-eh_likelihood:441.30817
# [81]	validation_0-eh_likelihood:1762.56658	validation_1-eh_likelihood:439.79082
# [82]	validation_0-eh_likelihood:1759.46394	validation_1-eh_likelihood:439.36689
# [83]	validation_0-eh_likelihood:1760.20847	validation_1-eh_likelihood:439.09059
# [83]	validation_0-eh_likelihood:1756.86413	validation_1-eh_likelihood:439.44851
# [83]	validation_0-eh_likelihood:1757.36656	validation_1-eh_likelihood:441.30767
# [82]	validation_0-eh_likelihood:1762.56658	validation_1-eh_likelihood:439.79082
# [83]	validation_0-eh_likelihood:1759.38767	validation_1-eh_likelihood:439.34716
# [84]	validation_0-eh_likelihood:1760.12265	validation_1-eh_likelihood:439.06961
# [84]	validation_0-eh_likelihood:1756.83795	validation_1-eh_likelihood:439.43879
# [84]	validation_0-eh_likelihood:1757.40405	validation_1-eh_likelihood:441.31874
# [83]	validation_0-eh_likelihood:1762.56335	validation_1-eh_likelihood:439.79328
# [84]	validation_0-eh_likelihood:1759.37630	validation_1-eh_likelihood:439.34240
# [85]	validation_0-eh_likelihood:1760.08976	validation_1-eh_likelihood:439.05181
# [85]	validation_0-eh_likelihood:1756.80779	validation_1-eh_likelihood:439.42257
# [85]	validation_0-eh_likelihood:1757.32611	validation_1-eh_likelihood:441.30236
# [84]	validation_0-eh_likelihood:1762.47814	validation_1-eh_likelihood:439.78143
# [85]	validation_0-eh_likelihood:1759.37630	validation_1-eh_likelihood:439.34240
# [86]	validation_0-eh_likelihood:1756.73907	validation_1-eh_likelihood:439.40677
# [86]	validation_0-eh_likelihood:1760.08257	validation_1-eh_likelihood:439.05042
# [86]	validation_0-eh_likelihood:1757.26792	validation_1-eh_likelihood:441.29872
# [85]	validation_0-eh_likelihood:1762.49976	validation_1-eh_likelihood:439.78116
# [87]	validation_0-eh_likelihood:1756.72372	validation_1-eh_likelihood:439.40297
# [86]	validation_0-eh_likelihood:1759.35412	validation_1-eh_likelihood:439.33796
# [87]	validation_0-eh_likelihood:1757.28334	validation_1-eh_likelihood:441.30374
# [87]	validation_0-eh_likelihood:1760.08257	validation_1-eh_likelihood:439.05042
# [86]	validation_0-eh_likelihood:1762.49976	validation_1-eh_likelihood:439.78116
# [88]	validation_0-eh_likelihood:1756.71426	validation_1-eh_likelihood:439.39838
# [88]	validation_0-eh_likelihood:1757.25316	validation_1-eh_likelihood:441.31540
# [87]	validation_0-eh_likelihood:1759.35412	validation_1-eh_likelihood:439.33796
# [88]	validation_0-eh_likelihood:1760.04779	validation_1-eh_likelihood:439.03736
# [87]	validation_0-eh_likelihood:1762.51058	validation_1-eh_likelihood:439.78303
# [89]	validation_0-eh_likelihood:1756.67531	validation_1-eh_likelihood:439.39539
# [89]	validation_0-eh_likelihood:1757.23269	validation_1-eh_likelihood:441.31185
# [88]	validation_0-eh_likelihood:1759.33791	validation_1-eh_likelihood:439.32124
# [89]	validation_0-eh_likelihood:1760.03654	validation_1-eh_likelihood:439.03484
# [88]	validation_0-eh_likelihood:1762.47986	validation_1-eh_likelihood:439.78717
# [90]	validation_0-eh_likelihood:1756.65124	validation_1-eh_likelihood:439.38658
# [90]	validation_0-eh_likelihood:1757.20872	validation_1-eh_likelihood:441.31174
# [89]	validation_0-eh_likelihood:1759.32842	validation_1-eh_likelihood:439.31972
# [90]	validation_0-eh_likelihood:1760.03526	validation_1-eh_likelihood:439.03873
# [89]	validation_0-eh_likelihood:1762.45301	validation_1-eh_likelihood:439.78004
# [91]	validation_0-eh_likelihood:1756.63403	validation_1-eh_likelihood:439.38111
# [91]	validation_0-eh_likelihood:1757.18090	validation_1-eh_likelihood:441.30927
# [90]	validation_0-eh_likelihood:1759.28101	validation_1-eh_likelihood:439.31075
# [91]	validation_0-eh_likelihood:1760.03526	validation_1-eh_likelihood:439.03873
# [90]	validation_0-eh_likelihood:1762.39743	validation_1-eh_likelihood:439.77434
# [92]	validation_0-eh_likelihood:1756.63403	validation_1-eh_likelihood:439.38111
# [92]	validation_0-eh_likelihood:1757.18090	validation_1-eh_likelihood:441.30927
# [91]	validation_0-eh_likelihood:1759.28101	validation_1-eh_likelihood:439.31075
# [92]	validation_0-eh_likelihood:1760.00428	validation_1-eh_likelihood:439.02338
# [91]	validation_0-eh_likelihood:1762.39743	validation_1-eh_likelihood:439.77434
# [93]	validation_0-eh_likelihood:1756.55999	validation_1-eh_likelihood:439.36341
# [93]	validation_0-eh_likelihood:1757.14467	validation_1-eh_likelihood:441.30974
# [92]	validation_0-eh_likelihood:1759.28742	validation_1-eh_likelihood:439.31598
# [93]	validation_0-eh_likelihood:1760.00428	validation_1-eh_likelihood:439.02338
# [92]	validation_0-eh_likelihood:1762.37466	validation_1-eh_likelihood:439.76612
# [94]	validation_0-eh_likelihood:1756.55999	validation_1-eh_likelihood:439.36341
# [94]	validation_0-eh_likelihood:1757.14467	validation_1-eh_likelihood:441.30974
# [93]	validation_0-eh_likelihood:1759.28623	validation_1-eh_likelihood:439.31541
# [94]	validation_0-eh_likelihood:1760.00428	validation_1-eh_likelihood:439.02338
# [93]	validation_0-eh_likelihood:1762.35203	validation_1-eh_likelihood:439.76309
# [95]	validation_0-eh_likelihood:1756.51613	validation_1-eh_likelihood:439.35692
# [95]	validation_0-eh_likelihood:1757.13764	validation_1-eh_likelihood:441.30737
# [94]	validation_0-eh_likelihood:1759.25068	validation_1-eh_likelihood:439.30779
# [95]	validation_0-eh_likelihood:1759.98147	validation_1-eh_likelihood:439.01347
# [94]	validation_0-eh_likelihood:1762.33407	validation_1-eh_likelihood:439.76114
# [96]	validation_0-eh_likelihood:1756.51613	validation_1-eh_likelihood:439.35692
# [95]	validation_0-eh_likelihood:1759.20733	validation_1-eh_likelihood:439.29839
# [96]	validation_0-eh_likelihood:1759.97565	validation_1-eh_likelihood:439.01811
# [95]	validation_0-eh_likelihood:1762.31444	validation_1-eh_likelihood:439.76415
# [97]	validation_0-eh_likelihood:1756.53353	validation_1-eh_likelihood:439.36138
# [96]	validation_0-eh_likelihood:1759.18773	validation_1-eh_likelihood:439.29745
# [97]	validation_0-eh_likelihood:1759.97565	validation_1-eh_likelihood:439.01811
# [98]	validation_0-eh_likelihood:1756.45833	validation_1-eh_likelihood:439.35848
# [96]	validation_0-eh_likelihood:1762.29429	validation_1-eh_likelihood:439.75804
# [97]	validation_0-eh_likelihood:1759.18773	validation_1-eh_likelihood:439.29745
# [98]	validation_0-eh_likelihood:1759.93352	validation_1-eh_likelihood:439.00716
# [99]	validation_0-eh_likelihood:1756.38231	validation_1-eh_likelihood:439.34145
# [97]	validation_0-eh_likelihood:1762.26027	validation_1-eh_likelihood:439.74573
# [99]	validation_0-eh_likelihood:1759.91353	validation_1-eh_likelihood:438.99457
# [98]	validation_0-eh_likelihood:1759.12020	validation_1-eh_likelihood:439.28567
# [100]	validation_0-eh_likelihood:1756.27866	validation_1-eh_likelihood:439.32390
# [98]	validation_0-eh_likelihood:1762.23628	validation_1-eh_likelihood:439.74655
# [100]	validation_0-eh_likelihood:1759.91410	validation_1-eh_likelihood:438.99682
# [99]	validation_0-eh_likelihood:1759.09684	validation_1-eh_likelihood:439.28040
# [101]	validation_0-eh_likelihood:1756.24202	validation_1-eh_likelihood:439.31825
# [99]	validation_0-eh_likelihood:1762.22228	validation_1-eh_likelihood:439.74863
# [101]	validation_0-eh_likelihood:1759.89327	validation_1-eh_likelihood:438.99282
# [100]	validation_0-eh_likelihood:1759.04654	validation_1-eh_likelihood:439.26300
# [102]	validation_0-eh_likelihood:1756.24467	validation_1-eh_likelihood:439.31387
# [100]	validation_0-eh_likelihood:1762.23001	validation_1-eh_likelihood:439.74827
# [102]	validation_0-eh_likelihood:1759.87049	validation_1-eh_likelihood:438.98620
# [101]	validation_0-eh_likelihood:1758.95673	validation_1-eh_likelihood:439.24412
# [103]	validation_0-eh_likelihood:1756.17810	validation_1-eh_likelihood:439.29816
# [101]	validation_0-eh_likelihood:1762.12399	validation_1-eh_likelihood:439.73477
# [103]	validation_0-eh_likelihood:1759.75715	validation_1-eh_likelihood:438.95691
# [102]	validation_0-eh_likelihood:1758.91361	validation_1-eh_likelihood:439.23617
# [104]	validation_0-eh_likelihood:1756.17026	validation_1-eh_likelihood:439.30314
# [102]	validation_0-eh_likelihood:1762.07487	validation_1-eh_likelihood:439.72458
# [104]	validation_0-eh_likelihood:1759.70523	validation_1-eh_likelihood:438.94883
# [103]	validation_0-eh_likelihood:1758.88869	validation_1-eh_likelihood:439.23189
# [105]	validation_0-eh_likelihood:1756.16705	validation_1-eh_likelihood:439.29976
# [103]	validation_0-eh_likelihood:1761.94999	validation_1-eh_likelihood:439.70651
# [105]	validation_0-eh_likelihood:1759.67642	validation_1-eh_likelihood:438.93176
# [104]	validation_0-eh_likelihood:1758.83010	validation_1-eh_likelihood:439.21771
# [106]	validation_0-eh_likelihood:1756.09193	validation_1-eh_likelihood:439.28578
# [104]	validation_0-eh_likelihood:1761.87930	validation_1-eh_likelihood:439.70250
# [106]	validation_0-eh_likelihood:1759.72679	validation_1-eh_likelihood:438.93346
# [105]	validation_0-eh_likelihood:1758.73934	validation_1-eh_likelihood:439.19728
# [107]	validation_0-eh_likelihood:1756.05214	validation_1-eh_likelihood:439.27794
# [105]	validation_0-eh_likelihood:1761.85604	validation_1-eh_likelihood:439.70058
# [107]	validation_0-eh_likelihood:1759.71652	validation_1-eh_likelihood:438.92954
# [106]	validation_0-eh_likelihood:1758.76130	validation_1-eh_likelihood:439.20060
# [108]	validation_0-eh_likelihood:1755.97414	validation_1-eh_likelihood:439.26881
# [106]	validation_0-eh_likelihood:1761.85604	validation_1-eh_likelihood:439.70058
# [107]	validation_0-eh_likelihood:1758.71224	validation_1-eh_likelihood:439.18420
# [108]	validation_0-eh_likelihood:1759.70400	validation_1-eh_likelihood:438.94090
# [109]	validation_0-eh_likelihood:1755.96454	validation_1-eh_likelihood:439.26292
# [107]	validation_0-eh_likelihood:1761.77370	validation_1-eh_likelihood:439.68621
# [108]	validation_0-eh_likelihood:1758.70150	validation_1-eh_likelihood:439.18105
# [109]	validation_0-eh_likelihood:1759.60818	validation_1-eh_likelihood:438.91872
# [110]	validation_0-eh_likelihood:1755.89380	validation_1-eh_likelihood:439.25832
# [108]	validation_0-eh_likelihood:1761.73998	validation_1-eh_likelihood:439.68509
# [109]	validation_0-eh_likelihood:1758.63482	validation_1-eh_likelihood:439.16004
# [110]	validation_0-eh_likelihood:1759.60818	validation_1-eh_likelihood:438.91872
# [111]	validation_0-eh_likelihood:1755.85901	validation_1-eh_likelihood:439.25144
# [109]	validation_0-eh_likelihood:1761.65678	validation_1-eh_likelihood:439.67330
# [110]	validation_0-eh_likelihood:1758.63035	validation_1-eh_likelihood:439.16238
# [111]	validation_0-eh_likelihood:1759.58074	validation_1-eh_likelihood:438.91389
# [112]	validation_0-eh_likelihood:1755.80597	validation_1-eh_likelihood:439.24039
# [110]	validation_0-eh_likelihood:1761.64386	validation_1-eh_likelihood:439.67672
# [111]	validation_0-eh_likelihood:1758.58666	validation_1-eh_likelihood:439.15468
# [113]	validation_0-eh_likelihood:1755.80597	validation_1-eh_likelihood:439.24039
# [112]	validation_0-eh_likelihood:1759.58509	validation_1-eh_likelihood:438.91346
# [111]	validation_0-eh_likelihood:1761.62199	validation_1-eh_likelihood:439.66843
# [112]	validation_0-eh_likelihood:1758.54001	validation_1-eh_likelihood:439.15722
# [114]	validation_0-eh_likelihood:1755.80570	validation_1-eh_likelihood:439.23913
# [113]	validation_0-eh_likelihood:1759.54341	validation_1-eh_likelihood:438.89403
# [112]	validation_0-eh_likelihood:1761.57437	validation_1-eh_likelihood:439.66806
# [113]	validation_0-eh_likelihood:1758.52997	validation_1-eh_likelihood:439.15846
# [115]	validation_0-eh_likelihood:1755.80088	validation_1-eh_likelihood:439.23843
# [114]	validation_0-eh_likelihood:1759.51926	validation_1-eh_likelihood:438.88108
# [113]	validation_0-eh_likelihood:1761.46566	validation_1-eh_likelihood:439.64402
# [114]	validation_0-eh_likelihood:1758.52997	validation_1-eh_likelihood:439.15846
# [116]	validation_0-eh_likelihood:1755.80088	validation_1-eh_likelihood:439.23843
# [115]	validation_0-eh_likelihood:1759.48580	validation_1-eh_likelihood:438.87702
# [114]	validation_0-eh_likelihood:1761.42902	validation_1-eh_likelihood:439.63614
# [115]	validation_0-eh_likelihood:1758.41492	validation_1-eh_likelihood:439.12873
# [117]	validation_0-eh_likelihood:1755.79764	validation_1-eh_likelihood:439.23698
# [116]	validation_0-eh_likelihood:1759.50396	validation_1-eh_likelihood:438.89436
# [115]	validation_0-eh_likelihood:1761.35620	validation_1-eh_likelihood:439.62131
# [116]	validation_0-eh_likelihood:1758.45013	validation_1-eh_likelihood:439.13669
# [118]	validation_0-eh_likelihood:1755.77609	validation_1-eh_likelihood:439.23516
# [117]	validation_0-eh_likelihood:1759.46447	validation_1-eh_likelihood:438.88803
# [116]	validation_0-eh_likelihood:1761.31760	validation_1-eh_likelihood:439.61907
# [117]	validation_0-eh_likelihood:1758.42706	validation_1-eh_likelihood:439.13299
# [119]	validation_0-eh_likelihood:1755.77205	validation_1-eh_likelihood:439.23715
# [118]	validation_0-eh_likelihood:1759.46447	validation_1-eh_likelihood:438.88803
# [117]	validation_0-eh_likelihood:1761.29476	validation_1-eh_likelihood:439.61547
# [118]	validation_0-eh_likelihood:1758.35023	validation_1-eh_likelihood:439.10765
# [120]	validation_0-eh_likelihood:1755.77205	validation_1-eh_likelihood:439.23715
# [119]	validation_0-eh_likelihood:1759.42553	validation_1-eh_likelihood:438.88494
# [119]	validation_0-eh_likelihood:1758.35023	validation_1-eh_likelihood:439.10765[118]	validation_0-eh_likelihood:1761.23143	validation_1-eh_likelihood:439.60506
#
# [121]	validation_0-eh_likelihood:1755.71958	validation_1-eh_likelihood:439.22712
# [120]	validation_0-eh_likelihood:1759.40755	validation_1-eh_likelihood:438.88561
# [119]	validation_0-eh_likelihood:1761.23786	validation_1-eh_likelihood:439.60608
# [120]	validation_0-eh_likelihood:1758.35616	validation_1-eh_likelihood:439.11030
# [122]	validation_0-eh_likelihood:1755.64058	validation_1-eh_likelihood:439.21785
# [121]	validation_0-eh_likelihood:1759.28966	validation_1-eh_likelihood:438.86366
# [120]	validation_0-eh_likelihood:1761.16914	validation_1-eh_likelihood:439.59228
# [121]	validation_0-eh_likelihood:1758.29939	validation_1-eh_likelihood:439.10418
# [123]	validation_0-eh_likelihood:1755.68312	validation_1-eh_likelihood:439.22858
# [122]	validation_0-eh_likelihood:1759.28966	validation_1-eh_likelihood:438.86366
# [121]	validation_0-eh_likelihood:1761.19303	validation_1-eh_likelihood:439.60715
# [122]	validation_0-eh_likelihood:1758.26020	validation_1-eh_likelihood:439.08535
# [124]	validation_0-eh_likelihood:1755.68387	validation_1-eh_likelihood:439.22358
# [123]	validation_0-eh_likelihood:1759.31758	validation_1-eh_likelihood:438.86854
# [123]	validation_0-eh_likelihood:1758.21602	validation_1-eh_likelihood:439.07951
# [122]	validation_0-eh_likelihood:1761.18415	validation_1-eh_likelihood:439.60686
# [125]	validation_0-eh_likelihood:1755.62535	validation_1-eh_likelihood:439.22518
# [124]	validation_0-eh_likelihood:1759.33114	validation_1-eh_likelihood:438.87399
# [124]	validation_0-eh_likelihood:1758.21602	validation_1-eh_likelihood:439.07951
# [123]	validation_0-eh_likelihood:1761.14388	validation_1-eh_likelihood:439.60339
# [126]	validation_0-eh_likelihood:1755.57446	validation_1-eh_likelihood:439.21523
# [125]	validation_0-eh_likelihood:1759.31176	validation_1-eh_likelihood:438.87810
# [125]	validation_0-eh_likelihood:1758.18774	validation_1-eh_likelihood:439.07613
# ...
# [187]	validation_0-eh_likelihood:1758.55792	validation_1-eh_likelihood:440.86724
# [191]	validation_0-eh_likelihood:1755.32164	validation_1-eh_likelihood:440.86321
# [334]	validation_0-eh_likelihood:1752.62881	validation_1-eh_likelihood:439.79833
# [188]	validation_0-eh_likelihood:1758.55916	validation_1-eh_likelihood:440.87031
# [192]	validation_0-eh_likelihood:1755.33544	validation_1-eh_likelihood:440.85315
# [335]	validation_0-eh_likelihood:1752.58480	validation_1-eh_likelihood:439.79064
# [189]	validation_0-eh_likelihood:1758.54017	validation_1-eh_likelihood:440.85860
# [193]	validation_0-eh_likelihood:1755.20392	validation_1-eh_likelihood:440.82561
# [336]	validation_0-eh_likelihood:1752.51088	validation_1-eh_likelihood:439.76283
# [190]	validation_0-eh_likelihood:1758.54017	validation_1-eh_likelihood:440.85860
# [194]	validation_0-eh_likelihood:1755.14601	validation_1-eh_likelihood:440.82036
# [337]	validation_0-eh_likelihood:1752.49781	validation_1-eh_likelihood:439.75608
# [191]	validation_0-eh_likelihood:1758.52410	validation_1-eh_likelihood:440.85519
# [195]	validation_0-eh_likelihood:1755.11518	validation_1-eh_likelihood:440.81768
# [338]	validation_0-eh_likelihood:1752.46698	validation_1-eh_likelihood:439.75132
# [192]	validation_0-eh_likelihood:1758.55540	validation_1-eh_likelihood:440.86594
# [196]	validation_0-eh_likelihood:1755.01493	validation_1-eh_likelihood:440.78998
# [339]	validation_0-eh_likelihood:1752.50975	validation_1-eh_likelihood:439.76303
# [193]	validation_0-eh_likelihood:1758.56086	validation_1-eh_likelihood:440.87821
# [197]	validation_0-eh_likelihood:1754.99734	validation_1-eh_likelihood:440.78500
# [340]	validation_0-eh_likelihood:1752.49721	validation_1-eh_likelihood:439.75516
# [194]	validation_0-eh_likelihood:1758.51884	validation_1-eh_likelihood:440.86015
# [198]	validation_0-eh_likelihood:1754.99734	validation_1-eh_likelihood:440.78500
# [341]	validation_0-eh_likelihood:1752.46077	validation_1-eh_likelihood:439.75151
# [195]	validation_0-eh_likelihood:1758.46566	validation_1-eh_likelihood:440.84891
# [199]	validation_0-eh_likelihood:1754.97847	validation_1-eh_likelihood:440.78777
# [342]	validation_0-eh_likelihood:1752.36544	validation_1-eh_likelihood:439.73428
# [200]	validation_0-eh_likelihood:1754.90612	validation_1-eh_likelihood:440.75645
# [196]	validation_0-eh_likelihood:1758.41087	validation_1-eh_likelihood:440.84231
# [343]	validation_0-eh_likelihood:1752.30784	validation_1-eh_likelihood:439.71691
# [201]	validation_0-eh_likelihood:1754.83122	validation_1-eh_likelihood:440.73737
# [197]	validation_0-eh_likelihood:1758.28944	validation_1-eh_likelihood:440.81498
# [344]	validation_0-eh_likelihood:1752.30784	validation_1-eh_likelihood:439.71691
# [202]	validation_0-eh_likelihood:1754.80371	validation_1-eh_likelihood:440.73110
# [198]	validation_0-eh_likelihood:1758.21955	validation_1-eh_likelihood:440.79572
# [345]	validation_0-eh_likelihood:1752.30784	validation_1-eh_likelihood:439.71691
# [203]	validation_0-eh_likelihood:1754.74806	validation_1-eh_likelihood:440.72875
# [199]	validation_0-eh_likelihood:1758.21109	validation_1-eh_likelihood:440.79606
# [346]	validation_0-eh_likelihood:1752.22617	validation_1-eh_likelihood:439.68783
# [204]	validation_0-eh_likelihood:1754.70674	validation_1-eh_likelihood:440.71407
# [200]	validation_0-eh_likelihood:1758.15130	validation_1-eh_likelihood:440.78539
# [347]	validation_0-eh_likelihood:1752.22617	validation_1-eh_likelihood:439.68783
# [205]	validation_0-eh_likelihood:1754.68025	validation_1-eh_likelihood:440.71061
# [201]	validation_0-eh_likelihood:1758.07548	validation_1-eh_likelihood:440.76350
# [348]	validation_0-eh_likelihood:1752.17538	validation_1-eh_likelihood:439.67466
# [206]	validation_0-eh_likelihood:1754.66249	validation_1-eh_likelihood:440.70891
# [202]	validation_0-eh_likelihood:1758.04066	validation_1-eh_likelihood:440.74977
# [349]	validation_0-eh_likelihood:1752.17538	validation_1-eh_likelihood:439.67466
# [207]	validation_0-eh_likelihood:1754.59232	validation_1-eh_likelihood:440.68893
# [203]	validation_0-eh_likelihood:1758.05348	validation_1-eh_likelihood:440.75892
# [350]	validation_0-eh_likelihood:1752.17470	validation_1-eh_likelihood:439.67586
# [208]	validation_0-eh_likelihood:1754.56699	validation_1-eh_likelihood:440.68129
# [204]	validation_0-eh_likelihood:1758.05348	validation_1-eh_likelihood:440.75892
# [351]	validation_0-eh_likelihood:1752.12738	validation_1-eh_likelihood:439.66652
# [209]	validation_0-eh_likelihood:1754.54341	validation_1-eh_likelihood:440.67894
# [205]	validation_0-eh_likelihood:1758.09262	validation_1-eh_likelihood:440.77498
# [352]	validation_0-eh_likelihood:1752.07407	validation_1-eh_likelihood:439.65532
# [210]	validation_0-eh_likelihood:1754.54341	validation_1-eh_likelihood:440.67894
# [206]	validation_0-eh_likelihood:1758.04543	validation_1-eh_likelihood:440.76312
# [353]	validation_0-eh_likelihood:1752.07407	validation_1-eh_likelihood:439.65532
# [211]	validation_0-eh_likelihood:1754.48863	validation_1-eh_likelihood:440.66272
# [207]	validation_0-eh_likelihood:1758.04615	validation_1-eh_likelihood:440.75932
# [354]	validation_0-eh_likelihood:1752.07249	validation_1-eh_likelihood:439.65028
# [212]	validation_0-eh_likelihood:1754.48616	validation_1-eh_likelihood:440.67422
# [208]	validation_0-eh_likelihood:1758.03457	validation_1-eh_likelihood:440.75747
# [355]	validation_0-eh_likelihood:1752.05901	validation_1-eh_likelihood:439.65096
# [213]	validation_0-eh_likelihood:1754.48248	validation_1-eh_likelihood:440.67712
# [209]	validation_0-eh_likelihood:1758.03560	validation_1-eh_likelihood:440.74422
# [356]	validation_0-eh_likelihood:1752.03279	validation_1-eh_likelihood:439.64318
# [214]	validation_0-eh_likelihood:1754.39951	validation_1-eh_likelihood:440.66347
# [210]	validation_0-eh_likelihood:1757.97725	validation_1-eh_likelihood:440.73471
# [357]	validation_0-eh_likelihood:1752.02022	validation_1-eh_likelihood:439.64269
# [215]	validation_0-eh_likelihood:1754.34035	validation_1-eh_likelihood:440.64294
# [211]	validation_0-eh_likelihood:1757.97549	validation_1-eh_likelihood:440.73676
# [358]	validation_0-eh_likelihood:1751.98718	validation_1-eh_likelihood:439.63659
# [216]	validation_0-eh_likelihood:1754.25755	validation_1-eh_likelihood:440.62036
# [359]	validation_0-eh_likelihood:1751.98718	validation_1-eh_likelihood:439.63659
# [212]	validation_0-eh_likelihood:1757.95405	validation_1-eh_likelihood:440.73834
# [217]	validation_0-eh_likelihood:1754.22055	validation_1-eh_likelihood:440.61578
# [360]	validation_0-eh_likelihood:1751.98718	validation_1-eh_likelihood:439.63659
# [213]	validation_0-eh_likelihood:1757.93993	validation_1-eh_likelihood:440.72793
# [218]	validation_0-eh_likelihood:1754.18203	validation_1-eh_likelihood:440.60344
# [361]	validation_0-eh_likelihood:1751.95898	validation_1-eh_likelihood:439.62096
# [214]	validation_0-eh_likelihood:1757.91150	validation_1-eh_likelihood:440.70530
# [219]	validation_0-eh_likelihood:1754.15978	validation_1-eh_likelihood:440.59903
# [362]	validation_0-eh_likelihood:1751.99400	validation_1-eh_likelihood:439.63272
# [215]	validation_0-eh_likelihood:1757.91150	validation_1-eh_likelihood:440.70530
# [220]	validation_0-eh_likelihood:1754.16404	validation_1-eh_likelihood:440.59484
# [363]	validation_0-eh_likelihood:1751.98263	validation_1-eh_likelihood:439.63207
# [216]	validation_0-eh_likelihood:1757.91150	validation_1-eh_likelihood:440.70530
# [221]	validation_0-eh_likelihood:1754.16404	validation_1-eh_likelihood:440.59484
# [364]	validation_0-eh_likelihood:1751.98892	validation_1-eh_likelihood:439.63297
# [217]	validation_0-eh_likelihood:1757.89040	validation_1-eh_likelihood:440.70414
# [222]	validation_0-eh_likelihood:1754.11710	validation_1-eh_likelihood:440.58164
# [365]	validation_0-eh_likelihood:1751.96853	validation_1-eh_likelihood:439.62278
# [218]	validation_0-eh_likelihood:1757.88734	validation_1-eh_likelihood:440.70581
# [366]	validation_0-eh_likelihood:1751.93341	validation_1-eh_likelihood:439.62177
# [223]	validation_0-eh_likelihood:1754.07456	validation_1-eh_likelihood:440.57671
# [219]	validation_0-eh_likelihood:1757.86526	validation_1-eh_likelihood:440.69896
# [367]	validation_0-eh_likelihood:1751.90055	validation_1-eh_likelihood:439.61764
# [224]	validation_0-eh_likelihood:1754.03763	validation_1-eh_likelihood:440.57715
# [220]	validation_0-eh_likelihood:1757.83562	validation_1-eh_likelihood:440.69182
# [368]	validation_0-eh_likelihood:1751.84945	validation_1-eh_likelihood:439.60208
# [225]	validation_0-eh_likelihood:1754.04960	validation_1-eh_likelihood:440.58374
# [221]	validation_0-eh_likelihood:1757.79866	validation_1-eh_likelihood:440.68424
# [369]	validation_0-eh_likelihood:1751.81747	validation_1-eh_likelihood:439.60324
# [226]	validation_0-eh_likelihood:1754.00702	validation_1-eh_likelihood:440.58279
# [222]	validation_0-eh_likelihood:1757.76248	validation_1-eh_likelihood:440.66868
# [370]	validation_0-eh_likelihood:1751.76685	validation_1-eh_likelihood:439.59388
# [227]	validation_0-eh_likelihood:1753.99836	validation_1-eh_likelihood:440.57493
# [223]	validation_0-eh_likelihood:1757.70259	validation_1-eh_likelihood:440.64533
# [371]	validation_0-eh_likelihood:1751.72093	validation_1-eh_likelihood:439.57701
# [228]	validation_0-eh_likelihood:1753.95586	validation_1-eh_likelihood:440.56717
# [224]	validation_0-eh_likelihood:1757.67898	validation_1-eh_likelihood:440.63441
# [372]	validation_0-eh_likelihood:1751.69058	validation_1-eh_likelihood:439.57191
# [229]	validation_0-eh_likelihood:1753.95586	validation_1-eh_likelihood:440.56717
# [225]	validation_0-eh_likelihood:1757.61352	validation_1-eh_likelihood:440.61527
# [373]	validation_0-eh_likelihood:1751.68364	validation_1-eh_likelihood:439.56725
# [230]	validation_0-eh_likelihood:1753.91307	validation_1-eh_likelihood:440.55504
# [374]	validation_0-eh_likelihood:1751.68912	validation_1-eh_likelihood:439.56465
# [226]	validation_0-eh_likelihood:1757.58050	validation_1-eh_likelihood:440.60357
# [231]	validation_0-eh_likelihood:1753.86871	validation_1-eh_likelihood:440.54937
# [375]	validation_0-eh_likelihood:1751.68912	validation_1-eh_likelihood:439.56465
# [227]	validation_0-eh_likelihood:1757.58231	validation_1-eh_likelihood:440.60384
# [232]	validation_0-eh_likelihood:1753.84998	validation_1-eh_likelihood:440.54269
# [376]	validation_0-eh_likelihood:1751.62935	validation_1-eh_likelihood:439.55032
# [228]	validation_0-eh_likelihood:1757.56665	validation_1-eh_likelihood:440.60078
# [233]	validation_0-eh_likelihood:1753.78759	validation_1-eh_likelihood:440.53175
# [377]	validation_0-eh_likelihood:1751.58652	validation_1-eh_likelihood:439.53981
# [229]	validation_0-eh_likelihood:1757.56669	validation_1-eh_likelihood:440.60327
# [378]	validation_0-eh_likelihood:1751.52677	validation_1-eh_likelihood:439.52106
# [230]	validation_0-eh_likelihood:1757.52413	validation_1-eh_likelihood:440.59795
# [379]	validation_0-eh_likelihood:1751.50650	validation_1-eh_likelihood:439.51304
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 67
#      59 np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
#      61 #np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
#      62 #np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')
#      63
#      64 #np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
#      65 #np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')
# ---> 67 rs.fit(X_train, y_train.values, estimator__eval_test_size=validation_size)
#      68 best_preds_train = rs.best_estimator_.predict(X_train)
#      69 best_preds_test = rs.best_estimator_.predict(X_test)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1768, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1766 def _run_search(self, evaluate_candidates):
#    1767     """Search n_iter candidates from param_distributions"""
# -> 1768     evaluate_candidates(
#    1769         ParameterSampler(
#    1770             self.param_distributions, self.n_iter, random_state=self.random_state
#    1771         )
#    1772     )
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## TCGA Train, Test, Evaluation

# %%
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
'pca__n_components': [8, 16, 32, 64]
}

# %%
cancer_types = ['BLCA',
    'BRCA',
    'HNSC',
    'KIRC',
    'LGG',
    'LIHC',
    'LUAD',
    'LUSC',
    'OV',
    'STAD']
agg_metrics_cindex = []
agg_metrics_ibs = []


for idx, cancer_type in enumerate(cancer_types):
    model = 'xgbsurv_eh_'
    # get name of current dataset
    data = load_tcga(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", cancer_type=cancer_type, as_frame=True)
    filename = data.filename
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()
    X, y = sort_X_y_pandas(X, y)
    y = pd.concat([data.target,data.target], axis=1)
    dataset_name = filename.split('_')[0]

    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='eh_objective',
        eval_metric='eh_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    
    pipe = Pipeline([('scaler',ct),
                    ('pca', PCA()),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=n_iter, refit=True, random_state=rand_state)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        #print(y_train.shape, type(y_train))
        #print(X_train.shape, type(X_train))
        #print(X_test.shape, type(X_test))
        #print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_eh(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_eh(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
            # cindex
    df_agg_metrics_cindex = pd.DataFrame({'dataset':[dataset_name],
                                            'cindex_train_mean':df_outer_scores['cindex_train_'+dataset_name].mean(),
                                            'cindex_train_std':df_outer_scores['cindex_train_'+dataset_name].std(),
                                            'cindex_test_mean':df_outer_scores['cindex_test_'+dataset_name].mean(),
                                            'cindex_test_std':df_outer_scores['cindex_test_'+dataset_name].std() })
    # IBS
    df_agg_metrics_ibs = pd.DataFrame({'dataset':[dataset_name],
                                            'ibs_train_mean':df_outer_scores['ibs_train_'+dataset_name].mean(),
                                            'ibs_train_std':df_outer_scores['ibs_train_'+dataset_name].std(),
                                            'ibs_test_mean':df_outer_scores['ibs_test_'+dataset_name].mean(),
                                            'ibs_test_std':df_outer_scores['ibs_test_'+dataset_name].std() })

    agg_metrics_cindex.append(df_agg_metrics_cindex)
    agg_metrics_ibs.append(df_agg_metrics_ibs)
# Out:
# y errory error       target  target
# 346 -1582.0 -1582.0
# 320 -1110.0 -1110.0
# 343 -1542.0 -1542.0
# 124  -372.0  -372.0
# 234   599.0   599.0
# ..      ...     ...
# 20    -68.0   -68.0
# 225  -578.0  -578.0
# 146   406.0   406.0
# 242   623.0   623.0
# 256   674.0   674.0
#
# [207 rows x 2 columns] <class 'pandas.core.frame.DataFrame'>
#      target  target
# 355 -1761.0 -1761.0
# 322 -1127.0 -1127.0
# 353 -1714.0 -1714.0
# 120  -369.0  -369.0
# 243   630.0   630.0
# ..      ...     ...
# 25    -82.0   -82.0
# 237  -610.0  -610.0
# 162   434.0   434.0
# 255   665.0   665.0
# 264   706.0   706.0
#
# [207 rows x 2 columns] <class 'pandas.core.frame.DataFrame'>
# y error      target  target
# 350 -1649.0 -1649.0
# 179  -475.0  -475.0
# 382 -2380.0 -2380.0
# 117  -366.0  -366.0
# 385  2641.0  2641.0
# ..      ...     ...
# 358 -1806.0 -1806.0
# 229  -582.0  -582.0
# 136   386.0   386.0
# 18     65.0    65.0
# 259   690.0   690.0
#
# [207 rows x 2 columns] <class 'pandas.core.frame.DataFrame'>
# y error      target  target
# 358 -1806.0 -1806.0
# 189  -495.0  -495.0
# 388 -2790.0 -2790.0
# 120  -369.0  -369.0
# 370  2020.0  2020.0
# ..      ...     ...
# 364 -1947.0 -1947.0
# 237  -610.0  -610.0
# 123   370.0   370.0
# 5      20.0    20.0
# 257   680.0   680.0
#
# [207 rows x 2 columns] <class 'pandas.core.frame.DataFrame'>
# y error      target  target
# 72    237.0   237.0
# 14    -59.0   -59.0
# 88    273.0   273.0
# 119  -368.0  -368.0
# 91    278.0   278.0
# ..      ...     ...
# 356 -1792.0 -1792.0
# 225  -578.0  -578.0
# 147   408.0   408.0
# 257   680.0   680.0
# 308  1004.0  1004.0
#
# [208 rows x 2 columns] <class 'pandas.core.frame.DataFrame'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 72
#      69 np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
#      70 np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')
# ---> 72 rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
#      73 best_preds_train = rs.best_estimator_.predict(X_train)
#      74 best_preds_test = rs.best_estimator_.predict(X_test)
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1768, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1766 def _run_search(self, evaluate_candidates):
#    1767     """Search n_iter candidates from param_distributions"""
# -> 1768     evaluate_candidates(
#    1769         ParameterSampler(
#    1770             self.param_distributions, self.n_iter, random_state=self.random_state
#    1771         )
#    1772     )
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:851, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     844 elif len(out) != n_candidates * n_splits:
#     845     raise ValueError(
#     846         "cv.split and cv.get_n_splits returned "
#     847         "inconsistent results. Expected {} "
#     848         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     849     )
# --> 851 _warn_or_raise_about_fit_failures(out, self.error_score)
#     853 # For callable self.scoring, the return type is only know after
#     854 # calling. If the return type is a dictionary, the error scores
#     855 # can now be inserted with the correct key. The type checking
#     856 # of out will be done in `_insert_error_scores`.
#     857 if callable(self.scoring):
#
# File ~/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:367, in _warn_or_raise_about_fit_failures(results, error_score)
#     360 if num_failed_fits == num_fits:
#     361     all_fits_failed_message = (
#     362         f"\nAll the {num_fits} fits failed.\n"
#     363         "It is very likely that your model is misconfigured.\n"
#     364         "You can try to debug the error by setting error_score='raise'.\n\n"
#     365         f"Below are more details about the failures:\n{fit_errors_summary}"
#     366     )
# --> 367     raise ValueError(all_fits_failed_message)
#     369 else:
#     370     some_fits_failed_message = (
#     371         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     372         "The score on these train-test partitions for these parameters"
#    (...)
#     376         f"Below are more details about the failures:\n{fit_errors_summary}"
#     377     )
#
# ValueError:
# All the 5 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/sklearn/pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/xgbsurv/base.py", line 107, in fit
#     X_train, y_train = self._sort_X_y(X_train, y_train)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.11/site-packages/xgbsurv/base.py", line 175, in _sort_X_y
#     raise ValueError(f'y is not numpy.ndarray. Got {type(y)}.')
# ValueError: y is not numpy.ndarray. Got <class 'pandas.core.frame.DataFrame'>.

# %%
df_final_breslow_1_cindex = pd.concat([df for df in agg_metrics_cindex]).round(4)
df_final_breslow_1_cindex.to_csv('metrics/final_gbdt_tcga_eh_1_cindex.csv', index=False)
df_final_breslow_1_cindex.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_tcga_eh_cindex.csv', index=False)  #
df_final_breslow_1_cindex
# Out:
#   dataset  cindex_train_mean  cindex_train_std  cindex_test_mean  \
# 0    BLCA             0.7440            0.0122            0.5822
# 0    BRCA             0.8445            0.0161            0.5264
# 0    HNSC             0.7756            0.0118            0.5219
# 0    KIRC             0.8115            0.0121            0.6186
# 0     LGG             0.8461            0.0136            0.7583
# 0    LIHC             0.7482            0.0622            0.5116
# 0    LUAD             0.7718            0.0075            0.5470
# 0    LUSC             0.6836            0.0810            0.4753
# 0      OV             0.5916            0.0198            0.4774
# 0    STAD             0.6990            0.1153            0.4875
#
#    cindex_test_std
# 0           0.0175
# 0           0.0513
# 0           0.0441
# 0           0.0546
# 0           0.0493
# 0           0.0510
# 0           0.0468
# 0           0.0590
# 0           0.0339
# 0           0.0582

# %%
df_final_breslow_1_ibs = pd.concat([df for df in agg_metrics_ibs]).round(4)
df_final_breslow_1_ibs.to_csv('metrics/final_gbdt_tcga_eh_ibs.csv', index=False)
df_final_breslow_1_ibs.to_csv('/Users/JUSC/Documents/644928e0fb7e147893e8ec15/05_thesis/tables/final_gbdt_tcga_eh_ibs.csv', index=False) 
df_final_breslow_1_ibs
# Out:
#   dataset  ibs_train_mean  ibs_train_std  ibs_test_mean  ibs_test_std
# 0    BLCA          0.2090         0.0047         0.2224        0.0066
# 0    BRCA          0.1854         0.0027         0.1962        0.0097
# 0    HNSC          0.1803         0.0054         0.2038        0.0062
# 0    KIRC          0.1969         0.0026         0.1998        0.0065
# 0     LGG          0.1690         0.0054         0.1912        0.0127
# 0    LIHC          0.2023         0.0074         0.2181        0.0136
# 0    LUAD          0.1851         0.0046         0.1990        0.0108
# 0    LUSC          0.1892         0.0039         0.2037        0.0119
# 0      OV          0.1266         0.0077         0.1442        0.0183
# 0    STAD          0.2056         0.0038         0.2166        0.0081
