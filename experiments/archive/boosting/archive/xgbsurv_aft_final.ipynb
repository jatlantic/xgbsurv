# %%
## XGBSurv AFT Benchmark

# %%
from xgbsurv.datasets import (load_metabric, load_flchain, load_rgbsg, load_support, load_tcga)
from xgbsurv import XGBSurv
from xgbsurv.evaluation import cindex_censored, ibs
from xgbsurv.models.utils import sort_X_y
import os
import numpy as np
import pandas as pd
from scipy.stats import uniform as scuniform
from scipy.stats import randint as scrandint
from scipy.stats import loguniform as scloguniform 
from sklearn.metrics import make_scorer
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, LabelBinarizer, OneHotEncoder
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.decomposition import PCA
# import models
from xgbsurv.models.breslow_final import breslow_likelihood,get_cumulative_hazard_function_breslow
from xgbsurv.models.eh_aft_final import aft_likelihood
from pycox.evaluation import EvalSurv
from xgbsurv.models.utils import sort_X_y_pandas, transform_back, transform
from xgbsurv.preprocessing.dataset_preprocessing import discretizer_df

# %% [markdown]
# ## Set Parameters

# %%
# set parameters
n_outer_splits = 5
n_inner_splits = 5
rand_state = 42
n_iter = 100
early_stopping_rounds=10
base_score = 0.0

# Define parameter grid for random forest classifier
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
}

# %% [markdown]
# ## Custom Splitting

# %%
class CustomSplit(StratifiedKFold):
    def __init__(self, n_splits=5, shuffle=True, random_state=None):
        super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)

    def split(self, X, y, groups=None):
        try:
            if y.shape[1]>1:
                y = y[:,0]
        except:
            pass
        bins = np.sign(y)
        return super().split(X, bins, groups=groups)

    def get_n_splits(self, X=None, y=None, groups=None):
        return self.n_splits

outer_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)
inner_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)

# %%
## Scoring Function

# %%
scoring_function = make_scorer(aft_likelihood, greater_is_better=False)

# %%
## Set Model & Train Test Evaluate

# %%
data_set_fns = [load_metabric,  load_flchain, load_rgbsg, load_support] #, load_flchain, load_rgbsg, load_support, load_tcga]
data_set_fns_str = ['load_metabric', 'load_flchain', 'load_rgbsg', 'load_support'] 
one_hot_dict = {'load_flchain': ['mgus'], 'load_support':['cancer'], 'load_rgbsg':['grade']}

for idx, dataset in enumerate(data_set_fns):
    model = 'xgbsurv_aft_'
    # get name of current dataset
    data = dataset(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=True)
    filename = data.filename
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()

    print(data_set_fns_str[idx])
    if data_set_fns_str[idx] in one_hot_dict.keys():
        X = pd.get_dummies(X, columns=one_hot_dict[data_set_fns_str[idx]])
    X, y = sort_X_y_pandas(X, y)
    #print(X.dtypes)
    dataset_name = filename.split('_')[0]
    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            #(OneHotEncoder(sparse_output=False), make_column_selector(dtype_include=['category', 'object']))
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='aft_objective',
        eval_metric='aft_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    pipe = Pipeline([('scaler',ct),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=2, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        print(X_train.shape, type(X_train))
        print(y_train.shape, type(y_train))
        print(X_test.shape, type(X_test))
        print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_breslow(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_breslow(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# Out:
# load_metabric
# (1522, 9) <class 'pandas.core.frame.DataFrame'>
# (1522,) <class 'pandas.core.series.Series'>
# (381, 9) <class 'pandas.core.frame.DataFrame'>
# (381,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [0]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [1]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [1]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [2]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [2]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [3]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [3]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [4]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [4]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [5]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [5]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [6]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [6]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [7]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [7]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [8]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [8]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [9]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [9]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [0]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [0]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [1]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [1]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [2]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [2]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [0]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [0]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [0]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [3]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [0]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [3]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [1]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [4]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [1]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [1]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [0]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [1]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [4]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [0]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [2]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [5]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [2]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [2]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [1]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [5]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [2]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [3]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [6]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [1]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [3]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [3]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [2]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [3]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [6]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [4]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [7]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [4]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [4]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [2]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [5]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [3]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [4]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [7]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [8]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [5]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [4]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [5]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [6]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [3]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [8]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [5]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [9]	validation_0-aft_likelihood:3.09031	validation_1-aft_likelihood:3.23914
# [6]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [6]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [7]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [6]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [5]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [9]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [4]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [7]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [8]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [5]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [7]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [6]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [8]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [7]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [9]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [8]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [9]	validation_0-aft_likelihood:3.09364	validation_1-aft_likelihood:3.22469
# [6]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [7]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [8]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [9]	validation_0-aft_likelihood:3.12968	validation_1-aft_likelihood:3.08786
# [8]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [7]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [8]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [9]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [9]	validation_0-aft_likelihood:3.12291	validation_1-aft_likelihood:3.13984
# [9]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [10]	validation_0-aft_likelihood:3.09534	validation_1-aft_likelihood:3.21812
# [0]	validation_0-aft_likelihood:3.07901	validation_1-aft_likelihood:3.28572
# [1]	validation_0-aft_likelihood:3.07901	validation_1-aft_likelihood:3.28572
# [2]	validation_0-aft_likelihood:3.07901	validation_1-aft_likelihood:3.28572
# [3]	validation_0-aft_likelihood:3.07901	validation_1-aft_likelihood:3.28572
# [4]	validation_0-aft_likelihood:3.07901	validation_1-aft_likelihood:3.28572
# [5]	validation_0-aft_likelihood:3.07901	validation_1-aft_likelihood:3.28572
# [6]	validation_0-aft_likelihood:3.07901	validation_1-aft_likelihood:3.28572
# [7]	validation_0-aft_likelihood:3.07901	validation_1-aft_likelihood:3.28572
# [8]	validation_0-aft_likelihood:3.07901	validation_1-aft_likelihood:3.28572
# [9]	validation_0-aft_likelihood:3.07901	validation_1-aft_likelihood:3.28572
# Concordance Index 0.0
# Integrated Brier Score: 0.1740533502911732
# durations 0.76666665 337.03333
# Concordance Index 0.0
# Integrated Brier Score: 0.1877528848500374
# (1522, 9) <class 'pandas.core.frame.DataFrame'>
# (1522,) <class 'pandas.core.series.Series'>
# (381, 9) <class 'pandas.core.frame.DataFrame'>
# (381,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [0]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [0]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [1]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [0]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [0]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [0]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [0]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [1]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [1]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [2]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [0]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [1]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [1]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [1]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [2]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [1]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [2]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [2]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [3]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [3]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [2]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [1]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [2]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [4]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [4]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [2]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [3]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [3]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [5]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [5]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [2]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [3]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [3]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [6]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [4]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [4]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [3]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [6]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [3]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [7]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [4]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [4]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [5]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [5]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [7]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [4]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [8]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [4]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [6]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [5]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [5]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [8]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [5]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [9]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [6]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [5]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [7]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [6]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [6]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [6]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [7]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [7]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [8]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [9]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [6]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [7]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [7]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [8]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [8]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [9]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [7]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [8]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [8]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [9]	validation_0-aft_likelihood:3.11769	validation_1-aft_likelihood:3.17496
# [9]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [8]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [10]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [9]	validation_0-aft_likelihood:3.17366	validation_1-aft_likelihood:2.96079
# [9]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [9]	validation_0-aft_likelihood:3.14350	validation_1-aft_likelihood:3.03076
# [0]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [0]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [1]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [1]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [2]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [2]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [3]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [3]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [4]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [4]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [5]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [5]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [6]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [6]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [7]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [7]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [8]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [8]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [9]	validation_0-aft_likelihood:3.12139	validation_1-aft_likelihood:3.12259
# [9]	validation_0-aft_likelihood:3.14477	validation_1-aft_likelihood:3.03300
# [0]	validation_0-aft_likelihood:3.10869	validation_1-aft_likelihood:3.18232
# [1]	validation_0-aft_likelihood:3.10869	validation_1-aft_likelihood:3.18232
# [2]	validation_0-aft_likelihood:3.10869	validation_1-aft_likelihood:3.18232
# [3]	validation_0-aft_likelihood:3.10869	validation_1-aft_likelihood:3.18232
# [4]	validation_0-aft_likelihood:3.10869	validation_1-aft_likelihood:3.18232
# [5]	validation_0-aft_likelihood:3.10869	validation_1-aft_likelihood:3.18232
# [6]	validation_0-aft_likelihood:3.10869	validation_1-aft_likelihood:3.18232
# [7]	validation_0-aft_likelihood:3.10869	validation_1-aft_likelihood:3.18232
# [8]	validation_0-aft_likelihood:3.10869	validation_1-aft_likelihood:3.18232
# [9]	validation_0-aft_likelihood:3.10869	validation_1-aft_likelihood:3.18232
# Concordance Index 0.0
# Integrated Brier Score: 0.1760937570049515
# durations 0.1 330.36667
# Concordance Index 0.0
# Integrated Brier Score: 0.18324782772643033
# (1522, 9) <class 'pandas.core.frame.DataFrame'>
# (1522,) <class 'pandas.core.series.Series'>
# (381, 9) <class 'pandas.core.frame.DataFrame'>
# (381,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [0]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [0]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [1]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [0]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [0]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [1]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [2]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [0]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [1]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [0]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [0]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [2]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [1]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [3]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [1]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [1]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [3]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [2]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [4]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [0]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [2]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [1]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [4]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [1]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [2]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [5]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [3]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [2]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [1]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [5]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [2]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [3]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [3]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [4]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [6]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [6]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [4]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [2]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [3]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [3]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [7]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [5]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [7]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [2]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [4]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [5]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [4]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [8]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [3]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [4]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [6]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [3]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [5]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [8]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [6]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [9]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [0]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [6]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [5]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [7]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [9]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [4]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [7]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [4]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [5]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [6]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [7]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [8]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [5]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [5]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [8]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [1]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [7]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [6]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [8]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [6]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [9]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [6]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [9]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [8]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [10]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [7]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [7]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [9]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [7]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [10]	validation_0-aft_likelihood:3.15519	validation_1-aft_likelihood:3.01245
# [2]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [9]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [8]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [8]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [8]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [10]	validation_0-aft_likelihood:3.10884	validation_1-aft_likelihood:3.16637
# [9]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [9]	validation_0-aft_likelihood:3.12533	validation_1-aft_likelihood:3.09743
# [9]	validation_0-aft_likelihood:3.13347	validation_1-aft_likelihood:3.08305
# [3]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [4]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [5]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [6]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [7]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [8]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [9]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [10]	validation_0-aft_likelihood:3.09744	validation_1-aft_likelihood:3.20978
# [0]	validation_0-aft_likelihood:3.13403	validation_1-aft_likelihood:3.06110
# [1]	validation_0-aft_likelihood:3.13403	validation_1-aft_likelihood:3.06110
# [2]	validation_0-aft_likelihood:3.13403	validation_1-aft_likelihood:3.06110
# [3]	validation_0-aft_likelihood:3.13403	validation_1-aft_likelihood:3.06110
# [4]	validation_0-aft_likelihood:3.13403	validation_1-aft_likelihood:3.06110
# [5]	validation_0-aft_likelihood:3.13403	validation_1-aft_likelihood:3.06110
# [6]	validation_0-aft_likelihood:3.13403	validation_1-aft_likelihood:3.06110
# [7]	validation_0-aft_likelihood:3.13403	validation_1-aft_likelihood:3.06110
# [8]	validation_0-aft_likelihood:3.13403	validation_1-aft_likelihood:3.06110
# [9]	validation_0-aft_likelihood:3.13403	validation_1-aft_likelihood:3.06110
# Concordance Index 0.0
# Integrated Brier Score: 0.1748198370086462
# durations 1.4333333 301.23334
# Concordance Index 0.0
# Integrated Brier Score: 0.19281420544431668
# (1523, 9) <class 'pandas.core.frame.DataFrame'>
# (1523,) <class 'pandas.core.series.Series'>
# (380, 9) <class 'pandas.core.frame.DataFrame'>
# (380,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [0]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [0]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [0]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [0]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [0]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [0]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [1]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [0]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [1]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [0]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [2]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [1]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [1]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [3]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [1]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [2]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [1]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [4]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [1]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [1]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [5]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [0]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [1]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [6]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [2]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [2]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [3]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [3]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [2]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [2]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [7]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [4]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [2]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [2]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [1]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [2]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [8]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [3]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [3]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [3]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [9]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [3]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [4]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [2]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [5]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [10]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [3]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [3]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [4]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [4]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [4]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [4]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [3]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [6]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [4]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [5]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [5]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [5]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [4]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [5]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [7]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [6]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [5]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [4]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [5]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [6]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [6]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [5]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [6]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [6]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [7]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [8]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [7]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [5]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [7]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [6]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [7]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [6]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [8]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [8]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [8]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [6]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [7]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [8]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [7]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [9]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [7]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [9]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [7]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [9]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [9]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [8]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [8]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [9]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [8]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [10]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [8]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [10]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [10]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [10]	validation_0-aft_likelihood:3.10891	validation_1-aft_likelihood:3.15287
# [9]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [10]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [9]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [9]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [9]	validation_0-aft_likelihood:3.09160	validation_1-aft_likelihood:3.24298
# [10]	validation_0-aft_likelihood:3.10993	validation_1-aft_likelihood:3.17820
# [10]	validation_0-aft_likelihood:3.11802	validation_1-aft_likelihood:3.12520
# [10]	validation_0-aft_likelihood:3.10085	validation_1-aft_likelihood:3.16326
# [0]	validation_0-aft_likelihood:3.10592	validation_1-aft_likelihood:3.17059
# [1]	validation_0-aft_likelihood:3.10592	validation_1-aft_likelihood:3.17059
# [2]	validation_0-aft_likelihood:3.10592	validation_1-aft_likelihood:3.17059
# [3]	validation_0-aft_likelihood:3.10592	validation_1-aft_likelihood:3.17059
# [4]	validation_0-aft_likelihood:3.10592	validation_1-aft_likelihood:3.17059
# [5]	validation_0-aft_likelihood:3.10592	validation_1-aft_likelihood:3.17059
# [6]	validation_0-aft_likelihood:3.10592	validation_1-aft_likelihood:3.17059
# [7]	validation_0-aft_likelihood:3.10592	validation_1-aft_likelihood:3.17059
# [8]	validation_0-aft_likelihood:3.10592	validation_1-aft_likelihood:3.17059
# [9]	validation_0-aft_likelihood:3.10592	validation_1-aft_likelihood:3.17059
# Concordance Index 0.0
# Integrated Brier Score: 0.17924114641947886
# durations 1.2333333 355.2
# Concordance Index 0.0
# Integrated Brier Score: 0.1691919531920127
# (1523, 9) <class 'pandas.core.frame.DataFrame'>
# (1523,) <class 'pandas.core.series.Series'>
# (380, 9) <class 'pandas.core.frame.DataFrame'>
# (380,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [0]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [0]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [0]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [0]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [1]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [0]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [1]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [0]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [1]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [0]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [0]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [2]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [0]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [1]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [2]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [1]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [2]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [1]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [1]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [1]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [3]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [1]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [1]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [2]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [2]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [2]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [3]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [4]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [2]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [3]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [3]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [2]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [5]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [2]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [3]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [4]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [3]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [4]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [2]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [3]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [3]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [5]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [3]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [4]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [4]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [5]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [6]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [6]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [5]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [4]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [4]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [3]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [4]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [5]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [4]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [7]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [7]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [5]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [6]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [5]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [6]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [5]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [5]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [4]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [8]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [6]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [8]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [7]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [6]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [5]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [7]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [6]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [6]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [7]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [9]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [9]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [7]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [6]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [8]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [6]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [8]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [7]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [7]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [10]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [8]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [8]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [7]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [9]	validation_0-aft_likelihood:3.09473	validation_1-aft_likelihood:3.22401
# [9]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [7]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [8]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [8]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [9]	validation_0-aft_likelihood:3.13529	validation_1-aft_likelihood:3.07445
# [9]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [8]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [9]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [8]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [9]	validation_0-aft_likelihood:3.11532	validation_1-aft_likelihood:3.15418
# [9]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [10]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [10]	validation_0-aft_likelihood:3.07659	validation_1-aft_likelihood:3.24493
# [9]	validation_0-aft_likelihood:3.13459	validation_1-aft_likelihood:3.05870
# [0]	validation_0-aft_likelihood:3.08862	validation_1-aft_likelihood:3.23486
# [1]	validation_0-aft_likelihood:3.08862	validation_1-aft_likelihood:3.23486
# [2]	validation_0-aft_likelihood:3.08862	validation_1-aft_likelihood:3.23486
# [3]	validation_0-aft_likelihood:3.08862	validation_1-aft_likelihood:3.23486
# [4]	validation_0-aft_likelihood:3.08862	validation_1-aft_likelihood:3.23486
# [5]	validation_0-aft_likelihood:3.08862	validation_1-aft_likelihood:3.23486
# [6]	validation_0-aft_likelihood:3.08862	validation_1-aft_likelihood:3.23486
# [7]	validation_0-aft_likelihood:3.08862	validation_1-aft_likelihood:3.23486
# [8]	validation_0-aft_likelihood:3.08862	validation_1-aft_likelihood:3.23486
# [9]	validation_0-aft_likelihood:3.08862	validation_1-aft_likelihood:3.23486
# [10]	validation_0-aft_likelihood:3.08862	validation_1-aft_likelihood:3.23486
# Concordance Index 0.0
# Integrated Brier Score: 0.17558212481994526
# durations 1.2666667 351.0
# Concordance Index 0.0
# Integrated Brier Score: 0.1812792676409439
# load_flchain
# (6296, 9) <class 'pandas.core.frame.DataFrame'>
# (6296,) <class 'pandas.core.series.Series'>
# (1575, 9) <class 'pandas.core.frame.DataFrame'>
# (1575,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:2.57183	validation_1-aft_likelihood:2.77579
# [0]	validation_0-aft_likelihood:2.57092	validation_1-aft_likelihood:2.77779
# [0]	validation_0-aft_likelihood:2.57092	validation_1-aft_likelihood:2.77779
# [0]	validation_0-aft_likelihood:2.60154	validation_1-aft_likelihood:2.65622
# [0]	validation_0-aft_likelihood:2.58997	validation_1-aft_likelihood:2.70122
# [0]	validation_0-aft_likelihood:2.60433	validation_1-aft_likelihood:2.64234
# [0]	validation_0-aft_likelihood:2.60433	validation_1-aft_likelihood:2.64234
# [0]	validation_0-aft_likelihood:2.58997	validation_1-aft_likelihood:2.70122
# [0]	validation_0-aft_likelihood:2.60154	validation_1-aft_likelihood:2.65622
# [0]	validation_0-aft_likelihood:2.57183	validation_1-aft_likelihood:2.77579
# [1]	validation_0-aft_likelihood:2.57092	validation_1-aft_likelihood:2.77779
# [1]	validation_0-aft_likelihood:2.58997	validation_1-aft_likelihood:2.70122
# [1]	validation_0-aft_likelihood:2.60154	validation_1-aft_likelihood:2.65622
# [1]	validation_0-aft_likelihood:2.57183	validation_1-aft_likelihood:2.77579
# [1]	validation_0-aft_likelihood:2.57092	validation_1-aft_likelihood:2.77779
# [1]	validation_0-aft_likelihood:2.60433	validation_1-aft_likelihood:2.64234
# [1]	validation_0-aft_likelihood:2.58997	validation_1-aft_likelihood:2.70122
# [1]	validation_0-aft_likelihood:2.60154	validation_1-aft_likelihood:2.65622
# [1]	validation_0-aft_likelihood:2.57183	validation_1-aft_likelihood:2.77579
# [1]	validation_0-aft_likelihood:2.60433	validation_1-aft_likelihood:2.64234
# [2]	validation_0-aft_likelihood:2.57092	validation_1-aft_likelihood:2.77779
# [2]	validation_0-aft_likelihood:2.57183	validation_1-aft_likelihood:2.77579
# [2]	validation_0-aft_likelihood:2.60154	validation_1-aft_likelihood:2.65622
# [2]	validation_0-aft_likelihood:2.57183	validation_1-aft_likelihood:2.77579
# [2]	validation_0-aft_likelihood:2.60154	validation_1-aft_likelihood:2.65622
# [2]	validation_0-aft_likelihood:2.58997	validation_1-aft_likelihood:2.70122
# [2]	validation_0-aft_likelihood:2.58997	validation_1-aft_likelihood:2.70122
# [2]	validation_0-aft_likelihood:2.60433	validation_1-aft_likelihood:2.64234
# [2]	validation_0-aft_likelihood:2.60433	validation_1-aft_likelihood:2.64234
# [2]	validation_0-aft_likelihood:2.57092	validation_1-aft_likelihood:2.77779
# [3]	validation_0-aft_likelihood:2.57092	validation_1-aft_likelihood:2.77779
# [3]	validation_0-aft_likelihood:2.60154	validation_1-aft_likelihood:2.65622
# [3]	validation_0-aft_likelihood:2.57183	validation_1-aft_likelihood:2.77579
# [3]	validation_0-aft_likelihood:2.58997	validation_1-aft_likelihood:2.70122
# [3]	validation_0-aft_likelihood:2.57183	validation_1-aft_likelihood:2.77579
# [3]	validation_0-aft_likelihood:2.58997	validation_1-aft_likelihood:2.70122
# [3]	validation_0-aft_likelihood:2.60433	validation_1-aft_likelihood:2.64234
# ...
# [8]	validation_0-aft_likelihood:3.91458	validation_1-aft_likelihood:3.93393
# [9]	validation_0-aft_likelihood:3.91458	validation_1-aft_likelihood:3.93393
# [10]	validation_0-aft_likelihood:3.91458	validation_1-aft_likelihood:3.93393
# Concordance Index 0.0
# Integrated Brier Score: 0.21559349274681067
# durations 3.0 2029.0
# Concordance Index 0.0
# Integrated Brier Score: 0.21436785164385194
# (7099, 16) <class 'pandas.core.frame.DataFrame'>
# (7099,) <class 'pandas.core.series.Series'>
# (1774, 16) <class 'pandas.core.frame.DataFrame'>
# (1774,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [0]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [0]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [1]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [1]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [1]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [2]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [2]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [0]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [3]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [0]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [0]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [0]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [0]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [2]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [0]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [0]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [3]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [1]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [1]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [1]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [1]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [1]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [1]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [1]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [3]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [4]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [2]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [2]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [2]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [2]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [2]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [2]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [2]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [3]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [5]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [3]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [3]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [3]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [3]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [4]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [4]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [3]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [3]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [6]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [4]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [5]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [4]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [7]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [5]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [5]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [6]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [5]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [8]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [6]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [6]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [7]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [6]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [9]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [7]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [7]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [8]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [7]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [10]	validation_0-aft_likelihood:3.92149	validation_1-aft_likelihood:3.99897
# [8]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [8]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [8]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [9]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [9]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [9]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [9]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [10]	validation_0-aft_likelihood:3.92473	validation_1-aft_likelihood:3.93570
# [10]	validation_0-aft_likelihood:3.93664	validation_1-aft_likelihood:3.94031
# [10]	validation_0-aft_likelihood:3.92290	validation_1-aft_likelihood:3.88014
# [10]	validation_0-aft_likelihood:3.95881	validation_1-aft_likelihood:3.81501
# [0]	validation_0-aft_likelihood:3.93175	validation_1-aft_likelihood:3.91830
# [1]	validation_0-aft_likelihood:3.93175	validation_1-aft_likelihood:3.91830
# [2]	validation_0-aft_likelihood:3.93175	validation_1-aft_likelihood:3.91830
# [3]	validation_0-aft_likelihood:3.93175	validation_1-aft_likelihood:3.91830
# Concordance Index 0.0
# Integrated Brier Score: 0.21547830288969685
# durations 3.0 2029.0
# Concordance Index 0.0
# Integrated Brier Score: 0.21478057231375294
# (7099, 16) <class 'pandas.core.frame.DataFrame'>
# (7099,) <class 'pandas.core.series.Series'>
# (1774, 16) <class 'pandas.core.frame.DataFrame'>
# (1774,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [0]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [1]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [1]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [2]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [0]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [2]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [0]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [0]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [0]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [0]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [3]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [0]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [1]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [3]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [0]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [1]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [0]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [1]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [1]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [1]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [2]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [1]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [4]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [1]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [4]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [2]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [1]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [2]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [2]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [2]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [3]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [5]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [2]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [2]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [5]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [3]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [2]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [3]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [3]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [4]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [3]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [3]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [6]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [5]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [3]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [6]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [4]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [3]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [4]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [4]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [6]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [7]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [4]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [4]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [7]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [4]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [8]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [7]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [5]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [5]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [4]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [5]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [5]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [9]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [5]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [8]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [10]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [5]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [6]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [8]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [6]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [6]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [6]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [5]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [6]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [6]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [9]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [7]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [9]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [7]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [7]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [7]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [6]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [8]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [7]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [8]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [7]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [9]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [9]	validation_0-aft_likelihood:3.91949	validation_1-aft_likelihood:3.93136
# [8]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [10]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [8]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [8]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [7]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [8]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [9]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [9]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [10]	validation_0-aft_likelihood:3.94194	validation_1-aft_likelihood:3.87451
# [10]	validation_0-aft_likelihood:3.93844	validation_1-aft_likelihood:3.88904
# [9]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [8]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [9]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [10]	validation_0-aft_likelihood:3.95523	validation_1-aft_likelihood:3.77017
# [9]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [10]	validation_0-aft_likelihood:3.91028	validation_1-aft_likelihood:3.88859
# [0]	validation_0-aft_likelihood:3.93271	validation_1-aft_likelihood:3.87119
# [1]	validation_0-aft_likelihood:3.93271	validation_1-aft_likelihood:3.87119
# [2]	validation_0-aft_likelihood:3.93271	validation_1-aft_likelihood:3.87119
# [3]	validation_0-aft_likelihood:3.93271	validation_1-aft_likelihood:3.87119
# [4]	validation_0-aft_likelihood:3.93271	validation_1-aft_likelihood:3.87119
# [5]	validation_0-aft_likelihood:3.93271	validation_1-aft_likelihood:3.87119
# [6]	validation_0-aft_likelihood:3.93271	validation_1-aft_likelihood:3.87119
# [7]	validation_0-aft_likelihood:3.93271	validation_1-aft_likelihood:3.87119
# [8]	validation_0-aft_likelihood:3.93271	validation_1-aft_likelihood:3.87119
# [9]	validation_0-aft_likelihood:3.93271	validation_1-aft_likelihood:3.87119
# [10]	validation_0-aft_likelihood:3.93271	validation_1-aft_likelihood:3.87119
# Concordance Index 0.0
# Integrated Brier Score: 0.21545316006091458
# durations 3.0 2029.0
# Concordance Index 0.0
# Integrated Brier Score: 0.21501091500200498

# %% [markdown]
# ## TCGA Train, Test, Evaluation

# %%
param_grid = {
'estimator__reg_alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'estimator__reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'estimator__learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'estimator__n_estimators':  scrandint(1,100), # corresponds to num_rounds
'estimator__gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'estimator__colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'estimator__colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'estimator__colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'estimator__max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'estimator__max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'estimator__min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'estimator__subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
'pca__n_components': [8, 10, 12, 14, 16]
}

# %%
cancer_types = ['BLCA',
    'BRCA',
    'HNSC',
    'KIRC',
    'LGG',
    'LIHC',
    'LUAD',
    'LUSC',
    'OV',
    'STAD']


for idx, cancer_type in enumerate(cancer_types):
    model = 'xgbsurv_aft_'
    # get name of current dataset
    data = load_tcga(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", cancer_type=cancer_type, as_frame=True)
    X  = data.data #.astype(np.float32)
    y = data.target #.values #.to_numpy()
    filename = data.filename
    dataset_name = filename.split('_')[0]
    X, y = sort_X_y_pandas(X, y)

    # add IBS later
    outer_scores = {'cindex_train_'+dataset_name:[], 'cindex_test_'+dataset_name:[],
                    'ibs_train_'+dataset_name:[], 'ibs_test_'+dataset_name:[]}
    best_params = {'best_params_'+dataset_name:[]}
    best_model = {'best_model_'+dataset_name:[]}
    ct = make_column_transformer(
            #(OneHotEncoder(sparse_output=False), make_column_selector(dtype_include=['category', 'object']))
            (StandardScaler(), make_column_selector(dtype_include=['float32']))
            ,remainder='passthrough')
    
    estimator = XGBSurv(
        objective='aft_objective',
        eval_metric='aft_loss',
        random_state=rand_state, 
        disable_default_eval_metric=True,
        early_stopping_rounds=early_stopping_rounds, 
        base_score=base_score
                        )
    
    pipe = Pipeline([('scaler',ct),
                    ('pca', PCA()),
                    ('estimator', estimator)])
    
    rs = RandomizedSearchCV(pipe, param_grid, scoring = scoring_function, n_jobs=-1, 
                             cv=inner_custom_cv, n_iter=2, refit=True)
    
    for i, (train_index, test_index) in enumerate(outer_custom_cv.split(X, y)):
        # Split data into training and testing sets for outer fold
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        X_train, y_train = sort_X_y_pandas(X_train, y_train)
        X_test, y_test = sort_X_y_pandas(X_test, y_test)

        print(X_train.shape, type(X_train))
        print(y_train.shape, type(y_train))
        print(X_test.shape, type(X_test))
        print(y_test.shape, type(y_test))
        # save splits and data
        np.savetxt('splits/'+model+'train_index_'+str(i)+'_'+filename, train_index, delimiter=',')
        np.savetxt('splits/'+model+'test_index_'+str(i)+'_'+filename, test_index, delimiter=',')
        
        np.savetxt('splits/'+model+'X_train_'+str(i)+'_'+filename, X_train, delimiter=',')
        np.savetxt('splits/'+model+'X_test_'+str(i)+'_'+filename, X_test, delimiter=',')

        np.savetxt('splits/'+model+'y_train_'+str(i)+'_'+filename, y_train, delimiter=',')
        np.savetxt('splits/'+model+'y_test_'+str(i)+'_'+filename, y_test, delimiter=',')

        rs.fit(X_train, y_train, estimator__eval_test_size=0.2)
        best_preds_train = rs.best_estimator_.predict(X_train)
        best_preds_test = rs.best_estimator_.predict(X_test)
        # save hyperparameter settings
        params = rs.best_estimator_.get_params
        best_params['best_params_'+dataset_name] += [rs.best_params_]
        best_model['best_model_'+dataset_name] += [params]
        try:
            cum_hazard_train = get_cumulative_hazard_function_breslow(
                    X_train.values, X_train.values, y_train.values, y_train.values,
                    best_preds_train.reshape(-1), best_preds_train.reshape(-1)
                    )

            df_survival_train = np.exp(-cum_hazard_train)
            durations_train, events_train = transform_back(y_train.values)
            time_grid_train = np.linspace(durations_train.min(), durations_train.max(), 100)
            ev = EvalSurv(df_survival_train, durations_train, events_train, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_train))
            cindex_score_train = ev.concordance_td('antolini')
            ibs_score_train = ev.integrated_brier_score(time_grid_train)

            outer_scores['cindex_train_'+dataset_name] += [cindex_score_train]
            outer_scores['ibs_train_'+dataset_name] += [ibs_score_train]

        except:
            outer_scores['cindex_train_'+dataset_name] += [np.nan]
            outer_scores['ibs_train_'+dataset_name] += [np.nan]
            
        try:
            cum_hazard_test = get_cumulative_hazard_function_breslow(
                    X_train.values, X_test.values, y_train.values, y_test.values,
                    best_preds_train.reshape(-1), best_preds_test.reshape(-1)
                    )
            df_survival_test = np.exp(-cum_hazard_test)
            durations_test, events_test = transform_back(y_test.values)
            print('durations',durations_test.min(), durations_test.max())
            time_grid_test = np.linspace(durations_test.min(), durations_test.max(), 100)
            ev = EvalSurv(df_survival_test, durations_test, events_test, censor_surv='km')
            print('Concordance Index',ev.concordance_td('antolini'))
            print('Integrated Brier Score:',ev.integrated_brier_score(time_grid_test))
            cindex_score_test = ev.concordance_td('antolini')
            ibs_score_test = ev.integrated_brier_score(time_grid_test)

            outer_scores['cindex_test_'+dataset_name] += [cindex_score_test]
            outer_scores['ibs_test_'+dataset_name] += [ibs_score_test]
        except: 
            outer_scores['cindex_test_'+dataset_name] += [np.nan]
            outer_scores['ibs_test_'+dataset_name] += [np.nan]
            
    df_best_params = pd.DataFrame(best_params)
    df_best_model = pd.DataFrame(best_model)
    df_outer_scores = pd.DataFrame(outer_scores)
    df_metrics = pd.concat([df_best_params,df_best_model,df_outer_scores], axis=1)
    df_metrics.to_csv('metrics/'+model+'metric_summary_'+filename, index=False)
# Out:
# (324, 20531) <class 'pandas.core.frame.DataFrame'>
# (324,) <class 'pandas.core.series.Series'>
# (82, 20531) <class 'pandas.core.frame.DataFrame'>
# (82,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [1]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [2]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [3]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [4]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [5]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [6]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [7]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [8]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [0]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [9]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [1]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [2]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [3]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [4]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [5]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [6]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [7]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [8]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [9]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [10]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [0]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [1]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [2]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [3]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [4]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [5]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [6]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [7]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [8]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [9]	validation_0-aft_likelihood:3.16752	validation_1-aft_likelihood:3.59042
# [0]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [1]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [0]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [1]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [2]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [2]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [3]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [3]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [4]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [4]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [5]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [5]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [6]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [7]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [6]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [8]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [7]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [9]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [8]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [9]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [0]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [1]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [2]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [3]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [4]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [5]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [6]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [7]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [8]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [9]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [10]	validation_0-aft_likelihood:3.17904	validation_1-aft_likelihood:3.70488
# [0]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [1]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [2]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [3]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [4]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [5]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [6]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [7]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [8]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [9]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [0]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [1]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [2]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [3]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [4]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [5]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [6]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [7]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [8]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [9]	validation_0-aft_likelihood:3.06903	validation_1-aft_likelihood:3.88228
# [0]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [1]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [2]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [3]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [4]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [5]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [6]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [7]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [8]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [9]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [10]	validation_0-aft_likelihood:3.25761	validation_1-aft_likelihood:3.28007
# [0]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [1]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [2]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [3]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [4]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [5]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [6]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [7]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [8]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [9]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [10]	validation_0-aft_likelihood:3.18258	validation_1-aft_likelihood:3.71013
# [0]	validation_0-aft_likelihood:3.36900	validation_1-aft_likelihood:2.87567
# [1]	validation_0-aft_likelihood:3.36900	validation_1-aft_likelihood:2.87567
# [2]	validation_0-aft_likelihood:3.36900	validation_1-aft_likelihood:2.87567
# [3]	validation_0-aft_likelihood:3.36900	validation_1-aft_likelihood:2.87567
# [4]	validation_0-aft_likelihood:3.36900	validation_1-aft_likelihood:2.87567
# [5]	validation_0-aft_likelihood:3.36900	validation_1-aft_likelihood:2.87567
# [6]	validation_0-aft_likelihood:3.36900	validation_1-aft_likelihood:2.87567
# [7]	validation_0-aft_likelihood:3.36900	validation_1-aft_likelihood:2.87567
# [8]	validation_0-aft_likelihood:3.36900	validation_1-aft_likelihood:2.87567
# [9]	validation_0-aft_likelihood:3.36900	validation_1-aft_likelihood:2.87567
# [10]	validation_0-aft_likelihood:3.36900	validation_1-aft_likelihood:2.87567
# Concordance Index 0.0
# Integrated Brier Score: 0.21331883998459683
# durations 17.0 4343.0
# Concordance Index 0.0
# Integrated Brier Score: 0.2271128259147732
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [1]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [2]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [3]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [0]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [1]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [2]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [3]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [0]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [1]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [2]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [3]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [0]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [1]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [2]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [0]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [1]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [3]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [2]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [3]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [4]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [5]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [6]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [7]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [8]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [0]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [9]	validation_0-aft_likelihood:3.20478	validation_1-aft_likelihood:3.39563
# [1]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [2]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [3]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [4]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [5]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [6]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [7]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [8]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [9]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [0]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [1]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [2]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [3]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [4]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [5]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [6]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [7]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [8]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [9]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [10]	validation_0-aft_likelihood:3.34008	validation_1-aft_likelihood:2.77255
# [0]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [1]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [2]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [3]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [4]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [5]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [6]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [7]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [8]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [9]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [10]	validation_0-aft_likelihood:3.20526	validation_1-aft_likelihood:3.25892
# [0]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [1]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [0]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [2]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [1]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [3]	validation_0-aft_likelihood:3.36998	validation_1-aft_likelihood:2.88468
# [2]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [3]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [4]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [5]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [6]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [7]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [8]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [9]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [10]	validation_0-aft_likelihood:3.33111	validation_1-aft_likelihood:3.06481
# [0]	validation_0-aft_likelihood:3.41894	validation_1-aft_likelihood:2.58065
# [1]	validation_0-aft_likelihood:3.41894	validation_1-aft_likelihood:2.58065
# [2]	validation_0-aft_likelihood:3.41894	validation_1-aft_likelihood:2.58065
# [3]	validation_0-aft_likelihood:3.41894	validation_1-aft_likelihood:2.58065
# Concordance Index 0.0
# Integrated Brier Score: 0.21182897976871268
# durations 15.0 3817.0
# Concordance Index 0.0
# Integrated Brier Score: 0.2253946023724897
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [1]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [2]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [3]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [4]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [5]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [6]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [7]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [8]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [9]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [10]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [0]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [1]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [2]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [3]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [4]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [5]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [0]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [6]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [7]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [1]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [8]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [2]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [9]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [3]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [4]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [5]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [6]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [7]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [8]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [9]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [0]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [1]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [2]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [0]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [3]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [4]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [5]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [6]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [1]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [2]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [3]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [7]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [8]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [4]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [9]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [5]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [10]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [6]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [7]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [8]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [9]	validation_0-aft_likelihood:3.04855	validation_1-aft_likelihood:4.00300
# [0]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [1]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [2]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [3]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [4]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [5]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [6]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [7]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [8]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [9]	validation_0-aft_likelihood:3.34889	validation_1-aft_likelihood:3.02388
# [0]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [1]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [2]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [3]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [4]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [0]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [5]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [1]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [2]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572[6]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
#
# [7]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [3]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [8]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [9]	validation_0-aft_likelihood:3.29176	validation_1-aft_likelihood:3.07274
# [4]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [5]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [6]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [7]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [8]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [9]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [10]	validation_0-aft_likelihood:3.34147	validation_1-aft_likelihood:3.00572
# [0]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [1]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [2]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [3]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [0]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [4]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [1]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [5]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [2]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [6]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [7]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [3]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [8]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [4]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [9]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [10]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [5]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [6]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [7]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [8]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [9]	validation_0-aft_likelihood:3.22125	validation_1-aft_likelihood:3.22749
# [0]	validation_0-aft_likelihood:3.29712	validation_1-aft_likelihood:3.04788
# [1]	validation_0-aft_likelihood:3.29712	validation_1-aft_likelihood:3.04788
# [2]	validation_0-aft_likelihood:3.29712	validation_1-aft_likelihood:3.04788
# [3]	validation_0-aft_likelihood:3.29712	validation_1-aft_likelihood:3.04788
# [4]	validation_0-aft_likelihood:3.29712	validation_1-aft_likelihood:3.04788
# [5]	validation_0-aft_likelihood:3.29712	validation_1-aft_likelihood:3.04788
# [6]	validation_0-aft_likelihood:3.29712	validation_1-aft_likelihood:3.04788
# [7]	validation_0-aft_likelihood:3.29712	validation_1-aft_likelihood:3.04788
# [8]	validation_0-aft_likelihood:3.29712	validation_1-aft_likelihood:3.04788
# [9]	validation_0-aft_likelihood:3.29712	validation_1-aft_likelihood:3.04788
# Concordance Index 0.0
# Integrated Brier Score: 0.21317496009921233
# durations 59.0 5050.0
# Concordance Index 0.0
# Integrated Brier Score: 0.22386710205749907
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [1]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [2]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [3]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [4]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [5]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [6]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [7]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [0]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [8]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [9]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [1]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [2]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [3]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [4]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [5]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [6]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [7]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [8]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [9]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [10]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [0]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [1]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [2]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [3]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [0]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [1]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [4]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [2]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [3]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [5]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [4]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [5]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [6]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [6]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [7]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [7]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [8]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [8]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [9]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [9]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [10]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [0]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [1]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [2]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [3]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [4]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [5]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [0]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [6]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [1]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [0]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [7]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [1]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [2]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [8]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [2]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [3]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [3]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [9]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [4]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [5]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [6]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [4]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [7]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [5]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [8]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [6]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [9]	validation_0-aft_likelihood:3.25427	validation_1-aft_likelihood:3.31211
# [7]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [8]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [9]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [10]	validation_0-aft_likelihood:3.35973	validation_1-aft_likelihood:2.81764
# [0]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [1]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [2]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [3]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [4]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [5]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [6]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [7]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [8]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [9]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [0]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [10]	validation_0-aft_likelihood:3.25591	validation_1-aft_likelihood:3.00457
# [1]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [2]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [3]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [4]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [5]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [6]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [7]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [8]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [9]	validation_0-aft_likelihood:3.25198	validation_1-aft_likelihood:3.19817
# [0]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [1]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [2]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [3]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [4]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [5]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [6]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [7]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [8]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [9]	validation_0-aft_likelihood:3.19106	validation_1-aft_likelihood:3.62328
# [0]	validation_0-aft_likelihood:3.26643	validation_1-aft_likelihood:3.15679
# [1]	validation_0-aft_likelihood:3.26643	validation_1-aft_likelihood:3.15679
# [2]	validation_0-aft_likelihood:3.26643	validation_1-aft_likelihood:3.15679
# [3]	validation_0-aft_likelihood:3.26643	validation_1-aft_likelihood:3.15679
# [4]	validation_0-aft_likelihood:3.26643	validation_1-aft_likelihood:3.15679
# [5]	validation_0-aft_likelihood:3.26643	validation_1-aft_likelihood:3.15679
# [6]	validation_0-aft_likelihood:3.26643	validation_1-aft_likelihood:3.15679
# [7]	validation_0-aft_likelihood:3.26643	validation_1-aft_likelihood:3.15679
# [8]	validation_0-aft_likelihood:3.26643	validation_1-aft_likelihood:3.15679
# [9]	validation_0-aft_likelihood:3.26643	validation_1-aft_likelihood:3.15679
# Concordance Index 0.0
# Integrated Brier Score: 0.21568592278289148
# durations 55.0 5041.0
# Concordance Index 0.0
# Integrated Brier Score: 0.2238189653245612
# (325, 20531) <class 'pandas.core.frame.DataFrame'>
# (325,) <class 'pandas.core.series.Series'>
# (81, 20531) <class 'pandas.core.frame.DataFrame'>
# (81,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [0]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [1]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [2]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [1]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [3]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [2]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [4]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [3]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [5]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [4]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [6]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [5]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [7]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [6]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [8]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [7]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [0]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [9]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [8]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [1]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [9]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [2]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [3]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [4]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [5]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [6]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [7]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [0]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [8]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [1]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [9]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [2]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [10]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [3]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [0]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [4]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [5]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [0]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [6]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [1]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [7]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [2]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [1]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [3]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [2]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [4]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [3]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [5]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [8]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [6]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [9]	validation_0-aft_likelihood:3.10836	validation_1-aft_likelihood:3.60221
# [4]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [7]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [5]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [6]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [8]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [7]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [9]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [8]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [9]	validation_0-aft_likelihood:3.19708	validation_1-aft_likelihood:3.12624
# [0]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [1]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [2]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [3]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [4]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [5]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [6]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [7]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [8]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [0]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [9]	validation_0-aft_likelihood:3.22284	validation_1-aft_likelihood:2.99467
# [1]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [2]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [3]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [0]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [4]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [5]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [1]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [6]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [7]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [2]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [8]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [3]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [9]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [4]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [10]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [5]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [6]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [7]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [8]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [9]	validation_0-aft_likelihood:3.13129	validation_1-aft_likelihood:3.23317
# [0]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [1]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [2]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [3]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [4]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [5]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [6]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [7]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [8]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [9]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [10]	validation_0-aft_likelihood:3.05754	validation_1-aft_likelihood:3.77925
# [0]	validation_0-aft_likelihood:3.10425	validation_1-aft_likelihood:3.53347
# [1]	validation_0-aft_likelihood:3.10425	validation_1-aft_likelihood:3.53347
# [2]	validation_0-aft_likelihood:3.10425	validation_1-aft_likelihood:3.53347
# [3]	validation_0-aft_likelihood:3.10425	validation_1-aft_likelihood:3.53347
# [4]	validation_0-aft_likelihood:3.10425	validation_1-aft_likelihood:3.53347
# [5]	validation_0-aft_likelihood:3.10425	validation_1-aft_likelihood:3.53347
# [6]	validation_0-aft_likelihood:3.10425	validation_1-aft_likelihood:3.53347
# [7]	validation_0-aft_likelihood:3.10425	validation_1-aft_likelihood:3.53347
# [8]	validation_0-aft_likelihood:3.10425	validation_1-aft_likelihood:3.53347
# [9]	validation_0-aft_likelihood:3.10425	validation_1-aft_likelihood:3.53347
# Concordance Index 0.0
# Integrated Brier Score: 0.2222963717982715
# durations 13.0 3432.0
# Concordance Index 0.0
# Integrated Brier Score: 0.213407359650274
# (864, 20531) <class 'pandas.core.frame.DataFrame'>
# (864,) <class 'pandas.core.series.Series'>
# (217, 20531) <class 'pandas.core.frame.DataFrame'>
# (217,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [0]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [1]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [2]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [1]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [2]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [3]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [3]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [4]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [4]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [5]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [5]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [6]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [6]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [7]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [7]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [8]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [8]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [0]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [0]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [1]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [0]	validation_0-aft_likelihood:1.14319	validation_1-aft_likelihood:1.70189
# [1]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [2]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [2]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [1]	validation_0-aft_likelihood:1.14319	validation_1-aft_likelihood:1.70189
# [3]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [3]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [2]	validation_0-aft_likelihood:1.14319	validation_1-aft_likelihood:1.70189
# [4]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [4]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [3]	validation_0-aft_likelihood:1.14319	validation_1-aft_likelihood:1.70189
# [5]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [4]	validation_0-aft_likelihood:1.14319	validation_1-aft_likelihood:1.70189
# [5]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [5]	validation_0-aft_likelihood:1.14319	validation_1-aft_likelihood:1.70189
# [6]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [6]	validation_0-aft_likelihood:1.14319	validation_1-aft_likelihood:1.70189
# [6]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [7]	validation_0-aft_likelihood:1.14319	validation_1-aft_likelihood:1.70189
# [7]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [7]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [8]	validation_0-aft_likelihood:1.14319	validation_1-aft_likelihood:1.70189
# [8]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [8]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [9]	validation_0-aft_likelihood:1.14319	validation_1-aft_likelihood:1.70189
# [9]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [10]	validation_0-aft_likelihood:1.34994	validation_1-aft_likelihood:0.88526
# [0]	validation_0-aft_likelihood:1.28005	validation_1-aft_likelihood:1.18050
# [1]	validation_0-aft_likelihood:1.28005	validation_1-aft_likelihood:1.18050
# [2]	validation_0-aft_likelihood:1.28005	validation_1-aft_likelihood:1.18050
# [3]	validation_0-aft_likelihood:1.28005	validation_1-aft_likelihood:1.18050
# [4]	validation_0-aft_likelihood:1.28005	validation_1-aft_likelihood:1.18050
# [5]	validation_0-aft_likelihood:1.28005	validation_1-aft_likelihood:1.18050
# [6]	validation_0-aft_likelihood:1.28005	validation_1-aft_likelihood:1.18050
# [7]	validation_0-aft_likelihood:1.28005	validation_1-aft_likelihood:1.18050
# [8]	validation_0-aft_likelihood:1.28005	validation_1-aft_likelihood:1.18050
# [0]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [1]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [2]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [3]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [4]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [5]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [6]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [7]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [8]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [9]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [10]	validation_0-aft_likelihood:1.27679	validation_1-aft_likelihood:1.18023
# [0]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [1]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [2]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [3]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# [4]	validation_0-aft_likelihood:1.26326	validation_1-aft_likelihood:1.24335
# ...
# [3]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [2]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [3]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [0]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [4]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [4]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [5]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [1]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [5]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [2]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [6]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [6]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [7]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [7]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [3]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [8]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [8]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [4]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [9]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [5]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [10]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [6]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [7]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [8]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [9]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [10]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [9]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [10]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [0]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [1]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [2]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [3]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [4]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [5]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [6]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [7]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [8]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [9]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [0]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [1]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [2]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [3]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [4]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [5]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [6]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [7]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [8]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [9]	validation_0-aft_likelihood:2.64555	validation_1-aft_likelihood:3.10779
# [0]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [1]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [0]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [2]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [1]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [3]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [2]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [4]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [3]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [5]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [4]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [5]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [6]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [7]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [8]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [6]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [9]	validation_0-aft_likelihood:2.81798	validation_1-aft_likelihood:2.45914
# [7]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [8]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [9]	validation_0-aft_likelihood:2.74105	validation_1-aft_likelihood:2.79008
# [0]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [1]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [2]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [3]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [4]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [5]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [6]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [7]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [8]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [9]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [10]	validation_0-aft_likelihood:2.87506	validation_1-aft_likelihood:2.22083
# [0]	validation_0-aft_likelihood:2.84551	validation_1-aft_likelihood:2.39782
# [1]	validation_0-aft_likelihood:2.84551	validation_1-aft_likelihood:2.39782
# [2]	validation_0-aft_likelihood:2.84551	validation_1-aft_likelihood:2.39782
# [3]	validation_0-aft_likelihood:2.84551	validation_1-aft_likelihood:2.39782
# [4]	validation_0-aft_likelihood:2.84551	validation_1-aft_likelihood:2.39782
# [5]	validation_0-aft_likelihood:2.84551	validation_1-aft_likelihood:2.39782
# [6]	validation_0-aft_likelihood:2.84551	validation_1-aft_likelihood:2.39782
# [7]	validation_0-aft_likelihood:2.84551	validation_1-aft_likelihood:2.39782
# [8]	validation_0-aft_likelihood:2.84551	validation_1-aft_likelihood:2.39782
# [9]	validation_0-aft_likelihood:2.84551	validation_1-aft_likelihood:2.39782
# [0]	validation_0-aft_likelihood:2.64729	validation_1-aft_likelihood:3.15092
# [1]	validation_0-aft_likelihood:2.64729	validation_1-aft_likelihood:3.15092
# [2]	validation_0-aft_likelihood:2.64729	validation_1-aft_likelihood:3.15092
# [3]	validation_0-aft_likelihood:2.64729	validation_1-aft_likelihood:3.15092
# [4]	validation_0-aft_likelihood:2.64729	validation_1-aft_likelihood:3.15092
# [5]	validation_0-aft_likelihood:2.64729	validation_1-aft_likelihood:3.15092
# [6]	validation_0-aft_likelihood:2.64729	validation_1-aft_likelihood:3.15092
# [7]	validation_0-aft_likelihood:2.64729	validation_1-aft_likelihood:3.15092
# [8]	validation_0-aft_likelihood:2.64729	validation_1-aft_likelihood:3.15092
# [9]	validation_0-aft_likelihood:2.64729	validation_1-aft_likelihood:3.15092
# [10]	validation_0-aft_likelihood:2.64729	validation_1-aft_likelihood:3.15092
# Concordance Index 0.0
# Integrated Brier Score: 0.2012578598147577
# durations 3.0 4537.0
# Concordance Index 0.0
# Integrated Brier Score: 0.2136209627781217
# (425, 20531) <class 'pandas.core.frame.DataFrame'>
# (425,) <class 'pandas.core.series.Series'>
# (106, 20531) <class 'pandas.core.frame.DataFrame'>
# (106,) <class 'pandas.core.series.Series'>
# [0]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [1]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [2]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [3]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [4]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [5]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [6]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [7]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [8]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [9]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [10]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [0]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [1]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [2]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [3]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [4]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [5]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [6]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [7]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [8]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [9]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [0]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [1]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [2]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [3]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [4]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [5]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [6]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [7]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [0]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [8]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [1]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [9]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [2]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [10]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [3]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [4]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [5]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [6]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [0]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [7]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [1]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [8]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [2]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [9]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [10]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [3]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [4]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [5]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [6]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [7]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [8]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [9]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [10]	validation_0-aft_likelihood:2.78084	validation_1-aft_likelihood:2.47241
# [0]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [0]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [1]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [0]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [2]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [1]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [3]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [1]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [2]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [4]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [2]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [5]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [3]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [3]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [6]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [4]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [0]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [7]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [5]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [4]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [8]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [5]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [1]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [9]	validation_0-aft_likelihood:2.60272	validation_1-aft_likelihood:3.21965
# [6]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [2]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [6]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [3]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [7]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [7]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [4]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [8]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [8]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [0]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [5]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [9]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [9]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [1]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [6]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [7]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [10]	validation_0-aft_likelihood:2.79115	validation_1-aft_likelihood:2.46922
# [2]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [3]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [8]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [9]	validation_0-aft_likelihood:2.74233	validation_1-aft_likelihood:2.65818
# [4]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [5]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [6]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [7]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [8]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
# [9]	validation_0-aft_likelihood:2.68217	validation_1-aft_likelihood:2.90229
