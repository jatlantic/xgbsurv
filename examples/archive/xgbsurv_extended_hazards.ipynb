# %% [markdown]
# # Introduction to the xgbsurv package
#
# This notebook introduces `xgbsurv` using a specific dataset. It structured by the following steps:
#
# - Load data
# - Load model
# - Fit model
# - Predict and evaluate model
#
# The syntax conveniently follows that of sklearn.

# %%
from xgbsurv.datasets import load_metabric
from xgbsurv.models.eh_final import eh_likelihood #, eh_objective
from xgbsurv import XGBSurv
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load Data

# %%
data = load_metabric(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=False)
n = data.target.shape[0]
target2 = data.target.reshape(n,1)
target2 = np.tile(target2, (1,2)) #.shape
target2
# Out:
# array([[ 1.0000000e-01,  1.0000000e-01],
#        [-7.6666665e-01, -7.6666665e-01],
#        [-1.2333333e+00, -1.2333333e+00],
#        ...,
#        [-3.3703333e+02, -3.3703333e+02],
#        [ 3.5100000e+02,  3.5100000e+02],
#        [ 3.5520001e+02,  3.5520001e+02]], dtype=float32)

# %%
# test run likelihood
#eh_likelihood(data.target, target2)

# %% [markdown]
# ## Load Model

# %%
model = XGBSurv(n_estimators=2000, objective="eh_objective",
                                             eval_metric="eh_loss",
                                             learning_rate=0.01,
                                             random_state=7, disable_default_metric=True, base_score=0.3)
model.get_params()
# Out:
# {'eval_metric': CPUDispatcher(<function eh_likelihood at 0x7fceca8db130>),
#  'objective': CPUDispatcher(<function eh_objective at 0x7fceca8dbb50>),
#  'base_score': 0.3,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': 0.01,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 2000,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': 7,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None,
#  'disable_default_metric': True}

# %% [markdown]
# The options of loss and objective functions can be obtained like below:

# %%
print(model.get_loss_functions().keys())
print(model.get_objective_functions().keys())
# Out:
# dict_keys(['breslow_loss', 'efron_loss', 'cind_loss', 'deephit_loss', 'aft_loss', 'ah_loss', 'eh_loss'])
# dict_keys(['breslow_objective', 'efron_objective', 'cind_objective', 'deephit_objective', 'aft_objective', 'ah_objective', 'eh_objective'])

# %% [markdown]
# ## Fit Model

# %%
eval_set = [(data.data, target2)]

# %%
model.fit(data.data, target2, eval_set=eval_set)
# Out:
# [10:05:35] WARNING: /var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_b2k4a2hea3/croot/xgboost-split_1675457783214/work/src/learner.cc:767:
# Parameters: { "disable_default_metric" } are not used.
#
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140353835665406
# [0]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114034866679437
# [1]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140343497937337
# [2]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114033832909432
# [3]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114033316026527
# [4]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140327991450247
# [5]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114032282264922
# [6]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114031767574591
# [7]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114031252885647
# [8]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140307381980907
# [9]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114030223511925
# [10]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140297088271454
# [11]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114029194143753
# [12]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140286794617498
# [13]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140281647811343
# [14]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114027650101906
# [15]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114027135424068
# [16]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140266207476155
# [17]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114026106072553
# [18]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114025591398877
# [19]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11403
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114025076726591
# [20]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140245620556892
# [21]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11402404738618
# [22]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114023532718056
# [23]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114023018051321
# [24]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114022503385972
# [25]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114021988722013
# [26]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114021474059443
# [27]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140209593982586
# [28]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140204447384625
# [29]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140199300800564
# [30]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114019415423038
# [31]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140189007674057
# [32]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11401838611316
# [33]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140178714603075
# [34]	validation_0-rmse:146.53337	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140173568088385
# [35]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140168421587586
# [36]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140163275100687
# [37]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114015812862765
# [38]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11401529821685
# [39]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114014783572322
# [40]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11402
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140142689291843
# [41]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114013754287433
# [42]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114013239647069
# [43]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114012725008095
# [44]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140122103705066
# [45]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114011695734308
# [46]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114011181099497
# [47]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114010666466074
# [48]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140101518340386
# [49]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140096372033907
# [50]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114009122574132
# [51]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140086079462606
# [52]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140080933197782
# [53]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140075786946837
# [54]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140070640709774
# [55]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140065494486566
# [56]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140060348277268
# [57]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114005520208183
# [58]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140050055900272
# [59]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11401
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11400449097326
# [60]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114003976357882
# [61]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114003461743892
# [62]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140029471312887
# [63]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140024325200724
# [64]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114001917910248
# [65]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.114001403301809
# [66]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140008886947563
# [67]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1140003740890934
# [68]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113999859484818
# [69]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113999344881932
# [70]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113998830280434
# [71]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113998315680323
# [72]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139978010815987
# [73]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139972864842664
# [74]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139967718883206
# [75]	validation_0-rmse:146.53336	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139962572937603
# [76]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113995742700589
# [77]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113995228108807
# [78]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113994713518411
# [79]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11400
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139941989294053
# [80]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113993684341786
# [81]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139931697555565
# [82]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139926551707133
# [83]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139921405872597
# [84]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139916260051925
# [85]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113991111424513
# [86]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139905968452246
# [87]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113990082267322
# [88]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139895676908056
# [89]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113989053115682
# [90]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139885385419426
# [91]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139880239695907
# [92]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11398750939863
# [93]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113986994829055
# [94]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113986480260869
# [95]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11398596569407
# [96]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139854511286598
# [97]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113984936564637
# [98]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11399
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139844220020043
# [99]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139839074407574
# [100]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113983392880897
# [101]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139828783224295
# [102]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113982363765347
# [103]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113981849209653
# [104]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139813346553473
# [105]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113980820102429
# [106]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139803055508977
# [107]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139797910007565
# [108]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139792764520013
# [109]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139787619046375
# [110]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139782473586584
# [111]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139777328140688
# [112]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139772182708656
# [113]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139767037290533
# [114]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113976189188627
# [115]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113975674649589
# [116]	validation_0-rmse:146.53335	validation_0-eh_likelihood:3.11398
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139751601119388
# [117]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113974645575678
# [118]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139741310408047
# [119]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113973616507318
# [120]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139731019752195
# [121]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139725874445117
# [122]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139720729151885
# [123]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113971558387255
# [124]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113971043860711
# [125]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113970529335552
# [126]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113970014811783
# [127]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113969500289402
# [128]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139689857684067
# [129]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113968471248802
# [130]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139679567305856
# [131]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113967442213755
# [132]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113966927698314
# [133]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113966413184262
# [134]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139658986715957
# [135]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11397
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113965384160318
# [136]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113964869650429
# [137]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113964355141928
# [138]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113963840634815
# [139]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139633261290895
# [140]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139628116247535
# [141]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139622971218017
# [142]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113961782620243
# [143]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139612681200672
# [144]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113960753621284
# [145]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113960239123888
# [146]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113959724627879
# [147]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139592101332556
# [148]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139586956400245
# [149]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113958181148179
# [150]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113957666657723
# [151]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139571521686533
# [152]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113956637680973
# [153]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11395612319468
# [154]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139556087097757
# [155]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11396
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139550942262604
# [156]	validation_0-rmse:146.53334	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113954579744129
# [157]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113954065263389
# [158]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139535507840375
# [159]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113953036306074
# [160]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113952521829494
# [161]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113952007354307
# [162]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139514928805077
# [163]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113950978408096
# [164]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139504639370696
# [165]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113949949467435
# [166]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139494349991863
# [167]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139489205323247
# [168]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139484060668527
# [169]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139478916027685
# [170]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139473771400734
# [171]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139468626787647
# [172]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139463482188448
# [173]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139458337603134
# [174]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139453193031685
# [175]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113944804847414
# [176]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11395
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113944290393044
# [177]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139437759400637
# [178]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113943261488472
# [179]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139427470382692
# [180]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139422325894515
# [181]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139417181420237
# [182]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139412036959864
# [183]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139406892513333
# [184]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113940174808067
# [185]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113939660366194
# [186]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139391459257073
# [187]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139386314866067
# [188]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113938117048896
# [189]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139376026125722
# [190]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139370881776354
# [191]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139365737440885
# [192]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139360593119294
# [193]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113935544881158
# [194]	validation_0-rmse:146.53333	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113935030451775
# [195]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139345160237797
# [196]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11394
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113934001597172
# [197]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139334871719533
# [198]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113932972748122
# [199]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11393245832568
# [200]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139319439046247
# [201]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113931429484957
# [202]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139309150666796
# [203]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113930400649787
# [204]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113929886234285
# [205]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11392937182017
# [206]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139288574074424
# [207]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139283429961044
# [208]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139278285861534
# [209]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113927314177591
# [210]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113926799770416
# [211]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113926285364628
# [212]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139257709602304
# [213]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139252565572195
# [214]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139247421555982
# [215]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11393
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113924227755364
# [216]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139237133565154
# [217]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113923198959059
# [218]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139226845629886
# [219]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139221701683044
# [220]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139216557750116
# [221]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113921141383107
# [222]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139206269925856
# [223]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139201126034584
# [224]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139195982157153
# [225]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139190838293604
# [226]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139185694443947
# [227]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113918055060817
# [228]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139175406786266
# [229]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139170262978255
# [230]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139165119184122
# [231]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113915997540387
# [232]	validation_0-rmse:146.53332	validation_0-eh_likelihood:3.11392
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139154831637477
# [233]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139149687885004
# [234]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139144544146373
# [235]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139139400421634
# [236]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139134256710777
# [237]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11391291130138
# [238]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139123969330704
# [239]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113911882566149
# [240]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113911368200615
# [241]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11391085383647
# [242]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113910339473715
# [243]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113909825112345
# [244]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139093107523648
# [245]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139087963937695
# [246]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113908282036566
# [247]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113907767680749
# [248]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113907253326319
# [249]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113906738973278
# [250]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113906224621626
# [251]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139057102713608
# [252]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11391
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139051959224844
# [253]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139046815749962
# [254]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113904167228895
# [255]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139036528841832
# [256]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139031385408567
# [257]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139026241989196
# [258]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113902109858373
# [259]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113901595519213
# [260]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1139010811814396
# [261]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113900566845056
# [262]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11390005251006
# [263]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11389953817645
# [264]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113899023844231
# [265]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138985095133997
# [266]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113897995183955
# [267]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138974808558997
# [268]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11389696652923
# [269]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113896452203952
# [270]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138959378800597
# [271]	validation_0-rmse:146.53331	validation_0-eh_likelihood:3.11390
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138954235575564
# [272]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138949092364405
# [273]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113894394916712
# [274]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138938805983725
# [275]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138933662814208
# [276]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138928519658564
# [277]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138923376516816
# [278]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113891823338896
# [279]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113891309027496
# [280]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138907947174843
# [281]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11389028040886
# [282]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113889766101626
# [283]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113889251795778
# [284]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138887374913176
# [285]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138882231882485
# [286]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138877088865646
# [287]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138871945862703
# [288]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138866802873624
# [289]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113886165989845
# [290]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113885651693714
# [291]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11389
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113885137398972
# [292]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138846231056156
# [293]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11388410881365
# [294]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138835945230716
# [295]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113883080233881
# [296]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113882565946078
# [297]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138820516596635
# [298]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113881537374638
# [299]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138810230909995
# [300]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138805088087484
# [301]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138799945278857
# [302]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113879480248413
# [303]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138789659703274
# [304]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138784516936275
# [305]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113877937418319
# [306]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138774231443977
# [307]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113876908871862
# [308]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113876394600718
# [309]	validation_0-rmse:146.53330	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138758803309585
# [310]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138753660625915
# [311]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138748517956105
# [312]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11388
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138743375300133
# [313]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11387382326581
# [314]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138733090029924
# [315]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113872794741563
# [316]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138722804815204
# [317]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138717662228688
# [318]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113871251965602
# [319]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113870737709725
# [320]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113870223455237
# [321]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113869709202137
# [322]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138691949504236
# [323]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138686807000973
# [324]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113868166451161
# [325]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113867652203613
# [326]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138671379574534
# [327]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138666237126795
# [328]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113866109469293
# [329]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113865595227299
# [330]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138650809866895
# [331]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11386456674747
# [332]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11387
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113864052509637
# [333]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138635382731934
# [334]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113863024038139
# [335]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11386250980447
# [336]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138619955721882
# [337]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138614813412984
# [338]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138609671117927
# [339]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113860452883678
# [340]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138599386569497
# [341]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113859424431609
# [342]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113858910207658
# [343]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113858395985094
# [344]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113857881763919
# [345]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138573675441314
# [346]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138568533257325
# [347]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113856339108721
# [348]	validation_0-rmse:146.53329	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138558248930974
# [349]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138553106788613
# [350]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138547964660157
# [351]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11386
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113854282254557
# [352]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113853768044485
# [353]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113853253835803
# [354]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138527396285074
# [355]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113852225422601
# [356]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113851711424805
# [357]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138511974283967
# [358]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113850683433375
# [359]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113850169439742
# [360]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113849655447494
# [361]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138491414566354
# [362]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138486274671626
# [363]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113848113479078
# [364]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138475994923804
# [365]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138470855070692
# [366]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113846571523147
# [367]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138460575406124
# [368]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138455435594623
# [369]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11385
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138450295797018
# [370]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11384
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113844515601327
# [371]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11384
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113844001624339
# [372]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11384
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138434876487415
# [373]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11384
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138429736745272
# [374]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11384
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1138424597017025
# [375]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11384
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113841945730265
# [376]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11384
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113841431760214
# [377]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11384
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11384091779155
# [378]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11384
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113840403824275
# [379]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11384
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113839889858387
# [380]	validation_0-rmse:146.53328	validation_0-eh_likelihood:3.11384
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113839375893885
# ...
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130723946797985
# [1880]	validation_0-rmse:146.53290	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130718850182104
# [1881]	validation_0-rmse:146.53290	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113071375357993
# [1882]	validation_0-rmse:146.53290	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130708656991475
# [1883]	validation_0-rmse:146.53290	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130703560416744
# [1884]	validation_0-rmse:146.53290	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113069846385572
# [1885]	validation_0-rmse:146.53290	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130693367308444
# [1886]	validation_0-rmse:146.53290	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130688270774876
# [1887]	validation_0-rmse:146.53290	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130683174255025
# [1888]	validation_0-rmse:146.53290	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113067807774889
# [1889]	validation_0-rmse:146.53290	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113067298125648
# [1890]	validation_0-rmse:146.53290	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130667884777794
# [1891]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130662788312824
# [1892]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130657691861563
# [1893]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113065259542404
# [1894]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130647499000212
# [1895]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11307
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130642402590123
# [1896]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113063730619374
# [1897]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130632209811093
# [1898]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113062711344219
# [1899]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130622017086944
# [1900]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130616920745453
# [1901]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113061182441769
# [1902]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130606728103634
# [1903]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113060163180328
# [1904]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113059653551668
# [1905]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113059143924378
# [1906]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130586342984627
# [1907]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113058124673916
# [1908]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130576150507423
# [1909]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130571054289415
# [1910]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130565958085126
# [1911]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113056086189456
# [1912]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113055576571768
# [1913]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113055066955453
# [1914]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113054557340514
# [1915]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11306
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130540477269437
# [1916]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113053538114747
# [1917]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130530285039213
# [1918]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113052518894466
# [1919]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130520092863856
# [1920]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113051499679677
# [1921]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113050990074339
# [1922]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130504804703727
# [1923]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11304997086778
# [1924]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113049461266559
# [1925]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130489516667073
# [1926]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130484420682305
# [1927]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130479324711255
# [1928]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130474228753915
# [1929]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130469132810297
# [1930]	validation_0-rmse:146.53289	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130464036880374
# [1931]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113045894096424
# [1932]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130453845061776
# [1933]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130448749173025
# [1934]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11305
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113044365329802
# [1935]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130438557436726
# [1936]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113043346158913
# [1937]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130428365755303
# [1938]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130423269935155
# [1939]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130418174128724
# [1940]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130413078336048
# [1941]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113040798255706
# [1942]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11304028867918
# [1943]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130397791040267
# [1944]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113039269530243
# [1945]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130387599578353
# [1946]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130382503867984
# [1947]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113037740817132
# [1948]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130372312488377
# [1949]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130367216819166
# [1950]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130362121163664
# [1951]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113035702552188
# [1952]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11304
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130351929893822
# [1953]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113034683427949
# [1954]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113034173867888
# [1955]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113033664309198
# [1956]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11303315475188
# [1957]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113032645195934
# [1958]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11303213564136
# [1959]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130316260881594
# [1960]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113031116536328
# [1961]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130306069858715
# [1962]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113030097436786
# [1963]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130295878890726
# [1964]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113029078342729
# [1965]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130285687977612
# [1966]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130280592541624
# [1967]	validation_0-rmse:146.53288	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130275497119375
# [1968]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130270401710836
# [1969]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113026530631602
# [1970]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130260210934915
# [1971]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113025511556754
# [1972]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11303
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130250020213883
# [1973]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130244924873938
# [1974]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113023982954772
# [1975]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130234734235236
# [1976]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130229638936453
# [1977]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113022454365141
# [1978]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113021944838007
# [1979]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130214353122443
# [1980]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113020925787854
# [1981]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113020416264837
# [1982]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113019906743191
# [1983]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113019397222917
# [1984]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113018887704016
# [1985]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113018378186484
# [1986]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113017868670328
# [1987]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130173591555423
# [1988]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113016849642128
# [1989]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.113016340130087
# [1990]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130158306194176
# [1991]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11302
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130153211101192
# [1992]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11301
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130148116021945
# [1993]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11301
# y shape (3806,)
# (1903, 2)
# -likelihood 3.11301430209564
# [1994]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11301
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130137925904586
# [1995]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11301
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130132830866493
# [1996]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11301
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130127735842117
# [1997]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11301
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130122640831464
# [1998]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11301
# y shape (3806,)
# (1903, 2)
# -likelihood 3.1130117545834515
# [1999]	validation_0-rmse:146.53287	validation_0-eh_likelihood:3.11301
# XGBSurv(base_score=0.3, booster=None, callbacks=None, colsample_bylevel=None,
#         colsample_bynode=None, colsample_bytree=None,
#         disable_default_metric=True, early_stopping_rounds=None,
#         enable_categorical=False,
#         eval_metric=CPUDispatcher(<function eh_likelihood at 0x7fceca8db130>),
#         feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#         importance_type=None, interaction_constraints=None, learning_rate=0.01,
#         max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#         max_delta_step=None, max_depth=None, max_leaves=None,
#         min_child_weight=None, missing=nan, monotone_constraints=None,
#         n_estimators=2000, n_jobs=None, num_parallel_tree=None,
#         objective=CPUDispatcher(<function eh_objective at 0x7fceca8dbb50>), ...)

# %% [markdown]
# The model can be saved like below. Note that objective and eval_metric are not saved.

# %%
model.save_model("eh_model.json")

# %% [markdown]
# ## Predict

# %%
preds = model.predict(np.nan_to_num(data.data), output_margin=True, validate_features=False)
preds
# Out:
# array([[0.2997616 , 0.30381492],
#        [0.3010133 , 0.2983907 ],
#        [0.2997616 , 0.30381492],
#        ...,
#        [0.2997616 , 0.2983907 ],
#        [0.2997616 , 0.2983907 ],
#        [0.2997616 , 0.2983907 ]], dtype=float32)

# %% [markdown]
# ### Predict Cumulative Hazard

# %%
df_cum_hazards = model.predict_cumulative_hazard_function(data, dataframe=True)
df_cum_hazards.head(5)
# Out:
# denominator 1.4150272607803345
# (1685,) (1685,)
#        time  patient_0  patient_1  patient_2  patient_3  patient_4  patient_5  \
# 0  0.100000   0.000589   0.000476   0.000552   0.000584   0.000437   0.000632
# 1  0.766667   0.001771   0.001431   0.001657   0.001753   0.001312   0.001897
# 2  1.233333   0.003545   0.002864   0.003316   0.003509   0.002626   0.003797
# 3  1.266667   0.005912   0.004776   0.005531   0.005852   0.004379   0.006333
# 4  1.433333   0.008874   0.007169   0.008302   0.008784   0.006573   0.009506
#
#    patient_6  patient_7  patient_8  ...  patient_1893  patient_1894  \
# 0   0.000476   0.000635   0.000481  ...      0.000476      0.000476
# 1   0.001431   0.001909   0.001445  ...      0.001431      0.001431
# 2   0.002864   0.003821   0.002892  ...      0.002864      0.002864
# 3   0.004776   0.006373   0.004824  ...      0.004776      0.004776
# 4   0.007169   0.009565   0.007240  ...      0.007169      0.007169
#
#    patient_1895  patient_1896  patient_1897  patient_1898  patient_1899  \
# 0      0.000491      0.000588      0.000468      0.000468      0.000493
# 1      0.001474      0.001767      0.001407      0.001407      0.001479
# 2      0.002951      0.003537      0.002816      0.002816      0.002962
# 3      0.004923      0.005900      0.004698      0.004698      0.004940
# 4      0.007389      0.008855      0.007051      0.007051      0.007414
#
#    patient_1900  patient_1901  patient_1902
# 0      0.000476      0.000476      0.000432
# 1      0.001431      0.001431      0.001298
# 2      0.002864      0.002864      0.002598
# 3      0.004776      0.004776      0.004334
# 4      0.007169      0.007169      0.006505
#
# [5 rows x 1904 columns]

# %%
df_cum_hazards.to_csv('test.csv')

# %%
np.savetxt("preds.csv", preds, delimiter=",")

# %%
len(np.unique(np.absolute(target)))
# Out:
# 1685

# %%
len(target)
# Out:
# 1903

# %% [markdown]
# ### Predict Survival Function

# %%
df_survival = model.predict_survival_function(data, dataframe=True)
df_survival
# Out:
#             time      patient_0      patient_1      patient_2      patient_3  \
# 0       0.100000   9.994107e-01   9.995238e-01   9.994486e-01   9.994167e-01
# 1       0.766667   9.982309e-01   9.985704e-01   9.983447e-01   9.982488e-01
# 2       1.233333   9.964618e-01   9.971403e-01   9.966892e-01   9.964975e-01
# 3       1.266667   9.941055e-01   9.952349e-01   9.944840e-01   9.941651e-01
# 4       1.433333   9.911657e-01   9.928563e-01   9.917321e-01   9.912548e-01
# ...          ...            ...            ...            ...            ...
# 1680  335.600000  4.656672e-217  1.646696e-175  3.954090e-203  7.237864e-215
# 1681  335.733340  4.656672e-217  1.646696e-175  3.954090e-203  7.237864e-215
# 1682  337.033330  4.656672e-217  1.646696e-175  3.954090e-203  7.237864e-215
# 1683  351.000000  4.656672e-217  1.646696e-175  3.954090e-203  7.237864e-215
# 1684  355.200000  4.656672e-217  1.646696e-175  3.954090e-203  7.237864e-215
#
#           patient_4      patient_5      patient_6      patient_7  \
# 0      9.995634e-01   9.993687e-01   9.995238e-01   9.993648e-01
# 1      9.986892e-01   9.981049e-01   9.985704e-01   9.980931e-01
# 2      9.973777e-01   9.962100e-01   9.971403e-01   9.961864e-01
# 3      9.956301e-01   9.936866e-01   9.952349e-01   9.936474e-01
# 4      9.934482e-01   9.905388e-01   9.928563e-01   9.904802e-01
# ...             ...            ...            ...            ...
# 1680  5.566516e-161  1.755569e-232  1.646696e-175  6.337285e-234
# 1681  5.566516e-161  1.755569e-232  1.646696e-175  6.337285e-234
# 1682  5.566516e-161  1.755569e-232  1.646696e-175  6.337285e-234
# 1683  5.566516e-161  1.755569e-232  1.646696e-175  6.337285e-234
# 1684  5.566516e-161  1.755569e-232  1.646696e-175  6.337285e-234
#
#           patient_8  ...   patient_1893   patient_1894   patient_1895  \
# 0      9.995191e-01  ...   9.995238e-01   9.995238e-01   9.995093e-01
# 1      9.985563e-01  ...   9.985704e-01   9.985704e-01   9.985267e-01
# 2      9.971122e-01  ...   9.971403e-01   9.971403e-01   9.970530e-01
# 3      9.951880e-01  ...   9.952349e-01   9.952349e-01   9.950896e-01
# 4      9.927861e-01  ...   9.928563e-01   9.928563e-01   9.926387e-01
# ...             ...  ...            ...            ...            ...
# 1680  3.116488e-177  ...  1.646696e-175  1.646696e-175  7.458802e-181
# 1681  3.116488e-177  ...  1.646696e-175  1.646696e-175  7.458802e-181
# 1682  3.116488e-177  ...  1.646696e-175  1.646696e-175  7.458802e-181
# 1683  3.116488e-177  ...  1.646696e-175  1.646696e-175  7.458802e-181
# 1684  3.116488e-177  ...  1.646696e-175  1.646696e-175  7.458802e-181
#
#        patient_1896   patient_1897   patient_1898   patient_1899  \
# 0      9.994119e-01   9.995317e-01   9.995317e-01   9.995076e-01
# 1      9.982345e-01   9.985940e-01   9.985940e-01   9.985216e-01
# 2      9.964690e-01   9.971875e-01   9.971875e-01   9.970428e-01
# 3      9.941176e-01   9.953134e-01   9.953134e-01   9.950726e-01
# 4      9.911838e-01   9.929738e-01   9.929738e-01   9.926133e-01
# ...             ...            ...            ...            ...
# 1680  1.300179e-216  1.265915e-172  1.265915e-172  1.774117e-181
# 1681  1.300179e-216  1.265915e-172  1.265915e-172  1.774117e-181
# 1682  1.300179e-216  1.265915e-172  1.265915e-172  1.774117e-181
# 1683  1.300179e-216  1.265915e-172  1.265915e-172  1.774117e-181
# 1684  1.300179e-216  1.265915e-172  1.265915e-172  1.774117e-181
#
#        patient_1900   patient_1901   patient_1902
# 0      9.995238e-01   9.995238e-01   9.995680e-01
# 1      9.985704e-01   9.985704e-01   9.987028e-01
# 2      9.971403e-01   9.971403e-01   9.974050e-01
# 3      9.952349e-01   9.952349e-01   9.956755e-01
# 4      9.928563e-01   9.928563e-01   9.935161e-01
# ...             ...            ...            ...
# 1680  1.646696e-175  1.646696e-175  2.578949e-159
# 1681  1.646696e-175  1.646696e-175  2.578949e-159
# 1682  1.646696e-175  1.646696e-175  2.578949e-159
# 1683  1.646696e-175  1.646696e-175  2.578949e-159
# 1684  1.646696e-175  1.646696e-175  2.578949e-159
#
# [1685 rows x 1904 columns]

# %% [markdown]
# ### Visualize Predictions

# %%
import sys
# !conda install --yes --prefix {sys.prefix} -c plotly plotly_express
# !conda install --yes --prefix {sys.prefix} -c ipykernel
import plotly_express as px
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/JUSC/miniconda3/envs/xgbsurv
#
#   added / updated specs:
#     - plotly_express
#
#
# The following NEW packages will be INSTALLED:
#
#   patsy              pkgs/main/osx-64::patsy-0.5.3-py310hecd8cb5_0
#   plotly             plotly/noarch::plotly-5.13.1-py_0
#   plotly_express     plotly/noarch::plotly_express-0.4.1-py_0
#   statsmodels        pkgs/main/osx-64::statsmodels-0.13.5-py310h7b7cdfe_1
#   tenacity           pkgs/main/osx-64::tenacity-8.0.1-py310hecd8cb5_1
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# CondaValueError: too few arguments, must supply command line package specs or --file

# %%
# cumhazard
px.line(df_cum_hazards, x= 'time',y = df_cum_hazards.columns[1:4],range_y=[0,1], title='Cumulative Hazard over Time')

# %%
# survival function
px.line(df_survival, x= 'time',y = df_cum_hazards.columns[1:4],range_y=[0,1], title='Survival Function over Time')

# %%
# !conda remove --yes --prefix {sys.prefix} -c plotly plotly_express
# !conda remove --yes --prefix {sys.prefix} -c nbformat
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/JUSC/miniconda3/envs/xgbsurv
#
#   removed specs:
#     - plotly_express
#
#
# The following packages will be REMOVED:
#
#   patsy-0.5.3-py310hecd8cb5_0
#   plotly-5.13.1-py_0
#   plotly_express-0.4.1-py_0
#   statsmodels-0.13.5-py310h7b7cdfe_1
#   tenacity-8.0.1-py310hecd8cb5_1
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# CondaValueError: no package names supplied,
#        try "conda remove -h" for more details

# %% [markdown]
# ## Evaluate

# %%
#from sksurv.metrics import concordance_index_censored
from xgbsurv.evaluation import cindex_censored, ibs

# %%
cindex_censored(data.target, preds[:,1])
# Out:
# 0.659739525116822

# %%
np.savetxt('preds_eh.csv', preds)
