# %% [markdown]
# # Introduction to the xgbsurv package
#
# This notebook introduces `xgbsurv` using a specific dataset. It structured by the following steps:
#
# - Load data
# - Load model
# - Fit model
# - Predict and evaluate model
#
# The syntax conveniently follows that of sklearn.

# %%
from xgbsurv.datasets import load_metabric
from xgbsurv.preprocessing.dataset_preprocessing import discretizer_df
from xgbsurv.models.utils import sort_X_y, transform_back, transform
from xgbsurv import XGBSurv
from sklearn.model_selection import train_test_split
import numpy as np
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load Data

# %%
data, target = load_metabric(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=True)
# add discretizer

time, event = transform_back(target.to_numpy())
data['time'] = time
data['event'] = event
df = discretizer_df(data, n_cuts=100, type = 'equidistant', min_time=0.0)
df.head()
# Out:
#        MKI67      EGFR        PGR     ERBB2  hormone_treatment  radiotherapy  \
# 0   5.818934  6.470783  10.672935  5.630679                0.0           0.0
# 1  10.117913  5.335095   9.717084  5.893656                0.0           0.0
# 2   5.705204  8.450347  10.859011  5.667925                0.0           0.0
# 3   5.184060  8.427523  10.361415  5.575082                1.0           0.0
# 4   5.621474  5.456216   9.500981  5.753597                1.0           0.0
#
#    chemotherapy  ER_positive    age  time  event
# 0           0.0          1.0  75.33     1      1
# 1           0.0          0.0  54.10     1      0
# 2           0.0          1.0  73.64     1      0
# 3           0.0          1.0  73.98     1      0
# 4           0.0          1.0  34.68     1      0

# %%
target = transform(df.time.to_numpy(), df.event.to_numpy())
print(target)
data = df.iloc[:,:-2].to_numpy()
#target = target[:10]
#data = data[:10,:]
target_sign = np.sign(target)
X_train, X_test, y_train, y_test = train_test_split(data, target, stratify=target_sign)
X_train, y_train = sort_X_y(X_train, y_train)
X_test, y_test = sort_X_y(X_test, y_test)
n = len(np.unique(np.absolute(y_train)))
print(n)
y_train= np.tile(y_train, (n,1)).T
y_train.shape
# Out:
# [  1  -1  -1 ... -94  98 100]
# 90
# (1427, 90)

# %%
y_test.shape
# Out:
# (476,)

# %%
event
# Out:
# array([1, 0, 0, ..., 0, 1, 1])

# %% [markdown]
# ## Load Model

# %%
model = XGBSurv(n_estimators=2000, objective="deephit_objective",
                                             eval_metric="deephit_loss",
                                             learning_rate=0.10,
                                             random_state=7, disable_default_metric=True, base_score=0.3)
#model.get_params()

# %% [markdown]
# The options of loss and objective functions can be obtained like below:

# %%
print(model.get_loss_functions().keys())
print(model.get_objective_functions().keys())
# Out:
# dict_keys(['breslow_loss', 'efron_loss', 'cind_loss', 'deephit_loss', 'aft_loss'])
# dict_keys(['breslow_objective', 'efron_objective', 'cind_objective', 'deephit_objective', 'aft_objective'])

# %% [markdown]
# ## Fit Model

# %%
eval_set = [(X_train, y_train)]

# %%
model.fit(X_train, y_train, eval_set=eval_set)
# Out:
# [18:36:26] WARNING: /var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_b2k4a2hea3/croot/xgboost-split_1675457783214/work/src/learner.cc:767:
# Parameters: { "disable_default_metric" } are not used.
#
# [0]	validation_0-rmse:40.94116	validation_0-deephit_loss1_pycox:4072.31716
# [1]	validation_0-rmse:40.93432	validation_0-deephit_loss1_pycox:3949.27767
# [2]	validation_0-rmse:40.92861	validation_0-deephit_loss1_pycox:3833.94574
# [3]	validation_0-rmse:40.92256	validation_0-deephit_loss1_pycox:3726.46669
# [4]	validation_0-rmse:40.91604	validation_0-deephit_loss1_pycox:3629.81873
# [5]	validation_0-rmse:40.90998	validation_0-deephit_loss1_pycox:3536.02988
# [6]	validation_0-rmse:40.90417	validation_0-deephit_loss1_pycox:3441.79081
# [7]	validation_0-rmse:40.89821	validation_0-deephit_loss1_pycox:3354.60703
# [8]	validation_0-rmse:40.89282	validation_0-deephit_loss1_pycox:3270.57953
# [9]	validation_0-rmse:40.88763	validation_0-deephit_loss1_pycox:3187.60195
# [10]	validation_0-rmse:40.88300	validation_0-deephit_loss1_pycox:3111.06013
# [11]	validation_0-rmse:40.87798	validation_0-deephit_loss1_pycox:3035.26880
# [12]	validation_0-rmse:40.87275	validation_0-deephit_loss1_pycox:2961.50673
# [13]	validation_0-rmse:40.86778	validation_0-deephit_loss1_pycox:2891.78505
# [14]	validation_0-rmse:40.86281	validation_0-deephit_loss1_pycox:2823.19091
# [15]	validation_0-rmse:40.85750	validation_0-deephit_loss1_pycox:2757.44754
# [16]	validation_0-rmse:40.85270	validation_0-deephit_loss1_pycox:2696.47340
# [17]	validation_0-rmse:40.84775	validation_0-deephit_loss1_pycox:2631.64846
# [18]	validation_0-rmse:40.84341	validation_0-deephit_loss1_pycox:2571.49944
# [19]	validation_0-rmse:40.83863	validation_0-deephit_loss1_pycox:2512.45771
# [20]	validation_0-rmse:40.83450	validation_0-deephit_loss1_pycox:2454.11109
# [21]	validation_0-rmse:40.82987	validation_0-deephit_loss1_pycox:2398.25250
# [22]	validation_0-rmse:40.82562	validation_0-deephit_loss1_pycox:2344.21338
# [23]	validation_0-rmse:40.82146	validation_0-deephit_loss1_pycox:2292.18973
# [24]	validation_0-rmse:40.81660	validation_0-deephit_loss1_pycox:2241.35336
# [25]	validation_0-rmse:40.81194	validation_0-deephit_loss1_pycox:2190.81839
# [26]	validation_0-rmse:40.80781	validation_0-deephit_loss1_pycox:2142.97372
# [27]	validation_0-rmse:40.80327	validation_0-deephit_loss1_pycox:2094.24606
# [28]	validation_0-rmse:40.79914	validation_0-deephit_loss1_pycox:2049.89510
# [29]	validation_0-rmse:40.79512	validation_0-deephit_loss1_pycox:2007.45324
# [30]	validation_0-rmse:40.79111	validation_0-deephit_loss1_pycox:1964.56175
# [31]	validation_0-rmse:40.78734	validation_0-deephit_loss1_pycox:1923.30630
# [32]	validation_0-rmse:40.78396	validation_0-deephit_loss1_pycox:1884.00834
# [33]	validation_0-rmse:40.78003	validation_0-deephit_loss1_pycox:1844.13196
# [34]	validation_0-rmse:40.77615	validation_0-deephit_loss1_pycox:1806.03698
# [35]	validation_0-rmse:40.77286	validation_0-deephit_loss1_pycox:1769.91781
# [36]	validation_0-rmse:40.76889	validation_0-deephit_loss1_pycox:1734.24673
# [37]	validation_0-rmse:40.76512	validation_0-deephit_loss1_pycox:1699.38400
# [38]	validation_0-rmse:40.76172	validation_0-deephit_loss1_pycox:1666.48688
# [39]	validation_0-rmse:40.75777	validation_0-deephit_loss1_pycox:1633.92451
# [40]	validation_0-rmse:40.75483	validation_0-deephit_loss1_pycox:1603.59074
# [41]	validation_0-rmse:40.75131	validation_0-deephit_loss1_pycox:1572.76716
# [42]	validation_0-rmse:40.74819	validation_0-deephit_loss1_pycox:1545.95828
# [43]	validation_0-rmse:40.74493	validation_0-deephit_loss1_pycox:1516.79128
# [44]	validation_0-rmse:40.74186	validation_0-deephit_loss1_pycox:1489.95833
# [45]	validation_0-rmse:40.73834	validation_0-deephit_loss1_pycox:1461.43624
# [46]	validation_0-rmse:40.73472	validation_0-deephit_loss1_pycox:1435.60207
# [47]	validation_0-rmse:40.73178	validation_0-deephit_loss1_pycox:1409.16926
# [48]	validation_0-rmse:40.72854	validation_0-deephit_loss1_pycox:1383.79129
# [49]	validation_0-rmse:40.72536	validation_0-deephit_loss1_pycox:1358.78430
# [50]	validation_0-rmse:40.72222	validation_0-deephit_loss1_pycox:1334.31245
# [51]	validation_0-rmse:40.71930	validation_0-deephit_loss1_pycox:1310.04467
# [52]	validation_0-rmse:40.71642	validation_0-deephit_loss1_pycox:1286.66910
# [53]	validation_0-rmse:40.71355	validation_0-deephit_loss1_pycox:1265.26231
# [54]	validation_0-rmse:40.71054	validation_0-deephit_loss1_pycox:1243.31074
# [55]	validation_0-rmse:40.70743	validation_0-deephit_loss1_pycox:1222.30436
# [56]	validation_0-rmse:40.70470	validation_0-deephit_loss1_pycox:1201.93329
# [57]	validation_0-rmse:40.70200	validation_0-deephit_loss1_pycox:1182.94114
# [58]	validation_0-rmse:40.69957	validation_0-deephit_loss1_pycox:1163.25850
# [59]	validation_0-rmse:40.69728	validation_0-deephit_loss1_pycox:1144.85700
# [60]	validation_0-rmse:40.69450	validation_0-deephit_loss1_pycox:1127.39977
# [61]	validation_0-rmse:40.69165	validation_0-deephit_loss1_pycox:1109.12321
# [62]	validation_0-rmse:40.68905	validation_0-deephit_loss1_pycox:1093.02023
# [63]	validation_0-rmse:40.68672	validation_0-deephit_loss1_pycox:1077.62365
# [64]	validation_0-rmse:40.68419	validation_0-deephit_loss1_pycox:1061.97769
# [65]	validation_0-rmse:40.68181	validation_0-deephit_loss1_pycox:1046.27393
# [66]	validation_0-rmse:40.67957	validation_0-deephit_loss1_pycox:1030.91833
# [67]	validation_0-rmse:40.67723	validation_0-deephit_loss1_pycox:1015.88306
# [68]	validation_0-rmse:40.67515	validation_0-deephit_loss1_pycox:1001.36177
# [69]	validation_0-rmse:40.67270	validation_0-deephit_loss1_pycox:987.68760
# [70]	validation_0-rmse:40.67065	validation_0-deephit_loss1_pycox:973.32969
# [71]	validation_0-rmse:40.66872	validation_0-deephit_loss1_pycox:959.37958
# [72]	validation_0-rmse:40.66658	validation_0-deephit_loss1_pycox:946.62509
# [73]	validation_0-rmse:40.66443	validation_0-deephit_loss1_pycox:933.44030
# [74]	validation_0-rmse:40.66263	validation_0-deephit_loss1_pycox:920.34501
# [75]	validation_0-rmse:40.66059	validation_0-deephit_loss1_pycox:907.04553
# [76]	validation_0-rmse:40.65865	validation_0-deephit_loss1_pycox:895.30256
# [77]	validation_0-rmse:40.65688	validation_0-deephit_loss1_pycox:882.64736
# [78]	validation_0-rmse:40.65500	validation_0-deephit_loss1_pycox:870.96827
# [79]	validation_0-rmse:40.65343	validation_0-deephit_loss1_pycox:859.39181
# [80]	validation_0-rmse:40.65151	validation_0-deephit_loss1_pycox:848.58745
# [81]	validation_0-rmse:40.64978	validation_0-deephit_loss1_pycox:837.57183
# [82]	validation_0-rmse:40.64813	validation_0-deephit_loss1_pycox:826.73937
# [83]	validation_0-rmse:40.64659	validation_0-deephit_loss1_pycox:816.33105
# [84]	validation_0-rmse:40.64533	validation_0-deephit_loss1_pycox:805.98668
# [85]	validation_0-rmse:40.64418	validation_0-deephit_loss1_pycox:795.84219
# [86]	validation_0-rmse:40.64265	validation_0-deephit_loss1_pycox:786.04029
# [87]	validation_0-rmse:40.64135	validation_0-deephit_loss1_pycox:776.20287
# [88]	validation_0-rmse:40.64014	validation_0-deephit_loss1_pycox:766.85792
# [89]	validation_0-rmse:40.63917	validation_0-deephit_loss1_pycox:757.29664
# [90]	validation_0-rmse:40.63827	validation_0-deephit_loss1_pycox:747.62024
# [91]	validation_0-rmse:40.63725	validation_0-deephit_loss1_pycox:738.79262
# [92]	validation_0-rmse:40.63605	validation_0-deephit_loss1_pycox:730.59238
# [93]	validation_0-rmse:40.63485	validation_0-deephit_loss1_pycox:721.61695
# [94]	validation_0-rmse:40.63381	validation_0-deephit_loss1_pycox:713.09961
# [95]	validation_0-rmse:40.63311	validation_0-deephit_loss1_pycox:704.88298
# [96]	validation_0-rmse:40.63186	validation_0-deephit_loss1_pycox:697.16778
# [97]	validation_0-rmse:40.63106	validation_0-deephit_loss1_pycox:689.37802
# [98]	validation_0-rmse:40.62999	validation_0-deephit_loss1_pycox:681.87031
# [99]	validation_0-rmse:40.62937	validation_0-deephit_loss1_pycox:674.52510
# [100]	validation_0-rmse:40.62898	validation_0-deephit_loss1_pycox:667.32097
# [101]	validation_0-rmse:40.62826	validation_0-deephit_loss1_pycox:660.01397
# [102]	validation_0-rmse:40.62752	validation_0-deephit_loss1_pycox:653.03642
# [103]	validation_0-rmse:40.62703	validation_0-deephit_loss1_pycox:645.96543
# [104]	validation_0-rmse:40.62658	validation_0-deephit_loss1_pycox:639.44232
# [105]	validation_0-rmse:40.62636	validation_0-deephit_loss1_pycox:632.75569
# [106]	validation_0-rmse:40.62596	validation_0-deephit_loss1_pycox:625.98026
# [107]	validation_0-rmse:40.62570	validation_0-deephit_loss1_pycox:619.51023
# [108]	validation_0-rmse:40.62533	validation_0-deephit_loss1_pycox:613.56217
# [109]	validation_0-rmse:40.62531	validation_0-deephit_loss1_pycox:607.64482
# [110]	validation_0-rmse:40.62482	validation_0-deephit_loss1_pycox:601.81916
# [111]	validation_0-rmse:40.62479	validation_0-deephit_loss1_pycox:595.89208
# [112]	validation_0-rmse:40.62436	validation_0-deephit_loss1_pycox:590.02261
# [113]	validation_0-rmse:40.62428	validation_0-deephit_loss1_pycox:584.57759
# [114]	validation_0-rmse:40.62388	validation_0-deephit_loss1_pycox:579.15077
# [115]	validation_0-rmse:40.62391	validation_0-deephit_loss1_pycox:573.92659
# [116]	validation_0-rmse:40.62408	validation_0-deephit_loss1_pycox:568.29521
# [117]	validation_0-rmse:40.62380	validation_0-deephit_loss1_pycox:563.11065
# [118]	validation_0-rmse:40.62364	validation_0-deephit_loss1_pycox:557.94555
# [119]	validation_0-rmse:40.62371	validation_0-deephit_loss1_pycox:553.18423
# [120]	validation_0-rmse:40.62392	validation_0-deephit_loss1_pycox:548.07159
# [121]	validation_0-rmse:40.62410	validation_0-deephit_loss1_pycox:543.31867
# [122]	validation_0-rmse:40.62386	validation_0-deephit_loss1_pycox:538.16925
# [123]	validation_0-rmse:40.62380	validation_0-deephit_loss1_pycox:533.30569
# [124]	validation_0-rmse:40.62391	validation_0-deephit_loss1_pycox:528.50430
# [125]	validation_0-rmse:40.62407	validation_0-deephit_loss1_pycox:524.04416
# [126]	validation_0-rmse:40.62438	validation_0-deephit_loss1_pycox:519.65731
# [127]	validation_0-rmse:40.62441	validation_0-deephit_loss1_pycox:515.38390
# [128]	validation_0-rmse:40.62461	validation_0-deephit_loss1_pycox:510.98155
# [129]	validation_0-rmse:40.62486	validation_0-deephit_loss1_pycox:506.66302
# [130]	validation_0-rmse:40.62509	validation_0-deephit_loss1_pycox:502.27218
# [131]	validation_0-rmse:40.62524	validation_0-deephit_loss1_pycox:498.26945
# [132]	validation_0-rmse:40.62558	validation_0-deephit_loss1_pycox:494.36716
# [133]	validation_0-rmse:40.62608	validation_0-deephit_loss1_pycox:490.56857
# [134]	validation_0-rmse:40.62638	validation_0-deephit_loss1_pycox:486.78284
# [135]	validation_0-rmse:40.62691	validation_0-deephit_loss1_pycox:482.84475
# [136]	validation_0-rmse:40.62713	validation_0-deephit_loss1_pycox:479.13997
# [137]	validation_0-rmse:40.62738	validation_0-deephit_loss1_pycox:475.56636
# [138]	validation_0-rmse:40.62787	validation_0-deephit_loss1_pycox:472.06979
# [139]	validation_0-rmse:40.62825	validation_0-deephit_loss1_pycox:468.67430
# [140]	validation_0-rmse:40.62876	validation_0-deephit_loss1_pycox:465.39088
# [141]	validation_0-rmse:40.62919	validation_0-deephit_loss1_pycox:461.92182
# [142]	validation_0-rmse:40.62949	validation_0-deephit_loss1_pycox:458.76985
# [143]	validation_0-rmse:40.63029	validation_0-deephit_loss1_pycox:455.74189
# [144]	validation_0-rmse:40.63073	validation_0-deephit_loss1_pycox:452.52835
# [145]	validation_0-rmse:40.63118	validation_0-deephit_loss1_pycox:449.60720
# [146]	validation_0-rmse:40.63154	validation_0-deephit_loss1_pycox:446.70697
# [147]	validation_0-rmse:40.63215	validation_0-deephit_loss1_pycox:443.92154
# [148]	validation_0-rmse:40.63268	validation_0-deephit_loss1_pycox:441.07291
# [149]	validation_0-rmse:40.63298	validation_0-deephit_loss1_pycox:438.45932
# [150]	validation_0-rmse:40.63350	validation_0-deephit_loss1_pycox:435.79591
# [151]	validation_0-rmse:40.63418	validation_0-deephit_loss1_pycox:433.27433
# [152]	validation_0-rmse:40.63449	validation_0-deephit_loss1_pycox:430.73060
# [153]	validation_0-rmse:40.63519	validation_0-deephit_loss1_pycox:428.16407
# [154]	validation_0-rmse:40.63537	validation_0-deephit_loss1_pycox:425.58226
# [155]	validation_0-rmse:40.63575	validation_0-deephit_loss1_pycox:423.20866
# [156]	validation_0-rmse:40.63636	validation_0-deephit_loss1_pycox:420.86582
# [157]	validation_0-rmse:40.63706	validation_0-deephit_loss1_pycox:418.68992
# [158]	validation_0-rmse:40.63751	validation_0-deephit_loss1_pycox:416.38414
# [159]	validation_0-rmse:40.63788	validation_0-deephit_loss1_pycox:414.24980
# [160]	validation_0-rmse:40.63850	validation_0-deephit_loss1_pycox:412.05513
# [161]	validation_0-rmse:40.63922	validation_0-deephit_loss1_pycox:409.94854
# [162]	validation_0-rmse:40.63974	validation_0-deephit_loss1_pycox:407.88507
# [163]	validation_0-rmse:40.64041	validation_0-deephit_loss1_pycox:405.90265
# [164]	validation_0-rmse:40.64092	validation_0-deephit_loss1_pycox:403.89766
# [165]	validation_0-rmse:40.64150	validation_0-deephit_loss1_pycox:401.90755
# [166]	validation_0-rmse:40.64210	validation_0-deephit_loss1_pycox:400.01145
# [167]	validation_0-rmse:40.64277	validation_0-deephit_loss1_pycox:398.07224
# [168]	validation_0-rmse:40.64342	validation_0-deephit_loss1_pycox:396.26248
# [169]	validation_0-rmse:40.64413	validation_0-deephit_loss1_pycox:394.48103
# [170]	validation_0-rmse:40.64474	validation_0-deephit_loss1_pycox:392.63715
# [171]	validation_0-rmse:40.64530	validation_0-deephit_loss1_pycox:390.89299
# [172]	validation_0-rmse:40.64594	validation_0-deephit_loss1_pycox:389.28158
# [173]	validation_0-rmse:40.64650	validation_0-deephit_loss1_pycox:387.61363
# [174]	validation_0-rmse:40.64721	validation_0-deephit_loss1_pycox:386.07077
# [175]	validation_0-rmse:40.64779	validation_0-deephit_loss1_pycox:384.47301
# [176]	validation_0-rmse:40.64834	validation_0-deephit_loss1_pycox:382.94006
# [177]	validation_0-rmse:40.64905	validation_0-deephit_loss1_pycox:381.50748
# [178]	validation_0-rmse:40.64988	validation_0-deephit_loss1_pycox:380.01338
# [179]	validation_0-rmse:40.65043	validation_0-deephit_loss1_pycox:378.48243
# [180]	validation_0-rmse:40.65101	validation_0-deephit_loss1_pycox:377.06928
# [181]	validation_0-rmse:40.65143	validation_0-deephit_loss1_pycox:375.60782
# [182]	validation_0-rmse:40.65214	validation_0-deephit_loss1_pycox:374.25026
# [183]	validation_0-rmse:40.65284	validation_0-deephit_loss1_pycox:372.81437
# [184]	validation_0-rmse:40.65345	validation_0-deephit_loss1_pycox:371.54399
# [185]	validation_0-rmse:40.65404	validation_0-deephit_loss1_pycox:370.26735
# [186]	validation_0-rmse:40.65474	validation_0-deephit_loss1_pycox:368.98476
# [187]	validation_0-rmse:40.65534	validation_0-deephit_loss1_pycox:367.67779
# [188]	validation_0-rmse:40.65574	validation_0-deephit_loss1_pycox:366.43493
# [189]	validation_0-rmse:40.65639	validation_0-deephit_loss1_pycox:365.23914
# [190]	validation_0-rmse:40.65694	validation_0-deephit_loss1_pycox:364.08029
# [191]	validation_0-rmse:40.65768	validation_0-deephit_loss1_pycox:362.96715
# [192]	validation_0-rmse:40.65826	validation_0-deephit_loss1_pycox:361.81353
# [193]	validation_0-rmse:40.65887	validation_0-deephit_loss1_pycox:360.64531
# [194]	validation_0-rmse:40.65940	validation_0-deephit_loss1_pycox:359.52432
# [195]	validation_0-rmse:40.66004	validation_0-deephit_loss1_pycox:358.40192
# [196]	validation_0-rmse:40.66056	validation_0-deephit_loss1_pycox:357.31588
# [197]	validation_0-rmse:40.66093	validation_0-deephit_loss1_pycox:356.24982
# [198]	validation_0-rmse:40.66171	validation_0-deephit_loss1_pycox:355.17768
# [199]	validation_0-rmse:40.66225	validation_0-deephit_loss1_pycox:354.13363
# [200]	validation_0-rmse:40.66281	validation_0-deephit_loss1_pycox:353.08673
# [201]	validation_0-rmse:40.66326	validation_0-deephit_loss1_pycox:351.94425
# [202]	validation_0-rmse:40.66393	validation_0-deephit_loss1_pycox:350.92842
# [203]	validation_0-rmse:40.66449	validation_0-deephit_loss1_pycox:349.94867
# [204]	validation_0-rmse:40.66504	validation_0-deephit_loss1_pycox:348.95845
# [205]	validation_0-rmse:40.66567	validation_0-deephit_loss1_pycox:347.95368
# [206]	validation_0-rmse:40.66626	validation_0-deephit_loss1_pycox:347.04250
# [207]	validation_0-rmse:40.66678	validation_0-deephit_loss1_pycox:346.12099
# [208]	validation_0-rmse:40.66731	validation_0-deephit_loss1_pycox:345.17339
# [209]	validation_0-rmse:40.66794	validation_0-deephit_loss1_pycox:344.26130
# [210]	validation_0-rmse:40.66845	validation_0-deephit_loss1_pycox:343.36004
# [211]	validation_0-rmse:40.66878	validation_0-deephit_loss1_pycox:342.44669
# [212]	validation_0-rmse:40.66936	validation_0-deephit_loss1_pycox:341.58605
# [213]	validation_0-rmse:40.66988	validation_0-deephit_loss1_pycox:340.76931
# [214]	validation_0-rmse:40.67036	validation_0-deephit_loss1_pycox:339.92679
# [215]	validation_0-rmse:40.67084	validation_0-deephit_loss1_pycox:339.04672
# [216]	validation_0-rmse:40.67154	validation_0-deephit_loss1_pycox:338.20985
# [217]	validation_0-rmse:40.67205	validation_0-deephit_loss1_pycox:337.41432
# [218]	validation_0-rmse:40.67269	validation_0-deephit_loss1_pycox:336.59202
# [219]	validation_0-rmse:40.67309	validation_0-deephit_loss1_pycox:335.80718
# [220]	validation_0-rmse:40.67367	validation_0-deephit_loss1_pycox:334.94097
# [221]	validation_0-rmse:40.67431	validation_0-deephit_loss1_pycox:334.17331
# [222]	validation_0-rmse:40.67494	validation_0-deephit_loss1_pycox:333.41630
# [223]	validation_0-rmse:40.67545	validation_0-deephit_loss1_pycox:332.69423
# [224]	validation_0-rmse:40.67606	validation_0-deephit_loss1_pycox:331.91410
# [225]	validation_0-rmse:40.67658	validation_0-deephit_loss1_pycox:331.21380
# [226]	validation_0-rmse:40.67699	validation_0-deephit_loss1_pycox:330.43613
# [227]	validation_0-rmse:40.67752	validation_0-deephit_loss1_pycox:329.71447
# [228]	validation_0-rmse:40.67798	validation_0-deephit_loss1_pycox:329.06648
# [229]	validation_0-rmse:40.67844	validation_0-deephit_loss1_pycox:328.32468
# [230]	validation_0-rmse:40.67884	validation_0-deephit_loss1_pycox:327.59154
# [231]	validation_0-rmse:40.67943	validation_0-deephit_loss1_pycox:326.92284
# [232]	validation_0-rmse:40.67993	validation_0-deephit_loss1_pycox:326.22307
# [233]	validation_0-rmse:40.68038	validation_0-deephit_loss1_pycox:325.57364
# [234]	validation_0-rmse:40.68077	validation_0-deephit_loss1_pycox:324.90168
# [235]	validation_0-rmse:40.68131	validation_0-deephit_loss1_pycox:324.21560
# [236]	validation_0-rmse:40.68152	validation_0-deephit_loss1_pycox:323.50937
# [237]	validation_0-rmse:40.68208	validation_0-deephit_loss1_pycox:322.84369
# [238]	validation_0-rmse:40.68257	validation_0-deephit_loss1_pycox:322.20452
# [239]	validation_0-rmse:40.68302	validation_0-deephit_loss1_pycox:321.62268
# [240]	validation_0-rmse:40.68347	validation_0-deephit_loss1_pycox:320.99067
# [241]	validation_0-rmse:40.68387	validation_0-deephit_loss1_pycox:320.35976
# [242]	validation_0-rmse:40.68431	validation_0-deephit_loss1_pycox:319.71753
# [243]	validation_0-rmse:40.68472	validation_0-deephit_loss1_pycox:319.06435
# [244]	validation_0-rmse:40.68517	validation_0-deephit_loss1_pycox:318.51243
# [245]	validation_0-rmse:40.68556	validation_0-deephit_loss1_pycox:317.91044
# [246]	validation_0-rmse:40.68596	validation_0-deephit_loss1_pycox:317.33131
# [247]	validation_0-rmse:40.68652	validation_0-deephit_loss1_pycox:316.68624
# [248]	validation_0-rmse:40.68684	validation_0-deephit_loss1_pycox:316.06458
# [249]	validation_0-rmse:40.68725	validation_0-deephit_loss1_pycox:315.49583
# [250]	validation_0-rmse:40.68759	validation_0-deephit_loss1_pycox:314.95512
# [251]	validation_0-rmse:40.68798	validation_0-deephit_loss1_pycox:314.42640
# [252]	validation_0-rmse:40.68830	validation_0-deephit_loss1_pycox:313.92186
# [253]	validation_0-rmse:40.68866	validation_0-deephit_loss1_pycox:313.36377
# [254]	validation_0-rmse:40.68904	validation_0-deephit_loss1_pycox:312.82499
# [255]	validation_0-rmse:40.68933	validation_0-deephit_loss1_pycox:312.24696
# [256]	validation_0-rmse:40.68976	validation_0-deephit_loss1_pycox:311.72737
# [257]	validation_0-rmse:40.69008	validation_0-deephit_loss1_pycox:311.22681
# [258]	validation_0-rmse:40.69051	validation_0-deephit_loss1_pycox:310.71765
# [259]	validation_0-rmse:40.69105	validation_0-deephit_loss1_pycox:310.12187
# [260]	validation_0-rmse:40.69123	validation_0-deephit_loss1_pycox:309.63832
# [261]	validation_0-rmse:40.69172	validation_0-deephit_loss1_pycox:309.14124
# [262]	validation_0-rmse:40.69201	validation_0-deephit_loss1_pycox:308.67145
# [263]	validation_0-rmse:40.69243	validation_0-deephit_loss1_pycox:308.15283
# [264]	validation_0-rmse:40.69289	validation_0-deephit_loss1_pycox:307.63723
# [265]	validation_0-rmse:40.69321	validation_0-deephit_loss1_pycox:307.15283
# [266]	validation_0-rmse:40.69344	validation_0-deephit_loss1_pycox:306.71239
# [267]	validation_0-rmse:40.69377	validation_0-deephit_loss1_pycox:306.23770
# [268]	validation_0-rmse:40.69408	validation_0-deephit_loss1_pycox:305.78950
# [269]	validation_0-rmse:40.69447	validation_0-deephit_loss1_pycox:305.31442
# [270]	validation_0-rmse:40.69467	validation_0-deephit_loss1_pycox:304.82256
# [271]	validation_0-rmse:40.69502	validation_0-deephit_loss1_pycox:304.35139
# [272]	validation_0-rmse:40.69533	validation_0-deephit_loss1_pycox:303.90064
# [273]	validation_0-rmse:40.69563	validation_0-deephit_loss1_pycox:303.47728
# [274]	validation_0-rmse:40.69586	validation_0-deephit_loss1_pycox:303.02994
# [275]	validation_0-rmse:40.69624	validation_0-deephit_loss1_pycox:302.54564
# [276]	validation_0-rmse:40.69659	validation_0-deephit_loss1_pycox:302.09888
# [277]	validation_0-rmse:40.69688	validation_0-deephit_loss1_pycox:301.64311
# [278]	validation_0-rmse:40.69718	validation_0-deephit_loss1_pycox:301.18605
# [279]	validation_0-rmse:40.69744	validation_0-deephit_loss1_pycox:300.77634
# [280]	validation_0-rmse:40.69771	validation_0-deephit_loss1_pycox:300.36877
# [281]	validation_0-rmse:40.69810	validation_0-deephit_loss1_pycox:299.95087
# [282]	validation_0-rmse:40.69844	validation_0-deephit_loss1_pycox:299.48880
# [283]	validation_0-rmse:40.69870	validation_0-deephit_loss1_pycox:299.06543
# [284]	validation_0-rmse:40.69898	validation_0-deephit_loss1_pycox:298.66001
# [285]	validation_0-rmse:40.69929	validation_0-deephit_loss1_pycox:298.24914
# [286]	validation_0-rmse:40.69957	validation_0-deephit_loss1_pycox:297.82178
# [287]	validation_0-rmse:40.69988	validation_0-deephit_loss1_pycox:297.41512
# [288]	validation_0-rmse:40.70018	validation_0-deephit_loss1_pycox:297.01563
# [289]	validation_0-rmse:40.70047	validation_0-deephit_loss1_pycox:296.60691
# [290]	validation_0-rmse:40.70070	validation_0-deephit_loss1_pycox:296.22578
# [291]	validation_0-rmse:40.70104	validation_0-deephit_loss1_pycox:295.79632
# [292]	validation_0-rmse:40.70121	validation_0-deephit_loss1_pycox:295.42739
# [293]	validation_0-rmse:40.70140	validation_0-deephit_loss1_pycox:295.02349
# [294]	validation_0-rmse:40.70168	validation_0-deephit_loss1_pycox:294.66018
# [295]	validation_0-rmse:40.70184	validation_0-deephit_loss1_pycox:294.26551
# [296]	validation_0-rmse:40.70218	validation_0-deephit_loss1_pycox:293.84414
# [297]	validation_0-rmse:40.70245	validation_0-deephit_loss1_pycox:293.50858
# [298]	validation_0-rmse:40.70268	validation_0-deephit_loss1_pycox:293.07361
# [299]	validation_0-rmse:40.70289	validation_0-deephit_loss1_pycox:292.72984
# [300]	validation_0-rmse:40.70309	validation_0-deephit_loss1_pycox:292.36565
# [301]	validation_0-rmse:40.70337	validation_0-deephit_loss1_pycox:291.99938
# [302]	validation_0-rmse:40.70373	validation_0-deephit_loss1_pycox:291.63568
# [303]	validation_0-rmse:40.70399	validation_0-deephit_loss1_pycox:291.27715
# [304]	validation_0-rmse:40.70420	validation_0-deephit_loss1_pycox:290.94229
# [305]	validation_0-rmse:40.70450	validation_0-deephit_loss1_pycox:290.58925
# [306]	validation_0-rmse:40.70480	validation_0-deephit_loss1_pycox:290.22677
# [307]	validation_0-rmse:40.70504	validation_0-deephit_loss1_pycox:289.86530
# [308]	validation_0-rmse:40.70524	validation_0-deephit_loss1_pycox:289.51736
# [309]	validation_0-rmse:40.70552	validation_0-deephit_loss1_pycox:289.17396
# [310]	validation_0-rmse:40.70568	validation_0-deephit_loss1_pycox:288.80362
# [311]	validation_0-rmse:40.70590	validation_0-deephit_loss1_pycox:288.43700
# [312]	validation_0-rmse:40.70603	validation_0-deephit_loss1_pycox:288.06895
# [313]	validation_0-rmse:40.70630	validation_0-deephit_loss1_pycox:287.72486
# [314]	validation_0-rmse:40.70652	validation_0-deephit_loss1_pycox:287.40607
# [315]	validation_0-rmse:40.70685	validation_0-deephit_loss1_pycox:287.08317
# [316]	validation_0-rmse:40.70690	validation_0-deephit_loss1_pycox:286.73467
# [317]	validation_0-rmse:40.70703	validation_0-deephit_loss1_pycox:286.40838
# [318]	validation_0-rmse:40.70722	validation_0-deephit_loss1_pycox:286.07290
# [319]	validation_0-rmse:40.70739	validation_0-deephit_loss1_pycox:285.75330
# [320]	validation_0-rmse:40.70764	validation_0-deephit_loss1_pycox:285.43494
# [321]	validation_0-rmse:40.70780	validation_0-deephit_loss1_pycox:285.11576
# [322]	validation_0-rmse:40.70806	validation_0-deephit_loss1_pycox:284.75373
# [323]	validation_0-rmse:40.70820	validation_0-deephit_loss1_pycox:284.44630
# [324]	validation_0-rmse:40.70844	validation_0-deephit_loss1_pycox:284.12219
# [325]	validation_0-rmse:40.70876	validation_0-deephit_loss1_pycox:283.80770
# [326]	validation_0-rmse:40.70893	validation_0-deephit_loss1_pycox:283.48994
# [327]	validation_0-rmse:40.70904	validation_0-deephit_loss1_pycox:283.15535
# [328]	validation_0-rmse:40.70914	validation_0-deephit_loss1_pycox:282.85837
# [329]	validation_0-rmse:40.70928	validation_0-deephit_loss1_pycox:282.56052
# [330]	validation_0-rmse:40.70956	validation_0-deephit_loss1_pycox:282.24192
# [331]	validation_0-rmse:40.70970	validation_0-deephit_loss1_pycox:281.96064
# [332]	validation_0-rmse:40.70984	validation_0-deephit_loss1_pycox:281.66912
# [333]	validation_0-rmse:40.70993	validation_0-deephit_loss1_pycox:281.33789
# [334]	validation_0-rmse:40.71024	validation_0-deephit_loss1_pycox:281.05172
# [335]	validation_0-rmse:40.71042	validation_0-deephit_loss1_pycox:280.76205
# [336]	validation_0-rmse:40.71052	validation_0-deephit_loss1_pycox:280.46063
# [337]	validation_0-rmse:40.71057	validation_0-deephit_loss1_pycox:280.17531
# [338]	validation_0-rmse:40.71066	validation_0-deephit_loss1_pycox:279.89967
# [339]	validation_0-rmse:40.71089	validation_0-deephit_loss1_pycox:279.61895
# [340]	validation_0-rmse:40.71094	validation_0-deephit_loss1_pycox:279.31466
# [341]	validation_0-rmse:40.71117	validation_0-deephit_loss1_pycox:279.02893
# [342]	validation_0-rmse:40.71123	validation_0-deephit_loss1_pycox:278.72819
# [343]	validation_0-rmse:40.71150	validation_0-deephit_loss1_pycox:278.44322
# [344]	validation_0-rmse:40.71161	validation_0-deephit_loss1_pycox:278.15785
# [345]	validation_0-rmse:40.71179	validation_0-deephit_loss1_pycox:277.88072
# [346]	validation_0-rmse:40.71183	validation_0-deephit_loss1_pycox:277.58276
# [347]	validation_0-rmse:40.71192	validation_0-deephit_loss1_pycox:277.28587
# [348]	validation_0-rmse:40.71223	validation_0-deephit_loss1_pycox:277.02971
# [349]	validation_0-rmse:40.71230	validation_0-deephit_loss1_pycox:276.74493
# [350]	validation_0-rmse:40.71252	validation_0-deephit_loss1_pycox:276.47465
# [351]	validation_0-rmse:40.71249	validation_0-deephit_loss1_pycox:276.19581
# [352]	validation_0-rmse:40.71268	validation_0-deephit_loss1_pycox:275.93629
# [353]	validation_0-rmse:40.71278	validation_0-deephit_loss1_pycox:275.64134
# [354]	validation_0-rmse:40.71285	validation_0-deephit_loss1_pycox:275.36179
# [355]	validation_0-rmse:40.71305	validation_0-deephit_loss1_pycox:275.10128
# [356]	validation_0-rmse:40.71316	validation_0-deephit_loss1_pycox:274.84502
# [357]	validation_0-rmse:40.71319	validation_0-deephit_loss1_pycox:274.55741
# [358]	validation_0-rmse:40.71337	validation_0-deephit_loss1_pycox:274.29552
# [359]	validation_0-rmse:40.71351	validation_0-deephit_loss1_pycox:274.03931
# [360]	validation_0-rmse:40.71360	validation_0-deephit_loss1_pycox:273.76339
# [361]	validation_0-rmse:40.71368	validation_0-deephit_loss1_pycox:273.49796
# [362]	validation_0-rmse:40.71374	validation_0-deephit_loss1_pycox:273.25172
# [363]	validation_0-rmse:40.71378	validation_0-deephit_loss1_pycox:272.99530
# [364]	validation_0-rmse:40.71388	validation_0-deephit_loss1_pycox:272.75752
# [365]	validation_0-rmse:40.71410	validation_0-deephit_loss1_pycox:272.51710
# [366]	validation_0-rmse:40.71419	validation_0-deephit_loss1_pycox:272.26760
# [367]	validation_0-rmse:40.71436	validation_0-deephit_loss1_pycox:272.00344
# [368]	validation_0-rmse:40.71445	validation_0-deephit_loss1_pycox:271.75353
# [369]	validation_0-rmse:40.71455	validation_0-deephit_loss1_pycox:271.50472
# [370]	validation_0-rmse:40.71449	validation_0-deephit_loss1_pycox:271.28899
# [371]	validation_0-rmse:40.71459	validation_0-deephit_loss1_pycox:271.06554
# [372]	validation_0-rmse:40.71467	validation_0-deephit_loss1_pycox:270.83089
# [373]	validation_0-rmse:40.71472	validation_0-deephit_loss1_pycox:270.60445
# [374]	validation_0-rmse:40.71495	validation_0-deephit_loss1_pycox:270.38075
# [375]	validation_0-rmse:40.71502	validation_0-deephit_loss1_pycox:270.13370
# [376]	validation_0-rmse:40.71513	validation_0-deephit_loss1_pycox:269.89763
# [377]	validation_0-rmse:40.71516	validation_0-deephit_loss1_pycox:269.67058
# [378]	validation_0-rmse:40.71520	validation_0-deephit_loss1_pycox:269.45276
# [379]	validation_0-rmse:40.71538	validation_0-deephit_loss1_pycox:269.21267
# [380]	validation_0-rmse:40.71547	validation_0-deephit_loss1_pycox:268.97945
# [381]	validation_0-rmse:40.71550	validation_0-deephit_loss1_pycox:268.76872
# [382]	validation_0-rmse:40.71564	validation_0-deephit_loss1_pycox:268.52672
# [383]	validation_0-rmse:40.71570	validation_0-deephit_loss1_pycox:268.32566
# [384]	validation_0-rmse:40.71577	validation_0-deephit_loss1_pycox:268.11025
# [385]	validation_0-rmse:40.71581	validation_0-deephit_loss1_pycox:267.86292
# [386]	validation_0-rmse:40.71592	validation_0-deephit_loss1_pycox:267.64723
# [387]	validation_0-rmse:40.71607	validation_0-deephit_loss1_pycox:267.42115
# [388]	validation_0-rmse:40.71609	validation_0-deephit_loss1_pycox:267.18976
# [389]	validation_0-rmse:40.71615	validation_0-deephit_loss1_pycox:266.97372
# [390]	validation_0-rmse:40.71622	validation_0-deephit_loss1_pycox:266.75272
# [391]	validation_0-rmse:40.71634	validation_0-deephit_loss1_pycox:266.54271
# [392]	validation_0-rmse:40.71635	validation_0-deephit_loss1_pycox:266.32415
# [393]	validation_0-rmse:40.71634	validation_0-deephit_loss1_pycox:266.11904
# [394]	validation_0-rmse:40.71640	validation_0-deephit_loss1_pycox:265.91533
# [395]	validation_0-rmse:40.71659	validation_0-deephit_loss1_pycox:265.70328
# [396]	validation_0-rmse:40.71677	validation_0-deephit_loss1_pycox:265.49556
# [397]	validation_0-rmse:40.71680	validation_0-deephit_loss1_pycox:265.28429
# [398]	validation_0-rmse:40.71681	validation_0-deephit_loss1_pycox:265.07545
# [399]	validation_0-rmse:40.71684	validation_0-deephit_loss1_pycox:264.86482
# [400]	validation_0-rmse:40.71703	validation_0-deephit_loss1_pycox:264.65630
# [401]	validation_0-rmse:40.71705	validation_0-deephit_loss1_pycox:264.42541
# [402]	validation_0-rmse:40.71711	validation_0-deephit_loss1_pycox:264.22248
# [403]	validation_0-rmse:40.71719	validation_0-deephit_loss1_pycox:264.01072
# [404]	validation_0-rmse:40.71716	validation_0-deephit_loss1_pycox:263.83168
# [405]	validation_0-rmse:40.71729	validation_0-deephit_loss1_pycox:263.61742
# [406]	validation_0-rmse:40.71728	validation_0-deephit_loss1_pycox:263.41496
# [407]	validation_0-rmse:40.71739	validation_0-deephit_loss1_pycox:263.20923
# [408]	validation_0-rmse:40.71750	validation_0-deephit_loss1_pycox:263.01444
# [409]	validation_0-rmse:40.71753	validation_0-deephit_loss1_pycox:262.82128
# [410]	validation_0-rmse:40.71760	validation_0-deephit_loss1_pycox:262.60069
# [411]	validation_0-rmse:40.71774	validation_0-deephit_loss1_pycox:262.40854
# [412]	validation_0-rmse:40.71774	validation_0-deephit_loss1_pycox:262.21311
# [413]	validation_0-rmse:40.71778	validation_0-deephit_loss1_pycox:262.00843
# [414]	validation_0-rmse:40.71794	validation_0-deephit_loss1_pycox:261.80616
# [415]	validation_0-rmse:40.71802	validation_0-deephit_loss1_pycox:261.60647
# [416]	validation_0-rmse:40.71815	validation_0-deephit_loss1_pycox:261.41406
# [417]	validation_0-rmse:40.71815	validation_0-deephit_loss1_pycox:261.22925
# [418]	validation_0-rmse:40.71811	validation_0-deephit_loss1_pycox:261.03594
# [419]	validation_0-rmse:40.71825	validation_0-deephit_loss1_pycox:260.85757
# [420]	validation_0-rmse:40.71835	validation_0-deephit_loss1_pycox:260.66397
# [421]	validation_0-rmse:40.71852	validation_0-deephit_loss1_pycox:260.48056
# [422]	validation_0-rmse:40.71849	validation_0-deephit_loss1_pycox:260.29685
# [423]	validation_0-rmse:40.71862	validation_0-deephit_loss1_pycox:260.11782
# [424]	validation_0-rmse:40.71860	validation_0-deephit_loss1_pycox:259.93364
# [425]	validation_0-rmse:40.71869	validation_0-deephit_loss1_pycox:259.75013
# [426]	validation_0-rmse:40.71875	validation_0-deephit_loss1_pycox:259.56448
# [427]	validation_0-rmse:40.71880	validation_0-deephit_loss1_pycox:259.39874
# [428]	validation_0-rmse:40.71885	validation_0-deephit_loss1_pycox:259.21752
# [429]	validation_0-rmse:40.71894	validation_0-deephit_loss1_pycox:259.04396
# [430]	validation_0-rmse:40.71897	validation_0-deephit_loss1_pycox:258.84920
# [431]	validation_0-rmse:40.71899	validation_0-deephit_loss1_pycox:258.68586
# [432]	validation_0-rmse:40.71902	validation_0-deephit_loss1_pycox:258.49879
# [433]	validation_0-rmse:40.71907	validation_0-deephit_loss1_pycox:258.33297
# [434]	validation_0-rmse:40.71925	validation_0-deephit_loss1_pycox:258.14816
# [435]	validation_0-rmse:40.71932	validation_0-deephit_loss1_pycox:257.97828
# [436]	validation_0-rmse:40.71942	validation_0-deephit_loss1_pycox:257.80034
# [437]	validation_0-rmse:40.71950	validation_0-deephit_loss1_pycox:257.61163
# [438]	validation_0-rmse:40.71948	validation_0-deephit_loss1_pycox:257.43067
# [439]	validation_0-rmse:40.71959	validation_0-deephit_loss1_pycox:257.27481
# [440]	validation_0-rmse:40.71977	validation_0-deephit_loss1_pycox:257.10279
# [441]	validation_0-rmse:40.71982	validation_0-deephit_loss1_pycox:256.92040
# [442]	validation_0-rmse:40.71987	validation_0-deephit_loss1_pycox:256.74540
# [443]	validation_0-rmse:40.71980	validation_0-deephit_loss1_pycox:256.58469
# [444]	validation_0-rmse:40.71982	validation_0-deephit_loss1_pycox:256.40672
# [445]	validation_0-rmse:40.71989	validation_0-deephit_loss1_pycox:256.24415
# [446]	validation_0-rmse:40.71996	validation_0-deephit_loss1_pycox:256.09092
# [447]	validation_0-rmse:40.71994	validation_0-deephit_loss1_pycox:255.92722
# [448]	validation_0-rmse:40.72009	validation_0-deephit_loss1_pycox:255.77200
# [449]	validation_0-rmse:40.72014	validation_0-deephit_loss1_pycox:255.61288
# [450]	validation_0-rmse:40.72018	validation_0-deephit_loss1_pycox:255.44432
# [451]	validation_0-rmse:40.72016	validation_0-deephit_loss1_pycox:255.27356
# [452]	validation_0-rmse:40.72024	validation_0-deephit_loss1_pycox:255.11792
# [453]	validation_0-rmse:40.72034	validation_0-deephit_loss1_pycox:254.96052
# [454]	validation_0-rmse:40.72034	validation_0-deephit_loss1_pycox:254.79580
# [455]	validation_0-rmse:40.72043	validation_0-deephit_loss1_pycox:254.62131
# [456]	validation_0-rmse:40.72049	validation_0-deephit_loss1_pycox:254.46051
# [457]	validation_0-rmse:40.72053	validation_0-deephit_loss1_pycox:254.31280
# [458]	validation_0-rmse:40.72067	validation_0-deephit_loss1_pycox:254.14790
# [459]	validation_0-rmse:40.72080	validation_0-deephit_loss1_pycox:253.97463
# [460]	validation_0-rmse:40.72081	validation_0-deephit_loss1_pycox:253.81501
# [461]	validation_0-rmse:40.72083	validation_0-deephit_loss1_pycox:253.65669
# [462]	validation_0-rmse:40.72083	validation_0-deephit_loss1_pycox:253.49363
# [463]	validation_0-rmse:40.72086	validation_0-deephit_loss1_pycox:253.34246
# [464]	validation_0-rmse:40.72095	validation_0-deephit_loss1_pycox:253.18514
# [465]	validation_0-rmse:40.72092	validation_0-deephit_loss1_pycox:253.02469
# [466]	validation_0-rmse:40.72104	validation_0-deephit_loss1_pycox:252.86669
# [467]	validation_0-rmse:40.72108	validation_0-deephit_loss1_pycox:252.70893
# [468]	validation_0-rmse:40.72110	validation_0-deephit_loss1_pycox:252.55003
# [469]	validation_0-rmse:40.72115	validation_0-deephit_loss1_pycox:252.38162
# [470]	validation_0-rmse:40.72128	validation_0-deephit_loss1_pycox:252.23550
# [471]	validation_0-rmse:40.72134	validation_0-deephit_loss1_pycox:252.09032
# [472]	validation_0-rmse:40.72149	validation_0-deephit_loss1_pycox:251.93878
# [473]	validation_0-rmse:40.72147	validation_0-deephit_loss1_pycox:251.78494
# [474]	validation_0-rmse:40.72155	validation_0-deephit_loss1_pycox:251.62869
# [475]	validation_0-rmse:40.72169	validation_0-deephit_loss1_pycox:251.47231
# [476]	validation_0-rmse:40.72171	validation_0-deephit_loss1_pycox:251.32789
# [477]	validation_0-rmse:40.72170	validation_0-deephit_loss1_pycox:251.17519
# [478]	validation_0-rmse:40.72174	validation_0-deephit_loss1_pycox:251.02930
# [479]	validation_0-rmse:40.72180	validation_0-deephit_loss1_pycox:250.87231
# [480]	validation_0-rmse:40.72186	validation_0-deephit_loss1_pycox:250.72663
# [481]	validation_0-rmse:40.72191	validation_0-deephit_loss1_pycox:250.57418
# [482]	validation_0-rmse:40.72193	validation_0-deephit_loss1_pycox:250.43227
# [483]	validation_0-rmse:40.72205	validation_0-deephit_loss1_pycox:250.28564
# [484]	validation_0-rmse:40.72208	validation_0-deephit_loss1_pycox:250.13828
# [485]	validation_0-rmse:40.72206	validation_0-deephit_loss1_pycox:249.99474
# [486]	validation_0-rmse:40.72214	validation_0-deephit_loss1_pycox:249.85428
# [487]	validation_0-rmse:40.72215	validation_0-deephit_loss1_pycox:249.71697
# [488]	validation_0-rmse:40.72226	validation_0-deephit_loss1_pycox:249.57213
# [489]	validation_0-rmse:40.72235	validation_0-deephit_loss1_pycox:249.43971
# [490]	validation_0-rmse:40.72232	validation_0-deephit_loss1_pycox:249.27739
# [491]	validation_0-rmse:40.72239	validation_0-deephit_loss1_pycox:249.14186
# [492]	validation_0-rmse:40.72245	validation_0-deephit_loss1_pycox:248.99887
# [493]	validation_0-rmse:40.72243	validation_0-deephit_loss1_pycox:248.84203
# [494]	validation_0-rmse:40.72247	validation_0-deephit_loss1_pycox:248.69700
# [495]	validation_0-rmse:40.72259	validation_0-deephit_loss1_pycox:248.55430
# [496]	validation_0-rmse:40.72262	validation_0-deephit_loss1_pycox:248.42016
# [497]	validation_0-rmse:40.72271	validation_0-deephit_loss1_pycox:248.28384
# [498]	validation_0-rmse:40.72275	validation_0-deephit_loss1_pycox:248.13081
# [499]	validation_0-rmse:40.72282	validation_0-deephit_loss1_pycox:247.98271
# [500]	validation_0-rmse:40.72282	validation_0-deephit_loss1_pycox:247.83454
# [501]	validation_0-rmse:40.72280	validation_0-deephit_loss1_pycox:247.69183
# [502]	validation_0-rmse:40.72288	validation_0-deephit_loss1_pycox:247.54070
# [503]	validation_0-rmse:40.72301	validation_0-deephit_loss1_pycox:247.40836
# [504]	validation_0-rmse:40.72302	validation_0-deephit_loss1_pycox:247.26577
# [505]	validation_0-rmse:40.72317	validation_0-deephit_loss1_pycox:247.12518
# [506]	validation_0-rmse:40.72309	validation_0-deephit_loss1_pycox:246.98876
# [507]	validation_0-rmse:40.72312	validation_0-deephit_loss1_pycox:246.85011
# [508]	validation_0-rmse:40.72322	validation_0-deephit_loss1_pycox:246.71614
# [509]	validation_0-rmse:40.72319	validation_0-deephit_loss1_pycox:246.59679
# [510]	validation_0-rmse:40.72330	validation_0-deephit_loss1_pycox:246.44529
# [511]	validation_0-rmse:40.72336	validation_0-deephit_loss1_pycox:246.31433
# [512]	validation_0-rmse:40.72334	validation_0-deephit_loss1_pycox:246.18788
# [513]	validation_0-rmse:40.72351	validation_0-deephit_loss1_pycox:246.04816
# [514]	validation_0-rmse:40.72346	validation_0-deephit_loss1_pycox:245.90047
# [515]	validation_0-rmse:40.72351	validation_0-deephit_loss1_pycox:245.76429
# [516]	validation_0-rmse:40.72358	validation_0-deephit_loss1_pycox:245.63933
# [517]	validation_0-rmse:40.72357	validation_0-deephit_loss1_pycox:245.50762
# [518]	validation_0-rmse:40.72365	validation_0-deephit_loss1_pycox:245.37115
# [519]	validation_0-rmse:40.72364	validation_0-deephit_loss1_pycox:245.24026
# [520]	validation_0-rmse:40.72366	validation_0-deephit_loss1_pycox:245.11678
# [521]	validation_0-rmse:40.72371	validation_0-deephit_loss1_pycox:244.97390
# [522]	validation_0-rmse:40.72374	validation_0-deephit_loss1_pycox:244.85700
# [523]	validation_0-rmse:40.72387	validation_0-deephit_loss1_pycox:244.73524
# [524]	validation_0-rmse:40.72383	validation_0-deephit_loss1_pycox:244.61535
# [525]	validation_0-rmse:40.72390	validation_0-deephit_loss1_pycox:244.48598
# [526]	validation_0-rmse:40.72386	validation_0-deephit_loss1_pycox:244.35357
# [527]	validation_0-rmse:40.72397	validation_0-deephit_loss1_pycox:244.23109
# [528]	validation_0-rmse:40.72394	validation_0-deephit_loss1_pycox:244.09961
# [529]	validation_0-rmse:40.72395	validation_0-deephit_loss1_pycox:243.98600
# [530]	validation_0-rmse:40.72398	validation_0-deephit_loss1_pycox:243.85567
# [531]	validation_0-rmse:40.72404	validation_0-deephit_loss1_pycox:243.74801
# [532]	validation_0-rmse:40.72412	validation_0-deephit_loss1_pycox:243.61049
# [533]	validation_0-rmse:40.72408	validation_0-deephit_loss1_pycox:243.49069
# [534]	validation_0-rmse:40.72411	validation_0-deephit_loss1_pycox:243.37190
# [535]	validation_0-rmse:40.72419	validation_0-deephit_loss1_pycox:243.24805
# [536]	validation_0-rmse:40.72434	validation_0-deephit_loss1_pycox:243.12743
# [537]	validation_0-rmse:40.72438	validation_0-deephit_loss1_pycox:243.00414
# [538]	validation_0-rmse:40.72429	validation_0-deephit_loss1_pycox:242.88380
# [539]	validation_0-rmse:40.72433	validation_0-deephit_loss1_pycox:242.75585
# [540]	validation_0-rmse:40.72436	validation_0-deephit_loss1_pycox:242.63140
# [541]	validation_0-rmse:40.72443	validation_0-deephit_loss1_pycox:242.51071
# [542]	validation_0-rmse:40.72445	validation_0-deephit_loss1_pycox:242.39271
# [543]	validation_0-rmse:40.72447	validation_0-deephit_loss1_pycox:242.28149
# [544]	validation_0-rmse:40.72449	validation_0-deephit_loss1_pycox:242.16965
# [545]	validation_0-rmse:40.72453	validation_0-deephit_loss1_pycox:242.05184
# [546]	validation_0-rmse:40.72458	validation_0-deephit_loss1_pycox:241.93167
# [547]	validation_0-rmse:40.72462	validation_0-deephit_loss1_pycox:241.81496
# [548]	validation_0-rmse:40.72467	validation_0-deephit_loss1_pycox:241.68734
# [549]	validation_0-rmse:40.72463	validation_0-deephit_loss1_pycox:241.57396
# [550]	validation_0-rmse:40.72474	validation_0-deephit_loss1_pycox:241.46130
# [551]	validation_0-rmse:40.72474	validation_0-deephit_loss1_pycox:241.35058
# [552]	validation_0-rmse:40.72467	validation_0-deephit_loss1_pycox:241.23653
# [553]	validation_0-rmse:40.72482	validation_0-deephit_loss1_pycox:241.12790
# [554]	validation_0-rmse:40.72472	validation_0-deephit_loss1_pycox:241.01913
# [555]	validation_0-rmse:40.72478	validation_0-deephit_loss1_pycox:240.90265
# [556]	validation_0-rmse:40.72477	validation_0-deephit_loss1_pycox:240.77929
# [557]	validation_0-rmse:40.72484	validation_0-deephit_loss1_pycox:240.66218
# [558]	validation_0-rmse:40.72487	validation_0-deephit_loss1_pycox:240.54516
# [559]	validation_0-rmse:40.72490	validation_0-deephit_loss1_pycox:240.43472
# [560]	validation_0-rmse:40.72496	validation_0-deephit_loss1_pycox:240.32083
# [561]	validation_0-rmse:40.72500	validation_0-deephit_loss1_pycox:240.20982
# [562]	validation_0-rmse:40.72501	validation_0-deephit_loss1_pycox:240.09950
# [563]	validation_0-rmse:40.72500	validation_0-deephit_loss1_pycox:239.98639
# [564]	validation_0-rmse:40.72499	validation_0-deephit_loss1_pycox:239.88440
# [565]	validation_0-rmse:40.72503	validation_0-deephit_loss1_pycox:239.77495
# [566]	validation_0-rmse:40.72514	validation_0-deephit_loss1_pycox:239.67370
# [567]	validation_0-rmse:40.72514	validation_0-deephit_loss1_pycox:239.57804
# [568]	validation_0-rmse:40.72515	validation_0-deephit_loss1_pycox:239.47420
# [569]	validation_0-rmse:40.72518	validation_0-deephit_loss1_pycox:239.36365
# [570]	validation_0-rmse:40.72516	validation_0-deephit_loss1_pycox:239.26444
# [571]	validation_0-rmse:40.72523	validation_0-deephit_loss1_pycox:239.15994
# [572]	validation_0-rmse:40.72518	validation_0-deephit_loss1_pycox:239.06309
# [573]	validation_0-rmse:40.72523	validation_0-deephit_loss1_pycox:238.95808
# [574]	validation_0-rmse:40.72529	validation_0-deephit_loss1_pycox:238.85201
# [575]	validation_0-rmse:40.72525	validation_0-deephit_loss1_pycox:238.74764
# [576]	validation_0-rmse:40.72533	validation_0-deephit_loss1_pycox:238.64780
# [577]	validation_0-rmse:40.72538	validation_0-deephit_loss1_pycox:238.54797
# [578]	validation_0-rmse:40.72541	validation_0-deephit_loss1_pycox:238.45142
# [579]	validation_0-rmse:40.72539	validation_0-deephit_loss1_pycox:238.34632
# [580]	validation_0-rmse:40.72546	validation_0-deephit_loss1_pycox:238.24868
# [581]	validation_0-rmse:40.72543	validation_0-deephit_loss1_pycox:238.14881
# [582]	validation_0-rmse:40.72552	validation_0-deephit_loss1_pycox:238.04928
# [583]	validation_0-rmse:40.72557	validation_0-deephit_loss1_pycox:237.94771
# [584]	validation_0-rmse:40.72561	validation_0-deephit_loss1_pycox:237.85811
# [585]	validation_0-rmse:40.72563	validation_0-deephit_loss1_pycox:237.73802
# [586]	validation_0-rmse:40.72560	validation_0-deephit_loss1_pycox:237.64427
# [587]	validation_0-rmse:40.72562	validation_0-deephit_loss1_pycox:237.53513
# [588]	validation_0-rmse:40.72560	validation_0-deephit_loss1_pycox:237.44070
# [589]	validation_0-rmse:40.72574	validation_0-deephit_loss1_pycox:237.33518
# [590]	validation_0-rmse:40.72570	validation_0-deephit_loss1_pycox:237.23294
# [591]	validation_0-rmse:40.72567	validation_0-deephit_loss1_pycox:237.12215
# [592]	validation_0-rmse:40.72573	validation_0-deephit_loss1_pycox:237.02307
# [593]	validation_0-rmse:40.72579	validation_0-deephit_loss1_pycox:236.92602
# [594]	validation_0-rmse:40.72574	validation_0-deephit_loss1_pycox:236.83287
# [595]	validation_0-rmse:40.72580	validation_0-deephit_loss1_pycox:236.72487
# [596]	validation_0-rmse:40.72580	validation_0-deephit_loss1_pycox:236.63796
# [597]	validation_0-rmse:40.72585	validation_0-deephit_loss1_pycox:236.53976
# [598]	validation_0-rmse:40.72593	validation_0-deephit_loss1_pycox:236.44174
# [599]	validation_0-rmse:40.72593	validation_0-deephit_loss1_pycox:236.34431
# [600]	validation_0-rmse:40.72596	validation_0-deephit_loss1_pycox:236.24595
# [601]	validation_0-rmse:40.72601	validation_0-deephit_loss1_pycox:236.13660
# [602]	validation_0-rmse:40.72595	validation_0-deephit_loss1_pycox:236.04523
# [603]	validation_0-rmse:40.72610	validation_0-deephit_loss1_pycox:235.94992
# [604]	validation_0-rmse:40.72611	validation_0-deephit_loss1_pycox:235.84878
# [605]	validation_0-rmse:40.72609	validation_0-deephit_loss1_pycox:235.74705
# [606]	validation_0-rmse:40.72612	validation_0-deephit_loss1_pycox:235.64869
# [607]	validation_0-rmse:40.72612	validation_0-deephit_loss1_pycox:235.55305
# [608]	validation_0-rmse:40.72616	validation_0-deephit_loss1_pycox:235.45435
# [609]	validation_0-rmse:40.72620	validation_0-deephit_loss1_pycox:235.35647
# [610]	validation_0-rmse:40.72620	validation_0-deephit_loss1_pycox:235.26671
# [611]	validation_0-rmse:40.72624	validation_0-deephit_loss1_pycox:235.16884
# [612]	validation_0-rmse:40.72624	validation_0-deephit_loss1_pycox:235.07748
# [613]	validation_0-rmse:40.72625	validation_0-deephit_loss1_pycox:234.98293
# [614]	validation_0-rmse:40.72628	validation_0-deephit_loss1_pycox:234.87639
# [615]	validation_0-rmse:40.72634	validation_0-deephit_loss1_pycox:234.77850
# [616]	validation_0-rmse:40.72634	validation_0-deephit_loss1_pycox:234.68592
# [617]	validation_0-rmse:40.72640	validation_0-deephit_loss1_pycox:234.58325
# [618]	validation_0-rmse:40.72640	validation_0-deephit_loss1_pycox:234.49256
# [619]	validation_0-rmse:40.72636	validation_0-deephit_loss1_pycox:234.39643
# [620]	validation_0-rmse:40.72636	validation_0-deephit_loss1_pycox:234.30662
# [621]	validation_0-rmse:40.72644	validation_0-deephit_loss1_pycox:234.21926
# [622]	validation_0-rmse:40.72640	validation_0-deephit_loss1_pycox:234.12094
# [623]	validation_0-rmse:40.72642	validation_0-deephit_loss1_pycox:234.02841
# [624]	validation_0-rmse:40.72643	validation_0-deephit_loss1_pycox:233.93088
# [625]	validation_0-rmse:40.72646	validation_0-deephit_loss1_pycox:233.84768
# [626]	validation_0-rmse:40.72647	validation_0-deephit_loss1_pycox:233.75824
# [627]	validation_0-rmse:40.72649	validation_0-deephit_loss1_pycox:233.67331
# [628]	validation_0-rmse:40.72649	validation_0-deephit_loss1_pycox:233.58603
# ...
# [1803]	validation_0-rmse:40.74782	validation_0-deephit_loss1_pycox:193.71186
# [1804]	validation_0-rmse:40.74785	validation_0-deephit_loss1_pycox:193.69872
# [1805]	validation_0-rmse:40.74787	validation_0-deephit_loss1_pycox:193.68443
# [1806]	validation_0-rmse:40.74788	validation_0-deephit_loss1_pycox:193.67166
# [1807]	validation_0-rmse:40.74787	validation_0-deephit_loss1_pycox:193.65738
# [1808]	validation_0-rmse:40.74793	validation_0-deephit_loss1_pycox:193.64472
# [1809]	validation_0-rmse:40.74791	validation_0-deephit_loss1_pycox:193.63040
# [1810]	validation_0-rmse:40.74794	validation_0-deephit_loss1_pycox:193.61693
# [1811]	validation_0-rmse:40.74794	validation_0-deephit_loss1_pycox:193.60274
# [1812]	validation_0-rmse:40.74794	validation_0-deephit_loss1_pycox:193.58922
# [1813]	validation_0-rmse:40.74797	validation_0-deephit_loss1_pycox:193.57582
# [1814]	validation_0-rmse:40.74799	validation_0-deephit_loss1_pycox:193.56264
# [1815]	validation_0-rmse:40.74799	validation_0-deephit_loss1_pycox:193.54863
# [1816]	validation_0-rmse:40.74803	validation_0-deephit_loss1_pycox:193.53530
# [1817]	validation_0-rmse:40.74804	validation_0-deephit_loss1_pycox:193.52087
# [1818]	validation_0-rmse:40.74806	validation_0-deephit_loss1_pycox:193.50765
# [1819]	validation_0-rmse:40.74804	validation_0-deephit_loss1_pycox:193.49414
# [1820]	validation_0-rmse:40.74808	validation_0-deephit_loss1_pycox:193.48048
# [1821]	validation_0-rmse:40.74810	validation_0-deephit_loss1_pycox:193.46684
# [1822]	validation_0-rmse:40.74815	validation_0-deephit_loss1_pycox:193.45288
# [1823]	validation_0-rmse:40.74813	validation_0-deephit_loss1_pycox:193.43944
# [1824]	validation_0-rmse:40.74815	validation_0-deephit_loss1_pycox:193.42547
# [1825]	validation_0-rmse:40.74815	validation_0-deephit_loss1_pycox:193.41137
# [1826]	validation_0-rmse:40.74817	validation_0-deephit_loss1_pycox:193.39836
# [1827]	validation_0-rmse:40.74819	validation_0-deephit_loss1_pycox:193.38433
# [1828]	validation_0-rmse:40.74816	validation_0-deephit_loss1_pycox:193.37168
# [1829]	validation_0-rmse:40.74818	validation_0-deephit_loss1_pycox:193.35830
# [1830]	validation_0-rmse:40.74818	validation_0-deephit_loss1_pycox:193.34382
# [1831]	validation_0-rmse:40.74821	validation_0-deephit_loss1_pycox:193.32931
# [1832]	validation_0-rmse:40.74820	validation_0-deephit_loss1_pycox:193.31473
# [1833]	validation_0-rmse:40.74821	validation_0-deephit_loss1_pycox:193.30200
# [1834]	validation_0-rmse:40.74823	validation_0-deephit_loss1_pycox:193.28788
# [1835]	validation_0-rmse:40.74825	validation_0-deephit_loss1_pycox:193.27494
# [1836]	validation_0-rmse:40.74827	validation_0-deephit_loss1_pycox:193.26008
# [1837]	validation_0-rmse:40.74828	validation_0-deephit_loss1_pycox:193.24782
# [1838]	validation_0-rmse:40.74829	validation_0-deephit_loss1_pycox:193.23435
# [1839]	validation_0-rmse:40.74832	validation_0-deephit_loss1_pycox:193.22048
# [1840]	validation_0-rmse:40.74831	validation_0-deephit_loss1_pycox:193.20719
# [1841]	validation_0-rmse:40.74834	validation_0-deephit_loss1_pycox:193.19417
# [1842]	validation_0-rmse:40.74833	validation_0-deephit_loss1_pycox:193.18069
# [1843]	validation_0-rmse:40.74838	validation_0-deephit_loss1_pycox:193.16770
# [1844]	validation_0-rmse:40.74837	validation_0-deephit_loss1_pycox:193.15423
# [1845]	validation_0-rmse:40.74837	validation_0-deephit_loss1_pycox:193.14067
# [1846]	validation_0-rmse:40.74837	validation_0-deephit_loss1_pycox:193.12694
# [1847]	validation_0-rmse:40.74838	validation_0-deephit_loss1_pycox:193.11339
# [1848]	validation_0-rmse:40.74838	validation_0-deephit_loss1_pycox:193.10026
# [1849]	validation_0-rmse:40.74840	validation_0-deephit_loss1_pycox:193.08731
# [1850]	validation_0-rmse:40.74842	validation_0-deephit_loss1_pycox:193.07306
# [1851]	validation_0-rmse:40.74844	validation_0-deephit_loss1_pycox:193.06002
# [1852]	validation_0-rmse:40.74846	validation_0-deephit_loss1_pycox:193.04736
# [1853]	validation_0-rmse:40.74847	validation_0-deephit_loss1_pycox:193.03425
# [1854]	validation_0-rmse:40.74845	validation_0-deephit_loss1_pycox:193.02133
# [1855]	validation_0-rmse:40.74849	validation_0-deephit_loss1_pycox:193.00782
# [1856]	validation_0-rmse:40.74849	validation_0-deephit_loss1_pycox:192.99462
# [1857]	validation_0-rmse:40.74852	validation_0-deephit_loss1_pycox:192.98195
# [1858]	validation_0-rmse:40.74852	validation_0-deephit_loss1_pycox:192.96847
# [1859]	validation_0-rmse:40.74855	validation_0-deephit_loss1_pycox:192.95435
# [1860]	validation_0-rmse:40.74855	validation_0-deephit_loss1_pycox:192.94097
# [1861]	validation_0-rmse:40.74854	validation_0-deephit_loss1_pycox:192.92833
# [1862]	validation_0-rmse:40.74855	validation_0-deephit_loss1_pycox:192.91518
# [1863]	validation_0-rmse:40.74858	validation_0-deephit_loss1_pycox:192.90077
# [1864]	validation_0-rmse:40.74855	validation_0-deephit_loss1_pycox:192.88703
# [1865]	validation_0-rmse:40.74858	validation_0-deephit_loss1_pycox:192.87341
# [1866]	validation_0-rmse:40.74855	validation_0-deephit_loss1_pycox:192.86094
# [1867]	validation_0-rmse:40.74860	validation_0-deephit_loss1_pycox:192.84852
# [1868]	validation_0-rmse:40.74859	validation_0-deephit_loss1_pycox:192.83496
# [1869]	validation_0-rmse:40.74861	validation_0-deephit_loss1_pycox:192.82261
# [1870]	validation_0-rmse:40.74862	validation_0-deephit_loss1_pycox:192.80940
# [1871]	validation_0-rmse:40.74867	validation_0-deephit_loss1_pycox:192.79581
# [1872]	validation_0-rmse:40.74867	validation_0-deephit_loss1_pycox:192.78271
# [1873]	validation_0-rmse:40.74864	validation_0-deephit_loss1_pycox:192.77075
# [1874]	validation_0-rmse:40.74866	validation_0-deephit_loss1_pycox:192.75660
# [1875]	validation_0-rmse:40.74868	validation_0-deephit_loss1_pycox:192.74350
# [1876]	validation_0-rmse:40.74869	validation_0-deephit_loss1_pycox:192.73092
# [1877]	validation_0-rmse:40.74870	validation_0-deephit_loss1_pycox:192.71738
# [1878]	validation_0-rmse:40.74873	validation_0-deephit_loss1_pycox:192.70485
# [1879]	validation_0-rmse:40.74871	validation_0-deephit_loss1_pycox:192.69079
# [1880]	validation_0-rmse:40.74875	validation_0-deephit_loss1_pycox:192.67832
# [1881]	validation_0-rmse:40.74872	validation_0-deephit_loss1_pycox:192.66543
# [1882]	validation_0-rmse:40.74877	validation_0-deephit_loss1_pycox:192.65375
# [1883]	validation_0-rmse:40.74879	validation_0-deephit_loss1_pycox:192.64070
# [1884]	validation_0-rmse:40.74879	validation_0-deephit_loss1_pycox:192.62783
# [1885]	validation_0-rmse:40.74879	validation_0-deephit_loss1_pycox:192.61455
# [1886]	validation_0-rmse:40.74881	validation_0-deephit_loss1_pycox:192.60199
# [1887]	validation_0-rmse:40.74883	validation_0-deephit_loss1_pycox:192.58871
# [1888]	validation_0-rmse:40.74883	validation_0-deephit_loss1_pycox:192.57543
# [1889]	validation_0-rmse:40.74884	validation_0-deephit_loss1_pycox:192.56272
# [1890]	validation_0-rmse:40.74884	validation_0-deephit_loss1_pycox:192.55054
# [1891]	validation_0-rmse:40.74885	validation_0-deephit_loss1_pycox:192.53762
# [1892]	validation_0-rmse:40.74887	validation_0-deephit_loss1_pycox:192.52534
# [1893]	validation_0-rmse:40.74889	validation_0-deephit_loss1_pycox:192.51258
# [1894]	validation_0-rmse:40.74890	validation_0-deephit_loss1_pycox:192.50000
# [1895]	validation_0-rmse:40.74890	validation_0-deephit_loss1_pycox:192.48745
# [1896]	validation_0-rmse:40.74891	validation_0-deephit_loss1_pycox:192.47484
# [1897]	validation_0-rmse:40.74893	validation_0-deephit_loss1_pycox:192.46213
# [1898]	validation_0-rmse:40.74895	validation_0-deephit_loss1_pycox:192.44949
# [1899]	validation_0-rmse:40.74899	validation_0-deephit_loss1_pycox:192.43745
# [1900]	validation_0-rmse:40.74898	validation_0-deephit_loss1_pycox:192.42404
# [1901]	validation_0-rmse:40.74899	validation_0-deephit_loss1_pycox:192.41086
# [1902]	validation_0-rmse:40.74898	validation_0-deephit_loss1_pycox:192.39846
# [1903]	validation_0-rmse:40.74901	validation_0-deephit_loss1_pycox:192.38518
# [1904]	validation_0-rmse:40.74901	validation_0-deephit_loss1_pycox:192.37281
# [1905]	validation_0-rmse:40.74904	validation_0-deephit_loss1_pycox:192.35985
# [1906]	validation_0-rmse:40.74904	validation_0-deephit_loss1_pycox:192.34705
# [1907]	validation_0-rmse:40.74906	validation_0-deephit_loss1_pycox:192.33455
# [1908]	validation_0-rmse:40.74905	validation_0-deephit_loss1_pycox:192.32244
# [1909]	validation_0-rmse:40.74909	validation_0-deephit_loss1_pycox:192.30932
# [1910]	validation_0-rmse:40.74908	validation_0-deephit_loss1_pycox:192.29751
# [1911]	validation_0-rmse:40.74912	validation_0-deephit_loss1_pycox:192.28493
# [1912]	validation_0-rmse:40.74909	validation_0-deephit_loss1_pycox:192.27221
# [1913]	validation_0-rmse:40.74913	validation_0-deephit_loss1_pycox:192.26014
# [1914]	validation_0-rmse:40.74911	validation_0-deephit_loss1_pycox:192.24656
# [1915]	validation_0-rmse:40.74916	validation_0-deephit_loss1_pycox:192.23294
# [1916]	validation_0-rmse:40.74914	validation_0-deephit_loss1_pycox:192.22035
# [1917]	validation_0-rmse:40.74918	validation_0-deephit_loss1_pycox:192.20798
# [1918]	validation_0-rmse:40.74917	validation_0-deephit_loss1_pycox:192.19633
# [1919]	validation_0-rmse:40.74921	validation_0-deephit_loss1_pycox:192.18227
# [1920]	validation_0-rmse:40.74921	validation_0-deephit_loss1_pycox:192.17009
# [1921]	validation_0-rmse:40.74923	validation_0-deephit_loss1_pycox:192.15661
# [1922]	validation_0-rmse:40.74921	validation_0-deephit_loss1_pycox:192.14481
# [1923]	validation_0-rmse:40.74927	validation_0-deephit_loss1_pycox:192.13144
# [1924]	validation_0-rmse:40.74926	validation_0-deephit_loss1_pycox:192.11964
# [1925]	validation_0-rmse:40.74930	validation_0-deephit_loss1_pycox:192.10692
# [1926]	validation_0-rmse:40.74926	validation_0-deephit_loss1_pycox:192.09376
# [1927]	validation_0-rmse:40.74930	validation_0-deephit_loss1_pycox:192.08151
# [1928]	validation_0-rmse:40.74931	validation_0-deephit_loss1_pycox:192.06906
# [1929]	validation_0-rmse:40.74935	validation_0-deephit_loss1_pycox:192.05673
# [1930]	validation_0-rmse:40.74934	validation_0-deephit_loss1_pycox:192.04513
# [1931]	validation_0-rmse:40.74936	validation_0-deephit_loss1_pycox:192.03182
# [1932]	validation_0-rmse:40.74936	validation_0-deephit_loss1_pycox:192.02009
# [1933]	validation_0-rmse:40.74939	validation_0-deephit_loss1_pycox:192.00708
# [1934]	validation_0-rmse:40.74938	validation_0-deephit_loss1_pycox:191.99523
# [1935]	validation_0-rmse:40.74940	validation_0-deephit_loss1_pycox:191.98225
# [1936]	validation_0-rmse:40.74941	validation_0-deephit_loss1_pycox:191.97061
# [1937]	validation_0-rmse:40.74942	validation_0-deephit_loss1_pycox:191.95740
# [1938]	validation_0-rmse:40.74944	validation_0-deephit_loss1_pycox:191.94553
# [1939]	validation_0-rmse:40.74946	validation_0-deephit_loss1_pycox:191.93291
# [1940]	validation_0-rmse:40.74948	validation_0-deephit_loss1_pycox:191.91954
# [1941]	validation_0-rmse:40.74950	validation_0-deephit_loss1_pycox:191.90792
# [1942]	validation_0-rmse:40.74947	validation_0-deephit_loss1_pycox:191.89556
# [1943]	validation_0-rmse:40.74950	validation_0-deephit_loss1_pycox:191.88351
# [1944]	validation_0-rmse:40.74950	validation_0-deephit_loss1_pycox:191.87112
# [1945]	validation_0-rmse:40.74953	validation_0-deephit_loss1_pycox:191.85893
# [1946]	validation_0-rmse:40.74953	validation_0-deephit_loss1_pycox:191.84648
# [1947]	validation_0-rmse:40.74954	validation_0-deephit_loss1_pycox:191.83467
# [1948]	validation_0-rmse:40.74954	validation_0-deephit_loss1_pycox:191.82253
# [1949]	validation_0-rmse:40.74957	validation_0-deephit_loss1_pycox:191.81082
# [1950]	validation_0-rmse:40.74954	validation_0-deephit_loss1_pycox:191.79890
# [1951]	validation_0-rmse:40.74957	validation_0-deephit_loss1_pycox:191.78665
# [1952]	validation_0-rmse:40.74959	validation_0-deephit_loss1_pycox:191.77427
# [1953]	validation_0-rmse:40.74961	validation_0-deephit_loss1_pycox:191.76215
# [1954]	validation_0-rmse:40.74963	validation_0-deephit_loss1_pycox:191.75051
# [1955]	validation_0-rmse:40.74962	validation_0-deephit_loss1_pycox:191.73825
# [1956]	validation_0-rmse:40.74963	validation_0-deephit_loss1_pycox:191.72605
# [1957]	validation_0-rmse:40.74963	validation_0-deephit_loss1_pycox:191.71336
# [1958]	validation_0-rmse:40.74964	validation_0-deephit_loss1_pycox:191.70140
# [1959]	validation_0-rmse:40.74965	validation_0-deephit_loss1_pycox:191.68923
# [1960]	validation_0-rmse:40.74968	validation_0-deephit_loss1_pycox:191.67736
# [1961]	validation_0-rmse:40.74968	validation_0-deephit_loss1_pycox:191.66506
# [1962]	validation_0-rmse:40.74970	validation_0-deephit_loss1_pycox:191.65349
# [1963]	validation_0-rmse:40.74972	validation_0-deephit_loss1_pycox:191.64039
# [1964]	validation_0-rmse:40.74970	validation_0-deephit_loss1_pycox:191.62879
# [1965]	validation_0-rmse:40.74973	validation_0-deephit_loss1_pycox:191.61614
# [1966]	validation_0-rmse:40.74971	validation_0-deephit_loss1_pycox:191.60376
# [1967]	validation_0-rmse:40.74975	validation_0-deephit_loss1_pycox:191.59170
# [1968]	validation_0-rmse:40.74974	validation_0-deephit_loss1_pycox:191.58008
# [1969]	validation_0-rmse:40.74975	validation_0-deephit_loss1_pycox:191.56813
# [1970]	validation_0-rmse:40.74975	validation_0-deephit_loss1_pycox:191.55574
# [1971]	validation_0-rmse:40.74977	validation_0-deephit_loss1_pycox:191.54283
# [1972]	validation_0-rmse:40.74979	validation_0-deephit_loss1_pycox:191.53164
# [1973]	validation_0-rmse:40.74978	validation_0-deephit_loss1_pycox:191.51930
# [1974]	validation_0-rmse:40.74981	validation_0-deephit_loss1_pycox:191.50793
# [1975]	validation_0-rmse:40.74982	validation_0-deephit_loss1_pycox:191.49511
# [1976]	validation_0-rmse:40.74981	validation_0-deephit_loss1_pycox:191.48377
# [1977]	validation_0-rmse:40.74985	validation_0-deephit_loss1_pycox:191.47109
# [1978]	validation_0-rmse:40.74986	validation_0-deephit_loss1_pycox:191.45944
# [1979]	validation_0-rmse:40.74986	validation_0-deephit_loss1_pycox:191.44683
# [1980]	validation_0-rmse:40.74986	validation_0-deephit_loss1_pycox:191.43469
# [1981]	validation_0-rmse:40.74990	validation_0-deephit_loss1_pycox:191.42299
# [1982]	validation_0-rmse:40.74989	validation_0-deephit_loss1_pycox:191.41062
# [1983]	validation_0-rmse:40.74990	validation_0-deephit_loss1_pycox:191.39893
# [1984]	validation_0-rmse:40.74990	validation_0-deephit_loss1_pycox:191.38705
# [1985]	validation_0-rmse:40.74993	validation_0-deephit_loss1_pycox:191.37584
# [1986]	validation_0-rmse:40.74994	validation_0-deephit_loss1_pycox:191.36358
# [1987]	validation_0-rmse:40.74999	validation_0-deephit_loss1_pycox:191.35233
# [1988]	validation_0-rmse:40.74997	validation_0-deephit_loss1_pycox:191.34004
# [1989]	validation_0-rmse:40.75002	validation_0-deephit_loss1_pycox:191.32871
# [1990]	validation_0-rmse:40.74999	validation_0-deephit_loss1_pycox:191.31736
# [1991]	validation_0-rmse:40.75006	validation_0-deephit_loss1_pycox:191.30498
# [1992]	validation_0-rmse:40.75004	validation_0-deephit_loss1_pycox:191.29367
# [1993]	validation_0-rmse:40.75006	validation_0-deephit_loss1_pycox:191.28142
# [1994]	validation_0-rmse:40.75005	validation_0-deephit_loss1_pycox:191.27072
# [1995]	validation_0-rmse:40.75005	validation_0-deephit_loss1_pycox:191.25835
# [1996]	validation_0-rmse:40.75006	validation_0-deephit_loss1_pycox:191.24746
# [1997]	validation_0-rmse:40.75009	validation_0-deephit_loss1_pycox:191.23472
# [1998]	validation_0-rmse:40.75008	validation_0-deephit_loss1_pycox:191.22383
# [1999]	validation_0-rmse:40.75009	validation_0-deephit_loss1_pycox:191.21140
# XGBSurv(base_score=0.3, booster=None, callbacks=None, colsample_bylevel=None,
#         colsample_bynode=None, colsample_bytree=None,
#         disable_default_metric=True, early_stopping_rounds=None,
#         enable_categorical=False,
#         eval_metric=<function deephit_loss1_pycox at 0x7ff659a4b1c0>,
#         feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#         importance_type=None, interaction_constraints=None, learning_rate=0.1,
#         max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#         max_delta_step=None, max_depth=None, max_leaves=None,
#         min_child_weight=None, missing=nan, monotone_constraints=None,
#         n_estimators=2000, n_jobs=None, num_parallel_tree=None,
#         objective=<function deephit_pycox_objective at 0x7ff659a4b370>, ...)

# %%
target.shape
# Out:
# (1903,)

# %% [markdown]
# The model can be saved like below. Note that objective and eval_metric are not saved.

# %%
model.save_model("deephit_model.json")
# Out:
# /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py:761: UserWarning: objective is not saved in Scikit-Learn meta.
#   warnings.warn(
# /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py:761: UserWarning: eval_metric is not saved in Scikit-Learn meta.
#   warnings.warn(
# /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py:761: UserWarning: y is not saved in Scikit-Learn meta.
#   warnings.warn(
# /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py:761: UserWarning: X is not saved in Scikit-Learn meta.
#   warnings.warn(

# %% [markdown]
# ## Predict & Evaluate

# %%
import sys
# !conda install --yes --prefix {sys.prefix} -c conda-forge pycox
#from sksurv.metrics import concordance_index_censored
from xgbsurv.evaluation import cindex_censored, ibs
from pycox.evaluation import EvalSurv
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
import pandas as pd
preds_test = model.predict(X_test, output_margin=True, validate_features=False)
preds_train = model.predict(X_train, output_margin=True, validate_features=False)
preds_test.shape
# Out:
# (476, 90)

# %%
preds_test.T.shape[1]
cols = [str(i) for i in range(preds_test.T.shape[1])]
surv = pd.DataFrame(data=preds_test.T, columns=cols)
surv
# Out:
#            0         1         2         3         4         5          6  \
# 0  -6.890857 -6.890857 -6.796816 -7.929599 -6.756095 -8.410784  -5.927662
# 1  -9.895530 -5.321617 -4.261624 -6.743558 -8.661213 -8.760814  -7.653399
# 2  -7.455766 -7.514219 -6.992144 -5.912518 -6.457172 -6.607211 -10.417833
# 3  -8.312634 -7.200647 -6.059400 -1.116745 -6.596586 -7.956530  -9.803360
# 4  -5.341692 -6.748853 -6.461722 -4.583495 -5.260877 -7.094065  -6.592380
# ..       ...       ...       ...       ...       ...       ...        ...
# 85 -4.282473 -4.282473 -4.282473 -4.282473 -4.282473 -4.282473  -4.282473
# 86 -4.281430 -4.281430 -4.281430 -4.281430 -4.281430 -4.281430  -4.281430
# 87 -4.280212 -4.280212 -4.280212 -4.280212 -4.280212 -4.280212  -4.280212
# 88 -5.048205 -4.760234 -4.113268 -4.006267 -3.097589 -4.760234  -5.115020
# 89 -4.425764 -4.425764 -3.279652 -3.372341 -4.474356 -4.425764  -3.433770
#
#            7         8          9  ...       466       467        468  \
# 0  -4.743150 -3.418882  -6.970855  ... -6.670851 -6.286502  -6.499992
# 1  -5.949537 -5.176513 -10.898017  ... -9.545039 -9.908096 -10.066805
# 2  -3.309223 -4.802322 -10.334987  ... -7.551781 -8.474930  -8.762161
# 3   1.702691 -2.690145  -7.607093  ... -4.865688 -8.878933  -9.834019
# 4  -1.273125 -2.958032  -6.233868  ... -8.360245 -3.939768 -10.532650
# ..       ...       ...        ...  ...       ...       ...        ...
# 85 -4.282473 -4.282473  -4.282473  ... -4.282473 -4.282473  -4.282473
# 86 -4.281430 -4.281430  -4.281430  ... -4.281430 -4.281430  -4.281430
# 87 -4.280212 -4.280212  -4.280212  ... -4.280212 -4.280212  -4.280212
# 88 -4.006267 -2.590357  -4.641217  ... -5.059464 -5.115020  -5.228909
# 89 -4.216809 -5.067224  -4.474356  ... -3.887604 -4.425764  -5.221342
#
#           469       470        471       472       473       474        475
# 0   -8.502278 -6.536090  -7.105617 -6.062424 -6.286502 -6.199988  -7.886333
# 1  -10.563773 -9.475101 -10.375940 -7.424945 -8.119374 -6.769309 -11.337688
# 2   -9.120632 -7.478767  -8.521143 -8.420971 -8.639685 -7.519887  -9.255885
# 3   -9.899033 -7.143303  -3.682276 -6.255867 -8.831538 -7.086382  -9.835267
# 4   -9.529613 -5.885591 -10.297590 -7.586340 -8.177292 -7.548578  -8.055818
# ..        ...       ...        ...       ...       ...       ...        ...
# 85  -4.282473 -4.282473  -4.282473 -4.282473 -4.282473 -4.282473  -4.282473
# 86  -4.281430 -4.281430  -4.281430 -4.281430 -4.281430 -4.281430  -4.281430
# 87  -4.280212 -4.280212  -4.280212 -4.280212 -4.280212 -4.280212  -4.280212
# 88  -5.228909 -4.662936  -5.228909 -4.945575 -5.115020 -5.228909  -5.228909
# 89  -5.067224 -4.135708  -5.067224 -2.578971 -4.827262 -3.758410  -4.135708
#
# [90 rows x 476 columns]

# %%
time, event = transform_back(y_test)
ev = EvalSurv(surv, time, event, censor_surv='km')
ev.concordance_td('antolini')
# Out:
# /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/pycox/evaluation/eval_surv.py:36: FutureWarning: is_monotonic is deprecated and will be removed in a future version. Use is_monotonic_increasing instead.
#   assert pd.Series(self.index_surv).is_monotonic
# 0.4134386538189397

# %%
cols = [str(i) for i in range(preds_train.T.shape[1])]
surv = pd.DataFrame(data=preds_train.T, columns=cols)
time, event = transform_back(y_train[:,0])
ev = EvalSurv(surv, time, event, censor_surv='km')
ev.concordance_td('antolini')
# Out:
# /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/pycox/evaluation/eval_surv.py:36: FutureWarning: is_monotonic is deprecated and will be removed in a future version. Use is_monotonic_increasing instead.
#   assert pd.Series(self.index_surv).is_monotonic
# 0.42011173661716894

# %%
event
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
surv.to_csv('surv_data.csv', index=False)

# %%
# # XGBsurv benchmark
# from xgbsurv.datasets import load_metabric
# from xgbsurv import XGBSurv
# from xgbsurv.evaluation import cindex_censored, ibs
# import numpy as np
# import pandas as pd
# from scipy.stats import uniform as scuniform
# from scipy.stats import randint as scrandint
# from scipy.stats import loguniform as scloguniform 
# from sklearn.model_selection import RandomizedSearchCV, KFold, StratifiedKFold
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.datasets import load_iris
# from sklearn.metrics import make_scorer
# # import models
# from xgbsurv.models.breslow_final import breslow_likelihood
# from xgbsurv.models.efron_final import efron_likelihood
# from xgbsurv.models.cind_final import cind_loss
# from xgbsurv.models.deephit_pycox_final import deephit_loss1_pycox

# # set parameters
# n_outer_splits = 5
# n_inner_splits = 5
# rand_state = 42
# n_iter = 40
# n_iter_cind = 200
# early_stopping_rounds=10

# # Load dataset
# X, y = load_metabric(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=False)

# # deephit data adaptation
# n = len(np.unique(np.absolute(y)))
# y_deephit = np.tile(y, (n,1)).T



# # Define parameter grid for random forest classifier
# param_grid = {
# 'alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
# 'reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
# 'learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
# 'n_estimators':  scrandint(1,100), # corresponds to num_rounds
# 'gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
# 'colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
# 'colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
# 'colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
# 'max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
# 'max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
# 'min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
# 'subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
# }

# # Define stratified outer k-fold cross-validation
# #outer_cv = StratifiedKFold(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)


# # Define stratified inner k-fold cross-validation
# class CustomSplit(StratifiedKFold):
#     def __init__(self, n_splits=5, shuffle=True, random_state=None):
#         super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)

#     def split(self, X, y, groups=None):
#         try:
#             if y.shape[1]>1:
#                 y = y[:,0]
#         except:
#             pass
#         bins = np.sign(y)
#         return super().split(X, bins, groups=groups)

#     def get_n_splits(self, X=None, y=None, groups=None):
#         return self.n_splits

# outer_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)
# inner_custom_cv = CustomSplit(n_splits=n_outer_splits, shuffle=True, random_state=rand_state)




# # Define models to apply
# loss_functions = ['breslow_loss', 'efron_loss', 'cind_loss', 'deephit_loss', 'aft_loss']
# objective_functions = ['breslow_objective', 'efron_objective', 'cind_objective', 'deephit_objective', 'aft_objective']
# scoring_functions = [breslow_likelihood, efron_likelihood, cind_loss, deephit_loss1_pycox]
# n_models = len(scoring_functions)

# # dict of outer scores
# outer_scores = {'breslow_loss':[], 'efron_loss':[], 'cind_loss':[], 'deephit_loss':[]} #, 'aft_loss':[]
# # Loop over models
# for model in range(n_models):
#     obj = objective_functions[model]
#     print('Current model being run:', obj)
#     # adapt for cind (learning rate should also be adapted)
#     if obj=='cind_objective':
#         n_iter = n_iter_cind
#     if obj=='deephit_objective':
#         y = y_deephit

#     # Define Scorer
#     scoring_function = make_scorer(scoring_functions[model], greater_is_better=False)
#     # Define custom cross-validation strategy
#     # custom_cv = custom_split(X, y)
#     # Define Model
#     estimator = XGBSurv(objective=objective_functions[model],eval_metric=loss_functions[model],
#                                             random_state=rand_state, disable_default_eval_metric=True,
#                                             early_stopping_rounds=early_stopping_rounds)
    
    
#     # Define RandomizedSearchCV object
#     rs = RandomizedSearchCV(estimator, param_grid, scoring = scoring_function, n_jobs=-1, 
#                             cv=inner_custom_cv, n_iter=n_iter, refit=True)

#     # loop over outer split
#     for train_index, test_index in outer_custom_cv.split(X, y):
#         # Split data into training and testing sets for outer fold
#         X_train, X_test = X[train_index], X[test_index]
#         y_train, y_test = y[train_index], y[test_index]
#         # Early stopping within model
#         rs.fit(X_train, y_train, eval_test_size=0.1)
#         preds_test = rs.best_estimator_.predict(X_test, output_margin = True)
#         score = cindex_censored(y_test, preds_test)
#         print('cindex score:', score)
#         outer_scores[loss_functions[model]] += [score]

# df = pd.DataFrame(outer_scores)
# df.columns = ['breslow', 'efron', 'cind', 'deephit']
# df.to_csv('benchmarking_results.csv', index=False)
# print(df.describe())


# # Print the mean and standard deviation of the outer scores
# print(f"Nested CV score: {np.mean(np.array(df).T, axis=1)} (+/- {np.std(np.array(df).T, axis=1)})")
