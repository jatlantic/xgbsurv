# %% [markdown]
# # Introduction to the xgbsurv package
#
# This notebook demonstrates how to use `xgbsurv` using cross validation from scikit-learn. It structured by the following steps:
#
# - Load data
# - Load model
# - Fit model
# - Predict and evaluate model
#
# The syntax conveniently follows that of sklearn.

# %%
from xgbsurv.datasets import load_metabric
from xgbsurv.models.breslow_final import breslow_likelihood
from xgbsurv import XGBSurv
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import make_scorer
#from sksurv.metrics import concordance_index_censored
from xgbsurv.evaluation import cindex_censored, ibs
import numpy as np
import pandas as pd
from scipy.stats import uniform as scuniform
from scipy.stats import randint as scrandint
from scipy.stats import loguniform as scloguniform 
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load Data

# %%
data, target = load_metabric(path="/Users/JUSC/Documents/xgbsurv/xgbsurv/datasets/data/", as_frame=False)
# stratification on event type
target_sign = np.sign(target)
X_train, X_test, y_train, y_test = train_test_split(data, target, stratify=target_sign)

# %%
# Set Hyperparameter Space

param_grid = {
'alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'n_estimators':  scrandint(1,100), # corresponds to num_rounds
'gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
}

# %% [markdown]
# ## Load Model - Cross Validation without Early Stopping

# %%
# xgbsurv_pipe = Pipeline(steps=[
#                      ('xgbsurv',XGBSurv(objective="breslow_objective",
#                                              eval_metric="breslow_loss",
#                                              random_state=8, disable_default_eval_metric=True ))    
#                                              ])
model = XGBSurv(objective="breslow_objective",eval_metric="breslow_loss",
                                             random_state=8, disable_default_eval_metric=True )
#scoring function form of score_func(y, y_pred)
# -1 means using all processors.
grid_search = RandomizedSearchCV(model, param_grid, scoring = make_scorer(breslow_likelihood, greater_is_better=False), n_jobs=-1, cv=10, n_iter=40)

# %% [markdown]
# ## Fit Model

# %%
grid_result = grid_search.fit(X_train, y_train)

# %%
pd.DataFrame(grid_result.cv_results_).describe()
# Out:
#        mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# count      40.000000     40.000000        40.000000       40.000000
# mean        0.084516      0.019231         0.014207        0.005427
# std         0.177165      0.068524         0.071371        0.029056
# min         0.007340      0.001709         0.000470        0.000014
# 25%         0.028706      0.003431         0.000664        0.000057
# 50%         0.051478      0.007024         0.000761        0.000266
# 75%         0.081724      0.010723         0.000930        0.000467
# max         1.141923      0.439931         0.445161        0.183568
#
#        split0_test_score  split1_test_score  split2_test_score  \
# count          40.000000          40.000000          40.000000
# mean           -4.639719          -4.863800          -4.618429
# std             2.562232           2.553611           1.667517
# min           -18.705285         -16.372307         -11.849984
# 25%            -3.907049          -4.079060          -4.104810
# 50%            -3.897675          -3.980760          -4.029819
# 75%            -3.880365          -3.973612          -4.019735
# max            -3.846123          -3.947119          -3.989037
#
#        split3_test_score  split4_test_score  split5_test_score  \
# count          40.000000          40.000000          40.000000
# mean           -4.805938          -4.623692          -4.872388
# std             2.275549           2.109226           2.485533
# min           -14.023804         -14.203815         -16.171601
# 25%            -4.043592          -3.932945          -4.143065
# 50%            -4.017801          -3.902086          -4.048994
# 75%            -3.999365          -3.893770          -4.044140
# max            -3.972305          -3.856155          -4.035679
#
#        split6_test_score  split7_test_score  split8_test_score  \
# count          40.000000          40.000000          40.000000
# mean           -4.969491          -4.843168          -4.785771
# std             2.831186           3.054724           2.441867
# min           -19.172601         -21.774283         -16.199625
# 25%            -4.083507          -4.028489          -4.011417
# 50%            -4.064031          -3.918900          -3.938437
# 75%            -4.043168          -3.915477          -3.933196
# max            -4.010262          -3.904973          -3.890445
#
#        split9_test_score  mean_test_score  std_test_score  rank_test_score
# count          40.000000        40.000000       40.000000        40.000000
# mean           -4.886405        -4.790880        0.262858        20.500000
# std             2.671290         2.414811        0.568778        11.690452
# min           -18.771677       -16.724498        0.048481         1.000000
# 25%            -4.067268        -4.032347        0.061554        10.750000
# 50%            -4.055156        -3.984901        0.063663        20.500000
# 75%            -4.035829        -3.973354        0.089442        30.250000
# max            -3.941707        -3.960424        2.787861        40.000000

# %% [markdown]
# ## Train Model with Best Parameters

# %%
best_params = grid_result.best_estimator_
p = best_params.get_params()
bmodel = XGBSurv(**p)
bmodel.fit(X_train, y_train)
# Out:
# XGBSurv(alpha=1.082917574169687e-05, base_score=None, booster=None,
#         callbacks=None, colsample_bylevel=0.37418233437337356,
#         colsample_bynode=0.7109561523463722,
#         colsample_bytree=0.9484803241991003, disable_default_eval_metric=True,
#         early_stopping_rounds=None, enable_categorical=False,
#         eval_metric=CPUDispatcher(<function breslow_likelihood at 0x7f89297445e0>),
#         fea...68, gpu_id=None,
#         grow_policy=None, importance_type=None, interaction_constraints=None,
#         learning_rate=0.03410321249363602, max_bin=None, max_cat_threshold=None,
#         max_cat_to_onehot=None, max_delta_step=8, max_depth=15, max_leaves=None,
#         min_child_weight=1.5906986613605163, missing=nan,
#         monotone_constraints=None, n_estimators=40, n_jobs=None,
#         num_parallel_tree=None, ...)

# %%
bmodel.save_model("best_cv_model.json")
# Out:
# /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py:761: UserWarning: objective is not saved in Scikit-Learn meta.
#   warnings.warn(
# /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py:761: UserWarning: eval_metric is not saved in Scikit-Learn meta.
#   warnings.warn(
# /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py:761: UserWarning: y is not saved in Scikit-Learn meta.
#   warnings.warn(
# /Users/JUSC/miniconda3/envs/xgbsurv/lib/python3.10/site-packages/xgboost/sklearn.py:761: UserWarning: X is not saved in Scikit-Learn meta.
#   warnings.warn(

# %% [markdown]
# ## Predict

# %%
preds_train = bmodel.predict(X_train, output_margin=True)
preds_test = bmodel.predict(X_test, output_margin=True)

# %% [markdown]
# ## Evaluation

# %%
# train
cindex_censored(y_train, preds_train)
# Out:
# 0.6649808870518152

# %%
# test
cindex_censored(y_test, preds_test)
# Out:
# 0.6278086707093073

# %% [markdown]
# ## Cross Validation with Early Stopping

# %%
# Set Hyperparameter Space

param_grid = {
'early_stopping_rounds': scrandint(1,20),
'alpha': scloguniform(1e-10,1),#[1e-10,1], # from hyp augmentation, L1 regularization
'reg_lambda': scloguniform(1e-10,1), #[1e-10,1], #alias l2_regularization, lambda in augmentation
'learning_rate': scloguniform(0.001,1), #[0.001,1], # assumed alias eta from augmentation,
'n_estimators':  scrandint(1,100), # corresponds to num_rounds
'gamma': scuniform(0.1,1-0.1),#[0.1,1], # minimum loss reduction required to make a further partition on a leaf node of the tree.
'colsample_bylevel': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation
'colsample_bynode': scuniform(0.1, 1-0.1), #[0.1,1], # from hyp augmentation, uniform(0.1,1),
'colsample_bytree': scuniform(0.5, 1-0.5),#[0.5,1], # from hyp augmentation, seems to exceed the bound, uniform(0.5,1)
'max_depth': scrandint(1,20),#[1,20], # from hyp augmentation
'max_delta_step': scrandint(0,10),#[0,10], # from hyp augmentation
'min_child_weight' : scloguniform(0.1,20-0.1),#[0.1,20], # from hyp augmentation
'subsample': scuniform(0.01,1-0.01),#[0.01,1], # from hyp augmentation
}

# %%
model = XGBSurv(objective="breslow_objective",eval_metric="breslow_loss",
                                             random_state=8, disable_default_eval_metric=True, early_stopping_rounds=10)
#scoring function form of score_func(y, y_pred)
# -1 means using all processors.
grid_search = RandomizedSearchCV(model, param_grid, scoring = make_scorer(breslow_likelihood, greater_is_better=False), n_jobs=-1, cv=10, n_iter=40)

grid_result = grid_search.fit(X_train, y_train, eval_test_size=0.1)
# Out:
# [0]	validation_0-breslow_likelihood:6.12623	validation_1-breslow_likelihood:3.73119
# [1]	validation_0-breslow_likelihood:6.12572	validation_1-breslow_likelihood:3.73102
# [2]	validation_0-breslow_likelihood:6.12510	validation_1-breslow_likelihood:3.73077
# [0]	validation_0-breslow_likelihood:6.08129	validation_1-breslow_likelihood:3.92599
# [3]	validation_0-breslow_likelihood:6.12467	validation_1-breslow_likelihood:3.73081
# [1]	validation_0-breslow_likelihood:6.08068	validation_1-breslow_likelihood:3.92578
# [2]	validation_0-breslow_likelihood:6.08065	validation_1-breslow_likelihood:3.92577
# [3]	validation_0-breslow_likelihood:6.08025	validation_1-breslow_likelihood:3.92555
# [4]	validation_0-breslow_likelihood:6.12409	validation_1-breslow_likelihood:3.73070
# [4]	validation_0-breslow_likelihood:6.07966	validation_1-breslow_likelihood:3.92531
# [5]	validation_0-breslow_likelihood:6.07944	validation_1-breslow_likelihood:3.92509
# [6]	validation_0-breslow_likelihood:6.07901	validation_1-breslow_likelihood:3.92494
# [5]	validation_0-breslow_likelihood:6.12354	validation_1-breslow_likelihood:3.73048
# [7]	validation_0-breslow_likelihood:6.07856	validation_1-breslow_likelihood:3.92480
# [8]	validation_0-breslow_likelihood:6.07789	validation_1-breslow_likelihood:3.92458
# [6]	validation_0-breslow_likelihood:6.12299	validation_1-breslow_likelihood:3.73049
# [0]	validation_0-breslow_likelihood:6.10705	validation_1-breslow_likelihood:3.76790
# [9]	validation_0-breslow_likelihood:6.07764	validation_1-breslow_likelihood:3.92440
# [7]	validation_0-breslow_likelihood:6.12230	validation_1-breslow_likelihood:3.73047
# [1]	validation_0-breslow_likelihood:6.10646	validation_1-breslow_likelihood:3.76754
# [8]	validation_0-breslow_likelihood:6.12174	validation_1-breslow_likelihood:3.73041
# [2]	validation_0-breslow_likelihood:6.10597	validation_1-breslow_likelihood:3.76728
# [10]	validation_0-breslow_likelihood:6.07711	validation_1-breslow_likelihood:3.92407
# [9]	validation_0-breslow_likelihood:6.12133	validation_1-breslow_likelihood:3.73041
# [3]	validation_0-breslow_likelihood:6.10548	validation_1-breslow_likelihood:3.76724
# [11]	validation_0-breslow_likelihood:6.07666	validation_1-breslow_likelihood:3.92388
# [10]	validation_0-breslow_likelihood:6.12079	validation_1-breslow_likelihood:3.73038
# [4]	validation_0-breslow_likelihood:6.10491	validation_1-breslow_likelihood:3.76715
# [12]	validation_0-breslow_likelihood:6.07616	validation_1-breslow_likelihood:3.92358
# [11]	validation_0-breslow_likelihood:6.12009	validation_1-breslow_likelihood:3.73027
# [5]	validation_0-breslow_likelihood:6.10440	validation_1-breslow_likelihood:3.76706
# [13]	validation_0-breslow_likelihood:6.07568	validation_1-breslow_likelihood:3.92358
# [12]	validation_0-breslow_likelihood:6.11965	validation_1-breslow_likelihood:3.73020
# [6]	validation_0-breslow_likelihood:6.10399	validation_1-breslow_likelihood:3.76691
# [13]	validation_0-breslow_likelihood:6.11930	validation_1-breslow_likelihood:3.72991
# [14]	validation_0-breslow_likelihood:6.07525	validation_1-breslow_likelihood:3.92325
# [7]	validation_0-breslow_likelihood:6.10339	validation_1-breslow_likelihood:3.76677
# [14]	validation_0-breslow_likelihood:6.11875	validation_1-breslow_likelihood:3.72956
# [15]	validation_0-breslow_likelihood:6.07493	validation_1-breslow_likelihood:3.92330
# [8]	validation_0-breslow_likelihood:6.10289	validation_1-breslow_likelihood:3.76665
# [16]	validation_0-breslow_likelihood:6.07435	validation_1-breslow_likelihood:3.92313
# [9]	validation_0-breslow_likelihood:6.10245	validation_1-breslow_likelihood:3.76652
# [15]	validation_0-breslow_likelihood:6.11825	validation_1-breslow_likelihood:3.72942
# [17]	validation_0-breslow_likelihood:6.07391	validation_1-breslow_likelihood:3.92278
# [10]	validation_0-breslow_likelihood:6.10194	validation_1-breslow_likelihood:3.76639
# [11]	validation_0-breslow_likelihood:6.10135	validation_1-breslow_likelihood:3.76607
# [0]	validation_0-breslow_likelihood:6.07169	validation_1-breslow_likelihood:3.95071
# [18]	validation_0-breslow_likelihood:6.07340	validation_1-breslow_likelihood:3.92293
# [12]	validation_0-breslow_likelihood:6.10095	validation_1-breslow_likelihood:3.76577
# [16]	validation_0-breslow_likelihood:6.11790	validation_1-breslow_likelihood:3.72932
# [13]	validation_0-breslow_likelihood:6.10068	validation_1-breslow_likelihood:3.76552
# [1]	validation_0-breslow_likelihood:6.06950	validation_1-breslow_likelihood:3.95079
# [14]	validation_0-breslow_likelihood:6.10013	validation_1-breslow_likelihood:3.76541
# [19]	validation_0-breslow_likelihood:6.07292	validation_1-breslow_likelihood:3.92258
# [15]	validation_0-breslow_likelihood:6.09969	validation_1-breslow_likelihood:3.76552
# [17]	validation_0-breslow_likelihood:6.11725	validation_1-breslow_likelihood:3.72906
# [16]	validation_0-breslow_likelihood:6.09905	validation_1-breslow_likelihood:3.76527
# [0]	validation_0-breslow_likelihood:6.05839	validation_1-breslow_likelihood:3.96840
# [17]	validation_0-breslow_likelihood:6.09842	validation_1-breslow_likelihood:3.76504
# [20]	validation_0-breslow_likelihood:6.07232	validation_1-breslow_likelihood:3.92256
# [18]	validation_0-breslow_likelihood:6.11676	validation_1-breslow_likelihood:3.72889
# [1]	validation_0-breslow_likelihood:6.05795	validation_1-breslow_likelihood:3.96845
# [19]	validation_0-breslow_likelihood:6.11601	validation_1-breslow_likelihood:3.72866
# [21]	validation_0-breslow_likelihood:6.07203	validation_1-breslow_likelihood:3.92252
# [2]	validation_0-breslow_likelihood:6.05792	validation_1-breslow_likelihood:3.96841
# [18]	validation_0-breslow_likelihood:6.09812	validation_1-breslow_likelihood:3.76497
# [20]	validation_0-breslow_likelihood:6.11547	validation_1-breslow_likelihood:3.72843
# [22]	validation_0-breslow_likelihood:6.07184	validation_1-breslow_likelihood:3.92234
# [3]	validation_0-breslow_likelihood:6.05740	validation_1-breslow_likelihood:3.96832
# [21]	validation_0-breslow_likelihood:6.11521	validation_1-breslow_likelihood:3.72829
# [23]	validation_0-breslow_likelihood:6.07137	validation_1-breslow_likelihood:3.92225
# [22]	validation_0-breslow_likelihood:6.11500	validation_1-breslow_likelihood:3.72816
# [4]	validation_0-breslow_likelihood:6.05691	validation_1-breslow_likelihood:3.96833
# [19]	validation_0-breslow_likelihood:6.09742	validation_1-breslow_likelihood:3.76490
# [24]	validation_0-breslow_likelihood:6.07094	validation_1-breslow_likelihood:3.92203
# [5]	validation_0-breslow_likelihood:6.05641	validation_1-breslow_likelihood:3.96847
# [23]	validation_0-breslow_likelihood:6.11451	validation_1-breslow_likelihood:3.72824
# [25]	validation_0-breslow_likelihood:6.07066	validation_1-breslow_likelihood:3.92194
# [6]	validation_0-breslow_likelihood:6.05600	validation_1-breslow_likelihood:3.96838
# [24]	validation_0-breslow_likelihood:6.11396	validation_1-breslow_likelihood:3.72829
# [26]	validation_0-breslow_likelihood:6.07036	validation_1-breslow_likelihood:3.92202
# [7]	validation_0-breslow_likelihood:6.05560	validation_1-breslow_likelihood:3.96812
# [25]	validation_0-breslow_likelihood:6.11351	validation_1-breslow_likelihood:3.72820
# [27]	validation_0-breslow_likelihood:6.07032	validation_1-breslow_likelihood:3.92201
# [20]	validation_0-breslow_likelihood:6.09702	validation_1-breslow_likelihood:3.76479
# [8]	validation_0-breslow_likelihood:6.05513	validation_1-breslow_likelihood:3.96802
# [26]	validation_0-breslow_likelihood:6.11313	validation_1-breslow_likelihood:3.72811
# [28]	validation_0-breslow_likelihood:6.06990	validation_1-breslow_likelihood:3.92183
# [9]	validation_0-breslow_likelihood:6.05486	validation_1-breslow_likelihood:3.96781
# [21]	validation_0-breslow_likelihood:6.09676	validation_1-breslow_likelihood:3.76461
# [29]	validation_0-breslow_likelihood:6.06968	validation_1-breslow_likelihood:3.92166
# [0]	validation_0-breslow_likelihood:6.08609	validation_1-breslow_likelihood:3.95342
# [10]	validation_0-breslow_likelihood:6.05437	validation_1-breslow_likelihood:3.96779
# [22]	validation_0-breslow_likelihood:6.09636	validation_1-breslow_likelihood:3.76453
# [30]	validation_0-breslow_likelihood:6.06909	validation_1-breslow_likelihood:3.92143
# [27]	validation_0-breslow_likelihood:6.11258	validation_1-breslow_likelihood:3.72789
# [31]	validation_0-breslow_likelihood:6.06888	validation_1-breslow_likelihood:3.92131
# [23]	validation_0-breslow_likelihood:6.09586	validation_1-breslow_likelihood:3.76439
# [11]	validation_0-breslow_likelihood:6.05386	validation_1-breslow_likelihood:3.96784
# [24]	validation_0-breslow_likelihood:6.09536	validation_1-breslow_likelihood:3.76410
# [28]	validation_0-breslow_likelihood:6.11225	validation_1-breslow_likelihood:3.72779
# [25]	validation_0-breslow_likelihood:6.09492	validation_1-breslow_likelihood:3.76394
# [29]	validation_0-breslow_likelihood:6.11163	validation_1-breslow_likelihood:3.72786
# [12]	validation_0-breslow_likelihood:6.05343	validation_1-breslow_likelihood:3.96775
# [1]	validation_0-breslow_likelihood:6.08550	validation_1-breslow_likelihood:3.95324
# [26]	validation_0-breslow_likelihood:6.09456	validation_1-breslow_likelihood:3.76380
# [30]	validation_0-breslow_likelihood:6.11115	validation_1-breslow_likelihood:3.72788
# [32]	validation_0-breslow_likelihood:6.06852	validation_1-breslow_likelihood:3.92112
# [27]	validation_0-breslow_likelihood:6.09397	validation_1-breslow_likelihood:3.76360
# [31]	validation_0-breslow_likelihood:6.11083	validation_1-breslow_likelihood:3.72790
# [2]	validation_0-breslow_likelihood:6.08547	validation_1-breslow_likelihood:3.95319
# [28]	validation_0-breslow_likelihood:6.09361	validation_1-breslow_likelihood:3.76349
# [32]	validation_0-breslow_likelihood:6.11039	validation_1-breslow_likelihood:3.72803
# [13]	validation_0-breslow_likelihood:6.05300	validation_1-breslow_likelihood:3.96759
# [33]	validation_0-breslow_likelihood:6.06801	validation_1-breslow_likelihood:3.92084
# [29]	validation_0-breslow_likelihood:6.09314	validation_1-breslow_likelihood:3.76333
# [33]	validation_0-breslow_likelihood:6.10995	validation_1-breslow_likelihood:3.72778
# [34]	validation_0-breslow_likelihood:6.06791	validation_1-breslow_likelihood:3.92081
# [3]	validation_0-breslow_likelihood:6.08501	validation_1-breslow_likelihood:3.95290
# [30]	validation_0-breslow_likelihood:6.09272	validation_1-breslow_likelihood:3.76323
# [34]	validation_0-breslow_likelihood:6.10948	validation_1-breslow_likelihood:3.72758
# [14]	validation_0-breslow_likelihood:6.05258	validation_1-breslow_likelihood:3.96771
# [4]	validation_0-breslow_likelihood:6.08453	validation_1-breslow_likelihood:3.95276
# [31]	validation_0-breslow_likelihood:6.09232	validation_1-breslow_likelihood:3.76311
# [35]	validation_0-breslow_likelihood:6.10874	validation_1-breslow_likelihood:3.72746
# [35]	validation_0-breslow_likelihood:6.06751	validation_1-breslow_likelihood:3.92065
# [15]	validation_0-breslow_likelihood:6.05225	validation_1-breslow_likelihood:3.96775
# [36]	validation_0-breslow_likelihood:6.10854	validation_1-breslow_likelihood:3.72747
# [32]	validation_0-breslow_likelihood:6.09180	validation_1-breslow_likelihood:3.76298
# [5]	validation_0-breslow_likelihood:6.08404	validation_1-breslow_likelihood:3.95269
# [37]	validation_0-breslow_likelihood:6.10797	validation_1-breslow_likelihood:3.72736
# [33]	validation_0-breslow_likelihood:6.09130	validation_1-breslow_likelihood:3.76273
# [36]	validation_0-breslow_likelihood:6.06712	validation_1-breslow_likelihood:3.92047
# [6]	validation_0-breslow_likelihood:6.08355	validation_1-breslow_likelihood:3.95249
# [38]	validation_0-breslow_likelihood:6.10753	validation_1-breslow_likelihood:3.72727
# [0]	validation_0-breslow_likelihood:6.07312	validation_1-breslow_likelihood:3.95204
# [34]	validation_0-breslow_likelihood:6.09090	validation_1-breslow_likelihood:3.76269
# [37]	validation_0-breslow_likelihood:6.06682	validation_1-breslow_likelihood:3.92044
# [7]	validation_0-breslow_likelihood:6.08317	validation_1-breslow_likelihood:3.95239
# [39]	validation_0-breslow_likelihood:6.10718	validation_1-breslow_likelihood:3.72721
# [16]	validation_0-breslow_likelihood:6.05166	validation_1-breslow_likelihood:3.96762
# [35]	validation_0-breslow_likelihood:6.09031	validation_1-breslow_likelihood:3.76237
# [40]	validation_0-breslow_likelihood:6.10688	validation_1-breslow_likelihood:3.72725
# [8]	validation_0-breslow_likelihood:6.08250	validation_1-breslow_likelihood:3.95242
# [36]	validation_0-breslow_likelihood:6.09007	validation_1-breslow_likelihood:3.76242
# [1]	validation_0-breslow_likelihood:6.07265	validation_1-breslow_likelihood:3.95170
# [38]	validation_0-breslow_likelihood:6.06642	validation_1-breslow_likelihood:3.92050
# [9]	validation_0-breslow_likelihood:6.08207	validation_1-breslow_likelihood:3.95220
# [41]	validation_0-breslow_likelihood:6.10649	validation_1-breslow_likelihood:3.72702
# [37]	validation_0-breslow_likelihood:6.08957	validation_1-breslow_likelihood:3.76202
# [2]	validation_0-breslow_likelihood:6.07260	validation_1-breslow_likelihood:3.95161
# [42]	validation_0-breslow_likelihood:6.10633	validation_1-breslow_likelihood:3.72711
# [38]	validation_0-breslow_likelihood:6.08908	validation_1-breslow_likelihood:3.76202
# [17]	validation_0-breslow_likelihood:6.05119	validation_1-breslow_likelihood:3.96774
# [43]	validation_0-breslow_likelihood:6.10586	validation_1-breslow_likelihood:3.72698
# [39]	validation_0-breslow_likelihood:6.08870	validation_1-breslow_likelihood:3.76193
# [3]	validation_0-breslow_likelihood:6.07217	validation_1-breslow_likelihood:3.95145
# [39]	validation_0-breslow_likelihood:6.06605	validation_1-breslow_likelihood:3.92055
# [40]	validation_0-breslow_likelihood:6.08838	validation_1-breslow_likelihood:3.76171
# [44]	validation_0-breslow_likelihood:6.10540	validation_1-breslow_likelihood:3.72688
# [18]	validation_0-breslow_likelihood:6.05075	validation_1-breslow_likelihood:3.96766
# [41]	validation_0-breslow_likelihood:6.08791	validation_1-breslow_likelihood:3.76157
# [45]	validation_0-breslow_likelihood:6.10481	validation_1-breslow_likelihood:3.72681
# [10]	validation_0-breslow_likelihood:6.08148	validation_1-breslow_likelihood:3.95222
# [4]	validation_0-breslow_likelihood:6.07172	validation_1-breslow_likelihood:3.95131
# [40]	validation_0-breslow_likelihood:6.06564	validation_1-breslow_likelihood:3.92020
# [42]	validation_0-breslow_likelihood:6.08762	validation_1-breslow_likelihood:3.76154
# [46]	validation_0-breslow_likelihood:6.10433	validation_1-breslow_likelihood:3.72665
# [19]	validation_0-breslow_likelihood:6.05026	validation_1-breslow_likelihood:3.96762
# [43]	validation_0-breslow_likelihood:6.08711	validation_1-breslow_likelihood:3.76134
# [47]	validation_0-breslow_likelihood:6.10368	validation_1-breslow_likelihood:3.72656
# [41]	validation_0-breslow_likelihood:6.06522	validation_1-breslow_likelihood:3.92026
# [5]	validation_0-breslow_likelihood:6.07117	validation_1-breslow_likelihood:3.95121
# [44]	validation_0-breslow_likelihood:6.08666	validation_1-breslow_likelihood:3.76102
# [20]	validation_0-breslow_likelihood:6.04981	validation_1-breslow_likelihood:3.96737
# [48]	validation_0-breslow_likelihood:6.10334	validation_1-breslow_likelihood:3.72639
# [11]	validation_0-breslow_likelihood:6.08095	validation_1-breslow_likelihood:3.95216
# [42]	validation_0-breslow_likelihood:6.06479	validation_1-breslow_likelihood:3.92015
# [49]	validation_0-breslow_likelihood:6.10309	validation_1-breslow_likelihood:3.72624
# [45]	validation_0-breslow_likelihood:6.08610	validation_1-breslow_likelihood:3.76081
# [21]	validation_0-breslow_likelihood:6.04951	validation_1-breslow_likelihood:3.96730
# [50]	validation_0-breslow_likelihood:6.10290	validation_1-breslow_likelihood:3.72620
# [46]	validation_0-breslow_likelihood:6.08565	validation_1-breslow_likelihood:3.76065
# [6]	validation_0-breslow_likelihood:6.07083	validation_1-breslow_likelihood:3.95096
# [22]	validation_0-breslow_likelihood:6.04929	validation_1-breslow_likelihood:3.96720
# [12]	validation_0-breslow_likelihood:6.08061	validation_1-breslow_likelihood:3.95196
# [51]	validation_0-breslow_likelihood:6.10221	validation_1-breslow_likelihood:3.72615
# [47]	validation_0-breslow_likelihood:6.08513	validation_1-breslow_likelihood:3.76066
# [23]	validation_0-breslow_likelihood:6.04889	validation_1-breslow_likelihood:3.96733
# [43]	validation_0-breslow_likelihood:6.06458	validation_1-breslow_likelihood:3.92008
# [0]	validation_0-breslow_likelihood:6.05700	validation_1-breslow_likelihood:3.96750
# [52]	validation_0-breslow_likelihood:6.10155	validation_1-breslow_likelihood:3.72622
# [48]	validation_0-breslow_likelihood:6.08463	validation_1-breslow_likelihood:3.76043
# [7]	validation_0-breslow_likelihood:6.07043	validation_1-breslow_likelihood:3.95056
# [13]	validation_0-breslow_likelihood:6.07993	validation_1-breslow_likelihood:3.95182
# [1]	validation_0-breslow_likelihood:6.05513	validation_1-breslow_likelihood:3.96766[24]	validation_0-breslow_likelihood:6.04849	validation_1-breslow_likelihood:3.96736
#
# [49]	validation_0-breslow_likelihood:6.08440	validation_1-breslow_likelihood:3.76038[53]	validation_0-breslow_likelihood:6.10113	validation_1-breslow_likelihood:3.72624
#
# [25]	validation_0-breslow_likelihood:6.04824	validation_1-breslow_likelihood:3.96719
# [54]	validation_0-breslow_likelihood:6.10082	validation_1-breslow_likelihood:3.72633
# [50]	validation_0-breslow_likelihood:6.08403	validation_1-breslow_likelihood:3.76024
# [14]	validation_0-breslow_likelihood:6.07943	validation_1-breslow_likelihood:3.95152
# [44]	validation_0-breslow_likelihood:6.06421	validation_1-breslow_likelihood:3.91982
# [0]	validation_0-breslow_likelihood:6.10518	validation_1-breslow_likelihood:3.72708
# [26]	validation_0-breslow_likelihood:6.04776	validation_1-breslow_likelihood:3.96721
# [55]	validation_0-breslow_likelihood:6.10027	validation_1-breslow_likelihood:3.72621
# [51]	validation_0-breslow_likelihood:6.08338	validation_1-breslow_likelihood:3.76012
# [8]	validation_0-breslow_likelihood:6.06983	validation_1-breslow_likelihood:3.95013
# [27]	validation_0-breslow_likelihood:6.04773	validation_1-breslow_likelihood:3.96719
# [56]	validation_0-breslow_likelihood:6.09974	validation_1-breslow_likelihood:3.72603
# [1]	validation_0-breslow_likelihood:6.10462	validation_1-breslow_likelihood:3.72709
# [52]	validation_0-breslow_likelihood:6.08287	validation_1-breslow_likelihood:3.75995
# [45]	validation_0-breslow_likelihood:6.06385	validation_1-breslow_likelihood:3.91961
# [28]	validation_0-breslow_likelihood:6.04737	validation_1-breslow_likelihood:3.96704
# [15]	validation_0-breslow_likelihood:6.07908	validation_1-breslow_likelihood:3.95139
# [2]	validation_0-breslow_likelihood:6.10416	validation_1-breslow_likelihood:3.72691
# [53]	validation_0-breslow_likelihood:6.08270	validation_1-breslow_likelihood:3.75983
# [57]	validation_0-breslow_likelihood:6.09932	validation_1-breslow_likelihood:3.72590
# [29]	validation_0-breslow_likelihood:6.04715	validation_1-breslow_likelihood:3.96700
# [3]	validation_0-breslow_likelihood:6.10379	validation_1-breslow_likelihood:3.72677
# [58]	validation_0-breslow_likelihood:6.09883	validation_1-breslow_likelihood:3.72589
# [54]	validation_0-breslow_likelihood:6.08242	validation_1-breslow_likelihood:3.75999
# [46]	validation_0-breslow_likelihood:6.06351	validation_1-breslow_likelihood:3.91976
# [30]	validation_0-breslow_likelihood:6.04661	validation_1-breslow_likelihood:3.96698
# [59]	validation_0-breslow_likelihood:6.09831	validation_1-breslow_likelihood:3.72577
# [9]	validation_0-breslow_likelihood:6.06935	validation_1-breslow_likelihood:3.94993
# [47]	validation_0-breslow_likelihood:6.06327	validation_1-breslow_likelihood:3.91981
# [16]	validation_0-breslow_likelihood:6.07848	validation_1-breslow_likelihood:3.95138
# [55]	validation_0-breslow_likelihood:6.08200	validation_1-breslow_likelihood:3.75972[4]	validation_0-breslow_likelihood:6.10325	validation_1-breslow_likelihood:3.72671
#
# [60]	validation_0-breslow_likelihood:6.09824	validation_1-breslow_likelihood:3.72579
# [48]	validation_0-breslow_likelihood:6.06295	validation_1-breslow_likelihood:3.91969
# [10]	validation_0-breslow_likelihood:6.06889	validation_1-breslow_likelihood:3.94984
# [17]	validation_0-breslow_likelihood:6.07811	validation_1-breslow_likelihood:3.95158
# [61]	validation_0-breslow_likelihood:6.09767	validation_1-breslow_likelihood:3.72569
# [56]	validation_0-breslow_likelihood:6.08152	validation_1-breslow_likelihood:3.75949
# [0]	validation_0-breslow_likelihood:6.06751	validation_1-breslow_likelihood:3.92732
# [49]	validation_0-breslow_likelihood:6.06248	validation_1-breslow_likelihood:3.91961
# [11]	validation_0-breslow_likelihood:6.06837	validation_1-breslow_likelihood:3.94974
# [18]	validation_0-breslow_likelihood:6.07758	validation_1-breslow_likelihood:3.95162
# [62]	validation_0-breslow_likelihood:6.09731	validation_1-breslow_likelihood:3.72560
# [57]	validation_0-breslow_likelihood:6.08109	validation_1-breslow_likelihood:3.75950
# [31]	validation_0-breslow_likelihood:6.04632	validation_1-breslow_likelihood:3.96689
# [50]	validation_0-breslow_likelihood:6.06221	validation_1-breslow_likelihood:3.91960
# [5]	validation_0-breslow_likelihood:6.10277	validation_1-breslow_likelihood:3.72654
# [12]	validation_0-breslow_likelihood:6.06786	validation_1-breslow_likelihood:3.94944
# [19]	validation_0-breslow_likelihood:6.07707	validation_1-breslow_likelihood:3.95131
# [63]	validation_0-breslow_likelihood:6.09686	validation_1-breslow_likelihood:3.72555
# [58]	validation_0-breslow_likelihood:6.08060	validation_1-breslow_likelihood:3.75931
# [51]	validation_0-breslow_likelihood:6.06197	validation_1-breslow_likelihood:3.91937
# [1]	validation_0-breslow_likelihood:6.06692	validation_1-breslow_likelihood:3.92714
# [13]	validation_0-breslow_likelihood:6.06736	validation_1-breslow_likelihood:3.94935
# [20]	validation_0-breslow_likelihood:6.07653	validation_1-breslow_likelihood:3.95124
# [64]	validation_0-breslow_likelihood:6.09613	validation_1-breslow_likelihood:3.72545
# [52]	validation_0-breslow_likelihood:6.06159	validation_1-breslow_likelihood:3.91925
# [59]	validation_0-breslow_likelihood:6.08018	validation_1-breslow_likelihood:3.75914
# [6]	validation_0-breslow_likelihood:6.10222	validation_1-breslow_likelihood:3.72660
# [14]	validation_0-breslow_likelihood:6.06688	validation_1-breslow_likelihood:3.94922
# [21]	validation_0-breslow_likelihood:6.07622	validation_1-breslow_likelihood:3.95120
# [60]	validation_0-breslow_likelihood:6.08009	validation_1-breslow_likelihood:3.75911
# [65]	validation_0-breslow_likelihood:6.09573	validation_1-breslow_likelihood:3.72560
# [2]	validation_0-breslow_likelihood:6.06689	validation_1-breslow_likelihood:3.92711
# [15]	validation_0-breslow_likelihood:6.06675	validation_1-breslow_likelihood:3.94925
# [53]	validation_0-breslow_likelihood:6.06098	validation_1-breslow_likelihood:3.91896
# [22]	validation_0-breslow_likelihood:6.07594	validation_1-breslow_likelihood:3.95100
# [66]	validation_0-breslow_likelihood:6.09531	validation_1-breslow_likelihood:3.72567
# [61]	validation_0-breslow_likelihood:6.07952	validation_1-breslow_likelihood:3.75891
# [16]	validation_0-breslow_likelihood:6.06620	validation_1-breslow_likelihood:3.94891
# [7]	validation_0-breslow_likelihood:6.10160	validation_1-breslow_likelihood:3.72640
# [54]	validation_0-breslow_likelihood:6.06055	validation_1-breslow_likelihood:3.91875
# [32]	validation_0-breslow_likelihood:6.04591	validation_1-breslow_likelihood:3.96695
# [23]	validation_0-breslow_likelihood:6.07542	validation_1-breslow_likelihood:3.95092
# [67]	validation_0-breslow_likelihood:6.09492	validation_1-breslow_likelihood:3.72570
# [62]	validation_0-breslow_likelihood:6.07925	validation_1-breslow_likelihood:3.75901
# [17]	validation_0-breslow_likelihood:6.06569	validation_1-breslow_likelihood:3.94890
# [55]	validation_0-breslow_likelihood:6.06011	validation_1-breslow_likelihood:3.91876
# [24]	validation_0-breslow_likelihood:6.07512	validation_1-breslow_likelihood:3.95104
# [3]	validation_0-breslow_likelihood:6.06644	validation_1-breslow_likelihood:3.92660
# [68]	validation_0-breslow_likelihood:6.09449	validation_1-breslow_likelihood:3.72572
# [63]	validation_0-breslow_likelihood:6.07886	validation_1-breslow_likelihood:3.75895
# [33]	validation_0-breslow_likelihood:6.04539	validation_1-breslow_likelihood:3.96684
# [18]	validation_0-breslow_likelihood:6.06517	validation_1-breslow_likelihood:3.94870
# [56]	validation_0-breslow_likelihood:6.05962	validation_1-breslow_likelihood:3.91871
# [25]	validation_0-breslow_likelihood:6.07474	validation_1-breslow_likelihood:3.95116
# [69]	validation_0-breslow_likelihood:6.09408	validation_1-breslow_likelihood:3.72598[34]	validation_0-breslow_likelihood:6.04530	validation_1-breslow_likelihood:3.96686
#
# [64]	validation_0-breslow_likelihood:6.07838	validation_1-breslow_likelihood:3.75889
# [8]	validation_0-breslow_likelihood:6.10104	validation_1-breslow_likelihood:3.72622
# [19]	validation_0-breslow_likelihood:6.06482	validation_1-breslow_likelihood:3.94849
# [57]	validation_0-breslow_likelihood:6.05926	validation_1-breslow_likelihood:3.91874
# [26]	validation_0-breslow_likelihood:6.07439	validation_1-breslow_likelihood:3.95118
# [65]	validation_0-breslow_likelihood:6.07800	validation_1-breslow_likelihood:3.75896
# [70]	validation_0-breslow_likelihood:6.09345	validation_1-breslow_likelihood:3.72596
# [27]	validation_0-breslow_likelihood:6.07435	validation_1-breslow_likelihood:3.95118
# [4]	validation_0-breslow_likelihood:6.06605	validation_1-breslow_likelihood:3.92646
# [20]	validation_0-breslow_likelihood:6.06433	validation_1-breslow_likelihood:3.94805
# [35]	validation_0-breslow_likelihood:6.04482	validation_1-breslow_likelihood:3.96686
# [66]	validation_0-breslow_likelihood:6.07751	validation_1-breslow_likelihood:3.75893
# [58]	validation_0-breslow_likelihood:6.05889	validation_1-breslow_likelihood:3.91874
# [28]	validation_0-breslow_likelihood:6.07392	validation_1-breslow_likelihood:3.95098
# [71]	validation_0-breslow_likelihood:6.09290	validation_1-breslow_likelihood:3.72596
# [21]	validation_0-breslow_likelihood:6.06396	validation_1-breslow_likelihood:3.94784
# [67]	validation_0-breslow_likelihood:6.07712	validation_1-breslow_likelihood:3.75889
# [29]	validation_0-breslow_likelihood:6.07367	validation_1-breslow_likelihood:3.95078
# [22]	validation_0-breslow_likelihood:6.06369	validation_1-breslow_likelihood:3.94762
# [5]	validation_0-breslow_likelihood:6.06552	validation_1-breslow_likelihood:3.92627
# [72]	validation_0-breslow_likelihood:6.09237	validation_1-breslow_likelihood:3.72588
# [9]	validation_0-breslow_likelihood:6.10063	validation_1-breslow_likelihood:3.72631
# [68]	validation_0-breslow_likelihood:6.07669	validation_1-breslow_likelihood:3.75892
# [59]	validation_0-breslow_likelihood:6.05832	validation_1-breslow_likelihood:3.91854
# [30]	validation_0-breslow_likelihood:6.07322	validation_1-breslow_likelihood:3.95078
# [6]	validation_0-breslow_likelihood:6.06527	validation_1-breslow_likelihood:3.92616
# [23]	validation_0-breslow_likelihood:6.06325	validation_1-breslow_likelihood:3.94767
# [73]	validation_0-breslow_likelihood:6.09191	validation_1-breslow_likelihood:3.72598
# [36]	validation_0-breslow_likelihood:6.04441	validation_1-breslow_likelihood:3.96684
# [69]	validation_0-breslow_likelihood:6.07624	validation_1-breslow_likelihood:3.75886
# [31]	validation_0-breslow_likelihood:6.07294	validation_1-breslow_likelihood:3.95078
# [24]	validation_0-breslow_likelihood:6.06287	validation_1-breslow_likelihood:3.94745
# [7]	validation_0-breslow_likelihood:6.06479	validation_1-breslow_likelihood:3.92600
# [74]	validation_0-breslow_likelihood:6.09155	validation_1-breslow_likelihood:3.72591
# [10]	validation_0-breslow_likelihood:6.10011	validation_1-breslow_likelihood:3.72644
# [32]	validation_0-breslow_likelihood:6.07253	validation_1-breslow_likelihood:3.95060
# [70]	validation_0-breslow_likelihood:6.07569	validation_1-breslow_likelihood:3.75851
# [25]	validation_0-breslow_likelihood:6.06260	validation_1-breslow_likelihood:3.94741
# [8]	validation_0-breslow_likelihood:6.06421	validation_1-breslow_likelihood:3.92596
# [60]	validation_0-breslow_likelihood:6.05799	validation_1-breslow_likelihood:3.91825
# [75]	validation_0-breslow_likelihood:6.09102	validation_1-breslow_likelihood:3.72582
# [37]	validation_0-breslow_likelihood:6.04407	validation_1-breslow_likelihood:3.96667
# [71]	validation_0-breslow_likelihood:6.07510	validation_1-breslow_likelihood:3.75820
# [33]	validation_0-breslow_likelihood:6.07212	validation_1-breslow_likelihood:3.95062
# [0]	validation_0-breslow_likelihood:6.07556	validation_1-breslow_likelihood:3.95910
# [9]	validation_0-breslow_likelihood:6.06400	validation_1-breslow_likelihood:3.92589
# [26]	validation_0-breslow_likelihood:6.06213	validation_1-breslow_likelihood:3.94745
# [0]	validation_0-breslow_likelihood:6.07416	validation_1-breslow_likelihood:3.93407
# [76]	validation_0-breslow_likelihood:6.09052	validation_1-breslow_likelihood:3.72576
# [34]	validation_0-breslow_likelihood:6.07172	validation_1-breslow_likelihood:3.95034
# [72]	validation_0-breslow_likelihood:6.07458	validation_1-breslow_likelihood:3.75797
# [10]	validation_0-breslow_likelihood:6.06356	validation_1-breslow_likelihood:3.92550
# [1]	validation_0-breslow_likelihood:6.07493	validation_1-breslow_likelihood:3.95884
# [27]	validation_0-breslow_likelihood:6.06208	validation_1-breslow_likelihood:3.94748
# [1]	validation_0-breslow_likelihood:6.07363	validation_1-breslow_likelihood:3.93412
# [61]	validation_0-breslow_likelihood:6.05758	validation_1-breslow_likelihood:3.91791
# [77]	validation_0-breslow_likelihood:6.09003	validation_1-breslow_likelihood:3.72591
# [35]	validation_0-breslow_likelihood:6.07136	validation_1-breslow_likelihood:3.95035
# [2]	validation_0-breslow_likelihood:6.07490	validation_1-breslow_likelihood:3.95881
# [73]	validation_0-breslow_likelihood:6.07409	validation_1-breslow_likelihood:3.75801
# [11]	validation_0-breslow_likelihood:6.06310	validation_1-breslow_likelihood:3.92530
# [38]	validation_0-breslow_likelihood:6.04359	validation_1-breslow_likelihood:3.96666
# [2]	validation_0-breslow_likelihood:6.07360	validation_1-breslow_likelihood:3.93409
# [62]	validation_0-breslow_likelihood:6.05706	validation_1-breslow_likelihood:3.91799
# [78]	validation_0-breslow_likelihood:6.08985	validation_1-breslow_likelihood:3.72592
# [74]	validation_0-breslow_likelihood:6.07364	validation_1-breslow_likelihood:3.75770
# [36]	validation_0-breslow_likelihood:6.07096	validation_1-breslow_likelihood:3.95051
# [12]	validation_0-breslow_likelihood:6.06264	validation_1-breslow_likelihood:3.92513
# [11]	validation_0-breslow_likelihood:6.09946	validation_1-breslow_likelihood:3.72634
# [3]	validation_0-breslow_likelihood:6.07450	validation_1-breslow_likelihood:3.95849
# [3]	validation_0-breslow_likelihood:6.07315	validation_1-breslow_likelihood:3.93409
# [39]	validation_0-breslow_likelihood:6.04319	validation_1-breslow_likelihood:3.96663
# [37]	validation_0-breslow_likelihood:6.07046	validation_1-breslow_likelihood:3.95033
# [75]	validation_0-breslow_likelihood:6.07328	validation_1-breslow_likelihood:3.75762
# [79]	validation_0-breslow_likelihood:6.08937	validation_1-breslow_likelihood:3.72581
# [13]	validation_0-breslow_likelihood:6.06208	validation_1-breslow_likelihood:3.92509
# [63]	validation_0-breslow_likelihood:6.05666	validation_1-breslow_likelihood:3.91779
# [4]	validation_0-breslow_likelihood:6.07401	validation_1-breslow_likelihood:3.95839
# [4]	validation_0-breslow_likelihood:6.07266	validation_1-breslow_likelihood:3.93382
# [28]	validation_0-breslow_likelihood:6.06168	validation_1-breslow_likelihood:3.94741
# [80]	validation_0-breslow_likelihood:6.08920	validation_1-breslow_likelihood:3.72576
# [38]	validation_0-breslow_likelihood:6.07026	validation_1-breslow_likelihood:3.95041
# [76]	validation_0-breslow_likelihood:6.07281	validation_1-breslow_likelihood:3.75750
# [14]	validation_0-breslow_likelihood:6.06161	validation_1-breslow_likelihood:3.92475
# [5]	validation_0-breslow_likelihood:6.07356	validation_1-breslow_likelihood:3.95834
# [5]	validation_0-breslow_likelihood:6.07216	validation_1-breslow_likelihood:3.93352
# [29]	validation_0-breslow_likelihood:6.06138	validation_1-breslow_likelihood:3.94727
# [81]	validation_0-breslow_likelihood:6.08866	validation_1-breslow_likelihood:3.72540
# [15]	validation_0-breslow_likelihood:6.06135	validation_1-breslow_likelihood:3.92477
# [6]	validation_0-breslow_likelihood:6.07305	validation_1-breslow_likelihood:3.95814
# [77]	validation_0-breslow_likelihood:6.07237	validation_1-breslow_likelihood:3.75738
# [12]	validation_0-breslow_likelihood:6.09917	validation_1-breslow_likelihood:3.72630
# [6]	validation_0-breslow_likelihood:6.07180	validation_1-breslow_likelihood:3.93334
# [40]	validation_0-breslow_likelihood:6.04269	validation_1-breslow_likelihood:3.96649
# [82]	validation_0-breslow_likelihood:6.08814	validation_1-breslow_likelihood:3.72533
# [78]	validation_0-breslow_likelihood:6.07236	validation_1-breslow_likelihood:3.75740
# [64]	validation_0-breslow_likelihood:6.05636	validation_1-breslow_likelihood:3.91774
# [39]	validation_0-breslow_likelihood:6.06987	validation_1-breslow_likelihood:3.95040
# [16]	validation_0-breslow_likelihood:6.06086	validation_1-breslow_likelihood:3.92457
# [7]	validation_0-breslow_likelihood:6.07265	validation_1-breslow_likelihood:3.95802
# [13]	validation_0-breslow_likelihood:6.09888	validation_1-breslow_likelihood:3.72607
# [7]	validation_0-breslow_likelihood:6.07144	validation_1-breslow_likelihood:3.93306
# [41]	validation_0-breslow_likelihood:6.04227	validation_1-breslow_likelihood:3.96629
# [83]	validation_0-breslow_likelihood:6.08769	validation_1-breslow_likelihood:3.72517
# [79]	validation_0-breslow_likelihood:6.07194	validation_1-breslow_likelihood:3.75735
# [30]	validation_0-breslow_likelihood:6.06082	validation_1-breslow_likelihood:3.94703
# [17]	validation_0-breslow_likelihood:6.06033	validation_1-breslow_likelihood:3.92456
# [14]	validation_0-breslow_likelihood:6.09832	validation_1-breslow_likelihood:3.72598
# [8]	validation_0-breslow_likelihood:6.07194	validation_1-breslow_likelihood:3.95771
# [8]	validation_0-breslow_likelihood:6.07088	validation_1-breslow_likelihood:3.93311
# [80]	validation_0-breslow_likelihood:6.07194	validation_1-breslow_likelihood:3.75735
# [42]	validation_0-breslow_likelihood:6.04181	validation_1-breslow_likelihood:3.96638
# [84]	validation_0-breslow_likelihood:6.08703	validation_1-breslow_likelihood:3.72536
# [18]	validation_0-breslow_likelihood:6.05985	validation_1-breslow_likelihood:3.92433
# [43]	validation_0-breslow_likelihood:6.04154	validation_1-breslow_likelihood:3.96615
# [9]	validation_0-breslow_likelihood:6.07051	validation_1-breslow_likelihood:3.93274[15]	validation_0-breslow_likelihood:6.09784	validation_1-breslow_likelihood:3.72587
#
# [40]	validation_0-breslow_likelihood:6.06937	validation_1-breslow_likelihood:3.95041
# [81]	validation_0-breslow_likelihood:6.07142	validation_1-breslow_likelihood:3.75707
# [85]	validation_0-breslow_likelihood:6.08655	validation_1-breslow_likelihood:3.72541
# [65]	validation_0-breslow_likelihood:6.05587	validation_1-breslow_likelihood:3.91768
# [44]	validation_0-breslow_likelihood:6.04112	validation_1-breslow_likelihood:3.96593
# [19]	validation_0-breslow_likelihood:6.05932	validation_1-breslow_likelihood:3.92437
# [10]	validation_0-breslow_likelihood:6.06994	validation_1-breslow_likelihood:3.93264
# [41]	validation_0-breslow_likelihood:6.06902	validation_1-breslow_likelihood:3.95035
# [82]	validation_0-breslow_likelihood:6.07099	validation_1-breslow_likelihood:3.75684
# [16]	validation_0-breslow_likelihood:6.09735	validation_1-breslow_likelihood:3.72565
# [86]	validation_0-breslow_likelihood:6.08598	validation_1-breslow_likelihood:3.72503
# [9]	validation_0-breslow_likelihood:6.07148	validation_1-breslow_likelihood:3.95747
# [11]	validation_0-breslow_likelihood:6.06947	validation_1-breslow_likelihood:3.93267
# [20]	validation_0-breslow_likelihood:6.05884	validation_1-breslow_likelihood:3.92407
# [31]	validation_0-breslow_likelihood:6.06052	validation_1-breslow_likelihood:3.94686
# [42]	validation_0-breslow_likelihood:6.06856	validation_1-breslow_likelihood:3.95036
# [83]	validation_0-breslow_likelihood:6.07056	validation_1-breslow_likelihood:3.75646
# [66]	validation_0-breslow_likelihood:6.05537	validation_1-breslow_likelihood:3.91752
# [45]	validation_0-breslow_likelihood:6.04071	validation_1-breslow_likelihood:3.96576
# [87]	validation_0-breslow_likelihood:6.08554	validation_1-breslow_likelihood:3.72484
# [43]	validation_0-breslow_likelihood:6.06829	validation_1-breslow_likelihood:3.95019
# [12]	validation_0-breslow_likelihood:6.06907	validation_1-breslow_likelihood:3.93228
# [21]	validation_0-breslow_likelihood:6.05847	validation_1-breslow_likelihood:3.92393
# [17]	validation_0-breslow_likelihood:6.09683	validation_1-breslow_likelihood:3.72555
# [88]	validation_0-breslow_likelihood:6.08516	validation_1-breslow_likelihood:3.72468[67]	validation_0-breslow_likelihood:6.05510	validation_1-breslow_likelihood:3.91762
#
# [22]	validation_0-breslow_likelihood:6.05826	validation_1-breslow_likelihood:3.92377[46]	validation_0-breslow_likelihood:6.04031	validation_1-breslow_likelihood:3.96592
#
# [84]	validation_0-breslow_likelihood:6.07000	validation_1-breslow_likelihood:3.75609
# [44]	validation_0-breslow_likelihood:6.06789	validation_1-breslow_likelihood:3.95008
# [10]	validation_0-breslow_likelihood:6.07089	validation_1-breslow_likelihood:3.95724
# [13]	validation_0-breslow_likelihood:6.06853	validation_1-breslow_likelihood:3.93218
# [32]	validation_0-breslow_likelihood:6.06005	validation_1-breslow_likelihood:3.94680
# [85]	validation_0-breslow_likelihood:6.06978	validation_1-breslow_likelihood:3.75610
# [23]	validation_0-breslow_likelihood:6.05787	validation_1-breslow_likelihood:3.92378
# [89]	validation_0-breslow_likelihood:6.08464	validation_1-breslow_likelihood:3.72467
# [45]	validation_0-breslow_likelihood:6.06744	validation_1-breslow_likelihood:3.95018
# [18]	validation_0-breslow_likelihood:6.09630	validation_1-breslow_likelihood:3.72566
# [14]	validation_0-breslow_likelihood:6.06814	validation_1-breslow_likelihood:3.93191
# [90]	validation_0-breslow_likelihood:6.08442	validation_1-breslow_likelihood:3.72463
# [24]	validation_0-breslow_likelihood:6.05756	validation_1-breslow_likelihood:3.92355
# [15]	validation_0-breslow_likelihood:6.06796	validation_1-breslow_likelihood:3.93186
# [86]	validation_0-breslow_likelihood:6.06913	validation_1-breslow_likelihood:3.75569
# [46]	validation_0-breslow_likelihood:6.06707	validation_1-breslow_likelihood:3.95010
# [47]	validation_0-breslow_likelihood:6.03986	validation_1-breslow_likelihood:3.96591
# [19]	validation_0-breslow_likelihood:6.09567	validation_1-breslow_likelihood:3.72521
# [68]	validation_0-breslow_likelihood:6.05475	validation_1-breslow_likelihood:3.91777
# [25]	validation_0-breslow_likelihood:6.05730	validation_1-breslow_likelihood:3.92348
# [91]	validation_0-breslow_likelihood:6.08377	validation_1-breslow_likelihood:3.72467
# [11]	validation_0-breslow_likelihood:6.07041	validation_1-breslow_likelihood:3.95713
# [87]	validation_0-breslow_likelihood:6.06866	validation_1-breslow_likelihood:3.75546
# [47]	validation_0-breslow_likelihood:6.06660	validation_1-breslow_likelihood:3.95028
# [20]	validation_0-breslow_likelihood:6.09512	validation_1-breslow_likelihood:3.72513
# [69]	validation_0-breslow_likelihood:6.05433	validation_1-breslow_likelihood:3.91775
# [92]	validation_0-breslow_likelihood:6.08336	validation_1-breslow_likelihood:3.72463
# [26]	validation_0-breslow_likelihood:6.05689	validation_1-breslow_likelihood:3.92363
# [33]	validation_0-breslow_likelihood:6.05960	validation_1-breslow_likelihood:3.94667
# [88]	validation_0-breslow_likelihood:6.06828	validation_1-breslow_likelihood:3.75529
# [21]	validation_0-breslow_likelihood:6.09489	validation_1-breslow_likelihood:3.72508
# [48]	validation_0-breslow_likelihood:6.06632	validation_1-breslow_likelihood:3.95017
# [27]	validation_0-breslow_likelihood:6.05686	validation_1-breslow_likelihood:3.92362
# [70]	validation_0-breslow_likelihood:6.05387	validation_1-breslow_likelihood:3.91738
# [93]	validation_0-breslow_likelihood:6.08304	validation_1-breslow_likelihood:3.72474
# [89]	validation_0-breslow_likelihood:6.06774	validation_1-breslow_likelihood:3.75518
# [22]	validation_0-breslow_likelihood:6.09448	validation_1-breslow_likelihood:3.72508
# [49]	validation_0-breslow_likelihood:6.06588	validation_1-breslow_likelihood:3.95023
# [71]	validation_0-breslow_likelihood:6.05367	validation_1-breslow_likelihood:3.91727
# [48]	validation_0-breslow_likelihood:6.03958	validation_1-breslow_likelihood:3.96593
# [28]	validation_0-breslow_likelihood:6.05644	validation_1-breslow_likelihood:3.92335
# [16]	validation_0-breslow_likelihood:6.06739	validation_1-breslow_likelihood:3.93171
# [90]	validation_0-breslow_likelihood:6.06755	validation_1-breslow_likelihood:3.75508
# [50]	validation_0-breslow_likelihood:6.06570	validation_1-breslow_likelihood:3.95027
# [23]	validation_0-breslow_likelihood:6.09391	validation_1-breslow_likelihood:3.72514
# [12]	validation_0-breslow_likelihood:6.06991	validation_1-breslow_likelihood:3.95699
# [34]	validation_0-breslow_likelihood:6.05950	validation_1-breslow_likelihood:3.94664
# [29]	validation_0-breslow_likelihood:6.05623	validation_1-breslow_likelihood:3.92326
# [51]	validation_0-breslow_likelihood:6.06530	validation_1-breslow_likelihood:3.95011
# [91]	validation_0-breslow_likelihood:6.06694	validation_1-breslow_likelihood:3.75502
# [72]	validation_0-breslow_likelihood:6.05332	validation_1-breslow_likelihood:3.91697
# [13]	validation_0-breslow_likelihood:6.06931	validation_1-breslow_likelihood:3.95687
# [30]	validation_0-breslow_likelihood:6.05570	validation_1-breslow_likelihood:3.92297
# [52]	validation_0-breslow_likelihood:6.06480	validation_1-breslow_likelihood:3.95005
# [49]	validation_0-breslow_likelihood:6.03916	validation_1-breslow_likelihood:3.96575
# [92]	validation_0-breslow_likelihood:6.06654	validation_1-breslow_likelihood:3.75486
# [73]	validation_0-breslow_likelihood:6.05308	validation_1-breslow_likelihood:3.91699
# [31]	validation_0-breslow_likelihood:6.05549	validation_1-breslow_likelihood:3.92293
# [24]	validation_0-breslow_likelihood:6.09338	validation_1-breslow_likelihood:3.72513
# [14]	validation_0-breslow_likelihood:6.06879	validation_1-breslow_likelihood:3.95658
# [17]	validation_0-breslow_likelihood:6.06694	validation_1-breslow_likelihood:3.93176
# [35]	validation_0-breslow_likelihood:6.05906	validation_1-breslow_likelihood:3.94631
# [53]	validation_0-breslow_likelihood:6.06426	validation_1-breslow_likelihood:3.94970
# [93]	validation_0-breslow_likelihood:6.06621	validation_1-breslow_likelihood:3.75476
# [74]	validation_0-breslow_likelihood:6.05261	validation_1-breslow_likelihood:3.91677
# [32]	validation_0-breslow_likelihood:6.05508	validation_1-breslow_likelihood:3.92279
# [15]	validation_0-breslow_likelihood:6.06850	validation_1-breslow_likelihood:3.95634
# [54]	validation_0-breslow_likelihood:6.06372	validation_1-breslow_likelihood:3.94961
# [33]	validation_0-breslow_likelihood:6.05444	validation_1-breslow_likelihood:3.92290
# [50]	validation_0-breslow_likelihood:6.03901	validation_1-breslow_likelihood:3.96567
# [55]	validation_0-breslow_likelihood:6.06318	validation_1-breslow_likelihood:3.94952
# [25]	validation_0-breslow_likelihood:6.09296	validation_1-breslow_likelihood:3.72497
# [34]	validation_0-breslow_likelihood:6.05435	validation_1-breslow_likelihood:3.92286
# [18]	validation_0-breslow_likelihood:6.06642	validation_1-breslow_likelihood:3.93178
# [16]	validation_0-breslow_likelihood:6.06806	validation_1-breslow_likelihood:3.95625
# [56]	validation_0-breslow_likelihood:6.06265	validation_1-breslow_likelihood:3.94958
# [35]	validation_0-breslow_likelihood:6.05391	validation_1-breslow_likelihood:3.92284
# [17]	validation_0-breslow_likelihood:6.06767	validation_1-breslow_likelihood:3.95614
# [75]	validation_0-breslow_likelihood:6.05223	validation_1-breslow_likelihood:3.91682
# [51]	validation_0-breslow_likelihood:6.03868	validation_1-breslow_likelihood:3.96573
# [57]	validation_0-breslow_likelihood:6.06212	validation_1-breslow_likelihood:3.94941
# [36]	validation_0-breslow_likelihood:6.05350	validation_1-breslow_likelihood:3.92274
# [36]	validation_0-breslow_likelihood:6.05865	validation_1-breslow_likelihood:3.94643
# [18]	validation_0-breslow_likelihood:6.06710	validation_1-breslow_likelihood:3.95600
# [76]	validation_0-breslow_likelihood:6.05199	validation_1-breslow_likelihood:3.91699
# [19]	validation_0-breslow_likelihood:6.06589	validation_1-breslow_likelihood:3.93176
# [58]	validation_0-breslow_likelihood:6.06165	validation_1-breslow_likelihood:3.94948
# [37]	validation_0-breslow_likelihood:6.05322	validation_1-breslow_likelihood:3.92277
# [26]	validation_0-breslow_likelihood:6.09241	validation_1-breslow_likelihood:3.72512
# [19]	validation_0-breslow_likelihood:6.06654	validation_1-breslow_likelihood:3.95591
# [20]	validation_0-breslow_likelihood:6.06533	validation_1-breslow_likelihood:3.93159
# [59]	validation_0-breslow_likelihood:6.06114	validation_1-breslow_likelihood:3.94944
# [52]	validation_0-breslow_likelihood:6.03816	validation_1-breslow_likelihood:3.96547
# [77]	validation_0-breslow_likelihood:6.05164	validation_1-breslow_likelihood:3.91685
# [20]	validation_0-breslow_likelihood:6.06599	validation_1-breslow_likelihood:3.95600
# [37]	validation_0-breslow_likelihood:6.05827	validation_1-breslow_likelihood:3.94611
# [21]	validation_0-breslow_likelihood:6.06496	validation_1-breslow_likelihood:3.93157
# [60]	validation_0-breslow_likelihood:6.06062	validation_1-breslow_likelihood:3.94912
# [53]	validation_0-breslow_likelihood:6.03765	validation_1-breslow_likelihood:3.96520
# [27]	validation_0-breslow_likelihood:6.09197	validation_1-breslow_likelihood:3.72511
# [22]	validation_0-breslow_likelihood:6.06468	validation_1-breslow_likelihood:3.93126
# [61]	validation_0-breslow_likelihood:6.06019	validation_1-breslow_likelihood:3.94891
# [38]	validation_0-breslow_likelihood:6.05285	validation_1-breslow_likelihood:3.92281
# [78]	validation_0-breslow_likelihood:6.05107	validation_1-breslow_likelihood:3.91674
# [23]	validation_0-breslow_likelihood:6.06415	validation_1-breslow_likelihood:3.93144
# [38]	validation_0-breslow_likelihood:6.05785	validation_1-breslow_likelihood:3.94607
# [62]	validation_0-breslow_likelihood:6.05959	validation_1-breslow_likelihood:3.94900
# [54]	validation_0-breslow_likelihood:6.03723	validation_1-breslow_likelihood:3.96507
# [28]	validation_0-breslow_likelihood:6.09161	validation_1-breslow_likelihood:3.72525
# [24]	validation_0-breslow_likelihood:6.06384	validation_1-breslow_likelihood:3.93148
# [39]	validation_0-breslow_likelihood:6.05750	validation_1-breslow_likelihood:3.94625
# [39]	validation_0-breslow_likelihood:6.05256	validation_1-breslow_likelihood:3.92292
# [21]	validation_0-breslow_likelihood:6.06572	validation_1-breslow_likelihood:3.95598
# [63]	validation_0-breslow_likelihood:6.05928	validation_1-breslow_likelihood:3.94907
# [55]	validation_0-breslow_likelihood:6.03674	validation_1-breslow_likelihood:3.96493
# [25]	validation_0-breslow_likelihood:6.06352	validation_1-breslow_likelihood:3.93123
# [40]	validation_0-breslow_likelihood:6.05695	validation_1-breslow_likelihood:3.94598
# [79]	validation_0-breslow_likelihood:6.05074	validation_1-breslow_likelihood:3.91673
# [64]	validation_0-breslow_likelihood:6.05892	validation_1-breslow_likelihood:3.94913
# [29]	validation_0-breslow_likelihood:6.09107	validation_1-breslow_likelihood:3.72520
# [26]	validation_0-breslow_likelihood:6.06325	validation_1-breslow_likelihood:3.93125
# [41]	validation_0-breslow_likelihood:6.05656	validation_1-breslow_likelihood:3.94570
# [80]	validation_0-breslow_likelihood:6.05053	validation_1-breslow_likelihood:3.91670
# [65]	validation_0-breslow_likelihood:6.05843	validation_1-breslow_likelihood:3.94923
# [22]	validation_0-breslow_likelihood:6.06538	validation_1-breslow_likelihood:3.95571
# [27]	validation_0-breslow_likelihood:6.06319	validation_1-breslow_likelihood:3.93126
# [56]	validation_0-breslow_likelihood:6.03621	validation_1-breslow_likelihood:3.96489
# [40]	validation_0-breslow_likelihood:6.05208	validation_1-breslow_likelihood:3.92296
# [42]	validation_0-breslow_likelihood:6.05612	validation_1-breslow_likelihood:3.94578
# [81]	validation_0-breslow_likelihood:6.05012	validation_1-breslow_likelihood:3.91648
# [66]	validation_0-breslow_likelihood:6.05800	validation_1-breslow_likelihood:3.94910
# [28]	validation_0-breslow_likelihood:6.06280	validation_1-breslow_likelihood:3.93110
# [43]	validation_0-breslow_likelihood:6.05587	validation_1-breslow_likelihood:3.94549
# ...
# [52]	validation_0-breslow_likelihood:6.05140	validation_1-breslow_likelihood:3.93496
# [53]	validation_0-breslow_likelihood:6.05088	validation_1-breslow_likelihood:3.93453
# [54]	validation_0-breslow_likelihood:6.05057	validation_1-breslow_likelihood:3.93410
# [55]	validation_0-breslow_likelihood:6.04991	validation_1-breslow_likelihood:3.93340
# [56]	validation_0-breslow_likelihood:6.04952	validation_1-breslow_likelihood:3.93285
# [57]	validation_0-breslow_likelihood:6.04893	validation_1-breslow_likelihood:3.93251
# [58]	validation_0-breslow_likelihood:6.04837	validation_1-breslow_likelihood:3.93216
# [59]	validation_0-breslow_likelihood:6.04763	validation_1-breslow_likelihood:3.93182
# [60]	validation_0-breslow_likelihood:6.04700	validation_1-breslow_likelihood:3.93132
# [61]	validation_0-breslow_likelihood:6.04652	validation_1-breslow_likelihood:3.93070
# [62]	validation_0-breslow_likelihood:6.04594	validation_1-breslow_likelihood:3.93070
# [63]	validation_0-breslow_likelihood:6.04549	validation_1-breslow_likelihood:3.93042
# [64]	validation_0-breslow_likelihood:6.04521	validation_1-breslow_likelihood:3.93011
# [65]	validation_0-breslow_likelihood:6.04466	validation_1-breslow_likelihood:3.92970
# [66]	validation_0-breslow_likelihood:6.04408	validation_1-breslow_likelihood:3.92924
# [67]	validation_0-breslow_likelihood:6.04361	validation_1-breslow_likelihood:3.92919
# [68]	validation_0-breslow_likelihood:6.04322	validation_1-breslow_likelihood:3.92934
# [69]	validation_0-breslow_likelihood:6.04264	validation_1-breslow_likelihood:3.92912
# [70]	validation_0-breslow_likelihood:6.04195	validation_1-breslow_likelihood:3.92915
# [71]	validation_0-breslow_likelihood:6.04171	validation_1-breslow_likelihood:3.92921
# [72]	validation_0-breslow_likelihood:6.04101	validation_1-breslow_likelihood:3.92908
# [73]	validation_0-breslow_likelihood:6.04059	validation_1-breslow_likelihood:3.92894
# [74]	validation_0-breslow_likelihood:6.04010	validation_1-breslow_likelihood:3.92877
# [75]	validation_0-breslow_likelihood:6.03946	validation_1-breslow_likelihood:3.92834
# [76]	validation_0-breslow_likelihood:6.03898	validation_1-breslow_likelihood:3.92828
# [77]	validation_0-breslow_likelihood:6.03851	validation_1-breslow_likelihood:3.92796
# [0]	validation_0-breslow_likelihood:6.10666	validation_1-breslow_likelihood:3.76743
# [1]	validation_0-breslow_likelihood:6.10565	validation_1-breslow_likelihood:3.76676
# [2]	validation_0-breslow_likelihood:6.10520	validation_1-breslow_likelihood:3.76587
# [3]	validation_0-breslow_likelihood:6.10458	validation_1-breslow_likelihood:3.76558
# [4]	validation_0-breslow_likelihood:6.10372	validation_1-breslow_likelihood:3.76476
# [5]	validation_0-breslow_likelihood:6.10309	validation_1-breslow_likelihood:3.76470
# [6]	validation_0-breslow_likelihood:6.10228	validation_1-breslow_likelihood:3.76392
# [7]	validation_0-breslow_likelihood:6.10147	validation_1-breslow_likelihood:3.76372
# [8]	validation_0-breslow_likelihood:6.10089	validation_1-breslow_likelihood:3.76368
# [9]	validation_0-breslow_likelihood:6.10030	validation_1-breslow_likelihood:3.76351
# [10]	validation_0-breslow_likelihood:6.09958	validation_1-breslow_likelihood:3.76379
# [11]	validation_0-breslow_likelihood:6.09846	validation_1-breslow_likelihood:3.76363
# [12]	validation_0-breslow_likelihood:6.09786	validation_1-breslow_likelihood:3.76339
# [13]	validation_0-breslow_likelihood:6.09703	validation_1-breslow_likelihood:3.76288
# [14]	validation_0-breslow_likelihood:6.09645	validation_1-breslow_likelihood:3.76362
# [15]	validation_0-breslow_likelihood:6.09590	validation_1-breslow_likelihood:3.76326
# [16]	validation_0-breslow_likelihood:6.09504	validation_1-breslow_likelihood:3.76282
# [17]	validation_0-breslow_likelihood:6.09439	validation_1-breslow_likelihood:3.76222
# [18]	validation_0-breslow_likelihood:6.09347	validation_1-breslow_likelihood:3.76212
# [19]	validation_0-breslow_likelihood:6.09267	validation_1-breslow_likelihood:3.76128
# [20]	validation_0-breslow_likelihood:6.09180	validation_1-breslow_likelihood:3.76078
# [21]	validation_0-breslow_likelihood:6.09099	validation_1-breslow_likelihood:3.75993
# [22]	validation_0-breslow_likelihood:6.09017	validation_1-breslow_likelihood:3.75919
# [23]	validation_0-breslow_likelihood:6.08931	validation_1-breslow_likelihood:3.75945
# [24]	validation_0-breslow_likelihood:6.08859	validation_1-breslow_likelihood:3.75854
# [25]	validation_0-breslow_likelihood:6.08789	validation_1-breslow_likelihood:3.75795
# [26]	validation_0-breslow_likelihood:6.08747	validation_1-breslow_likelihood:3.75773
# [27]	validation_0-breslow_likelihood:6.08653	validation_1-breslow_likelihood:3.75712
# [28]	validation_0-breslow_likelihood:6.08588	validation_1-breslow_likelihood:3.75723
# [29]	validation_0-breslow_likelihood:6.08503	validation_1-breslow_likelihood:3.75672
# [30]	validation_0-breslow_likelihood:6.08422	validation_1-breslow_likelihood:3.75620
# [31]	validation_0-breslow_likelihood:6.08364	validation_1-breslow_likelihood:3.75548
# [32]	validation_0-breslow_likelihood:6.08305	validation_1-breslow_likelihood:3.75528
# [33]	validation_0-breslow_likelihood:6.08252	validation_1-breslow_likelihood:3.75468
# [34]	validation_0-breslow_likelihood:6.08183	validation_1-breslow_likelihood:3.75467
# [35]	validation_0-breslow_likelihood:6.08100	validation_1-breslow_likelihood:3.75479
# [36]	validation_0-breslow_likelihood:6.08020	validation_1-breslow_likelihood:3.75409
# [37]	validation_0-breslow_likelihood:6.07952	validation_1-breslow_likelihood:3.75395
# [38]	validation_0-breslow_likelihood:6.07861	validation_1-breslow_likelihood:3.75364
# [39]	validation_0-breslow_likelihood:6.07796	validation_1-breslow_likelihood:3.75343
# [40]	validation_0-breslow_likelihood:6.07734	validation_1-breslow_likelihood:3.75343
# [41]	validation_0-breslow_likelihood:6.07679	validation_1-breslow_likelihood:3.75333
# [42]	validation_0-breslow_likelihood:6.07629	validation_1-breslow_likelihood:3.75263
# [43]	validation_0-breslow_likelihood:6.07570	validation_1-breslow_likelihood:3.75240
# [44]	validation_0-breslow_likelihood:6.07538	validation_1-breslow_likelihood:3.75206
# [45]	validation_0-breslow_likelihood:6.07474	validation_1-breslow_likelihood:3.75149
# [46]	validation_0-breslow_likelihood:6.07413	validation_1-breslow_likelihood:3.75113
# [47]	validation_0-breslow_likelihood:6.07344	validation_1-breslow_likelihood:3.75065
# [48]	validation_0-breslow_likelihood:6.07285	validation_1-breslow_likelihood:3.75083
# [49]	validation_0-breslow_likelihood:6.07232	validation_1-breslow_likelihood:3.75006
# [50]	validation_0-breslow_likelihood:6.07180	validation_1-breslow_likelihood:3.75002
# [51]	validation_0-breslow_likelihood:6.07100	validation_1-breslow_likelihood:3.74893
# [52]	validation_0-breslow_likelihood:6.07043	validation_1-breslow_likelihood:3.74924
# [53]	validation_0-breslow_likelihood:6.06999	validation_1-breslow_likelihood:3.74911
# [54]	validation_0-breslow_likelihood:6.06940	validation_1-breslow_likelihood:3.74868
# [55]	validation_0-breslow_likelihood:6.06873	validation_1-breslow_likelihood:3.74860
# [56]	validation_0-breslow_likelihood:6.06814	validation_1-breslow_likelihood:3.74850
# [57]	validation_0-breslow_likelihood:6.06764	validation_1-breslow_likelihood:3.74781
# [58]	validation_0-breslow_likelihood:6.06712	validation_1-breslow_likelihood:3.74795
# [59]	validation_0-breslow_likelihood:6.06669	validation_1-breslow_likelihood:3.74798
# [60]	validation_0-breslow_likelihood:6.06615	validation_1-breslow_likelihood:3.74765
# [61]	validation_0-breslow_likelihood:6.06565	validation_1-breslow_likelihood:3.74738
# [62]	validation_0-breslow_likelihood:6.06526	validation_1-breslow_likelihood:3.74758
# [63]	validation_0-breslow_likelihood:6.06467	validation_1-breslow_likelihood:3.74722
# [64]	validation_0-breslow_likelihood:6.06391	validation_1-breslow_likelihood:3.74724
# [65]	validation_0-breslow_likelihood:6.06338	validation_1-breslow_likelihood:3.74679
# [66]	validation_0-breslow_likelihood:6.06257	validation_1-breslow_likelihood:3.74688
# [67]	validation_0-breslow_likelihood:6.06210	validation_1-breslow_likelihood:3.74666
# [68]	validation_0-breslow_likelihood:6.06135	validation_1-breslow_likelihood:3.74658
# [69]	validation_0-breslow_likelihood:6.06103	validation_1-breslow_likelihood:3.74648
# [70]	validation_0-breslow_likelihood:6.06042	validation_1-breslow_likelihood:3.74654
# [71]	validation_0-breslow_likelihood:6.05958	validation_1-breslow_likelihood:3.74647
# [72]	validation_0-breslow_likelihood:6.05888	validation_1-breslow_likelihood:3.74560
# [73]	validation_0-breslow_likelihood:6.05844	validation_1-breslow_likelihood:3.74551
# [74]	validation_0-breslow_likelihood:6.05784	validation_1-breslow_likelihood:3.74532
# [75]	validation_0-breslow_likelihood:6.05729	validation_1-breslow_likelihood:3.74532
# [76]	validation_0-breslow_likelihood:6.05684	validation_1-breslow_likelihood:3.74518
# [77]	validation_0-breslow_likelihood:6.05623	validation_1-breslow_likelihood:3.74552
# [0]	validation_0-breslow_likelihood:6.17761	validation_1-breslow_likelihood:3.99178
# [1]	validation_0-breslow_likelihood:6.17730	validation_1-breslow_likelihood:3.99209
# [2]	validation_0-breslow_likelihood:6.17628	validation_1-breslow_likelihood:3.99127
# [3]	validation_0-breslow_likelihood:6.17568	validation_1-breslow_likelihood:3.99107
# [4]	validation_0-breslow_likelihood:6.17492	validation_1-breslow_likelihood:3.99105
# [5]	validation_0-breslow_likelihood:6.17408	validation_1-breslow_likelihood:3.99080
# [6]	validation_0-breslow_likelihood:6.17308	validation_1-breslow_likelihood:3.98983
# [7]	validation_0-breslow_likelihood:6.17253	validation_1-breslow_likelihood:3.98884
# [8]	validation_0-breslow_likelihood:6.17185	validation_1-breslow_likelihood:3.98821
# [9]	validation_0-breslow_likelihood:6.17041	validation_1-breslow_likelihood:3.98663
# [10]	validation_0-breslow_likelihood:6.17007	validation_1-breslow_likelihood:3.98686
# [11]	validation_0-breslow_likelihood:6.16935	validation_1-breslow_likelihood:3.98645
# [12]	validation_0-breslow_likelihood:6.16864	validation_1-breslow_likelihood:3.98553
# [13]	validation_0-breslow_likelihood:6.16749	validation_1-breslow_likelihood:3.98519
# [14]	validation_0-breslow_likelihood:6.16627	validation_1-breslow_likelihood:3.98426
# [15]	validation_0-breslow_likelihood:6.16606	validation_1-breslow_likelihood:3.98344
# [16]	validation_0-breslow_likelihood:6.16588	validation_1-breslow_likelihood:3.98279
# [17]	validation_0-breslow_likelihood:6.16533	validation_1-breslow_likelihood:3.98179
# [18]	validation_0-breslow_likelihood:6.16482	validation_1-breslow_likelihood:3.98056
# [19]	validation_0-breslow_likelihood:6.16386	validation_1-breslow_likelihood:3.98073
# [20]	validation_0-breslow_likelihood:6.16367	validation_1-breslow_likelihood:3.98074
# [21]	validation_0-breslow_likelihood:6.16257	validation_1-breslow_likelihood:3.98041
# [22]	validation_0-breslow_likelihood:6.16180	validation_1-breslow_likelihood:3.97985
# [23]	validation_0-breslow_likelihood:6.16077	validation_1-breslow_likelihood:3.97868
# [24]	validation_0-breslow_likelihood:6.15953	validation_1-breslow_likelihood:3.97859
# [25]	validation_0-breslow_likelihood:6.15887	validation_1-breslow_likelihood:3.97825
# [26]	validation_0-breslow_likelihood:6.15826	validation_1-breslow_likelihood:3.97740
# [27]	validation_0-breslow_likelihood:6.15749	validation_1-breslow_likelihood:3.97612
# [28]	validation_0-breslow_likelihood:6.15667	validation_1-breslow_likelihood:3.97421
# [29]	validation_0-breslow_likelihood:6.15629	validation_1-breslow_likelihood:3.97418
# [30]	validation_0-breslow_likelihood:6.15550	validation_1-breslow_likelihood:3.97316
# [31]	validation_0-breslow_likelihood:6.15401	validation_1-breslow_likelihood:3.97125
# [32]	validation_0-breslow_likelihood:6.15376	validation_1-breslow_likelihood:3.97118
# [33]	validation_0-breslow_likelihood:6.15321	validation_1-breslow_likelihood:3.97109
# [34]	validation_0-breslow_likelihood:6.15241	validation_1-breslow_likelihood:3.97044
# [35]	validation_0-breslow_likelihood:6.15213	validation_1-breslow_likelihood:3.96996
# [36]	validation_0-breslow_likelihood:6.15203	validation_1-breslow_likelihood:3.96994
# [37]	validation_0-breslow_likelihood:6.15074	validation_1-breslow_likelihood:3.96954
# [38]	validation_0-breslow_likelihood:6.15015	validation_1-breslow_likelihood:3.96891
# [39]	validation_0-breslow_likelihood:6.14968	validation_1-breslow_likelihood:3.96886
# [40]	validation_0-breslow_likelihood:6.14858	validation_1-breslow_likelihood:3.96826
# [41]	validation_0-breslow_likelihood:6.14791	validation_1-breslow_likelihood:3.96782
# [42]	validation_0-breslow_likelihood:6.14718	validation_1-breslow_likelihood:3.96728
# [43]	validation_0-breslow_likelihood:6.14643	validation_1-breslow_likelihood:3.96646
# [44]	validation_0-breslow_likelihood:6.14570	validation_1-breslow_likelihood:3.96443
# [45]	validation_0-breslow_likelihood:6.14496	validation_1-breslow_likelihood:3.96462
# [46]	validation_0-breslow_likelihood:6.14507	validation_1-breslow_likelihood:3.96468
# [47]	validation_0-breslow_likelihood:6.14445	validation_1-breslow_likelihood:3.96477
# [48]	validation_0-breslow_likelihood:6.14367	validation_1-breslow_likelihood:3.96522
# [49]	validation_0-breslow_likelihood:6.14293	validation_1-breslow_likelihood:3.96578
# [50]	validation_0-breslow_likelihood:6.14237	validation_1-breslow_likelihood:3.96614
# [51]	validation_0-breslow_likelihood:6.14199	validation_1-breslow_likelihood:3.96550
# [52]	validation_0-breslow_likelihood:6.14161	validation_1-breslow_likelihood:3.96463
# [53]	validation_0-breslow_likelihood:6.14061	validation_1-breslow_likelihood:3.96358
# [54]	validation_0-breslow_likelihood:6.14064	validation_1-breslow_likelihood:3.96382
# [55]	validation_0-breslow_likelihood:6.14023	validation_1-breslow_likelihood:3.96232
# [56]	validation_0-breslow_likelihood:6.13993	validation_1-breslow_likelihood:3.96234
# [57]	validation_0-breslow_likelihood:6.13921	validation_1-breslow_likelihood:3.96183
# [58]	validation_0-breslow_likelihood:6.13903	validation_1-breslow_likelihood:3.96192
# [59]	validation_0-breslow_likelihood:6.13870	validation_1-breslow_likelihood:3.96235
# [60]	validation_0-breslow_likelihood:6.13863	validation_1-breslow_likelihood:3.96282
# [61]	validation_0-breslow_likelihood:6.13845	validation_1-breslow_likelihood:3.96260
# [62]	validation_0-breslow_likelihood:6.13772	validation_1-breslow_likelihood:3.96234
# [63]	validation_0-breslow_likelihood:6.13728	validation_1-breslow_likelihood:3.96193
# [64]	validation_0-breslow_likelihood:6.13692	validation_1-breslow_likelihood:3.96160
# [65]	validation_0-breslow_likelihood:6.13651	validation_1-breslow_likelihood:3.96099
# [66]	validation_0-breslow_likelihood:6.13613	validation_1-breslow_likelihood:3.96118
# [67]	validation_0-breslow_likelihood:6.13571	validation_1-breslow_likelihood:3.96060
# [68]	validation_0-breslow_likelihood:6.13559	validation_1-breslow_likelihood:3.96050
# [69]	validation_0-breslow_likelihood:6.13552	validation_1-breslow_likelihood:3.95934
# [70]	validation_0-breslow_likelihood:6.13458	validation_1-breslow_likelihood:3.96003
# [71]	validation_0-breslow_likelihood:6.13440	validation_1-breslow_likelihood:3.96002
# [72]	validation_0-breslow_likelihood:6.13397	validation_1-breslow_likelihood:3.95924
# [73]	validation_0-breslow_likelihood:6.13310	validation_1-breslow_likelihood:3.96032
# [74]	validation_0-breslow_likelihood:6.13303	validation_1-breslow_likelihood:3.96004
# [75]	validation_0-breslow_likelihood:6.13263	validation_1-breslow_likelihood:3.96173
# [76]	validation_0-breslow_likelihood:6.13215	validation_1-breslow_likelihood:3.96132
# [77]	validation_0-breslow_likelihood:6.13166	validation_1-breslow_likelihood:3.96007
# [78]	validation_0-breslow_likelihood:6.13114	validation_1-breslow_likelihood:3.96002
# [79]	validation_0-breslow_likelihood:6.13127	validation_1-breslow_likelihood:3.95933
# [80]	validation_0-breslow_likelihood:6.13102	validation_1-breslow_likelihood:3.95937
# [81]	validation_0-breslow_likelihood:6.13052	validation_1-breslow_likelihood:3.95955
# [82]	validation_0-breslow_likelihood:6.13013	validation_1-breslow_likelihood:3.95974
# [83]	validation_0-breslow_likelihood:6.12943	validation_1-breslow_likelihood:3.96018

# %% [markdown]
# ## Fit Best Model

# %%
grid_result.best_estimator_.fit(X_train, y_train, eval_test_size=0.1)
# Out:
# [0]	validation_0-breslow_likelihood:6.17761	validation_1-breslow_likelihood:3.99178
# [1]	validation_0-breslow_likelihood:6.17730	validation_1-breslow_likelihood:3.99209
# [2]	validation_0-breslow_likelihood:6.17628	validation_1-breslow_likelihood:3.99127
# [3]	validation_0-breslow_likelihood:6.17568	validation_1-breslow_likelihood:3.99107
# [4]	validation_0-breslow_likelihood:6.17492	validation_1-breslow_likelihood:3.99105
# [5]	validation_0-breslow_likelihood:6.17408	validation_1-breslow_likelihood:3.99080
# [6]	validation_0-breslow_likelihood:6.17308	validation_1-breslow_likelihood:3.98983
# [7]	validation_0-breslow_likelihood:6.17253	validation_1-breslow_likelihood:3.98884
# [8]	validation_0-breslow_likelihood:6.17185	validation_1-breslow_likelihood:3.98821
# [9]	validation_0-breslow_likelihood:6.17041	validation_1-breslow_likelihood:3.98663
# [10]	validation_0-breslow_likelihood:6.17007	validation_1-breslow_likelihood:3.98686
# [11]	validation_0-breslow_likelihood:6.16935	validation_1-breslow_likelihood:3.98645
# [12]	validation_0-breslow_likelihood:6.16864	validation_1-breslow_likelihood:3.98553
# [13]	validation_0-breslow_likelihood:6.16749	validation_1-breslow_likelihood:3.98519
# [14]	validation_0-breslow_likelihood:6.16627	validation_1-breslow_likelihood:3.98426
# [15]	validation_0-breslow_likelihood:6.16606	validation_1-breslow_likelihood:3.98344
# [16]	validation_0-breslow_likelihood:6.16588	validation_1-breslow_likelihood:3.98279
# [17]	validation_0-breslow_likelihood:6.16533	validation_1-breslow_likelihood:3.98179
# [18]	validation_0-breslow_likelihood:6.16482	validation_1-breslow_likelihood:3.98056
# [19]	validation_0-breslow_likelihood:6.16386	validation_1-breslow_likelihood:3.98073
# [20]	validation_0-breslow_likelihood:6.16367	validation_1-breslow_likelihood:3.98074
# [21]	validation_0-breslow_likelihood:6.16257	validation_1-breslow_likelihood:3.98041
# [22]	validation_0-breslow_likelihood:6.16180	validation_1-breslow_likelihood:3.97985
# [23]	validation_0-breslow_likelihood:6.16077	validation_1-breslow_likelihood:3.97868
# [24]	validation_0-breslow_likelihood:6.15953	validation_1-breslow_likelihood:3.97859
# [25]	validation_0-breslow_likelihood:6.15887	validation_1-breslow_likelihood:3.97825
# [26]	validation_0-breslow_likelihood:6.15826	validation_1-breslow_likelihood:3.97740
# [27]	validation_0-breslow_likelihood:6.15749	validation_1-breslow_likelihood:3.97612
# [28]	validation_0-breslow_likelihood:6.15667	validation_1-breslow_likelihood:3.97421
# [29]	validation_0-breslow_likelihood:6.15629	validation_1-breslow_likelihood:3.97418
# [30]	validation_0-breslow_likelihood:6.15550	validation_1-breslow_likelihood:3.97316
# [31]	validation_0-breslow_likelihood:6.15401	validation_1-breslow_likelihood:3.97125
# [32]	validation_0-breslow_likelihood:6.15376	validation_1-breslow_likelihood:3.97118
# [33]	validation_0-breslow_likelihood:6.15321	validation_1-breslow_likelihood:3.97109
# [34]	validation_0-breslow_likelihood:6.15241	validation_1-breslow_likelihood:3.97044
# [35]	validation_0-breslow_likelihood:6.15213	validation_1-breslow_likelihood:3.96996
# [36]	validation_0-breslow_likelihood:6.15203	validation_1-breslow_likelihood:3.96994
# [37]	validation_0-breslow_likelihood:6.15074	validation_1-breslow_likelihood:3.96954
# [38]	validation_0-breslow_likelihood:6.15015	validation_1-breslow_likelihood:3.96891
# [39]	validation_0-breslow_likelihood:6.14968	validation_1-breslow_likelihood:3.96886
# [40]	validation_0-breslow_likelihood:6.14858	validation_1-breslow_likelihood:3.96826
# [41]	validation_0-breslow_likelihood:6.14791	validation_1-breslow_likelihood:3.96782
# [42]	validation_0-breslow_likelihood:6.14718	validation_1-breslow_likelihood:3.96728
# [43]	validation_0-breslow_likelihood:6.14643	validation_1-breslow_likelihood:3.96646
# [44]	validation_0-breslow_likelihood:6.14570	validation_1-breslow_likelihood:3.96443
# [45]	validation_0-breslow_likelihood:6.14496	validation_1-breslow_likelihood:3.96462
# [46]	validation_0-breslow_likelihood:6.14507	validation_1-breslow_likelihood:3.96468
# [47]	validation_0-breslow_likelihood:6.14445	validation_1-breslow_likelihood:3.96477
# [48]	validation_0-breslow_likelihood:6.14367	validation_1-breslow_likelihood:3.96522
# [49]	validation_0-breslow_likelihood:6.14293	validation_1-breslow_likelihood:3.96578
# [50]	validation_0-breslow_likelihood:6.14237	validation_1-breslow_likelihood:3.96614
# [51]	validation_0-breslow_likelihood:6.14199	validation_1-breslow_likelihood:3.96550
# [52]	validation_0-breslow_likelihood:6.14161	validation_1-breslow_likelihood:3.96463
# [53]	validation_0-breslow_likelihood:6.14061	validation_1-breslow_likelihood:3.96358
# [54]	validation_0-breslow_likelihood:6.14064	validation_1-breslow_likelihood:3.96382
# [55]	validation_0-breslow_likelihood:6.14023	validation_1-breslow_likelihood:3.96232
# [56]	validation_0-breslow_likelihood:6.13993	validation_1-breslow_likelihood:3.96234
# [57]	validation_0-breslow_likelihood:6.13921	validation_1-breslow_likelihood:3.96183
# [58]	validation_0-breslow_likelihood:6.13903	validation_1-breslow_likelihood:3.96192
# [59]	validation_0-breslow_likelihood:6.13870	validation_1-breslow_likelihood:3.96235
# [60]	validation_0-breslow_likelihood:6.13863	validation_1-breslow_likelihood:3.96282
# [61]	validation_0-breslow_likelihood:6.13845	validation_1-breslow_likelihood:3.96260
# [62]	validation_0-breslow_likelihood:6.13772	validation_1-breslow_likelihood:3.96234
# [63]	validation_0-breslow_likelihood:6.13728	validation_1-breslow_likelihood:3.96193
# [64]	validation_0-breslow_likelihood:6.13692	validation_1-breslow_likelihood:3.96160
# [65]	validation_0-breslow_likelihood:6.13651	validation_1-breslow_likelihood:3.96099
# [66]	validation_0-breslow_likelihood:6.13613	validation_1-breslow_likelihood:3.96118
# [67]	validation_0-breslow_likelihood:6.13571	validation_1-breslow_likelihood:3.96060
# [68]	validation_0-breslow_likelihood:6.13559	validation_1-breslow_likelihood:3.96050
# [69]	validation_0-breslow_likelihood:6.13552	validation_1-breslow_likelihood:3.95934
# [70]	validation_0-breslow_likelihood:6.13458	validation_1-breslow_likelihood:3.96003
# [71]	validation_0-breslow_likelihood:6.13440	validation_1-breslow_likelihood:3.96002
# [72]	validation_0-breslow_likelihood:6.13397	validation_1-breslow_likelihood:3.95924
# [73]	validation_0-breslow_likelihood:6.13310	validation_1-breslow_likelihood:3.96032
# [74]	validation_0-breslow_likelihood:6.13303	validation_1-breslow_likelihood:3.96004
# [75]	validation_0-breslow_likelihood:6.13263	validation_1-breslow_likelihood:3.96173
# [76]	validation_0-breslow_likelihood:6.13215	validation_1-breslow_likelihood:3.96132
# [77]	validation_0-breslow_likelihood:6.13166	validation_1-breslow_likelihood:3.96007
# [78]	validation_0-breslow_likelihood:6.13114	validation_1-breslow_likelihood:3.96002
# [79]	validation_0-breslow_likelihood:6.13127	validation_1-breslow_likelihood:3.95933
# [80]	validation_0-breslow_likelihood:6.13102	validation_1-breslow_likelihood:3.95937
# [81]	validation_0-breslow_likelihood:6.13052	validation_1-breslow_likelihood:3.95955
# [82]	validation_0-breslow_likelihood:6.13013	validation_1-breslow_likelihood:3.95974
# [83]	validation_0-breslow_likelihood:6.12943	validation_1-breslow_likelihood:3.96018
# XGBSurv(alpha=0.011870553892155444, base_score=None, booster=None,
#         callbacks=None, colsample_bylevel=0.5600455784222086,
#         colsample_bynode=0.9954311703965663,
#         colsample_bytree=0.9088679002722677, disable_default_eval_metric=True,
#         early_stopping_rounds=11, enable_categorical=False,
#         eval_metric=CPUDispatcher(<function breslow_likelihood at 0x7f89297445e0>),
#         feature...6, gpu_id=None,
#         grow_policy=None, importance_type=None, interaction_constraints=None,
#         learning_rate=0.015022574285782025, max_bin=None,
#         max_cat_threshold=None, max_cat_to_onehot=None, max_delta_step=9,
#         max_depth=12, max_leaves=None, min_child_weight=15.514576291395171,
#         missing=nan, monotone_constraints=None, n_estimators=93, n_jobs=None,
#         num_parallel_tree=None, ...)

# %%
preds_train = bmodel.predict(X_train, output_margin=True)
preds_test = bmodel.predict(X_test, output_margin=True)

# %%
# train
cindex_censored(y_train, preds_train)
# Out:
# 0.6649808870518152

# %%
# test
cindex_censored(y_test, preds_test)
# Out:
# 0.6278086707093073
